# %% [markdown]
# # Management - Gen 2 Torsion 2

# %% [markdown]
# For large molecules, accept errors. Make new dataset version with errors left out.

# %%
import qcportal as ptl
import pandas as pd
import datetime
import time

from management import *

# %% [raw]
# # connect without auth
# # read only
# client = ptl.FractalClient()

# %%
# connect with authentication, therefore write access
# don't use unless you plan to submit things
client = ptl.FractalClient.from_file()

# %%
client
# Out:
# FractalClient(server_name='The MolSSI QCArchive Server', address='https://api.qcarchive.molssi.org:443/', username='ddotson')

# %% [markdown]
# ## Dataset tracking - OpenFF Gen 2 Torsion Set 1 Roche 2

# %% [markdown]
# ### 2020.06.27 01:10 UTC

# %%
dataset = "OpenFF Gen 2 Torsion Set 1 Roche 2"

# %%
ds = client.get_collection("TorsionDriveDataset", dataset)

# %%
ds.list_specifications()
# Out:
#                                          Description
# Name
# default  Standard OpenFF torsiondrive specification.

# %%
res = get_unfinished_torsiondrive_optimizations(ds, 'default', client)
res
# Out:
# {'18045309': [OptimizationRecord(id='18045374', status='COMPLETE'),
#   OptimizationRecord(id='18045584', status='COMPLETE'),
#   OptimizationRecord(id='18045585', status='COMPLETE'),
#   OptimizationRecord(id='18047897', status='COMPLETE'),
#   OptimizationRecord(id='18047898', status='COMPLETE'),
#   OptimizationRecord(id='18047899', status='INCOMPLETE'),
#   OptimizationRecord(id='18047900', status='COMPLETE')],
#  '18045317': [OptimizationRecord(id='18045386', status='COMPLETE'),
#   OptimizationRecord(id='18046176', status='COMPLETE'),
#   OptimizationRecord(id='18046177', status='COMPLETE'),
#   OptimizationRecord(id='18052471', status='COMPLETE'),
#   OptimizationRecord(id='18052472', status='COMPLETE'),
#   OptimizationRecord(id='18052473', status='COMPLETE'),
#   OptimizationRecord(id='18052474', status='INCOMPLETE')],
#  '18045321': [OptimizationRecord(id='18045393', status='COMPLETE'),
#   OptimizationRecord(id='18046677', status='COMPLETE'),
#   OptimizationRecord(id='18046678', status='COMPLETE'),
#   OptimizationRecord(id='18058695', status='COMPLETE'),
#   OptimizationRecord(id='18058696', status='COMPLETE'),
#   OptimizationRecord(id='18058697', status='COMPLETE'),
#   OptimizationRecord(id='18058698', status='COMPLETE'),
#   OptimizationRecord(id='18070236', status='COMPLETE'),
#   OptimizationRecord(id='18070237', status='COMPLETE'),
#   OptimizationRecord(id='18070238', status='COMPLETE'),
#   OptimizationRecord(id='18070239', status='COMPLETE'),
#   OptimizationRecord(id='18087845', status='COMPLETE'),
#   OptimizationRecord(id='18087846', status='COMPLETE'),
#   OptimizationRecord(id='18087847', status='COMPLETE'),
#   OptimizationRecord(id='18087848', status='COMPLETE'),
#   OptimizationRecord(id='18101580', status='COMPLETE'),
#   OptimizationRecord(id='18101590', status='COMPLETE'),
#   OptimizationRecord(id='18101591', status='COMPLETE'),
#   OptimizationRecord(id='18101605', status='COMPLETE'),
#   OptimizationRecord(id='18112988', status='COMPLETE'),
#   OptimizationRecord(id='18112989', status='COMPLETE'),
#   OptimizationRecord(id='18112990', status='COMPLETE'),
#   OptimizationRecord(id='18112991', status='COMPLETE'),
#   OptimizationRecord(id='18129130', status='COMPLETE'),
#   OptimizationRecord(id='18129131', status='COMPLETE'),
#   OptimizationRecord(id='18129132', status='COMPLETE'),
#   OptimizationRecord(id='18129144', status='COMPLETE'),
#   OptimizationRecord(id='18136428', status='COMPLETE'),
#   OptimizationRecord(id='18136444', status='COMPLETE'),
#   OptimizationRecord(id='18136445', status='COMPLETE'),
#   OptimizationRecord(id='18136446', status='COMPLETE'),
#   OptimizationRecord(id='18144949', status='COMPLETE'),
#   OptimizationRecord(id='18144950', status='COMPLETE'),
#   OptimizationRecord(id='18144951', status='INCOMPLETE'),
#   OptimizationRecord(id='18144952', status='COMPLETE')],
#  '18045349': [OptimizationRecord(id='18045458', status='COMPLETE'),
#   OptimizationRecord(id='18046572', status='COMPLETE'),
#   OptimizationRecord(id='18046573', status='COMPLETE'),
#   OptimizationRecord(id='18055296', status='COMPLETE'),
#   OptimizationRecord(id='18055297', status='COMPLETE'),
#   OptimizationRecord(id='18055298', status='COMPLETE'),
#   OptimizationRecord(id='18055299', status='COMPLETE'),
#   OptimizationRecord(id='18149799', status='COMPLETE'),
#   OptimizationRecord(id='18149800', status='COMPLETE'),
#   OptimizationRecord(id='18149801', status='COMPLETE'),
#   OptimizationRecord(id='18149802', status='COMPLETE'),
#   OptimizationRecord(id='18158671', status='COMPLETE'),
#   OptimizationRecord(id='18158672', status='COMPLETE'),
#   OptimizationRecord(id='18158673', status='COMPLETE'),
#   OptimizationRecord(id='18158674', status='COMPLETE'),
#   OptimizationRecord(id='18165875', status='COMPLETE'),
#   OptimizationRecord(id='18165901', status='COMPLETE'),
#   OptimizationRecord(id='18165902', status='COMPLETE'),
#   OptimizationRecord(id='18165903', status='COMPLETE'),
#   OptimizationRecord(id='18174168', status='COMPLETE'),
#   OptimizationRecord(id='18174169', status='COMPLETE'),
#   OptimizationRecord(id='18174170', status='COMPLETE'),
#   OptimizationRecord(id='18174171', status='COMPLETE'),
#   OptimizationRecord(id='18186493', status='COMPLETE'),
#   OptimizationRecord(id='18186494', status='COMPLETE'),
#   OptimizationRecord(id='18186495', status='COMPLETE'),
#   OptimizationRecord(id='18186496', status='INCOMPLETE')],
#  '18535895': [OptimizationRecord(id='18045525', status='COMPLETE'),
#   OptimizationRecord(id='18045526', status='COMPLETE'),
#   OptimizationRecord(id='18045527', status='COMPLETE'),
#   OptimizationRecord(id='18045528', status='COMPLETE'),
#   OptimizationRecord(id='18047962', status='INCOMPLETE'),
#   OptimizationRecord(id='18047963', status='COMPLETE'),
#   OptimizationRecord(id='18047964', status='COMPLETE'),
#   OptimizationRecord(id='18047965', status='COMPLETE')],
#  '18535900': [OptimizationRecord(id='18045536', status='ERROR'),
#   OptimizationRecord(id='18045537', status='COMPLETE'),
#   OptimizationRecord(id='18045538', status='ERROR'),
#   OptimizationRecord(id='18045539', status='ERROR'),
#   OptimizationRecord(id='18045540', status='ERROR')]}

# %%
resm = merge(res)

# %%
incomplete = (opt.dict() for opt in resm if opt.status == 'INCOMPLETE')

# %%
next(incomplete)
# Out:
# {'id': '18047899',
#  'hash_index': 'b1628857d19f073372327b18f6140be254e4be5b',
#  'procedure': 'optimization',
#  'program': 'geometric',
#  'version': 1,
#  'protocols': {},
#  'extras': {},
#  'stdout': '20995173',
#  'stderr': None,
#  'error': None,
#  'task_id': None,
#  'manager_name': None,
#  'status': <RecordStatusEnum.incomplete: 'INCOMPLETE'>,
#  'modified_on': datetime.datetime(2020, 3, 14, 1, 24, 46, 892186),
#  'created_on': datetime.datetime(2020, 3, 13, 21, 16, 9, 469776),
#  'provenance': {'creator': 'geomeTRIC',
#   'version': '0.9.7.2',
#   'routine': 'geometric.run_json.geometric_run_json',
#   'qcengine_version': '0.14.0',
#   'wall_time': 84.95713329315186,
#   'cpu': 'Intel(R) Xeon(R) CPU E5-2697 v4 @ 2.30GHz',
#   'username': 'chodera',
#   'hostname': 'ls13'},
#  'schema_version': 1,
#  'initial_molecule': '11767251',
#  'qc_spec': {'driver': <DriverEnum.gradient: 'gradient'>,
#   'method': 'b3lyp-d3bj',
#   'basis': 'dzvp',
#   'keywords': '2',
#   'program': 'psi4'},
#  'keywords': {'coordsys': 'tric',
#   'enforce': 0.1,
#   'reset': True,
#   'qccnv': True,
#   'epsilon': 0,
#   'constraints': {'set': [{'type': 'dihedral',
#      'indices': [0, 2, 3, 1],
#      'value': 75}]},
#   'program': 'psi4'},
#  'energies': [-158.48473542907092,
#   -158.48515692494664,
#   -158.48544337560912,
#   -158.48577360513067,
#   -158.48602622446123,
#   -158.48615254821843,
#   -158.48615891570498,
#   -158.48617408222924,
#   -158.48618005791081,
#   -158.4861826531143,
#   -158.48618276434942],
#  'final_molecule': '11781143',
#  'trajectory': ['18047886',
#   '18062745',
#   '18062747',
#   '18062749',
#   '18062751',
#   '18062753',
#   '18062755',
#   '18062757',
#   '18062759',
#   '18062761',
#   '18062762']}

# %% [markdown]
# All Lilac INCOMPLETEs

# %%
count_unique_optimization_error_messages(resm, full=True, pretty_print=True)
# Out:
# There are 1 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1298, in optimizeGeometry
#     self.calcEnergyForce()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1002, in calcEnergyForce
#     spcalc = self.engine.calc(self.X, self.dirname)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/engine.py", line 873, in calc
#     return self.calc_new(coords, dirname)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/engine.py", line 865, in calc_new
#     raise QCEngineAPIEngineError("QCEngineAPI computation did not execute correctly. Message: " + ret["error"]["error_message"])
# geometric.errors.QCEngineAPIEngineError: QCEngineAPI computation did not execute correctly. Message: QCEngine Unknown Error: Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/json_wrapper.py", line 217, in run_json
#     json_data = run_json_qcschema(copy.deepcopy(json_data), clean)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/json_wrapper.py", line 312, in run_json_qcschema
#     val, wfn = methods_dict_[json_data["driver"]](method, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/driver.py", line 691, in gradient
#     wfn = procedures['gradient'][lowername](lowername, molecule=molecule, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/proc.py", line 2064, in run_scf_gradient
#     ref_wfn = run_scf(name, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/proc.py", line 2002, in run_scf
#     scf_wfn = scf_helper(name, post_scf=False, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/proc.py", line 1363, in scf_helper
#     e_scf = scf_wfn.compute_energy()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 94, in scf_compute_energy
#     raise e
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 87, in scf_compute_energy
#     self.iterations()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 447, in scf_iterate
#     raise SCFConvergenceError("""SCF iterations""", self.iteration_, self, Ediff, Dnorm)
# psi4.driver.p4util.exceptions.SCFConvergenceError: Could not converge SCF iterations in 200 iterations.
#
#
# -------------------------------------
#
# There are 3 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1296, in optimizeGeometry
#     self.step()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1100, in step
#     self.checkCoordinateSystem(recover=True, cartesian=LastForce)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 959, in checkCoordinateSystem
#     raise ValueError("Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates")
# ValueError: Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates
#
# -------------------------------------

# %%
restart_optimizations(resm, client)
# Out:
# OptimizationRecord(id='18045536', status='ERROR')
# OptimizationRecord(id='18045538', status='ERROR')
# OptimizationRecord(id='18045539', status='ERROR')
# OptimizationRecord(id='18045540', status='ERROR')

# %%
[tdr for tdr in ds.df.default if tdr.status == 'ERROR']
# Out:
# [TorsionDriveRecord(id='18535900', status='ERROR')]

# %%
restart_torsiondrives(ds.df.default.tolist(), client)
# Out:
# TorsionDriveRecord(id='18535900', status='ERROR')

# %% [markdown]
# ### 2020.06.11 22:15 UTC

# %%
dataset = "OpenFF Gen 2 Torsion Set 1 Roche 2"

# %%
ds = client.get_collection("TorsionDriveDataset", dataset)

# %%
ds.list_specifications()
# Out:
#                                          Description
# Name
# default  Standard OpenFF torsiondrive specification.

# %%
res = get_unfinished_torsiondrive_optimizations(ds, 'default', client, merged=False)
res
# Out:
# {'18045309': [OptimizationRecord(id='18045374', status='COMPLETE'),
#   OptimizationRecord(id='18045584', status='COMPLETE'),
#   OptimizationRecord(id='18045585', status='COMPLETE'),
#   OptimizationRecord(id='18047897', status='COMPLETE'),
#   OptimizationRecord(id='18047898', status='COMPLETE'),
#   OptimizationRecord(id='18047899', status='INCOMPLETE'),
#   OptimizationRecord(id='18047900', status='COMPLETE')],
#  '18045317': [OptimizationRecord(id='18045386', status='COMPLETE'),
#   OptimizationRecord(id='18046176', status='COMPLETE'),
#   OptimizationRecord(id='18046177', status='COMPLETE'),
#   OptimizationRecord(id='18052471', status='COMPLETE'),
#   OptimizationRecord(id='18052472', status='COMPLETE'),
#   OptimizationRecord(id='18052473', status='COMPLETE'),
#   OptimizationRecord(id='18052474', status='INCOMPLETE')],
#  '18045321': [OptimizationRecord(id='18045393', status='COMPLETE'),
#   OptimizationRecord(id='18046677', status='COMPLETE'),
#   OptimizationRecord(id='18046678', status='COMPLETE'),
#   OptimizationRecord(id='18058695', status='COMPLETE'),
#   OptimizationRecord(id='18058696', status='COMPLETE'),
#   OptimizationRecord(id='18058697', status='COMPLETE'),
#   OptimizationRecord(id='18058698', status='COMPLETE'),
#   OptimizationRecord(id='18070236', status='COMPLETE'),
#   OptimizationRecord(id='18070237', status='COMPLETE'),
#   OptimizationRecord(id='18070238', status='COMPLETE'),
#   OptimizationRecord(id='18070239', status='COMPLETE'),
#   OptimizationRecord(id='18087845', status='COMPLETE'),
#   OptimizationRecord(id='18087846', status='COMPLETE'),
#   OptimizationRecord(id='18087847', status='COMPLETE'),
#   OptimizationRecord(id='18087848', status='COMPLETE'),
#   OptimizationRecord(id='18101580', status='COMPLETE'),
#   OptimizationRecord(id='18101590', status='COMPLETE'),
#   OptimizationRecord(id='18101591', status='COMPLETE'),
#   OptimizationRecord(id='18101605', status='COMPLETE'),
#   OptimizationRecord(id='18112988', status='COMPLETE'),
#   OptimizationRecord(id='18112989', status='COMPLETE'),
#   OptimizationRecord(id='18112990', status='COMPLETE'),
#   OptimizationRecord(id='18112991', status='COMPLETE'),
#   OptimizationRecord(id='18129130', status='COMPLETE'),
#   OptimizationRecord(id='18129131', status='COMPLETE'),
#   OptimizationRecord(id='18129132', status='COMPLETE'),
#   OptimizationRecord(id='18129144', status='COMPLETE'),
#   OptimizationRecord(id='18136428', status='COMPLETE'),
#   OptimizationRecord(id='18136444', status='COMPLETE'),
#   OptimizationRecord(id='18136445', status='COMPLETE'),
#   OptimizationRecord(id='18136446', status='COMPLETE'),
#   OptimizationRecord(id='18144949', status='COMPLETE'),
#   OptimizationRecord(id='18144950', status='COMPLETE'),
#   OptimizationRecord(id='18144951', status='INCOMPLETE'),
#   OptimizationRecord(id='18144952', status='COMPLETE')],
#  '18045349': [OptimizationRecord(id='18045458', status='COMPLETE'),
#   OptimizationRecord(id='18046572', status='COMPLETE'),
#   OptimizationRecord(id='18046573', status='COMPLETE'),
#   OptimizationRecord(id='18055296', status='COMPLETE'),
#   OptimizationRecord(id='18055297', status='COMPLETE'),
#   OptimizationRecord(id='18055298', status='COMPLETE'),
#   OptimizationRecord(id='18055299', status='COMPLETE'),
#   OptimizationRecord(id='18149799', status='COMPLETE'),
#   OptimizationRecord(id='18149800', status='COMPLETE'),
#   OptimizationRecord(id='18149801', status='COMPLETE'),
#   OptimizationRecord(id='18149802', status='COMPLETE'),
#   OptimizationRecord(id='18158671', status='COMPLETE'),
#   OptimizationRecord(id='18158672', status='COMPLETE'),
#   OptimizationRecord(id='18158673', status='COMPLETE'),
#   OptimizationRecord(id='18158674', status='COMPLETE'),
#   OptimizationRecord(id='18165875', status='COMPLETE'),
#   OptimizationRecord(id='18165901', status='COMPLETE'),
#   OptimizationRecord(id='18165902', status='COMPLETE'),
#   OptimizationRecord(id='18165903', status='COMPLETE'),
#   OptimizationRecord(id='18174168', status='COMPLETE'),
#   OptimizationRecord(id='18174169', status='COMPLETE'),
#   OptimizationRecord(id='18174170', status='COMPLETE'),
#   OptimizationRecord(id='18174171', status='COMPLETE'),
#   OptimizationRecord(id='18186493', status='COMPLETE'),
#   OptimizationRecord(id='18186494', status='COMPLETE'),
#   OptimizationRecord(id='18186495', status='COMPLETE'),
#   OptimizationRecord(id='18186496', status='INCOMPLETE')],
#  '18535895': [OptimizationRecord(id='18045525', status='COMPLETE'),
#   OptimizationRecord(id='18045526', status='COMPLETE'),
#   OptimizationRecord(id='18045527', status='COMPLETE'),
#   OptimizationRecord(id='18045528', status='COMPLETE'),
#   OptimizationRecord(id='18047962', status='INCOMPLETE'),
#   OptimizationRecord(id='18047963', status='COMPLETE'),
#   OptimizationRecord(id='18047964', status='COMPLETE'),
#   OptimizationRecord(id='18047965', status='COMPLETE')],
#  '18535900': [OptimizationRecord(id='18045536', status='ERROR'),
#   OptimizationRecord(id='18045537', status='COMPLETE'),
#   OptimizationRecord(id='18045538', status='ERROR'),
#   OptimizationRecord(id='18045539', status='ERROR'),
#   OptimizationRecord(id='18045540', status='ERROR')]}

# %%
resm = merge(res)

# %%
incomplete = (opt.dict() for opt in resm if opt.status == 'INCOMPLETE')

# %%
next(incomplete)
# Out:
# {'id': '18144951',
#  'hash_index': '7948db9825b89a7819a0e9725ba59fc21c257117',
#  'procedure': 'optimization',
#  'program': 'geometric',
#  'version': 1,
#  'protocols': {},
#  'extras': {},
#  'stdout': '21095991',
#  'stderr': None,
#  'error': None,
#  'task_id': None,
#  'manager_name': None,
#  'status': <RecordStatusEnum.incomplete: 'INCOMPLETE'>,
#  'modified_on': datetime.datetime(2020, 3, 16, 21, 37, 59, 524188),
#  'created_on': datetime.datetime(2020, 3, 14, 10, 0, 10, 126729),
#  'provenance': {'creator': 'geomeTRIC',
#   'version': '0.9.7.2',
#   'routine': 'geometric.run_json.geometric_run_json',
#   'cpu': 'Intel(R) Xeon(R) CPU E5-2697 v4 @ 2.30GHz',
#   'wall_time': 445.01690459251404,
#   'username': 'chodera',
#   'hostname': 'lt15',
#   'qcengine_version': '0.14.0'},
#  'schema_version': 1,
#  'initial_molecule': '11854550',
#  'qc_spec': {'driver': <DriverEnum.gradient: 'gradient'>,
#   'method': 'b3lyp-d3bj',
#   'basis': 'dzvp',
#   'keywords': '2',
#   'program': 'psi4'},
#  'keywords': {'coordsys': 'tric',
#   'enforce': 0.1,
#   'reset': True,
#   'qccnv': True,
#   'epsilon': 0,
#   'constraints': {'set': [{'type': 'dihedral',
#      'indices': [8, 2, 6, 9],
#      'value': 135}]},
#   'program': 'psi4'},
#  'energies': [-512.9569500855227,
#   -512.9563927316079,
#   -512.9561161206278,
#   -512.9556242092958,
#   -512.9557692851557,
#   -512.9558823699228,
#   -512.9559158615513,
#   -512.9559446314839,
#   -512.9559438218103,
#   -512.9559783275754,
#   -512.9559818159315,
#   -512.9559908765304,
#   -512.9559940678564,
#   -512.955998239715,
#   -512.9560037410599,
#   -512.9560111840626,
#   -512.9560178156157,
#   -512.9560197236941,
#   -512.9560209022359,
#   -512.9560214606527],
#  'final_molecule': '11862384',
#  'trajectory': ['18142202',
#   '18150862',
#   '18150863',
#   '18150864',
#   '18150865',
#   '18150866',
#   '18150867',
#   '18150868',
#   '18150869',
#   '18150870',
#   '18150871',
#   '18150872',
#   '18150873',
#   '18150874',
#   '18150875',
#   '18150876',
#   '18150877',
#   '18150878',
#   '18150879',
#   '18150880']}

# %% [markdown]
# All Lilac INCOMPLETEs?

# %%
count_unique_optimization_error_messages(resm, full=True, pretty_print=True)
# Out:
# There are 4 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1296, in optimizeGeometry
#     self.step()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1100, in step
#     self.checkCoordinateSystem(recover=True, cartesian=LastForce)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 959, in checkCoordinateSystem
#     raise ValueError("Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates")
# ValueError: Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates
#
# -------------------------------------

# %%
restart_optimizations(resm, client)
# Out:
# OptimizationRecord(id='18045536', status='ERROR')
# OptimizationRecord(id='18045538', status='ERROR')
# OptimizationRecord(id='18045539', status='ERROR')
# OptimizationRecord(id='18045540', status='ERROR')

# %%
[tdr for tdr in ds.df.default if tdr.status == 'ERROR']
# Out:
# [TorsionDriveRecord(id='18535900', status='ERROR')]

# %%
restart_torsiondrives(ds.df.default.tolist(), client)
# Out:
# TorsionDriveRecord(id='18535900', status='ERROR')

# %% [markdown]
# ## Dataset tracking - OpenFF Gen 2 Torsion Set 2 Coverage 2

# %% [markdown]
# ### 2020.06.27 01:15 UTC

# %%
dataset = "OpenFF Gen 2 Torsion Set 2 Coverage 2"

# %%
ds = client.get_collection("TorsionDriveDataset", dataset)

# %%
ds.list_specifications()
# Out:
#                                          Description
# Name
# default  Standard OpenFF torsiondrive specification.

# %%
res = get_unfinished_torsiondrive_optimizations(ds, 'default', client)
res
# Out:
# {'18536034': [OptimizationRecord(id='18536837', status='COMPLETE'),
#   OptimizationRecord(id='18556386', status='COMPLETE'),
#   OptimizationRecord(id='18556387', status='COMPLETE'),
#   OptimizationRecord(id='18563815', status='COMPLETE'),
#   OptimizationRecord(id='18563816', status='COMPLETE'),
#   OptimizationRecord(id='18563817', status='COMPLETE'),
#   OptimizationRecord(id='18563818', status='COMPLETE'),
#   OptimizationRecord(id='18581746', status='COMPLETE'),
#   OptimizationRecord(id='18581747', status='COMPLETE'),
#   OptimizationRecord(id='18581748', status='COMPLETE'),
#   OptimizationRecord(id='18581749', status='COMPLETE'),
#   OptimizationRecord(id='18593042', status='COMPLETE'),
#   OptimizationRecord(id='18593043', status='COMPLETE'),
#   OptimizationRecord(id='18593044', status='COMPLETE'),
#   OptimizationRecord(id='18593045', status='COMPLETE'),
#   OptimizationRecord(id='18599295', status='COMPLETE'),
#   OptimizationRecord(id='18599296', status='COMPLETE'),
#   OptimizationRecord(id='18599297', status='COMPLETE'),
#   OptimizationRecord(id='18599298', status='COMPLETE'),
#   OptimizationRecord(id='18608910', status='COMPLETE'),
#   OptimizationRecord(id='18608911', status='COMPLETE'),
#   OptimizationRecord(id='18608912', status='ERROR'),
#   OptimizationRecord(id='18608913', status='COMPLETE')],
#  '18536035': [OptimizationRecord(id='18536896', status='COMPLETE'),
#   OptimizationRecord(id='18555593', status='COMPLETE'),
#   OptimizationRecord(id='18555594', status='COMPLETE'),
#   OptimizationRecord(id='18600678', status='COMPLETE'),
#   OptimizationRecord(id='18600679', status='COMPLETE'),
#   OptimizationRecord(id='18600680', status='COMPLETE'),
#   OptimizationRecord(id='18600681', status='COMPLETE'),
#   OptimizationRecord(id='18609138', status='ERROR'),
#   OptimizationRecord(id='18609139', status='COMPLETE')],
#  '18536082': [OptimizationRecord(id='18045818', status='COMPLETE'),
#   OptimizationRecord(id='18045819', status='COMPLETE'),
#   OptimizationRecord(id='18045820', status='COMPLETE'),
#   OptimizationRecord(id='18045821', status='COMPLETE'),
#   OptimizationRecord(id='18045822', status='COMPLETE'),
#   OptimizationRecord(id='18045823', status='COMPLETE'),
#   OptimizationRecord(id='18045824', status='COMPLETE'),
#   OptimizationRecord(id='18045825', status='COMPLETE'),
#   OptimizationRecord(id='18058703', status='COMPLETE'),
#   OptimizationRecord(id='18058704', status='COMPLETE'),
#   OptimizationRecord(id='18058705', status='COMPLETE'),
#   OptimizationRecord(id='18058706', status='COMPLETE'),
#   OptimizationRecord(id='18058707', status='COMPLETE'),
#   OptimizationRecord(id='18058708', status='COMPLETE'),
#   OptimizationRecord(id='18058709', status='COMPLETE'),
#   OptimizationRecord(id='18058710', status='COMPLETE'),
#   OptimizationRecord(id='18058711', status='COMPLETE'),
#   OptimizationRecord(id='18058712', status='COMPLETE'),
#   OptimizationRecord(id='18058713', status='COMPLETE'),
#   OptimizationRecord(id='18058714', status='COMPLETE'),
#   OptimizationRecord(id='18080103', status='COMPLETE'),
#   OptimizationRecord(id='18080104', status='COMPLETE'),
#   OptimizationRecord(id='18080105', status='COMPLETE'),
#   OptimizationRecord(id='18080106', status='COMPLETE'),
#   OptimizationRecord(id='18080107', status='COMPLETE'),
#   OptimizationRecord(id='18080108', status='COMPLETE'),
#   OptimizationRecord(id='18080109', status='COMPLETE'),
#   OptimizationRecord(id='18080110', status='COMPLETE'),
#   OptimizationRecord(id='18080111', status='COMPLETE'),
#   OptimizationRecord(id='18080112', status='COMPLETE'),
#   OptimizationRecord(id='18080113', status='COMPLETE'),
#   OptimizationRecord(id='18080114', status='COMPLETE'),
#   OptimizationRecord(id='18080115', status='COMPLETE'),
#   OptimizationRecord(id='18080133', status='COMPLETE'),
#   OptimizationRecord(id='18080134', status='COMPLETE'),
#   OptimizationRecord(id='18080151', status='COMPLETE'),
#   OptimizationRecord(id='18080165', status='COMPLETE'),
#   OptimizationRecord(id='18080178', status='COMPLETE'),
#   OptimizationRecord(id='18102688', status='COMPLETE'),
#   OptimizationRecord(id='18102689', status='COMPLETE'),
#   OptimizationRecord(id='18102690', status='COMPLETE'),
#   OptimizationRecord(id='18102691', status='COMPLETE'),
#   OptimizationRecord(id='18102692', status='COMPLETE'),
#   OptimizationRecord(id='18102693', status='COMPLETE'),
#   OptimizationRecord(id='18102694', status='COMPLETE'),
#   OptimizationRecord(id='18102695', status='COMPLETE'),
#   OptimizationRecord(id='18102696', status='COMPLETE'),
#   OptimizationRecord(id='18102697', status='COMPLETE'),
#   OptimizationRecord(id='18102698', status='COMPLETE'),
#   OptimizationRecord(id='18102699', status='COMPLETE'),
#   OptimizationRecord(id='18102700', status='COMPLETE'),
#   OptimizationRecord(id='18102701', status='COMPLETE'),
#   OptimizationRecord(id='18102702', status='COMPLETE'),
#   OptimizationRecord(id='18102703', status='COMPLETE'),
#   OptimizationRecord(id='18129151', status='COMPLETE'),
#   OptimizationRecord(id='18129152', status='COMPLETE'),
#   OptimizationRecord(id='18129153', status='COMPLETE'),
#   OptimizationRecord(id='18129154', status='COMPLETE'),
#   OptimizationRecord(id='18129155', status='COMPLETE'),
#   OptimizationRecord(id='18129156', status='COMPLETE'),
#   OptimizationRecord(id='18129157', status='COMPLETE'),
#   OptimizationRecord(id='18129158', status='COMPLETE'),
#   OptimizationRecord(id='18129159', status='COMPLETE'),
#   OptimizationRecord(id='18129160', status='COMPLETE'),
#   OptimizationRecord(id='18129161', status='COMPLETE'),
#   OptimizationRecord(id='18129162', status='COMPLETE'),
#   OptimizationRecord(id='18129163', status='COMPLETE'),
#   OptimizationRecord(id='18129164', status='COMPLETE'),
#   OptimizationRecord(id='18144347', status='COMPLETE'),
#   OptimizationRecord(id='18144348', status='COMPLETE'),
#   OptimizationRecord(id='18144349', status='COMPLETE'),
#   OptimizationRecord(id='18144350', status='COMPLETE'),
#   OptimizationRecord(id='18144363', status='COMPLETE'),
#   OptimizationRecord(id='18144364', status='COMPLETE'),
#   OptimizationRecord(id='18144365', status='INCOMPLETE'),
#   OptimizationRecord(id='18144366', status='COMPLETE')],
#  '18536087': [OptimizationRecord(id='18045842', status='COMPLETE'),
#   OptimizationRecord(id='18045843', status='COMPLETE'),
#   OptimizationRecord(id='18045844', status='COMPLETE'),
#   OptimizationRecord(id='18045845', status='COMPLETE'),
#   OptimizationRecord(id='18045846', status='COMPLETE'),
#   OptimizationRecord(id='18050965', status='COMPLETE'),
#   OptimizationRecord(id='18050966', status='INCOMPLETE'),
#   OptimizationRecord(id='18050967', status='COMPLETE'),
#   OptimizationRecord(id='18050968', status='COMPLETE'),
#   OptimizationRecord(id='18050969', status='COMPLETE'),
#   OptimizationRecord(id='18050970', status='COMPLETE')],
#  '18536088': [OptimizationRecord(id='18596728', status='COMPLETE'),
#   OptimizationRecord(id='18596729', status='COMPLETE'),
#   OptimizationRecord(id='18596744', status='COMPLETE'),
#   OptimizationRecord(id='18596745', status='COMPLETE'),
#   OptimizationRecord(id='18596746', status='COMPLETE'),
#   OptimizationRecord(id='18596747', status='COMPLETE'),
#   OptimizationRecord(id='18596748', status='COMPLETE'),
#   OptimizationRecord(id='18603864', status='COMPLETE'),
#   OptimizationRecord(id='18603865', status='COMPLETE'),
#   OptimizationRecord(id='18603878', status='COMPLETE'),
#   OptimizationRecord(id='18603879', status='COMPLETE'),
#   OptimizationRecord(id='18603880', status='COMPLETE'),
#   OptimizationRecord(id='18603881', status='COMPLETE'),
#   OptimizationRecord(id='18627114', status='COMPLETE'),
#   OptimizationRecord(id='18627115', status='COMPLETE'),
#   OptimizationRecord(id='18627116', status='COMPLETE'),
#   OptimizationRecord(id='18627117', status='COMPLETE'),
#   OptimizationRecord(id='18627118', status='COMPLETE'),
#   OptimizationRecord(id='18627151', status='COMPLETE'),
#   OptimizationRecord(id='18627191', status='COMPLETE'),
#   OptimizationRecord(id='18627192', status='COMPLETE'),
#   OptimizationRecord(id='18627193', status='COMPLETE'),
#   OptimizationRecord(id='18627194', status='COMPLETE'),
#   OptimizationRecord(id='18627195', status='COMPLETE'),
#   OptimizationRecord(id='18627196', status='COMPLETE'),
#   OptimizationRecord(id='18648377', status='COMPLETE'),
#   OptimizationRecord(id='18648378', status='COMPLETE'),
#   OptimizationRecord(id='18648379', status='COMPLETE'),
#   OptimizationRecord(id='18648380', status='COMPLETE'),
#   OptimizationRecord(id='18648381', status='COMPLETE'),
#   OptimizationRecord(id='18648382', status='COMPLETE'),
#   OptimizationRecord(id='18648383', status='COMPLETE'),
#   OptimizationRecord(id='18648384', status='COMPLETE'),
#   OptimizationRecord(id='18648385', status='COMPLETE'),
#   OptimizationRecord(id='18648386', status='COMPLETE'),
#   OptimizationRecord(id='18648387', status='COMPLETE'),
#   OptimizationRecord(id='18648388', status='COMPLETE'),
#   OptimizationRecord(id='18663537', status='COMPLETE'),
#   OptimizationRecord(id='18663538', status='COMPLETE'),
#   OptimizationRecord(id='18663539', status='COMPLETE'),
#   OptimizationRecord(id='18663540', status='COMPLETE'),
#   OptimizationRecord(id='18663541', status='COMPLETE'),
#   OptimizationRecord(id='18663542', status='COMPLETE'),
#   OptimizationRecord(id='18663543', status='COMPLETE'),
#   OptimizationRecord(id='18663555', status='COMPLETE'),
#   OptimizationRecord(id='18663556', status='COMPLETE'),
#   OptimizationRecord(id='18663557', status='COMPLETE'),
#   OptimizationRecord(id='18663558', status='COMPLETE'),
#   OptimizationRecord(id='18663559', status='COMPLETE'),
#   OptimizationRecord(id='18666879', status='COMPLETE'),
#   OptimizationRecord(id='18666880', status='COMPLETE'),
#   OptimizationRecord(id='18666881', status='COMPLETE'),
#   OptimizationRecord(id='18666882', status='COMPLETE'),
#   OptimizationRecord(id='18666883', status='COMPLETE'),
#   OptimizationRecord(id='18666884', status='COMPLETE'),
#   OptimizationRecord(id='18666885', status='COMPLETE'),
#   OptimizationRecord(id='18666886', status='COMPLETE'),
#   OptimizationRecord(id='18687096', status='COMPLETE'),
#   OptimizationRecord(id='18687097', status='COMPLETE'),
#   OptimizationRecord(id='18687107', status='COMPLETE'),
#   OptimizationRecord(id='18687108', status='INCOMPLETE'),
#   OptimizationRecord(id='18687119', status='COMPLETE'),
#   OptimizationRecord(id='18687120', status='COMPLETE')],
#  '18536089': [OptimizationRecord(id='18045847', status='COMPLETE'),
#   OptimizationRecord(id='18045848', status='COMPLETE'),
#   OptimizationRecord(id='18045849', status='COMPLETE'),
#   OptimizationRecord(id='18050293', status='COMPLETE'),
#   OptimizationRecord(id='18050294', status='COMPLETE'),
#   OptimizationRecord(id='18050295', status='COMPLETE'),
#   OptimizationRecord(id='18050296', status='INCOMPLETE')],
#  '18536127': [OptimizationRecord(id='18644196', status='COMPLETE'),
#   OptimizationRecord(id='18644197', status='COMPLETE'),
#   OptimizationRecord(id='18644198', status='COMPLETE'),
#   OptimizationRecord(id='18644199', status='COMPLETE'),
#   OptimizationRecord(id='18644200', status='COMPLETE'),
#   OptimizationRecord(id='18644201', status='COMPLETE'),
#   OptimizationRecord(id='18644202', status='COMPLETE'),
#   OptimizationRecord(id='18644203', status='COMPLETE'),
#   OptimizationRecord(id='18660792', status='COMPLETE'),
#   OptimizationRecord(id='18660793', status='COMPLETE'),
#   OptimizationRecord(id='18660794', status='COMPLETE'),
#   OptimizationRecord(id='18660795', status='COMPLETE'),
#   OptimizationRecord(id='18660796', status='COMPLETE'),
#   OptimizationRecord(id='18660797', status='COMPLETE'),
#   OptimizationRecord(id='18668798', status='COMPLETE'),
#   OptimizationRecord(id='18668799', status='COMPLETE'),
#   OptimizationRecord(id='18668800', status='COMPLETE'),
#   OptimizationRecord(id='18668801', status='COMPLETE'),
#   OptimizationRecord(id='18668802', status='COMPLETE'),
#   OptimizationRecord(id='18668803', status='COMPLETE'),
#   OptimizationRecord(id='18668804', status='COMPLETE'),
#   OptimizationRecord(id='18668805', status='COMPLETE'),
#   OptimizationRecord(id='18668806', status='COMPLETE'),
#   OptimizationRecord(id='18668807', status='COMPLETE'),
#   OptimizationRecord(id='18681090', status='COMPLETE'),
#   OptimizationRecord(id='18681091', status='COMPLETE'),
#   OptimizationRecord(id='18681092', status='COMPLETE'),
#   OptimizationRecord(id='18681106', status='COMPLETE'),
#   OptimizationRecord(id='18681107', status='COMPLETE'),
#   OptimizationRecord(id='18681108', status='COMPLETE'),
#   OptimizationRecord(id='18681109', status='COMPLETE'),
#   OptimizationRecord(id='18681110', status='COMPLETE'),
#   OptimizationRecord(id='21231577', status='COMPLETE'),
#   OptimizationRecord(id='21231578', status='COMPLETE'),
#   OptimizationRecord(id='21231579', status='COMPLETE'),
#   OptimizationRecord(id='21231580', status='COMPLETE'),
#   OptimizationRecord(id='21231581', status='COMPLETE'),
#   OptimizationRecord(id='21231582', status='COMPLETE'),
#   OptimizationRecord(id='21231583', status='COMPLETE'),
#   OptimizationRecord(id='21231584', status='COMPLETE'),
#   OptimizationRecord(id='21231585', status='COMPLETE'),
#   OptimizationRecord(id='21231586', status='COMPLETE'),
#   OptimizationRecord(id='21236797', status='COMPLETE'),
#   OptimizationRecord(id='21236798', status='COMPLETE'),
#   OptimizationRecord(id='21236799', status='COMPLETE'),
#   OptimizationRecord(id='21236800', status='COMPLETE'),
#   OptimizationRecord(id='21236801', status='COMPLETE'),
#   OptimizationRecord(id='21236802', status='COMPLETE'),
#   OptimizationRecord(id='21236803', status='COMPLETE'),
#   OptimizationRecord(id='21236804', status='COMPLETE'),
#   OptimizationRecord(id='21239903', status='COMPLETE'),
#   OptimizationRecord(id='21239904', status='COMPLETE'),
#   OptimizationRecord(id='21239905', status='COMPLETE'),
#   OptimizationRecord(id='21239906', status='COMPLETE'),
#   OptimizationRecord(id='21239907', status='COMPLETE'),
#   OptimizationRecord(id='21239908', status='COMPLETE'),
#   OptimizationRecord(id='21239909', status='COMPLETE'),
#   OptimizationRecord(id='21239910', status='COMPLETE'),
#   OptimizationRecord(id='21239911', status='COMPLETE'),
#   OptimizationRecord(id='21239912', status='COMPLETE'),
#   OptimizationRecord(id='21241318', status='COMPLETE'),
#   OptimizationRecord(id='21241319', status='ERROR'),
#   OptimizationRecord(id='21241320', status='ERROR'),
#   OptimizationRecord(id='21241321', status='INCOMPLETE'),
#   OptimizationRecord(id='21241322', status='INCOMPLETE'),
#   OptimizationRecord(id='21241323', status='INCOMPLETE'),
#   OptimizationRecord(id='21241324', status='INCOMPLETE'),
#   OptimizationRecord(id='21241325', status='INCOMPLETE'),
#   OptimizationRecord(id='21241326', status='INCOMPLETE'),
#   OptimizationRecord(id='21241338', status='INCOMPLETE'),
#   OptimizationRecord(id='21241339', status='INCOMPLETE'),
#   OptimizationRecord(id='21241340', status='COMPLETE')],
#  '18536131': [OptimizationRecord(id='18646139', status='COMPLETE'),
#   OptimizationRecord(id='18646140', status='ERROR'),
#   OptimizationRecord(id='18646141', status='COMPLETE'),
#   OptimizationRecord(id='18646142', status='ERROR')],
#  '18536132': [OptimizationRecord(id='18646152', status='COMPLETE'),
#   OptimizationRecord(id='18646153', status='ERROR')],
#  '2703420': [OptimizationRecord(id='2726913', status='COMPLETE'),
#   OptimizationRecord(id='2726914', status='COMPLETE'),
#   OptimizationRecord(id='2740473', status='COMPLETE'),
#   OptimizationRecord(id='2740474', status='COMPLETE'),
#   OptimizationRecord(id='2773564', status='COMPLETE'),
#   OptimizationRecord(id='2773565', status='COMPLETE'),
#   OptimizationRecord(id='2773566', status='COMPLETE'),
#   OptimizationRecord(id='2773567', status='COMPLETE'),
#   OptimizationRecord(id='2783938', status='COMPLETE'),
#   OptimizationRecord(id='2783939', status='COMPLETE'),
#   OptimizationRecord(id='2783940', status='COMPLETE'),
#   OptimizationRecord(id='2783941', status='COMPLETE'),
#   OptimizationRecord(id='2794739', status='COMPLETE'),
#   OptimizationRecord(id='2794740', status='COMPLETE'),
#   OptimizationRecord(id='2794741', status='COMPLETE'),
#   OptimizationRecord(id='2794742', status='COMPLETE'),
#   OptimizationRecord(id='2804667', status='COMPLETE'),
#   OptimizationRecord(id='2804668', status='COMPLETE'),
#   OptimizationRecord(id='2804669', status='COMPLETE'),
#   OptimizationRecord(id='2804670', status='COMPLETE'),
#   OptimizationRecord(id='21139831', status='COMPLETE'),
#   OptimizationRecord(id='21139832', status='ERROR'),
#   OptimizationRecord(id='21139833', status='ERROR'),
#   OptimizationRecord(id='21139834', status='COMPLETE')],
#  '18536133': [OptimizationRecord(id='18646309', status='COMPLETE'),
#   OptimizationRecord(id='18647315', status='COMPLETE'),
#   OptimizationRecord(id='18647316', status='COMPLETE'),
#   OptimizationRecord(id='18653175', status='COMPLETE'),
#   OptimizationRecord(id='18653176', status='COMPLETE'),
#   OptimizationRecord(id='18653177', status='COMPLETE'),
#   OptimizationRecord(id='18653178', status='COMPLETE'),
#   OptimizationRecord(id='18657324', status='COMPLETE'),
#   OptimizationRecord(id='18657325', status='COMPLETE'),
#   OptimizationRecord(id='18657326', status='COMPLETE'),
#   OptimizationRecord(id='18657327', status='COMPLETE'),
#   OptimizationRecord(id='18657328', status='COMPLETE'),
#   OptimizationRecord(id='18657329', status='COMPLETE'),
#   OptimizationRecord(id='18662418', status='COMPLETE'),
#   OptimizationRecord(id='18662419', status='COMPLETE'),
#   OptimizationRecord(id='18662420', status='ERROR'),
#   OptimizationRecord(id='18662421', status='ERROR'),
#   OptimizationRecord(id='18662422', status='COMPLETE'),
#   OptimizationRecord(id='18662423', status='COMPLETE')]}

# %%
resm = merge(res)

# %%
incomplete = (opt.dict() for opt in resm if opt.status == 'INCOMPLETE')

# %%
next(incomplete)
# Out:
# {'id': '21241321',
#  'hash_index': '7a79b2e5e31fc1f29b2da8912f492d9399c47587',
#  'procedure': 'optimization',
#  'program': 'geometric',
#  'version': 1,
#  'protocols': {},
#  'extras': {},
#  'stdout': None,
#  'stderr': None,
#  'error': None,
#  'task_id': None,
#  'manager_name': None,
#  'status': <RecordStatusEnum.incomplete: 'INCOMPLETE'>,
#  'modified_on': datetime.datetime(2020, 6, 22, 7, 16, 8, 457895),
#  'created_on': datetime.datetime(2020, 6, 22, 7, 16, 8, 457898),
#  'provenance': None,
#  'schema_version': 1,
#  'initial_molecule': '14744228',
#  'qc_spec': {'driver': <DriverEnum.gradient: 'gradient'>,
#   'method': 'b3lyp-d3bj',
#   'basis': 'dzvp',
#   'keywords': '2',
#   'program': 'psi4'},
#  'keywords': {'coordsys': 'tric',
#   'enforce': 0.1,
#   'reset': True,
#   'qccnv': True,
#   'epsilon': 0,
#   'constraints': {'set': [{'type': 'dihedral',
#      'indices': [7, 14, 17, 16],
#      'value': -75}]},
#   'program': 'psi4'},
#  'energies': None,
#  'final_molecule': None,
#  'trajectory': None}

# %% [markdown]
# Seeing Lilac INCOMPLETEs, but also ones without any manager info at all.

# %%
count_unique_optimization_error_messages(resm, full=True, pretty_print=True)
# Out:
# There are 2 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1296, in optimizeGeometry
#     self.step()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1100, in step
#     self.checkCoordinateSystem(recover=True, cartesian=LastForce)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 959, in checkCoordinateSystem
#     raise ValueError("Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates")
# ValueError: Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates
#
# -------------------------------------
#
# There are 2 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1301, in optimizeGeometry
#     raise GeomOptNotConvergedError("Optimizer.optimizeGeometry() failed to converge.")
# geometric.errors.GeomOptNotConvergedError: Optimizer.optimizeGeometry() failed to converge.
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# Caught Executor Error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/opt/lib/python3.7/site-packages/qcfractal-0.13.1+54.g3caa178.dirty-py3.7.egg/qcfractal/queue/executor_adapter.py", line 15, in _get_future
#     return future.result()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/distributed/client.py", line 218, in result
#     raise exc.with_traceback(tb)
# distributed.scheduler.KilledWorker: ('compute_procedure-1ee7a30449203d45d1e806f6a2538de4', <Worker 'tcp://10.240.60.31:36923', name: 82, memory: 0, processing: 4>)
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# Caught Executor Error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/opt/lib/python3.7/site-packages/qcfractal-0.13.1+54.g3caa178.dirty-py3.7.egg/qcfractal/queue/executor_adapter.py", line 15, in _get_future
#     return future.result()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/distributed/client.py", line 218, in result
#     raise exc.with_traceback(tb)
# distributed.scheduler.KilledWorker: ('compute_procedure-506178a9245afbe2d227cbfef855faad', <Worker 'tcp://10.240.60.16:38571', name: 102, memory: 0, processing: 3>)
#
# -------------------------------------
#
# There are 3 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1298, in optimizeGeometry
#     self.calcEnergyForce()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1002, in calcEnergyForce
#     spcalc = self.engine.calc(self.X, self.dirname)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/engine.py", line 873, in calc
#     return self.calc_new(coords, dirname)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/engine.py", line 865, in calc_new
#     raise QCEngineAPIEngineError("QCEngineAPI computation did not execute correctly. Message: " + ret["error"]["error_message"])
# geometric.errors.QCEngineAPIEngineError: QCEngineAPI computation did not execute correctly. Message: QCEngine Unknown Error: Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/json_wrapper.py", line 217, in run_json
#     json_data = run_json_qcschema(copy.deepcopy(json_data), clean)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/json_wrapper.py", line 312, in run_json_qcschema
#     val, wfn = methods_dict_[json_data["driver"]](method, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/driver.py", line 691, in gradient
#     wfn = procedures['gradient'][lowername](lowername, molecule=molecule, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/proc.py", line 2064, in run_scf_gradient
#     ref_wfn = run_scf(name, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/proc.py", line 2002, in run_scf
#     scf_wfn = scf_helper(name, post_scf=False, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/proc.py", line 1363, in scf_helper
#     e_scf = scf_wfn.compute_energy()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 94, in scf_compute_energy
#     raise e
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 87, in scf_compute_energy
#     self.iterations()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 447, in scf_iterate
#     raise SCFConvergenceError("""SCF iterations""", self.iteration_, self, Ediff, Dnorm)
# psi4.driver.p4util.exceptions.SCFConvergenceError: Could not converge SCF iterations in 200 iterations.
#
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1296, in optimizeGeometry
#     self.step()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1100, in step
#     self.checkCoordinateSystem(recover=True, cartesian=LastForce)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 959, in checkCoordinateSystem
#     raise ValueError("Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates")
# ValueError: Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# Caught Executor Error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/qcfractal/queue/executor_adapter.py", line 15, in _get_future
#     return future.result()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/concurrent/futures/_base.py", line 425, in result
#     return self.__get_result()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
# concurrent.futures.process.BrokenProcessPool: A process in the process pool was terminated abruptly while the future was running or pending.
#
# -------------------------------------

# %%
restart_optimizations(resm, client)
# Out:
# OptimizationRecord(id='18608912', status='ERROR')
# OptimizationRecord(id='18609138', status='ERROR')
# OptimizationRecord(id='21241319', status='ERROR')
# OptimizationRecord(id='21241320', status='ERROR')
# OptimizationRecord(id='18646140', status='ERROR')
# OptimizationRecord(id='18646142', status='ERROR')
# OptimizationRecord(id='18646153', status='ERROR')
# OptimizationRecord(id='21139832', status='ERROR')
# OptimizationRecord(id='21139833', status='ERROR')
# OptimizationRecord(id='18662420', status='ERROR')
# OptimizationRecord(id='18662421', status='ERROR')

# %%
restart_torsiondrives(ds.df.default.tolist(), client)
# Out:
# TorsionDriveRecord(id='18536034', status='ERROR')
# TorsionDriveRecord(id='18536035', status='ERROR')
# TorsionDriveRecord(id='18536127', status='ERROR')
# TorsionDriveRecord(id='2703602', status='ERROR')
# TorsionDriveRecord(id='18536131', status='ERROR')
# TorsionDriveRecord(id='18536132', status='ERROR')
# TorsionDriveRecord(id='2703420', status='ERROR')
# TorsionDriveRecord(id='18536133', status='ERROR')
# TorsionDriveRecord(id='2703594', status='ERROR')

# %% [markdown]
# ### 2020.06.11 22:15 UTC

# %%
dataset = "OpenFF Gen 2 Torsion Set 2 Coverage 2"

# %%
ds = client.get_collection("TorsionDriveDataset", dataset)

# %%
ds.list_specifications()
# Out:
#                                          Description
# Name
# default  Standard OpenFF torsiondrive specification.

# %%
res = get_unfinished_torsiondrive_optimizations(ds, 'default', client, merged=False)
res
# Out:
# {'18536034': [OptimizationRecord(id='18536837', status='COMPLETE'),
#   OptimizationRecord(id='18556386', status='COMPLETE'),
#   OptimizationRecord(id='18556387', status='COMPLETE'),
#   OptimizationRecord(id='18563815', status='COMPLETE'),
#   OptimizationRecord(id='18563816', status='COMPLETE'),
#   OptimizationRecord(id='18563817', status='COMPLETE'),
#   OptimizationRecord(id='18563818', status='COMPLETE'),
#   OptimizationRecord(id='18581746', status='COMPLETE'),
#   OptimizationRecord(id='18581747', status='COMPLETE'),
#   OptimizationRecord(id='18581748', status='COMPLETE'),
#   OptimizationRecord(id='18581749', status='COMPLETE'),
#   OptimizationRecord(id='18593042', status='COMPLETE'),
#   OptimizationRecord(id='18593043', status='COMPLETE'),
#   OptimizationRecord(id='18593044', status='COMPLETE'),
#   OptimizationRecord(id='18593045', status='COMPLETE'),
#   OptimizationRecord(id='18599295', status='COMPLETE'),
#   OptimizationRecord(id='18599296', status='COMPLETE'),
#   OptimizationRecord(id='18599297', status='COMPLETE'),
#   OptimizationRecord(id='18599298', status='COMPLETE'),
#   OptimizationRecord(id='18608910', status='COMPLETE'),
#   OptimizationRecord(id='18608911', status='COMPLETE'),
#   OptimizationRecord(id='18608912', status='ERROR'),
#   OptimizationRecord(id='18608913', status='COMPLETE')],
#  '18536035': [OptimizationRecord(id='18536896', status='COMPLETE'),
#   OptimizationRecord(id='18555593', status='COMPLETE'),
#   OptimizationRecord(id='18555594', status='COMPLETE'),
#   OptimizationRecord(id='18600678', status='COMPLETE'),
#   OptimizationRecord(id='18600679', status='COMPLETE'),
#   OptimizationRecord(id='18600680', status='COMPLETE'),
#   OptimizationRecord(id='18600681', status='COMPLETE'),
#   OptimizationRecord(id='18609138', status='ERROR'),
#   OptimizationRecord(id='18609139', status='COMPLETE')],
#  '18536082': [OptimizationRecord(id='18045818', status='COMPLETE'),
#   OptimizationRecord(id='18045819', status='COMPLETE'),
#   OptimizationRecord(id='18045820', status='COMPLETE'),
#   OptimizationRecord(id='18045821', status='COMPLETE'),
#   OptimizationRecord(id='18045822', status='COMPLETE'),
#   OptimizationRecord(id='18045823', status='COMPLETE'),
#   OptimizationRecord(id='18045824', status='COMPLETE'),
#   OptimizationRecord(id='18045825', status='COMPLETE'),
#   OptimizationRecord(id='18058703', status='COMPLETE'),
#   OptimizationRecord(id='18058704', status='COMPLETE'),
#   OptimizationRecord(id='18058705', status='COMPLETE'),
#   OptimizationRecord(id='18058706', status='COMPLETE'),
#   OptimizationRecord(id='18058707', status='COMPLETE'),
#   OptimizationRecord(id='18058708', status='COMPLETE'),
#   OptimizationRecord(id='18058709', status='COMPLETE'),
#   OptimizationRecord(id='18058710', status='COMPLETE'),
#   OptimizationRecord(id='18058711', status='COMPLETE'),
#   OptimizationRecord(id='18058712', status='COMPLETE'),
#   OptimizationRecord(id='18058713', status='COMPLETE'),
#   OptimizationRecord(id='18058714', status='COMPLETE'),
#   OptimizationRecord(id='18080103', status='COMPLETE'),
#   OptimizationRecord(id='18080104', status='COMPLETE'),
#   OptimizationRecord(id='18080105', status='COMPLETE'),
#   OptimizationRecord(id='18080106', status='COMPLETE'),
#   OptimizationRecord(id='18080107', status='COMPLETE'),
#   OptimizationRecord(id='18080108', status='COMPLETE'),
#   OptimizationRecord(id='18080109', status='COMPLETE'),
#   OptimizationRecord(id='18080110', status='COMPLETE'),
#   OptimizationRecord(id='18080111', status='COMPLETE'),
#   OptimizationRecord(id='18080112', status='COMPLETE'),
#   OptimizationRecord(id='18080113', status='COMPLETE'),
#   OptimizationRecord(id='18080114', status='COMPLETE'),
#   OptimizationRecord(id='18080115', status='COMPLETE'),
#   OptimizationRecord(id='18080133', status='COMPLETE'),
#   OptimizationRecord(id='18080134', status='COMPLETE'),
#   OptimizationRecord(id='18080151', status='COMPLETE'),
#   OptimizationRecord(id='18080165', status='COMPLETE'),
#   OptimizationRecord(id='18080178', status='COMPLETE'),
#   OptimizationRecord(id='18102688', status='COMPLETE'),
#   OptimizationRecord(id='18102689', status='COMPLETE'),
#   OptimizationRecord(id='18102690', status='COMPLETE'),
#   OptimizationRecord(id='18102691', status='COMPLETE'),
#   OptimizationRecord(id='18102692', status='COMPLETE'),
#   OptimizationRecord(id='18102693', status='COMPLETE'),
#   OptimizationRecord(id='18102694', status='COMPLETE'),
#   OptimizationRecord(id='18102695', status='COMPLETE'),
#   OptimizationRecord(id='18102696', status='COMPLETE'),
#   OptimizationRecord(id='18102697', status='COMPLETE'),
#   OptimizationRecord(id='18102698', status='COMPLETE'),
#   OptimizationRecord(id='18102699', status='COMPLETE'),
#   OptimizationRecord(id='18102700', status='COMPLETE'),
#   OptimizationRecord(id='18102701', status='COMPLETE'),
#   OptimizationRecord(id='18102702', status='COMPLETE'),
#   OptimizationRecord(id='18102703', status='COMPLETE'),
#   OptimizationRecord(id='18129151', status='COMPLETE'),
#   OptimizationRecord(id='18129152', status='COMPLETE'),
#   OptimizationRecord(id='18129153', status='COMPLETE'),
#   OptimizationRecord(id='18129154', status='COMPLETE'),
#   OptimizationRecord(id='18129155', status='COMPLETE'),
#   OptimizationRecord(id='18129156', status='COMPLETE'),
#   OptimizationRecord(id='18129157', status='COMPLETE'),
#   OptimizationRecord(id='18129158', status='COMPLETE'),
#   OptimizationRecord(id='18129159', status='COMPLETE'),
#   OptimizationRecord(id='18129160', status='COMPLETE'),
#   OptimizationRecord(id='18129161', status='COMPLETE'),
#   OptimizationRecord(id='18129162', status='COMPLETE'),
#   OptimizationRecord(id='18129163', status='COMPLETE'),
#   OptimizationRecord(id='18129164', status='COMPLETE'),
#   OptimizationRecord(id='18144347', status='COMPLETE'),
#   OptimizationRecord(id='18144348', status='COMPLETE'),
#   OptimizationRecord(id='18144349', status='COMPLETE'),
#   OptimizationRecord(id='18144350', status='COMPLETE'),
#   OptimizationRecord(id='18144363', status='COMPLETE'),
#   OptimizationRecord(id='18144364', status='COMPLETE'),
#   OptimizationRecord(id='18144365', status='INCOMPLETE'),
#   OptimizationRecord(id='18144366', status='COMPLETE')],
#  '18536087': [OptimizationRecord(id='18045842', status='COMPLETE'),
#   OptimizationRecord(id='18045843', status='COMPLETE'),
#   OptimizationRecord(id='18045844', status='COMPLETE'),
#   OptimizationRecord(id='18045845', status='COMPLETE'),
#   OptimizationRecord(id='18045846', status='COMPLETE'),
#   OptimizationRecord(id='18050965', status='COMPLETE'),
#   OptimizationRecord(id='18050966', status='INCOMPLETE'),
#   OptimizationRecord(id='18050967', status='COMPLETE'),
#   OptimizationRecord(id='18050968', status='COMPLETE'),
#   OptimizationRecord(id='18050969', status='COMPLETE'),
#   OptimizationRecord(id='18050970', status='COMPLETE')],
#  '18536088': [OptimizationRecord(id='18596728', status='COMPLETE'),
#   OptimizationRecord(id='18596729', status='COMPLETE'),
#   OptimizationRecord(id='18596744', status='COMPLETE'),
#   OptimizationRecord(id='18596745', status='COMPLETE'),
#   OptimizationRecord(id='18596746', status='COMPLETE'),
#   OptimizationRecord(id='18596747', status='COMPLETE'),
#   OptimizationRecord(id='18596748', status='COMPLETE'),
#   OptimizationRecord(id='18603864', status='COMPLETE'),
#   OptimizationRecord(id='18603865', status='COMPLETE'),
#   OptimizationRecord(id='18603878', status='COMPLETE'),
#   OptimizationRecord(id='18603879', status='COMPLETE'),
#   OptimizationRecord(id='18603880', status='COMPLETE'),
#   OptimizationRecord(id='18603881', status='COMPLETE'),
#   OptimizationRecord(id='18627114', status='COMPLETE'),
#   OptimizationRecord(id='18627115', status='COMPLETE'),
#   OptimizationRecord(id='18627116', status='COMPLETE'),
#   OptimizationRecord(id='18627117', status='COMPLETE'),
#   OptimizationRecord(id='18627118', status='COMPLETE'),
#   OptimizationRecord(id='18627151', status='COMPLETE'),
#   OptimizationRecord(id='18627191', status='COMPLETE'),
#   OptimizationRecord(id='18627192', status='COMPLETE'),
#   OptimizationRecord(id='18627193', status='COMPLETE'),
#   OptimizationRecord(id='18627194', status='COMPLETE'),
#   OptimizationRecord(id='18627195', status='COMPLETE'),
#   OptimizationRecord(id='18627196', status='COMPLETE'),
#   OptimizationRecord(id='18648377', status='COMPLETE'),
#   OptimizationRecord(id='18648378', status='COMPLETE'),
#   OptimizationRecord(id='18648379', status='COMPLETE'),
#   OptimizationRecord(id='18648380', status='COMPLETE'),
#   OptimizationRecord(id='18648381', status='COMPLETE'),
#   OptimizationRecord(id='18648382', status='COMPLETE'),
#   OptimizationRecord(id='18648383', status='COMPLETE'),
#   OptimizationRecord(id='18648384', status='COMPLETE'),
#   OptimizationRecord(id='18648385', status='COMPLETE'),
#   OptimizationRecord(id='18648386', status='COMPLETE'),
#   OptimizationRecord(id='18648387', status='COMPLETE'),
#   OptimizationRecord(id='18648388', status='COMPLETE'),
#   OptimizationRecord(id='18663537', status='COMPLETE'),
#   OptimizationRecord(id='18663538', status='COMPLETE'),
#   OptimizationRecord(id='18663539', status='COMPLETE'),
#   OptimizationRecord(id='18663540', status='COMPLETE'),
#   OptimizationRecord(id='18663541', status='COMPLETE'),
#   OptimizationRecord(id='18663542', status='COMPLETE'),
#   OptimizationRecord(id='18663543', status='COMPLETE'),
#   OptimizationRecord(id='18663555', status='COMPLETE'),
#   OptimizationRecord(id='18663556', status='COMPLETE'),
#   OptimizationRecord(id='18663557', status='COMPLETE'),
#   OptimizationRecord(id='18663558', status='COMPLETE'),
#   OptimizationRecord(id='18663559', status='COMPLETE'),
#   OptimizationRecord(id='18666879', status='COMPLETE'),
#   OptimizationRecord(id='18666880', status='COMPLETE'),
#   OptimizationRecord(id='18666881', status='COMPLETE'),
#   OptimizationRecord(id='18666882', status='COMPLETE'),
#   OptimizationRecord(id='18666883', status='COMPLETE'),
#   OptimizationRecord(id='18666884', status='COMPLETE'),
#   OptimizationRecord(id='18666885', status='COMPLETE'),
#   OptimizationRecord(id='18666886', status='COMPLETE'),
#   OptimizationRecord(id='18687096', status='COMPLETE'),
#   OptimizationRecord(id='18687097', status='COMPLETE'),
#   OptimizationRecord(id='18687107', status='COMPLETE'),
#   OptimizationRecord(id='18687108', status='INCOMPLETE'),
#   OptimizationRecord(id='18687119', status='COMPLETE'),
#   OptimizationRecord(id='18687120', status='COMPLETE')],
#  '18536089': [OptimizationRecord(id='18045847', status='COMPLETE'),
#   OptimizationRecord(id='18045848', status='COMPLETE'),
#   OptimizationRecord(id='18045849', status='COMPLETE'),
#   OptimizationRecord(id='18050293', status='COMPLETE'),
#   OptimizationRecord(id='18050294', status='COMPLETE'),
#   OptimizationRecord(id='18050295', status='COMPLETE'),
#   OptimizationRecord(id='18050296', status='INCOMPLETE')],
#  '18536127': [OptimizationRecord(id='18644196', status='COMPLETE'),
#   OptimizationRecord(id='18644197', status='COMPLETE'),
#   OptimizationRecord(id='18644198', status='COMPLETE'),
#   OptimizationRecord(id='18644199', status='COMPLETE'),
#   OptimizationRecord(id='18644200', status='COMPLETE'),
#   OptimizationRecord(id='18644201', status='COMPLETE'),
#   OptimizationRecord(id='18644202', status='COMPLETE'),
#   OptimizationRecord(id='18644203', status='COMPLETE'),
#   OptimizationRecord(id='18660792', status='COMPLETE'),
#   OptimizationRecord(id='18660793', status='COMPLETE'),
#   OptimizationRecord(id='18660794', status='COMPLETE'),
#   OptimizationRecord(id='18660795', status='COMPLETE'),
#   OptimizationRecord(id='18660796', status='COMPLETE'),
#   OptimizationRecord(id='18660797', status='COMPLETE'),
#   OptimizationRecord(id='18668798', status='COMPLETE'),
#   OptimizationRecord(id='18668799', status='COMPLETE'),
#   OptimizationRecord(id='18668800', status='COMPLETE'),
#   OptimizationRecord(id='18668801', status='COMPLETE'),
#   OptimizationRecord(id='18668802', status='COMPLETE'),
#   OptimizationRecord(id='18668803', status='COMPLETE'),
#   OptimizationRecord(id='18668804', status='COMPLETE'),
#   OptimizationRecord(id='18668805', status='COMPLETE'),
#   OptimizationRecord(id='18668806', status='COMPLETE'),
#   OptimizationRecord(id='18668807', status='COMPLETE'),
#   OptimizationRecord(id='18681090', status='COMPLETE'),
#   OptimizationRecord(id='18681091', status='COMPLETE'),
#   OptimizationRecord(id='18681092', status='ERROR'),
#   OptimizationRecord(id='18681106', status='COMPLETE'),
#   OptimizationRecord(id='18681107', status='COMPLETE'),
#   OptimizationRecord(id='18681108', status='COMPLETE'),
#   OptimizationRecord(id='18681109', status='COMPLETE'),
#   OptimizationRecord(id='18681110', status='COMPLETE')],
#  '18536131': [OptimizationRecord(id='18646139', status='COMPLETE'),
#   OptimizationRecord(id='18646140', status='ERROR'),
#   OptimizationRecord(id='18646141', status='COMPLETE'),
#   OptimizationRecord(id='18646142', status='ERROR')],
#  '18536132': [OptimizationRecord(id='18646152', status='COMPLETE'),
#   OptimizationRecord(id='18646153', status='ERROR')],
#  '18536133': [OptimizationRecord(id='18646309', status='COMPLETE'),
#   OptimizationRecord(id='18647315', status='COMPLETE'),
#   OptimizationRecord(id='18647316', status='COMPLETE'),
#   OptimizationRecord(id='18653175', status='COMPLETE'),
#   OptimizationRecord(id='18653176', status='COMPLETE'),
#   OptimizationRecord(id='18653177', status='COMPLETE'),
#   OptimizationRecord(id='18653178', status='COMPLETE'),
#   OptimizationRecord(id='18657324', status='COMPLETE'),
#   OptimizationRecord(id='18657325', status='COMPLETE'),
#   OptimizationRecord(id='18657326', status='COMPLETE'),
#   OptimizationRecord(id='18657327', status='COMPLETE'),
#   OptimizationRecord(id='18657328', status='COMPLETE'),
#   OptimizationRecord(id='18657329', status='COMPLETE'),
#   OptimizationRecord(id='18662418', status='COMPLETE'),
#   OptimizationRecord(id='18662419', status='COMPLETE'),
#   OptimizationRecord(id='18662420', status='ERROR'),
#   OptimizationRecord(id='18662421', status='ERROR'),
#   OptimizationRecord(id='18662422', status='COMPLETE'),
#   OptimizationRecord(id='18662423', status='COMPLETE')]}

# %%
resm = merge(res)

# %%
incomplete = (opt.dict() for opt in resm if opt.status == 'INCOMPLETE')

# %%
next(incomplete)
# Out:
# {'id': '18144365',
#  'hash_index': '12c52157913c5cb74ca332942fc32e8f6945178c',
#  'procedure': 'optimization',
#  'program': 'geometric',
#  'version': 1,
#  'protocols': {},
#  'extras': {},
#  'stdout': '21098431',
#  'stderr': None,
#  'error': None,
#  'task_id': None,
#  'manager_name': None,
#  'status': <RecordStatusEnum.incomplete: 'INCOMPLETE'>,
#  'modified_on': datetime.datetime(2020, 3, 16, 21, 37, 59, 569792),
#  'created_on': datetime.datetime(2020, 3, 14, 9, 56, 15, 750484),
#  'provenance': {'creator': 'geomeTRIC',
#   'version': '0.9.7.2',
#   'routine': 'geometric.run_json.geometric_run_json',
#   'cpu': 'Intel(R) Xeon(R) CPU E5-2697 v4 @ 2.30GHz',
#   'wall_time': 1850.50550699234,
#   'username': 'chodera',
#   'hostname': 'ls08',
#   'qcengine_version': '0.14.0'},
#  'schema_version': 1,
#  'initial_molecule': '11851196',
#  'qc_spec': {'driver': <DriverEnum.gradient: 'gradient'>,
#   'method': 'b3lyp-d3bj',
#   'basis': 'dzvp',
#   'keywords': '2',
#   'program': 'psi4'},
#  'keywords': {'coordsys': 'tric',
#   'enforce': 0.1,
#   'reset': True,
#   'qccnv': True,
#   'epsilon': 0,
#   'constraints': {'set': [{'type': 'dihedral',
#      'indices': [3, 4, 12, 17],
#      'value': 105}]},
#   'program': 'psi4'},
#  'energies': [-1485.1363666701043,
#   -1485.1344585985266,
#   -1485.1334948899091,
#   -1485.1340776858326,
#   -1485.1342688436225,
#   -1485.134317512343,
#   -1485.1343869606449,
#   -1485.1344197313113,
#   -1485.1345038125025,
#   -1485.134513982869,
#   -1485.1345246629085,
#   -1485.1345402219665,
#   -1485.1345436684276,
#   -1485.1345487483418,
#   -1485.1345543603768,
#   -1485.1345564558005,
#   -1485.134559180771,
#   -1485.134560653166,
#   -1485.1345619588521,
#   -1485.1345620971056],
#  'final_molecule': '11864399',
#  'trajectory': ['18138628',
#   '18152990',
#   '18153008',
#   '18153010',
#   '18153011',
#   '18153012',
#   '18153013',
#   '18153014',
#   '18153015',
#   '18153016',
#   '18153017',
#   '18153018',
#   '18153019',
#   '18153020',
#   '18153021',
#   '18153022',
#   '18153023',
#   '18153024',
#   '18153025',
#   '18153026']}

# %% [markdown]
# All Lilac INCOMPLETEs?

# %%
count_unique_optimization_error_messages(resm, full=True, pretty_print=True)
# Out:
# There are 4 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1296, in optimizeGeometry
#     self.step()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1100, in step
#     self.checkCoordinateSystem(recover=True, cartesian=LastForce)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 959, in checkCoordinateSystem
#     raise ValueError("Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates")
# ValueError: Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1301, in optimizeGeometry
#     raise GeomOptNotConvergedError("Optimizer.optimizeGeometry() failed to converge.")
# geometric.errors.GeomOptNotConvergedError: Optimizer.optimizeGeometry() failed to converge.
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1299, in optimizeGeometry
#     self.evaluateStep()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1277, in evaluateStep
#     Eig1 = np.linalg.eigh(self.H)[0]
#   File "<__array_function__ internals>", line 6, in eigh
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/numpy/linalg/linalg.py", line 1456, in eigh
#     w, vt = gufunc(a, signature=signature, extobj=extobj)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/numpy/linalg/linalg.py", line 103, in _raise_linalgerror_eigenvalues_nonconvergence
#     raise LinAlgError("Eigenvalues did not converge")
# numpy.linalg.LinAlgError: Eigenvalues did not converge
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1298, in optimizeGeometry
#     self.calcEnergyForce()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1002, in calcEnergyForce
#     spcalc = self.engine.calc(self.X, self.dirname)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/engine.py", line 873, in calc
#     return self.calc_new(coords, dirname)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/engine.py", line 865, in calc_new
#     raise QCEngineAPIEngineError("QCEngineAPI computation did not execute correctly. Message: " + ret["error"]["error_message"])
# geometric.errors.QCEngineAPIEngineError: QCEngineAPI computation did not execute correctly. Message: QCEngine Unknown Error: Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/json_wrapper.py", line 217, in run_json
#     json_data = run_json_qcschema(copy.deepcopy(json_data), clean)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/json_wrapper.py", line 312, in run_json_qcschema
#     val, wfn = methods_dict_[json_data["driver"]](method, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/driver.py", line 691, in gradient
#     wfn = procedures['gradient'][lowername](lowername, molecule=molecule, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/proc.py", line 2064, in run_scf_gradient
#     ref_wfn = run_scf(name, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/proc.py", line 2002, in run_scf
#     scf_wfn = scf_helper(name, post_scf=False, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/proc.py", line 1363, in scf_helper
#     e_scf = scf_wfn.compute_energy()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 94, in scf_compute_energy
#     raise e
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 87, in scf_compute_energy
#     self.iterations()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 447, in scf_iterate
#     raise SCFConvergenceError("""SCF iterations""", self.iteration_, self, Ediff, Dnorm)
# psi4.driver.p4util.exceptions.SCFConvergenceError: Could not converge SCF iterations in 200 iterations.
#
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/home/chodera/miniconda/envs/qcfractal/lib/python3.6/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/home/chodera/miniconda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/home/chodera/miniconda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1296, in optimizeGeometry
#     self.step()
#   File "/home/chodera/miniconda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1100, in step
#     self.checkCoordinateSystem(recover=True, cartesian=LastForce)
#   File "/home/chodera/miniconda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 959, in checkCoordinateSystem
#     raise ValueError("Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates")
# ValueError: Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates
#
# -------------------------------------

# %%
restart_optimizations(resm, client)
# Out:
# OptimizationRecord(id='18608912', status='ERROR')
# OptimizationRecord(id='18609138', status='ERROR')
# OptimizationRecord(id='18681092', status='ERROR')
# OptimizationRecord(id='18646140', status='ERROR')
# OptimizationRecord(id='18646142', status='ERROR')
# OptimizationRecord(id='18646153', status='ERROR')
# OptimizationRecord(id='18662420', status='ERROR')
# OptimizationRecord(id='18662421', status='ERROR')

# %%
restart_torsiondrives(ds.df.default.tolist(), client)
# Out:
# TorsionDriveRecord(id='18536034', status='ERROR')
# TorsionDriveRecord(id='18536035', status='ERROR')
# TorsionDriveRecord(id='18536127', status='ERROR')
# TorsionDriveRecord(id='2703602', status='ERROR')
# TorsionDriveRecord(id='18536131', status='ERROR')
# TorsionDriveRecord(id='18536132', status='ERROR')
# TorsionDriveRecord(id='2703420', status='ERROR')
# TorsionDriveRecord(id='18536133', status='ERROR')
# TorsionDriveRecord(id='2703594', status='ERROR')

# %% [markdown]
# ## Dataset tracking - OpenFF Gen 2 Torsion Set 3 Pfizer Discrepancy 2

# %% [markdown]
# ### 2020.06.17 01:20 UTC

# %%
dataset = "OpenFF Gen 2 Torsion Set 3 Pfizer Discrepancy 2"

# %%
ds = client.get_collection("TorsionDriveDataset", dataset)

# %%
ds.list_specifications()
# Out:
#                                          Description
# Name
# default  Standard OpenFF torsiondrive specification.

# %%
res = get_unfinished_torsiondrive_optimizations(ds, 'default', client)
res
# Out:
# {'6098580': [OptimizationRecord(id='6098847', status='COMPLETE'),
#   OptimizationRecord(id='6904364', status='COMPLETE'),
#   OptimizationRecord(id='6904365', status='COMPLETE'),
#   OptimizationRecord(id='6924262', status='COMPLETE'),
#   OptimizationRecord(id='6924263', status='COMPLETE'),
#   OptimizationRecord(id='6924264', status='COMPLETE'),
#   OptimizationRecord(id='6924265', status='COMPLETE'),
#   OptimizationRecord(id='6935440', status='COMPLETE'),
#   OptimizationRecord(id='6935441', status='COMPLETE'),
#   OptimizationRecord(id='6935442', status='COMPLETE'),
#   OptimizationRecord(id='6935443', status='COMPLETE'),
#   OptimizationRecord(id='6967532', status='COMPLETE'),
#   OptimizationRecord(id='6967533', status='COMPLETE'),
#   OptimizationRecord(id='6967534', status='COMPLETE'),
#   OptimizationRecord(id='6967535', status='COMPLETE'),
#   OptimizationRecord(id='6985115', status='COMPLETE'),
#   OptimizationRecord(id='6985116', status='COMPLETE'),
#   OptimizationRecord(id='6985117', status='COMPLETE'),
#   OptimizationRecord(id='6985118', status='COMPLETE'),
#   OptimizationRecord(id='6985512', status='COMPLETE'),
#   OptimizationRecord(id='6985513', status='COMPLETE'),
#   OptimizationRecord(id='6985514', status='COMPLETE'),
#   OptimizationRecord(id='6985515', status='COMPLETE'),
#   OptimizationRecord(id='6986226', status='COMPLETE'),
#   OptimizationRecord(id='6986227', status='COMPLETE'),
#   OptimizationRecord(id='6986228', status='COMPLETE'),
#   OptimizationRecord(id='6986229', status='COMPLETE'),
#   OptimizationRecord(id='7004608', status='COMPLETE'),
#   OptimizationRecord(id='7004609', status='COMPLETE'),
#   OptimizationRecord(id='7004610', status='COMPLETE'),
#   OptimizationRecord(id='7004611', status='COMPLETE'),
#   OptimizationRecord(id='7011947', status='COMPLETE'),
#   OptimizationRecord(id='7011948', status='COMPLETE'),
#   OptimizationRecord(id='7011949', status='COMPLETE'),
#   OptimizationRecord(id='7011950', status='COMPLETE'),
#   OptimizationRecord(id='7022965', status='COMPLETE'),
#   OptimizationRecord(id='7022966', status='COMPLETE'),
#   OptimizationRecord(id='7022967', status='COMPLETE'),
#   OptimizationRecord(id='7022968', status='COMPLETE'),
#   OptimizationRecord(id='7022969', status='COMPLETE'),
#   OptimizationRecord(id='7022970', status='COMPLETE'),
#   OptimizationRecord(id='21139835', status='COMPLETE'),
#   OptimizationRecord(id='21139836', status='COMPLETE'),
#   OptimizationRecord(id='21139837', status='ERROR'),
#   OptimizationRecord(id='21139838', status='COMPLETE'),
#   OptimizationRecord(id='21139839', status='COMPLETE'),
#   OptimizationRecord(id='21139840', status='COMPLETE')]}

# %%
resm = merge(res)

# %%
incomplete = (opt.dict() for opt in resm if opt.status == 'INCOMPLETE')

# %%
next(incomplete)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-61-3729b8af7b87> in <module>
# ----> 1 next(incomplete)
#
# StopIteration:

# %% [markdown]
# Yay!

# %%
count_unique_optimization_error_messages(resm, full=True, pretty_print=True)
# Out:
# There are 1 instances of
# -------------------------------------
# Caught Executor Error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/qcfractal/queue/executor_adapter.py", line 15, in _get_future
#     return future.result()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/concurrent/futures/_base.py", line 425, in result
#     return self.__get_result()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
# concurrent.futures.process.BrokenProcessPool: A process in the process pool was terminated abruptly while the future was running or pending.
#
# -------------------------------------

# %%
restart_optimizations(resm, client)
# Out:
# OptimizationRecord(id='21139837', status='ERROR')

# %%
restart_torsiondrives(ds.df.default.tolist(), client)
# Out:
# TorsionDriveRecord(id='6098580', status='ERROR')

# %% [markdown]
# Oh...might need to keep going.

# %% [markdown]
# ### 2020.06.11 22:20 UTC

# %%
dataset = "OpenFF Gen 2 Torsion Set 3 Pfizer Discrepancy 2"

# %%
ds = client.get_collection("TorsionDriveDataset", dataset)

# %%
ds.list_specifications()
# Out:
#                                          Description
# Name
# default  Standard OpenFF torsiondrive specification.

# %%
res = get_unfinished_torsiondrive_optimizations(ds, 'default', client, merged=False)
res
# Out:
# {}

# %%
resm = merge(res)

# %%
incomplete = (opt.dict() for opt in resm if opt.status == 'INCOMPLETE')

# %%
next(incomplete)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-52-3729b8af7b87> in <module>
# ----> 1 next(incomplete)
#
# StopIteration:

# %% [markdown]
# Yay!

# %%
count_unique_optimization_error_messages(resm, pretty_print=True)

# %%
restart_optimizations(resm, client)

# %%
restart_torsiondrives(ds.df.default.tolist(), client)
# Out:
# TorsionDriveRecord(id='6098580', status='ERROR')

# %% [markdown]
# Oh...might need to keep going.

# %% [markdown]
# ## Dataset tracking - OpenFF Gen 2 Torsion Set 4 eMolecules Discrepancy 2

# %% [markdown]
# ### 2020.06.27 01:20 UTC

# %%
dataset = "OpenFF Gen 2 Torsion Set 4 eMolecules Discrepancy 2"

# %%
ds = client.get_collection("TorsionDriveDataset", dataset)

# %%
ds.list_specifications()
# Out:
#                                          Description
# Name
# default  Standard OpenFF torsiondrive specification.

# %%
res = get_unfinished_torsiondrive_optimizations(ds, 'default', client)
res
# Out:
# {'18536969': [OptimizationRecord(id='18702051', status='COMPLETE'),
#   OptimizationRecord(id='18702052', status='COMPLETE'),
#   OptimizationRecord(id='18702053', status='COMPLETE'),
#   OptimizationRecord(id='18702054', status='COMPLETE'),
#   OptimizationRecord(id='18702055', status='COMPLETE'),
#   OptimizationRecord(id='18702056', status='COMPLETE'),
#   OptimizationRecord(id='18702068', status='COMPLETE'),
#   OptimizationRecord(id='18702069', status='COMPLETE'),
#   OptimizationRecord(id='18702070', status='COMPLETE'),
#   OptimizationRecord(id='18719526', status='COMPLETE'),
#   OptimizationRecord(id='18719527', status='COMPLETE'),
#   OptimizationRecord(id='18724906', status='COMPLETE'),
#   OptimizationRecord(id='18724907', status='COMPLETE'),
#   OptimizationRecord(id='18724908', status='COMPLETE'),
#   OptimizationRecord(id='18724909', status='COMPLETE'),
#   OptimizationRecord(id='18731422', status='COMPLETE'),
#   OptimizationRecord(id='18731423', status='COMPLETE'),
#   OptimizationRecord(id='18731424', status='COMPLETE'),
#   OptimizationRecord(id='18731438', status='COMPLETE'),
#   OptimizationRecord(id='18740358', status='COMPLETE'),
#   OptimizationRecord(id='18740359', status='COMPLETE'),
#   OptimizationRecord(id='18740360', status='COMPLETE'),
#   OptimizationRecord(id='18740361', status='COMPLETE'),
#   OptimizationRecord(id='18745720', status='COMPLETE'),
#   OptimizationRecord(id='18745721', status='COMPLETE'),
#   OptimizationRecord(id='18745722', status='COMPLETE'),
#   OptimizationRecord(id='18745723', status='COMPLETE'),
#   OptimizationRecord(id='18754935', status='COMPLETE'),
#   OptimizationRecord(id='18754936', status='COMPLETE'),
#   OptimizationRecord(id='18754937', status='COMPLETE'),
#   OptimizationRecord(id='18754938', status='COMPLETE'),
#   OptimizationRecord(id='18763290', status='COMPLETE'),
#   OptimizationRecord(id='18763291', status='COMPLETE'),
#   OptimizationRecord(id='18763318', status='COMPLETE'),
#   OptimizationRecord(id='18763319', status='COMPLETE'),
#   OptimizationRecord(id='18769173', status='COMPLETE'),
#   OptimizationRecord(id='18769174', status='COMPLETE'),
#   OptimizationRecord(id='18769175', status='COMPLETE'),
#   OptimizationRecord(id='18769176', status='COMPLETE'),
#   OptimizationRecord(id='18773286', status='COMPLETE'),
#   OptimizationRecord(id='18773287', status='COMPLETE'),
#   OptimizationRecord(id='18773288', status='COMPLETE'),
#   OptimizationRecord(id='18773302', status='COMPLETE'),
#   OptimizationRecord(id='21139841', status='COMPLETE'),
#   OptimizationRecord(id='21139842', status='COMPLETE'),
#   OptimizationRecord(id='21139843', status='COMPLETE'),
#   OptimizationRecord(id='21139844', status='COMPLETE'),
#   OptimizationRecord(id='21226508', status='COMPLETE'),
#   OptimizationRecord(id='21226509', status='COMPLETE'),
#   OptimizationRecord(id='21226510', status='COMPLETE'),
#   OptimizationRecord(id='21226511', status='COMPLETE'),
#   OptimizationRecord(id='21229655', status='COMPLETE'),
#   OptimizationRecord(id='21229656', status='COMPLETE'),
#   OptimizationRecord(id='21229657', status='COMPLETE'),
#   OptimizationRecord(id='21229658', status='COMPLETE'),
#   OptimizationRecord(id='21230311', status='ERROR'),
#   OptimizationRecord(id='21230312', status='COMPLETE')],
#  '18536971': [OptimizationRecord(id='18702529', status='COMPLETE'),
#   OptimizationRecord(id='18702540', status='COMPLETE'),
#   OptimizationRecord(id='18707071', status='COMPLETE'),
#   OptimizationRecord(id='18707072', status='COMPLETE'),
#   OptimizationRecord(id='18707073', status='COMPLETE'),
#   OptimizationRecord(id='18707074', status='COMPLETE'),
#   OptimizationRecord(id='18713190', status='COMPLETE'),
#   OptimizationRecord(id='18713191', status='COMPLETE'),
#   OptimizationRecord(id='18713192', status='COMPLETE'),
#   OptimizationRecord(id='18713193', status='COMPLETE'),
#   OptimizationRecord(id='18713194', status='COMPLETE'),
#   OptimizationRecord(id='18713195', status='COMPLETE'),
#   OptimizationRecord(id='18713214', status='COMPLETE'),
#   OptimizationRecord(id='18713215', status='COMPLETE'),
#   OptimizationRecord(id='18719197', status='COMPLETE'),
#   OptimizationRecord(id='18719198', status='COMPLETE'),
#   OptimizationRecord(id='18719199', status='COMPLETE'),
#   OptimizationRecord(id='18719200', status='COMPLETE'),
#   OptimizationRecord(id='18719201', status='COMPLETE'),
#   OptimizationRecord(id='18719202', status='COMPLETE'),
#   OptimizationRecord(id='18719203', status='COMPLETE'),
#   OptimizationRecord(id='18719204', status='COMPLETE'),
#   OptimizationRecord(id='18728536', status='COMPLETE'),
#   OptimizationRecord(id='18728537', status='COMPLETE'),
#   OptimizationRecord(id='18728548', status='COMPLETE'),
#   OptimizationRecord(id='18728558', status='COMPLETE'),
#   OptimizationRecord(id='18728574', status='INCOMPLETE'),
#   OptimizationRecord(id='18728575', status='COMPLETE'),
#   OptimizationRecord(id='18728576', status='COMPLETE'),
#   OptimizationRecord(id='18728577', status='COMPLETE')],
#  '18536988': [OptimizationRecord(id='17443442', status='COMPLETE'),
#   OptimizationRecord(id='17443443', status='COMPLETE'),
#   OptimizationRecord(id='17443444', status='COMPLETE'),
#   OptimizationRecord(id='17443445', status='COMPLETE'),
#   OptimizationRecord(id='17454188', status='COMPLETE'),
#   OptimizationRecord(id='17454189', status='COMPLETE'),
#   OptimizationRecord(id='17454190', status='COMPLETE'),
#   OptimizationRecord(id='17454191', status='COMPLETE'),
#   OptimizationRecord(id='17454192', status='COMPLETE'),
#   OptimizationRecord(id='17454193', status='COMPLETE'),
#   OptimizationRecord(id='17454194', status='COMPLETE'),
#   OptimizationRecord(id='17454195', status='COMPLETE'),
#   OptimizationRecord(id='17462908', status='COMPLETE'),
#   OptimizationRecord(id='17462909', status='COMPLETE'),
#   OptimizationRecord(id='17462910', status='COMPLETE'),
#   OptimizationRecord(id='17462911', status='COMPLETE'),
#   OptimizationRecord(id='17462912', status='COMPLETE'),
#   OptimizationRecord(id='17462913', status='COMPLETE'),
#   OptimizationRecord(id='17462914', status='COMPLETE'),
#   OptimizationRecord(id='17462915', status='COMPLETE'),
#   OptimizationRecord(id='17462916', status='COMPLETE'),
#   OptimizationRecord(id='17462917', status='COMPLETE'),
#   OptimizationRecord(id='17462918', status='COMPLETE'),
#   OptimizationRecord(id='17462919', status='COMPLETE'),
#   OptimizationRecord(id='17462920', status='COMPLETE'),
#   OptimizationRecord(id='17462921', status='COMPLETE'),
#   OptimizationRecord(id='17462933', status='COMPLETE'),
#   OptimizationRecord(id='17462934', status='COMPLETE'),
#   OptimizationRecord(id='17477557', status='COMPLETE'),
#   OptimizationRecord(id='17477558', status='COMPLETE'),
#   OptimizationRecord(id='17477559', status='COMPLETE'),
#   OptimizationRecord(id='17477560', status='COMPLETE'),
#   OptimizationRecord(id='17477561', status='COMPLETE'),
#   OptimizationRecord(id='17477562', status='COMPLETE'),
#   OptimizationRecord(id='17477563', status='COMPLETE'),
#   OptimizationRecord(id='17477564', status='COMPLETE'),
#   OptimizationRecord(id='17477565', status='COMPLETE'),
#   OptimizationRecord(id='17477566', status='COMPLETE'),
#   OptimizationRecord(id='17477567', status='COMPLETE'),
#   OptimizationRecord(id='17477568', status='COMPLETE'),
#   OptimizationRecord(id='17477569', status='COMPLETE'),
#   OptimizationRecord(id='17477570', status='COMPLETE'),
#   OptimizationRecord(id='17477571', status='ERROR'),
#   OptimizationRecord(id='17477572', status='COMPLETE')],
#  '18537041': [OptimizationRecord(id='18753840', status='COMPLETE'),
#   OptimizationRecord(id='18753841', status='COMPLETE'),
#   OptimizationRecord(id='18753842', status='COMPLETE'),
#   OptimizationRecord(id='18753843', status='COMPLETE'),
#   OptimizationRecord(id='18753844', status='COMPLETE'),
#   OptimizationRecord(id='18753845', status='COMPLETE'),
#   OptimizationRecord(id='18760545', status='COMPLETE'),
#   OptimizationRecord(id='18760549', status='COMPLETE'),
#   OptimizationRecord(id='18780223', status='COMPLETE'),
#   OptimizationRecord(id='18780224', status='COMPLETE'),
#   OptimizationRecord(id='18780225', status='COMPLETE'),
#   OptimizationRecord(id='18780226', status='COMPLETE'),
#   OptimizationRecord(id='18784286', status='COMPLETE'),
#   OptimizationRecord(id='18784287', status='COMPLETE'),
#   OptimizationRecord(id='18784288', status='COMPLETE'),
#   OptimizationRecord(id='18784289', status='COMPLETE'),
#   OptimizationRecord(id='18789634', status='COMPLETE'),
#   OptimizationRecord(id='18789635', status='COMPLETE'),
#   OptimizationRecord(id='18789636', status='COMPLETE'),
#   OptimizationRecord(id='18789637', status='COMPLETE'),
#   OptimizationRecord(id='18794787', status='COMPLETE'),
#   OptimizationRecord(id='18794796', status='COMPLETE'),
#   OptimizationRecord(id='18794797', status='COMPLETE'),
#   OptimizationRecord(id='18794798', status='COMPLETE'),
#   OptimizationRecord(id='18797372', status='COMPLETE'),
#   OptimizationRecord(id='18797373', status='COMPLETE'),
#   OptimizationRecord(id='18797374', status='COMPLETE'),
#   OptimizationRecord(id='18797375', status='COMPLETE'),
#   OptimizationRecord(id='18812934', status='COMPLETE'),
#   OptimizationRecord(id='18812935', status='COMPLETE'),
#   OptimizationRecord(id='18812936', status='COMPLETE'),
#   OptimizationRecord(id='18812937', status='COMPLETE'),
#   OptimizationRecord(id='21139845', status='COMPLETE'),
#   OptimizationRecord(id='21139846', status='COMPLETE'),
#   OptimizationRecord(id='21139847', status='COMPLETE'),
#   OptimizationRecord(id='21139848', status='COMPLETE'),
#   OptimizationRecord(id='21226870', status='COMPLETE'),
#   OptimizationRecord(id='21226871', status='COMPLETE'),
#   OptimizationRecord(id='21226872', status='COMPLETE'),
#   OptimizationRecord(id='21226873', status='COMPLETE'),
#   OptimizationRecord(id='21231210', status='COMPLETE'),
#   OptimizationRecord(id='21231211', status='COMPLETE'),
#   OptimizationRecord(id='21231212', status='COMPLETE'),
#   OptimizationRecord(id='21231213', status='COMPLETE'),
#   OptimizationRecord(id='21241786', status='COMPLETE'),
#   OptimizationRecord(id='21241787', status='COMPLETE'),
#   OptimizationRecord(id='21241788', status='COMPLETE'),
#   OptimizationRecord(id='21241789', status='INCOMPLETE')],
#  '18537046': [OptimizationRecord(id='18090040', status='COMPLETE'),
#   OptimizationRecord(id='18090041', status='COMPLETE'),
#   OptimizationRecord(id='18090042', status='COMPLETE'),
#   OptimizationRecord(id='18090043', status='COMPLETE'),
#   OptimizationRecord(id='18090044', status='COMPLETE'),
#   OptimizationRecord(id='18090045', status='COMPLETE'),
#   OptimizationRecord(id='18090046', status='COMPLETE'),
#   OptimizationRecord(id='18106804', status='COMPLETE'),
#   OptimizationRecord(id='18106805', status='COMPLETE'),
#   OptimizationRecord(id='18106806', status='COMPLETE'),
#   OptimizationRecord(id='18106807', status='COMPLETE'),
#   OptimizationRecord(id='18106808', status='COMPLETE'),
#   OptimizationRecord(id='18106809', status='COMPLETE'),
#   OptimizationRecord(id='18106810', status='COMPLETE'),
#   OptimizationRecord(id='18106811', status='COMPLETE'),
#   OptimizationRecord(id='18106812', status='COMPLETE'),
#   OptimizationRecord(id='18106813', status='COMPLETE'),
#   OptimizationRecord(id='18106814', status='COMPLETE'),
#   OptimizationRecord(id='18106815', status='COMPLETE'),
#   OptimizationRecord(id='18106816', status='COMPLETE'),
#   OptimizationRecord(id='18106817', status='COMPLETE'),
#   OptimizationRecord(id='18119959', status='COMPLETE'),
#   OptimizationRecord(id='18119960', status='COMPLETE'),
#   OptimizationRecord(id='18119961', status='COMPLETE'),
#   OptimizationRecord(id='18119962', status='COMPLETE'),
#   OptimizationRecord(id='18119963', status='COMPLETE'),
#   OptimizationRecord(id='18119964', status='COMPLETE'),
#   OptimizationRecord(id='18119965', status='COMPLETE'),
#   OptimizationRecord(id='18119966', status='COMPLETE'),
#   OptimizationRecord(id='18119967', status='COMPLETE'),
#   OptimizationRecord(id='18119968', status='COMPLETE'),
#   OptimizationRecord(id='18119969', status='COMPLETE'),
#   OptimizationRecord(id='18119970', status='COMPLETE'),
#   OptimizationRecord(id='18119971', status='COMPLETE'),
#   OptimizationRecord(id='18119972', status='COMPLETE'),
#   OptimizationRecord(id='18119973', status='COMPLETE'),
#   OptimizationRecord(id='18119974', status='COMPLETE'),
#   OptimizationRecord(id='18119975', status='COMPLETE'),
#   OptimizationRecord(id='18119976', status='COMPLETE'),
#   OptimizationRecord(id='18119977', status='COMPLETE'),
#   OptimizationRecord(id='18119981', status='COMPLETE'),
#   OptimizationRecord(id='18120001', status='COMPLETE'),
#   OptimizationRecord(id='18120007', status='COMPLETE'),
#   OptimizationRecord(id='18120015', status='COMPLETE'),
#   OptimizationRecord(id='18120016', status='COMPLETE'),
#   OptimizationRecord(id='18131661', status='COMPLETE'),
#   OptimizationRecord(id='18131662', status='COMPLETE'),
#   OptimizationRecord(id='18131663', status='COMPLETE'),
#   OptimizationRecord(id='18131664', status='COMPLETE'),
#   OptimizationRecord(id='18131681', status='COMPLETE'),
#   OptimizationRecord(id='18131682', status='COMPLETE'),
#   OptimizationRecord(id='18131683', status='COMPLETE'),
#   OptimizationRecord(id='18131684', status='COMPLETE'),
#   OptimizationRecord(id='18131685', status='COMPLETE'),
#   OptimizationRecord(id='18131686', status='COMPLETE'),
#   OptimizationRecord(id='18131687', status='COMPLETE'),
#   OptimizationRecord(id='18131688', status='COMPLETE'),
#   OptimizationRecord(id='18131689', status='COMPLETE'),
#   OptimizationRecord(id='18131690', status='COMPLETE'),
#   OptimizationRecord(id='18131691', status='COMPLETE'),
#   OptimizationRecord(id='18131692', status='COMPLETE'),
#   OptimizationRecord(id='18131693', status='COMPLETE'),
#   OptimizationRecord(id='18131694', status='COMPLETE'),
#   OptimizationRecord(id='18143618', status='COMPLETE'),
#   OptimizationRecord(id='18143619', status='COMPLETE'),
#   OptimizationRecord(id='18143620', status='INCOMPLETE'),
#   OptimizationRecord(id='18143630', status='COMPLETE'),
#   OptimizationRecord(id='18143631', status='COMPLETE'),
#   OptimizationRecord(id='18143632', status='COMPLETE'),
#   OptimizationRecord(id='18143633', status='COMPLETE'),
#   OptimizationRecord(id='18143634', status='COMPLETE'),
#   OptimizationRecord(id='18143635', status='COMPLETE'),
#   OptimizationRecord(id='18143636', status='COMPLETE'),
#   OptimizationRecord(id='18143637', status='COMPLETE'),
#   OptimizationRecord(id='18143638', status='COMPLETE'),
#   OptimizationRecord(id='18143639', status='COMPLETE'),
#   OptimizationRecord(id='18143640', status='COMPLETE'),
#   OptimizationRecord(id='18143641', status='COMPLETE'),
#   OptimizationRecord(id='18143642', status='COMPLETE'),
#   OptimizationRecord(id='18143643', status='COMPLETE'),
#   OptimizationRecord(id='18143644', status='COMPLETE')],
#  '18537079': [OptimizationRecord(id='18779153', status='COMPLETE'),
#   OptimizationRecord(id='18781999', status='COMPLETE'),
#   OptimizationRecord(id='18782000', status='COMPLETE'),
#   OptimizationRecord(id='18785759', status='COMPLETE'),
#   OptimizationRecord(id='18785760', status='COMPLETE'),
#   OptimizationRecord(id='18785761', status='COMPLETE'),
#   OptimizationRecord(id='18785762', status='COMPLETE'),
#   OptimizationRecord(id='18878347', status='COMPLETE'),
#   OptimizationRecord(id='18878348', status='COMPLETE'),
#   OptimizationRecord(id='18878349', status='COMPLETE'),
#   OptimizationRecord(id='18878350', status='COMPLETE'),
#   OptimizationRecord(id='18878351', status='COMPLETE'),
#   OptimizationRecord(id='18878352', status='COMPLETE'),
#   OptimizationRecord(id='18880720', status='COMPLETE'),
#   OptimizationRecord(id='18880721', status='COMPLETE'),
#   OptimizationRecord(id='18880722', status='COMPLETE'),
#   OptimizationRecord(id='18880723', status='COMPLETE'),
#   OptimizationRecord(id='18882203', status='COMPLETE'),
#   OptimizationRecord(id='18882204', status='COMPLETE'),
#   OptimizationRecord(id='18882205', status='COMPLETE'),
#   OptimizationRecord(id='18882206', status='COMPLETE'),
#   OptimizationRecord(id='18893526', status='ERROR'),
#   OptimizationRecord(id='18893527', status='COMPLETE'),
#   OptimizationRecord(id='18893528', status='COMPLETE'),
#   OptimizationRecord(id='18893529', status='COMPLETE')],
#  '18537099': [OptimizationRecord(id='18795576', status='COMPLETE'),
#   OptimizationRecord(id='18795577', status='COMPLETE'),
#   OptimizationRecord(id='18795578', status='COMPLETE'),
#   OptimizationRecord(id='18795579', status='COMPLETE'),
#   OptimizationRecord(id='18795580', status='COMPLETE'),
#   OptimizationRecord(id='18795581', status='COMPLETE'),
#   OptimizationRecord(id='18795582', status='COMPLETE'),
#   OptimizationRecord(id='18795583', status='COMPLETE'),
#   OptimizationRecord(id='18795584', status='COMPLETE'),
#   OptimizationRecord(id='18795585', status='COMPLETE'),
#   OptimizationRecord(id='18795586', status='COMPLETE'),
#   OptimizationRecord(id='18795587', status='COMPLETE'),
#   OptimizationRecord(id='18795588', status='COMPLETE'),
#   OptimizationRecord(id='18795589', status='COMPLETE'),
#   OptimizationRecord(id='18795590', status='COMPLETE'),
#   OptimizationRecord(id='18795591', status='COMPLETE'),
#   OptimizationRecord(id='18795592', status='COMPLETE'),
#   OptimizationRecord(id='18795593', status='COMPLETE'),
#   OptimizationRecord(id='18795594', status='COMPLETE'),
#   OptimizationRecord(id='18795595', status='COMPLETE'),
#   OptimizationRecord(id='18795596', status='COMPLETE'),
#   OptimizationRecord(id='18795597', status='COMPLETE'),
#   OptimizationRecord(id='18795598', status='COMPLETE'),
#   OptimizationRecord(id='18795599', status='COMPLETE'),
#   OptimizationRecord(id='18795600', status='COMPLETE'),
#   OptimizationRecord(id='18795601', status='COMPLETE'),
#   OptimizationRecord(id='18795602', status='COMPLETE'),
#   OptimizationRecord(id='18795603', status='COMPLETE'),
#   OptimizationRecord(id='18795604', status='COMPLETE'),
#   OptimizationRecord(id='18795605', status='COMPLETE'),
#   OptimizationRecord(id='18795606', status='COMPLETE'),
#   OptimizationRecord(id='18795607', status='COMPLETE'),
#   OptimizationRecord(id='18795608', status='COMPLETE'),
#   OptimizationRecord(id='18795609', status='COMPLETE'),
#   OptimizationRecord(id='18795610', status='COMPLETE'),
#   OptimizationRecord(id='18795611', status='COMPLETE'),
#   OptimizationRecord(id='18795612', status='COMPLETE'),
#   OptimizationRecord(id='18795613', status='COMPLETE'),
#   OptimizationRecord(id='18795614', status='COMPLETE'),
#   OptimizationRecord(id='18795615', status='COMPLETE'),
#   OptimizationRecord(id='18795616', status='COMPLETE'),
#   OptimizationRecord(id='18795617', status='COMPLETE'),
#   OptimizationRecord(id='18795618', status='COMPLETE'),
#   OptimizationRecord(id='18819828', status='ERROR'),
#   OptimizationRecord(id='18819829', status='COMPLETE'),
#   OptimizationRecord(id='18819830', status='COMPLETE'),
#   OptimizationRecord(id='18819831', status='COMPLETE'),
#   OptimizationRecord(id='18819832', status='COMPLETE'),
#   OptimizationRecord(id='18819833', status='COMPLETE'),
#   OptimizationRecord(id='18819834', status='COMPLETE'),
#   OptimizationRecord(id='18819835', status='COMPLETE'),
#   OptimizationRecord(id='18819836', status='COMPLETE'),
#   OptimizationRecord(id='18819837', status='COMPLETE'),
#   OptimizationRecord(id='18819838', status='COMPLETE'),
#   OptimizationRecord(id='18819839', status='COMPLETE'),
#   OptimizationRecord(id='18819860', status='COMPLETE'),
#   OptimizationRecord(id='18819861', status='COMPLETE'),
#   OptimizationRecord(id='18819862', status='COMPLETE'),
#   OptimizationRecord(id='18819894', status='COMPLETE'),
#   OptimizationRecord(id='18819895', status='COMPLETE'),
#   OptimizationRecord(id='18819896', status='COMPLETE'),
#   OptimizationRecord(id='18819897', status='COMPLETE'),
#   OptimizationRecord(id='18819898', status='COMPLETE'),
#   OptimizationRecord(id='18819899', status='COMPLETE'),
#   OptimizationRecord(id='18819900', status='COMPLETE'),
#   OptimizationRecord(id='18819901', status='COMPLETE'),
#   OptimizationRecord(id='18819902', status='COMPLETE')],
#  '18537137': [OptimizationRecord(id='18821592', status='COMPLETE'),
#   OptimizationRecord(id='18821593', status='COMPLETE'),
#   OptimizationRecord(id='18821594', status='COMPLETE'),
#   OptimizationRecord(id='18821595', status='COMPLETE'),
#   OptimizationRecord(id='18821596', status='COMPLETE'),
#   OptimizationRecord(id='18821597', status='COMPLETE'),
#   OptimizationRecord(id='18821598', status='COMPLETE'),
#   OptimizationRecord(id='18821599', status='COMPLETE'),
#   OptimizationRecord(id='18821611', status='COMPLETE'),
#   OptimizationRecord(id='18821612', status='COMPLETE'),
#   OptimizationRecord(id='18821613', status='COMPLETE'),
#   OptimizationRecord(id='18835237', status='COMPLETE'),
#   OptimizationRecord(id='18835238', status='COMPLETE'),
#   OptimizationRecord(id='18835239', status='COMPLETE'),
#   OptimizationRecord(id='18835240', status='COMPLETE'),
#   OptimizationRecord(id='18835241', status='COMPLETE'),
#   OptimizationRecord(id='18835242', status='COMPLETE'),
#   OptimizationRecord(id='18835243', status='COMPLETE'),
#   OptimizationRecord(id='18835244', status='COMPLETE'),
#   OptimizationRecord(id='18835245', status='COMPLETE'),
#   OptimizationRecord(id='18835246', status='COMPLETE'),
#   OptimizationRecord(id='18841316', status='COMPLETE'),
#   OptimizationRecord(id='18841317', status='COMPLETE'),
#   OptimizationRecord(id='18841318', status='COMPLETE'),
#   OptimizationRecord(id='18841319', status='COMPLETE'),
#   OptimizationRecord(id='18841320', status='COMPLETE'),
#   OptimizationRecord(id='18841321', status='COMPLETE'),
#   OptimizationRecord(id='18841322', status='COMPLETE'),
#   OptimizationRecord(id='18841323', status='COMPLETE'),
#   OptimizationRecord(id='18841324', status='INCOMPLETE'),
#   OptimizationRecord(id='18841325', status='COMPLETE'),
#   OptimizationRecord(id='18841326', status='COMPLETE'),
#   OptimizationRecord(id='18841327', status='COMPLETE'),
#   OptimizationRecord(id='18841328', status='COMPLETE'),
#   OptimizationRecord(id='18841329', status='COMPLETE')],
#  '18537143': [OptimizationRecord(id='18154864', status='COMPLETE'),
#   OptimizationRecord(id='18154865', status='COMPLETE'),
#   OptimizationRecord(id='18172099', status='COMPLETE'),
#   OptimizationRecord(id='18172100', status='COMPLETE'),
#   OptimizationRecord(id='18172101', status='COMPLETE'),
#   OptimizationRecord(id='18172102', status='COMPLETE'),
#   OptimizationRecord(id='18186081', status='INCOMPLETE'),
#   OptimizationRecord(id='18186082', status='COMPLETE'),
#   OptimizationRecord(id='18186083', status='COMPLETE'),
#   OptimizationRecord(id='18186084', status='COMPLETE'),
#   OptimizationRecord(id='18186085', status='COMPLETE'),
#   OptimizationRecord(id='18186086', status='COMPLETE'),
#   OptimizationRecord(id='18186087', status='COMPLETE'),
#   OptimizationRecord(id='18186088', status='COMPLETE')],
#  '18537175': [OptimizationRecord(id='18838540', status='ERROR'),
#   OptimizationRecord(id='18838541', status='COMPLETE'),
#   OptimizationRecord(id='18838542', status='ERROR'),
#   OptimizationRecord(id='18838543', status='ERROR'),
#   OptimizationRecord(id='18838544', status='ERROR')],
#  '18537176': [OptimizationRecord(id='18839164', status='COMPLETE'),
#   OptimizationRecord(id='18839165', status='COMPLETE'),
#   OptimizationRecord(id='18843502', status='COMPLETE'),
#   OptimizationRecord(id='18843512', status='COMPLETE'),
#   OptimizationRecord(id='18847389', status='COMPLETE'),
#   OptimizationRecord(id='18847390', status='COMPLETE'),
#   OptimizationRecord(id='18847391', status='COMPLETE'),
#   OptimizationRecord(id='18847392', status='COMPLETE'),
#   OptimizationRecord(id='18849382', status='COMPLETE'),
#   OptimizationRecord(id='18849383', status='COMPLETE'),
#   OptimizationRecord(id='18849384', status='COMPLETE'),
#   OptimizationRecord(id='18849385', status='COMPLETE'),
#   OptimizationRecord(id='18850754', status='COMPLETE'),
#   OptimizationRecord(id='18850755', status='COMPLETE'),
#   OptimizationRecord(id='18850756', status='COMPLETE'),
#   OptimizationRecord(id='18850757', status='COMPLETE'),
#   OptimizationRecord(id='18859075', status='COMPLETE'),
#   OptimizationRecord(id='18859076', status='ERROR'),
#   OptimizationRecord(id='18859077', status='COMPLETE'),
#   OptimizationRecord(id='18859078', status='COMPLETE')],
#  '18537177': [OptimizationRecord(id='18839166', status='COMPLETE'),
#   OptimizationRecord(id='18844526', status='COMPLETE'),
#   OptimizationRecord(id='18844527', status='COMPLETE'),
#   OptimizationRecord(id='18847208', status='COMPLETE'),
#   OptimizationRecord(id='18847221', status='COMPLETE'),
#   OptimizationRecord(id='18847222', status='COMPLETE'),
#   OptimizationRecord(id='18847223', status='COMPLETE'),
#   OptimizationRecord(id='18849392', status='COMPLETE'),
#   OptimizationRecord(id='18849398', status='COMPLETE'),
#   OptimizationRecord(id='18849399', status='COMPLETE'),
#   OptimizationRecord(id='18849400', status='COMPLETE'),
#   OptimizationRecord(id='18850603', status='COMPLETE'),
#   OptimizationRecord(id='18850604', status='COMPLETE'),
#   OptimizationRecord(id='18850605', status='COMPLETE'),
#   OptimizationRecord(id='18850606', status='COMPLETE'),
#   OptimizationRecord(id='18860205', status='COMPLETE'),
#   OptimizationRecord(id='18860217', status='COMPLETE'),
#   OptimizationRecord(id='18860218', status='COMPLETE'),
#   OptimizationRecord(id='18860219', status='COMPLETE'),
#   OptimizationRecord(id='18861419', status='COMPLETE'),
#   OptimizationRecord(id='18861420', status='ERROR'),
#   OptimizationRecord(id='18861421', status='ERROR'),
#   OptimizationRecord(id='18861422', status='COMPLETE')],
#  '18537178': [OptimizationRecord(id='18839167', status='COMPLETE'),
#   OptimizationRecord(id='18845169', status='COMPLETE'),
#   OptimizationRecord(id='18845170', status='COMPLETE'),
#   OptimizationRecord(id='18846968', status='COMPLETE'),
#   OptimizationRecord(id='18846969', status='COMPLETE'),
#   OptimizationRecord(id='18846970', status='COMPLETE'),
#   OptimizationRecord(id='18846971', status='COMPLETE'),
#   OptimizationRecord(id='18850907', status='COMPLETE'),
#   OptimizationRecord(id='18850908', status='COMPLETE'),
#   OptimizationRecord(id='18850909', status='COMPLETE'),
#   OptimizationRecord(id='18850910', status='COMPLETE'),
#   OptimizationRecord(id='18853274', status='COMPLETE'),
#   OptimizationRecord(id='18853275', status='COMPLETE'),
#   OptimizationRecord(id='18853276', status='COMPLETE'),
#   OptimizationRecord(id='18853277', status='COMPLETE'),
#   OptimizationRecord(id='18853287', status='COMPLETE'),
#   OptimizationRecord(id='18853288', status='COMPLETE'),
#   OptimizationRecord(id='18853289', status='COMPLETE'),
#   OptimizationRecord(id='18853290', status='COMPLETE'),
#   OptimizationRecord(id='18858457', status='COMPLETE'),
#   OptimizationRecord(id='18858458', status='COMPLETE'),
#   OptimizationRecord(id='18858459', status='COMPLETE'),
#   OptimizationRecord(id='18858460', status='COMPLETE'),
#   OptimizationRecord(id='18858461', status='COMPLETE'),
#   OptimizationRecord(id='18858462', status='COMPLETE'),
#   OptimizationRecord(id='18861796', status='COMPLETE'),
#   OptimizationRecord(id='18861797', status='COMPLETE'),
#   OptimizationRecord(id='18861798', status='ERROR'),
#   OptimizationRecord(id='18861799', status='ERROR'),
#   OptimizationRecord(id='18861800', status='COMPLETE'),
#   OptimizationRecord(id='18861801', status='COMPLETE')]}

# %%
resm = merge(res)

# %%
incomplete = (opt.dict() for opt in resm if opt.status == 'INCOMPLETE')

# %%
next(incomplete)
# Out:
# {'id': '18728574',
#  'hash_index': 'e6aab7bf13ba38652010a14e81d430c1677faf9c',
#  'procedure': 'optimization',
#  'program': 'geometric',
#  'version': 1,
#  'protocols': {},
#  'extras': {},
#  'stdout': '21880305',
#  'stderr': None,
#  'error': None,
#  'task_id': None,
#  'manager_name': None,
#  'status': <RecordStatusEnum.incomplete: 'INCOMPLETE'>,
#  'modified_on': datetime.datetime(2020, 3, 25, 20, 32, 14, 719173),
#  'created_on': datetime.datetime(2020, 3, 25, 19, 40, 9, 388225),
#  'provenance': {'creator': 'geomeTRIC',
#   'version': '0.9.7.2',
#   'routine': 'geometric.run_json.geometric_run_json',
#   'hostname': 'lt12',
#   'qcengine_version': '0.14.0',
#   'wall_time': 289.17519211769104,
#   'cpu': 'Intel(R) Xeon(R) CPU E5-2697 v4 @ 2.30GHz',
#   'username': 'chodera'},
#  'schema_version': 1,
#  'initial_molecule': '12388402',
#  'qc_spec': {'driver': <DriverEnum.gradient: 'gradient'>,
#   'method': 'b3lyp-d3bj',
#   'basis': 'dzvp',
#   'keywords': '2',
#   'program': 'psi4'},
#  'keywords': {'coordsys': 'tric',
#   'enforce': 0.1,
#   'reset': True,
#   'qccnv': True,
#   'epsilon': 0,
#   'constraints': {'set': [{'type': 'dihedral',
#      'indices': [0, 2, 6, 18],
#      'value': 30}]},
#   'program': 'psi4'},
#  'energies': [-736.1397689605966,
#   -736.1401683369459,
#   -736.1404376324541,
#   -736.1406625629581,
#   -736.1409776085941,
#   -736.1410123694537,
#   -736.1410128458234,
#   -736.1410193909098,
#   -736.1410204796607,
#   -736.1410214635695],
#  'final_molecule': '12400611',
#  'trajectory': ['18722932',
#   '18736175',
#   '18736177',
#   '18736179',
#   '18736181',
#   '18736183',
#   '18736185',
#   '18736187',
#   '18736189',
#   '18736190']}

# %% [markdown]
# Not quite all Lilac INCOMPLETEs; at least one without a manager.

# %%
count_unique_optimization_error_messages(resm, full=True, pretty_print=True, tolerate_missing=True)
# Out:
# There are 1 instances of
# -------------------------------------
# Caught Executor Error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/qcfractal/queue/executor_adapter.py", line 15, in _get_future
#     return future.result()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/concurrent/futures/_base.py", line 425, in result
#     return self.__get_result()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
# concurrent.futures.process.BrokenProcessPool: A process in the process pool was terminated abruptly while the future was running or pending.
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# None
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# Caught Executor Error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/opt/lib/python3.7/site-packages/qcfractal-0.13.1+54.g3caa178.dirty-py3.7.egg/qcfractal/queue/executor_adapter.py", line 15, in _get_future
#     return future.result()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/distributed/client.py", line 218, in result
#     raise exc.with_traceback(tb)
# distributed.scheduler.KilledWorker: ('compute_procedure-8b7d527b63687a4550d1418d753d3144', <Worker 'tcp://10.240.60.27:46854', name: 58, memory: 0, processing: 10>)
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# Caught Executor Error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/opt/lib/python3.7/site-packages/qcfractal-0.13.1+54.g3caa178.dirty-py3.7.egg/qcfractal/queue/executor_adapter.py", line 15, in _get_future
#     return future.result()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/distributed/client.py", line 218, in result
#     raise exc.with_traceback(tb)
# distributed.scheduler.KilledWorker: ('compute_procedure-b1dd2e868beadbc7140396f88b537f4d', <Worker 'tcp://10.240.60.43:35402', name: 64, memory: 0, processing: 1>)
#
# -------------------------------------
#
# There are 2 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1296, in optimizeGeometry
#     self.step()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1100, in step
#     self.checkCoordinateSystem(recover=True, cartesian=LastForce)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 959, in checkCoordinateSystem
#     raise ValueError("Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates")
# ValueError: Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates
#
# -------------------------------------
#
# There are 5 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1296, in optimizeGeometry
#     self.step()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1100, in step
#     self.checkCoordinateSystem(recover=True, cartesian=LastForce)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 959, in checkCoordinateSystem
#     raise ValueError("Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates")
# ValueError: Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1298, in optimizeGeometry
#     self.calcEnergyForce()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1002, in calcEnergyForce
#     spcalc = self.engine.calc(self.X, self.dirname)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/engine.py", line 873, in calc
#     return self.calc_new(coords, dirname)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/engine.py", line 865, in calc_new
#     raise QCEngineAPIEngineError("QCEngineAPI computation did not execute correctly. Message: " + ret["error"]["error_message"])
# geometric.errors.QCEngineAPIEngineError: QCEngineAPI computation did not execute correctly. Message: QCEngine Unknown Error: Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/json_wrapper.py", line 217, in run_json
#     json_data = run_json_qcschema(copy.deepcopy(json_data), clean)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/json_wrapper.py", line 312, in run_json_qcschema
#     val, wfn = methods_dict_[json_data["driver"]](method, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/driver.py", line 691, in gradient
#     wfn = procedures['gradient'][lowername](lowername, molecule=molecule, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/proc.py", line 2064, in run_scf_gradient
#     ref_wfn = run_scf(name, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/proc.py", line 2002, in run_scf
#     scf_wfn = scf_helper(name, post_scf=False, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/proc.py", line 1363, in scf_helper
#     e_scf = scf_wfn.compute_energy()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 94, in scf_compute_energy
#     raise e
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 87, in scf_compute_energy
#     self.iterations()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 447, in scf_iterate
#     raise SCFConvergenceError("""SCF iterations""", self.iteration_, self, Ediff, Dnorm)
# psi4.driver.p4util.exceptions.SCFConvergenceError: Could not converge SCF iterations in 200 iterations.
#
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1296, in optimizeGeometry
#     self.step()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1085, in step
#     iopt = brent_wiki(froot.evaluate, 0.0, iopt, froot.target, cvg=0.1, verbose=params.verbose)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 187, in brent_wiki
#     raise RuntimeError('Not bracketed')
# RuntimeError: Not bracketed
#
# -------------------------------------

# %%
restart_optimizations(resm, client)
# Out:
# OptimizationRecord(id='21230311', status='ERROR')
# OptimizationRecord(id='17477571', status='ERROR')
# OptimizationRecord(id='18893526', status='ERROR')
# OptimizationRecord(id='18819828', status='ERROR')
# OptimizationRecord(id='18838540', status='ERROR')
# OptimizationRecord(id='18838542', status='ERROR')
# OptimizationRecord(id='18838543', status='ERROR')
# OptimizationRecord(id='18838544', status='ERROR')
# OptimizationRecord(id='18859076', status='ERROR')
# OptimizationRecord(id='18861420', status='ERROR')
# OptimizationRecord(id='18861421', status='ERROR')
# OptimizationRecord(id='18861798', status='ERROR')
# OptimizationRecord(id='18861799', status='ERROR')

# %%
restart_torsiondrives(ds.df.default.tolist(), client)
# Out:
# TorsionDriveRecord(id='18536969', status='ERROR')
# TorsionDriveRecord(id='18536988', status='ERROR')
# TorsionDriveRecord(id='18537079', status='ERROR')
# TorsionDriveRecord(id='18537099', status='ERROR')
# TorsionDriveRecord(id='18537175', status='ERROR')
# TorsionDriveRecord(id='18537176', status='ERROR')
# TorsionDriveRecord(id='18537177', status='ERROR')
# TorsionDriveRecord(id='18537178', status='ERROR')

# %% [markdown]
# ### 2020.06.11 22:20 UTC

# %%
dataset = "OpenFF Gen 2 Torsion Set 4 eMolecules Discrepancy 2"

# %%
ds = client.get_collection("TorsionDriveDataset", dataset)

# %%
ds.list_specifications()
# Out:
#                                          Description
# Name
# default  Standard OpenFF torsiondrive specification.

# %%
res = get_unfinished_torsiondrive_optimizations(ds, 'default', client, merged=False)
res
# Out:
# {'18536969': [OptimizationRecord(id='18702051', status='COMPLETE'),
#   OptimizationRecord(id='18702052', status='COMPLETE'),
#   OptimizationRecord(id='18702053', status='COMPLETE'),
#   OptimizationRecord(id='18702054', status='COMPLETE'),
#   OptimizationRecord(id='18702055', status='COMPLETE'),
#   OptimizationRecord(id='18702056', status='COMPLETE'),
#   OptimizationRecord(id='18702068', status='COMPLETE'),
#   OptimizationRecord(id='18702069', status='COMPLETE'),
#   OptimizationRecord(id='18702070', status='COMPLETE'),
#   OptimizationRecord(id='18719526', status='COMPLETE'),
#   OptimizationRecord(id='18719527', status='COMPLETE'),
#   OptimizationRecord(id='18724906', status='COMPLETE'),
#   OptimizationRecord(id='18724907', status='COMPLETE'),
#   OptimizationRecord(id='18724908', status='COMPLETE'),
#   OptimizationRecord(id='18724909', status='COMPLETE'),
#   OptimizationRecord(id='18731422', status='COMPLETE'),
#   OptimizationRecord(id='18731423', status='COMPLETE'),
#   OptimizationRecord(id='18731424', status='COMPLETE'),
#   OptimizationRecord(id='18731438', status='COMPLETE'),
#   OptimizationRecord(id='18740358', status='COMPLETE'),
#   OptimizationRecord(id='18740359', status='COMPLETE'),
#   OptimizationRecord(id='18740360', status='COMPLETE'),
#   OptimizationRecord(id='18740361', status='COMPLETE'),
#   OptimizationRecord(id='18745720', status='COMPLETE'),
#   OptimizationRecord(id='18745721', status='COMPLETE'),
#   OptimizationRecord(id='18745722', status='COMPLETE'),
#   OptimizationRecord(id='18745723', status='COMPLETE'),
#   OptimizationRecord(id='18754935', status='COMPLETE'),
#   OptimizationRecord(id='18754936', status='COMPLETE'),
#   OptimizationRecord(id='18754937', status='COMPLETE'),
#   OptimizationRecord(id='18754938', status='COMPLETE'),
#   OptimizationRecord(id='18763290', status='COMPLETE'),
#   OptimizationRecord(id='18763291', status='COMPLETE'),
#   OptimizationRecord(id='18763318', status='COMPLETE'),
#   OptimizationRecord(id='18763319', status='COMPLETE'),
#   OptimizationRecord(id='18769173', status='COMPLETE'),
#   OptimizationRecord(id='18769174', status='COMPLETE'),
#   OptimizationRecord(id='18769175', status='COMPLETE'),
#   OptimizationRecord(id='18769176', status='COMPLETE'),
#   OptimizationRecord(id='18773286', status='COMPLETE'),
#   OptimizationRecord(id='18773287', status='COMPLETE'),
#   OptimizationRecord(id='18773288', status='COMPLETE'),
#   OptimizationRecord(id='18773302', status='COMPLETE')],
#  '18536971': [OptimizationRecord(id='18702529', status='COMPLETE'),
#   OptimizationRecord(id='18702540', status='COMPLETE'),
#   OptimizationRecord(id='18707071', status='COMPLETE'),
#   OptimizationRecord(id='18707072', status='COMPLETE'),
#   OptimizationRecord(id='18707073', status='COMPLETE'),
#   OptimizationRecord(id='18707074', status='COMPLETE'),
#   OptimizationRecord(id='18713190', status='COMPLETE'),
#   OptimizationRecord(id='18713191', status='COMPLETE'),
#   OptimizationRecord(id='18713192', status='COMPLETE'),
#   OptimizationRecord(id='18713193', status='COMPLETE'),
#   OptimizationRecord(id='18713194', status='COMPLETE'),
#   OptimizationRecord(id='18713195', status='COMPLETE'),
#   OptimizationRecord(id='18713214', status='COMPLETE'),
#   OptimizationRecord(id='18713215', status='COMPLETE'),
#   OptimizationRecord(id='18719197', status='COMPLETE'),
#   OptimizationRecord(id='18719198', status='COMPLETE'),
#   OptimizationRecord(id='18719199', status='COMPLETE'),
#   OptimizationRecord(id='18719200', status='COMPLETE'),
#   OptimizationRecord(id='18719201', status='COMPLETE'),
#   OptimizationRecord(id='18719202', status='COMPLETE'),
#   OptimizationRecord(id='18719203', status='COMPLETE'),
#   OptimizationRecord(id='18719204', status='COMPLETE'),
#   OptimizationRecord(id='18728536', status='COMPLETE'),
#   OptimizationRecord(id='18728537', status='COMPLETE'),
#   OptimizationRecord(id='18728548', status='COMPLETE'),
#   OptimizationRecord(id='18728558', status='COMPLETE'),
#   OptimizationRecord(id='18728574', status='INCOMPLETE'),
#   OptimizationRecord(id='18728575', status='COMPLETE'),
#   OptimizationRecord(id='18728576', status='COMPLETE'),
#   OptimizationRecord(id='18728577', status='COMPLETE')],
#  '18536988': [OptimizationRecord(id='17443442', status='COMPLETE'),
#   OptimizationRecord(id='17443443', status='COMPLETE'),
#   OptimizationRecord(id='17443444', status='COMPLETE'),
#   OptimizationRecord(id='17443445', status='COMPLETE'),
#   OptimizationRecord(id='17454188', status='COMPLETE'),
#   OptimizationRecord(id='17454189', status='COMPLETE'),
#   OptimizationRecord(id='17454190', status='COMPLETE'),
#   OptimizationRecord(id='17454191', status='COMPLETE'),
#   OptimizationRecord(id='17454192', status='COMPLETE'),
#   OptimizationRecord(id='17454193', status='COMPLETE'),
#   OptimizationRecord(id='17454194', status='COMPLETE'),
#   OptimizationRecord(id='17454195', status='COMPLETE'),
#   OptimizationRecord(id='17462908', status='COMPLETE'),
#   OptimizationRecord(id='17462909', status='COMPLETE'),
#   OptimizationRecord(id='17462910', status='COMPLETE'),
#   OptimizationRecord(id='17462911', status='COMPLETE'),
#   OptimizationRecord(id='17462912', status='COMPLETE'),
#   OptimizationRecord(id='17462913', status='COMPLETE'),
#   OptimizationRecord(id='17462914', status='COMPLETE'),
#   OptimizationRecord(id='17462915', status='COMPLETE'),
#   OptimizationRecord(id='17462916', status='COMPLETE'),
#   OptimizationRecord(id='17462917', status='COMPLETE'),
#   OptimizationRecord(id='17462918', status='COMPLETE'),
#   OptimizationRecord(id='17462919', status='COMPLETE'),
#   OptimizationRecord(id='17462920', status='COMPLETE'),
#   OptimizationRecord(id='17462921', status='COMPLETE'),
#   OptimizationRecord(id='17462933', status='COMPLETE'),
#   OptimizationRecord(id='17462934', status='COMPLETE'),
#   OptimizationRecord(id='17477557', status='COMPLETE'),
#   OptimizationRecord(id='17477558', status='COMPLETE'),
#   OptimizationRecord(id='17477559', status='COMPLETE'),
#   OptimizationRecord(id='17477560', status='COMPLETE'),
#   OptimizationRecord(id='17477561', status='COMPLETE'),
#   OptimizationRecord(id='17477562', status='COMPLETE'),
#   OptimizationRecord(id='17477563', status='COMPLETE'),
#   OptimizationRecord(id='17477564', status='COMPLETE'),
#   OptimizationRecord(id='17477565', status='COMPLETE'),
#   OptimizationRecord(id='17477566', status='COMPLETE'),
#   OptimizationRecord(id='17477567', status='COMPLETE'),
#   OptimizationRecord(id='17477568', status='COMPLETE'),
#   OptimizationRecord(id='17477569', status='COMPLETE'),
#   OptimizationRecord(id='17477570', status='COMPLETE'),
#   OptimizationRecord(id='17477571', status='ERROR'),
#   OptimizationRecord(id='17477572', status='COMPLETE')],
#  '18537041': [OptimizationRecord(id='18753840', status='COMPLETE'),
#   OptimizationRecord(id='18753841', status='COMPLETE'),
#   OptimizationRecord(id='18753842', status='COMPLETE'),
#   OptimizationRecord(id='18753843', status='COMPLETE'),
#   OptimizationRecord(id='18753844', status='COMPLETE'),
#   OptimizationRecord(id='18753845', status='COMPLETE'),
#   OptimizationRecord(id='18760545', status='COMPLETE'),
#   OptimizationRecord(id='18760549', status='COMPLETE'),
#   OptimizationRecord(id='18780223', status='COMPLETE'),
#   OptimizationRecord(id='18780224', status='COMPLETE'),
#   OptimizationRecord(id='18780225', status='COMPLETE'),
#   OptimizationRecord(id='18780226', status='COMPLETE'),
#   OptimizationRecord(id='18784286', status='COMPLETE'),
#   OptimizationRecord(id='18784287', status='COMPLETE'),
#   OptimizationRecord(id='18784288', status='COMPLETE'),
#   OptimizationRecord(id='18784289', status='COMPLETE'),
#   OptimizationRecord(id='18789634', status='COMPLETE'),
#   OptimizationRecord(id='18789635', status='COMPLETE'),
#   OptimizationRecord(id='18789636', status='COMPLETE'),
#   OptimizationRecord(id='18789637', status='COMPLETE'),
#   OptimizationRecord(id='18794787', status='COMPLETE'),
#   OptimizationRecord(id='18794796', status='COMPLETE'),
#   OptimizationRecord(id='18794797', status='COMPLETE'),
#   OptimizationRecord(id='18794798', status='COMPLETE'),
#   OptimizationRecord(id='18797372', status='COMPLETE'),
#   OptimizationRecord(id='18797373', status='COMPLETE'),
#   OptimizationRecord(id='18797374', status='COMPLETE'),
#   OptimizationRecord(id='18797375', status='COMPLETE'),
#   OptimizationRecord(id='18812934', status='COMPLETE'),
#   OptimizationRecord(id='18812935', status='COMPLETE'),
#   OptimizationRecord(id='18812936', status='COMPLETE'),
#   OptimizationRecord(id='18812937', status='COMPLETE')],
#  '18537046': [OptimizationRecord(id='18090040', status='COMPLETE'),
#   OptimizationRecord(id='18090041', status='COMPLETE'),
#   OptimizationRecord(id='18090042', status='COMPLETE'),
#   OptimizationRecord(id='18090043', status='COMPLETE'),
#   OptimizationRecord(id='18090044', status='COMPLETE'),
#   OptimizationRecord(id='18090045', status='COMPLETE'),
#   OptimizationRecord(id='18090046', status='COMPLETE'),
#   OptimizationRecord(id='18106804', status='COMPLETE'),
#   OptimizationRecord(id='18106805', status='COMPLETE'),
#   OptimizationRecord(id='18106806', status='COMPLETE'),
#   OptimizationRecord(id='18106807', status='COMPLETE'),
#   OptimizationRecord(id='18106808', status='COMPLETE'),
#   OptimizationRecord(id='18106809', status='COMPLETE'),
#   OptimizationRecord(id='18106810', status='COMPLETE'),
#   OptimizationRecord(id='18106811', status='COMPLETE'),
#   OptimizationRecord(id='18106812', status='COMPLETE'),
#   OptimizationRecord(id='18106813', status='COMPLETE'),
#   OptimizationRecord(id='18106814', status='COMPLETE'),
#   OptimizationRecord(id='18106815', status='COMPLETE'),
#   OptimizationRecord(id='18106816', status='COMPLETE'),
#   OptimizationRecord(id='18106817', status='COMPLETE'),
#   OptimizationRecord(id='18119959', status='COMPLETE'),
#   OptimizationRecord(id='18119960', status='COMPLETE'),
#   OptimizationRecord(id='18119961', status='COMPLETE'),
#   OptimizationRecord(id='18119962', status='COMPLETE'),
#   OptimizationRecord(id='18119963', status='COMPLETE'),
#   OptimizationRecord(id='18119964', status='COMPLETE'),
#   OptimizationRecord(id='18119965', status='COMPLETE'),
#   OptimizationRecord(id='18119966', status='COMPLETE'),
#   OptimizationRecord(id='18119967', status='COMPLETE'),
#   OptimizationRecord(id='18119968', status='COMPLETE'),
#   OptimizationRecord(id='18119969', status='COMPLETE'),
#   OptimizationRecord(id='18119970', status='COMPLETE'),
#   OptimizationRecord(id='18119971', status='COMPLETE'),
#   OptimizationRecord(id='18119972', status='COMPLETE'),
#   OptimizationRecord(id='18119973', status='COMPLETE'),
#   OptimizationRecord(id='18119974', status='COMPLETE'),
#   OptimizationRecord(id='18119975', status='COMPLETE'),
#   OptimizationRecord(id='18119976', status='COMPLETE'),
#   OptimizationRecord(id='18119977', status='COMPLETE'),
#   OptimizationRecord(id='18119981', status='COMPLETE'),
#   OptimizationRecord(id='18120001', status='COMPLETE'),
#   OptimizationRecord(id='18120007', status='COMPLETE'),
#   OptimizationRecord(id='18120015', status='COMPLETE'),
#   OptimizationRecord(id='18120016', status='COMPLETE'),
#   OptimizationRecord(id='18131661', status='COMPLETE'),
#   OptimizationRecord(id='18131662', status='COMPLETE'),
#   OptimizationRecord(id='18131663', status='COMPLETE'),
#   OptimizationRecord(id='18131664', status='COMPLETE'),
#   OptimizationRecord(id='18131681', status='COMPLETE'),
#   OptimizationRecord(id='18131682', status='COMPLETE'),
#   OptimizationRecord(id='18131683', status='COMPLETE'),
#   OptimizationRecord(id='18131684', status='COMPLETE'),
#   OptimizationRecord(id='18131685', status='COMPLETE'),
#   OptimizationRecord(id='18131686', status='COMPLETE'),
#   OptimizationRecord(id='18131687', status='COMPLETE'),
#   OptimizationRecord(id='18131688', status='COMPLETE'),
#   OptimizationRecord(id='18131689', status='COMPLETE'),
#   OptimizationRecord(id='18131690', status='COMPLETE'),
#   OptimizationRecord(id='18131691', status='COMPLETE'),
#   OptimizationRecord(id='18131692', status='COMPLETE'),
#   OptimizationRecord(id='18131693', status='COMPLETE'),
#   OptimizationRecord(id='18131694', status='COMPLETE'),
#   OptimizationRecord(id='18143618', status='COMPLETE'),
#   OptimizationRecord(id='18143619', status='COMPLETE'),
#   OptimizationRecord(id='18143620', status='INCOMPLETE'),
#   OptimizationRecord(id='18143630', status='COMPLETE'),
#   OptimizationRecord(id='18143631', status='COMPLETE'),
#   OptimizationRecord(id='18143632', status='COMPLETE'),
#   OptimizationRecord(id='18143633', status='COMPLETE'),
#   OptimizationRecord(id='18143634', status='COMPLETE'),
#   OptimizationRecord(id='18143635', status='COMPLETE'),
#   OptimizationRecord(id='18143636', status='COMPLETE'),
#   OptimizationRecord(id='18143637', status='COMPLETE'),
#   OptimizationRecord(id='18143638', status='COMPLETE'),
#   OptimizationRecord(id='18143639', status='COMPLETE'),
#   OptimizationRecord(id='18143640', status='COMPLETE'),
#   OptimizationRecord(id='18143641', status='COMPLETE'),
#   OptimizationRecord(id='18143642', status='COMPLETE'),
#   OptimizationRecord(id='18143643', status='COMPLETE'),
#   OptimizationRecord(id='18143644', status='COMPLETE')],
#  '18537079': [OptimizationRecord(id='18779153', status='COMPLETE'),
#   OptimizationRecord(id='18781999', status='COMPLETE'),
#   OptimizationRecord(id='18782000', status='COMPLETE'),
#   OptimizationRecord(id='18785759', status='COMPLETE'),
#   OptimizationRecord(id='18785760', status='COMPLETE'),
#   OptimizationRecord(id='18785761', status='COMPLETE'),
#   OptimizationRecord(id='18785762', status='COMPLETE'),
#   OptimizationRecord(id='18878347', status='COMPLETE'),
#   OptimizationRecord(id='18878348', status='COMPLETE'),
#   OptimizationRecord(id='18878349', status='COMPLETE'),
#   OptimizationRecord(id='18878350', status='COMPLETE'),
#   OptimizationRecord(id='18878351', status='COMPLETE'),
#   OptimizationRecord(id='18878352', status='COMPLETE'),
#   OptimizationRecord(id='18880720', status='COMPLETE'),
#   OptimizationRecord(id='18880721', status='COMPLETE'),
#   OptimizationRecord(id='18880722', status='COMPLETE'),
#   OptimizationRecord(id='18880723', status='COMPLETE'),
#   OptimizationRecord(id='18882203', status='COMPLETE'),
#   OptimizationRecord(id='18882204', status='COMPLETE'),
#   OptimizationRecord(id='18882205', status='COMPLETE'),
#   OptimizationRecord(id='18882206', status='COMPLETE'),
#   OptimizationRecord(id='18893526', status='ERROR'),
#   OptimizationRecord(id='18893527', status='COMPLETE'),
#   OptimizationRecord(id='18893528', status='COMPLETE'),
#   OptimizationRecord(id='18893529', status='COMPLETE')],
#  '18537099': [OptimizationRecord(id='18795576', status='COMPLETE'),
#   OptimizationRecord(id='18795577', status='COMPLETE'),
#   OptimizationRecord(id='18795578', status='COMPLETE'),
#   OptimizationRecord(id='18795579', status='COMPLETE'),
#   OptimizationRecord(id='18795580', status='COMPLETE'),
#   OptimizationRecord(id='18795581', status='COMPLETE'),
#   OptimizationRecord(id='18795582', status='COMPLETE'),
#   OptimizationRecord(id='18795583', status='COMPLETE'),
#   OptimizationRecord(id='18795584', status='COMPLETE'),
#   OptimizationRecord(id='18795585', status='COMPLETE'),
#   OptimizationRecord(id='18795586', status='COMPLETE'),
#   OptimizationRecord(id='18795587', status='COMPLETE'),
#   OptimizationRecord(id='18795588', status='COMPLETE'),
#   OptimizationRecord(id='18795589', status='COMPLETE'),
#   OptimizationRecord(id='18795590', status='COMPLETE'),
#   OptimizationRecord(id='18795591', status='COMPLETE'),
#   OptimizationRecord(id='18795592', status='COMPLETE'),
#   OptimizationRecord(id='18795593', status='COMPLETE'),
#   OptimizationRecord(id='18795594', status='COMPLETE'),
#   OptimizationRecord(id='18795595', status='COMPLETE'),
#   OptimizationRecord(id='18795596', status='COMPLETE'),
#   OptimizationRecord(id='18795597', status='COMPLETE'),
#   OptimizationRecord(id='18795598', status='COMPLETE'),
#   OptimizationRecord(id='18795599', status='COMPLETE'),
#   OptimizationRecord(id='18795600', status='COMPLETE'),
#   OptimizationRecord(id='18795601', status='COMPLETE'),
#   OptimizationRecord(id='18795602', status='COMPLETE'),
#   OptimizationRecord(id='18795603', status='COMPLETE'),
#   OptimizationRecord(id='18795604', status='COMPLETE'),
#   OptimizationRecord(id='18795605', status='COMPLETE'),
#   OptimizationRecord(id='18795606', status='COMPLETE'),
#   OptimizationRecord(id='18795607', status='COMPLETE'),
#   OptimizationRecord(id='18795608', status='COMPLETE'),
#   OptimizationRecord(id='18795609', status='COMPLETE'),
#   OptimizationRecord(id='18795610', status='COMPLETE'),
#   OptimizationRecord(id='18795611', status='COMPLETE'),
#   OptimizationRecord(id='18795612', status='COMPLETE'),
#   OptimizationRecord(id='18795613', status='COMPLETE'),
#   OptimizationRecord(id='18795614', status='COMPLETE'),
#   OptimizationRecord(id='18795615', status='COMPLETE'),
#   OptimizationRecord(id='18795616', status='COMPLETE'),
#   OptimizationRecord(id='18795617', status='COMPLETE'),
#   OptimizationRecord(id='18795618', status='COMPLETE'),
#   OptimizationRecord(id='18819828', status='ERROR'),
#   OptimizationRecord(id='18819829', status='COMPLETE'),
#   OptimizationRecord(id='18819830', status='COMPLETE'),
#   OptimizationRecord(id='18819831', status='COMPLETE'),
#   OptimizationRecord(id='18819832', status='COMPLETE'),
#   OptimizationRecord(id='18819833', status='COMPLETE'),
#   OptimizationRecord(id='18819834', status='COMPLETE'),
#   OptimizationRecord(id='18819835', status='COMPLETE'),
#   OptimizationRecord(id='18819836', status='COMPLETE'),
#   OptimizationRecord(id='18819837', status='COMPLETE'),
#   OptimizationRecord(id='18819838', status='COMPLETE'),
#   OptimizationRecord(id='18819839', status='COMPLETE'),
#   OptimizationRecord(id='18819860', status='COMPLETE'),
#   OptimizationRecord(id='18819861', status='COMPLETE'),
#   OptimizationRecord(id='18819862', status='COMPLETE'),
#   OptimizationRecord(id='18819894', status='COMPLETE'),
#   OptimizationRecord(id='18819895', status='COMPLETE'),
#   OptimizationRecord(id='18819896', status='COMPLETE'),
#   OptimizationRecord(id='18819897', status='COMPLETE'),
#   OptimizationRecord(id='18819898', status='COMPLETE'),
#   OptimizationRecord(id='18819899', status='COMPLETE'),
#   OptimizationRecord(id='18819900', status='COMPLETE'),
#   OptimizationRecord(id='18819901', status='COMPLETE'),
#   OptimizationRecord(id='18819902', status='COMPLETE')],
#  '18537114': [OptimizationRecord(id='18804557', status='COMPLETE'),
#   OptimizationRecord(id='18804558', status='COMPLETE'),
#   OptimizationRecord(id='18804559', status='COMPLETE'),
#   OptimizationRecord(id='18804560', status='COMPLETE'),
#   OptimizationRecord(id='18804561', status='COMPLETE'),
#   OptimizationRecord(id='18804562', status='COMPLETE'),
#   OptimizationRecord(id='18804563', status='COMPLETE'),
#   OptimizationRecord(id='18804564', status='COMPLETE'),
#   OptimizationRecord(id='18804565', status='COMPLETE'),
#   OptimizationRecord(id='18810095', status='COMPLETE'),
#   OptimizationRecord(id='18810111', status='COMPLETE'),
#   OptimizationRecord(id='18810112', status='COMPLETE'),
#   OptimizationRecord(id='18810113', status='COMPLETE'),
#   OptimizationRecord(id='18817808', status='COMPLETE'),
#   OptimizationRecord(id='18817809', status='COMPLETE'),
#   OptimizationRecord(id='18817810', status='COMPLETE'),
#   OptimizationRecord(id='18817825', status='COMPLETE'),
#   OptimizationRecord(id='18817826', status='COMPLETE'),
#   OptimizationRecord(id='18817827', status='COMPLETE'),
#   OptimizationRecord(id='18817828', status='COMPLETE'),
#   OptimizationRecord(id='18817829', status='COMPLETE'),
#   OptimizationRecord(id='18823144', status='COMPLETE'),
#   OptimizationRecord(id='18823147', status='COMPLETE'),
#   OptimizationRecord(id='18823148', status='COMPLETE'),
#   OptimizationRecord(id='18823149', status='COMPLETE'),
#   OptimizationRecord(id='18823159', status='COMPLETE'),
#   OptimizationRecord(id='18823160', status='COMPLETE'),
#   OptimizationRecord(id='18823161', status='COMPLETE'),
#   OptimizationRecord(id='18823176', status='COMPLETE'),
#   OptimizationRecord(id='18839071', status='COMPLETE'),
#   OptimizationRecord(id='18839085', status='COMPLETE'),
#   OptimizationRecord(id='18839086', status='COMPLETE'),
#   OptimizationRecord(id='18839104', status='COMPLETE'),
#   OptimizationRecord(id='18839122', status='COMPLETE'),
#   OptimizationRecord(id='18839132', status='COMPLETE'),
#   OptimizationRecord(id='18839154', status='COMPLETE'),
#   OptimizationRecord(id='18839155', status='COMPLETE'),
#   OptimizationRecord(id='18843705', status='COMPLETE'),
#   OptimizationRecord(id='18843706', status='COMPLETE'),
#   OptimizationRecord(id='18843707', status='COMPLETE'),
#   OptimizationRecord(id='18843708', status='COMPLETE'),
#   OptimizationRecord(id='18843709', status='COMPLETE'),
#   OptimizationRecord(id='18843710', status='COMPLETE'),
#   OptimizationRecord(id='18843711', status='COMPLETE'),
#   OptimizationRecord(id='18843712', status='COMPLETE'),
#   OptimizationRecord(id='18843721', status='COMPLETE'),
#   OptimizationRecord(id='18843722', status='COMPLETE'),
#   OptimizationRecord(id='18859712', status='COMPLETE'),
#   OptimizationRecord(id='18859713', status='COMPLETE'),
#   OptimizationRecord(id='18859714', status='COMPLETE'),
#   OptimizationRecord(id='18859715', status='COMPLETE'),
#   OptimizationRecord(id='18859716', status='COMPLETE'),
#   OptimizationRecord(id='18859717', status='COMPLETE'),
#   OptimizationRecord(id='18859718', status='COMPLETE'),
#   OptimizationRecord(id='18859719', status='COMPLETE'),
#   OptimizationRecord(id='18859720', status='COMPLETE'),
#   OptimizationRecord(id='18859721', status='COMPLETE'),
#   OptimizationRecord(id='18863275', status='COMPLETE'),
#   OptimizationRecord(id='18863276', status='COMPLETE'),
#   OptimizationRecord(id='18863277', status='COMPLETE'),
#   OptimizationRecord(id='18863278', status='COMPLETE')],
#  '18537137': [OptimizationRecord(id='18821592', status='COMPLETE'),
#   OptimizationRecord(id='18821593', status='COMPLETE'),
#   OptimizationRecord(id='18821594', status='COMPLETE'),
#   OptimizationRecord(id='18821595', status='COMPLETE'),
#   OptimizationRecord(id='18821596', status='COMPLETE'),
#   OptimizationRecord(id='18821597', status='COMPLETE'),
#   OptimizationRecord(id='18821598', status='COMPLETE'),
#   OptimizationRecord(id='18821599', status='COMPLETE'),
#   OptimizationRecord(id='18821611', status='COMPLETE'),
#   OptimizationRecord(id='18821612', status='COMPLETE'),
#   OptimizationRecord(id='18821613', status='COMPLETE'),
#   OptimizationRecord(id='18835237', status='COMPLETE'),
#   OptimizationRecord(id='18835238', status='COMPLETE'),
#   OptimizationRecord(id='18835239', status='COMPLETE'),
#   OptimizationRecord(id='18835240', status='COMPLETE'),
#   OptimizationRecord(id='18835241', status='COMPLETE'),
#   OptimizationRecord(id='18835242', status='COMPLETE'),
#   OptimizationRecord(id='18835243', status='COMPLETE'),
#   OptimizationRecord(id='18835244', status='COMPLETE'),
#   OptimizationRecord(id='18835245', status='COMPLETE'),
#   OptimizationRecord(id='18835246', status='COMPLETE'),
#   OptimizationRecord(id='18841316', status='COMPLETE'),
#   OptimizationRecord(id='18841317', status='COMPLETE'),
#   OptimizationRecord(id='18841318', status='COMPLETE'),
#   OptimizationRecord(id='18841319', status='COMPLETE'),
#   OptimizationRecord(id='18841320', status='COMPLETE'),
#   OptimizationRecord(id='18841321', status='COMPLETE'),
#   OptimizationRecord(id='18841322', status='COMPLETE'),
#   OptimizationRecord(id='18841323', status='COMPLETE'),
#   OptimizationRecord(id='18841324', status='INCOMPLETE'),
#   OptimizationRecord(id='18841325', status='COMPLETE'),
#   OptimizationRecord(id='18841326', status='COMPLETE'),
#   OptimizationRecord(id='18841327', status='COMPLETE'),
#   OptimizationRecord(id='18841328', status='COMPLETE'),
#   OptimizationRecord(id='18841329', status='COMPLETE')],
#  '18537143': [OptimizationRecord(id='18154864', status='COMPLETE'),
#   OptimizationRecord(id='18154865', status='COMPLETE'),
#   OptimizationRecord(id='18172099', status='COMPLETE'),
#   OptimizationRecord(id='18172100', status='COMPLETE'),
#   OptimizationRecord(id='18172101', status='COMPLETE'),
#   OptimizationRecord(id='18172102', status='COMPLETE'),
#   OptimizationRecord(id='18186081', status='INCOMPLETE'),
#   OptimizationRecord(id='18186082', status='COMPLETE'),
#   OptimizationRecord(id='18186083', status='COMPLETE'),
#   OptimizationRecord(id='18186084', status='COMPLETE'),
#   OptimizationRecord(id='18186085', status='COMPLETE'),
#   OptimizationRecord(id='18186086', status='COMPLETE'),
#   OptimizationRecord(id='18186087', status='COMPLETE'),
#   OptimizationRecord(id='18186088', status='COMPLETE')],
#  '18537175': [OptimizationRecord(id='18838540', status='ERROR'),
#   OptimizationRecord(id='18838541', status='COMPLETE'),
#   OptimizationRecord(id='18838542', status='ERROR'),
#   OptimizationRecord(id='18838543', status='ERROR'),
#   OptimizationRecord(id='18838544', status='ERROR')],
#  '18537176': [OptimizationRecord(id='18839164', status='COMPLETE'),
#   OptimizationRecord(id='18839165', status='COMPLETE'),
#   OptimizationRecord(id='18843502', status='COMPLETE'),
#   OptimizationRecord(id='18843512', status='COMPLETE'),
#   OptimizationRecord(id='18847389', status='COMPLETE'),
#   OptimizationRecord(id='18847390', status='COMPLETE'),
#   OptimizationRecord(id='18847391', status='COMPLETE'),
#   OptimizationRecord(id='18847392', status='COMPLETE'),
#   OptimizationRecord(id='18849382', status='COMPLETE'),
#   OptimizationRecord(id='18849383', status='COMPLETE'),
#   OptimizationRecord(id='18849384', status='COMPLETE'),
#   OptimizationRecord(id='18849385', status='COMPLETE'),
#   OptimizationRecord(id='18850754', status='COMPLETE'),
#   OptimizationRecord(id='18850755', status='COMPLETE'),
#   OptimizationRecord(id='18850756', status='COMPLETE'),
#   OptimizationRecord(id='18850757', status='COMPLETE'),
#   OptimizationRecord(id='18859075', status='COMPLETE'),
#   OptimizationRecord(id='18859076', status='ERROR'),
#   OptimizationRecord(id='18859077', status='COMPLETE'),
#   OptimizationRecord(id='18859078', status='COMPLETE')],
#  '18537177': [OptimizationRecord(id='18839166', status='COMPLETE'),
#   OptimizationRecord(id='18844526', status='COMPLETE'),
#   OptimizationRecord(id='18844527', status='COMPLETE'),
#   OptimizationRecord(id='18847208', status='COMPLETE'),
#   OptimizationRecord(id='18847221', status='COMPLETE'),
#   OptimizationRecord(id='18847222', status='COMPLETE'),
#   OptimizationRecord(id='18847223', status='COMPLETE'),
#   OptimizationRecord(id='18849392', status='COMPLETE'),
#   OptimizationRecord(id='18849398', status='COMPLETE'),
#   OptimizationRecord(id='18849399', status='COMPLETE'),
#   OptimizationRecord(id='18849400', status='COMPLETE'),
#   OptimizationRecord(id='18850603', status='COMPLETE'),
#   OptimizationRecord(id='18850604', status='COMPLETE'),
#   OptimizationRecord(id='18850605', status='COMPLETE'),
#   OptimizationRecord(id='18850606', status='COMPLETE'),
#   OptimizationRecord(id='18860205', status='COMPLETE'),
#   OptimizationRecord(id='18860217', status='COMPLETE'),
#   OptimizationRecord(id='18860218', status='COMPLETE'),
#   OptimizationRecord(id='18860219', status='COMPLETE'),
#   OptimizationRecord(id='18861419', status='COMPLETE'),
#   OptimizationRecord(id='18861420', status='ERROR'),
#   OptimizationRecord(id='18861421', status='ERROR'),
#   OptimizationRecord(id='18861422', status='COMPLETE')],
#  '18537178': [OptimizationRecord(id='18839167', status='COMPLETE'),
#   OptimizationRecord(id='18845169', status='COMPLETE'),
#   OptimizationRecord(id='18845170', status='COMPLETE'),
#   OptimizationRecord(id='18846968', status='COMPLETE'),
#   OptimizationRecord(id='18846969', status='COMPLETE'),
#   OptimizationRecord(id='18846970', status='COMPLETE'),
#   OptimizationRecord(id='18846971', status='COMPLETE'),
#   OptimizationRecord(id='18850907', status='COMPLETE'),
#   OptimizationRecord(id='18850908', status='COMPLETE'),
#   OptimizationRecord(id='18850909', status='COMPLETE'),
#   OptimizationRecord(id='18850910', status='COMPLETE'),
#   OptimizationRecord(id='18853274', status='COMPLETE'),
#   OptimizationRecord(id='18853275', status='COMPLETE'),
#   OptimizationRecord(id='18853276', status='COMPLETE'),
#   OptimizationRecord(id='18853277', status='COMPLETE'),
#   OptimizationRecord(id='18853287', status='COMPLETE'),
#   OptimizationRecord(id='18853288', status='COMPLETE'),
#   OptimizationRecord(id='18853289', status='COMPLETE'),
#   OptimizationRecord(id='18853290', status='COMPLETE'),
#   OptimizationRecord(id='18858457', status='COMPLETE'),
#   OptimizationRecord(id='18858458', status='COMPLETE'),
#   OptimizationRecord(id='18858459', status='COMPLETE'),
#   OptimizationRecord(id='18858460', status='COMPLETE'),
#   OptimizationRecord(id='18858461', status='COMPLETE'),
#   OptimizationRecord(id='18858462', status='COMPLETE'),
#   OptimizationRecord(id='18861796', status='COMPLETE'),
#   OptimizationRecord(id='18861797', status='COMPLETE'),
#   OptimizationRecord(id='18861798', status='ERROR'),
#   OptimizationRecord(id='18861799', status='ERROR'),
#   OptimizationRecord(id='18861800', status='COMPLETE'),
#   OptimizationRecord(id='18861801', status='COMPLETE')]}

# %%
resm = merge(res)

# %%
incomplete = (opt.dict() for opt in resm if opt.status == 'INCOMPLETE')

# %%
next(incomplete)
# Out:
# {'id': '18728574',
#  'hash_index': 'e6aab7bf13ba38652010a14e81d430c1677faf9c',
#  'procedure': 'optimization',
#  'program': 'geometric',
#  'version': 1,
#  'protocols': {},
#  'extras': {},
#  'stdout': '21880305',
#  'stderr': None,
#  'error': None,
#  'task_id': None,
#  'manager_name': None,
#  'status': <RecordStatusEnum.incomplete: 'INCOMPLETE'>,
#  'modified_on': datetime.datetime(2020, 3, 25, 20, 32, 14, 719173),
#  'created_on': datetime.datetime(2020, 3, 25, 19, 40, 9, 388225),
#  'provenance': {'creator': 'geomeTRIC',
#   'version': '0.9.7.2',
#   'routine': 'geometric.run_json.geometric_run_json',
#   'username': 'chodera',
#   'qcengine_version': '0.14.0',
#   'cpu': 'Intel(R) Xeon(R) CPU E5-2697 v4 @ 2.30GHz',
#   'hostname': 'lt12',
#   'wall_time': 289.17519211769104},
#  'schema_version': 1,
#  'initial_molecule': '12388402',
#  'qc_spec': {'driver': <DriverEnum.gradient: 'gradient'>,
#   'method': 'b3lyp-d3bj',
#   'basis': 'dzvp',
#   'keywords': '2',
#   'program': 'psi4'},
#  'keywords': {'coordsys': 'tric',
#   'enforce': 0.1,
#   'reset': True,
#   'qccnv': True,
#   'epsilon': 0,
#   'constraints': {'set': [{'type': 'dihedral',
#      'indices': [0, 2, 6, 18],
#      'value': 30}]},
#   'program': 'psi4'},
#  'energies': [-736.1397689605966,
#   -736.1401683369459,
#   -736.1404376324541,
#   -736.1406625629581,
#   -736.1409776085941,
#   -736.1410123694537,
#   -736.1410128458234,
#   -736.1410193909098,
#   -736.1410204796607,
#   -736.1410214635695],
#  'final_molecule': '12400611',
#  'trajectory': ['18722932',
#   '18736175',
#   '18736177',
#   '18736179',
#   '18736181',
#   '18736183',
#   '18736185',
#   '18736187',
#   '18736189',
#   '18736190']}

# %% [markdown]
# All Lilac INCOMPLETEs?

# %%
count_unique_optimization_error_messages(resm, full=True, pretty_print=True, tolerate_missing=True)
# Out:
# There are 1 instances of
# -------------------------------------
# None
# -------------------------------------
#
# There are 7 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1296, in optimizeGeometry
#     self.step()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1100, in step
#     self.checkCoordinateSystem(recover=True, cartesian=LastForce)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 959, in checkCoordinateSystem
#     raise ValueError("Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates")
# ValueError: Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates
#
# -------------------------------------
#
# There are 2 instances of
# -------------------------------------
# Caught Executor Error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/qcfractal/queue/executor_adapter.py", line 15, in _get_future
#     return future.result()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/concurrent/futures/_base.py", line 425, in result
#     return self.__get_result()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
# concurrent.futures.process.BrokenProcessPool: A process in the process pool was terminated abruptly while the future was running or pending.
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1296, in optimizeGeometry
#     self.step()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1085, in step
#     iopt = brent_wiki(froot.evaluate, 0.0, iopt, froot.target, cvg=0.1, verbose=params.verbose)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 187, in brent_wiki
#     raise RuntimeError('Not bracketed')
# RuntimeError: Not bracketed
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1298, in optimizeGeometry
#     self.calcEnergyForce()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1002, in calcEnergyForce
#     spcalc = self.engine.calc(self.X, self.dirname)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/engine.py", line 873, in calc
#     return self.calc_new(coords, dirname)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/engine.py", line 865, in calc_new
#     raise QCEngineAPIEngineError("QCEngineAPI computation did not execute correctly. Message: " + ret["error"]["error_message"])
# geometric.errors.QCEngineAPIEngineError: QCEngineAPI computation did not execute correctly. Message: QCEngine Unknown Error: Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/json_wrapper.py", line 217, in run_json
#     json_data = run_json_qcschema(copy.deepcopy(json_data), clean)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/json_wrapper.py", line 312, in run_json_qcschema
#     val, wfn = methods_dict_[json_data["driver"]](method, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/driver.py", line 691, in gradient
#     wfn = procedures['gradient'][lowername](lowername, molecule=molecule, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/proc.py", line 2064, in run_scf_gradient
#     ref_wfn = run_scf(name, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/proc.py", line 2002, in run_scf
#     scf_wfn = scf_helper(name, post_scf=False, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/proc.py", line 1363, in scf_helper
#     e_scf = scf_wfn.compute_energy()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 94, in scf_compute_energy
#     raise e
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 87, in scf_compute_energy
#     self.iterations()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 447, in scf_iterate
#     raise SCFConvergenceError("""SCF iterations""", self.iteration_, self, Ediff, Dnorm)
# psi4.driver.p4util.exceptions.SCFConvergenceError: Could not converge SCF iterations in 200 iterations.
#
#
# -------------------------------------

# %%
restart_optimizations(resm, client)
# Out:
# OptimizationRecord(id='17477571', status='ERROR')
# OptimizationRecord(id='18893526', status='ERROR')
# OptimizationRecord(id='18819828', status='ERROR')
# OptimizationRecord(id='18838540', status='ERROR')
# OptimizationRecord(id='18838542', status='ERROR')
# OptimizationRecord(id='18838543', status='ERROR')
# OptimizationRecord(id='18838544', status='ERROR')
# OptimizationRecord(id='18859076', status='ERROR')
# OptimizationRecord(id='18861420', status='ERROR')
# OptimizationRecord(id='18861421', status='ERROR')
# OptimizationRecord(id='18861798', status='ERROR')
# OptimizationRecord(id='18861799', status='ERROR')

# %%
restart_torsiondrives(ds.df.default.tolist(), client)
# Out:
# TorsionDriveRecord(id='18536969', status='ERROR')
# TorsionDriveRecord(id='18536988', status='ERROR')
# TorsionDriveRecord(id='18537041', status='ERROR')
# TorsionDriveRecord(id='18537079', status='ERROR')
# TorsionDriveRecord(id='18537099', status='ERROR')
# TorsionDriveRecord(id='18537114', status='ERROR')
# TorsionDriveRecord(id='18537175', status='ERROR')
# TorsionDriveRecord(id='18537176', status='ERROR')
# TorsionDriveRecord(id='18537177', status='ERROR')
# TorsionDriveRecord(id='18537178', status='ERROR')

# %% [markdown]
# ## Dataset tracking - OpenFF Gen 2 Torsion Set 5 Bayer 2

# %% [markdown]
# ### 2020.06.27 01:27 UTC

# %%
dataset = "OpenFF Gen 2 Torsion Set 5 Bayer 2"

# %%
ds = client.get_collection("TorsionDriveDataset", dataset)

# %%
ds.list_specifications()
# Out:
#                                          Description
# Name
# default  Standard OpenFF torsiondrive specification.

# %%
res = get_unfinished_torsiondrive_optimizations(ds, 'default', client)
res
# Out:
# {'18886168': [OptimizationRecord(id='18886256', status='COMPLETE'),
#   OptimizationRecord(id='18886259', status='COMPLETE'),
#   OptimizationRecord(id='18886262', status='COMPLETE'),
#   OptimizationRecord(id='18886264', status='COMPLETE'),
#   OptimizationRecord(id='18886267', status='COMPLETE'),
#   OptimizationRecord(id='18886268', status='COMPLETE'),
#   OptimizationRecord(id='18886271', status='COMPLETE'),
#   OptimizationRecord(id='18886273', status='COMPLETE'),
#   OptimizationRecord(id='18886275', status='COMPLETE'),
#   OptimizationRecord(id='18886277', status='COMPLETE'),
#   OptimizationRecord(id='18886279', status='COMPLETE'),
#   OptimizationRecord(id='18886291', status='COMPLETE'),
#   OptimizationRecord(id='18886292', status='COMPLETE'),
#   OptimizationRecord(id='18886295', status='COMPLETE'),
#   OptimizationRecord(id='18886296', status='COMPLETE'),
#   OptimizationRecord(id='18886297', status='COMPLETE'),
#   OptimizationRecord(id='18886298', status='COMPLETE'),
#   OptimizationRecord(id='18886300', status='COMPLETE'),
#   OptimizationRecord(id='18886302', status='COMPLETE'),
#   OptimizationRecord(id='18886304', status='COMPLETE'),
#   OptimizationRecord(id='18886305', status='COMPLETE'),
#   OptimizationRecord(id='18886309', status='COMPLETE'),
#   OptimizationRecord(id='18886311', status='COMPLETE'),
#   OptimizationRecord(id='18886313', status='COMPLETE'),
#   OptimizationRecord(id='18886316', status='COMPLETE'),
#   OptimizationRecord(id='18886318', status='COMPLETE'),
#   OptimizationRecord(id='18886320', status='COMPLETE'),
#   OptimizationRecord(id='18886322', status='COMPLETE'),
#   OptimizationRecord(id='18886323', status='COMPLETE'),
#   OptimizationRecord(id='18886325', status='COMPLETE'),
#   OptimizationRecord(id='18886327', status='COMPLETE'),
#   OptimizationRecord(id='18886328', status='COMPLETE'),
#   OptimizationRecord(id='18886329', status='COMPLETE'),
#   OptimizationRecord(id='18886330', status='COMPLETE'),
#   OptimizationRecord(id='18886332', status='COMPLETE'),
#   OptimizationRecord(id='18886334', status='COMPLETE'),
#   OptimizationRecord(id='18886335', status='COMPLETE'),
#   OptimizationRecord(id='18886336', status='COMPLETE'),
#   OptimizationRecord(id='18886337', status='COMPLETE'),
#   OptimizationRecord(id='18886338', status='COMPLETE'),
#   OptimizationRecord(id='18886341', status='COMPLETE'),
#   OptimizationRecord(id='18886344', status='COMPLETE'),
#   OptimizationRecord(id='18886347', status='COMPLETE'),
#   OptimizationRecord(id='18886349', status='COMPLETE'),
#   OptimizationRecord(id='18886352', status='COMPLETE'),
#   OptimizationRecord(id='18886353', status='COMPLETE'),
#   OptimizationRecord(id='18886356', status='COMPLETE'),
#   OptimizationRecord(id='18886357', status='COMPLETE'),
#   OptimizationRecord(id='18886358', status='COMPLETE'),
#   OptimizationRecord(id='18886360', status='COMPLETE'),
#   OptimizationRecord(id='18886363', status='COMPLETE'),
#   OptimizationRecord(id='18886365', status='COMPLETE'),
#   OptimizationRecord(id='18886366', status='COMPLETE'),
#   OptimizationRecord(id='18886367', status='COMPLETE'),
#   OptimizationRecord(id='18886368', status='COMPLETE'),
#   OptimizationRecord(id='18886370', status='COMPLETE'),
#   OptimizationRecord(id='18886373', status='COMPLETE'),
#   OptimizationRecord(id='18886377', status='COMPLETE'),
#   OptimizationRecord(id='18886380', status='COMPLETE'),
#   OptimizationRecord(id='18886382', status='COMPLETE'),
#   OptimizationRecord(id='18886385', status='COMPLETE'),
#   OptimizationRecord(id='18886386', status='COMPLETE'),
#   OptimizationRecord(id='18886387', status='COMPLETE'),
#   OptimizationRecord(id='18886390', status='COMPLETE'),
#   OptimizationRecord(id='18886393', status='COMPLETE'),
#   OptimizationRecord(id='18886395', status='COMPLETE')],
#  '18886202': [OptimizationRecord(id='18887451', status='COMPLETE'),
#   OptimizationRecord(id='18887452', status='COMPLETE'),
#   OptimizationRecord(id='18922536', status='COMPLETE'),
#   OptimizationRecord(id='18922537', status='COMPLETE'),
#   OptimizationRecord(id='18956306', status='COMPLETE'),
#   OptimizationRecord(id='18956307', status='COMPLETE'),
#   OptimizationRecord(id='18956308', status='COMPLETE'),
#   OptimizationRecord(id='18956309', status='COMPLETE'),
#   OptimizationRecord(id='18975308', status='COMPLETE'),
#   OptimizationRecord(id='18975309', status='COMPLETE'),
#   OptimizationRecord(id='18975310', status='COMPLETE'),
#   OptimizationRecord(id='18975311', status='COMPLETE'),
#   OptimizationRecord(id='18988928', status='COMPLETE'),
#   OptimizationRecord(id='18988929', status='COMPLETE'),
#   OptimizationRecord(id='18988930', status='COMPLETE'),
#   OptimizationRecord(id='18988931', status='COMPLETE'),
#   OptimizationRecord(id='18988932', status='COMPLETE'),
#   OptimizationRecord(id='18988933', status='COMPLETE'),
#   OptimizationRecord(id='18988934', status='COMPLETE'),
#   OptimizationRecord(id='18988935', status='COMPLETE'),
#   OptimizationRecord(id='19003570', status='COMPLETE'),
#   OptimizationRecord(id='19003571', status='COMPLETE'),
#   OptimizationRecord(id='19003572', status='COMPLETE'),
#   OptimizationRecord(id='19003573', status='COMPLETE'),
#   OptimizationRecord(id='19003574', status='COMPLETE'),
#   OptimizationRecord(id='19003575', status='COMPLETE'),
#   OptimizationRecord(id='19003576', status='COMPLETE'),
#   OptimizationRecord(id='19003577', status='COMPLETE'),
#   OptimizationRecord(id='19083510', status='COMPLETE'),
#   OptimizationRecord(id='19083511', status='COMPLETE'),
#   OptimizationRecord(id='19083512', status='COMPLETE'),
#   OptimizationRecord(id='19083513', status='COMPLETE'),
#   OptimizationRecord(id='19083514', status='COMPLETE'),
#   OptimizationRecord(id='19083515', status='COMPLETE')],
#  '18886207': [OptimizationRecord(id='18887748', status='COMPLETE'),
#   OptimizationRecord(id='18887749', status='COMPLETE'),
#   OptimizationRecord(id='18887750', status='COMPLETE'),
#   OptimizationRecord(id='18887751', status='COMPLETE'),
#   OptimizationRecord(id='18887752', status='COMPLETE'),
#   OptimizationRecord(id='18887753', status='COMPLETE'),
#   OptimizationRecord(id='18887754', status='COMPLETE'),
#   OptimizationRecord(id='18887755', status='COMPLETE'),
#   OptimizationRecord(id='18887756', status='COMPLETE'),
#   OptimizationRecord(id='18887757', status='COMPLETE'),
#   OptimizationRecord(id='18887758', status='COMPLETE'),
#   OptimizationRecord(id='18887759', status='COMPLETE'),
#   OptimizationRecord(id='18887760', status='COMPLETE'),
#   OptimizationRecord(id='18887761', status='COMPLETE'),
#   OptimizationRecord(id='18887762', status='COMPLETE'),
#   OptimizationRecord(id='18887763', status='COMPLETE'),
#   OptimizationRecord(id='18887764', status='COMPLETE'),
#   OptimizationRecord(id='18887765', status='COMPLETE'),
#   OptimizationRecord(id='18887766', status='COMPLETE'),
#   OptimizationRecord(id='18887767', status='COMPLETE'),
#   OptimizationRecord(id='18887768', status='COMPLETE'),
#   OptimizationRecord(id='18887769', status='COMPLETE'),
#   OptimizationRecord(id='18887770', status='COMPLETE'),
#   OptimizationRecord(id='18887771', status='COMPLETE'),
#   OptimizationRecord(id='18887772', status='COMPLETE'),
#   OptimizationRecord(id='18887773', status='COMPLETE'),
#   OptimizationRecord(id='18887774', status='COMPLETE'),
#   OptimizationRecord(id='18887775', status='COMPLETE'),
#   OptimizationRecord(id='18887776', status='COMPLETE'),
#   OptimizationRecord(id='18887777', status='COMPLETE'),
#   OptimizationRecord(id='18887778', status='COMPLETE'),
#   OptimizationRecord(id='18887779', status='COMPLETE'),
#   OptimizationRecord(id='18887780', status='COMPLETE'),
#   OptimizationRecord(id='18887781', status='COMPLETE'),
#   OptimizationRecord(id='18887782', status='COMPLETE'),
#   OptimizationRecord(id='18887783', status='COMPLETE'),
#   OptimizationRecord(id='18887784', status='COMPLETE'),
#   OptimizationRecord(id='18887785', status='COMPLETE'),
#   OptimizationRecord(id='18887786', status='COMPLETE'),
#   OptimizationRecord(id='18887787', status='COMPLETE'),
#   OptimizationRecord(id='18887788', status='COMPLETE'),
#   OptimizationRecord(id='18887789', status='COMPLETE'),
#   OptimizationRecord(id='18887790', status='COMPLETE'),
#   OptimizationRecord(id='18887791', status='COMPLETE'),
#   OptimizationRecord(id='18887792', status='COMPLETE'),
#   OptimizationRecord(id='18887793', status='COMPLETE'),
#   OptimizationRecord(id='18887794', status='COMPLETE'),
#   OptimizationRecord(id='18887795', status='COMPLETE'),
#   OptimizationRecord(id='18887796', status='COMPLETE'),
#   OptimizationRecord(id='18887797', status='COMPLETE'),
#   OptimizationRecord(id='18887798', status='COMPLETE'),
#   OptimizationRecord(id='18887799', status='COMPLETE'),
#   OptimizationRecord(id='18887800', status='COMPLETE'),
#   OptimizationRecord(id='18887801', status='COMPLETE'),
#   OptimizationRecord(id='18887802', status='COMPLETE'),
#   OptimizationRecord(id='18937010', status='COMPLETE'),
#   OptimizationRecord(id='18937011', status='COMPLETE'),
#   OptimizationRecord(id='18937012', status='COMPLETE'),
#   OptimizationRecord(id='18937013', status='COMPLETE'),
#   OptimizationRecord(id='18937014', status='COMPLETE'),
#   OptimizationRecord(id='18937015', status='COMPLETE'),
#   OptimizationRecord(id='18937016', status='COMPLETE'),
#   OptimizationRecord(id='18937017', status='COMPLETE'),
#   OptimizationRecord(id='18937018', status='COMPLETE'),
#   OptimizationRecord(id='18937019', status='COMPLETE'),
#   OptimizationRecord(id='18937020', status='COMPLETE'),
#   OptimizationRecord(id='18937021', status='COMPLETE'),
#   OptimizationRecord(id='18937022', status='COMPLETE'),
#   OptimizationRecord(id='18937023', status='COMPLETE'),
#   OptimizationRecord(id='18937024', status='COMPLETE'),
#   OptimizationRecord(id='18937025', status='COMPLETE'),
#   OptimizationRecord(id='18937026', status='COMPLETE'),
#   OptimizationRecord(id='18937027', status='COMPLETE'),
#   OptimizationRecord(id='18937028', status='COMPLETE'),
#   OptimizationRecord(id='18937029', status='COMPLETE'),
#   OptimizationRecord(id='18937030', status='COMPLETE'),
#   OptimizationRecord(id='18937031', status='COMPLETE'),
#   OptimizationRecord(id='18965628', status='COMPLETE'),
#   OptimizationRecord(id='18965629', status='COMPLETE'),
#   OptimizationRecord(id='18965630', status='COMPLETE'),
#   OptimizationRecord(id='18965631', status='COMPLETE'),
#   OptimizationRecord(id='18965632', status='COMPLETE'),
#   OptimizationRecord(id='18965633', status='COMPLETE'),
#   OptimizationRecord(id='18965634', status='COMPLETE'),
#   OptimizationRecord(id='18965635', status='COMPLETE'),
#   OptimizationRecord(id='18965636', status='COMPLETE'),
#   OptimizationRecord(id='18965637', status='COMPLETE'),
#   OptimizationRecord(id='18965638', status='COMPLETE'),
#   OptimizationRecord(id='18965639', status='COMPLETE'),
#   OptimizationRecord(id='18965640', status='COMPLETE'),
#   OptimizationRecord(id='18965641', status='COMPLETE'),
#   OptimizationRecord(id='18965642', status='COMPLETE'),
#   OptimizationRecord(id='18965643', status='COMPLETE'),
#   OptimizationRecord(id='18965644', status='COMPLETE'),
#   OptimizationRecord(id='18965645', status='COMPLETE'),
#   OptimizationRecord(id='18965646', status='COMPLETE'),
#   OptimizationRecord(id='18965647', status='COMPLETE'),
#   OptimizationRecord(id='18965648', status='COMPLETE'),
#   OptimizationRecord(id='18965649', status='COMPLETE'),
#   OptimizationRecord(id='18965650', status='COMPLETE'),
#   OptimizationRecord(id='18965651', status='COMPLETE'),
#   OptimizationRecord(id='18982580', status='COMPLETE'),
#   OptimizationRecord(id='18982581', status='COMPLETE'),
#   OptimizationRecord(id='18982582', status='COMPLETE'),
#   OptimizationRecord(id='18982583', status='COMPLETE'),
#   OptimizationRecord(id='18982584', status='COMPLETE'),
#   OptimizationRecord(id='18982585', status='COMPLETE'),
#   OptimizationRecord(id='18982586', status='COMPLETE'),
#   OptimizationRecord(id='18982587', status='COMPLETE'),
#   OptimizationRecord(id='18982588', status='COMPLETE'),
#   OptimizationRecord(id='18982589', status='COMPLETE'),
#   OptimizationRecord(id='18982590', status='COMPLETE'),
#   OptimizationRecord(id='18982591', status='COMPLETE'),
#   OptimizationRecord(id='18982592', status='COMPLETE'),
#   OptimizationRecord(id='18982593', status='COMPLETE'),
#   OptimizationRecord(id='18982594', status='COMPLETE'),
#   OptimizationRecord(id='18982595', status='COMPLETE'),
#   OptimizationRecord(id='18982596', status='COMPLETE'),
#   OptimizationRecord(id='18982597', status='COMPLETE'),
#   OptimizationRecord(id='18998836', status='COMPLETE'),
#   OptimizationRecord(id='18998837', status='COMPLETE'),
#   OptimizationRecord(id='18998838', status='COMPLETE'),
#   OptimizationRecord(id='18998839', status='COMPLETE'),
#   OptimizationRecord(id='18998840', status='COMPLETE'),
#   OptimizationRecord(id='18998841', status='COMPLETE'),
#   OptimizationRecord(id='18998842', status='COMPLETE'),
#   OptimizationRecord(id='18998843', status='COMPLETE'),
#   OptimizationRecord(id='18998844', status='COMPLETE'),
#   OptimizationRecord(id='18998845', status='COMPLETE'),
#   OptimizationRecord(id='19013301', status='COMPLETE'),
#   OptimizationRecord(id='19013302', status='COMPLETE'),
#   OptimizationRecord(id='19013303', status='COMPLETE'),
#   OptimizationRecord(id='19013304', status='COMPLETE'),
#   OptimizationRecord(id='19013305', status='COMPLETE'),
#   OptimizationRecord(id='19013306', status='COMPLETE'),
#   OptimizationRecord(id='19013307', status='COMPLETE'),
#   OptimizationRecord(id='19013308', status='COMPLETE'),
#   OptimizationRecord(id='19027391', status='COMPLETE'),
#   OptimizationRecord(id='19027392', status='COMPLETE'),
#   OptimizationRecord(id='19027393', status='COMPLETE'),
#   OptimizationRecord(id='19027394', status='COMPLETE'),
#   OptimizationRecord(id='19027395', status='COMPLETE'),
#   OptimizationRecord(id='19027396', status='COMPLETE'),
#   OptimizationRecord(id='19040614', status='COMPLETE'),
#   OptimizationRecord(id='19040615', status='COMPLETE'),
#   OptimizationRecord(id='19040616', status='COMPLETE'),
#   OptimizationRecord(id='19040617', status='COMPLETE'),
#   OptimizationRecord(id='19058923', status='COMPLETE'),
#   OptimizationRecord(id='19058924', status='COMPLETE'),
#   OptimizationRecord(id='19072648', status='COMPLETE'),
#   OptimizationRecord(id='19072649', status='COMPLETE')],
#  '18886222': [OptimizationRecord(id='18888477', status='COMPLETE'),
#   OptimizationRecord(id='18888478', status='COMPLETE'),
#   OptimizationRecord(id='18888479', status='COMPLETE'),
#   OptimizationRecord(id='18888480', status='COMPLETE'),
#   OptimizationRecord(id='18888502', status='COMPLETE'),
#   OptimizationRecord(id='18888506', status='COMPLETE'),
#   OptimizationRecord(id='18888507', status='COMPLETE'),
#   OptimizationRecord(id='18888508', status='COMPLETE'),
#   OptimizationRecord(id='18888509', status='COMPLETE'),
#   OptimizationRecord(id='18888510', status='COMPLETE'),
#   OptimizationRecord(id='18888511', status='COMPLETE'),
#   OptimizationRecord(id='18888512', status='COMPLETE'),
#   OptimizationRecord(id='18888513', status='COMPLETE'),
#   OptimizationRecord(id='18888514', status='COMPLETE'),
#   OptimizationRecord(id='18888515', status='COMPLETE'),
#   OptimizationRecord(id='18888516', status='COMPLETE'),
#   OptimizationRecord(id='18888517', status='COMPLETE'),
#   OptimizationRecord(id='18888518', status='COMPLETE'),
#   OptimizationRecord(id='18888519', status='COMPLETE'),
#   OptimizationRecord(id='18888520', status='COMPLETE'),
#   OptimizationRecord(id='18888521', status='COMPLETE'),
#   OptimizationRecord(id='18888522', status='COMPLETE'),
#   OptimizationRecord(id='18888523', status='COMPLETE'),
#   OptimizationRecord(id='18888524', status='COMPLETE'),
#   OptimizationRecord(id='18888525', status='COMPLETE'),
#   OptimizationRecord(id='18888526', status='COMPLETE'),
#   OptimizationRecord(id='18888527', status='COMPLETE'),
#   OptimizationRecord(id='18888528', status='COMPLETE'),
#   OptimizationRecord(id='18888529', status='COMPLETE'),
#   OptimizationRecord(id='18888530', status='COMPLETE'),
#   OptimizationRecord(id='18888531', status='COMPLETE'),
#   OptimizationRecord(id='18888532', status='ERROR')],
#  '18886225': [OptimizationRecord(id='18888979', status='COMPLETE'),
#   OptimizationRecord(id='18888980', status='COMPLETE'),
#   OptimizationRecord(id='18888981', status='COMPLETE'),
#   OptimizationRecord(id='18888982', status='COMPLETE'),
#   OptimizationRecord(id='18888983', status='COMPLETE'),
#   OptimizationRecord(id='18888984', status='COMPLETE'),
#   OptimizationRecord(id='18888985', status='COMPLETE'),
#   OptimizationRecord(id='18888986', status='COMPLETE'),
#   OptimizationRecord(id='18888987', status='COMPLETE'),
#   OptimizationRecord(id='18888988', status='COMPLETE'),
#   OptimizationRecord(id='18888989', status='COMPLETE')],
#  '18886228': [OptimizationRecord(id='18889082', status='COMPLETE'),
#   OptimizationRecord(id='18889083', status='COMPLETE'),
#   OptimizationRecord(id='18889084', status='COMPLETE'),
#   OptimizationRecord(id='18889085', status='COMPLETE'),
#   OptimizationRecord(id='18889086', status='COMPLETE'),
#   OptimizationRecord(id='18889087', status='COMPLETE'),
#   OptimizationRecord(id='18889088', status='COMPLETE'),
#   OptimizationRecord(id='18889089', status='COMPLETE'),
#   OptimizationRecord(id='18889090', status='COMPLETE'),
#   OptimizationRecord(id='18889091', status='COMPLETE'),
#   OptimizationRecord(id='18889092', status='COMPLETE'),
#   OptimizationRecord(id='18889093', status='COMPLETE'),
#   OptimizationRecord(id='18889094', status='COMPLETE'),
#   OptimizationRecord(id='18889095', status='COMPLETE'),
#   OptimizationRecord(id='18889096', status='COMPLETE'),
#   OptimizationRecord(id='18889097', status='COMPLETE'),
#   OptimizationRecord(id='18889098', status='COMPLETE'),
#   OptimizationRecord(id='18889099', status='COMPLETE'),
#   OptimizationRecord(id='18889100', status='COMPLETE'),
#   OptimizationRecord(id='18889101', status='COMPLETE'),
#   OptimizationRecord(id='18889102', status='COMPLETE'),
#   OptimizationRecord(id='18889103', status='COMPLETE'),
#   OptimizationRecord(id='18889104', status='COMPLETE'),
#   OptimizationRecord(id='18889105', status='COMPLETE'),
#   OptimizationRecord(id='18889106', status='COMPLETE'),
#   OptimizationRecord(id='18889107', status='COMPLETE'),
#   OptimizationRecord(id='18889108', status='COMPLETE'),
#   OptimizationRecord(id='18889109', status='COMPLETE'),
#   OptimizationRecord(id='18889110', status='COMPLETE'),
#   OptimizationRecord(id='18889111', status='COMPLETE'),
#   OptimizationRecord(id='18889112', status='COMPLETE'),
#   OptimizationRecord(id='18889113', status='COMPLETE'),
#   OptimizationRecord(id='18889114', status='COMPLETE')],
#  '18886319': [OptimizationRecord(id='19018428', status='COMPLETE'),
#   OptimizationRecord(id='19018429', status='COMPLETE'),
#   OptimizationRecord(id='19018430', status='COMPLETE'),
#   OptimizationRecord(id='19018431', status='COMPLETE'),
#   OptimizationRecord(id='19018432', status='COMPLETE'),
#   OptimizationRecord(id='19018433', status='COMPLETE'),
#   OptimizationRecord(id='19018434', status='COMPLETE'),
#   OptimizationRecord(id='19029482', status='COMPLETE'),
#   OptimizationRecord(id='19029483', status='COMPLETE'),
#   OptimizationRecord(id='19029484', status='COMPLETE'),
#   OptimizationRecord(id='19029493', status='COMPLETE'),
#   OptimizationRecord(id='19029494', status='COMPLETE'),
#   OptimizationRecord(id='19029495', status='COMPLETE'),
#   OptimizationRecord(id='19029496', status='COMPLETE'),
#   OptimizationRecord(id='19029497', status='COMPLETE'),
#   OptimizationRecord(id='19044800', status='COMPLETE'),
#   OptimizationRecord(id='19044801', status='COMPLETE'),
#   OptimizationRecord(id='19044802', status='COMPLETE'),
#   OptimizationRecord(id='19044803', status='COMPLETE'),
#   OptimizationRecord(id='19044804', status='COMPLETE'),
#   OptimizationRecord(id='19044805', status='COMPLETE'),
#   OptimizationRecord(id='19044806', status='COMPLETE'),
#   OptimizationRecord(id='19044807', status='COMPLETE'),
#   OptimizationRecord(id='19044808', status='COMPLETE'),
#   OptimizationRecord(id='19044809', status='COMPLETE'),
#   OptimizationRecord(id='19044810', status='COMPLETE'),
#   OptimizationRecord(id='19044811', status='COMPLETE'),
#   OptimizationRecord(id='19063096', status='COMPLETE'),
#   OptimizationRecord(id='19063097', status='COMPLETE'),
#   OptimizationRecord(id='19063098', status='COMPLETE'),
#   OptimizationRecord(id='19063099', status='COMPLETE'),
#   OptimizationRecord(id='19063100', status='COMPLETE'),
#   OptimizationRecord(id='19063101', status='COMPLETE'),
#   OptimizationRecord(id='19063102', status='COMPLETE'),
#   OptimizationRecord(id='19063103', status='COMPLETE'),
#   OptimizationRecord(id='19063104', status='COMPLETE'),
#   OptimizationRecord(id='19063105', status='COMPLETE'),
#   OptimizationRecord(id='19063106', status='COMPLETE'),
#   OptimizationRecord(id='19063107', status='COMPLETE')],
#  '18886340': [OptimizationRecord(id='19028799', status='COMPLETE'),
#   OptimizationRecord(id='19028800', status='COMPLETE'),
#   OptimizationRecord(id='19028801', status='COMPLETE'),
#   OptimizationRecord(id='19028802', status='COMPLETE'),
#   OptimizationRecord(id='19028803', status='COMPLETE'),
#   OptimizationRecord(id='19028804', status='COMPLETE'),
#   OptimizationRecord(id='19028805', status='COMPLETE'),
#   OptimizationRecord(id='19028806', status='COMPLETE'),
#   OptimizationRecord(id='19028807', status='COMPLETE'),
#   OptimizationRecord(id='19028808', status='COMPLETE'),
#   OptimizationRecord(id='19028809', status='COMPLETE'),
#   OptimizationRecord(id='19028810', status='COMPLETE'),
#   OptimizationRecord(id='19040904', status='COMPLETE'),
#   OptimizationRecord(id='19040905', status='COMPLETE'),
#   OptimizationRecord(id='19040906', status='COMPLETE'),
#   OptimizationRecord(id='19040907', status='COMPLETE'),
#   OptimizationRecord(id='19060959', status='COMPLETE'),
#   OptimizationRecord(id='19060968', status='COMPLETE'),
#   OptimizationRecord(id='19060969', status='COMPLETE'),
#   OptimizationRecord(id='19060970', status='COMPLETE'),
#   OptimizationRecord(id='19060971', status='COMPLETE'),
#   OptimizationRecord(id='19060972', status='COMPLETE'),
#   OptimizationRecord(id='19060973', status='COMPLETE'),
#   OptimizationRecord(id='19060974', status='COMPLETE'),
#   OptimizationRecord(id='19073108', status='COMPLETE'),
#   OptimizationRecord(id='19073109', status='COMPLETE'),
#   OptimizationRecord(id='19073110', status='COMPLETE'),
#   OptimizationRecord(id='19073111', status='COMPLETE'),
#   OptimizationRecord(id='19073112', status='COMPLETE'),
#   OptimizationRecord(id='19073113', status='COMPLETE'),
#   OptimizationRecord(id='19073114', status='COMPLETE'),
#   OptimizationRecord(id='19073115', status='COMPLETE'),
#   OptimizationRecord(id='19435064', status='COMPLETE'),
#   OptimizationRecord(id='19435065', status='COMPLETE'),
#   OptimizationRecord(id='19435066', status='COMPLETE'),
#   OptimizationRecord(id='19435067', status='COMPLETE'),
#   OptimizationRecord(id='19435068', status='COMPLETE'),
#   OptimizationRecord(id='19435069', status='COMPLETE'),
#   OptimizationRecord(id='19435070', status='COMPLETE'),
#   OptimizationRecord(id='19435071', status='COMPLETE'),
#   OptimizationRecord(id='19496823', status='COMPLETE'),
#   OptimizationRecord(id='19496824', status='COMPLETE'),
#   OptimizationRecord(id='19496825', status='COMPLETE'),
#   OptimizationRecord(id='19496826', status='COMPLETE'),
#   OptimizationRecord(id='19496827', status='COMPLETE'),
#   OptimizationRecord(id='19496828', status='COMPLETE'),
#   OptimizationRecord(id='19498273', status='COMPLETE'),
#   OptimizationRecord(id='19498274', status='COMPLETE'),
#   OptimizationRecord(id='19498275', status='COMPLETE'),
#   OptimizationRecord(id='19498276', status='INCOMPLETE'),
#   OptimizationRecord(id='19498277', status='COMPLETE'),
#   OptimizationRecord(id='19498278', status='COMPLETE')],
#  '18886354': [OptimizationRecord(id='19039752', status='COMPLETE'),
#   OptimizationRecord(id='19039753', status='COMPLETE'),
#   OptimizationRecord(id='19039754', status='COMPLETE'),
#   OptimizationRecord(id='19039755', status='COMPLETE'),
#   OptimizationRecord(id='19039756', status='COMPLETE'),
#   OptimizationRecord(id='19039757', status='COMPLETE'),
#   OptimizationRecord(id='19039758', status='COMPLETE'),
#   OptimizationRecord(id='19039759', status='COMPLETE'),
#   OptimizationRecord(id='19039760', status='COMPLETE'),
#   OptimizationRecord(id='19039761', status='COMPLETE'),
#   OptimizationRecord(id='19039762', status='COMPLETE'),
#   OptimizationRecord(id='19039763', status='COMPLETE'),
#   OptimizationRecord(id='19039764', status='COMPLETE'),
#   OptimizationRecord(id='19039765', status='COMPLETE'),
#   OptimizationRecord(id='19039766', status='COMPLETE'),
#   OptimizationRecord(id='19039767', status='COMPLETE'),
#   OptimizationRecord(id='19039768', status='COMPLETE'),
#   OptimizationRecord(id='19039769', status='COMPLETE'),
#   OptimizationRecord(id='19039770', status='COMPLETE'),
#   OptimizationRecord(id='19039771', status='COMPLETE'),
#   OptimizationRecord(id='19039772', status='COMPLETE'),
#   OptimizationRecord(id='19039773', status='COMPLETE'),
#   OptimizationRecord(id='19039774', status='COMPLETE'),
#   OptimizationRecord(id='19039775', status='COMPLETE'),
#   OptimizationRecord(id='19039776', status='COMPLETE'),
#   OptimizationRecord(id='19039777', status='COMPLETE'),
#   OptimizationRecord(id='19039778', status='COMPLETE'),
#   OptimizationRecord(id='19039779', status='COMPLETE'),
#   OptimizationRecord(id='19039780', status='COMPLETE'),
#   OptimizationRecord(id='19039781', status='COMPLETE'),
#   OptimizationRecord(id='19039782', status='COMPLETE'),
#   OptimizationRecord(id='19039783', status='COMPLETE'),
#   OptimizationRecord(id='19039784', status='COMPLETE'),
#   OptimizationRecord(id='19039785', status='COMPLETE'),
#   OptimizationRecord(id='19039786', status='COMPLETE'),
#   OptimizationRecord(id='19039787', status='COMPLETE'),
#   OptimizationRecord(id='19039788', status='COMPLETE'),
#   OptimizationRecord(id='19039789', status='COMPLETE'),
#   OptimizationRecord(id='19039790', status='COMPLETE'),
#   OptimizationRecord(id='19039791', status='COMPLETE'),
#   OptimizationRecord(id='19039792', status='COMPLETE'),
#   OptimizationRecord(id='19039793', status='COMPLETE'),
#   OptimizationRecord(id='19039794', status='COMPLETE'),
#   OptimizationRecord(id='19039795', status='COMPLETE'),
#   OptimizationRecord(id='19039796', status='COMPLETE'),
#   OptimizationRecord(id='19039797', status='COMPLETE'),
#   OptimizationRecord(id='19039798', status='COMPLETE'),
#   OptimizationRecord(id='19039799', status='COMPLETE'),
#   OptimizationRecord(id='19039800', status='COMPLETE'),
#   OptimizationRecord(id='19039801', status='COMPLETE'),
#   OptimizationRecord(id='19039802', status='COMPLETE'),
#   OptimizationRecord(id='19039803', status='COMPLETE'),
#   OptimizationRecord(id='19039804', status='COMPLETE'),
#   OptimizationRecord(id='19039805', status='COMPLETE'),
#   OptimizationRecord(id='19039806', status='COMPLETE'),
#   OptimizationRecord(id='19039807', status='COMPLETE'),
#   OptimizationRecord(id='19039808', status='COMPLETE'),
#   OptimizationRecord(id='19039809', status='COMPLETE'),
#   OptimizationRecord(id='19039810', status='COMPLETE'),
#   OptimizationRecord(id='19039811', status='COMPLETE'),
#   OptimizationRecord(id='19039812', status='COMPLETE'),
#   OptimizationRecord(id='19039813', status='COMPLETE'),
#   OptimizationRecord(id='19039814', status='COMPLETE'),
#   OptimizationRecord(id='19039815', status='COMPLETE'),
#   OptimizationRecord(id='19039816', status='COMPLETE'),
#   OptimizationRecord(id='19039817', status='COMPLETE'),
#   OptimizationRecord(id='19039818', status='COMPLETE'),
#   OptimizationRecord(id='19039819', status='COMPLETE'),
#   OptimizationRecord(id='19039820', status='COMPLETE'),
#   OptimizationRecord(id='19039821', status='COMPLETE'),
#   OptimizationRecord(id='19039822', status='COMPLETE'),
#   OptimizationRecord(id='19039823', status='COMPLETE'),
#   OptimizationRecord(id='19039824', status='COMPLETE'),
#   OptimizationRecord(id='19039825', status='COMPLETE'),
#   OptimizationRecord(id='19039826', status='COMPLETE'),
#   OptimizationRecord(id='19039827', status='COMPLETE'),
#   OptimizationRecord(id='19039828', status='COMPLETE'),
#   OptimizationRecord(id='19039829', status='COMPLETE'),
#   OptimizationRecord(id='19039830', status='COMPLETE'),
#   OptimizationRecord(id='19039831', status='COMPLETE'),
#   OptimizationRecord(id='19039832', status='COMPLETE'),
#   OptimizationRecord(id='19039833', status='COMPLETE'),
#   OptimizationRecord(id='19039834', status='COMPLETE'),
#   OptimizationRecord(id='19039835', status='COMPLETE'),
#   OptimizationRecord(id='19039836', status='COMPLETE'),
#   OptimizationRecord(id='19039837', status='COMPLETE'),
#   OptimizationRecord(id='19039838', status='COMPLETE'),
#   OptimizationRecord(id='19039839', status='COMPLETE'),
#   OptimizationRecord(id='19039840', status='COMPLETE'),
#   OptimizationRecord(id='19039841', status='COMPLETE'),
#   OptimizationRecord(id='19039842', status='COMPLETE'),
#   OptimizationRecord(id='19039843', status='COMPLETE'),
#   OptimizationRecord(id='19039844', status='COMPLETE'),
#   OptimizationRecord(id='19039845', status='COMPLETE'),
#   OptimizationRecord(id='19039846', status='COMPLETE'),
#   OptimizationRecord(id='19056846', status='COMPLETE'),
#   OptimizationRecord(id='19056847', status='COMPLETE'),
#   OptimizationRecord(id='19056848', status='COMPLETE'),
#   OptimizationRecord(id='19056849', status='COMPLETE'),
#   OptimizationRecord(id='19056850', status='COMPLETE'),
#   OptimizationRecord(id='19056851', status='COMPLETE'),
#   OptimizationRecord(id='19056852', status='COMPLETE'),
#   OptimizationRecord(id='19056853', status='COMPLETE'),
#   OptimizationRecord(id='19056854', status='COMPLETE'),
#   OptimizationRecord(id='19056855', status='COMPLETE'),
#   OptimizationRecord(id='19071971', status='COMPLETE'),
#   OptimizationRecord(id='19071972', status='COMPLETE'),
#   OptimizationRecord(id='19071973', status='COMPLETE'),
#   OptimizationRecord(id='19071974', status='COMPLETE'),
#   OptimizationRecord(id='19071975', status='COMPLETE'),
#   OptimizationRecord(id='19071976', status='COMPLETE'),
#   OptimizationRecord(id='19071977', status='COMPLETE'),
#   OptimizationRecord(id='19071978', status='COMPLETE'),
#   OptimizationRecord(id='19071979', status='COMPLETE'),
#   OptimizationRecord(id='19071980', status='COMPLETE'),
#   OptimizationRecord(id='19071981', status='COMPLETE'),
#   OptimizationRecord(id='19071982', status='COMPLETE'),
#   OptimizationRecord(id='19256344', status='COMPLETE'),
#   OptimizationRecord(id='19256345', status='COMPLETE'),
#   OptimizationRecord(id='19256346', status='COMPLETE'),
#   OptimizationRecord(id='19256347', status='COMPLETE'),
#   OptimizationRecord(id='19256348', status='COMPLETE'),
#   OptimizationRecord(id='19256349', status='COMPLETE'),
#   OptimizationRecord(id='19256350', status='COMPLETE'),
#   OptimizationRecord(id='19256351', status='COMPLETE'),
#   OptimizationRecord(id='19256352', status='COMPLETE'),
#   OptimizationRecord(id='19256353', status='COMPLETE'),
#   OptimizationRecord(id='19256354', status='COMPLETE'),
#   OptimizationRecord(id='19256355', status='COMPLETE'),
#   OptimizationRecord(id='19269409', status='COMPLETE'),
#   OptimizationRecord(id='19269410', status='COMPLETE'),
#   OptimizationRecord(id='19269411', status='COMPLETE'),
#   OptimizationRecord(id='19269412', status='COMPLETE'),
#   OptimizationRecord(id='19269413', status='COMPLETE'),
#   OptimizationRecord(id='19269414', status='COMPLETE'),
#   OptimizationRecord(id='19269415', status='COMPLETE'),
#   OptimizationRecord(id='19269416', status='COMPLETE'),
#   OptimizationRecord(id='19285307', status='COMPLETE'),
#   OptimizationRecord(id='19285308', status='COMPLETE'),
#   OptimizationRecord(id='19285309', status='COMPLETE'),
#   OptimizationRecord(id='19285310', status='COMPLETE'),
#   OptimizationRecord(id='19285311', status='COMPLETE'),
#   OptimizationRecord(id='19285312', status='COMPLETE'),
#   OptimizationRecord(id='19285313', status='COMPLETE'),
#   OptimizationRecord(id='19285314', status='COMPLETE'),
#   OptimizationRecord(id='19285315', status='COMPLETE'),
#   OptimizationRecord(id='19285316', status='COMPLETE'),
#   OptimizationRecord(id='19285317', status='COMPLETE'),
#   OptimizationRecord(id='19285318', status='COMPLETE'),
#   OptimizationRecord(id='19314977', status='COMPLETE'),
#   OptimizationRecord(id='19314978', status='COMPLETE'),
#   OptimizationRecord(id='19314979', status='COMPLETE'),
#   OptimizationRecord(id='19314980', status='COMPLETE'),
#   OptimizationRecord(id='19314981', status='COMPLETE'),
#   OptimizationRecord(id='19314982', status='COMPLETE'),
#   OptimizationRecord(id='19314983', status='COMPLETE'),
#   OptimizationRecord(id='19314984', status='COMPLETE'),
#   OptimizationRecord(id='19314985', status='COMPLETE'),
#   OptimizationRecord(id='19314986', status='COMPLETE'),
#   OptimizationRecord(id='19342693', status='COMPLETE'),
#   OptimizationRecord(id='19342694', status='COMPLETE'),
#   OptimizationRecord(id='19342695', status='COMPLETE'),
#   OptimizationRecord(id='19342696', status='COMPLETE'),
#   OptimizationRecord(id='19342697', status='COMPLETE'),
#   OptimizationRecord(id='19342698', status='COMPLETE'),
#   OptimizationRecord(id='19342699', status='COMPLETE'),
#   OptimizationRecord(id='19342700', status='COMPLETE'),
#   OptimizationRecord(id='19342701', status='COMPLETE'),
#   OptimizationRecord(id='19342702', status='COMPLETE'),
#   OptimizationRecord(id='19342703', status='COMPLETE'),
#   OptimizationRecord(id='19342704', status='COMPLETE'),
#   OptimizationRecord(id='19342705', status='COMPLETE'),
#   OptimizationRecord(id='19342706', status='COMPLETE'),
#   OptimizationRecord(id='19360505', status='COMPLETE'),
#   OptimizationRecord(id='19360506', status='COMPLETE'),
#   OptimizationRecord(id='19360507', status='COMPLETE'),
#   OptimizationRecord(id='19360508', status='COMPLETE'),
#   OptimizationRecord(id='19360509', status='COMPLETE'),
#   OptimizationRecord(id='19360510', status='COMPLETE'),
#   OptimizationRecord(id='19375418', status='COMPLETE'),
#   OptimizationRecord(id='19375419', status='COMPLETE'),
#   OptimizationRecord(id='19375420', status='COMPLETE'),
#   OptimizationRecord(id='19375421', status='COMPLETE'),
#   OptimizationRecord(id='19375422', status='COMPLETE'),
#   OptimizationRecord(id='19375423', status='COMPLETE'),
#   OptimizationRecord(id='19387214', status='COMPLETE'),
#   OptimizationRecord(id='19387215', status='COMPLETE'),
#   OptimizationRecord(id='19387216', status='COMPLETE'),
#   OptimizationRecord(id='19387217', status='COMPLETE'),
#   OptimizationRecord(id='19430102', status='COMPLETE'),
#   OptimizationRecord(id='19430103', status='COMPLETE'),
#   OptimizationRecord(id='19430104', status='COMPLETE'),
#   OptimizationRecord(id='19430105', status='COMPLETE')],
#  '18886355': [OptimizationRecord(id='19040042', status='COMPLETE'),
#   OptimizationRecord(id='19040043', status='COMPLETE'),
#   OptimizationRecord(id='19040044', status='COMPLETE'),
#   OptimizationRecord(id='19040045', status='COMPLETE'),
#   OptimizationRecord(id='19040046', status='COMPLETE'),
#   OptimizationRecord(id='19040047', status='COMPLETE'),
#   OptimizationRecord(id='19040048', status='COMPLETE'),
#   OptimizationRecord(id='19040049', status='COMPLETE'),
#   OptimizationRecord(id='19040050', status='COMPLETE'),
#   OptimizationRecord(id='19040051', status='COMPLETE'),
#   OptimizationRecord(id='19040052', status='COMPLETE'),
#   OptimizationRecord(id='19040053', status='COMPLETE'),
#   OptimizationRecord(id='19040054', status='COMPLETE'),
#   OptimizationRecord(id='19040055', status='COMPLETE'),
#   OptimizationRecord(id='19040056', status='COMPLETE'),
#   OptimizationRecord(id='19040057', status='COMPLETE'),
#   OptimizationRecord(id='19040058', status='COMPLETE'),
#   OptimizationRecord(id='19040059', status='COMPLETE'),
#   OptimizationRecord(id='19040060', status='COMPLETE'),
#   OptimizationRecord(id='19040061', status='COMPLETE'),
#   OptimizationRecord(id='19040062', status='COMPLETE'),
#   OptimizationRecord(id='19040063', status='COMPLETE'),
#   OptimizationRecord(id='19040064', status='COMPLETE'),
#   OptimizationRecord(id='19040065', status='COMPLETE'),
#   OptimizationRecord(id='19040066', status='COMPLETE'),
#   OptimizationRecord(id='19040067', status='COMPLETE'),
#   OptimizationRecord(id='19040068', status='COMPLETE'),
#   OptimizationRecord(id='19040069', status='COMPLETE'),
#   OptimizationRecord(id='19040070', status='COMPLETE'),
#   OptimizationRecord(id='19040071', status='COMPLETE'),
#   OptimizationRecord(id='19040072', status='COMPLETE'),
#   OptimizationRecord(id='19040073', status='COMPLETE'),
#   OptimizationRecord(id='19040074', status='COMPLETE'),
#   OptimizationRecord(id='19040075', status='COMPLETE'),
#   OptimizationRecord(id='19040076', status='COMPLETE'),
#   OptimizationRecord(id='19040077', status='COMPLETE'),
#   OptimizationRecord(id='19040078', status='COMPLETE'),
#   OptimizationRecord(id='19040079', status='COMPLETE'),
#   OptimizationRecord(id='19040080', status='COMPLETE'),
#   OptimizationRecord(id='19040081', status='COMPLETE'),
#   OptimizationRecord(id='19040082', status='COMPLETE'),
#   OptimizationRecord(id='19040083', status='COMPLETE'),
#   OptimizationRecord(id='19040084', status='COMPLETE'),
#   OptimizationRecord(id='19040085', status='COMPLETE'),
#   OptimizationRecord(id='19040086', status='COMPLETE'),
#   OptimizationRecord(id='19040087', status='COMPLETE'),
#   OptimizationRecord(id='19040088', status='COMPLETE'),
#   OptimizationRecord(id='19040089', status='COMPLETE'),
#   OptimizationRecord(id='19040090', status='COMPLETE'),
#   OptimizationRecord(id='19040091', status='COMPLETE'),
#   OptimizationRecord(id='19040092', status='COMPLETE'),
#   OptimizationRecord(id='19040093', status='COMPLETE'),
#   OptimizationRecord(id='19040094', status='COMPLETE'),
#   OptimizationRecord(id='19040095', status='COMPLETE'),
#   OptimizationRecord(id='19040096', status='COMPLETE'),
#   OptimizationRecord(id='19040097', status='COMPLETE'),
#   OptimizationRecord(id='19040098', status='COMPLETE'),
#   OptimizationRecord(id='19040099', status='COMPLETE'),
#   OptimizationRecord(id='19040100', status='COMPLETE'),
#   OptimizationRecord(id='19040101', status='COMPLETE'),
#   OptimizationRecord(id='19040102', status='COMPLETE'),
#   OptimizationRecord(id='19040103', status='COMPLETE'),
#   OptimizationRecord(id='19040104', status='COMPLETE'),
#   OptimizationRecord(id='19040105', status='COMPLETE'),
#   OptimizationRecord(id='19040106', status='COMPLETE'),
#   OptimizationRecord(id='19040107', status='COMPLETE'),
#   OptimizationRecord(id='19040108', status='COMPLETE'),
#   OptimizationRecord(id='19040109', status='COMPLETE'),
#   OptimizationRecord(id='19040110', status='COMPLETE'),
#   OptimizationRecord(id='19040111', status='COMPLETE'),
#   OptimizationRecord(id='19040112', status='COMPLETE'),
#   OptimizationRecord(id='19040113', status='COMPLETE'),
#   OptimizationRecord(id='19040114', status='COMPLETE'),
#   OptimizationRecord(id='19040115', status='COMPLETE'),
#   OptimizationRecord(id='19040116', status='COMPLETE'),
#   OptimizationRecord(id='19040117', status='COMPLETE'),
#   OptimizationRecord(id='19040118', status='COMPLETE'),
#   OptimizationRecord(id='19040119', status='COMPLETE'),
#   OptimizationRecord(id='19040120', status='COMPLETE'),
#   OptimizationRecord(id='19040121', status='COMPLETE'),
#   OptimizationRecord(id='19040122', status='COMPLETE'),
#   OptimizationRecord(id='19040123', status='COMPLETE'),
#   OptimizationRecord(id='19040124', status='COMPLETE'),
#   OptimizationRecord(id='19040125', status='COMPLETE'),
#   OptimizationRecord(id='19040126', status='COMPLETE'),
#   OptimizationRecord(id='19040127', status='COMPLETE'),
#   OptimizationRecord(id='19040128', status='COMPLETE'),
#   OptimizationRecord(id='19040129', status='COMPLETE'),
#   OptimizationRecord(id='19040154', status='COMPLETE'),
#   OptimizationRecord(id='19040159', status='COMPLETE'),
#   OptimizationRecord(id='19040160', status='COMPLETE'),
#   OptimizationRecord(id='19040161', status='COMPLETE'),
#   OptimizationRecord(id='19040162', status='COMPLETE'),
#   OptimizationRecord(id='19040163', status='COMPLETE'),
#   OptimizationRecord(id='19040164', status='COMPLETE'),
#   OptimizationRecord(id='19040165', status='COMPLETE'),
#   OptimizationRecord(id='19040166', status='COMPLETE'),
#   OptimizationRecord(id='19040167', status='COMPLETE'),
#   OptimizationRecord(id='19040168', status='COMPLETE'),
#   OptimizationRecord(id='19040169', status='COMPLETE'),
#   OptimizationRecord(id='19040170', status='COMPLETE'),
#   OptimizationRecord(id='19040171', status='COMPLETE'),
#   OptimizationRecord(id='19040172', status='COMPLETE'),
#   OptimizationRecord(id='19040173', status='COMPLETE'),
#   OptimizationRecord(id='19040174', status='COMPLETE'),
#   OptimizationRecord(id='19040175', status='COMPLETE'),
#   OptimizationRecord(id='19040176', status='COMPLETE'),
#   OptimizationRecord(id='19040177', status='COMPLETE'),
#   OptimizationRecord(id='19040178', status='COMPLETE'),
#   OptimizationRecord(id='19040179', status='COMPLETE'),
#   OptimizationRecord(id='19040180', status='COMPLETE'),
#   OptimizationRecord(id='19040181', status='COMPLETE'),
#   OptimizationRecord(id='19040182', status='COMPLETE'),
#   OptimizationRecord(id='19040183', status='COMPLETE'),
#   OptimizationRecord(id='19040184', status='COMPLETE'),
#   OptimizationRecord(id='19040185', status='COMPLETE'),
#   OptimizationRecord(id='19040186', status='COMPLETE'),
#   OptimizationRecord(id='19040187', status='COMPLETE'),
#   OptimizationRecord(id='19061049', status='COMPLETE'),
#   OptimizationRecord(id='19061050', status='COMPLETE'),
#   OptimizationRecord(id='19061051', status='COMPLETE'),
#   OptimizationRecord(id='19061052', status='COMPLETE'),
#   OptimizationRecord(id='19061053', status='COMPLETE'),
#   OptimizationRecord(id='19061054', status='COMPLETE'),
#   OptimizationRecord(id='19061055', status='COMPLETE'),
#   OptimizationRecord(id='19061056', status='COMPLETE'),
#   OptimizationRecord(id='19061057', status='COMPLETE'),
#   OptimizationRecord(id='19061058', status='COMPLETE'),
#   OptimizationRecord(id='19061059', status='COMPLETE'),
#   OptimizationRecord(id='19061060', status='COMPLETE'),
#   OptimizationRecord(id='19074331', status='COMPLETE'),
#   OptimizationRecord(id='19074332', status='ERROR'),
#   OptimizationRecord(id='19074333', status='COMPLETE'),
#   OptimizationRecord(id='19074334', status='COMPLETE'),
#   OptimizationRecord(id='19074335', status='COMPLETE'),
#   OptimizationRecord(id='19074336', status='COMPLETE'),
#   OptimizationRecord(id='19074337', status='COMPLETE'),
#   OptimizationRecord(id='19074338', status='COMPLETE'),
#   OptimizationRecord(id='19074339', status='COMPLETE'),
#   OptimizationRecord(id='19074340', status='COMPLETE'),
#   OptimizationRecord(id='19074341', status='COMPLETE'),
#   OptimizationRecord(id='19074342', status='COMPLETE'),
#   OptimizationRecord(id='19074343', status='COMPLETE'),
#   OptimizationRecord(id='19074344', status='COMPLETE'),
#   OptimizationRecord(id='19074345', status='COMPLETE'),
#   OptimizationRecord(id='19074346', status='COMPLETE'),
#   OptimizationRecord(id='19074347', status='COMPLETE'),
#   OptimizationRecord(id='19074348', status='COMPLETE')],
#  '18886362': [OptimizationRecord(id='19044362', status='COMPLETE'),
#   OptimizationRecord(id='19044363', status='COMPLETE'),
#   OptimizationRecord(id='19044364', status='COMPLETE'),
#   OptimizationRecord(id='19044365', status='COMPLETE'),
#   OptimizationRecord(id='19044366', status='COMPLETE'),
#   OptimizationRecord(id='19044367', status='COMPLETE'),
#   OptimizationRecord(id='19044368', status='COMPLETE'),
#   OptimizationRecord(id='19062903', status='COMPLETE'),
#   OptimizationRecord(id='19062904', status='COMPLETE'),
#   OptimizationRecord(id='19074474', status='COMPLETE'),
#   OptimizationRecord(id='19074475', status='COMPLETE'),
#   OptimizationRecord(id='19074476', status='COMPLETE'),
#   OptimizationRecord(id='19074477', status='COMPLETE'),
#   OptimizationRecord(id='19435537', status='COMPLETE'),
#   OptimizationRecord(id='19435538', status='COMPLETE'),
#   OptimizationRecord(id='19435539', status='COMPLETE'),
#   OptimizationRecord(id='19435540', status='COMPLETE'),
#   OptimizationRecord(id='19435541', status='COMPLETE'),
#   OptimizationRecord(id='19435542', status='COMPLETE'),
#   OptimizationRecord(id='19442926', status='COMPLETE'),
#   OptimizationRecord(id='19442927', status='COMPLETE'),
#   OptimizationRecord(id='19442928', status='COMPLETE'),
#   OptimizationRecord(id='19442929', status='COMPLETE'),
#   OptimizationRecord(id='19498584', status='COMPLETE'),
#   OptimizationRecord(id='19498585', status='INCOMPLETE'),
#   OptimizationRecord(id='19498586', status='COMPLETE'),
#   OptimizationRecord(id='19498587', status='COMPLETE')],
#  '18886376': [OptimizationRecord(id='19050243', status='COMPLETE'),
#   OptimizationRecord(id='19050244', status='COMPLETE'),
#   OptimizationRecord(id='19050245', status='COMPLETE'),
#   OptimizationRecord(id='19050246', status='COMPLETE'),
#   OptimizationRecord(id='19050247', status='COMPLETE'),
#   OptimizationRecord(id='19050248', status='COMPLETE'),
#   OptimizationRecord(id='19050249', status='COMPLETE'),
#   OptimizationRecord(id='19050250', status='COMPLETE'),
#   OptimizationRecord(id='19050251', status='COMPLETE'),
#   OptimizationRecord(id='19050252', status='COMPLETE'),
#   OptimizationRecord(id='19050253', status='COMPLETE'),
#   OptimizationRecord(id='19050254', status='COMPLETE'),
#   OptimizationRecord(id='19050255', status='COMPLETE'),
#   OptimizationRecord(id='19050256', status='COMPLETE'),
#   OptimizationRecord(id='19050257', status='COMPLETE'),
#   OptimizationRecord(id='19050258', status='COMPLETE'),
#   OptimizationRecord(id='19074061', status='COMPLETE'),
#   OptimizationRecord(id='19074062', status='COMPLETE'),
#   OptimizationRecord(id='19074063', status='COMPLETE'),
#   OptimizationRecord(id='19074064', status='COMPLETE'),
#   OptimizationRecord(id='19436952', status='COMPLETE'),
#   OptimizationRecord(id='19436953', status='COMPLETE'),
#   OptimizationRecord(id='19436954', status='COMPLETE'),
#   OptimizationRecord(id='19436955', status='COMPLETE'),
#   OptimizationRecord(id='19436956', status='COMPLETE'),
#   OptimizationRecord(id='19436957', status='COMPLETE'),
#   OptimizationRecord(id='19436958', status='COMPLETE'),
#   OptimizationRecord(id='19436959', status='COMPLETE')],
#  '18886384': [OptimizationRecord(id='19067822', status='COMPLETE'),
#   OptimizationRecord(id='19067823', status='COMPLETE'),
#   OptimizationRecord(id='19067824', status='COMPLETE'),
#   OptimizationRecord(id='19067825', status='COMPLETE'),
#   OptimizationRecord(id='19067826', status='COMPLETE'),
#   OptimizationRecord(id='19067827', status='COMPLETE'),
#   OptimizationRecord(id='19067828', status='COMPLETE'),
#   OptimizationRecord(id='19067829', status='COMPLETE'),
#   OptimizationRecord(id='19067830', status='COMPLETE'),
#   OptimizationRecord(id='19067831', status='COMPLETE'),
#   OptimizationRecord(id='19067832', status='COMPLETE'),
#   OptimizationRecord(id='19067833', status='COMPLETE'),
#   OptimizationRecord(id='19067834', status='COMPLETE'),
#   OptimizationRecord(id='19067835', status='COMPLETE'),
#   OptimizationRecord(id='19067836', status='COMPLETE'),
#   OptimizationRecord(id='19067837', status='COMPLETE'),
#   OptimizationRecord(id='19067838', status='COMPLETE'),
#   OptimizationRecord(id='19067839', status='COMPLETE'),
#   OptimizationRecord(id='19067840', status='COMPLETE'),
#   OptimizationRecord(id='19067841', status='COMPLETE'),
#   OptimizationRecord(id='19067842', status='COMPLETE'),
#   OptimizationRecord(id='19067843', status='COMPLETE'),
#   OptimizationRecord(id='19067844', status='COMPLETE'),
#   OptimizationRecord(id='19067845', status='COMPLETE'),
#   OptimizationRecord(id='19067846', status='COMPLETE'),
#   OptimizationRecord(id='19067847', status='COMPLETE'),
#   OptimizationRecord(id='19067848', status='COMPLETE'),
#   OptimizationRecord(id='19067849', status='COMPLETE'),
#   OptimizationRecord(id='19067850', status='COMPLETE'),
#   OptimizationRecord(id='19067851', status='COMPLETE'),
#   OptimizationRecord(id='19067852', status='COMPLETE'),
#   OptimizationRecord(id='19067853', status='COMPLETE'),
#   OptimizationRecord(id='19067854', status='COMPLETE'),
#   OptimizationRecord(id='19067855', status='COMPLETE'),
#   OptimizationRecord(id='19067856', status='COMPLETE'),
#   OptimizationRecord(id='19067857', status='COMPLETE'),
#   OptimizationRecord(id='19067858', status='COMPLETE'),
#   OptimizationRecord(id='19067859', status='COMPLETE'),
#   OptimizationRecord(id='19067860', status='COMPLETE'),
#   OptimizationRecord(id='19067861', status='COMPLETE'),
# ...
#   OptimizationRecord(id='19234293', status='COMPLETE'),
#   OptimizationRecord(id='19234294', status='COMPLETE'),
#   OptimizationRecord(id='19234295', status='COMPLETE'),
#   OptimizationRecord(id='19234296', status='COMPLETE'),
#   OptimizationRecord(id='19234297', status='COMPLETE'),
#   OptimizationRecord(id='19234298', status='COMPLETE'),
#   OptimizationRecord(id='19234299', status='COMPLETE'),
#   OptimizationRecord(id='19234300', status='COMPLETE'),
#   OptimizationRecord(id='19234301', status='COMPLETE'),
#   OptimizationRecord(id='19234302', status='COMPLETE'),
#   OptimizationRecord(id='19234303', status='COMPLETE'),
#   OptimizationRecord(id='19234304', status='COMPLETE'),
#   OptimizationRecord(id='19234305', status='COMPLETE'),
#   OptimizationRecord(id='19254779', status='COMPLETE'),
#   OptimizationRecord(id='19254780', status='COMPLETE'),
#   OptimizationRecord(id='19254781', status='COMPLETE'),
#   OptimizationRecord(id='19254782', status='COMPLETE'),
#   OptimizationRecord(id='19254783', status='COMPLETE'),
#   OptimizationRecord(id='19254784', status='COMPLETE'),
#   OptimizationRecord(id='19254785', status='COMPLETE'),
#   OptimizationRecord(id='19254786', status='COMPLETE'),
#   OptimizationRecord(id='19254787', status='COMPLETE'),
#   OptimizationRecord(id='19254788', status='COMPLETE'),
#   OptimizationRecord(id='19254789', status='COMPLETE'),
#   OptimizationRecord(id='19254790', status='COMPLETE'),
#   OptimizationRecord(id='19254791', status='COMPLETE'),
#   OptimizationRecord(id='19254792', status='COMPLETE'),
#   OptimizationRecord(id='19254793', status='COMPLETE'),
#   OptimizationRecord(id='19254794', status='COMPLETE'),
#   OptimizationRecord(id='19254795', status='COMPLETE'),
#   OptimizationRecord(id='19254796', status='COMPLETE'),
#   OptimizationRecord(id='19254797', status='COMPLETE'),
#   OptimizationRecord(id='19254798', status='COMPLETE'),
#   OptimizationRecord(id='19254799', status='COMPLETE'),
#   OptimizationRecord(id='19254800', status='COMPLETE'),
#   OptimizationRecord(id='19254801', status='COMPLETE'),
#   OptimizationRecord(id='19254802', status='COMPLETE'),
#   OptimizationRecord(id='19275229', status='COMPLETE'),
#   OptimizationRecord(id='19275230', status='COMPLETE'),
#   OptimizationRecord(id='19275231', status='COMPLETE'),
#   OptimizationRecord(id='19275232', status='COMPLETE'),
#   OptimizationRecord(id='19275233', status='COMPLETE'),
#   OptimizationRecord(id='19275234', status='COMPLETE'),
#   OptimizationRecord(id='19275235', status='COMPLETE'),
#   OptimizationRecord(id='19275236', status='COMPLETE'),
#   OptimizationRecord(id='19275237', status='COMPLETE'),
#   OptimizationRecord(id='19275238', status='COMPLETE'),
#   OptimizationRecord(id='19275239', status='COMPLETE'),
#   OptimizationRecord(id='19275240', status='COMPLETE'),
#   OptimizationRecord(id='19275241', status='COMPLETE'),
#   OptimizationRecord(id='19275242', status='COMPLETE'),
#   OptimizationRecord(id='19275243', status='COMPLETE'),
#   OptimizationRecord(id='19275244', status='COMPLETE'),
#   OptimizationRecord(id='19275245', status='COMPLETE'),
#   OptimizationRecord(id='19275246', status='COMPLETE'),
#   OptimizationRecord(id='19275247', status='COMPLETE'),
#   OptimizationRecord(id='19275248', status='COMPLETE'),
#   OptimizationRecord(id='19294856', status='COMPLETE'),
#   OptimizationRecord(id='19294857', status='COMPLETE'),
#   OptimizationRecord(id='19294858', status='COMPLETE'),
#   OptimizationRecord(id='19294859', status='COMPLETE'),
#   OptimizationRecord(id='19294860', status='COMPLETE'),
#   OptimizationRecord(id='19294861', status='COMPLETE'),
#   OptimizationRecord(id='19294862', status='COMPLETE'),
#   OptimizationRecord(id='19294863', status='COMPLETE'),
#   OptimizationRecord(id='19294864', status='COMPLETE'),
#   OptimizationRecord(id='19294865', status='COMPLETE'),
#   OptimizationRecord(id='19294866', status='COMPLETE'),
#   OptimizationRecord(id='19294867', status='COMPLETE'),
#   OptimizationRecord(id='19294868', status='COMPLETE'),
#   OptimizationRecord(id='19294869', status='COMPLETE'),
#   OptimizationRecord(id='19325906', status='COMPLETE'),
#   OptimizationRecord(id='19325907', status='COMPLETE'),
#   OptimizationRecord(id='19325908', status='COMPLETE'),
#   OptimizationRecord(id='19325909', status='COMPLETE'),
#   OptimizationRecord(id='19325910', status='COMPLETE'),
#   OptimizationRecord(id='19325911', status='COMPLETE'),
#   OptimizationRecord(id='19325912', status='COMPLETE'),
#   OptimizationRecord(id='19325913', status='COMPLETE'),
#   OptimizationRecord(id='19349673', status='COMPLETE'),
#   OptimizationRecord(id='19349674', status='COMPLETE'),
#   OptimizationRecord(id='19349675', status='COMPLETE'),
#   OptimizationRecord(id='19349676', status='COMPLETE'),
#   OptimizationRecord(id='19349677', status='COMPLETE'),
#   OptimizationRecord(id='19349678', status='COMPLETE'),
#   OptimizationRecord(id='19366765', status='COMPLETE'),
#   OptimizationRecord(id='19366766', status='COMPLETE'),
#   OptimizationRecord(id='19366767', status='COMPLETE'),
#   OptimizationRecord(id='19366768', status='COMPLETE'),
#   OptimizationRecord(id='19366769', status='COMPLETE'),
#   OptimizationRecord(id='19366770', status='COMPLETE'),
#   OptimizationRecord(id='19366771', status='COMPLETE'),
#   OptimizationRecord(id='19366772', status='COMPLETE'),
#   OptimizationRecord(id='19375351', status='COMPLETE'),
#   OptimizationRecord(id='19375352', status='COMPLETE'),
#   OptimizationRecord(id='19375353', status='COMPLETE'),
#   OptimizationRecord(id='19375354', status='COMPLETE'),
#   OptimizationRecord(id='19375355', status='COMPLETE'),
#   OptimizationRecord(id='19375356', status='COMPLETE'),
#   OptimizationRecord(id='19375357', status='COMPLETE'),
#   OptimizationRecord(id='19375358', status='COMPLETE'),
#   OptimizationRecord(id='19383505', status='COMPLETE'),
#   OptimizationRecord(id='19383506', status='COMPLETE'),
#   OptimizationRecord(id='19383507', status='COMPLETE'),
#   OptimizationRecord(id='19383508', status='COMPLETE'),
#   OptimizationRecord(id='19383509', status='COMPLETE'),
#   OptimizationRecord(id='19383510', status='COMPLETE'),
#   OptimizationRecord(id='19383511', status='COMPLETE'),
#   OptimizationRecord(id='19383512', status='COMPLETE')],
#  '18886555': [OptimizationRecord(id='19193821', status='COMPLETE'),
#   OptimizationRecord(id='19193822', status='COMPLETE'),
#   OptimizationRecord(id='19193823', status='COMPLETE'),
#   OptimizationRecord(id='19193824', status='COMPLETE')],
#  '18886557': [OptimizationRecord(id='19194079', status='ERROR'),
#   OptimizationRecord(id='19194080', status='COMPLETE'),
#   OptimizationRecord(id='19194081', status='ERROR'),
#   OptimizationRecord(id='19194082', status='COMPLETE'),
#   OptimizationRecord(id='19194083', status='COMPLETE'),
#   OptimizationRecord(id='19194090', status='ERROR')],
#  '18886558': [OptimizationRecord(id='19194331', status='ERROR'),
#   OptimizationRecord(id='19194332', status='ERROR'),
#   OptimizationRecord(id='19194333', status='ERROR'),
#   OptimizationRecord(id='19194334', status='COMPLETE'),
#   OptimizationRecord(id='19194335', status='COMPLETE'),
#   OptimizationRecord(id='19194336', status='ERROR'),
#   OptimizationRecord(id='19194337', status='COMPLETE'),
#   OptimizationRecord(id='19194338', status='ERROR'),
#   OptimizationRecord(id='19194339', status='ERROR'),
#   OptimizationRecord(id='19194340', status='ERROR'),
#   OptimizationRecord(id='19194341', status='ERROR'),
#   OptimizationRecord(id='19194342', status='ERROR'),
#   OptimizationRecord(id='19194343', status='ERROR'),
#   OptimizationRecord(id='19194344', status='ERROR'),
#   OptimizationRecord(id='19194345', status='COMPLETE'),
#   OptimizationRecord(id='19194346', status='ERROR'),
#   OptimizationRecord(id='19194347', status='ERROR'),
#   OptimizationRecord(id='19194348', status='ERROR'),
#   OptimizationRecord(id='19194349', status='ERROR'),
#   OptimizationRecord(id='19194350', status='COMPLETE'),
#   OptimizationRecord(id='19194351', status='COMPLETE'),
#   OptimizationRecord(id='19194352', status='COMPLETE'),
#   OptimizationRecord(id='19194353', status='ERROR'),
#   OptimizationRecord(id='19194354', status='ERROR'),
#   OptimizationRecord(id='19194355', status='COMPLETE'),
#   OptimizationRecord(id='19194356', status='COMPLETE'),
#   OptimizationRecord(id='19194357', status='ERROR'),
#   OptimizationRecord(id='19194358', status='ERROR'),
#   OptimizationRecord(id='19194359', status='COMPLETE'),
#   OptimizationRecord(id='19194360', status='ERROR'),
#   OptimizationRecord(id='19194361', status='COMPLETE'),
#   OptimizationRecord(id='19194362', status='ERROR'),
#   OptimizationRecord(id='19194363', status='COMPLETE'),
#   OptimizationRecord(id='19194364', status='COMPLETE'),
#   OptimizationRecord(id='19194365', status='COMPLETE'),
#   OptimizationRecord(id='19194366', status='COMPLETE'),
#   OptimizationRecord(id='19194367', status='ERROR'),
#   OptimizationRecord(id='19194368', status='COMPLETE'),
#   OptimizationRecord(id='19194369', status='ERROR'),
#   OptimizationRecord(id='19194370', status='COMPLETE'),
#   OptimizationRecord(id='19194371', status='COMPLETE'),
#   OptimizationRecord(id='19194372', status='COMPLETE'),
#   OptimizationRecord(id='19194373', status='ERROR'),
#   OptimizationRecord(id='19194374', status='COMPLETE'),
#   OptimizationRecord(id='19194375', status='ERROR'),
#   OptimizationRecord(id='19194376', status='COMPLETE'),
#   OptimizationRecord(id='19194377', status='COMPLETE'),
#   OptimizationRecord(id='19194378', status='COMPLETE'),
#   OptimizationRecord(id='19194379', status='COMPLETE'),
#   OptimizationRecord(id='19194380', status='COMPLETE'),
#   OptimizationRecord(id='19194381', status='ERROR'),
#   OptimizationRecord(id='19194382', status='COMPLETE'),
#   OptimizationRecord(id='19194383', status='ERROR'),
#   OptimizationRecord(id='19194384', status='ERROR'),
#   OptimizationRecord(id='19194385', status='ERROR'),
#   OptimizationRecord(id='19194386', status='COMPLETE'),
#   OptimizationRecord(id='19194387', status='COMPLETE'),
#   OptimizationRecord(id='19194388', status='ERROR'),
#   OptimizationRecord(id='19194389', status='COMPLETE')],
#  '18886560': [OptimizationRecord(id='19195425', status='ERROR'),
#   OptimizationRecord(id='19195426', status='COMPLETE'),
#   OptimizationRecord(id='19195427', status='INCOMPLETE'),
#   OptimizationRecord(id='19195428', status='ERROR'),
#   OptimizationRecord(id='19195429', status='COMPLETE')],
#  '18886561': [OptimizationRecord(id='19195439', status='ERROR'),
#   OptimizationRecord(id='19195440', status='COMPLETE'),
#   OptimizationRecord(id='19195441', status='ERROR'),
#   OptimizationRecord(id='19195442', status='ERROR'),
#   OptimizationRecord(id='19195443', status='COMPLETE'),
#   OptimizationRecord(id='19195444', status='ERROR'),
#   OptimizationRecord(id='19195452', status='ERROR'),
#   OptimizationRecord(id='19195453', status='ERROR'),
#   OptimizationRecord(id='19195454', status='COMPLETE'),
#   OptimizationRecord(id='19195455', status='ERROR'),
#   OptimizationRecord(id='19195456', status='ERROR'),
#   OptimizationRecord(id='19195457', status='ERROR'),
#   OptimizationRecord(id='19195458', status='ERROR'),
#   OptimizationRecord(id='19195459', status='COMPLETE'),
#   OptimizationRecord(id='19195460', status='ERROR'),
#   OptimizationRecord(id='19195461', status='ERROR'),
#   OptimizationRecord(id='19195462', status='COMPLETE'),
#   OptimizationRecord(id='19195463', status='ERROR'),
#   OptimizationRecord(id='19195464', status='ERROR'),
#   OptimizationRecord(id='19195465', status='ERROR')],
#  '18886563': [OptimizationRecord(id='19195660', status='ERROR'),
#   OptimizationRecord(id='19195661', status='ERROR')],
#  '18886565': [OptimizationRecord(id='19197484', status='COMPLETE'),
#   OptimizationRecord(id='19197485', status='COMPLETE'),
#   OptimizationRecord(id='19197486', status='ERROR'),
#   OptimizationRecord(id='19197487', status='ERROR'),
#   OptimizationRecord(id='19197488', status='ERROR'),
#   OptimizationRecord(id='19197489', status='COMPLETE')],
#  '18886566': [OptimizationRecord(id='19207846', status='COMPLETE'),
#   OptimizationRecord(id='19207847', status='COMPLETE'),
#   OptimizationRecord(id='19207848', status='COMPLETE'),
#   OptimizationRecord(id='19207849', status='COMPLETE'),
#   OptimizationRecord(id='19207850', status='ERROR'),
#   OptimizationRecord(id='19207851', status='COMPLETE'),
#   OptimizationRecord(id='19207852', status='COMPLETE'),
#   OptimizationRecord(id='19207853', status='ERROR'),
#   OptimizationRecord(id='19207854', status='COMPLETE'),
#   OptimizationRecord(id='19207855', status='COMPLETE'),
#   OptimizationRecord(id='19207856', status='COMPLETE'),
#   OptimizationRecord(id='19207857', status='COMPLETE'),
#   OptimizationRecord(id='19207858', status='COMPLETE'),
#   OptimizationRecord(id='19207859', status='COMPLETE'),
#   OptimizationRecord(id='19207860', status='COMPLETE'),
#   OptimizationRecord(id='19207861', status='COMPLETE'),
#   OptimizationRecord(id='19207862', status='COMPLETE'),
#   OptimizationRecord(id='19207863', status='ERROR'),
#   OptimizationRecord(id='19207864', status='COMPLETE'),
#   OptimizationRecord(id='19207865', status='COMPLETE'),
#   OptimizationRecord(id='19207866', status='COMPLETE'),
#   OptimizationRecord(id='19207867', status='COMPLETE'),
#   OptimizationRecord(id='19207868', status='COMPLETE'),
#   OptimizationRecord(id='19207869', status='COMPLETE'),
#   OptimizationRecord(id='19207870', status='COMPLETE'),
#   OptimizationRecord(id='19207871', status='COMPLETE'),
#   OptimizationRecord(id='19207872', status='COMPLETE'),
#   OptimizationRecord(id='19207873', status='ERROR'),
#   OptimizationRecord(id='19207874', status='COMPLETE'),
#   OptimizationRecord(id='19207875', status='COMPLETE'),
#   OptimizationRecord(id='19207876', status='COMPLETE'),
#   OptimizationRecord(id='19207877', status='COMPLETE'),
#   OptimizationRecord(id='19207878', status='ERROR'),
#   OptimizationRecord(id='19207879', status='COMPLETE'),
#   OptimizationRecord(id='19207880', status='COMPLETE'),
#   OptimizationRecord(id='19207881', status='COMPLETE'),
#   OptimizationRecord(id='19207882', status='COMPLETE'),
#   OptimizationRecord(id='19207883', status='COMPLETE'),
#   OptimizationRecord(id='19207884', status='COMPLETE'),
#   OptimizationRecord(id='19207885', status='ERROR'),
#   OptimizationRecord(id='19207886', status='COMPLETE'),
#   OptimizationRecord(id='19207887', status='COMPLETE'),
#   OptimizationRecord(id='19207888', status='COMPLETE'),
#   OptimizationRecord(id='19207889', status='COMPLETE'),
#   OptimizationRecord(id='19207890', status='COMPLETE'),
#   OptimizationRecord(id='19207891', status='COMPLETE'),
#   OptimizationRecord(id='19207892', status='COMPLETE'),
#   OptimizationRecord(id='19207893', status='COMPLETE'),
#   OptimizationRecord(id='19207894', status='COMPLETE'),
#   OptimizationRecord(id='19207895', status='COMPLETE'),
#   OptimizationRecord(id='19207896', status='COMPLETE'),
#   OptimizationRecord(id='19207897', status='COMPLETE'),
#   OptimizationRecord(id='19207898', status='COMPLETE'),
#   OptimizationRecord(id='19207899', status='COMPLETE'),
#   OptimizationRecord(id='19207900', status='COMPLETE'),
#   OptimizationRecord(id='19207901', status='COMPLETE'),
#   OptimizationRecord(id='19207902', status='COMPLETE'),
#   OptimizationRecord(id='19207903', status='COMPLETE'),
#   OptimizationRecord(id='19207904', status='ERROR'),
#   OptimizationRecord(id='19207905', status='COMPLETE'),
#   OptimizationRecord(id='19207906', status='COMPLETE'),
#   OptimizationRecord(id='19207907', status='ERROR'),
#   OptimizationRecord(id='19207908', status='COMPLETE'),
#   OptimizationRecord(id='19207909', status='COMPLETE'),
#   OptimizationRecord(id='19207910', status='ERROR'),
#   OptimizationRecord(id='19207911', status='COMPLETE'),
#   OptimizationRecord(id='19207912', status='COMPLETE'),
#   OptimizationRecord(id='19207913', status='COMPLETE'),
#   OptimizationRecord(id='19207914', status='COMPLETE'),
#   OptimizationRecord(id='19207915', status='ERROR'),
#   OptimizationRecord(id='19207916', status='COMPLETE'),
#   OptimizationRecord(id='19207917', status='COMPLETE')],
#  '18886569': [OptimizationRecord(id='19208151', status='ERROR'),
#   OptimizationRecord(id='19208152', status='ERROR'),
#   OptimizationRecord(id='19208153', status='ERROR'),
#   OptimizationRecord(id='19208154', status='ERROR')]}

# %%
resm = merge(res)

# %%
incomplete = (opt.dict() for opt in resm if opt.status == 'INCOMPLETE')

# %%
next(incomplete)
# Out:
# {'id': '19498276',
#  'hash_index': '2331cf1bddf4bd3322091a3926ffa645c701f84c',
#  'procedure': 'optimization',
#  'program': 'geometric',
#  'version': 1,
#  'protocols': {},
#  'extras': {},
#  'stdout': '22680080',
#  'stderr': None,
#  'error': None,
#  'task_id': None,
#  'manager_name': None,
#  'status': <RecordStatusEnum.incomplete: 'INCOMPLETE'>,
#  'modified_on': datetime.datetime(2020, 4, 20, 1, 44, 27, 311114),
#  'created_on': datetime.datetime(2020, 4, 20, 1, 29, 59, 14937),
#  'provenance': {'creator': 'geomeTRIC',
#   'version': '0.9.7.2',
#   'routine': 'geometric.run_json.geometric_run_json',
#   'hostname': 'ls04',
#   'qcengine_version': '0.14.0',
#   'wall_time': 438.6346173286438,
#   'cpu': 'Intel(R) Xeon(R) CPU E5-2697 v4 @ 2.30GHz',
#   'username': 'chodera'},
#  'schema_version': 1,
#  'initial_molecule': '13114262',
#  'qc_spec': {'driver': <DriverEnum.gradient: 'gradient'>,
#   'method': 'b3lyp-d3bj',
#   'basis': 'dzvp',
#   'keywords': '2',
#   'program': 'psi4'},
#  'keywords': {'coordsys': 'tric',
#   'enforce': 0.1,
#   'reset': True,
#   'qccnv': True,
#   'epsilon': 0,
#   'constraints': {'set': [{'type': 'dihedral',
#      'indices': [0, 5, 12, 33],
#      'value': 0}]},
#   'program': 'psi4'},
#  'energies': [-748.2713742793587,
#   -748.2713631403763,
#   -748.2713347902593,
#   -748.271252111364,
#   -748.2713580378326,
#   -748.2714639063247,
#   -748.2714916188927,
#   -748.2714956441314,
#   -748.27149594432],
#  'final_molecule': '13116222',
#  'trajectory': ['19496869',
#   '19498897',
#   '19498900',
#   '19498901',
#   '19498902',
#   '19498903',
#   '19498904',
#   '19498905',
#   '19498906']}

# %% [markdown]
# Not all Lilac INCOMPLETEs; some elsewhere, like UCI.

# %%
count_unique_optimization_error_messages(resm, full=True, pretty_print=True)
# Out:
# There are 3 instances of
# -------------------------------------
# Caught Executor Error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/qcfractal/queue/executor_adapter.py", line 15, in _get_future
#     return future.result()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/concurrent/futures/_base.py", line 425, in result
#     return self.__get_result()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
# concurrent.futures.process.BrokenProcessPool: A process in the process pool was terminated abruptly while the future was running or pending.
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# Caught Executor Error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/opt/lib/python3.7/site-packages/qcfractal-0.13.1+54.g3caa178.dirty-py3.7.egg/qcfractal/queue/executor_adapter.py", line 15, in _get_future
#     return future.result()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/distributed/client.py", line 218, in result
#     raise exc.with_traceback(tb)
# distributed.scheduler.KilledWorker: ('compute_procedure-b59f2687aad07f75e22f977885f4d1c7', <Worker 'tcp://10.240.60.37:44803', name: 40, memory: 0, processing: 14>)
#
# -------------------------------------
#
# There are 15 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1296, in optimizeGeometry
#     self.step()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1100, in step
#     self.checkCoordinateSystem(recover=True, cartesian=LastForce)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 959, in checkCoordinateSystem
#     raise ValueError("Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates")
# ValueError: Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1298, in optimizeGeometry
#     self.calcEnergyForce()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1002, in calcEnergyForce
#     spcalc = self.engine.calc(self.X, self.dirname)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/engine.py", line 873, in calc
#     return self.calc_new(coords, dirname)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/engine.py", line 865, in calc_new
#     raise QCEngineAPIEngineError("QCEngineAPI computation did not execute correctly. Message: " + ret["error"]["error_message"])
# geometric.errors.QCEngineAPIEngineError: QCEngineAPI computation did not execute correctly. Message: QCEngine Unknown Error: Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/json_wrapper.py", line 217, in run_json
#     json_data = run_json_qcschema(copy.deepcopy(json_data), clean)
#   File "/opt/conda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/json_wrapper.py", line 312, in run_json_qcschema
#     val, wfn = methods_dict_[json_data["driver"]](method, **kwargs)
#   File "/opt/conda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/driver.py", line 691, in gradient
#     wfn = procedures['gradient'][lowername](lowername, molecule=molecule, **kwargs)
#   File "/opt/conda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/procrouting/proc.py", line 2064, in run_scf_gradient
#     ref_wfn = run_scf(name, **kwargs)
#   File "/opt/conda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/procrouting/proc.py", line 2002, in run_scf
#     scf_wfn = scf_helper(name, post_scf=False, **kwargs)
#   File "/opt/conda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/procrouting/proc.py", line 1363, in scf_helper
#     e_scf = scf_wfn.compute_energy()
#   File "/opt/conda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 94, in scf_compute_energy
#     raise e
#   File "/opt/conda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 87, in scf_compute_energy
#     self.iterations()
#   File "/opt/conda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 447, in scf_iterate
#     raise SCFConvergenceError("""SCF iterations""", self.iteration_, self, Ediff, Dnorm)
# psi4.driver.p4util.exceptions.SCFConvergenceError: Could not converge SCF iterations in 200 iterations.
#
#
# -------------------------------------
#
# There are 16 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1298, in optimizeGeometry
#     self.calcEnergyForce()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1002, in calcEnergyForce
#     spcalc = self.engine.calc(self.X, self.dirname)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/engine.py", line 873, in calc
#     return self.calc_new(coords, dirname)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/engine.py", line 865, in calc_new
#     raise QCEngineAPIEngineError("QCEngineAPI computation did not execute correctly. Message: " + ret["error"]["error_message"])
# geometric.errors.QCEngineAPIEngineError: QCEngineAPI computation did not execute correctly. Message: QCEngine Unknown Error: Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/json_wrapper.py", line 217, in run_json
#     json_data = run_json_qcschema(copy.deepcopy(json_data), clean)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/json_wrapper.py", line 312, in run_json_qcschema
#     val, wfn = methods_dict_[json_data["driver"]](method, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/driver.py", line 691, in gradient
#     wfn = procedures['gradient'][lowername](lowername, molecule=molecule, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/proc.py", line 2064, in run_scf_gradient
#     ref_wfn = run_scf(name, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/proc.py", line 2002, in run_scf
#     scf_wfn = scf_helper(name, post_scf=False, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/proc.py", line 1363, in scf_helper
#     e_scf = scf_wfn.compute_energy()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 94, in scf_compute_energy
#     raise e
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 87, in scf_compute_energy
#     self.iterations()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 447, in scf_iterate
#     raise SCFConvergenceError("""SCF iterations""", self.iteration_, self, Ediff, Dnorm)
# psi4.driver.p4util.exceptions.SCFConvergenceError: Could not converge SCF iterations in 200 iterations.
#
#
# -------------------------------------
#
# There are 30 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1296, in optimizeGeometry
#     self.step()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1100, in step
#     self.checkCoordinateSystem(recover=True, cartesian=LastForce)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 959, in checkCoordinateSystem
#     raise ValueError("Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates")
# ValueError: Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1296, in optimizeGeometry
#     self.step()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1085, in step
#     iopt = brent_wiki(froot.evaluate, 0.0, iopt, froot.target, cvg=0.1, verbose=params.verbose)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 187, in brent_wiki
#     raise RuntimeError('Not bracketed')
# RuntimeError: Not bracketed
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# Caught Executor Error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/opt/lib/python3.7/site-packages/qcfractal-0.13.1+54.g3caa178.dirty-py3.7.egg/qcfractal/queue/executor_adapter.py", line 15, in _get_future
#     return future.result()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/distributed/client.py", line 218, in result
#     raise exc.with_traceback(tb)
# distributed.scheduler.KilledWorker: ('compute_procedure-098cf1ae9094eab35cbdf8a71439e0a0', <Worker 'tcp://10.240.60.26:41482', name: 33, memory: 0, processing: 19>)
#
# -------------------------------------
#
# There are 3 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1296, in optimizeGeometry
#     self.step()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1085, in step
#     iopt = brent_wiki(froot.evaluate, 0.0, iopt, froot.target, cvg=0.1, verbose=params.verbose)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 187, in brent_wiki
#     raise RuntimeError('Not bracketed')
# RuntimeError: Not bracketed
#
# -------------------------------------

# %%
restart_optimizations(resm, client)
# Out:
# OptimizationRecord(id='18888532', status='ERROR')
# OptimizationRecord(id='19074332', status='ERROR')
# OptimizationRecord(id='19194079', status='ERROR')
# OptimizationRecord(id='19194081', status='ERROR')
# OptimizationRecord(id='19194090', status='ERROR')
# OptimizationRecord(id='19194331', status='ERROR')
# OptimizationRecord(id='19194332', status='ERROR')
# OptimizationRecord(id='19194333', status='ERROR')
# OptimizationRecord(id='19194336', status='ERROR')
# OptimizationRecord(id='19194338', status='ERROR')
# OptimizationRecord(id='19194339', status='ERROR')
# OptimizationRecord(id='19194340', status='ERROR')
# OptimizationRecord(id='19194341', status='ERROR')
# OptimizationRecord(id='19194342', status='ERROR')
# OptimizationRecord(id='19194343', status='ERROR')
# OptimizationRecord(id='19194344', status='ERROR')
# OptimizationRecord(id='19194346', status='ERROR')
# OptimizationRecord(id='19194347', status='ERROR')
# OptimizationRecord(id='19194348', status='ERROR')
# OptimizationRecord(id='19194349', status='ERROR')
# OptimizationRecord(id='19194353', status='ERROR')
# OptimizationRecord(id='19194354', status='ERROR')
# OptimizationRecord(id='19194357', status='ERROR')
# OptimizationRecord(id='19194358', status='ERROR')
# OptimizationRecord(id='19194360', status='ERROR')
# OptimizationRecord(id='19194362', status='ERROR')
# OptimizationRecord(id='19194367', status='ERROR')
# OptimizationRecord(id='19194369', status='ERROR')
# OptimizationRecord(id='19194373', status='ERROR')
# OptimizationRecord(id='19194375', status='ERROR')
# OptimizationRecord(id='19194381', status='ERROR')
# OptimizationRecord(id='19194383', status='ERROR')
# OptimizationRecord(id='19194384', status='ERROR')
# OptimizationRecord(id='19194385', status='ERROR')
# OptimizationRecord(id='19194388', status='ERROR')
# OptimizationRecord(id='19195425', status='ERROR')
# OptimizationRecord(id='19195428', status='ERROR')
# OptimizationRecord(id='19195439', status='ERROR')
# OptimizationRecord(id='19195441', status='ERROR')
# OptimizationRecord(id='19195442', status='ERROR')
# OptimizationRecord(id='19195444', status='ERROR')
# OptimizationRecord(id='19195452', status='ERROR')
# OptimizationRecord(id='19195453', status='ERROR')
# OptimizationRecord(id='19195455', status='ERROR')
# OptimizationRecord(id='19195456', status='ERROR')
# OptimizationRecord(id='19195457', status='ERROR')
# OptimizationRecord(id='19195458', status='ERROR')
# OptimizationRecord(id='19195460', status='ERROR')
# OptimizationRecord(id='19195461', status='ERROR')
# OptimizationRecord(id='19195463', status='ERROR')
# OptimizationRecord(id='19195464', status='ERROR')
# OptimizationRecord(id='19195465', status='ERROR')
# OptimizationRecord(id='19195660', status='ERROR')
# OptimizationRecord(id='19195661', status='ERROR')
# OptimizationRecord(id='19197486', status='ERROR')
# OptimizationRecord(id='19197487', status='ERROR')
# OptimizationRecord(id='19197488', status='ERROR')
# OptimizationRecord(id='19207850', status='ERROR')
# OptimizationRecord(id='19207853', status='ERROR')
# OptimizationRecord(id='19207863', status='ERROR')
# OptimizationRecord(id='19207873', status='ERROR')
# OptimizationRecord(id='19207878', status='ERROR')
# OptimizationRecord(id='19207885', status='ERROR')
# OptimizationRecord(id='19207904', status='ERROR')
# OptimizationRecord(id='19207907', status='ERROR')
# OptimizationRecord(id='19207910', status='ERROR')
# OptimizationRecord(id='19207915', status='ERROR')
# OptimizationRecord(id='19208151', status='ERROR')
# OptimizationRecord(id='19208152', status='ERROR')
# OptimizationRecord(id='19208153', status='ERROR')
# OptimizationRecord(id='19208154', status='ERROR')

# %%
restart_torsiondrives(ds.df.default.tolist(), client)
# Out:
# TorsionDriveRecord(id='18886168', status='ERROR')
# TorsionDriveRecord(id='18886202', status='ERROR')
# TorsionDriveRecord(id='18886207', status='ERROR')
# TorsionDriveRecord(id='18886222', status='ERROR')
# TorsionDriveRecord(id='18886225', status='ERROR')
# TorsionDriveRecord(id='18886228', status='ERROR')
# TorsionDriveRecord(id='18886319', status='ERROR')
# TorsionDriveRecord(id='18886354', status='ERROR')
# TorsionDriveRecord(id='18886355', status='ERROR')
# TorsionDriveRecord(id='18886376', status='ERROR')
# TorsionDriveRecord(id='18886384', status='ERROR')
# TorsionDriveRecord(id='18886391', status='ERROR')
# TorsionDriveRecord(id='18886397', status='ERROR')
# TorsionDriveRecord(id='18886436', status='ERROR')
# TorsionDriveRecord(id='18886491', status='ERROR')
# TorsionDriveRecord(id='18886532', status='ERROR')
# TorsionDriveRecord(id='18886540', status='ERROR')
# TorsionDriveRecord(id='18886551', status='ERROR')
# TorsionDriveRecord(id='18886552', status='ERROR')
# TorsionDriveRecord(id='18886555', status='ERROR')
# TorsionDriveRecord(id='18886557', status='ERROR')
# TorsionDriveRecord(id='18886558', status='ERROR')
# TorsionDriveRecord(id='18886560', status='ERROR')
# TorsionDriveRecord(id='18886561', status='ERROR')
# TorsionDriveRecord(id='18886563', status='ERROR')
# TorsionDriveRecord(id='18886565', status='ERROR')
# TorsionDriveRecord(id='18886566', status='ERROR')
# TorsionDriveRecord(id='18886569', status='ERROR')

# %% [markdown]
# ### 2020.06.11 22:40 UTC

# %%
dataset = "OpenFF Gen 2 Torsion Set 5 Bayer 2"

# %%
ds = client.get_collection("TorsionDriveDataset", dataset)

# %%
ds.list_specifications()
# Out:
#                                          Description
# Name
# default  Standard OpenFF torsiondrive specification.

# %%
res = get_unfinished_torsiondrive_optimizations(ds, 'default', client, merged=False)
res
# Out:
# {'18886168': [OptimizationRecord(id='18886256', status='COMPLETE'),
#   OptimizationRecord(id='18886259', status='COMPLETE'),
#   OptimizationRecord(id='18886262', status='COMPLETE'),
#   OptimizationRecord(id='18886264', status='COMPLETE'),
#   OptimizationRecord(id='18886267', status='COMPLETE'),
#   OptimizationRecord(id='18886268', status='COMPLETE'),
#   OptimizationRecord(id='18886271', status='COMPLETE'),
#   OptimizationRecord(id='18886273', status='COMPLETE'),
#   OptimizationRecord(id='18886275', status='COMPLETE'),
#   OptimizationRecord(id='18886277', status='COMPLETE'),
#   OptimizationRecord(id='18886279', status='COMPLETE'),
#   OptimizationRecord(id='18886291', status='COMPLETE'),
#   OptimizationRecord(id='18886292', status='COMPLETE'),
#   OptimizationRecord(id='18886295', status='COMPLETE'),
#   OptimizationRecord(id='18886296', status='COMPLETE'),
#   OptimizationRecord(id='18886297', status='COMPLETE'),
#   OptimizationRecord(id='18886298', status='COMPLETE'),
#   OptimizationRecord(id='18886300', status='COMPLETE'),
#   OptimizationRecord(id='18886302', status='COMPLETE'),
#   OptimizationRecord(id='18886304', status='COMPLETE'),
#   OptimizationRecord(id='18886305', status='COMPLETE'),
#   OptimizationRecord(id='18886309', status='COMPLETE'),
#   OptimizationRecord(id='18886311', status='COMPLETE'),
#   OptimizationRecord(id='18886313', status='COMPLETE'),
#   OptimizationRecord(id='18886316', status='COMPLETE'),
#   OptimizationRecord(id='18886318', status='COMPLETE'),
#   OptimizationRecord(id='18886320', status='COMPLETE'),
#   OptimizationRecord(id='18886322', status='COMPLETE'),
#   OptimizationRecord(id='18886323', status='COMPLETE'),
#   OptimizationRecord(id='18886325', status='COMPLETE'),
#   OptimizationRecord(id='18886327', status='COMPLETE'),
#   OptimizationRecord(id='18886328', status='COMPLETE'),
#   OptimizationRecord(id='18886329', status='ERROR'),
#   OptimizationRecord(id='18886330', status='COMPLETE'),
#   OptimizationRecord(id='18886332', status='COMPLETE'),
#   OptimizationRecord(id='18886334', status='COMPLETE'),
#   OptimizationRecord(id='18886335', status='COMPLETE'),
#   OptimizationRecord(id='18886336', status='COMPLETE'),
#   OptimizationRecord(id='18886337', status='COMPLETE'),
#   OptimizationRecord(id='18886338', status='COMPLETE'),
#   OptimizationRecord(id='18886341', status='COMPLETE'),
#   OptimizationRecord(id='18886344', status='COMPLETE'),
#   OptimizationRecord(id='18886347', status='COMPLETE'),
#   OptimizationRecord(id='18886349', status='COMPLETE'),
#   OptimizationRecord(id='18886352', status='COMPLETE'),
#   OptimizationRecord(id='18886353', status='COMPLETE'),
#   OptimizationRecord(id='18886356', status='COMPLETE'),
#   OptimizationRecord(id='18886357', status='COMPLETE'),
#   OptimizationRecord(id='18886358', status='COMPLETE'),
#   OptimizationRecord(id='18886360', status='COMPLETE'),
#   OptimizationRecord(id='18886363', status='COMPLETE'),
#   OptimizationRecord(id='18886365', status='COMPLETE'),
#   OptimizationRecord(id='18886366', status='COMPLETE'),
#   OptimizationRecord(id='18886367', status='COMPLETE'),
#   OptimizationRecord(id='18886368', status='COMPLETE'),
#   OptimizationRecord(id='18886370', status='COMPLETE'),
#   OptimizationRecord(id='18886373', status='COMPLETE'),
#   OptimizationRecord(id='18886377', status='COMPLETE'),
#   OptimizationRecord(id='18886380', status='COMPLETE'),
#   OptimizationRecord(id='18886382', status='COMPLETE'),
#   OptimizationRecord(id='18886385', status='COMPLETE'),
#   OptimizationRecord(id='18886386', status='COMPLETE'),
#   OptimizationRecord(id='18886387', status='COMPLETE'),
#   OptimizationRecord(id='18886390', status='COMPLETE'),
#   OptimizationRecord(id='18886393', status='COMPLETE'),
#   OptimizationRecord(id='18886395', status='COMPLETE')],
#  '18886202': [OptimizationRecord(id='18887451', status='COMPLETE'),
#   OptimizationRecord(id='18887452', status='COMPLETE'),
#   OptimizationRecord(id='18922536', status='COMPLETE'),
#   OptimizationRecord(id='18922537', status='COMPLETE'),
#   OptimizationRecord(id='18956306', status='COMPLETE'),
#   OptimizationRecord(id='18956307', status='COMPLETE'),
#   OptimizationRecord(id='18956308', status='COMPLETE'),
#   OptimizationRecord(id='18956309', status='COMPLETE'),
#   OptimizationRecord(id='18975308', status='COMPLETE'),
#   OptimizationRecord(id='18975309', status='COMPLETE'),
#   OptimizationRecord(id='18975310', status='COMPLETE'),
#   OptimizationRecord(id='18975311', status='COMPLETE'),
#   OptimizationRecord(id='18988928', status='COMPLETE'),
#   OptimizationRecord(id='18988929', status='COMPLETE'),
#   OptimizationRecord(id='18988930', status='COMPLETE'),
#   OptimizationRecord(id='18988931', status='COMPLETE'),
#   OptimizationRecord(id='18988932', status='COMPLETE'),
#   OptimizationRecord(id='18988933', status='COMPLETE'),
#   OptimizationRecord(id='18988934', status='COMPLETE'),
#   OptimizationRecord(id='18988935', status='COMPLETE'),
#   OptimizationRecord(id='19003570', status='COMPLETE'),
#   OptimizationRecord(id='19003571', status='COMPLETE'),
#   OptimizationRecord(id='19003572', status='COMPLETE'),
#   OptimizationRecord(id='19003573', status='COMPLETE'),
#   OptimizationRecord(id='19003574', status='COMPLETE'),
#   OptimizationRecord(id='19003575', status='COMPLETE'),
#   OptimizationRecord(id='19003576', status='COMPLETE'),
#   OptimizationRecord(id='19003577', status='COMPLETE'),
#   OptimizationRecord(id='19083510', status='COMPLETE'),
#   OptimizationRecord(id='19083511', status='COMPLETE'),
#   OptimizationRecord(id='19083512', status='COMPLETE'),
#   OptimizationRecord(id='19083513', status='COMPLETE'),
#   OptimizationRecord(id='19083514', status='COMPLETE'),
#   OptimizationRecord(id='19083515', status='COMPLETE')],
#  '18886207': [OptimizationRecord(id='18887748', status='COMPLETE'),
#   OptimizationRecord(id='18887749', status='COMPLETE'),
#   OptimizationRecord(id='18887750', status='COMPLETE'),
#   OptimizationRecord(id='18887751', status='COMPLETE'),
#   OptimizationRecord(id='18887752', status='COMPLETE'),
#   OptimizationRecord(id='18887753', status='COMPLETE'),
#   OptimizationRecord(id='18887754', status='COMPLETE'),
#   OptimizationRecord(id='18887755', status='COMPLETE'),
#   OptimizationRecord(id='18887756', status='COMPLETE'),
#   OptimizationRecord(id='18887757', status='COMPLETE'),
#   OptimizationRecord(id='18887758', status='COMPLETE'),
#   OptimizationRecord(id='18887759', status='COMPLETE'),
#   OptimizationRecord(id='18887760', status='COMPLETE'),
#   OptimizationRecord(id='18887761', status='COMPLETE'),
#   OptimizationRecord(id='18887762', status='COMPLETE'),
#   OptimizationRecord(id='18887763', status='COMPLETE'),
#   OptimizationRecord(id='18887764', status='COMPLETE'),
#   OptimizationRecord(id='18887765', status='COMPLETE'),
#   OptimizationRecord(id='18887766', status='COMPLETE'),
#   OptimizationRecord(id='18887767', status='COMPLETE'),
#   OptimizationRecord(id='18887768', status='COMPLETE'),
#   OptimizationRecord(id='18887769', status='COMPLETE'),
#   OptimizationRecord(id='18887770', status='COMPLETE'),
#   OptimizationRecord(id='18887771', status='COMPLETE'),
#   OptimizationRecord(id='18887772', status='COMPLETE'),
#   OptimizationRecord(id='18887773', status='COMPLETE'),
#   OptimizationRecord(id='18887774', status='COMPLETE'),
#   OptimizationRecord(id='18887775', status='COMPLETE'),
#   OptimizationRecord(id='18887776', status='COMPLETE'),
#   OptimizationRecord(id='18887777', status='COMPLETE'),
#   OptimizationRecord(id='18887778', status='COMPLETE'),
#   OptimizationRecord(id='18887779', status='COMPLETE'),
#   OptimizationRecord(id='18887780', status='COMPLETE'),
#   OptimizationRecord(id='18887781', status='COMPLETE'),
#   OptimizationRecord(id='18887782', status='COMPLETE'),
#   OptimizationRecord(id='18887783', status='COMPLETE'),
#   OptimizationRecord(id='18887784', status='COMPLETE'),
#   OptimizationRecord(id='18887785', status='COMPLETE'),
#   OptimizationRecord(id='18887786', status='COMPLETE'),
#   OptimizationRecord(id='18887787', status='COMPLETE'),
#   OptimizationRecord(id='18887788', status='COMPLETE'),
#   OptimizationRecord(id='18887789', status='COMPLETE'),
#   OptimizationRecord(id='18887790', status='COMPLETE'),
#   OptimizationRecord(id='18887791', status='COMPLETE'),
#   OptimizationRecord(id='18887792', status='COMPLETE'),
#   OptimizationRecord(id='18887793', status='COMPLETE'),
#   OptimizationRecord(id='18887794', status='COMPLETE'),
#   OptimizationRecord(id='18887795', status='COMPLETE'),
#   OptimizationRecord(id='18887796', status='COMPLETE'),
#   OptimizationRecord(id='18887797', status='COMPLETE'),
#   OptimizationRecord(id='18887798', status='COMPLETE'),
#   OptimizationRecord(id='18887799', status='COMPLETE'),
#   OptimizationRecord(id='18887800', status='COMPLETE'),
#   OptimizationRecord(id='18887801', status='COMPLETE'),
#   OptimizationRecord(id='18887802', status='COMPLETE'),
#   OptimizationRecord(id='18937010', status='COMPLETE'),
#   OptimizationRecord(id='18937011', status='COMPLETE'),
#   OptimizationRecord(id='18937012', status='COMPLETE'),
#   OptimizationRecord(id='18937013', status='COMPLETE'),
#   OptimizationRecord(id='18937014', status='COMPLETE'),
#   OptimizationRecord(id='18937015', status='COMPLETE'),
#   OptimizationRecord(id='18937016', status='COMPLETE'),
#   OptimizationRecord(id='18937017', status='COMPLETE'),
#   OptimizationRecord(id='18937018', status='COMPLETE'),
#   OptimizationRecord(id='18937019', status='COMPLETE'),
#   OptimizationRecord(id='18937020', status='COMPLETE'),
#   OptimizationRecord(id='18937021', status='COMPLETE'),
#   OptimizationRecord(id='18937022', status='COMPLETE'),
#   OptimizationRecord(id='18937023', status='COMPLETE'),
#   OptimizationRecord(id='18937024', status='COMPLETE'),
#   OptimizationRecord(id='18937025', status='COMPLETE'),
#   OptimizationRecord(id='18937026', status='COMPLETE'),
#   OptimizationRecord(id='18937027', status='COMPLETE'),
#   OptimizationRecord(id='18937028', status='COMPLETE'),
#   OptimizationRecord(id='18937029', status='COMPLETE'),
#   OptimizationRecord(id='18937030', status='COMPLETE'),
#   OptimizationRecord(id='18937031', status='COMPLETE'),
#   OptimizationRecord(id='18965628', status='COMPLETE'),
#   OptimizationRecord(id='18965629', status='COMPLETE'),
#   OptimizationRecord(id='18965630', status='COMPLETE'),
#   OptimizationRecord(id='18965631', status='COMPLETE'),
#   OptimizationRecord(id='18965632', status='COMPLETE'),
#   OptimizationRecord(id='18965633', status='COMPLETE'),
#   OptimizationRecord(id='18965634', status='COMPLETE'),
#   OptimizationRecord(id='18965635', status='COMPLETE'),
#   OptimizationRecord(id='18965636', status='COMPLETE'),
#   OptimizationRecord(id='18965637', status='COMPLETE'),
#   OptimizationRecord(id='18965638', status='COMPLETE'),
#   OptimizationRecord(id='18965639', status='COMPLETE'),
#   OptimizationRecord(id='18965640', status='COMPLETE'),
#   OptimizationRecord(id='18965641', status='COMPLETE'),
#   OptimizationRecord(id='18965642', status='COMPLETE'),
#   OptimizationRecord(id='18965643', status='COMPLETE'),
#   OptimizationRecord(id='18965644', status='COMPLETE'),
#   OptimizationRecord(id='18965645', status='COMPLETE'),
#   OptimizationRecord(id='18965646', status='COMPLETE'),
#   OptimizationRecord(id='18965647', status='COMPLETE'),
#   OptimizationRecord(id='18965648', status='COMPLETE'),
#   OptimizationRecord(id='18965649', status='COMPLETE'),
#   OptimizationRecord(id='18965650', status='COMPLETE'),
#   OptimizationRecord(id='18965651', status='COMPLETE'),
#   OptimizationRecord(id='18982580', status='COMPLETE'),
#   OptimizationRecord(id='18982581', status='COMPLETE'),
#   OptimizationRecord(id='18982582', status='COMPLETE'),
#   OptimizationRecord(id='18982583', status='COMPLETE'),
#   OptimizationRecord(id='18982584', status='COMPLETE'),
#   OptimizationRecord(id='18982585', status='COMPLETE'),
#   OptimizationRecord(id='18982586', status='COMPLETE'),
#   OptimizationRecord(id='18982587', status='COMPLETE'),
#   OptimizationRecord(id='18982588', status='COMPLETE'),
#   OptimizationRecord(id='18982589', status='COMPLETE'),
#   OptimizationRecord(id='18982590', status='COMPLETE'),
#   OptimizationRecord(id='18982591', status='COMPLETE'),
#   OptimizationRecord(id='18982592', status='COMPLETE'),
#   OptimizationRecord(id='18982593', status='COMPLETE'),
#   OptimizationRecord(id='18982594', status='COMPLETE'),
#   OptimizationRecord(id='18982595', status='COMPLETE'),
#   OptimizationRecord(id='18982596', status='COMPLETE'),
#   OptimizationRecord(id='18982597', status='COMPLETE'),
#   OptimizationRecord(id='18998836', status='COMPLETE'),
#   OptimizationRecord(id='18998837', status='COMPLETE'),
#   OptimizationRecord(id='18998838', status='COMPLETE'),
#   OptimizationRecord(id='18998839', status='COMPLETE'),
#   OptimizationRecord(id='18998840', status='COMPLETE'),
#   OptimizationRecord(id='18998841', status='COMPLETE'),
#   OptimizationRecord(id='18998842', status='COMPLETE'),
#   OptimizationRecord(id='18998843', status='COMPLETE'),
#   OptimizationRecord(id='18998844', status='COMPLETE'),
#   OptimizationRecord(id='18998845', status='COMPLETE'),
#   OptimizationRecord(id='19013301', status='COMPLETE'),
#   OptimizationRecord(id='19013302', status='COMPLETE'),
#   OptimizationRecord(id='19013303', status='COMPLETE'),
#   OptimizationRecord(id='19013304', status='COMPLETE'),
#   OptimizationRecord(id='19013305', status='COMPLETE'),
#   OptimizationRecord(id='19013306', status='COMPLETE'),
#   OptimizationRecord(id='19013307', status='COMPLETE'),
#   OptimizationRecord(id='19013308', status='COMPLETE'),
#   OptimizationRecord(id='19027391', status='COMPLETE'),
#   OptimizationRecord(id='19027392', status='COMPLETE'),
#   OptimizationRecord(id='19027393', status='COMPLETE'),
#   OptimizationRecord(id='19027394', status='COMPLETE'),
#   OptimizationRecord(id='19027395', status='COMPLETE'),
#   OptimizationRecord(id='19027396', status='COMPLETE'),
#   OptimizationRecord(id='19040614', status='COMPLETE'),
#   OptimizationRecord(id='19040615', status='COMPLETE'),
#   OptimizationRecord(id='19040616', status='COMPLETE'),
#   OptimizationRecord(id='19040617', status='COMPLETE'),
#   OptimizationRecord(id='19058923', status='COMPLETE'),
#   OptimizationRecord(id='19058924', status='COMPLETE'),
#   OptimizationRecord(id='19072648', status='COMPLETE'),
#   OptimizationRecord(id='19072649', status='ERROR')],
#  '18886222': [OptimizationRecord(id='18888477', status='COMPLETE'),
#   OptimizationRecord(id='18888478', status='COMPLETE'),
#   OptimizationRecord(id='18888479', status='COMPLETE'),
#   OptimizationRecord(id='18888480', status='COMPLETE'),
#   OptimizationRecord(id='18888502', status='COMPLETE'),
#   OptimizationRecord(id='18888506', status='COMPLETE'),
#   OptimizationRecord(id='18888507', status='COMPLETE'),
#   OptimizationRecord(id='18888508', status='COMPLETE'),
#   OptimizationRecord(id='18888509', status='COMPLETE'),
#   OptimizationRecord(id='18888510', status='COMPLETE'),
#   OptimizationRecord(id='18888511', status='COMPLETE'),
#   OptimizationRecord(id='18888512', status='COMPLETE'),
#   OptimizationRecord(id='18888513', status='COMPLETE'),
#   OptimizationRecord(id='18888514', status='COMPLETE'),
#   OptimizationRecord(id='18888515', status='COMPLETE'),
#   OptimizationRecord(id='18888516', status='COMPLETE'),
#   OptimizationRecord(id='18888517', status='COMPLETE'),
#   OptimizationRecord(id='18888518', status='COMPLETE'),
#   OptimizationRecord(id='18888519', status='COMPLETE'),
#   OptimizationRecord(id='18888520', status='COMPLETE'),
#   OptimizationRecord(id='18888521', status='COMPLETE'),
#   OptimizationRecord(id='18888522', status='COMPLETE'),
#   OptimizationRecord(id='18888523', status='COMPLETE'),
#   OptimizationRecord(id='18888524', status='COMPLETE'),
#   OptimizationRecord(id='18888525', status='COMPLETE'),
#   OptimizationRecord(id='18888526', status='COMPLETE'),
#   OptimizationRecord(id='18888527', status='COMPLETE'),
#   OptimizationRecord(id='18888528', status='COMPLETE'),
#   OptimizationRecord(id='18888529', status='COMPLETE'),
#   OptimizationRecord(id='18888530', status='COMPLETE'),
#   OptimizationRecord(id='18888531', status='COMPLETE'),
#   OptimizationRecord(id='18888532', status='ERROR')],
#  '18886225': [OptimizationRecord(id='18888979', status='COMPLETE'),
#   OptimizationRecord(id='18888980', status='COMPLETE'),
#   OptimizationRecord(id='18888981', status='COMPLETE'),
#   OptimizationRecord(id='18888982', status='COMPLETE'),
#   OptimizationRecord(id='18888983', status='COMPLETE'),
#   OptimizationRecord(id='18888984', status='COMPLETE'),
#   OptimizationRecord(id='18888985', status='COMPLETE'),
#   OptimizationRecord(id='18888986', status='COMPLETE'),
#   OptimizationRecord(id='18888987', status='COMPLETE'),
#   OptimizationRecord(id='18888988', status='COMPLETE'),
#   OptimizationRecord(id='18888989', status='COMPLETE')],
#  '18886228': [OptimizationRecord(id='18889082', status='COMPLETE'),
#   OptimizationRecord(id='18889083', status='COMPLETE'),
#   OptimizationRecord(id='18889084', status='COMPLETE'),
#   OptimizationRecord(id='18889085', status='COMPLETE'),
#   OptimizationRecord(id='18889086', status='COMPLETE'),
#   OptimizationRecord(id='18889087', status='COMPLETE'),
#   OptimizationRecord(id='18889088', status='COMPLETE'),
#   OptimizationRecord(id='18889089', status='COMPLETE'),
#   OptimizationRecord(id='18889090', status='COMPLETE'),
#   OptimizationRecord(id='18889091', status='COMPLETE'),
#   OptimizationRecord(id='18889092', status='COMPLETE'),
#   OptimizationRecord(id='18889093', status='COMPLETE'),
#   OptimizationRecord(id='18889094', status='COMPLETE'),
#   OptimizationRecord(id='18889095', status='COMPLETE'),
#   OptimizationRecord(id='18889096', status='COMPLETE'),
#   OptimizationRecord(id='18889097', status='COMPLETE'),
#   OptimizationRecord(id='18889098', status='COMPLETE'),
#   OptimizationRecord(id='18889099', status='COMPLETE'),
#   OptimizationRecord(id='18889100', status='COMPLETE'),
#   OptimizationRecord(id='18889101', status='COMPLETE'),
#   OptimizationRecord(id='18889102', status='COMPLETE'),
#   OptimizationRecord(id='18889103', status='COMPLETE'),
#   OptimizationRecord(id='18889104', status='COMPLETE'),
#   OptimizationRecord(id='18889105', status='COMPLETE'),
#   OptimizationRecord(id='18889106', status='COMPLETE'),
#   OptimizationRecord(id='18889107', status='COMPLETE'),
#   OptimizationRecord(id='18889108', status='COMPLETE'),
#   OptimizationRecord(id='18889109', status='COMPLETE'),
#   OptimizationRecord(id='18889110', status='COMPLETE'),
#   OptimizationRecord(id='18889111', status='COMPLETE'),
#   OptimizationRecord(id='18889112', status='COMPLETE'),
#   OptimizationRecord(id='18889113', status='COMPLETE'),
#   OptimizationRecord(id='18889114', status='COMPLETE')],
#  '18886319': [OptimizationRecord(id='19018428', status='COMPLETE'),
#   OptimizationRecord(id='19018429', status='COMPLETE'),
#   OptimizationRecord(id='19018430', status='COMPLETE'),
#   OptimizationRecord(id='19018431', status='COMPLETE'),
#   OptimizationRecord(id='19018432', status='COMPLETE'),
#   OptimizationRecord(id='19018433', status='COMPLETE'),
#   OptimizationRecord(id='19018434', status='COMPLETE'),
#   OptimizationRecord(id='19029482', status='COMPLETE'),
#   OptimizationRecord(id='19029483', status='COMPLETE'),
#   OptimizationRecord(id='19029484', status='COMPLETE'),
#   OptimizationRecord(id='19029493', status='COMPLETE'),
#   OptimizationRecord(id='19029494', status='COMPLETE'),
#   OptimizationRecord(id='19029495', status='COMPLETE'),
#   OptimizationRecord(id='19029496', status='COMPLETE'),
#   OptimizationRecord(id='19029497', status='COMPLETE'),
#   OptimizationRecord(id='19044800', status='COMPLETE'),
#   OptimizationRecord(id='19044801', status='COMPLETE'),
#   OptimizationRecord(id='19044802', status='COMPLETE'),
#   OptimizationRecord(id='19044803', status='COMPLETE'),
#   OptimizationRecord(id='19044804', status='COMPLETE'),
#   OptimizationRecord(id='19044805', status='COMPLETE'),
#   OptimizationRecord(id='19044806', status='COMPLETE'),
#   OptimizationRecord(id='19044807', status='COMPLETE'),
#   OptimizationRecord(id='19044808', status='COMPLETE'),
#   OptimizationRecord(id='19044809', status='COMPLETE'),
#   OptimizationRecord(id='19044810', status='COMPLETE'),
#   OptimizationRecord(id='19044811', status='COMPLETE'),
#   OptimizationRecord(id='19063096', status='ERROR'),
#   OptimizationRecord(id='19063097', status='COMPLETE'),
#   OptimizationRecord(id='19063098', status='COMPLETE'),
#   OptimizationRecord(id='19063099', status='COMPLETE'),
#   OptimizationRecord(id='19063100', status='COMPLETE'),
#   OptimizationRecord(id='19063101', status='COMPLETE'),
#   OptimizationRecord(id='19063102', status='COMPLETE'),
#   OptimizationRecord(id='19063103', status='COMPLETE'),
#   OptimizationRecord(id='19063104', status='COMPLETE'),
#   OptimizationRecord(id='19063105', status='COMPLETE'),
#   OptimizationRecord(id='19063106', status='COMPLETE'),
#   OptimizationRecord(id='19063107', status='COMPLETE')],
#  '18886340': [OptimizationRecord(id='19028799', status='COMPLETE'),
#   OptimizationRecord(id='19028800', status='COMPLETE'),
#   OptimizationRecord(id='19028801', status='COMPLETE'),
#   OptimizationRecord(id='19028802', status='COMPLETE'),
#   OptimizationRecord(id='19028803', status='COMPLETE'),
#   OptimizationRecord(id='19028804', status='COMPLETE'),
#   OptimizationRecord(id='19028805', status='COMPLETE'),
#   OptimizationRecord(id='19028806', status='COMPLETE'),
#   OptimizationRecord(id='19028807', status='COMPLETE'),
#   OptimizationRecord(id='19028808', status='COMPLETE'),
#   OptimizationRecord(id='19028809', status='COMPLETE'),
#   OptimizationRecord(id='19028810', status='COMPLETE'),
#   OptimizationRecord(id='19040904', status='COMPLETE'),
#   OptimizationRecord(id='19040905', status='COMPLETE'),
#   OptimizationRecord(id='19040906', status='COMPLETE'),
#   OptimizationRecord(id='19040907', status='COMPLETE'),
#   OptimizationRecord(id='19060959', status='COMPLETE'),
#   OptimizationRecord(id='19060968', status='COMPLETE'),
#   OptimizationRecord(id='19060969', status='COMPLETE'),
#   OptimizationRecord(id='19060970', status='COMPLETE'),
#   OptimizationRecord(id='19060971', status='COMPLETE'),
#   OptimizationRecord(id='19060972', status='COMPLETE'),
#   OptimizationRecord(id='19060973', status='COMPLETE'),
#   OptimizationRecord(id='19060974', status='COMPLETE'),
#   OptimizationRecord(id='19073108', status='COMPLETE'),
#   OptimizationRecord(id='19073109', status='COMPLETE'),
#   OptimizationRecord(id='19073110', status='COMPLETE'),
#   OptimizationRecord(id='19073111', status='COMPLETE'),
#   OptimizationRecord(id='19073112', status='COMPLETE'),
#   OptimizationRecord(id='19073113', status='COMPLETE'),
#   OptimizationRecord(id='19073114', status='COMPLETE'),
#   OptimizationRecord(id='19073115', status='COMPLETE'),
#   OptimizationRecord(id='19435064', status='COMPLETE'),
#   OptimizationRecord(id='19435065', status='COMPLETE'),
#   OptimizationRecord(id='19435066', status='COMPLETE'),
#   OptimizationRecord(id='19435067', status='COMPLETE'),
#   OptimizationRecord(id='19435068', status='COMPLETE'),
#   OptimizationRecord(id='19435069', status='COMPLETE'),
#   OptimizationRecord(id='19435070', status='COMPLETE'),
#   OptimizationRecord(id='19435071', status='COMPLETE'),
#   OptimizationRecord(id='19496823', status='COMPLETE'),
#   OptimizationRecord(id='19496824', status='COMPLETE'),
#   OptimizationRecord(id='19496825', status='COMPLETE'),
#   OptimizationRecord(id='19496826', status='COMPLETE'),
#   OptimizationRecord(id='19496827', status='COMPLETE'),
#   OptimizationRecord(id='19496828', status='COMPLETE'),
#   OptimizationRecord(id='19498273', status='COMPLETE'),
#   OptimizationRecord(id='19498274', status='COMPLETE'),
#   OptimizationRecord(id='19498275', status='COMPLETE'),
#   OptimizationRecord(id='19498276', status='INCOMPLETE'),
#   OptimizationRecord(id='19498277', status='COMPLETE'),
#   OptimizationRecord(id='19498278', status='COMPLETE')],
#  '18886354': [OptimizationRecord(id='19039752', status='COMPLETE'),
#   OptimizationRecord(id='19039753', status='COMPLETE'),
#   OptimizationRecord(id='19039754', status='COMPLETE'),
#   OptimizationRecord(id='19039755', status='COMPLETE'),
#   OptimizationRecord(id='19039756', status='COMPLETE'),
#   OptimizationRecord(id='19039757', status='COMPLETE'),
#   OptimizationRecord(id='19039758', status='COMPLETE'),
#   OptimizationRecord(id='19039759', status='COMPLETE'),
#   OptimizationRecord(id='19039760', status='COMPLETE'),
#   OptimizationRecord(id='19039761', status='COMPLETE'),
#   OptimizationRecord(id='19039762', status='COMPLETE'),
#   OptimizationRecord(id='19039763', status='COMPLETE'),
#   OptimizationRecord(id='19039764', status='COMPLETE'),
#   OptimizationRecord(id='19039765', status='COMPLETE'),
#   OptimizationRecord(id='19039766', status='COMPLETE'),
#   OptimizationRecord(id='19039767', status='COMPLETE'),
#   OptimizationRecord(id='19039768', status='COMPLETE'),
#   OptimizationRecord(id='19039769', status='COMPLETE'),
#   OptimizationRecord(id='19039770', status='COMPLETE'),
#   OptimizationRecord(id='19039771', status='COMPLETE'),
#   OptimizationRecord(id='19039772', status='COMPLETE'),
#   OptimizationRecord(id='19039773', status='COMPLETE'),
#   OptimizationRecord(id='19039774', status='COMPLETE'),
#   OptimizationRecord(id='19039775', status='COMPLETE'),
#   OptimizationRecord(id='19039776', status='COMPLETE'),
#   OptimizationRecord(id='19039777', status='COMPLETE'),
#   OptimizationRecord(id='19039778', status='COMPLETE'),
#   OptimizationRecord(id='19039779', status='COMPLETE'),
#   OptimizationRecord(id='19039780', status='COMPLETE'),
#   OptimizationRecord(id='19039781', status='COMPLETE'),
#   OptimizationRecord(id='19039782', status='COMPLETE'),
#   OptimizationRecord(id='19039783', status='COMPLETE'),
#   OptimizationRecord(id='19039784', status='COMPLETE'),
#   OptimizationRecord(id='19039785', status='COMPLETE'),
#   OptimizationRecord(id='19039786', status='COMPLETE'),
#   OptimizationRecord(id='19039787', status='COMPLETE'),
#   OptimizationRecord(id='19039788', status='COMPLETE'),
#   OptimizationRecord(id='19039789', status='COMPLETE'),
#   OptimizationRecord(id='19039790', status='COMPLETE'),
#   OptimizationRecord(id='19039791', status='COMPLETE'),
#   OptimizationRecord(id='19039792', status='COMPLETE'),
#   OptimizationRecord(id='19039793', status='COMPLETE'),
#   OptimizationRecord(id='19039794', status='COMPLETE'),
#   OptimizationRecord(id='19039795', status='COMPLETE'),
#   OptimizationRecord(id='19039796', status='COMPLETE'),
#   OptimizationRecord(id='19039797', status='COMPLETE'),
#   OptimizationRecord(id='19039798', status='COMPLETE'),
#   OptimizationRecord(id='19039799', status='COMPLETE'),
#   OptimizationRecord(id='19039800', status='COMPLETE'),
#   OptimizationRecord(id='19039801', status='COMPLETE'),
#   OptimizationRecord(id='19039802', status='COMPLETE'),
#   OptimizationRecord(id='19039803', status='COMPLETE'),
#   OptimizationRecord(id='19039804', status='COMPLETE'),
#   OptimizationRecord(id='19039805', status='COMPLETE'),
#   OptimizationRecord(id='19039806', status='COMPLETE'),
#   OptimizationRecord(id='19039807', status='COMPLETE'),
#   OptimizationRecord(id='19039808', status='COMPLETE'),
#   OptimizationRecord(id='19039809', status='COMPLETE'),
#   OptimizationRecord(id='19039810', status='COMPLETE'),
#   OptimizationRecord(id='19039811', status='COMPLETE'),
#   OptimizationRecord(id='19039812', status='COMPLETE'),
#   OptimizationRecord(id='19039813', status='COMPLETE'),
#   OptimizationRecord(id='19039814', status='COMPLETE'),
#   OptimizationRecord(id='19039815', status='COMPLETE'),
#   OptimizationRecord(id='19039816', status='COMPLETE'),
#   OptimizationRecord(id='19039817', status='COMPLETE'),
#   OptimizationRecord(id='19039818', status='COMPLETE'),
#   OptimizationRecord(id='19039819', status='COMPLETE'),
#   OptimizationRecord(id='19039820', status='COMPLETE'),
#   OptimizationRecord(id='19039821', status='COMPLETE'),
#   OptimizationRecord(id='19039822', status='COMPLETE'),
#   OptimizationRecord(id='19039823', status='COMPLETE'),
#   OptimizationRecord(id='19039824', status='COMPLETE'),
#   OptimizationRecord(id='19039825', status='COMPLETE'),
#   OptimizationRecord(id='19039826', status='COMPLETE'),
#   OptimizationRecord(id='19039827', status='COMPLETE'),
#   OptimizationRecord(id='19039828', status='COMPLETE'),
#   OptimizationRecord(id='19039829', status='COMPLETE'),
#   OptimizationRecord(id='19039830', status='COMPLETE'),
#   OptimizationRecord(id='19039831', status='COMPLETE'),
#   OptimizationRecord(id='19039832', status='COMPLETE'),
#   OptimizationRecord(id='19039833', status='COMPLETE'),
#   OptimizationRecord(id='19039834', status='COMPLETE'),
#   OptimizationRecord(id='19039835', status='COMPLETE'),
#   OptimizationRecord(id='19039836', status='COMPLETE'),
#   OptimizationRecord(id='19039837', status='COMPLETE'),
#   OptimizationRecord(id='19039838', status='COMPLETE'),
#   OptimizationRecord(id='19039839', status='COMPLETE'),
#   OptimizationRecord(id='19039840', status='COMPLETE'),
#   OptimizationRecord(id='19039841', status='COMPLETE'),
#   OptimizationRecord(id='19039842', status='COMPLETE'),
#   OptimizationRecord(id='19039843', status='COMPLETE'),
#   OptimizationRecord(id='19039844', status='COMPLETE'),
#   OptimizationRecord(id='19039845', status='COMPLETE'),
#   OptimizationRecord(id='19039846', status='COMPLETE'),
#   OptimizationRecord(id='19056846', status='COMPLETE'),
#   OptimizationRecord(id='19056847', status='COMPLETE'),
#   OptimizationRecord(id='19056848', status='COMPLETE'),
#   OptimizationRecord(id='19056849', status='COMPLETE'),
#   OptimizationRecord(id='19056850', status='COMPLETE'),
#   OptimizationRecord(id='19056851', status='COMPLETE'),
#   OptimizationRecord(id='19056852', status='COMPLETE'),
#   OptimizationRecord(id='19056853', status='COMPLETE'),
#   OptimizationRecord(id='19056854', status='COMPLETE'),
#   OptimizationRecord(id='19056855', status='COMPLETE'),
#   OptimizationRecord(id='19071971', status='COMPLETE'),
#   OptimizationRecord(id='19071972', status='COMPLETE'),
#   OptimizationRecord(id='19071973', status='COMPLETE'),
#   OptimizationRecord(id='19071974', status='COMPLETE'),
#   OptimizationRecord(id='19071975', status='COMPLETE'),
#   OptimizationRecord(id='19071976', status='COMPLETE'),
#   OptimizationRecord(id='19071977', status='COMPLETE'),
#   OptimizationRecord(id='19071978', status='COMPLETE'),
#   OptimizationRecord(id='19071979', status='COMPLETE'),
#   OptimizationRecord(id='19071980', status='COMPLETE'),
#   OptimizationRecord(id='19071981', status='COMPLETE'),
#   OptimizationRecord(id='19071982', status='COMPLETE'),
#   OptimizationRecord(id='19256344', status='COMPLETE'),
#   OptimizationRecord(id='19256345', status='COMPLETE'),
#   OptimizationRecord(id='19256346', status='COMPLETE'),
#   OptimizationRecord(id='19256347', status='COMPLETE'),
#   OptimizationRecord(id='19256348', status='COMPLETE'),
#   OptimizationRecord(id='19256349', status='COMPLETE'),
#   OptimizationRecord(id='19256350', status='COMPLETE'),
#   OptimizationRecord(id='19256351', status='COMPLETE'),
#   OptimizationRecord(id='19256352', status='COMPLETE'),
#   OptimizationRecord(id='19256353', status='COMPLETE'),
#   OptimizationRecord(id='19256354', status='COMPLETE'),
#   OptimizationRecord(id='19256355', status='COMPLETE'),
#   OptimizationRecord(id='19269409', status='COMPLETE'),
#   OptimizationRecord(id='19269410', status='COMPLETE'),
#   OptimizationRecord(id='19269411', status='COMPLETE'),
#   OptimizationRecord(id='19269412', status='COMPLETE'),
#   OptimizationRecord(id='19269413', status='COMPLETE'),
#   OptimizationRecord(id='19269414', status='COMPLETE'),
#   OptimizationRecord(id='19269415', status='COMPLETE'),
#   OptimizationRecord(id='19269416', status='COMPLETE'),
#   OptimizationRecord(id='19285307', status='COMPLETE'),
#   OptimizationRecord(id='19285308', status='COMPLETE'),
#   OptimizationRecord(id='19285309', status='COMPLETE'),
#   OptimizationRecord(id='19285310', status='COMPLETE'),
#   OptimizationRecord(id='19285311', status='COMPLETE'),
#   OptimizationRecord(id='19285312', status='COMPLETE'),
#   OptimizationRecord(id='19285313', status='COMPLETE'),
#   OptimizationRecord(id='19285314', status='COMPLETE'),
#   OptimizationRecord(id='19285315', status='COMPLETE'),
#   OptimizationRecord(id='19285316', status='COMPLETE'),
#   OptimizationRecord(id='19285317', status='COMPLETE'),
#   OptimizationRecord(id='19285318', status='COMPLETE'),
#   OptimizationRecord(id='19314977', status='COMPLETE'),
#   OptimizationRecord(id='19314978', status='COMPLETE'),
#   OptimizationRecord(id='19314979', status='COMPLETE'),
#   OptimizationRecord(id='19314980', status='COMPLETE'),
#   OptimizationRecord(id='19314981', status='COMPLETE'),
#   OptimizationRecord(id='19314982', status='COMPLETE'),
#   OptimizationRecord(id='19314983', status='COMPLETE'),
#   OptimizationRecord(id='19314984', status='COMPLETE'),
#   OptimizationRecord(id='19314985', status='COMPLETE'),
#   OptimizationRecord(id='19314986', status='COMPLETE'),
#   OptimizationRecord(id='19342693', status='COMPLETE'),
#   OptimizationRecord(id='19342694', status='COMPLETE'),
#   OptimizationRecord(id='19342695', status='COMPLETE'),
#   OptimizationRecord(id='19342696', status='COMPLETE'),
#   OptimizationRecord(id='19342697', status='COMPLETE'),
#   OptimizationRecord(id='19342698', status='COMPLETE'),
#   OptimizationRecord(id='19342699', status='COMPLETE'),
#   OptimizationRecord(id='19342700', status='COMPLETE'),
#   OptimizationRecord(id='19342701', status='COMPLETE'),
#   OptimizationRecord(id='19342702', status='COMPLETE'),
#   OptimizationRecord(id='19342703', status='COMPLETE'),
#   OptimizationRecord(id='19342704', status='COMPLETE'),
#   OptimizationRecord(id='19342705', status='COMPLETE'),
#   OptimizationRecord(id='19342706', status='COMPLETE'),
#   OptimizationRecord(id='19360505', status='COMPLETE'),
#   OptimizationRecord(id='19360506', status='COMPLETE'),
#   OptimizationRecord(id='19360507', status='COMPLETE'),
#   OptimizationRecord(id='19360508', status='COMPLETE'),
#   OptimizationRecord(id='19360509', status='COMPLETE'),
#   OptimizationRecord(id='19360510', status='COMPLETE'),
#   OptimizationRecord(id='19375418', status='COMPLETE'),
#   OptimizationRecord(id='19375419', status='COMPLETE'),
#   OptimizationRecord(id='19375420', status='COMPLETE'),
#   OptimizationRecord(id='19375421', status='COMPLETE'),
#   OptimizationRecord(id='19375422', status='COMPLETE'),
#   OptimizationRecord(id='19375423', status='COMPLETE'),
#   OptimizationRecord(id='19387214', status='COMPLETE'),
#   OptimizationRecord(id='19387215', status='COMPLETE'),
#   OptimizationRecord(id='19387216', status='COMPLETE'),
#   OptimizationRecord(id='19387217', status='COMPLETE'),
#   OptimizationRecord(id='19430102', status='COMPLETE'),
#   OptimizationRecord(id='19430103', status='ERROR'),
#   OptimizationRecord(id='19430104', status='ERROR'),
#   OptimizationRecord(id='19430105', status='ERROR')],
#  '18886355': [OptimizationRecord(id='19040042', status='COMPLETE'),
#   OptimizationRecord(id='19040043', status='COMPLETE'),
#   OptimizationRecord(id='19040044', status='COMPLETE'),
#   OptimizationRecord(id='19040045', status='COMPLETE'),
#   OptimizationRecord(id='19040046', status='COMPLETE'),
#   OptimizationRecord(id='19040047', status='COMPLETE'),
#   OptimizationRecord(id='19040048', status='COMPLETE'),
#   OptimizationRecord(id='19040049', status='COMPLETE'),
#   OptimizationRecord(id='19040050', status='COMPLETE'),
#   OptimizationRecord(id='19040051', status='COMPLETE'),
#   OptimizationRecord(id='19040052', status='COMPLETE'),
#   OptimizationRecord(id='19040053', status='COMPLETE'),
#   OptimizationRecord(id='19040054', status='COMPLETE'),
#   OptimizationRecord(id='19040055', status='COMPLETE'),
#   OptimizationRecord(id='19040056', status='COMPLETE'),
#   OptimizationRecord(id='19040057', status='COMPLETE'),
#   OptimizationRecord(id='19040058', status='COMPLETE'),
#   OptimizationRecord(id='19040059', status='COMPLETE'),
#   OptimizationRecord(id='19040060', status='COMPLETE'),
#   OptimizationRecord(id='19040061', status='COMPLETE'),
#   OptimizationRecord(id='19040062', status='COMPLETE'),
#   OptimizationRecord(id='19040063', status='COMPLETE'),
#   OptimizationRecord(id='19040064', status='COMPLETE'),
#   OptimizationRecord(id='19040065', status='COMPLETE'),
#   OptimizationRecord(id='19040066', status='COMPLETE'),
#   OptimizationRecord(id='19040067', status='COMPLETE'),
#   OptimizationRecord(id='19040068', status='COMPLETE'),
#   OptimizationRecord(id='19040069', status='COMPLETE'),
#   OptimizationRecord(id='19040070', status='COMPLETE'),
#   OptimizationRecord(id='19040071', status='COMPLETE'),
#   OptimizationRecord(id='19040072', status='COMPLETE'),
#   OptimizationRecord(id='19040073', status='COMPLETE'),
#   OptimizationRecord(id='19040074', status='COMPLETE'),
#   OptimizationRecord(id='19040075', status='COMPLETE'),
#   OptimizationRecord(id='19040076', status='COMPLETE'),
#   OptimizationRecord(id='19040077', status='COMPLETE'),
#   OptimizationRecord(id='19040078', status='COMPLETE'),
#   OptimizationRecord(id='19040079', status='COMPLETE'),
#   OptimizationRecord(id='19040080', status='COMPLETE'),
#   OptimizationRecord(id='19040081', status='COMPLETE'),
#   OptimizationRecord(id='19040082', status='COMPLETE'),
#   OptimizationRecord(id='19040083', status='COMPLETE'),
#   OptimizationRecord(id='19040084', status='COMPLETE'),
#   OptimizationRecord(id='19040085', status='COMPLETE'),
#   OptimizationRecord(id='19040086', status='COMPLETE'),
#   OptimizationRecord(id='19040087', status='COMPLETE'),
#   OptimizationRecord(id='19040088', status='COMPLETE'),
#   OptimizationRecord(id='19040089', status='COMPLETE'),
#   OptimizationRecord(id='19040090', status='COMPLETE'),
#   OptimizationRecord(id='19040091', status='COMPLETE'),
#   OptimizationRecord(id='19040092', status='COMPLETE'),
#   OptimizationRecord(id='19040093', status='COMPLETE'),
#   OptimizationRecord(id='19040094', status='COMPLETE'),
#   OptimizationRecord(id='19040095', status='COMPLETE'),
#   OptimizationRecord(id='19040096', status='COMPLETE'),
#   OptimizationRecord(id='19040097', status='COMPLETE'),
#   OptimizationRecord(id='19040098', status='COMPLETE'),
#   OptimizationRecord(id='19040099', status='COMPLETE'),
#   OptimizationRecord(id='19040100', status='COMPLETE'),
#   OptimizationRecord(id='19040101', status='COMPLETE'),
#   OptimizationRecord(id='19040102', status='COMPLETE'),
#   OptimizationRecord(id='19040103', status='COMPLETE'),
#   OptimizationRecord(id='19040104', status='COMPLETE'),
#   OptimizationRecord(id='19040105', status='COMPLETE'),
#   OptimizationRecord(id='19040106', status='COMPLETE'),
#   OptimizationRecord(id='19040107', status='COMPLETE'),
#   OptimizationRecord(id='19040108', status='COMPLETE'),
#   OptimizationRecord(id='19040109', status='COMPLETE'),
#   OptimizationRecord(id='19040110', status='COMPLETE'),
#   OptimizationRecord(id='19040111', status='COMPLETE'),
#   OptimizationRecord(id='19040112', status='COMPLETE'),
#   OptimizationRecord(id='19040113', status='COMPLETE'),
#   OptimizationRecord(id='19040114', status='COMPLETE'),
#   OptimizationRecord(id='19040115', status='COMPLETE'),
#   OptimizationRecord(id='19040116', status='COMPLETE'),
#   OptimizationRecord(id='19040117', status='COMPLETE'),
#   OptimizationRecord(id='19040118', status='COMPLETE'),
#   OptimizationRecord(id='19040119', status='COMPLETE'),
#   OptimizationRecord(id='19040120', status='COMPLETE'),
#   OptimizationRecord(id='19040121', status='COMPLETE'),
#   OptimizationRecord(id='19040122', status='COMPLETE'),
#   OptimizationRecord(id='19040123', status='COMPLETE'),
#   OptimizationRecord(id='19040124', status='COMPLETE'),
#   OptimizationRecord(id='19040125', status='COMPLETE'),
#   OptimizationRecord(id='19040126', status='COMPLETE'),
#   OptimizationRecord(id='19040127', status='COMPLETE'),
#   OptimizationRecord(id='19040128', status='COMPLETE'),
#   OptimizationRecord(id='19040129', status='COMPLETE'),
#   OptimizationRecord(id='19040154', status='COMPLETE'),
#   OptimizationRecord(id='19040159', status='COMPLETE'),
#   OptimizationRecord(id='19040160', status='COMPLETE'),
#   OptimizationRecord(id='19040161', status='COMPLETE'),
#   OptimizationRecord(id='19040162', status='COMPLETE'),
#   OptimizationRecord(id='19040163', status='COMPLETE'),
#   OptimizationRecord(id='19040164', status='COMPLETE'),
#   OptimizationRecord(id='19040165', status='COMPLETE'),
#   OptimizationRecord(id='19040166', status='COMPLETE'),
#   OptimizationRecord(id='19040167', status='COMPLETE'),
#   OptimizationRecord(id='19040168', status='COMPLETE'),
#   OptimizationRecord(id='19040169', status='COMPLETE'),
#   OptimizationRecord(id='19040170', status='COMPLETE'),
#   OptimizationRecord(id='19040171', status='COMPLETE'),
#   OptimizationRecord(id='19040172', status='COMPLETE'),
#   OptimizationRecord(id='19040173', status='COMPLETE'),
#   OptimizationRecord(id='19040174', status='COMPLETE'),
#   OptimizationRecord(id='19040175', status='COMPLETE'),
#   OptimizationRecord(id='19040176', status='COMPLETE'),
#   OptimizationRecord(id='19040177', status='COMPLETE'),
#   OptimizationRecord(id='19040178', status='COMPLETE'),
#   OptimizationRecord(id='19040179', status='COMPLETE'),
#   OptimizationRecord(id='19040180', status='COMPLETE'),
#   OptimizationRecord(id='19040181', status='COMPLETE'),
#   OptimizationRecord(id='19040182', status='COMPLETE'),
#   OptimizationRecord(id='19040183', status='COMPLETE'),
#   OptimizationRecord(id='19040184', status='COMPLETE'),
#   OptimizationRecord(id='19040185', status='COMPLETE'),
#   OptimizationRecord(id='19040186', status='COMPLETE'),
#   OptimizationRecord(id='19040187', status='COMPLETE'),
#   OptimizationRecord(id='19061049', status='COMPLETE'),
#   OptimizationRecord(id='19061050', status='COMPLETE'),
#   OptimizationRecord(id='19061051', status='COMPLETE'),
#   OptimizationRecord(id='19061052', status='COMPLETE'),
#   OptimizationRecord(id='19061053', status='COMPLETE'),
#   OptimizationRecord(id='19061054', status='COMPLETE'),
#   OptimizationRecord(id='19061055', status='COMPLETE'),
#   OptimizationRecord(id='19061056', status='COMPLETE'),
#   OptimizationRecord(id='19061057', status='COMPLETE'),
#   OptimizationRecord(id='19061058', status='COMPLETE'),
#   OptimizationRecord(id='19061059', status='COMPLETE'),
#   OptimizationRecord(id='19061060', status='COMPLETE'),
#   OptimizationRecord(id='19074331', status='COMPLETE'),
#   OptimizationRecord(id='19074332', status='ERROR'),
#   OptimizationRecord(id='19074333', status='COMPLETE'),
#   OptimizationRecord(id='19074334', status='COMPLETE'),
#   OptimizationRecord(id='19074335', status='COMPLETE'),
#   OptimizationRecord(id='19074336', status='COMPLETE'),
#   OptimizationRecord(id='19074337', status='COMPLETE'),
#   OptimizationRecord(id='19074338', status='COMPLETE'),
#   OptimizationRecord(id='19074339', status='COMPLETE'),
#   OptimizationRecord(id='19074340', status='COMPLETE'),
#   OptimizationRecord(id='19074341', status='COMPLETE'),
#   OptimizationRecord(id='19074342', status='COMPLETE'),
#   OptimizationRecord(id='19074343', status='COMPLETE'),
#   OptimizationRecord(id='19074344', status='COMPLETE'),
#   OptimizationRecord(id='19074345', status='COMPLETE'),
#   OptimizationRecord(id='19074346', status='COMPLETE'),
#   OptimizationRecord(id='19074347', status='COMPLETE'),
#   OptimizationRecord(id='19074348', status='COMPLETE')],
#  '18886362': [OptimizationRecord(id='19044362', status='COMPLETE'),
#   OptimizationRecord(id='19044363', status='COMPLETE'),
#   OptimizationRecord(id='19044364', status='COMPLETE'),
#   OptimizationRecord(id='19044365', status='COMPLETE'),
#   OptimizationRecord(id='19044366', status='COMPLETE'),
#   OptimizationRecord(id='19044367', status='COMPLETE'),
#   OptimizationRecord(id='19044368', status='COMPLETE'),
#   OptimizationRecord(id='19062903', status='COMPLETE'),
#   OptimizationRecord(id='19062904', status='COMPLETE'),
#   OptimizationRecord(id='19074474', status='COMPLETE'),
#   OptimizationRecord(id='19074475', status='COMPLETE'),
#   OptimizationRecord(id='19074476', status='COMPLETE'),
#   OptimizationRecord(id='19074477', status='COMPLETE'),
#   OptimizationRecord(id='19435537', status='COMPLETE'),
#   OptimizationRecord(id='19435538', status='COMPLETE'),
#   OptimizationRecord(id='19435539', status='COMPLETE'),
#   OptimizationRecord(id='19435540', status='COMPLETE'),
#   OptimizationRecord(id='19435541', status='COMPLETE'),
#   OptimizationRecord(id='19435542', status='COMPLETE'),
#   OptimizationRecord(id='19442926', status='COMPLETE'),
#   OptimizationRecord(id='19442927', status='COMPLETE'),
#   OptimizationRecord(id='19442928', status='COMPLETE'),
#   OptimizationRecord(id='19442929', status='COMPLETE'),
#   OptimizationRecord(id='19498584', status='COMPLETE'),
#   OptimizationRecord(id='19498585', status='INCOMPLETE'),
#   OptimizationRecord(id='19498586', status='COMPLETE'),
#   OptimizationRecord(id='19498587', status='COMPLETE')],
#  '18886376': [OptimizationRecord(id='19050243', status='COMPLETE'),
#   OptimizationRecord(id='19050244', status='COMPLETE'),
#   OptimizationRecord(id='19050245', status='COMPLETE'),
#   OptimizationRecord(id='19050246', status='COMPLETE'),
#   OptimizationRecord(id='19050247', status='COMPLETE'),
#   OptimizationRecord(id='19050248', status='COMPLETE'),
#   OptimizationRecord(id='19050249', status='COMPLETE'),
#   OptimizationRecord(id='19050250', status='COMPLETE'),
#   OptimizationRecord(id='19050251', status='COMPLETE'),
#   OptimizationRecord(id='19050252', status='COMPLETE'),
#   OptimizationRecord(id='19050253', status='COMPLETE'),
#   OptimizationRecord(id='19050254', status='COMPLETE'),
#   OptimizationRecord(id='19050255', status='COMPLETE'),
#   OptimizationRecord(id='19050256', status='COMPLETE'),
#   OptimizationRecord(id='19050257', status='COMPLETE'),
#   OptimizationRecord(id='19050258', status='COMPLETE'),
#   OptimizationRecord(id='19074061', status='COMPLETE'),
#   OptimizationRecord(id='19074062', status='COMPLETE'),
#   OptimizationRecord(id='19074063', status='COMPLETE'),
#   OptimizationRecord(id='19074064', status='COMPLETE'),
#   OptimizationRecord(id='19436952', status='COMPLETE'),
#   OptimizationRecord(id='19436953', status='COMPLETE'),
#   OptimizationRecord(id='19436954', status='COMPLETE'),
#   OptimizationRecord(id='19436955', status='COMPLETE'),
#   OptimizationRecord(id='19436956', status='COMPLETE'),
#   OptimizationRecord(id='19436957', status='COMPLETE'),
#   OptimizationRecord(id='19436958', status='COMPLETE'),
#   OptimizationRecord(id='19436959', status='COMPLETE')],
#  '18886384': [OptimizationRecord(id='19067822', status='COMPLETE'),
#   OptimizationRecord(id='19067823', status='COMPLETE'),
#   OptimizationRecord(id='19067824', status='COMPLETE'),
#   OptimizationRecord(id='19067825', status='COMPLETE'),
#   OptimizationRecord(id='19067826', status='COMPLETE'),
#   OptimizationRecord(id='19067827', status='COMPLETE'),
#   OptimizationRecord(id='19067828', status='COMPLETE'),
#   OptimizationRecord(id='19067829', status='COMPLETE'),
#   OptimizationRecord(id='19067830', status='COMPLETE'),
#   OptimizationRecord(id='19067831', status='COMPLETE'),
#   OptimizationRecord(id='19067832', status='COMPLETE'),
#   OptimizationRecord(id='19067833', status='COMPLETE'),
#   OptimizationRecord(id='19067834', status='COMPLETE'),
#   OptimizationRecord(id='19067835', status='COMPLETE'),
#   OptimizationRecord(id='19067836', status='COMPLETE'),
#   OptimizationRecord(id='19067837', status='COMPLETE'),
#   OptimizationRecord(id='19067838', status='COMPLETE'),
#   OptimizationRecord(id='19067839', status='COMPLETE'),
#   OptimizationRecord(id='19067840', status='COMPLETE'),
#   OptimizationRecord(id='19067841', status='COMPLETE'),
#   OptimizationRecord(id='19067842', status='COMPLETE'),
#   OptimizationRecord(id='19067843', status='COMPLETE'),
#   OptimizationRecord(id='19067844', status='COMPLETE'),
#   OptimizationRecord(id='19067845', status='COMPLETE'),
#   OptimizationRecord(id='19067846', status='COMPLETE'),
#   OptimizationRecord(id='19067847', status='COMPLETE'),
#   OptimizationRecord(id='19067848', status='COMPLETE'),
#   OptimizationRecord(id='19067849', status='COMPLETE'),
#   OptimizationRecord(id='19067850', status='COMPLETE'),
#   OptimizationRecord(id='19067851', status='COMPLETE'),
#   OptimizationRecord(id='19067852', status='ERROR'),
#   OptimizationRecord(id='19067853', status='COMPLETE'),
#   OptimizationRecord(id='19067854', status='COMPLETE'),
#   OptimizationRecord(id='19067855', status='COMPLETE'),
#   OptimizationRecord(id='19067856', status='COMPLETE'),
#   OptimizationRecord(id='19067857', status='COMPLETE'),
#   OptimizationRecord(id='19067858', status='COMPLETE'),
#   OptimizationRecord(id='19067859', status='COMPLETE'),
#   OptimizationRecord(id='19067860', status='COMPLETE'),
#   OptimizationRecord(id='19067861', status='COMPLETE'),
# ...
#   OptimizationRecord(id='19234292', status='COMPLETE'),
#   OptimizationRecord(id='19234293', status='COMPLETE'),
#   OptimizationRecord(id='19234294', status='COMPLETE'),
#   OptimizationRecord(id='19234295', status='COMPLETE'),
#   OptimizationRecord(id='19234296', status='COMPLETE'),
#   OptimizationRecord(id='19234297', status='COMPLETE'),
#   OptimizationRecord(id='19234298', status='COMPLETE'),
#   OptimizationRecord(id='19234299', status='COMPLETE'),
#   OptimizationRecord(id='19234300', status='COMPLETE'),
#   OptimizationRecord(id='19234301', status='COMPLETE'),
#   OptimizationRecord(id='19234302', status='COMPLETE'),
#   OptimizationRecord(id='19234303', status='COMPLETE'),
#   OptimizationRecord(id='19234304', status='COMPLETE'),
#   OptimizationRecord(id='19234305', status='COMPLETE'),
#   OptimizationRecord(id='19254779', status='COMPLETE'),
#   OptimizationRecord(id='19254780', status='COMPLETE'),
#   OptimizationRecord(id='19254781', status='COMPLETE'),
#   OptimizationRecord(id='19254782', status='COMPLETE'),
#   OptimizationRecord(id='19254783', status='COMPLETE'),
#   OptimizationRecord(id='19254784', status='COMPLETE'),
#   OptimizationRecord(id='19254785', status='COMPLETE'),
#   OptimizationRecord(id='19254786', status='COMPLETE'),
#   OptimizationRecord(id='19254787', status='COMPLETE'),
#   OptimizationRecord(id='19254788', status='COMPLETE'),
#   OptimizationRecord(id='19254789', status='COMPLETE'),
#   OptimizationRecord(id='19254790', status='COMPLETE'),
#   OptimizationRecord(id='19254791', status='COMPLETE'),
#   OptimizationRecord(id='19254792', status='COMPLETE'),
#   OptimizationRecord(id='19254793', status='COMPLETE'),
#   OptimizationRecord(id='19254794', status='COMPLETE'),
#   OptimizationRecord(id='19254795', status='COMPLETE'),
#   OptimizationRecord(id='19254796', status='COMPLETE'),
#   OptimizationRecord(id='19254797', status='COMPLETE'),
#   OptimizationRecord(id='19254798', status='COMPLETE'),
#   OptimizationRecord(id='19254799', status='COMPLETE'),
#   OptimizationRecord(id='19254800', status='COMPLETE'),
#   OptimizationRecord(id='19254801', status='COMPLETE'),
#   OptimizationRecord(id='19254802', status='COMPLETE'),
#   OptimizationRecord(id='19275229', status='COMPLETE'),
#   OptimizationRecord(id='19275230', status='COMPLETE'),
#   OptimizationRecord(id='19275231', status='COMPLETE'),
#   OptimizationRecord(id='19275232', status='COMPLETE'),
#   OptimizationRecord(id='19275233', status='COMPLETE'),
#   OptimizationRecord(id='19275234', status='COMPLETE'),
#   OptimizationRecord(id='19275235', status='COMPLETE'),
#   OptimizationRecord(id='19275236', status='COMPLETE'),
#   OptimizationRecord(id='19275237', status='COMPLETE'),
#   OptimizationRecord(id='19275238', status='COMPLETE'),
#   OptimizationRecord(id='19275239', status='COMPLETE'),
#   OptimizationRecord(id='19275240', status='COMPLETE'),
#   OptimizationRecord(id='19275241', status='COMPLETE'),
#   OptimizationRecord(id='19275242', status='COMPLETE'),
#   OptimizationRecord(id='19275243', status='COMPLETE'),
#   OptimizationRecord(id='19275244', status='COMPLETE'),
#   OptimizationRecord(id='19275245', status='COMPLETE'),
#   OptimizationRecord(id='19275246', status='COMPLETE'),
#   OptimizationRecord(id='19275247', status='COMPLETE'),
#   OptimizationRecord(id='19275248', status='COMPLETE'),
#   OptimizationRecord(id='19294856', status='COMPLETE'),
#   OptimizationRecord(id='19294857', status='COMPLETE'),
#   OptimizationRecord(id='19294858', status='COMPLETE'),
#   OptimizationRecord(id='19294859', status='COMPLETE'),
#   OptimizationRecord(id='19294860', status='COMPLETE'),
#   OptimizationRecord(id='19294861', status='COMPLETE'),
#   OptimizationRecord(id='19294862', status='COMPLETE'),
#   OptimizationRecord(id='19294863', status='COMPLETE'),
#   OptimizationRecord(id='19294864', status='COMPLETE'),
#   OptimizationRecord(id='19294865', status='COMPLETE'),
#   OptimizationRecord(id='19294866', status='COMPLETE'),
#   OptimizationRecord(id='19294867', status='COMPLETE'),
#   OptimizationRecord(id='19294868', status='COMPLETE'),
#   OptimizationRecord(id='19294869', status='COMPLETE'),
#   OptimizationRecord(id='19325906', status='COMPLETE'),
#   OptimizationRecord(id='19325907', status='COMPLETE'),
#   OptimizationRecord(id='19325908', status='COMPLETE'),
#   OptimizationRecord(id='19325909', status='COMPLETE'),
#   OptimizationRecord(id='19325910', status='COMPLETE'),
#   OptimizationRecord(id='19325911', status='COMPLETE'),
#   OptimizationRecord(id='19325912', status='COMPLETE'),
#   OptimizationRecord(id='19325913', status='COMPLETE'),
#   OptimizationRecord(id='19349673', status='COMPLETE'),
#   OptimizationRecord(id='19349674', status='COMPLETE'),
#   OptimizationRecord(id='19349675', status='COMPLETE'),
#   OptimizationRecord(id='19349676', status='COMPLETE'),
#   OptimizationRecord(id='19349677', status='COMPLETE'),
#   OptimizationRecord(id='19349678', status='COMPLETE'),
#   OptimizationRecord(id='19366765', status='COMPLETE'),
#   OptimizationRecord(id='19366766', status='COMPLETE'),
#   OptimizationRecord(id='19366767', status='COMPLETE'),
#   OptimizationRecord(id='19366768', status='COMPLETE'),
#   OptimizationRecord(id='19366769', status='COMPLETE'),
#   OptimizationRecord(id='19366770', status='COMPLETE'),
#   OptimizationRecord(id='19366771', status='COMPLETE'),
#   OptimizationRecord(id='19366772', status='COMPLETE'),
#   OptimizationRecord(id='19375351', status='COMPLETE'),
#   OptimizationRecord(id='19375352', status='COMPLETE'),
#   OptimizationRecord(id='19375353', status='COMPLETE'),
#   OptimizationRecord(id='19375354', status='COMPLETE'),
#   OptimizationRecord(id='19375355', status='COMPLETE'),
#   OptimizationRecord(id='19375356', status='COMPLETE'),
#   OptimizationRecord(id='19375357', status='COMPLETE'),
#   OptimizationRecord(id='19375358', status='COMPLETE'),
#   OptimizationRecord(id='19383505', status='COMPLETE'),
#   OptimizationRecord(id='19383506', status='COMPLETE'),
#   OptimizationRecord(id='19383507', status='ERROR'),
#   OptimizationRecord(id='19383508', status='COMPLETE'),
#   OptimizationRecord(id='19383509', status='ERROR'),
#   OptimizationRecord(id='19383510', status='COMPLETE'),
#   OptimizationRecord(id='19383511', status='COMPLETE'),
#   OptimizationRecord(id='19383512', status='COMPLETE')],
#  '18886555': [OptimizationRecord(id='19193821', status='COMPLETE'),
#   OptimizationRecord(id='19193822', status='COMPLETE'),
#   OptimizationRecord(id='19193823', status='COMPLETE'),
#   OptimizationRecord(id='19193824', status='COMPLETE')],
#  '18886557': [OptimizationRecord(id='19194079', status='ERROR'),
#   OptimizationRecord(id='19194080', status='COMPLETE'),
#   OptimizationRecord(id='19194081', status='ERROR'),
#   OptimizationRecord(id='19194082', status='COMPLETE'),
#   OptimizationRecord(id='19194083', status='COMPLETE'),
#   OptimizationRecord(id='19194090', status='ERROR')],
#  '18886558': [OptimizationRecord(id='19194331', status='ERROR'),
#   OptimizationRecord(id='19194332', status='ERROR'),
#   OptimizationRecord(id='19194333', status='ERROR'),
#   OptimizationRecord(id='19194334', status='COMPLETE'),
#   OptimizationRecord(id='19194335', status='COMPLETE'),
#   OptimizationRecord(id='19194336', status='ERROR'),
#   OptimizationRecord(id='19194337', status='COMPLETE'),
#   OptimizationRecord(id='19194338', status='ERROR'),
#   OptimizationRecord(id='19194339', status='ERROR'),
#   OptimizationRecord(id='19194340', status='ERROR'),
#   OptimizationRecord(id='19194341', status='ERROR'),
#   OptimizationRecord(id='19194342', status='ERROR'),
#   OptimizationRecord(id='19194343', status='ERROR'),
#   OptimizationRecord(id='19194344', status='ERROR'),
#   OptimizationRecord(id='19194345', status='ERROR'),
#   OptimizationRecord(id='19194346', status='ERROR'),
#   OptimizationRecord(id='19194347', status='ERROR'),
#   OptimizationRecord(id='19194348', status='ERROR'),
#   OptimizationRecord(id='19194349', status='ERROR'),
#   OptimizationRecord(id='19194350', status='ERROR'),
#   OptimizationRecord(id='19194351', status='ERROR'),
#   OptimizationRecord(id='19194352', status='COMPLETE'),
#   OptimizationRecord(id='19194353', status='ERROR'),
#   OptimizationRecord(id='19194354', status='ERROR'),
#   OptimizationRecord(id='19194355', status='ERROR'),
#   OptimizationRecord(id='19194356', status='COMPLETE'),
#   OptimizationRecord(id='19194357', status='ERROR'),
#   OptimizationRecord(id='19194358', status='ERROR'),
#   OptimizationRecord(id='19194359', status='COMPLETE'),
#   OptimizationRecord(id='19194360', status='ERROR'),
#   OptimizationRecord(id='19194361', status='COMPLETE'),
#   OptimizationRecord(id='19194362', status='ERROR'),
#   OptimizationRecord(id='19194363', status='COMPLETE'),
#   OptimizationRecord(id='19194364', status='COMPLETE'),
#   OptimizationRecord(id='19194365', status='COMPLETE'),
#   OptimizationRecord(id='19194366', status='COMPLETE'),
#   OptimizationRecord(id='19194367', status='ERROR'),
#   OptimizationRecord(id='19194368', status='COMPLETE'),
#   OptimizationRecord(id='19194369', status='ERROR'),
#   OptimizationRecord(id='19194370', status='COMPLETE'),
#   OptimizationRecord(id='19194371', status='COMPLETE'),
#   OptimizationRecord(id='19194372', status='COMPLETE'),
#   OptimizationRecord(id='19194373', status='ERROR'),
#   OptimizationRecord(id='19194374', status='ERROR'),
#   OptimizationRecord(id='19194375', status='ERROR'),
#   OptimizationRecord(id='19194376', status='COMPLETE'),
#   OptimizationRecord(id='19194377', status='ERROR'),
#   OptimizationRecord(id='19194378', status='COMPLETE'),
#   OptimizationRecord(id='19194379', status='ERROR'),
#   OptimizationRecord(id='19194380', status='ERROR'),
#   OptimizationRecord(id='19194381', status='ERROR'),
#   OptimizationRecord(id='19194382', status='COMPLETE'),
#   OptimizationRecord(id='19194383', status='ERROR'),
#   OptimizationRecord(id='19194384', status='ERROR'),
#   OptimizationRecord(id='19194385', status='ERROR'),
#   OptimizationRecord(id='19194386', status='COMPLETE'),
#   OptimizationRecord(id='19194387', status='COMPLETE'),
#   OptimizationRecord(id='19194388', status='ERROR'),
#   OptimizationRecord(id='19194389', status='COMPLETE')],
#  '18886560': [OptimizationRecord(id='19195425', status='ERROR'),
#   OptimizationRecord(id='19195426', status='COMPLETE'),
#   OptimizationRecord(id='19195427', status='ERROR'),
#   OptimizationRecord(id='19195428', status='ERROR'),
#   OptimizationRecord(id='19195429', status='COMPLETE')],
#  '18886561': [OptimizationRecord(id='19195439', status='ERROR'),
#   OptimizationRecord(id='19195440', status='ERROR'),
#   OptimizationRecord(id='19195441', status='ERROR'),
#   OptimizationRecord(id='19195442', status='ERROR'),
#   OptimizationRecord(id='19195443', status='COMPLETE'),
#   OptimizationRecord(id='19195444', status='ERROR'),
#   OptimizationRecord(id='19195452', status='ERROR'),
#   OptimizationRecord(id='19195453', status='ERROR'),
#   OptimizationRecord(id='19195454', status='COMPLETE'),
#   OptimizationRecord(id='19195455', status='ERROR'),
#   OptimizationRecord(id='19195456', status='ERROR'),
#   OptimizationRecord(id='19195457', status='ERROR'),
#   OptimizationRecord(id='19195458', status='ERROR'),
#   OptimizationRecord(id='19195459', status='COMPLETE'),
#   OptimizationRecord(id='19195460', status='ERROR'),
#   OptimizationRecord(id='19195461', status='ERROR'),
#   OptimizationRecord(id='19195462', status='COMPLETE'),
#   OptimizationRecord(id='19195463', status='ERROR'),
#   OptimizationRecord(id='19195464', status='ERROR'),
#   OptimizationRecord(id='19195465', status='ERROR')],
#  '18886563': [OptimizationRecord(id='19195660', status='ERROR'),
#   OptimizationRecord(id='19195661', status='ERROR')],
#  '18886565': [OptimizationRecord(id='19197484', status='COMPLETE'),
#   OptimizationRecord(id='19197485', status='COMPLETE'),
#   OptimizationRecord(id='19197486', status='ERROR'),
#   OptimizationRecord(id='19197487', status='ERROR'),
#   OptimizationRecord(id='19197488', status='ERROR'),
#   OptimizationRecord(id='19197489', status='COMPLETE')],
#  '18886566': [OptimizationRecord(id='19207846', status='COMPLETE'),
#   OptimizationRecord(id='19207847', status='COMPLETE'),
#   OptimizationRecord(id='19207848', status='COMPLETE'),
#   OptimizationRecord(id='19207849', status='COMPLETE'),
#   OptimizationRecord(id='19207850', status='ERROR'),
#   OptimizationRecord(id='19207851', status='COMPLETE'),
#   OptimizationRecord(id='19207852', status='COMPLETE'),
#   OptimizationRecord(id='19207853', status='ERROR'),
#   OptimizationRecord(id='19207854', status='COMPLETE'),
#   OptimizationRecord(id='19207855', status='COMPLETE'),
#   OptimizationRecord(id='19207856', status='COMPLETE'),
#   OptimizationRecord(id='19207857', status='COMPLETE'),
#   OptimizationRecord(id='19207858', status='COMPLETE'),
#   OptimizationRecord(id='19207859', status='COMPLETE'),
#   OptimizationRecord(id='19207860', status='COMPLETE'),
#   OptimizationRecord(id='19207861', status='COMPLETE'),
#   OptimizationRecord(id='19207862', status='COMPLETE'),
#   OptimizationRecord(id='19207863', status='ERROR'),
#   OptimizationRecord(id='19207864', status='COMPLETE'),
#   OptimizationRecord(id='19207865', status='COMPLETE'),
#   OptimizationRecord(id='19207866', status='COMPLETE'),
#   OptimizationRecord(id='19207867', status='COMPLETE'),
#   OptimizationRecord(id='19207868', status='COMPLETE'),
#   OptimizationRecord(id='19207869', status='COMPLETE'),
#   OptimizationRecord(id='19207870', status='COMPLETE'),
#   OptimizationRecord(id='19207871', status='COMPLETE'),
#   OptimizationRecord(id='19207872', status='COMPLETE'),
#   OptimizationRecord(id='19207873', status='ERROR'),
#   OptimizationRecord(id='19207874', status='COMPLETE'),
#   OptimizationRecord(id='19207875', status='COMPLETE'),
#   OptimizationRecord(id='19207876', status='COMPLETE'),
#   OptimizationRecord(id='19207877', status='COMPLETE'),
#   OptimizationRecord(id='19207878', status='ERROR'),
#   OptimizationRecord(id='19207879', status='COMPLETE'),
#   OptimizationRecord(id='19207880', status='COMPLETE'),
#   OptimizationRecord(id='19207881', status='COMPLETE'),
#   OptimizationRecord(id='19207882', status='COMPLETE'),
#   OptimizationRecord(id='19207883', status='COMPLETE'),
#   OptimizationRecord(id='19207884', status='COMPLETE'),
#   OptimizationRecord(id='19207885', status='ERROR'),
#   OptimizationRecord(id='19207886', status='ERROR'),
#   OptimizationRecord(id='19207887', status='COMPLETE'),
#   OptimizationRecord(id='19207888', status='COMPLETE'),
#   OptimizationRecord(id='19207889', status='COMPLETE'),
#   OptimizationRecord(id='19207890', status='COMPLETE'),
#   OptimizationRecord(id='19207891', status='COMPLETE'),
#   OptimizationRecord(id='19207892', status='COMPLETE'),
#   OptimizationRecord(id='19207893', status='COMPLETE'),
#   OptimizationRecord(id='19207894', status='COMPLETE'),
#   OptimizationRecord(id='19207895', status='COMPLETE'),
#   OptimizationRecord(id='19207896', status='COMPLETE'),
#   OptimizationRecord(id='19207897', status='COMPLETE'),
#   OptimizationRecord(id='19207898', status='COMPLETE'),
#   OptimizationRecord(id='19207899', status='COMPLETE'),
#   OptimizationRecord(id='19207900', status='COMPLETE'),
#   OptimizationRecord(id='19207901', status='COMPLETE'),
#   OptimizationRecord(id='19207902', status='COMPLETE'),
#   OptimizationRecord(id='19207903', status='COMPLETE'),
#   OptimizationRecord(id='19207904', status='ERROR'),
#   OptimizationRecord(id='19207905', status='COMPLETE'),
#   OptimizationRecord(id='19207906', status='COMPLETE'),
#   OptimizationRecord(id='19207907', status='ERROR'),
#   OptimizationRecord(id='19207908', status='COMPLETE'),
#   OptimizationRecord(id='19207909', status='COMPLETE'),
#   OptimizationRecord(id='19207910', status='ERROR'),
#   OptimizationRecord(id='19207911', status='COMPLETE'),
#   OptimizationRecord(id='19207912', status='COMPLETE'),
#   OptimizationRecord(id='19207913', status='COMPLETE'),
#   OptimizationRecord(id='19207914', status='COMPLETE'),
#   OptimizationRecord(id='19207915', status='ERROR'),
#   OptimizationRecord(id='19207916', status='COMPLETE'),
#   OptimizationRecord(id='19207917', status='COMPLETE')],
#  '18886569': [OptimizationRecord(id='19208151', status='ERROR'),
#   OptimizationRecord(id='19208152', status='ERROR'),
#   OptimizationRecord(id='19208153', status='ERROR'),
#   OptimizationRecord(id='19208154', status='ERROR')]}

# %%
resm = merge(res)

# %%
incomplete = (opt.dict() for opt in resm if opt.status == 'INCOMPLETE')

# %%
next(incomplete)
# Out:
# {'id': '19498276',
#  'hash_index': '2331cf1bddf4bd3322091a3926ffa645c701f84c',
#  'procedure': 'optimization',
#  'program': 'geometric',
#  'version': 1,
#  'protocols': {},
#  'extras': {},
#  'stdout': '22680080',
#  'stderr': None,
#  'error': None,
#  'task_id': None,
#  'manager_name': None,
#  'status': <RecordStatusEnum.incomplete: 'INCOMPLETE'>,
#  'modified_on': datetime.datetime(2020, 4, 20, 1, 44, 27, 311114),
#  'created_on': datetime.datetime(2020, 4, 20, 1, 29, 59, 14937),
#  'provenance': {'creator': 'geomeTRIC',
#   'version': '0.9.7.2',
#   'routine': 'geometric.run_json.geometric_run_json',
#   'username': 'chodera',
#   'qcengine_version': '0.14.0',
#   'cpu': 'Intel(R) Xeon(R) CPU E5-2697 v4 @ 2.30GHz',
#   'hostname': 'ls04',
#   'wall_time': 438.6346173286438},
#  'schema_version': 1,
#  'initial_molecule': '13114262',
#  'qc_spec': {'driver': <DriverEnum.gradient: 'gradient'>,
#   'method': 'b3lyp-d3bj',
#   'basis': 'dzvp',
#   'keywords': '2',
#   'program': 'psi4'},
#  'keywords': {'coordsys': 'tric',
#   'enforce': 0.1,
#   'reset': True,
#   'qccnv': True,
#   'epsilon': 0,
#   'constraints': {'set': [{'type': 'dihedral',
#      'indices': [0, 5, 12, 33],
#      'value': 0}]},
#   'program': 'psi4'},
#  'energies': [-748.2713742793587,
#   -748.2713631403763,
#   -748.2713347902593,
#   -748.271252111364,
#   -748.2713580378326,
#   -748.2714639063247,
#   -748.2714916188927,
#   -748.2714956441314,
#   -748.27149594432],
#  'final_molecule': '13116222',
#  'trajectory': ['19496869',
#   '19498897',
#   '19498900',
#   '19498901',
#   '19498902',
#   '19498903',
#   '19498904',
#   '19498905',
#   '19498906']}

# %% [markdown]
# All Lilac INCOMPLETEs?

# %%
count_unique_optimization_error_messages(resm, full=True, pretty_print=True)
# Out:
# There are 15 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1293, in optimizeGeometry
#     self.calcEnergyForce()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1002, in calcEnergyForce
#     spcalc = self.engine.calc(self.X, self.dirname)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/engine.py", line 873, in calc
#     return self.calc_new(coords, dirname)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/engine.py", line 865, in calc_new
#     raise QCEngineAPIEngineError("QCEngineAPI computation did not execute correctly. Message: " + ret["error"]["error_message"])
# geometric.errors.QCEngineAPIEngineError: QCEngineAPI computation did not execute correctly. Message: QCEngine Unknown Error:
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1299, in optimizeGeometry
#     self.evaluateStep()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1277, in evaluateStep
#     Eig1 = np.linalg.eigh(self.H)[0]
#   File "<__array_function__ internals>", line 6, in eigh
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/numpy/linalg/linalg.py", line 1456, in eigh
#     w, vt = gufunc(a, signature=signature, extobj=extobj)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/numpy/linalg/linalg.py", line 103, in _raise_linalgerror_eigenvalues_nonconvergence
#     raise LinAlgError("Eigenvalues did not converge")
# numpy.linalg.LinAlgError: Eigenvalues did not converge
#
# -------------------------------------
#
# There are 8 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1298, in optimizeGeometry
#     self.calcEnergyForce()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1002, in calcEnergyForce
#     spcalc = self.engine.calc(self.X, self.dirname)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/engine.py", line 873, in calc
#     return self.calc_new(coords, dirname)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/engine.py", line 865, in calc_new
#     raise QCEngineAPIEngineError("QCEngineAPI computation did not execute correctly. Message: " + ret["error"]["error_message"])
# geometric.errors.QCEngineAPIEngineError: QCEngineAPI computation did not execute correctly. Message: QCEngine Unknown Error:
#
# -------------------------------------
#
# There are 50 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1296, in optimizeGeometry
#     self.step()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1100, in step
#     self.checkCoordinateSystem(recover=True, cartesian=LastForce)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 959, in checkCoordinateSystem
#     raise ValueError("Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates")
# ValueError: Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates
#
# -------------------------------------
#
# There are 4 instances of
# -------------------------------------
# Caught Executor Error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/qcfractal/queue/executor_adapter.py", line 15, in _get_future
#     return future.result()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/concurrent/futures/_base.py", line 425, in result
#     return self.__get_result()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
# concurrent.futures.process.BrokenProcessPool: A process in the process pool was terminated abruptly while the future was running or pending.
#
# -------------------------------------
#
# There are 7 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1296, in optimizeGeometry
#     self.step()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1085, in step
#     iopt = brent_wiki(froot.evaluate, 0.0, iopt, froot.target, cvg=0.1, verbose=params.verbose)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 187, in brent_wiki
#     raise RuntimeError('Not bracketed')
# RuntimeError: Not bracketed
#
# -------------------------------------
#
# There are 3 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1296, in optimizeGeometry
#     self.step()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1100, in step
#     self.checkCoordinateSystem(recover=True, cartesian=LastForce)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 959, in checkCoordinateSystem
#     raise ValueError("Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates")
# ValueError: Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates
#
# -------------------------------------
#
# There are 8 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib/python3.7/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib/python3.7/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib/python3.7/site-packages/geometric/optimize.py", line 1296, in optimizeGeometry
#     self.step()
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib/python3.7/site-packages/geometric/optimize.py", line 1100, in step
#     self.checkCoordinateSystem(recover=True, cartesian=LastForce)
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib/python3.7/site-packages/geometric/optimize.py", line 959, in checkCoordinateSystem
#     raise ValueError("Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates")
# ValueError: Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates
#
# -------------------------------------
#
# There are 2 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib/python3.7/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib/python3.7/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib/python3.7/site-packages/geometric/optimize.py", line 1298, in optimizeGeometry
#     self.calcEnergyForce()
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib/python3.7/site-packages/geometric/optimize.py", line 1002, in calcEnergyForce
#     spcalc = self.engine.calc(self.X, self.dirname)
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib/python3.7/site-packages/geometric/engine.py", line 873, in calc
#     return self.calc_new(coords, dirname)
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib/python3.7/site-packages/geometric/engine.py", line 865, in calc_new
#     raise QCEngineAPIEngineError("QCEngineAPI computation did not execute correctly. Message: " + ret["error"]["error_message"])
# geometric.errors.QCEngineAPIEngineError: QCEngineAPI computation did not execute correctly. Message: QCEngine Unknown Error: Traceback (most recent call last):
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib//python3.7/site-packages/psi4/driver/schema_wrapper.py", line 391, in run_qcschema
#     ret_data = run_json_qcschema(input_model.dict(), clean, False, keep_wfn=keep_wfn)
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib//python3.7/site-packages/psi4/driver/schema_wrapper.py", line 538, in run_json_qcschema
#     val, wfn = methods_dict_[json_data["driver"]](method, **kwargs)
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib//python3.7/site-packages/psi4/driver/driver.py", line 711, in gradient
#     wfn = procedures['gradient'][lowername](lowername, molecule=molecule, **kwargs)
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib//python3.7/site-packages/psi4/driver/procrouting/proc.py", line 2310, in run_scf_gradient
#     ref_wfn = run_scf(name, **kwargs)
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib//python3.7/site-packages/psi4/driver/procrouting/proc.py", line 2215, in run_scf
#     scf_wfn = scf_helper(name, post_scf=False, **kwargs)
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib//python3.7/site-packages/psi4/driver/procrouting/proc.py", line 1516, in scf_helper
#     e_scf = scf_wfn.compute_energy()
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib//python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 93, in scf_compute_energy
#     raise e
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib//python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 86, in scf_compute_energy
#     self.iterations()
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib//python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 464, in scf_iterate
#     raise SCFConvergenceError("""SCF iterations""", self.iteration_, self, Ediff, Dnorm)
# psi4.driver.p4util.exceptions.SCFConvergenceError: Could not converge SCF iterations in 200 iterations.
#
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# Caught Executor Error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/opt/lib/python3.7/site-packages/qcfractal-0.13.1+54.g3caa178.dirty-py3.7.egg/qcfractal/queue/executor_adapter.py", line 15, in _get_future
#     return future.result()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/distributed/client.py", line 218, in result
#     raise exc.with_traceback(tb)
# distributed.scheduler.KilledWorker: ('compute_procedure-e009c5ade982bb11251b8ded697dd42b', <Worker 'tcp://10.240.60.29:41109', name: 1799, memory: 0, processing: 10>)
#
# -------------------------------------
#
# There are 2 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1298, in optimizeGeometry
#     self.calcEnergyForce()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1002, in calcEnergyForce
#     spcalc = self.engine.calc(self.X, self.dirname)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/engine.py", line 873, in calc
#     return self.calc_new(coords, dirname)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/engine.py", line 865, in calc_new
#     raise QCEngineAPIEngineError("QCEngineAPI computation did not execute correctly. Message: " + ret["error"]["error_message"])
# geometric.errors.QCEngineAPIEngineError: QCEngineAPI computation did not execute correctly. Message: QCEngine Unknown Error: Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/json_wrapper.py", line 217, in run_json
#     json_data = run_json_qcschema(copy.deepcopy(json_data), clean)
#   File "/opt/conda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/json_wrapper.py", line 312, in run_json_qcschema
#     val, wfn = methods_dict_[json_data["driver"]](method, **kwargs)
#   File "/opt/conda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/driver.py", line 691, in gradient
#     wfn = procedures['gradient'][lowername](lowername, molecule=molecule, **kwargs)
#   File "/opt/conda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/procrouting/proc.py", line 2064, in run_scf_gradient
#     ref_wfn = run_scf(name, **kwargs)
#   File "/opt/conda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/procrouting/proc.py", line 2002, in run_scf
#     scf_wfn = scf_helper(name, post_scf=False, **kwargs)
#   File "/opt/conda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/procrouting/proc.py", line 1363, in scf_helper
#     e_scf = scf_wfn.compute_energy()
#   File "/opt/conda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 94, in scf_compute_energy
#     raise e
#   File "/opt/conda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 87, in scf_compute_energy
#     self.iterations()
#   File "/opt/conda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 447, in scf_iterate
#     raise SCFConvergenceError("""SCF iterations""", self.iteration_, self, Ediff, Dnorm)
# psi4.driver.p4util.exceptions.SCFConvergenceError: Could not converge SCF iterations in 200 iterations.
#
#
# -------------------------------------
#
# There are 2 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/home/chodera/miniconda/envs/qcfractal/lib/python3.6/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/home/chodera/miniconda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/home/chodera/miniconda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1298, in optimizeGeometry
#     self.calcEnergyForce()
#   File "/home/chodera/miniconda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1002, in calcEnergyForce
#     spcalc = self.engine.calc(self.X, self.dirname)
#   File "/home/chodera/miniconda/envs/qcfractal/lib/python3.6/site-packages/geometric/engine.py", line 873, in calc
#     return self.calc_new(coords, dirname)
#   File "/home/chodera/miniconda/envs/qcfractal/lib/python3.6/site-packages/geometric/engine.py", line 865, in calc_new
#     raise QCEngineAPIEngineError("QCEngineAPI computation did not execute correctly. Message: " + ret["error"]["error_message"])
# geometric.errors.QCEngineAPIEngineError: QCEngineAPI computation did not execute correctly. Message: QCEngine Unknown Error: Traceback (most recent call last):
#   File "/home/chodera/miniconda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/json_wrapper.py", line 217, in run_json
#     json_data = run_json_qcschema(copy.deepcopy(json_data), clean)
#   File "/home/chodera/miniconda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/json_wrapper.py", line 312, in run_json_qcschema
#     val, wfn = methods_dict_[json_data["driver"]](method, **kwargs)
#   File "/home/chodera/miniconda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/driver.py", line 691, in gradient
#     wfn = procedures['gradient'][lowername](lowername, molecule=molecule, **kwargs)
#   File "/home/chodera/miniconda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/procrouting/proc.py", line 2064, in run_scf_gradient
#     ref_wfn = run_scf(name, **kwargs)
#   File "/home/chodera/miniconda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/procrouting/proc.py", line 2002, in run_scf
#     scf_wfn = scf_helper(name, post_scf=False, **kwargs)
#   File "/home/chodera/miniconda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/procrouting/proc.py", line 1363, in scf_helper
#     e_scf = scf_wfn.compute_energy()
#   File "/home/chodera/miniconda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 94, in scf_compute_energy
#     raise e
#   File "/home/chodera/miniconda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 87, in scf_compute_energy
#     self.iterations()
#   File "/home/chodera/miniconda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 447, in scf_iterate
#     raise SCFConvergenceError("""SCF iterations""", self.iteration_, self, Ediff, Dnorm)
# psi4.driver.p4util.exceptions.SCFConvergenceError: Could not converge SCF iterations in 200 iterations.
#
#
# -------------------------------------

# %%
restart_optimizations(resm, client)
# Out:
# OptimizationRecord(id='18886329', status='ERROR')
# OptimizationRecord(id='19072649', status='ERROR')
# OptimizationRecord(id='18888532', status='ERROR')
# OptimizationRecord(id='19063096', status='ERROR')
# OptimizationRecord(id='19430103', status='ERROR')
# OptimizationRecord(id='19430104', status='ERROR')
# OptimizationRecord(id='19430105', status='ERROR')
# OptimizationRecord(id='19074332', status='ERROR')
# OptimizationRecord(id='19067852', status='ERROR')
# OptimizationRecord(id='19067869', status='ERROR')
# OptimizationRecord(id='19519943', status='ERROR')
# OptimizationRecord(id='19137203', status='ERROR')
# OptimizationRecord(id='19137264', status='ERROR')
# OptimizationRecord(id='19183905', status='ERROR')
# OptimizationRecord(id='19183978', status='ERROR')
# OptimizationRecord(id='19495841', status='ERROR')
# OptimizationRecord(id='19495844', status='ERROR')
# OptimizationRecord(id='19495845', status='ERROR')
# OptimizationRecord(id='19495846', status='ERROR')
# OptimizationRecord(id='19495849', status='ERROR')
# OptimizationRecord(id='19495850', status='ERROR')
# OptimizationRecord(id='19383507', status='ERROR')
# OptimizationRecord(id='19383509', status='ERROR')
# OptimizationRecord(id='19194079', status='ERROR')
# OptimizationRecord(id='19194081', status='ERROR')
# OptimizationRecord(id='19194090', status='ERROR')
# OptimizationRecord(id='19194331', status='ERROR')
# OptimizationRecord(id='19194332', status='ERROR')
# OptimizationRecord(id='19194333', status='ERROR')
# OptimizationRecord(id='19194336', status='ERROR')
# OptimizationRecord(id='19194338', status='ERROR')
# OptimizationRecord(id='19194339', status='ERROR')
# OptimizationRecord(id='19194340', status='ERROR')
# OptimizationRecord(id='19194341', status='ERROR')
# OptimizationRecord(id='19194342', status='ERROR')
# OptimizationRecord(id='19194343', status='ERROR')
# OptimizationRecord(id='19194344', status='ERROR')
# OptimizationRecord(id='19194345', status='ERROR')
# OptimizationRecord(id='19194346', status='ERROR')
# OptimizationRecord(id='19194347', status='ERROR')
# OptimizationRecord(id='19194348', status='ERROR')
# OptimizationRecord(id='19194349', status='ERROR')
# OptimizationRecord(id='19194350', status='ERROR')
# OptimizationRecord(id='19194351', status='ERROR')
# OptimizationRecord(id='19194353', status='ERROR')
# OptimizationRecord(id='19194354', status='ERROR')
# OptimizationRecord(id='19194355', status='ERROR')
# OptimizationRecord(id='19194357', status='ERROR')
# OptimizationRecord(id='19194358', status='ERROR')
# OptimizationRecord(id='19194360', status='ERROR')
# OptimizationRecord(id='19194362', status='ERROR')
# OptimizationRecord(id='19194367', status='ERROR')
# OptimizationRecord(id='19194369', status='ERROR')
# OptimizationRecord(id='19194373', status='ERROR')
# OptimizationRecord(id='19194374', status='ERROR')
# OptimizationRecord(id='19194375', status='ERROR')
# OptimizationRecord(id='19194377', status='ERROR')
# OptimizationRecord(id='19194379', status='ERROR')
# OptimizationRecord(id='19194380', status='ERROR')
# OptimizationRecord(id='19194381', status='ERROR')
# OptimizationRecord(id='19194383', status='ERROR')
# OptimizationRecord(id='19194384', status='ERROR')
# OptimizationRecord(id='19194385', status='ERROR')
# OptimizationRecord(id='19194388', status='ERROR')
# OptimizationRecord(id='19195425', status='ERROR')
# OptimizationRecord(id='19195427', status='ERROR')
# OptimizationRecord(id='19195428', status='ERROR')
# OptimizationRecord(id='19195439', status='ERROR')
# OptimizationRecord(id='19195440', status='ERROR')
# OptimizationRecord(id='19195441', status='ERROR')
# OptimizationRecord(id='19195442', status='ERROR')
# OptimizationRecord(id='19195444', status='ERROR')
# OptimizationRecord(id='19195452', status='ERROR')
# OptimizationRecord(id='19195453', status='ERROR')
# OptimizationRecord(id='19195455', status='ERROR')
# OptimizationRecord(id='19195456', status='ERROR')
# OptimizationRecord(id='19195457', status='ERROR')
# OptimizationRecord(id='19195458', status='ERROR')
# OptimizationRecord(id='19195460', status='ERROR')
# OptimizationRecord(id='19195461', status='ERROR')
# OptimizationRecord(id='19195463', status='ERROR')
# OptimizationRecord(id='19195464', status='ERROR')
# OptimizationRecord(id='19195465', status='ERROR')
# OptimizationRecord(id='19195660', status='ERROR')
# OptimizationRecord(id='19195661', status='ERROR')
# OptimizationRecord(id='19197486', status='ERROR')
# OptimizationRecord(id='19197487', status='ERROR')
# OptimizationRecord(id='19197488', status='ERROR')
# OptimizationRecord(id='19207850', status='ERROR')
# OptimizationRecord(id='19207853', status='ERROR')
# OptimizationRecord(id='19207863', status='ERROR')
# OptimizationRecord(id='19207873', status='ERROR')
# OptimizationRecord(id='19207878', status='ERROR')
# OptimizationRecord(id='19207885', status='ERROR')
# OptimizationRecord(id='19207886', status='ERROR')
# OptimizationRecord(id='19207904', status='ERROR')
# OptimizationRecord(id='19207907', status='ERROR')
# OptimizationRecord(id='19207910', status='ERROR')
# OptimizationRecord(id='19207915', status='ERROR')
# OptimizationRecord(id='19208151', status='ERROR')
# OptimizationRecord(id='19208152', status='ERROR')
# OptimizationRecord(id='19208153', status='ERROR')
# OptimizationRecord(id='19208154', status='ERROR')

# %%
restart_torsiondrives(ds.df.default.tolist(), client)
# Out:
# TorsionDriveRecord(id='18045852', status='ERROR')
# TorsionDriveRecord(id='18045856', status='ERROR')
# TorsionDriveRecord(id='18045864', status='ERROR')
# TorsionDriveRecord(id='18045865', status='ERROR')
# TorsionDriveRecord(id='18045870', status='ERROR')
# TorsionDriveRecord(id='18045875', status='ERROR')
# TorsionDriveRecord(id='18045879', status='ERROR')
# TorsionDriveRecord(id='18045886', status='ERROR')
# TorsionDriveRecord(id='18045891', status='ERROR')
# TorsionDriveRecord(id='18045896', status='ERROR')
# TorsionDriveRecord(id='18045901', status='ERROR')
# TorsionDriveRecord(id='18045902', status='ERROR')
# TorsionDriveRecord(id='18045905', status='ERROR')
# TorsionDriveRecord(id='18045909', status='ERROR')
# TorsionDriveRecord(id='18045910', status='ERROR')
# TorsionDriveRecord(id='18045912', status='ERROR')
# TorsionDriveRecord(id='18045913', status='ERROR')
# TorsionDriveRecord(id='18045916', status='ERROR')
# TorsionDriveRecord(id='18045917', status='ERROR')
# TorsionDriveRecord(id='18045920', status='ERROR')
# TorsionDriveRecord(id='18045921', status='ERROR')
# TorsionDriveRecord(id='18045925', status='ERROR')
# TorsionDriveRecord(id='18045929', status='ERROR')
# TorsionDriveRecord(id='18045930', status='ERROR')
# TorsionDriveRecord(id='18045937', status='ERROR')
# TorsionDriveRecord(id='18045941', status='ERROR')
# TorsionDriveRecord(id='18045942', status='ERROR')
# TorsionDriveRecord(id='18045948', status='ERROR')
# TorsionDriveRecord(id='18045953', status='ERROR')
# TorsionDriveRecord(id='18045956', status='ERROR')
# TorsionDriveRecord(id='18045959', status='ERROR')
# TorsionDriveRecord(id='18045960', status='ERROR')
# TorsionDriveRecord(id='18045964', status='ERROR')
# TorsionDriveRecord(id='18045965', status='ERROR')
# TorsionDriveRecord(id='18045966', status='ERROR')
# TorsionDriveRecord(id='18045967', status='ERROR')
# TorsionDriveRecord(id='18045969', status='ERROR')

# %% [markdown]
# ## Dataset tracking - OpenFF Gen 2 Torsion Set 6 supplemental 2

# %% [markdown]
# ### 2020.06.27 01:37 UTC

# %%
dataset = "OpenFF Gen 2 Torsion Set 6 supplemental 2"

# %%
ds = client.get_collection("TorsionDriveDataset", dataset)

# %%
ds.list_specifications()
# Out:
#                                          Description
# Name
# default  Standard OpenFF torsiondrive specification.

# %%
res = get_unfinished_torsiondrive_optimizations(ds, 'default', client)
res
# Out:
# {'18885888': [OptimizationRecord(id='18885922', status='ERROR'),
#   OptimizationRecord(id='18885923', status='COMPLETE'),
#   OptimizationRecord(id='18885924', status='ERROR'),
#   OptimizationRecord(id='18885925', status='COMPLETE'),
#   OptimizationRecord(id='18885926', status='COMPLETE'),
#   OptimizationRecord(id='18885927', status='COMPLETE'),
#   OptimizationRecord(id='18885928', status='ERROR'),
#   OptimizationRecord(id='18885929', status='ERROR'),
#   OptimizationRecord(id='18885930', status='ERROR'),
#   OptimizationRecord(id='18885931', status='ERROR'),
#   OptimizationRecord(id='18885932', status='ERROR'),
#   OptimizationRecord(id='18885933', status='ERROR'),
#   OptimizationRecord(id='18885934', status='COMPLETE'),
#   OptimizationRecord(id='18885935', status='ERROR'),
#   OptimizationRecord(id='18885936', status='COMPLETE'),
#   OptimizationRecord(id='18885937', status='ERROR'),
#   OptimizationRecord(id='18885938', status='ERROR'),
#   OptimizationRecord(id='18885939', status='ERROR'),
#   OptimizationRecord(id='18885940', status='ERROR'),
#   OptimizationRecord(id='18885941', status='ERROR'),
#   OptimizationRecord(id='18885942', status='ERROR'),
#   OptimizationRecord(id='18885943', status='COMPLETE'),
#   OptimizationRecord(id='18885944', status='COMPLETE'),
#   OptimizationRecord(id='18885945', status='COMPLETE'),
#   OptimizationRecord(id='18885946', status='COMPLETE'),
#   OptimizationRecord(id='18885947', status='COMPLETE'),
#   OptimizationRecord(id='18885948', status='ERROR')]}

# %%
resm = merge(res)

# %%
incomplete = (opt.dict() for opt in resm if opt.status == 'INCOMPLETE')

# %%
next(incomplete)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-114-3729b8af7b87> in <module>
# ----> 1 next(incomplete)
#
# StopIteration:

# %% [markdown]
# Yay!

# %%
count_unique_optimization_error_messages(resm, full=True, pretty_print=True)
# Out:
# There are 1 instances of
# -------------------------------------
# Caught Executor Error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/opt/lib/python3.7/site-packages/qcfractal-0.13.1+54.g3caa178.dirty-py3.7.egg/qcfractal/queue/executor_adapter.py", line 15, in _get_future
#     return future.result()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/distributed/client.py", line 218, in result
#     raise exc.with_traceback(tb)
# distributed.scheduler.KilledWorker: ('compute_procedure-034812bf0fa56839ad730c80f9e18de8', <Worker 'tcp://10.240.60.27:46854', name: 58, memory: 0, processing: 10>)
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# Caught Executor Error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/opt/lib/python3.7/site-packages/qcfractal-0.13.1+54.g3caa178.dirty-py3.7.egg/qcfractal/queue/executor_adapter.py", line 15, in _get_future
#     return future.result()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/distributed/client.py", line 218, in result
#     raise exc.with_traceback(tb)
# distributed.scheduler.KilledWorker: ('compute_procedure-4537087e0e452d9d23379edd2d9d5ab8', <Worker 'tcp://10.240.60.24:36540', name: 58, memory: 0, processing: 22>)
#
# -------------------------------------
#
# There are 4 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1298, in optimizeGeometry
#     self.calcEnergyForce()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1002, in calcEnergyForce
#     spcalc = self.engine.calc(self.X, self.dirname)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/engine.py", line 873, in calc
#     return self.calc_new(coords, dirname)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/engine.py", line 865, in calc_new
#     raise QCEngineAPIEngineError("QCEngineAPI computation did not execute correctly. Message: " + ret["error"]["error_message"])
# geometric.errors.QCEngineAPIEngineError: QCEngineAPI computation did not execute correctly. Message: QCEngine Unknown Error: Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/json_wrapper.py", line 217, in run_json
#     json_data = run_json_qcschema(copy.deepcopy(json_data), clean)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/json_wrapper.py", line 312, in run_json_qcschema
#     val, wfn = methods_dict_[json_data["driver"]](method, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/driver.py", line 691, in gradient
#     wfn = procedures['gradient'][lowername](lowername, molecule=molecule, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/proc.py", line 2064, in run_scf_gradient
#     ref_wfn = run_scf(name, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/proc.py", line 2002, in run_scf
#     scf_wfn = scf_helper(name, post_scf=False, **kwargs)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/proc.py", line 1363, in scf_helper
#     e_scf = scf_wfn.compute_energy()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 94, in scf_compute_energy
#     raise e
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 87, in scf_compute_energy
#     self.iterations()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib//python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 447, in scf_iterate
#     raise SCFConvergenceError("""SCF iterations""", self.iteration_, self, Ediff, Dnorm)
# psi4.driver.p4util.exceptions.SCFConvergenceError: Could not converge SCF iterations in 200 iterations.
#
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# Caught Executor Error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/opt/lib/python3.7/site-packages/qcfractal-0.13.1+54.g3caa178.dirty-py3.7.egg/qcfractal/queue/executor_adapter.py", line 15, in _get_future
#     return future.result()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/distributed/client.py", line 218, in result
#     raise exc.with_traceback(tb)
# distributed.scheduler.KilledWorker: ('compute_procedure-fa2b39de570241a993dd9f58e322c17f', <Worker 'tcp://10.240.60.24:36540', name: 58, memory: 0, processing: 22>)
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# Caught Executor Error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/opt/lib/python3.7/site-packages/qcfractal-0.13.1+54.g3caa178.dirty-py3.7.egg/qcfractal/queue/executor_adapter.py", line 15, in _get_future
#     return future.result()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/distributed/client.py", line 218, in result
#     raise exc.with_traceback(tb)
# distributed.scheduler.KilledWorker: ('compute_procedure-1d79cd1beabbedfe3919003a7162ebb2', <Worker 'tcp://10.240.60.37:45103', name: 68, memory: 0, processing: 1>)
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1296, in optimizeGeometry
#     self.step()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1085, in step
#     iopt = brent_wiki(froot.evaluate, 0.0, iopt, froot.target, cvg=0.1, verbose=params.verbose)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 187, in brent_wiki
#     raise RuntimeError('Not bracketed')
# RuntimeError: Not bracketed
#
# -------------------------------------
#
# There are 5 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1296, in optimizeGeometry
#     self.step()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1100, in step
#     self.checkCoordinateSystem(recover=True, cartesian=LastForce)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 959, in checkCoordinateSystem
#     raise ValueError("Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates")
# ValueError: Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1296, in optimizeGeometry
#     self.step()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1100, in step
#     self.checkCoordinateSystem(recover=True, cartesian=LastForce)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 959, in checkCoordinateSystem
#     raise ValueError("Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates")
# ValueError: Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/data/homezvol0/tgokey/.local/miniconda3/envs/qcf/lib/python3.7/site-packages/geometric/optimize.py", line 1301, in optimizeGeometry
#     raise GeomOptNotConvergedError("Optimizer.optimizeGeometry() failed to converge.")
# geometric.errors.GeomOptNotConvergedError: Optimizer.optimizeGeometry() failed to converge.
#
# -------------------------------------

# %%
restart_optimizations(resm, client)
# Out:
# OptimizationRecord(id='18885922', status='ERROR')
# OptimizationRecord(id='18885924', status='ERROR')
# OptimizationRecord(id='18885928', status='ERROR')
# OptimizationRecord(id='18885929', status='ERROR')
# OptimizationRecord(id='18885930', status='ERROR')
# OptimizationRecord(id='18885931', status='ERROR')
# OptimizationRecord(id='18885932', status='ERROR')
# OptimizationRecord(id='18885933', status='ERROR')
# OptimizationRecord(id='18885935', status='ERROR')
# OptimizationRecord(id='18885937', status='ERROR')
# OptimizationRecord(id='18885938', status='ERROR')
# OptimizationRecord(id='18885939', status='ERROR')
# OptimizationRecord(id='18885940', status='ERROR')
# OptimizationRecord(id='18885941', status='ERROR')
# OptimizationRecord(id='18885942', status='ERROR')
# OptimizationRecord(id='18885948', status='ERROR')

# %%
restart_torsiondrives(ds.df.default.tolist(), client)
# Out:
# TorsionDriveRecord(id='18885888', status='ERROR')

# %% [markdown]
# ### 2020.06.11 22:45 UTC

# %%
dataset = "OpenFF Gen 2 Torsion Set 6 supplemental 2"

# %%
ds = client.get_collection("TorsionDriveDataset", dataset)

# %%
ds.list_specifications()
# Out:
#                                          Description
# Name
# default  Standard OpenFF torsiondrive specification.

# %%
res = get_unfinished_torsiondrive_optimizations(ds, 'default', client, merged=False)
res
# Out:
# {'18885888': [OptimizationRecord(id='18885922', status='ERROR'),
#   OptimizationRecord(id='18885923', status='COMPLETE'),
#   OptimizationRecord(id='18885924', status='ERROR'),
#   OptimizationRecord(id='18885925', status='COMPLETE'),
#   OptimizationRecord(id='18885926', status='COMPLETE'),
#   OptimizationRecord(id='18885927', status='COMPLETE'),
#   OptimizationRecord(id='18885928', status='ERROR'),
#   OptimizationRecord(id='18885929', status='ERROR'),
#   OptimizationRecord(id='18885930', status='ERROR'),
#   OptimizationRecord(id='18885931', status='ERROR'),
#   OptimizationRecord(id='18885932', status='ERROR'),
#   OptimizationRecord(id='18885933', status='ERROR'),
#   OptimizationRecord(id='18885934', status='COMPLETE'),
#   OptimizationRecord(id='18885935', status='ERROR'),
#   OptimizationRecord(id='18885936', status='ERROR'),
#   OptimizationRecord(id='18885937', status='ERROR'),
#   OptimizationRecord(id='18885938', status='ERROR'),
#   OptimizationRecord(id='18885939', status='ERROR'),
#   OptimizationRecord(id='18885940', status='ERROR'),
#   OptimizationRecord(id='18885941', status='ERROR'),
#   OptimizationRecord(id='18885942', status='ERROR'),
#   OptimizationRecord(id='18885943', status='COMPLETE'),
#   OptimizationRecord(id='18885944', status='COMPLETE'),
#   OptimizationRecord(id='18885945', status='COMPLETE'),
#   OptimizationRecord(id='18885946', status='COMPLETE'),
#   OptimizationRecord(id='18885947', status='COMPLETE'),
#   OptimizationRecord(id='18885948', status='ERROR')],
#  '18885892': [OptimizationRecord(id='18885959', status='COMPLETE'),
#   OptimizationRecord(id='18889016', status='COMPLETE'),
#   OptimizationRecord(id='18889017', status='COMPLETE'),
#   OptimizationRecord(id='18948869', status='COMPLETE'),
#   OptimizationRecord(id='18948870', status='COMPLETE'),
#   OptimizationRecord(id='18948871', status='COMPLETE'),
#   OptimizationRecord(id='18948872', status='COMPLETE'),
#   OptimizationRecord(id='18963685', status='COMPLETE'),
#   OptimizationRecord(id='18963686', status='COMPLETE'),
#   OptimizationRecord(id='18963687', status='COMPLETE'),
#   OptimizationRecord(id='18963688', status='COMPLETE'),
#   OptimizationRecord(id='18978083', status='COMPLETE'),
#   OptimizationRecord(id='18978084', status='COMPLETE'),
#   OptimizationRecord(id='18978085', status='COMPLETE'),
#   OptimizationRecord(id='18978086', status='COMPLETE'),
#   OptimizationRecord(id='18989684', status='COMPLETE'),
#   OptimizationRecord(id='18989685', status='COMPLETE'),
#   OptimizationRecord(id='18989686', status='COMPLETE'),
#   OptimizationRecord(id='18989687', status='COMPLETE'),
#   OptimizationRecord(id='19002378', status='COMPLETE'),
#   OptimizationRecord(id='19002379', status='COMPLETE'),
#   OptimizationRecord(id='19002380', status='COMPLETE'),
#   OptimizationRecord(id='19002381', status='COMPLETE'),
#   OptimizationRecord(id='19014303', status='COMPLETE'),
#   OptimizationRecord(id='19014304', status='COMPLETE'),
#   OptimizationRecord(id='19014305', status='COMPLETE'),
#   OptimizationRecord(id='19014306', status='COMPLETE'),
#   OptimizationRecord(id='19026440', status='COMPLETE'),
#   OptimizationRecord(id='19026441', status='COMPLETE'),
#   OptimizationRecord(id='19026451', status='COMPLETE'),
#   OptimizationRecord(id='19026452', status='COMPLETE'),
#   OptimizationRecord(id='19036751', status='COMPLETE'),
#   OptimizationRecord(id='19036752', status='COMPLETE'),
#   OptimizationRecord(id='19036753', status='COMPLETE'),
#   OptimizationRecord(id='19036754', status='COMPLETE'),
#   OptimizationRecord(id='19047276', status='COMPLETE'),
#   OptimizationRecord(id='19047277', status='COMPLETE'),
#   OptimizationRecord(id='19047278', status='COMPLETE'),
#   OptimizationRecord(id='19047279', status='COMPLETE'),
#   OptimizationRecord(id='19047280', status='COMPLETE'),
#   OptimizationRecord(id='19047281', status='COMPLETE'),
#   OptimizationRecord(id='19068538', status='COMPLETE'),
#   OptimizationRecord(id='19068539', status='COMPLETE'),
#   OptimizationRecord(id='19068540', status='COMPLETE'),
#   OptimizationRecord(id='19068541', status='COMPLETE'),
#   OptimizationRecord(id='19068542', status='COMPLETE'),
#   OptimizationRecord(id='19068543', status='COMPLETE'),
#   OptimizationRecord(id='19068544', status='COMPLETE'),
#   OptimizationRecord(id='19068545', status='COMPLETE'),
#   OptimizationRecord(id='19086693', status='COMPLETE'),
#   OptimizationRecord(id='19086694', status='COMPLETE'),
#   OptimizationRecord(id='19086695', status='COMPLETE'),
#   OptimizationRecord(id='19086696', status='COMPLETE'),
#   OptimizationRecord(id='19086697', status='COMPLETE'),
#   OptimizationRecord(id='19086698', status='COMPLETE'),
#   OptimizationRecord(id='19086699', status='COMPLETE'),
#   OptimizationRecord(id='19086700', status='COMPLETE'),
#   OptimizationRecord(id='19086701', status='COMPLETE'),
#   OptimizationRecord(id='19086702', status='COMPLETE')]}

# %%
resm = merge(res)

# %%
incomplete = (opt.dict() for opt in resm if opt.status == 'INCOMPLETE')

# %%
next(incomplete)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-34-3729b8af7b87> in <module>
# ----> 1 next(incomplete)
#
# StopIteration:

# %% [markdown]
# Yay!

# %%
count_unique_optimization_error_messages(resm, full=True, pretty_print=True)
# Out:
# There are 3 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1301, in optimizeGeometry
#     raise GeomOptNotConvergedError("Optimizer.optimizeGeometry() failed to converge.")
# geometric.errors.GeomOptNotConvergedError: Optimizer.optimizeGeometry() failed to converge.
#
# -------------------------------------
#
# There are 9 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1296, in optimizeGeometry
#     self.step()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1100, in step
#     self.checkCoordinateSystem(recover=True, cartesian=LastForce)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 959, in checkCoordinateSystem
#     raise ValueError("Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates")
# ValueError: Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates
#
# -------------------------------------
#
# There are 2 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/home/chodera/miniconda/envs/qcfractal/lib/python3.6/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/home/chodera/miniconda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/home/chodera/miniconda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1296, in optimizeGeometry
#     self.step()
#   File "/home/chodera/miniconda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1100, in step
#     self.checkCoordinateSystem(recover=True, cartesian=LastForce)
#   File "/home/chodera/miniconda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 959, in checkCoordinateSystem
#     raise ValueError("Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates")
# ValueError: Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib/python3.7/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib/python3.7/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib/python3.7/site-packages/geometric/optimize.py", line 1298, in optimizeGeometry
#     self.calcEnergyForce()
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib/python3.7/site-packages/geometric/optimize.py", line 1002, in calcEnergyForce
#     spcalc = self.engine.calc(self.X, self.dirname)
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib/python3.7/site-packages/geometric/engine.py", line 873, in calc
#     return self.calc_new(coords, dirname)
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib/python3.7/site-packages/geometric/engine.py", line 865, in calc_new
#     raise QCEngineAPIEngineError("QCEngineAPI computation did not execute correctly. Message: " + ret["error"]["error_message"])
# geometric.errors.QCEngineAPIEngineError: QCEngineAPI computation did not execute correctly. Message: QCEngine Unknown Error: Traceback (most recent call last):
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib//python3.7/site-packages/psi4/driver/schema_wrapper.py", line 391, in run_qcschema
#     ret_data = run_json_qcschema(input_model.dict(), clean, False, keep_wfn=keep_wfn)
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib//python3.7/site-packages/psi4/driver/schema_wrapper.py", line 538, in run_json_qcschema
#     val, wfn = methods_dict_[json_data["driver"]](method, **kwargs)
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib//python3.7/site-packages/psi4/driver/driver.py", line 711, in gradient
#     wfn = procedures['gradient'][lowername](lowername, molecule=molecule, **kwargs)
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib//python3.7/site-packages/psi4/driver/procrouting/proc.py", line 2310, in run_scf_gradient
#     ref_wfn = run_scf(name, **kwargs)
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib//python3.7/site-packages/psi4/driver/procrouting/proc.py", line 2215, in run_scf
#     scf_wfn = scf_helper(name, post_scf=False, **kwargs)
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib//python3.7/site-packages/psi4/driver/procrouting/proc.py", line 1516, in scf_helper
#     e_scf = scf_wfn.compute_energy()
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib//python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 93, in scf_compute_energy
#     raise e
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib//python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 86, in scf_compute_energy
#     self.iterations()
#   File "/home/bpp4/miniconda3/envs/qca_manager/lib//python3.7/site-packages/psi4/driver/procrouting/scf_proc/scf_iterator.py", line 464, in scf_iterate
#     raise SCFConvergenceError("""SCF iterations""", self.iteration_, self, Ediff, Dnorm)
# psi4.driver.p4util.exceptions.SCFConvergenceError: Could not converge SCF iterations in 200 iterations.
#
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# geomeTRIC run_json error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/run_json.py", line 225, in geometric_run_json
#     geometric.optimize.Optimize(coords, M, IC, engine, None, params)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1331, in Optimize
#     return optimizer.optimizeGeometry()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1298, in optimizeGeometry
#     self.calcEnergyForce()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/optimize.py", line 1002, in calcEnergyForce
#     spcalc = self.engine.calc(self.X, self.dirname)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/engine.py", line 873, in calc
#     return self.calc_new(coords, dirname)
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/geometric/engine.py", line 865, in calc_new
#     raise QCEngineAPIEngineError("QCEngineAPI computation did not execute correctly. Message: " + ret["error"]["error_message"])
# geometric.errors.QCEngineAPIEngineError: QCEngineAPI computation did not execute correctly. Message: QCEngine Input Error: Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/json_wrapper.py", line 217, in run_json
#     json_data = run_json_qcschema(copy.deepcopy(json_data), clean)
#   File "/opt/conda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/json_wrapper.py", line 286, in run_json_qcschema
#     mol = core.Molecule.from_schema(molschemus)
#   File "/opt/conda/envs/qcfractal/lib//python3.6/site-packages/psi4/driver/molutil.py", line 200, in molecule_from_schema
#     molrec = qcel.molparse.from_schema(molschema, verbose=verbose)
#   File "/opt/conda/envs/qcfractal/lib//python3.6/site-packages/qcelemental/molparse/from_schema.py", line 87, in from_schema
#     verbose=verbose,
#   File "/opt/conda/envs/qcfractal/lib//python3.6/site-packages/qcelemental/molparse/from_arrays.py", line 350, in from_arrays
#     processed = validate_and_fill_geometry(geom=geom, tooclose=tooclose, copy=copy)
#   File "/opt/conda/envs/qcfractal/lib//python3.6/site-packages/qcelemental/molparse/from_arrays.py", line 614, in validate_and_fill_geometry
#     """Following atoms are too close: {}""".format([(i, j, dist) for i, j, dist in tooclose_inds])
# qcelemental.exceptions.ValidationError: Following atoms are too close: [(0, 16, 0.04350453163279306)]
#
#
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# Caught Executor Error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/qcfractal/lib/python3.6/site-packages/qcfractal/queue/executor_adapter.py", line 15, in _get_future
#     return future.result()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/concurrent/futures/_base.py", line 425, in result
#     return self.__get_result()
#   File "/opt/conda/envs/qcfractal/lib/python3.6/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
# concurrent.futures.process.BrokenProcessPool: A process in the process pool was terminated abruptly while the future was running or pending.
#
# -------------------------------------

# %%
restart_optimizations(resm, client)
# Out:
# OptimizationRecord(id='18885922', status='ERROR')
# OptimizationRecord(id='18885924', status='ERROR')
# OptimizationRecord(id='18885928', status='ERROR')
# OptimizationRecord(id='18885929', status='ERROR')
# OptimizationRecord(id='18885930', status='ERROR')
# OptimizationRecord(id='18885931', status='ERROR')
# OptimizationRecord(id='18885932', status='ERROR')
# OptimizationRecord(id='18885933', status='ERROR')
# OptimizationRecord(id='18885935', status='ERROR')
# OptimizationRecord(id='18885936', status='ERROR')
# OptimizationRecord(id='18885937', status='ERROR')
# OptimizationRecord(id='18885938', status='ERROR')
# OptimizationRecord(id='18885939', status='ERROR')
# OptimizationRecord(id='18885940', status='ERROR')
# OptimizationRecord(id='18885941', status='ERROR')
# OptimizationRecord(id='18885942', status='ERROR')
# OptimizationRecord(id='18885948', status='ERROR')

# %%
restart_torsiondrives(ds.df.default.tolist(), client)
# Out:
# TorsionDriveRecord(id='18885888', status='ERROR')
# TorsionDriveRecord(id='18885892', status='ERROR')
