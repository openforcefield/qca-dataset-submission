# %% [markdown]
# # Management - Gen 2 Torsion

# %% [markdown]
# For large molecules, accept errors. Make new dataset version with errors left out.

# %%
import qcportal as ptl
import pandas as pd
import datetime
import time

from management import *

# %% [raw]
# # connect without auth
# # read only
# client = ptl.FractalClient()

# %%
# connect with authentication, therefore write access
# don't use unless you plan to submit things
client = ptl.FractalClient.from_file()

# %%
client
# Out:
# FractalClient(server_name='The MolSSI QCArchive Server', address='https://api.qcarchive.molssi.org:443/', username='ddotson')

# %% [markdown]
# ## Dataset tracking - OpenFF Gen 2 Torsion Set 1 Roche

# %% [markdown]
# ### 2020.06.11 16:45 UTC

# %%
dataset = "OpenFF Gen 2 Torsion Set 1 Roche"

# %%
ds = client.get_collection("TorsionDriveDataset", dataset)

# %%
ds.list_specifications()
# Out:
#                                          Description
# Name
# default  Standard OpenFF torsiondrive specification.

# %%
res = get_unfinished_torsiondrive_optimizations(ds, 'default', client, merged=False)
res
# Out:
# {'18045309': [OptimizationRecord(id='18045374', status='COMPLETE'),
#   OptimizationRecord(id='18045584', status='COMPLETE'),
#   OptimizationRecord(id='18045585', status='COMPLETE'),
#   OptimizationRecord(id='18047897', status='COMPLETE'),
#   OptimizationRecord(id='18047898', status='COMPLETE'),
#   OptimizationRecord(id='18047899', status='INCOMPLETE'),
#   OptimizationRecord(id='18047900', status='COMPLETE')],
#  '18045317': [OptimizationRecord(id='18045386', status='COMPLETE'),
#   OptimizationRecord(id='18046176', status='COMPLETE'),
#   OptimizationRecord(id='18046177', status='COMPLETE'),
#   OptimizationRecord(id='18052471', status='COMPLETE'),
#   OptimizationRecord(id='18052472', status='COMPLETE'),
#   OptimizationRecord(id='18052473', status='COMPLETE'),
#   OptimizationRecord(id='18052474', status='INCOMPLETE')],
#  '18045321': [OptimizationRecord(id='18045393', status='COMPLETE'),
#   OptimizationRecord(id='18046677', status='COMPLETE'),
#   OptimizationRecord(id='18046678', status='COMPLETE'),
#   OptimizationRecord(id='18058695', status='COMPLETE'),
#   OptimizationRecord(id='18058696', status='COMPLETE'),
#   OptimizationRecord(id='18058697', status='COMPLETE'),
#   OptimizationRecord(id='18058698', status='COMPLETE'),
#   OptimizationRecord(id='18070236', status='COMPLETE'),
#   OptimizationRecord(id='18070237', status='COMPLETE'),
#   OptimizationRecord(id='18070238', status='COMPLETE'),
#   OptimizationRecord(id='18070239', status='COMPLETE'),
#   OptimizationRecord(id='18087845', status='COMPLETE'),
#   OptimizationRecord(id='18087846', status='COMPLETE'),
#   OptimizationRecord(id='18087847', status='COMPLETE'),
#   OptimizationRecord(id='18087848', status='COMPLETE'),
#   OptimizationRecord(id='18101580', status='COMPLETE'),
#   OptimizationRecord(id='18101590', status='COMPLETE'),
#   OptimizationRecord(id='18101591', status='COMPLETE'),
#   OptimizationRecord(id='18101605', status='COMPLETE'),
#   OptimizationRecord(id='18112988', status='COMPLETE'),
#   OptimizationRecord(id='18112989', status='COMPLETE'),
#   OptimizationRecord(id='18112990', status='COMPLETE'),
#   OptimizationRecord(id='18112991', status='COMPLETE'),
#   OptimizationRecord(id='18129130', status='COMPLETE'),
#   OptimizationRecord(id='18129131', status='COMPLETE'),
#   OptimizationRecord(id='18129132', status='COMPLETE'),
#   OptimizationRecord(id='18129144', status='COMPLETE'),
#   OptimizationRecord(id='18136428', status='COMPLETE'),
#   OptimizationRecord(id='18136444', status='COMPLETE'),
#   OptimizationRecord(id='18136445', status='COMPLETE'),
#   OptimizationRecord(id='18136446', status='COMPLETE'),
#   OptimizationRecord(id='18144949', status='COMPLETE'),
#   OptimizationRecord(id='18144950', status='COMPLETE'),
#   OptimizationRecord(id='18144951', status='INCOMPLETE'),
#   OptimizationRecord(id='18144952', status='COMPLETE')],
#  '18045332': [OptimizationRecord(id='18045405', status='COMPLETE'),
#   OptimizationRecord(id='18046934', status='COMPLETE'),
#   OptimizationRecord(id='18046935', status='COMPLETE'),
#   OptimizationRecord(id='18058522', status='COMPLETE'),
#   OptimizationRecord(id='18058523', status='COMPLETE'),
#   OptimizationRecord(id='18058524', status='COMPLETE'),
#   OptimizationRecord(id='18058525', status='COMPLETE'),
#   OptimizationRecord(id='18068603', status='COMPLETE'),
#   OptimizationRecord(id='18068604', status='COMPLETE'),
#   OptimizationRecord(id='18068613', status='COMPLETE'),
#   OptimizationRecord(id='18068614', status='COMPLETE'),
#   OptimizationRecord(id='18068615', status='COMPLETE'),
#   OptimizationRecord(id='18068616', status='COMPLETE'),
#   OptimizationRecord(id='18081227', status='COMPLETE'),
#   OptimizationRecord(id='18081228', status='COMPLETE'),
#   OptimizationRecord(id='18081229', status='COMPLETE'),
#   OptimizationRecord(id='18081230', status='COMPLETE'),
#   OptimizationRecord(id='18092571', status='COMPLETE'),
#   OptimizationRecord(id='18092572', status='COMPLETE'),
#   OptimizationRecord(id='18092573', status='COMPLETE'),
#   OptimizationRecord(id='18092574', status='COMPLETE'),
#   OptimizationRecord(id='18092575', status='COMPLETE'),
#   OptimizationRecord(id='18092576', status='COMPLETE'),
#   OptimizationRecord(id='18092577', status='COMPLETE'),
#   OptimizationRecord(id='18092578', status='COMPLETE'),
#   OptimizationRecord(id='18113900', status='COMPLETE'),
#   OptimizationRecord(id='18113901', status='COMPLETE'),
#   OptimizationRecord(id='18113943', status='COMPLETE'),
#   OptimizationRecord(id='18113948', status='COMPLETE'),
#   OptimizationRecord(id='18128532', status='COMPLETE'),
#   OptimizationRecord(id='18128533', status='COMPLETE'),
#   OptimizationRecord(id='18128534', status='COMPLETE'),
#   OptimizationRecord(id='18128535', status='COMPLETE'),
#   OptimizationRecord(id='18135454', status='COMPLETE'),
#   OptimizationRecord(id='18135455', status='COMPLETE'),
#   OptimizationRecord(id='18135456', status='COMPLETE'),
#   OptimizationRecord(id='18135457', status='COMPLETE'),
#   OptimizationRecord(id='18144019', status='INCOMPLETE'),
#   OptimizationRecord(id='18144020', status='COMPLETE'),
#   OptimizationRecord(id='18144033', status='COMPLETE'),
#   OptimizationRecord(id='18144034', status='COMPLETE')],
#  '18045339': [OptimizationRecord(id='18045413', status='COMPLETE'),
#   OptimizationRecord(id='18046936', status='COMPLETE'),
#   OptimizationRecord(id='18046937', status='COMPLETE'),
#   OptimizationRecord(id='18059192', status='COMPLETE'),
#   OptimizationRecord(id='18059193', status='COMPLETE'),
#   OptimizationRecord(id='18059194', status='COMPLETE'),
#   OptimizationRecord(id='18059195', status='COMPLETE'),
#   OptimizationRecord(id='18071893', status='COMPLETE'),
#   OptimizationRecord(id='18071894', status='COMPLETE'),
#   OptimizationRecord(id='18071895', status='COMPLETE'),
#   OptimizationRecord(id='18071896', status='COMPLETE'),
#   OptimizationRecord(id='18084415', status='COMPLETE'),
#   OptimizationRecord(id='18084416', status='COMPLETE'),
#   OptimizationRecord(id='18084417', status='COMPLETE'),
#   OptimizationRecord(id='18084418', status='COMPLETE'),
#   OptimizationRecord(id='18096099', status='COMPLETE'),
#   OptimizationRecord(id='18096100', status='COMPLETE'),
#   OptimizationRecord(id='18096101', status='COMPLETE'),
#   OptimizationRecord(id='18096102', status='COMPLETE'),
#   OptimizationRecord(id='18108388', status='COMPLETE'),
#   OptimizationRecord(id='18108397', status='COMPLETE'),
#   OptimizationRecord(id='18108415', status='COMPLETE'),
#   OptimizationRecord(id='18108416', status='COMPLETE'),
#   OptimizationRecord(id='18120293', status='COMPLETE'),
#   OptimizationRecord(id='18120294', status='COMPLETE'),
#   OptimizationRecord(id='18120295', status='COMPLETE'),
#   OptimizationRecord(id='18120296', status='COMPLETE'),
#   OptimizationRecord(id='18127803', status='COMPLETE'),
#   OptimizationRecord(id='18127804', status='COMPLETE'),
#   OptimizationRecord(id='18127805', status='COMPLETE'),
#   OptimizationRecord(id='18127806', status='COMPLETE'),
#   OptimizationRecord(id='18135635', status='COMPLETE'),
#   OptimizationRecord(id='18135636', status='COMPLETE'),
#   OptimizationRecord(id='18135637', status='COMPLETE'),
#   OptimizationRecord(id='18135638', status='COMPLETE'),
#   OptimizationRecord(id='18144035', status='INCOMPLETE'),
#   OptimizationRecord(id='18144036', status='COMPLETE'),
#   OptimizationRecord(id='18144037', status='COMPLETE'),
#   OptimizationRecord(id='18144038', status='COMPLETE')],
#  '18045349': [OptimizationRecord(id='18045458', status='COMPLETE'),
#   OptimizationRecord(id='18046572', status='COMPLETE'),
#   OptimizationRecord(id='18046573', status='COMPLETE'),
#   OptimizationRecord(id='18055296', status='COMPLETE'),
#   OptimizationRecord(id='18055297', status='COMPLETE'),
#   OptimizationRecord(id='18055298', status='COMPLETE'),
#   OptimizationRecord(id='18055299', status='COMPLETE'),
#   OptimizationRecord(id='18149799', status='COMPLETE'),
#   OptimizationRecord(id='18149800', status='COMPLETE'),
#   OptimizationRecord(id='18149801', status='COMPLETE'),
#   OptimizationRecord(id='18149802', status='COMPLETE'),
#   OptimizationRecord(id='18158671', status='COMPLETE'),
#   OptimizationRecord(id='18158672', status='COMPLETE'),
#   OptimizationRecord(id='18158673', status='COMPLETE'),
#   OptimizationRecord(id='18158674', status='COMPLETE'),
#   OptimizationRecord(id='18165875', status='COMPLETE'),
#   OptimizationRecord(id='18165901', status='COMPLETE'),
#   OptimizationRecord(id='18165902', status='COMPLETE'),
#   OptimizationRecord(id='18165903', status='COMPLETE'),
#   OptimizationRecord(id='18174168', status='COMPLETE'),
#   OptimizationRecord(id='18174169', status='COMPLETE'),
#   OptimizationRecord(id='18174170', status='COMPLETE'),
#   OptimizationRecord(id='18174171', status='COMPLETE'),
#   OptimizationRecord(id='18186493', status='COMPLETE'),
#   OptimizationRecord(id='18186494', status='COMPLETE'),
#   OptimizationRecord(id='18186495', status='COMPLETE'),
#   OptimizationRecord(id='18186496', status='INCOMPLETE')],
#  '18045366': [OptimizationRecord(id='18045522', status='COMPLETE'),
#   OptimizationRecord(id='18045523', status='COMPLETE'),
#   OptimizationRecord(id='18045524', status='COMPLETE'),
#   OptimizationRecord(id='18047696', status='COMPLETE'),
#   OptimizationRecord(id='18047697', status='COMPLETE'),
#   OptimizationRecord(id='18047698', status='COMPLETE'),
#   OptimizationRecord(id='18047699', status='COMPLETE'),
#   OptimizationRecord(id='18064185', status='COMPLETE'),
#   OptimizationRecord(id='18064186', status='COMPLETE'),
#   OptimizationRecord(id='18064187', status='COMPLETE'),
#   OptimizationRecord(id='18064206', status='COMPLETE'),
#   OptimizationRecord(id='18064207', status='COMPLETE'),
#   OptimizationRecord(id='18064208', status='COMPLETE'),
#   OptimizationRecord(id='18064209', status='COMPLETE'),
#   OptimizationRecord(id='18064210', status='COMPLETE'),
#   OptimizationRecord(id='18078098', status='COMPLETE'),
#   OptimizationRecord(id='18078099', status='COMPLETE'),
#   OptimizationRecord(id='18078100', status='COMPLETE'),
#   OptimizationRecord(id='18078101', status='COMPLETE'),
#   OptimizationRecord(id='18078102', status='COMPLETE'),
#   OptimizationRecord(id='18078103', status='COMPLETE'),
#   OptimizationRecord(id='18078104', status='COMPLETE'),
#   OptimizationRecord(id='18078105', status='COMPLETE'),
#   OptimizationRecord(id='18096103', status='COMPLETE'),
#   OptimizationRecord(id='18096104', status='COMPLETE'),
#   OptimizationRecord(id='18096105', status='COMPLETE'),
#   OptimizationRecord(id='18096106', status='COMPLETE'),
#   OptimizationRecord(id='18096107', status='COMPLETE'),
#   OptimizationRecord(id='18096108', status='COMPLETE'),
#   OptimizationRecord(id='18096109', status='COMPLETE'),
#   OptimizationRecord(id='18096110', status='COMPLETE'),
#   OptimizationRecord(id='18107326', status='COMPLETE'),
#   OptimizationRecord(id='18107327', status='COMPLETE'),
#   OptimizationRecord(id='18107328', status='COMPLETE'),
#   OptimizationRecord(id='18107329', status='COMPLETE'),
#   OptimizationRecord(id='18107330', status='COMPLETE'),
#   OptimizationRecord(id='18107331', status='COMPLETE'),
#   OptimizationRecord(id='18136179', status='COMPLETE'),
#   OptimizationRecord(id='18136180', status='COMPLETE'),
#   OptimizationRecord(id='18136181', status='COMPLETE'),
#   OptimizationRecord(id='18136182', status='COMPLETE'),
#   OptimizationRecord(id='18144039', status='COMPLETE'),
#   OptimizationRecord(id='18144040', status='COMPLETE'),
#   OptimizationRecord(id='18144041', status='INCOMPLETE'),
#   OptimizationRecord(id='18144042', status='COMPLETE')],
#  '18045367': [OptimizationRecord(id='18045525', status='COMPLETE'),
#   OptimizationRecord(id='18045526', status='COMPLETE'),
#   OptimizationRecord(id='18045527', status='COMPLETE'),
#   OptimizationRecord(id='18045528', status='COMPLETE'),
#   OptimizationRecord(id='18047962', status='INCOMPLETE'),
#   OptimizationRecord(id='18047963', status='COMPLETE'),
#   OptimizationRecord(id='18047964', status='COMPLETE'),
#   OptimizationRecord(id='18047965', status='COMPLETE')],
#  '18045372': [OptimizationRecord(id='18045536', status='ERROR'),
#   OptimizationRecord(id='18045537', status='COMPLETE'),
#   OptimizationRecord(id='18045538', status='ERROR'),
#   OptimizationRecord(id='18045539', status='ERROR'),
#   OptimizationRecord(id='18045540', status='ERROR')]}

# %%
resm = get_unfinished_torsiondrive_optimizations(ds, 'default', client, merged=True)

# %%
incomplete = (opt.dict() for opt in resm if opt.status == 'INCOMPLETE')

# %%
next(incomplete)
# Out:
# {'id': '18047899',
#  'hash_index': 'b1628857d19f073372327b18f6140be254e4be5b',
#  'procedure': 'optimization',
#  'program': 'geometric',
#  'version': 1,
#  'protocols': {},
#  'extras': {},
#  'stdout': '20995173',
#  'stderr': None,
#  'error': None,
#  'task_id': None,
#  'manager_name': None,
#  'status': <RecordStatusEnum.incomplete: 'INCOMPLETE'>,
#  'modified_on': datetime.datetime(2020, 3, 14, 1, 24, 46, 892186),
#  'created_on': datetime.datetime(2020, 3, 13, 21, 16, 9, 469776),
#  'provenance': {'creator': 'geomeTRIC',
#   'version': '0.9.7.2',
#   'routine': 'geometric.run_json.geometric_run_json',
#   'username': 'chodera',
#   'wall_time': 84.95713329315186,
#   'cpu': 'Intel(R) Xeon(R) CPU E5-2697 v4 @ 2.30GHz',
#   'qcengine_version': '0.14.0',
#   'hostname': 'ls13'},
#  'schema_version': 1,
#  'initial_molecule': '11767251',
#  'qc_spec': {'driver': <DriverEnum.gradient: 'gradient'>,
#   'method': 'b3lyp-d3bj',
#   'basis': 'dzvp',
#   'keywords': '2',
#   'program': 'psi4'},
#  'keywords': {'coordsys': 'tric',
#   'enforce': 0.1,
#   'reset': True,
#   'qccnv': True,
#   'epsilon': 0,
#   'constraints': {'set': [{'type': 'dihedral',
#      'indices': [0, 2, 3, 1],
#      'value': 75}]},
#   'program': 'psi4'},
#  'energies': [-158.48473542907092,
#   -158.48515692494664,
#   -158.48544337560912,
#   -158.48577360513067,
#   -158.48602622446123,
#   -158.48615254821843,
#   -158.48615891570498,
#   -158.48617408222924,
#   -158.48618005791081,
#   -158.4861826531143,
#   -158.48618276434942],
#  'final_molecule': '11781143',
#  'trajectory': ['18047886',
#   '18062745',
#   '18062747',
#   '18062749',
#   '18062751',
#   '18062753',
#   '18062755',
#   '18062757',
#   '18062759',
#   '18062761',
#   '18062762']}

# %% [markdown]
# All Lilac INCOMPLETEs?

# %%
restart_optimizations(resm, client)
# Out:
# OptimizationRecord(id='18045536', status='ERROR')
# OptimizationRecord(id='18045538', status='ERROR')
# OptimizationRecord(id='18045539', status='ERROR')
# OptimizationRecord(id='18045540', status='ERROR')

# %%
[tdr for tdr in ds.df.default if tdr.status == 'ERROR']
# Out:
# [TorsionDriveRecord(id='18045372', status='ERROR')]

# %%
restart_torsiondrives(ds.df.default.tolist(), client)

# %% [markdown]
# ## Dataset tracking - OpenFF Gen 2 Torsion Set 2 Coverage

# %% [markdown]
# ### 2020.06.11 18:45 UTC

# %%
dataset = "OpenFF Gen 2 Torsion Set 2 Coverage"

# %%
ds = client.get_collection("TorsionDriveDataset", dataset)

# %%
ds.list_specifications()
# Out:
#                                          Description
# Name
# default  Standard OpenFF torsiondrive specification.

# %%
res = get_unfinished_torsiondrive_optimizations(ds, 'default', client, merged=False)
res
# Out:
# {'18045425': [OptimizationRecord(id='18045643', status='COMPLETE'),
#   OptimizationRecord(id='18048157', status='COMPLETE'),
#   OptimizationRecord(id='18048158', status='COMPLETE'),
#   OptimizationRecord(id='18066379', status='COMPLETE'),
#   OptimizationRecord(id='18066380', status='COMPLETE'),
#   OptimizationRecord(id='18066381', status='COMPLETE'),
#   OptimizationRecord(id='18066382', status='COMPLETE'),
#   OptimizationRecord(id='18075805', status='COMPLETE'),
#   OptimizationRecord(id='18075806', status='COMPLETE'),
#   OptimizationRecord(id='18075807', status='COMPLETE'),
#   OptimizationRecord(id='18075808', status='COMPLETE'),
#   OptimizationRecord(id='18086888', status='COMPLETE'),
#   OptimizationRecord(id='18086889', status='COMPLETE'),
#   OptimizationRecord(id='18086890', status='COMPLETE'),
#   OptimizationRecord(id='18086891', status='COMPLETE'),
#   OptimizationRecord(id='18097951', status='ERROR'),
#   OptimizationRecord(id='18097952', status='COMPLETE'),
#   OptimizationRecord(id='18097953', status='COMPLETE'),
#   OptimizationRecord(id='18097954', status='COMPLETE')],
#  '18045451': [OptimizationRecord(id='18045817', status='COMPLETE'),
#   OptimizationRecord(id='18049063', status='COMPLETE'),
#   OptimizationRecord(id='18049064', status='COMPLETE'),
#   OptimizationRecord(id='18062648', status='COMPLETE'),
#   OptimizationRecord(id='18062649', status='COMPLETE'),
#   OptimizationRecord(id='18062650', status='COMPLETE'),
#   OptimizationRecord(id='18062651', status='COMPLETE'),
#   OptimizationRecord(id='18073623', status='COMPLETE'),
#   OptimizationRecord(id='18073624', status='COMPLETE'),
#   OptimizationRecord(id='18073625', status='COMPLETE'),
#   OptimizationRecord(id='18073626', status='COMPLETE'),
#   OptimizationRecord(id='18084145', status='COMPLETE'),
#   OptimizationRecord(id='18084146', status='COMPLETE'),
#   OptimizationRecord(id='18084147', status='COMPLETE'),
#   OptimizationRecord(id='18084148', status='COMPLETE'),
#   OptimizationRecord(id='18094848', status='COMPLETE'),
#   OptimizationRecord(id='18094849', status='COMPLETE'),
#   OptimizationRecord(id='18094850', status='COMPLETE'),
#   OptimizationRecord(id='18094851', status='COMPLETE'),
#   OptimizationRecord(id='18106712', status='COMPLETE'),
#   OptimizationRecord(id='18106713', status='COMPLETE'),
#   OptimizationRecord(id='18106714', status='COMPLETE'),
#   OptimizationRecord(id='18106715', status='COMPLETE'),
#   OptimizationRecord(id='18121337', status='COMPLETE'),
#   OptimizationRecord(id='18121338', status='COMPLETE'),
#   OptimizationRecord(id='18121339', status='COMPLETE'),
#   OptimizationRecord(id='18121340', status='COMPLETE'),
#   OptimizationRecord(id='18131233', status='COMPLETE'),
#   OptimizationRecord(id='18131234', status='COMPLETE'),
#   OptimizationRecord(id='18131235', status='COMPLETE'),
#   OptimizationRecord(id='18131236', status='COMPLETE'),
#   OptimizationRecord(id='18138389', status='COMPLETE'),
#   OptimizationRecord(id='18138390', status='COMPLETE'),
#   OptimizationRecord(id='18138391', status='COMPLETE'),
#   OptimizationRecord(id='18138404', status='COMPLETE'),
#   OptimizationRecord(id='18149661', status='COMPLETE'),
#   OptimizationRecord(id='18149662', status='COMPLETE'),
#   OptimizationRecord(id='18149663', status='COMPLETE'),
#   OptimizationRecord(id='18149664', status='COMPLETE'),
#   OptimizationRecord(id='18158675', status='COMPLETE'),
#   OptimizationRecord(id='18158676', status='COMPLETE'),
#   OptimizationRecord(id='18158677', status='COMPLETE'),
#   OptimizationRecord(id='18158678', status='COMPLETE'),
#   OptimizationRecord(id='18158679', status='COMPLETE'),
#   OptimizationRecord(id='18158697', status='COMPLETE'),
#   OptimizationRecord(id='18158698', status='COMPLETE'),
#   OptimizationRecord(id='18158699', status='COMPLETE'),
#   OptimizationRecord(id='18171275', status='COMPLETE'),
#   OptimizationRecord(id='18171276', status='COMPLETE'),
#   OptimizationRecord(id='18171277', status='COMPLETE'),
#   OptimizationRecord(id='18171278', status='COMPLETE'),
#   OptimizationRecord(id='18171279', status='COMPLETE'),
#   OptimizationRecord(id='18171280', status='COMPLETE'),
#   OptimizationRecord(id='18171281', status='COMPLETE'),
#   OptimizationRecord(id='18171293', status='COMPLETE'),
#   OptimizationRecord(id='18171294', status='COMPLETE'),
#   OptimizationRecord(id='18171295', status='COMPLETE'),
#   OptimizationRecord(id='18171315', status='COMPLETE'),
#   OptimizationRecord(id='18171316', status='COMPLETE'),
#   OptimizationRecord(id='18185022', status='INCOMPLETE'),
#   OptimizationRecord(id='18185023', status='COMPLETE'),
#   OptimizationRecord(id='18185024', status='COMPLETE'),
#   OptimizationRecord(id='18185025', status='COMPLETE'),
#   OptimizationRecord(id='18185026', status='COMPLETE'),
#   OptimizationRecord(id='18185027', status='COMPLETE')],
#  '18045454': [OptimizationRecord(id='18045818', status='COMPLETE'),
#   OptimizationRecord(id='18045819', status='COMPLETE'),
#   OptimizationRecord(id='18045820', status='COMPLETE'),
#   OptimizationRecord(id='18045821', status='COMPLETE'),
#   OptimizationRecord(id='18045822', status='COMPLETE'),
#   OptimizationRecord(id='18045823', status='COMPLETE'),
#   OptimizationRecord(id='18045824', status='COMPLETE'),
#   OptimizationRecord(id='18045825', status='COMPLETE'),
#   OptimizationRecord(id='18058703', status='COMPLETE'),
#   OptimizationRecord(id='18058704', status='COMPLETE'),
#   OptimizationRecord(id='18058705', status='COMPLETE'),
#   OptimizationRecord(id='18058706', status='COMPLETE'),
#   OptimizationRecord(id='18058707', status='COMPLETE'),
#   OptimizationRecord(id='18058708', status='COMPLETE'),
#   OptimizationRecord(id='18058709', status='COMPLETE'),
#   OptimizationRecord(id='18058710', status='COMPLETE'),
#   OptimizationRecord(id='18058711', status='COMPLETE'),
#   OptimizationRecord(id='18058712', status='COMPLETE'),
#   OptimizationRecord(id='18058713', status='COMPLETE'),
#   OptimizationRecord(id='18058714', status='COMPLETE'),
#   OptimizationRecord(id='18080103', status='COMPLETE'),
#   OptimizationRecord(id='18080104', status='COMPLETE'),
#   OptimizationRecord(id='18080105', status='COMPLETE'),
#   OptimizationRecord(id='18080106', status='COMPLETE'),
#   OptimizationRecord(id='18080107', status='COMPLETE'),
#   OptimizationRecord(id='18080108', status='COMPLETE'),
#   OptimizationRecord(id='18080109', status='COMPLETE'),
#   OptimizationRecord(id='18080110', status='COMPLETE'),
#   OptimizationRecord(id='18080111', status='COMPLETE'),
#   OptimizationRecord(id='18080112', status='COMPLETE'),
#   OptimizationRecord(id='18080113', status='COMPLETE'),
#   OptimizationRecord(id='18080114', status='COMPLETE'),
#   OptimizationRecord(id='18080115', status='COMPLETE'),
#   OptimizationRecord(id='18080133', status='COMPLETE'),
#   OptimizationRecord(id='18080134', status='COMPLETE'),
#   OptimizationRecord(id='18080151', status='COMPLETE'),
#   OptimizationRecord(id='18080165', status='COMPLETE'),
#   OptimizationRecord(id='18080178', status='COMPLETE'),
#   OptimizationRecord(id='18102688', status='COMPLETE'),
#   OptimizationRecord(id='18102689', status='COMPLETE'),
#   OptimizationRecord(id='18102690', status='COMPLETE'),
#   OptimizationRecord(id='18102691', status='COMPLETE'),
#   OptimizationRecord(id='18102692', status='COMPLETE'),
#   OptimizationRecord(id='18102693', status='COMPLETE'),
#   OptimizationRecord(id='18102694', status='COMPLETE'),
#   OptimizationRecord(id='18102695', status='COMPLETE'),
#   OptimizationRecord(id='18102696', status='COMPLETE'),
#   OptimizationRecord(id='18102697', status='COMPLETE'),
#   OptimizationRecord(id='18102698', status='COMPLETE'),
#   OptimizationRecord(id='18102699', status='COMPLETE'),
#   OptimizationRecord(id='18102700', status='COMPLETE'),
#   OptimizationRecord(id='18102701', status='COMPLETE'),
#   OptimizationRecord(id='18102702', status='COMPLETE'),
#   OptimizationRecord(id='18102703', status='COMPLETE'),
#   OptimizationRecord(id='18129151', status='COMPLETE'),
#   OptimizationRecord(id='18129152', status='COMPLETE'),
#   OptimizationRecord(id='18129153', status='COMPLETE'),
#   OptimizationRecord(id='18129154', status='COMPLETE'),
#   OptimizationRecord(id='18129155', status='COMPLETE'),
#   OptimizationRecord(id='18129156', status='COMPLETE'),
#   OptimizationRecord(id='18129157', status='COMPLETE'),
#   OptimizationRecord(id='18129158', status='COMPLETE'),
#   OptimizationRecord(id='18129159', status='COMPLETE'),
#   OptimizationRecord(id='18129160', status='COMPLETE'),
#   OptimizationRecord(id='18129161', status='COMPLETE'),
#   OptimizationRecord(id='18129162', status='COMPLETE'),
#   OptimizationRecord(id='18129163', status='COMPLETE'),
#   OptimizationRecord(id='18129164', status='COMPLETE'),
#   OptimizationRecord(id='18144347', status='COMPLETE'),
#   OptimizationRecord(id='18144348', status='COMPLETE'),
#   OptimizationRecord(id='18144349', status='COMPLETE'),
#   OptimizationRecord(id='18144350', status='COMPLETE'),
#   OptimizationRecord(id='18144363', status='COMPLETE'),
#   OptimizationRecord(id='18144364', status='COMPLETE'),
#   OptimizationRecord(id='18144365', status='INCOMPLETE'),
#   OptimizationRecord(id='18144366', status='COMPLETE')],
#  '18045460': [OptimizationRecord(id='18045842', status='COMPLETE'),
#   OptimizationRecord(id='18045843', status='COMPLETE'),
#   OptimizationRecord(id='18045844', status='COMPLETE'),
#   OptimizationRecord(id='18045845', status='COMPLETE'),
#   OptimizationRecord(id='18045846', status='COMPLETE'),
#   OptimizationRecord(id='18050965', status='COMPLETE'),
#   OptimizationRecord(id='18050966', status='INCOMPLETE'),
#   OptimizationRecord(id='18050967', status='COMPLETE'),
#   OptimizationRecord(id='18050968', status='COMPLETE'),
#   OptimizationRecord(id='18050969', status='COMPLETE'),
#   OptimizationRecord(id='18050970', status='COMPLETE')],
#  '18045462': [OptimizationRecord(id='18045847', status='COMPLETE'),
#   OptimizationRecord(id='18045848', status='COMPLETE'),
#   OptimizationRecord(id='18045849', status='COMPLETE'),
#   OptimizationRecord(id='18050293', status='COMPLETE'),
#   OptimizationRecord(id='18050294', status='COMPLETE'),
#   OptimizationRecord(id='18050295', status='COMPLETE'),
#   OptimizationRecord(id='18050296', status='INCOMPLETE')],
#  '18045487': [OptimizationRecord(id='18045973', status='COMPLETE'),
#   OptimizationRecord(id='18045974', status='COMPLETE'),
#   OptimizationRecord(id='18045975', status='COMPLETE'),
#   OptimizationRecord(id='18045976', status='COMPLETE'),
#   OptimizationRecord(id='18045977', status='COMPLETE'),
#   OptimizationRecord(id='18045978', status='COMPLETE'),
#   OptimizationRecord(id='18045979', status='COMPLETE'),
#   OptimizationRecord(id='18045980', status='COMPLETE'),
#   OptimizationRecord(id='18045981', status='COMPLETE'),
#   OptimizationRecord(id='18045982', status='COMPLETE'),
#   OptimizationRecord(id='18045983', status='COMPLETE'),
#   OptimizationRecord(id='18045984', status='COMPLETE'),
#   OptimizationRecord(id='18051100', status='INCOMPLETE'),
#   OptimizationRecord(id='18051101', status='COMPLETE'),
#   OptimizationRecord(id='18051102', status='COMPLETE'),
#   OptimizationRecord(id='18051103', status='COMPLETE'),
#   OptimizationRecord(id='18051104', status='COMPLETE'),
#   OptimizationRecord(id='18051105', status='COMPLETE'),
#   OptimizationRecord(id='18051106', status='COMPLETE'),
#   OptimizationRecord(id='18051107', status='COMPLETE'),
#   OptimizationRecord(id='18051108', status='COMPLETE'),
#   OptimizationRecord(id='18051109', status='COMPLETE')],
#  '18045499': [OptimizationRecord(id='18046033', status='ERROR'),
#   OptimizationRecord(id='18046034', status='COMPLETE')]}

# %%
resm = get_unfinished_torsiondrive_optimizations(ds, 'default', client, merged=True)

# %%
incomplete = (opt.dict() for opt in resm if opt.status == 'INCOMPLETE')

# %%
next(incomplete)
# Out:
# {'id': '18050296',
#  'hash_index': '8ee5760a55eb161aa73ead9292a4f0b0b1e8d0e0',
#  'procedure': 'optimization',
#  'program': 'geometric',
#  'version': 1,
#  'protocols': {},
#  'extras': {},
#  'stdout': '20996575',
#  'stderr': None,
#  'error': None,
#  'task_id': None,
#  'manager_name': None,
#  'status': <RecordStatusEnum.incomplete: 'INCOMPLETE'>,
#  'modified_on': datetime.datetime(2020, 3, 14, 1, 24, 46, 807529),
#  'created_on': datetime.datetime(2020, 3, 13, 22, 28, 13, 951684),
#  'provenance': {'creator': 'geomeTRIC',
#   'version': '0.9.7.2',
#   'routine': 'geometric.run_json.geometric_run_json',
#   'username': 'chodera',
#   'wall_time': 166.50083994865417,
#   'hostname': 'lt01',
#   'cpu': 'Intel(R) Xeon(R) CPU E5-2697 v4 @ 2.30GHz',
#   'qcengine_version': '0.14.0'},
#  'schema_version': 1,
#  'initial_molecule': '11769440',
#  'qc_spec': {'driver': <DriverEnum.gradient: 'gradient'>,
#   'method': 'b3lyp-d3bj',
#   'basis': 'dzvp',
#   'keywords': '2',
#   'program': 'psi4'},
#  'keywords': {'coordsys': 'tric',
#   'enforce': 0.1,
#   'reset': True,
#   'qccnv': True,
#   'epsilon': 0,
#   'constraints': {'set': [{'type': 'dihedral',
#      'indices': [2, 7, 3, 5],
#      'value': 165}]},
#   'program': 'psi4'},
#  'energies': [-418.4892598870526,
#   -418.48907842143325,
#   -418.4889025232605,
#   -418.48868604187567,
#   -418.4887563867417,
#   -418.48876024469973,
#   -418.4887642432538,
#   -418.4887690928167,
#   -418.48877318117076,
#   -418.4887762029255,
#   -418.48877802930906,
#   -418.48877870124164],
#  'final_molecule': '11782240',
#  'trajectory': ['18050235',
#   '18063911',
#   '18063913',
#   '18063915',
#   '18063918',
#   '18063920',
#   '18063922',
#   '18063924',
#   '18063926',
#   '18063928',
#   '18063929',
#   '18063930']}

# %% [markdown]
# All Lilac INCOMPLETEs?

# %%
count_unique_optimization_error_messages(resm, pretty_print=True)
# Out:
# There are 2 instances of
# -------------------------------------
# ValueError: Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates
# -------------------------------------

# %%
restart_optimizations(resm, client)
# Out:
# OptimizationRecord(id='18046033', status='ERROR')
# OptimizationRecord(id='18097951', status='ERROR')

# %%
restart_torsiondrives(ds.df.default.tolist(), client)
# Out:
# TorsionDriveRecord(id='18045425', status='ERROR')
# TorsionDriveRecord(id='2703602', status='ERROR')
# TorsionDriveRecord(id='18045499', status='ERROR')
# TorsionDriveRecord(id='2703594', status='ERROR')

# %% [markdown]
# ## Dataset tracking - OpenFF Gen 2 Torsion Set 3 Pfizer Discrepancy

# %% [markdown]
# ### 2020.06.11 18:45 UTC

# %%
dataset = "OpenFF Gen 2 Torsion Set 3 Pfizer Discrepancy"

# %%
ds = client.get_collection("TorsionDriveDataset", dataset)

# %%
ds.list_specifications()
# Out:
#                                          Description
# Name
# default  Standard OpenFF torsiondrive specification.

# %%
res = get_unfinished_torsiondrive_optimizations(ds, 'default', client, merged=False)
res
# Out:
# {'18045543': [OptimizationRecord(id='18046044', status='COMPLETE'),
#   OptimizationRecord(id='18052655', status='COMPLETE'),
#   OptimizationRecord(id='18052656', status='COMPLETE'),
#   OptimizationRecord(id='18065406', status='COMPLETE'),
#   OptimizationRecord(id='18065407', status='COMPLETE'),
#   OptimizationRecord(id='18065408', status='COMPLETE'),
#   OptimizationRecord(id='18065409', status='COMPLETE'),
#   OptimizationRecord(id='18078133', status='COMPLETE'),
#   OptimizationRecord(id='18078134', status='COMPLETE'),
#   OptimizationRecord(id='18078135', status='COMPLETE'),
#   OptimizationRecord(id='18078136', status='COMPLETE'),
#   OptimizationRecord(id='18092291', status='COMPLETE'),
#   OptimizationRecord(id='18092292', status='COMPLETE'),
#   OptimizationRecord(id='18092293', status='COMPLETE'),
#   OptimizationRecord(id='18092305', status='COMPLETE'),
#   OptimizationRecord(id='18108838', status='COMPLETE'),
#   OptimizationRecord(id='18108885', status='COMPLETE'),
#   OptimizationRecord(id='18108887', status='COMPLETE'),
#   OptimizationRecord(id='18108888', status='COMPLETE'),
#   OptimizationRecord(id='18119602', status='COMPLETE'),
#   OptimizationRecord(id='18119603', status='COMPLETE'),
#   OptimizationRecord(id='18119604', status='COMPLETE'),
#   OptimizationRecord(id='18119605', status='COMPLETE'),
#   OptimizationRecord(id='18125884', status='COMPLETE'),
#   OptimizationRecord(id='18125885', status='COMPLETE'),
#   OptimizationRecord(id='18125886', status='COMPLETE'),
#   OptimizationRecord(id='18125887', status='COMPLETE'),
#   OptimizationRecord(id='18132047', status='COMPLETE'),
#   OptimizationRecord(id='18132048', status='COMPLETE'),
#   OptimizationRecord(id='18132049', status='COMPLETE'),
#   OptimizationRecord(id='18132050', status='COMPLETE'),
#   OptimizationRecord(id='18144377', status='COMPLETE'),
#   OptimizationRecord(id='18144378', status='INCOMPLETE'),
#   OptimizationRecord(id='18144379', status='COMPLETE'),
#   OptimizationRecord(id='18144391', status='COMPLETE')],
#  '18045548': [OptimizationRecord(id='18046067', status='COMPLETE'),
#   OptimizationRecord(id='18052475', status='COMPLETE'),
#   OptimizationRecord(id='18052476', status='COMPLETE'),
#   OptimizationRecord(id='18066391', status='COMPLETE'),
#   OptimizationRecord(id='18066392', status='COMPLETE'),
#   OptimizationRecord(id='18066393', status='COMPLETE'),
#   OptimizationRecord(id='18066394', status='COMPLETE'),
#   OptimizationRecord(id='18077675', status='COMPLETE'),
#   OptimizationRecord(id='18077676', status='COMPLETE'),
#   OptimizationRecord(id='18077677', status='COMPLETE'),
#   OptimizationRecord(id='18077678', status='COMPLETE'),
#   OptimizationRecord(id='18089283', status='COMPLETE'),
#   OptimizationRecord(id='18089284', status='COMPLETE'),
#   OptimizationRecord(id='18089285', status='COMPLETE'),
#   OptimizationRecord(id='18089286', status='COMPLETE'),
#   OptimizationRecord(id='18101276', status='COMPLETE'),
#   OptimizationRecord(id='18101277', status='COMPLETE'),
#   OptimizationRecord(id='18101278', status='COMPLETE'),
#   OptimizationRecord(id='18101279', status='COMPLETE'),
#   OptimizationRecord(id='18114275', status='COMPLETE'),
#   OptimizationRecord(id='18114276', status='COMPLETE'),
#   OptimizationRecord(id='18114277', status='COMPLETE'),
#   OptimizationRecord(id='18114278', status='COMPLETE'),
#   OptimizationRecord(id='18131237', status='COMPLETE'),
#   OptimizationRecord(id='18131238', status='COMPLETE'),
#   OptimizationRecord(id='18131239', status='COMPLETE'),
#   OptimizationRecord(id='18131250', status='COMPLETE'),
#   OptimizationRecord(id='18144660', status='INCOMPLETE'),
#   OptimizationRecord(id='18144663', status='COMPLETE'),
#   OptimizationRecord(id='18144680', status='COMPLETE'),
#   OptimizationRecord(id='18144682', status='COMPLETE')],
#  '18045555': [OptimizationRecord(id='18046085', status='COMPLETE'),
#   OptimizationRecord(id='18046086', status='COMPLETE'),
#   OptimizationRecord(id='18057933', status='COMPLETE'),
#   OptimizationRecord(id='18057934', status='COMPLETE'),
#   OptimizationRecord(id='18068346', status='COMPLETE'),
#   OptimizationRecord(id='18068347', status='COMPLETE'),
#   OptimizationRecord(id='18068348', status='COMPLETE'),
#   OptimizationRecord(id='18068349', status='COMPLETE'),
#   OptimizationRecord(id='18078426', status='COMPLETE'),
#   OptimizationRecord(id='18078427', status='COMPLETE'),
#   OptimizationRecord(id='18078445', status='COMPLETE'),
#   OptimizationRecord(id='18078446', status='COMPLETE'),
#   OptimizationRecord(id='18090658', status='COMPLETE'),
#   OptimizationRecord(id='18090659', status='COMPLETE'),
#   OptimizationRecord(id='18090660', status='COMPLETE'),
#   OptimizationRecord(id='18090662', status='COMPLETE'),
#   OptimizationRecord(id='18102421', status='COMPLETE'),
#   OptimizationRecord(id='18102422', status='COMPLETE'),
#   OptimizationRecord(id='18102423', status='COMPLETE'),
#   OptimizationRecord(id='18102424', status='COMPLETE'),
#   OptimizationRecord(id='18115237', status='COMPLETE'),
#   OptimizationRecord(id='18115238', status='COMPLETE'),
#   OptimizationRecord(id='18115239', status='COMPLETE'),
#   OptimizationRecord(id='18115240', status='INCOMPLETE'),
#   OptimizationRecord(id='18115241', status='COMPLETE'),
#   OptimizationRecord(id='18115242', status='COMPLETE')]}

# %%
resm = get_unfinished_torsiondrive_optimizations(ds, 'default', client, merged=True)

# %%
incomplete = (opt.dict() for opt in resm if opt.status == 'INCOMPLETE')

# %%
next(incomplete)
# Out:
# {'id': '18115240',
#  'hash_index': 'ff894ef7b9586f1c62e61fb575bc296529e91f96',
#  'procedure': 'optimization',
#  'program': 'geometric',
#  'version': 1,
#  'protocols': {},
#  'extras': {},
#  'stdout': '21063530',
#  'stderr': None,
#  'error': None,
#  'task_id': None,
#  'manager_name': None,
#  'status': <RecordStatusEnum.incomplete: 'INCOMPLETE'>,
#  'modified_on': datetime.datetime(2020, 3, 14, 6, 46, 18, 8855),
#  'created_on': datetime.datetime(2020, 3, 14, 6, 46, 18, 8857),
#  'provenance': {'creator': 'geomeTRIC',
#   'version': '0.9.7.2',
#   'routine': 'geometric.run_json.geometric_run_json',
#   'username': 'chodera',
#   'wall_time': 459.39927411079407,
#   'hostname': 'lt05',
#   'cpu': 'Intel(R) Xeon(R) CPU E5-2697 v4 @ 2.30GHz',
#   'qcengine_version': '0.14.0'},
#  'schema_version': 1,
#  'initial_molecule': '11827218',
#  'qc_spec': {'driver': <DriverEnum.gradient: 'gradient'>,
#   'method': 'b3lyp-d3bj',
#   'basis': 'dzvp',
#   'keywords': '2',
#   'program': 'psi4'},
#  'keywords': {'coordsys': 'tric',
#   'enforce': 0.1,
#   'reset': True,
#   'qccnv': True,
#   'epsilon': 0,
#   'constraints': {'set': [{'type': 'dihedral',
#      'indices': [7, 11, 3, 9],
#      'value': -45}]},
#   'program': 'psi4'},
#  'energies': [-660.587342185646,
#   -660.5887025704963,
#   -660.5894754826236,
#   -660.5900137194052,
#   -660.5907560637307,
#   -660.5909845308762,
#   -660.5910328041143,
#   -660.5910588038346,
#   -660.5911041805075,
#   -660.5911310072008,
#   -660.5911394605196,
#   -660.5911416249085,
#   -660.591142329595],
#  'final_molecule': '11836208',
#  'trajectory': ['18112902',
#   '18122550',
#   '18122552',
#   '18122554',
#   '18122556',
#   '18122558',
#   '18122559',
#   '18122560',
#   '18122561',
#   '18122562',
#   '18122563',
#   '18122564',
#   '18122565']}

# %% [markdown]
# All Lilac INCOMPLETEs?

# %%
count_unique_optimization_error_messages(resm, pretty_print=True)

# %%
restart_optimizations(resm, client)

# %%
restart_torsiondrives(ds.df.default.tolist(), client)

# %% [markdown]
# ## Dataset tracking - OpenFF Gen 2 Torsion Set 4 eMolecules Discrepancy

# %% [markdown]
# ### 2020.06.11 18:45 UTC

# %%
dataset = "OpenFF Gen 2 Torsion Set 4 eMolecules Discrepancy"

# %%
ds = client.get_collection("TorsionDriveDataset", dataset)

# %%
ds.list_specifications()
# Out:
#                                          Description
# Name
# default  Standard OpenFF torsiondrive specification.

# %%
res = get_unfinished_torsiondrive_optimizations(ds, 'default', client, merged=False)
res
# Out:
# {'18045591': [OptimizationRecord(id='18046247', status='COMPLETE'),
#   OptimizationRecord(id='18046248', status='COMPLETE'),
#   OptimizationRecord(id='18055825', status='COMPLETE'),
#   OptimizationRecord(id='18055826', status='COMPLETE'),
#   OptimizationRecord(id='18068154', status='COMPLETE'),
#   OptimizationRecord(id='18068155', status='COMPLETE'),
#   OptimizationRecord(id='18068156', status='COMPLETE'),
#   OptimizationRecord(id='18068157', status='COMPLETE'),
#   OptimizationRecord(id='18079128', status='COMPLETE'),
#   OptimizationRecord(id='18079129', status='COMPLETE'),
#   OptimizationRecord(id='18079130', status='COMPLETE'),
#   OptimizationRecord(id='18079131', status='COMPLETE'),
#   OptimizationRecord(id='18091759', status='COMPLETE'),
#   OptimizationRecord(id='18091769', status='COMPLETE'),
#   OptimizationRecord(id='18091770', status='COMPLETE'),
#   OptimizationRecord(id='18091771', status='COMPLETE'),
#   OptimizationRecord(id='18106427', status='COMPLETE'),
#   OptimizationRecord(id='18106428', status='COMPLETE'),
#   OptimizationRecord(id='18106429', status='COMPLETE'),
#   OptimizationRecord(id='18106430', status='COMPLETE'),
#   OptimizationRecord(id='18119254', status='COMPLETE'),
#   OptimizationRecord(id='18119255', status='COMPLETE'),
#   OptimizationRecord(id='18119256', status='COMPLETE'),
#   OptimizationRecord(id='18119257', status='COMPLETE'),
#   OptimizationRecord(id='18129220', status='COMPLETE'),
#   OptimizationRecord(id='18129221', status='COMPLETE'),
#   OptimizationRecord(id='18129222', status='COMPLETE'),
#   OptimizationRecord(id='18129223', status='COMPLETE'),
#   OptimizationRecord(id='18138042', status='COMPLETE'),
#   OptimizationRecord(id='18138043', status='COMPLETE'),
#   OptimizationRecord(id='18138044', status='COMPLETE'),
#   OptimizationRecord(id='18138045', status='COMPLETE'),
#   OptimizationRecord(id='18148174', status='COMPLETE'),
#   OptimizationRecord(id='18148179', status='COMPLETE'),
#   OptimizationRecord(id='18148192', status='COMPLETE'),
#   OptimizationRecord(id='18148193', status='COMPLETE'),
#   OptimizationRecord(id='18157950', status='COMPLETE'),
#   OptimizationRecord(id='18157951', status='COMPLETE'),
#   OptimizationRecord(id='18157952', status='COMPLETE'),
#   OptimizationRecord(id='18157953', status='COMPLETE'),
#   OptimizationRecord(id='18169271', status='COMPLETE'),
#   OptimizationRecord(id='18169272', status='COMPLETE'),
#   OptimizationRecord(id='18169273', status='COMPLETE'),
#   OptimizationRecord(id='18169274', status='COMPLETE'),
#   OptimizationRecord(id='18177335', status='COMPLETE'),
#   OptimizationRecord(id='18177336', status='INCOMPLETE'),
#   OptimizationRecord(id='18177337', status='COMPLETE'),
#   OptimizationRecord(id='18177338', status='COMPLETE')],
#  '18045594': [OptimizationRecord(id='18046263', status='COMPLETE'),
#   OptimizationRecord(id='18054332', status='INCOMPLETE'),
#   OptimizationRecord(id='18054333', status='COMPLETE')],
#  '18045605': [OptimizationRecord(id='18046271', status='COMPLETE'),
#   OptimizationRecord(id='18046272', status='COMPLETE'),
#   OptimizationRecord(id='18046273', status='COMPLETE'),
#   OptimizationRecord(id='18046274', status='COMPLETE'),
#   OptimizationRecord(id='18046275', status='COMPLETE'),
#   OptimizationRecord(id='18055314', status='INCOMPLETE'),
#   OptimizationRecord(id='18055315', status='COMPLETE'),
#   OptimizationRecord(id='18055316', status='COMPLETE'),
#   OptimizationRecord(id='18055317', status='COMPLETE')],
#  '18045611': [OptimizationRecord(id='18046297', status='COMPLETE'),
#   OptimizationRecord(id='18046298', status='COMPLETE'),
#   OptimizationRecord(id='18046299', status='COMPLETE'),
#   OptimizationRecord(id='18046300', status='COMPLETE'),
#   OptimizationRecord(id='18046301', status='COMPLETE'),
#   OptimizationRecord(id='18046302', status='COMPLETE'),
#   OptimizationRecord(id='18046303', status='COMPLETE'),
#   OptimizationRecord(id='18046304', status='COMPLETE'),
#   OptimizationRecord(id='18046305', status='COMPLETE'),
#   OptimizationRecord(id='18046306', status='COMPLETE'),
#   OptimizationRecord(id='18046307', status='COMPLETE'),
#   OptimizationRecord(id='18046308', status='COMPLETE'),
#   OptimizationRecord(id='18046309', status='COMPLETE'),
#   OptimizationRecord(id='18046310', status='COMPLETE'),
#   OptimizationRecord(id='18046311', status='COMPLETE'),
#   OptimizationRecord(id='18046312', status='COMPLETE'),
#   OptimizationRecord(id='18046313', status='COMPLETE'),
#   OptimizationRecord(id='18060573', status='COMPLETE'),
#   OptimizationRecord(id='18060574', status='COMPLETE'),
#   OptimizationRecord(id='18070942', status='COMPLETE'),
#   OptimizationRecord(id='18070943', status='COMPLETE'),
#   OptimizationRecord(id='18070944', status='COMPLETE'),
#   OptimizationRecord(id='18070945', status='COMPLETE'),
#   OptimizationRecord(id='18082258', status='COMPLETE'),
#   OptimizationRecord(id='18082259', status='COMPLETE'),
#   OptimizationRecord(id='18082260', status='COMPLETE'),
#   OptimizationRecord(id='18082261', status='COMPLETE'),
#   OptimizationRecord(id='18098988', status='COMPLETE'),
#   OptimizationRecord(id='18098989', status='COMPLETE'),
#   OptimizationRecord(id='18098990', status='COMPLETE'),
#   OptimizationRecord(id='18098991', status='COMPLETE'),
#   OptimizationRecord(id='18113308', status='COMPLETE'),
#   OptimizationRecord(id='18113316', status='COMPLETE'),
#   OptimizationRecord(id='18113325', status='COMPLETE'),
#   OptimizationRecord(id='18113326', status='COMPLETE'),
#   OptimizationRecord(id='18128593', status='COMPLETE'),
#   OptimizationRecord(id='18128594', status='COMPLETE'),
#   OptimizationRecord(id='18128595', status='COMPLETE'),
#   OptimizationRecord(id='18128596', status='COMPLETE'),
#   OptimizationRecord(id='18149471', status='COMPLETE'),
#   OptimizationRecord(id='18149472', status='COMPLETE'),
#   OptimizationRecord(id='18149473', status='COMPLETE'),
#   OptimizationRecord(id='18149474', status='COMPLETE'),
#   OptimizationRecord(id='18157646', status='COMPLETE'),
#   OptimizationRecord(id='18157647', status='COMPLETE'),
#   OptimizationRecord(id='18157648', status='COMPLETE'),
#   OptimizationRecord(id='18157649', status='COMPLETE'),
#   OptimizationRecord(id='18169675', status='COMPLETE'),
#   OptimizationRecord(id='18169676', status='COMPLETE'),
#   OptimizationRecord(id='18169678', status='COMPLETE'),
#   OptimizationRecord(id='18169690', status='COMPLETE'),
#   OptimizationRecord(id='18177720', status='INCOMPLETE'),
#   OptimizationRecord(id='18177721', status='COMPLETE'),
#   OptimizationRecord(id='18177722', status='COMPLETE'),
#   OptimizationRecord(id='18177723', status='INCOMPLETE')],
#  '18045619': [OptimizationRecord(id='18046992', status='COMPLETE'),
#   OptimizationRecord(id='18046993', status='COMPLETE'),
#   OptimizationRecord(id='18046994', status='COMPLETE'),
#   OptimizationRecord(id='18046995', status='COMPLETE'),
#   OptimizationRecord(id='18046996', status='COMPLETE'),
#   OptimizationRecord(id='18046997', status='COMPLETE'),
#   OptimizationRecord(id='18046998', status='COMPLETE'),
#   OptimizationRecord(id='18046999', status='COMPLETE'),
#   OptimizationRecord(id='18047000', status='COMPLETE'),
#   OptimizationRecord(id='18047001', status='COMPLETE'),
#   OptimizationRecord(id='18047002', status='COMPLETE'),
#   OptimizationRecord(id='18047003', status='COMPLETE'),
#   OptimizationRecord(id='18047004', status='COMPLETE'),
#   OptimizationRecord(id='18062660', status='COMPLETE'),
#   OptimizationRecord(id='18062661', status='COMPLETE'),
#   OptimizationRecord(id='18062662', status='COMPLETE'),
#   OptimizationRecord(id='18062663', status='COMPLETE'),
#   OptimizationRecord(id='18062664', status='COMPLETE'),
#   OptimizationRecord(id='18062665', status='COMPLETE'),
#   OptimizationRecord(id='18062666', status='COMPLETE'),
#   OptimizationRecord(id='18062667', status='COMPLETE'),
#   OptimizationRecord(id='18062668', status='COMPLETE'),
#   OptimizationRecord(id='18062669', status='COMPLETE'),
#   OptimizationRecord(id='18076736', status='COMPLETE'),
#   OptimizationRecord(id='18076737', status='COMPLETE'),
#   OptimizationRecord(id='18076738', status='COMPLETE'),
#   OptimizationRecord(id='18076739', status='COMPLETE'),
#   OptimizationRecord(id='18076740', status='COMPLETE'),
#   OptimizationRecord(id='18076741', status='COMPLETE'),
#   OptimizationRecord(id='18076742', status='COMPLETE'),
#   OptimizationRecord(id='18076743', status='COMPLETE'),
#   OptimizationRecord(id='18076744', status='COMPLETE'),
#   OptimizationRecord(id='18076745', status='COMPLETE'),
#   OptimizationRecord(id='18076746', status='COMPLETE'),
#   OptimizationRecord(id='18076747', status='COMPLETE'),
#   OptimizationRecord(id='18076748', status='COMPLETE'),
#   OptimizationRecord(id='18076749', status='COMPLETE'),
#   OptimizationRecord(id='18091830', status='COMPLETE'),
#   OptimizationRecord(id='18091831', status='COMPLETE'),
#   OptimizationRecord(id='18091832', status='COMPLETE'),
#   OptimizationRecord(id='18091835', status='COMPLETE'),
#   OptimizationRecord(id='18091843', status='COMPLETE'),
#   OptimizationRecord(id='18091844', status='COMPLETE'),
#   OptimizationRecord(id='18091860', status='COMPLETE'),
#   OptimizationRecord(id='18091861', status='COMPLETE'),
#   OptimizationRecord(id='18091862', status='COMPLETE'),
#   OptimizationRecord(id='18091863', status='COMPLETE'),
#   OptimizationRecord(id='18113327', status='COMPLETE'),
#   OptimizationRecord(id='18113328', status='COMPLETE'),
#   OptimizationRecord(id='18113329', status='COMPLETE'),
#   OptimizationRecord(id='18113330', status='COMPLETE'),
#   OptimizationRecord(id='18113331', status='COMPLETE'),
#   OptimizationRecord(id='18113332', status='COMPLETE'),
#   OptimizationRecord(id='18113333', status='COMPLETE'),
#   OptimizationRecord(id='18113334', status='COMPLETE'),
#   OptimizationRecord(id='18113335', status='COMPLETE'),
#   OptimizationRecord(id='18113336', status='COMPLETE'),
#   OptimizationRecord(id='18132941', status='COMPLETE'),
#   OptimizationRecord(id='18132942', status='COMPLETE'),
#   OptimizationRecord(id='18132943', status='COMPLETE'),
#   OptimizationRecord(id='18132944', status='COMPLETE'),
#   OptimizationRecord(id='18132950', status='COMPLETE'),
#   OptimizationRecord(id='18132951', status='COMPLETE'),
#   OptimizationRecord(id='18132952', status='COMPLETE'),
#   OptimizationRecord(id='18132953', status='COMPLETE'),
#   OptimizationRecord(id='18145410', status='COMPLETE'),
#   OptimizationRecord(id='18145411', status='COMPLETE'),
#   OptimizationRecord(id='18145412', status='COMPLETE'),
#   OptimizationRecord(id='18145413', status='INCOMPLETE')],
#  '18045631': [OptimizationRecord(id='18047290', status='COMPLETE'),
#   OptimizationRecord(id='18047291', status='COMPLETE'),
#   OptimizationRecord(id='18063943', status='COMPLETE'),
#   OptimizationRecord(id='18063944', status='COMPLETE'),
#   OptimizationRecord(id='18063945', status='COMPLETE'),
#   OptimizationRecord(id='18063946', status='COMPLETE'),
#   OptimizationRecord(id='18073316', status='COMPLETE'),
#   OptimizationRecord(id='18073317', status='COMPLETE'),
#   OptimizationRecord(id='18073318', status='COMPLETE'),
#   OptimizationRecord(id='18073329', status='COMPLETE'),
#   OptimizationRecord(id='18073330', status='COMPLETE'),
#   OptimizationRecord(id='18073331', status='COMPLETE'),
#   OptimizationRecord(id='18073332', status='COMPLETE'),
#   OptimizationRecord(id='18073333', status='COMPLETE'),
#   OptimizationRecord(id='18089687', status='COMPLETE'),
#   OptimizationRecord(id='18089688', status='COMPLETE'),
#   OptimizationRecord(id='18089689', status='COMPLETE'),
#   OptimizationRecord(id='18089690', status='COMPLETE'),
#   OptimizationRecord(id='18089691', status='COMPLETE'),
#   OptimizationRecord(id='18089692', status='COMPLETE'),
#   OptimizationRecord(id='18089693', status='COMPLETE'),
#   OptimizationRecord(id='18089694', status='COMPLETE'),
#   OptimizationRecord(id='18100377', status='COMPLETE'),
#   OptimizationRecord(id='18100378', status='COMPLETE'),
#   OptimizationRecord(id='18100379', status='COMPLETE'),
#   OptimizationRecord(id='18100380', status='COMPLETE'),
#   OptimizationRecord(id='18100381', status='COMPLETE'),
#   OptimizationRecord(id='18100382', status='COMPLETE'),
#   OptimizationRecord(id='18100383', status='COMPLETE'),
#   OptimizationRecord(id='18100384', status='COMPLETE'),
#   OptimizationRecord(id='18115243', status='COMPLETE'),
#   OptimizationRecord(id='18115244', status='COMPLETE'),
#   OptimizationRecord(id='18115245', status='COMPLETE'),
#   OptimizationRecord(id='18115246', status='INCOMPLETE'),
#   OptimizationRecord(id='18115247', status='COMPLETE'),
#   OptimizationRecord(id='18115248', status='COMPLETE'),
#   OptimizationRecord(id='18115249', status='COMPLETE'),
#   OptimizationRecord(id='18115250', status='COMPLETE')],
#  '18045633': [OptimizationRecord(id='18047407', status='COMPLETE'),
#   OptimizationRecord(id='18047408', status='COMPLETE'),
#   OptimizationRecord(id='18061947', status='COMPLETE'),
#   OptimizationRecord(id='18061948', status='COMPLETE'),
#   OptimizationRecord(id='18075068', status='COMPLETE'),
#   OptimizationRecord(id='18075069', status='COMPLETE'),
#   OptimizationRecord(id='18075070', status='COMPLETE'),
#   OptimizationRecord(id='18075071', status='COMPLETE'),
#   OptimizationRecord(id='18090692', status='COMPLETE'),
#   OptimizationRecord(id='18090693', status='COMPLETE'),
#   OptimizationRecord(id='18090694', status='COMPLETE'),
#   OptimizationRecord(id='18090695', status='COMPLETE'),
#   OptimizationRecord(id='18103359', status='COMPLETE'),
#   OptimizationRecord(id='18103360', status='COMPLETE'),
#   OptimizationRecord(id='18103361', status='COMPLETE'),
#   OptimizationRecord(id='18103362', status='COMPLETE'),
#   OptimizationRecord(id='18115581', status='COMPLETE'),
#   OptimizationRecord(id='18115582', status='COMPLETE'),
#   OptimizationRecord(id='18115583', status='COMPLETE'),
#   OptimizationRecord(id='18115584', status='INCOMPLETE')],
#  '18045635': [OptimizationRecord(id='18047414', status='COMPLETE'),
#   OptimizationRecord(id='18060575', status='COMPLETE'),
#   OptimizationRecord(id='18060576', status='COMPLETE'),
#   OptimizationRecord(id='18070020', status='COMPLETE'),
#   OptimizationRecord(id='18070021', status='COMPLETE'),
#   OptimizationRecord(id='18070022', status='COMPLETE'),
#   OptimizationRecord(id='18070023', status='COMPLETE'),
#   OptimizationRecord(id='18082262', status='COMPLETE'),
#   OptimizationRecord(id='18082263', status='COMPLETE'),
#   OptimizationRecord(id='18082264', status='COMPLETE'),
#   OptimizationRecord(id='18082265', status='COMPLETE'),
#   OptimizationRecord(id='18094538', status='COMPLETE'),
#   OptimizationRecord(id='18094539', status='COMPLETE'),
#   OptimizationRecord(id='18094540', status='COMPLETE'),
#   OptimizationRecord(id='18094541', status='COMPLETE'),
#   OptimizationRecord(id='18110206', status='COMPLETE'),
#   OptimizationRecord(id='18110207', status='COMPLETE'),
#   OptimizationRecord(id='18110208', status='COMPLETE'),
#   OptimizationRecord(id='18110209', status='COMPLETE'),
#   OptimizationRecord(id='18123085', status='COMPLETE'),
#   OptimizationRecord(id='18123086', status='COMPLETE'),
#   OptimizationRecord(id='18123087', status='COMPLETE'),
#   OptimizationRecord(id='18123088', status='COMPLETE'),
#   OptimizationRecord(id='18123089', status='COMPLETE'),
#   OptimizationRecord(id='18123090', status='COMPLETE'),
#   OptimizationRecord(id='18135210', status='COMPLETE'),
#   OptimizationRecord(id='18135211', status='COMPLETE'),
#   OptimizationRecord(id='18135212', status='COMPLETE'),
#   OptimizationRecord(id='18135213', status='COMPLETE'),
#   OptimizationRecord(id='18147835', status='COMPLETE'),
#   OptimizationRecord(id='18147836', status='COMPLETE'),
#   OptimizationRecord(id='18147837', status='COMPLETE'),
#   OptimizationRecord(id='18147845', status='COMPLETE'),
#   OptimizationRecord(id='18158970', status='COMPLETE'),
#   OptimizationRecord(id='18158971', status='COMPLETE'),
#   OptimizationRecord(id='18158972', status='COMPLETE'),
#   OptimizationRecord(id='18158973', status='COMPLETE'),
#   OptimizationRecord(id='18168894', status='COMPLETE'),
#   OptimizationRecord(id='18168895', status='COMPLETE'),
#   OptimizationRecord(id='18168896', status='COMPLETE'),
#   OptimizationRecord(id='18168897', status='COMPLETE'),
#   OptimizationRecord(id='18177891', status='COMPLETE'),
#   OptimizationRecord(id='18177892', status='COMPLETE'),
#   OptimizationRecord(id='18177893', status='COMPLETE'),
#   OptimizationRecord(id='18177894', status='COMPLETE'),
#   OptimizationRecord(id='18189022', status='INCOMPLETE'),
#   OptimizationRecord(id='18189023', status='COMPLETE'),
#   OptimizationRecord(id='18189024', status='COMPLETE'),
#   OptimizationRecord(id='18189025', status='COMPLETE')],
#  '18045639': [OptimizationRecord(id='18047534', status='COMPLETE'),
#   OptimizationRecord(id='18047535', status='COMPLETE'),
#   OptimizationRecord(id='18047536', status='COMPLETE'),
#   OptimizationRecord(id='18047537', status='COMPLETE'),
#   OptimizationRecord(id='18047538', status='COMPLETE'),
#   OptimizationRecord(id='18047539', status='COMPLETE'),
#   OptimizationRecord(id='18047540', status='COMPLETE'),
#   OptimizationRecord(id='18047541', status='COMPLETE'),
#   OptimizationRecord(id='18047542', status='COMPLETE'),
#   OptimizationRecord(id='18047543', status='COMPLETE'),
#   OptimizationRecord(id='18047544', status='COMPLETE'),
#   OptimizationRecord(id='18047545', status='COMPLETE'),
#   OptimizationRecord(id='18047546', status='COMPLETE'),
#   OptimizationRecord(id='18047547', status='COMPLETE'),
#   OptimizationRecord(id='18047548', status='COMPLETE'),
#   OptimizationRecord(id='18047549', status='COMPLETE'),
#   OptimizationRecord(id='18047550', status='COMPLETE'),
#   OptimizationRecord(id='18047551', status='COMPLETE'),
#   OptimizationRecord(id='18047552', status='COMPLETE'),
#   OptimizationRecord(id='18047553', status='COMPLETE'),
#   OptimizationRecord(id='18047554', status='COMPLETE'),
#   OptimizationRecord(id='18047555', status='COMPLETE'),
#   OptimizationRecord(id='18047556', status='COMPLETE'),
#   OptimizationRecord(id='18047557', status='COMPLETE'),
#   OptimizationRecord(id='18079170', status='COMPLETE'),
#   OptimizationRecord(id='18079171', status='COMPLETE'),
#   OptimizationRecord(id='18079172', status='COMPLETE'),
#   OptimizationRecord(id='18079173', status='COMPLETE'),
#   OptimizationRecord(id='18079174', status='COMPLETE'),
#   OptimizationRecord(id='18079175', status='COMPLETE'),
#   OptimizationRecord(id='18079176', status='COMPLETE'),
#   OptimizationRecord(id='18079177', status='COMPLETE'),
#   OptimizationRecord(id='18093304', status='COMPLETE'),
#   OptimizationRecord(id='18093314', status='COMPLETE'),
#   OptimizationRecord(id='18093315', status='COMPLETE'),
#   OptimizationRecord(id='18093316', status='COMPLETE'),
#   OptimizationRecord(id='18093317', status='COMPLETE'),
#   OptimizationRecord(id='18093318', status='COMPLETE'),
#   OptimizationRecord(id='18093319', status='COMPLETE'),
#   OptimizationRecord(id='18093320', status='COMPLETE'),
#   OptimizationRecord(id='18093321', status='COMPLETE'),
#   OptimizationRecord(id='18093322', status='COMPLETE'),
#   OptimizationRecord(id='18093326', status='COMPLETE'),
#   OptimizationRecord(id='18093337', status='COMPLETE'),
#   OptimizationRecord(id='18093347', status='COMPLETE'),
#   OptimizationRecord(id='18093348', status='COMPLETE'),
#   OptimizationRecord(id='18093349', status='COMPLETE'),
#   OptimizationRecord(id='18093350', status='COMPLETE'),
#   OptimizationRecord(id='18114640', status='COMPLETE'),
#   OptimizationRecord(id='18114641', status='COMPLETE'),
#   OptimizationRecord(id='18114642', status='COMPLETE'),
#   OptimizationRecord(id='18114643', status='COMPLETE'),
#   OptimizationRecord(id='18114644', status='COMPLETE'),
#   OptimizationRecord(id='18114653', status='COMPLETE'),
#   OptimizationRecord(id='18114654', status='COMPLETE'),
#   OptimizationRecord(id='18114655', status='INCOMPLETE')],
#  '18045646': [OptimizationRecord(id='18090040', status='COMPLETE'),
#   OptimizationRecord(id='18090041', status='COMPLETE'),
#   OptimizationRecord(id='18090042', status='COMPLETE'),
#   OptimizationRecord(id='18090043', status='COMPLETE'),
#   OptimizationRecord(id='18090044', status='COMPLETE'),
#   OptimizationRecord(id='18090045', status='COMPLETE'),
#   OptimizationRecord(id='18090046', status='COMPLETE'),
#   OptimizationRecord(id='18106804', status='COMPLETE'),
#   OptimizationRecord(id='18106805', status='COMPLETE'),
#   OptimizationRecord(id='18106806', status='COMPLETE'),
#   OptimizationRecord(id='18106807', status='COMPLETE'),
#   OptimizationRecord(id='18106808', status='COMPLETE'),
#   OptimizationRecord(id='18106809', status='COMPLETE'),
#   OptimizationRecord(id='18106810', status='COMPLETE'),
#   OptimizationRecord(id='18106811', status='COMPLETE'),
#   OptimizationRecord(id='18106812', status='COMPLETE'),
#   OptimizationRecord(id='18106813', status='COMPLETE'),
#   OptimizationRecord(id='18106814', status='COMPLETE'),
#   OptimizationRecord(id='18106815', status='COMPLETE'),
#   OptimizationRecord(id='18106816', status='COMPLETE'),
#   OptimizationRecord(id='18106817', status='COMPLETE'),
#   OptimizationRecord(id='18119959', status='COMPLETE'),
#   OptimizationRecord(id='18119960', status='COMPLETE'),
#   OptimizationRecord(id='18119961', status='COMPLETE'),
#   OptimizationRecord(id='18119962', status='COMPLETE'),
#   OptimizationRecord(id='18119963', status='COMPLETE'),
#   OptimizationRecord(id='18119964', status='COMPLETE'),
#   OptimizationRecord(id='18119965', status='COMPLETE'),
#   OptimizationRecord(id='18119966', status='COMPLETE'),
#   OptimizationRecord(id='18119967', status='COMPLETE'),
#   OptimizationRecord(id='18119968', status='COMPLETE'),
#   OptimizationRecord(id='18119969', status='COMPLETE'),
#   OptimizationRecord(id='18119970', status='COMPLETE'),
#   OptimizationRecord(id='18119971', status='COMPLETE'),
#   OptimizationRecord(id='18119972', status='COMPLETE'),
#   OptimizationRecord(id='18119973', status='COMPLETE'),
#   OptimizationRecord(id='18119974', status='COMPLETE'),
#   OptimizationRecord(id='18119975', status='COMPLETE'),
#   OptimizationRecord(id='18119976', status='COMPLETE'),
#   OptimizationRecord(id='18119977', status='COMPLETE'),
#   OptimizationRecord(id='18119981', status='COMPLETE'),
#   OptimizationRecord(id='18120001', status='COMPLETE'),
#   OptimizationRecord(id='18120007', status='COMPLETE'),
#   OptimizationRecord(id='18120015', status='COMPLETE'),
#   OptimizationRecord(id='18120016', status='COMPLETE'),
#   OptimizationRecord(id='18131661', status='COMPLETE'),
#   OptimizationRecord(id='18131662', status='COMPLETE'),
#   OptimizationRecord(id='18131663', status='COMPLETE'),
#   OptimizationRecord(id='18131664', status='COMPLETE'),
#   OptimizationRecord(id='18131681', status='COMPLETE'),
#   OptimizationRecord(id='18131682', status='COMPLETE'),
#   OptimizationRecord(id='18131683', status='COMPLETE'),
#   OptimizationRecord(id='18131684', status='COMPLETE'),
#   OptimizationRecord(id='18131685', status='COMPLETE'),
#   OptimizationRecord(id='18131686', status='COMPLETE'),
#   OptimizationRecord(id='18131687', status='COMPLETE'),
#   OptimizationRecord(id='18131688', status='COMPLETE'),
#   OptimizationRecord(id='18131689', status='COMPLETE'),
#   OptimizationRecord(id='18131690', status='COMPLETE'),
#   OptimizationRecord(id='18131691', status='COMPLETE'),
#   OptimizationRecord(id='18131692', status='COMPLETE'),
#   OptimizationRecord(id='18131693', status='COMPLETE'),
#   OptimizationRecord(id='18131694', status='COMPLETE'),
#   OptimizationRecord(id='18143618', status='COMPLETE'),
#   OptimizationRecord(id='18143619', status='COMPLETE'),
#   OptimizationRecord(id='18143620', status='INCOMPLETE'),
#   OptimizationRecord(id='18143630', status='COMPLETE'),
#   OptimizationRecord(id='18143631', status='COMPLETE'),
#   OptimizationRecord(id='18143632', status='COMPLETE'),
#   OptimizationRecord(id='18143633', status='COMPLETE'),
#   OptimizationRecord(id='18143634', status='COMPLETE'),
#   OptimizationRecord(id='18143635', status='COMPLETE'),
#   OptimizationRecord(id='18143636', status='COMPLETE'),
#   OptimizationRecord(id='18143637', status='COMPLETE'),
#   OptimizationRecord(id='18143638', status='COMPLETE'),
#   OptimizationRecord(id='18143639', status='COMPLETE'),
#   OptimizationRecord(id='18143640', status='COMPLETE'),
#   OptimizationRecord(id='18143641', status='COMPLETE'),
#   OptimizationRecord(id='18143642', status='COMPLETE'),
#   OptimizationRecord(id='18143643', status='COMPLETE'),
#   OptimizationRecord(id='18143644', status='COMPLETE')],
#  '18045659': [OptimizationRecord(id='18118921', status='INCOMPLETE'),
#   OptimizationRecord(id='18118928', status='COMPLETE'),
#   OptimizationRecord(id='18118929', status='COMPLETE')],
#  '18045663': [OptimizationRecord(id='18124012', status='COMPLETE'),
#   OptimizationRecord(id='18124026', status='COMPLETE'),
#   OptimizationRecord(id='18124027', status='COMPLETE'),
#   OptimizationRecord(id='18124028', status='COMPLETE'),
#   OptimizationRecord(id='18124029', status='COMPLETE'),
#   OptimizationRecord(id='18124036', status='COMPLETE'),
#   OptimizationRecord(id='18135942', status='COMPLETE'),
#   OptimizationRecord(id='18135943', status='COMPLETE'),
#   OptimizationRecord(id='18144074', status='INCOMPLETE'),
#   OptimizationRecord(id='18144075', status='COMPLETE'),
#   OptimizationRecord(id='18144094', status='COMPLETE'),
#   OptimizationRecord(id='18144095', status='COMPLETE')],
#  '18045679': [OptimizationRecord(id='18143674', status='COMPLETE'),
#   OptimizationRecord(id='18143675', status='COMPLETE'),
#   OptimizationRecord(id='18143676', status='COMPLETE'),
#   OptimizationRecord(id='18143685', status='COMPLETE'),
#   OptimizationRecord(id='18143702', status='INCOMPLETE'),
#   OptimizationRecord(id='18143711', status='COMPLETE'),
#   OptimizationRecord(id='18143712', status='COMPLETE')],
#  '18045680': [OptimizationRecord(id='18144102', status='COMPLETE'),
#   OptimizationRecord(id='18144103', status='COMPLETE'),
#   OptimizationRecord(id='18144104', status='COMPLETE'),
#   OptimizationRecord(id='18144105', status='COMPLETE'),
#   OptimizationRecord(id='18144106', status='COMPLETE'),
#   OptimizationRecord(id='18144107', status='INCOMPLETE'),
#   OptimizationRecord(id='18144108', status='COMPLETE')],
#  '18045681': [OptimizationRecord(id='18145836', status='COMPLETE'),
#   OptimizationRecord(id='18145837', status='COMPLETE'),
#   OptimizationRecord(id='18153081', status='COMPLETE'),
#   OptimizationRecord(id='18153082', status='COMPLETE'),
#   OptimizationRecord(id='18160874', status='COMPLETE'),
#   OptimizationRecord(id='18160875', status='COMPLETE'),
#   OptimizationRecord(id='18160876', status='COMPLETE'),
#   OptimizationRecord(id='18160877', status='COMPLETE'),
#   OptimizationRecord(id='18169315', status='COMPLETE'),
#   OptimizationRecord(id='18169316', status='COMPLETE'),
#   OptimizationRecord(id='18169327', status='COMPLETE'),
#   OptimizationRecord(id='18169328', status='COMPLETE'),
#   OptimizationRecord(id='18177895', status='COMPLETE'),
#   OptimizationRecord(id='18177896', status='COMPLETE'),
#   OptimizationRecord(id='18177897', status='COMPLETE'),
#   OptimizationRecord(id='18177898', status='COMPLETE'),
#   OptimizationRecord(id='18177918', status='COMPLETE'),
#   OptimizationRecord(id='18177919', status='COMPLETE'),
#   OptimizationRecord(id='18188755', status='COMPLETE'),
#   OptimizationRecord(id='18188756', status='COMPLETE'),
#   OptimizationRecord(id='18188757', status='COMPLETE'),
#   OptimizationRecord(id='18188758', status='COMPLETE'),
#   OptimizationRecord(id='18217149', status='COMPLETE'),
#   OptimizationRecord(id='18217150', status='COMPLETE'),
#   OptimizationRecord(id='18217151', status='COMPLETE'),
#   OptimizationRecord(id='18217152', status='COMPLETE'),
#   OptimizationRecord(id='18264351', status='COMPLETE'),
#   OptimizationRecord(id='18264352', status='COMPLETE'),
#   OptimizationRecord(id='18264353', status='COMPLETE'),
#   OptimizationRecord(id='18264354', status='COMPLETE'),
#   OptimizationRecord(id='18307399', status='COMPLETE'),
#   OptimizationRecord(id='18307400', status='COMPLETE'),
#   OptimizationRecord(id='18307401', status='COMPLETE'),
#   OptimizationRecord(id='18307402', status='COMPLETE'),
#   OptimizationRecord(id='18329761', status='COMPLETE'),
#   OptimizationRecord(id='18329762', status='COMPLETE'),
#   OptimizationRecord(id='18329763', status='COMPLETE'),
#   OptimizationRecord(id='18329764', status='COMPLETE'),
#   OptimizationRecord(id='18358627', status='COMPLETE'),
#   OptimizationRecord(id='18358628', status='COMPLETE'),
#   OptimizationRecord(id='18358629', status='COMPLETE'),
#   OptimizationRecord(id='18358630', status='COMPLETE'),
#   OptimizationRecord(id='18370261', status='COMPLETE'),
#   OptimizationRecord(id='18370262', status='COMPLETE'),
#   OptimizationRecord(id='18370263', status='COMPLETE'),
#   OptimizationRecord(id='18370264', status='COMPLETE'),
#   OptimizationRecord(id='18379952', status='COMPLETE'),
#   OptimizationRecord(id='18379953', status='COMPLETE'),
#   OptimizationRecord(id='18379954', status='COMPLETE'),
#   OptimizationRecord(id='18379955', status='COMPLETE'),
#   OptimizationRecord(id='18384333', status='COMPLETE'),
#   OptimizationRecord(id='18384334', status='COMPLETE')],
#  '18045695': [OptimizationRecord(id='18154864', status='COMPLETE'),
#   OptimizationRecord(id='18154865', status='COMPLETE'),
#   OptimizationRecord(id='18172099', status='COMPLETE'),
#   OptimizationRecord(id='18172100', status='COMPLETE'),
#   OptimizationRecord(id='18172101', status='COMPLETE'),
#   OptimizationRecord(id='18172102', status='COMPLETE'),
#   OptimizationRecord(id='18186081', status='INCOMPLETE'),
#   OptimizationRecord(id='18186082', status='COMPLETE'),
#   OptimizationRecord(id='18186083', status='COMPLETE'),
#   OptimizationRecord(id='18186084', status='COMPLETE'),
#   OptimizationRecord(id='18186085', status='COMPLETE'),
#   OptimizationRecord(id='18186086', status='COMPLETE'),
#   OptimizationRecord(id='18186087', status='COMPLETE'),
#   OptimizationRecord(id='18186088', status='COMPLETE')],
#  '18045704': [OptimizationRecord(id='18165663', status='COMPLETE'),
#   OptimizationRecord(id='18165664', status='COMPLETE'),
#   OptimizationRecord(id='18165665', status='COMPLETE'),
#   OptimizationRecord(id='18165666', status='COMPLETE'),
#   OptimizationRecord(id='18165667', status='COMPLETE'),
#   OptimizationRecord(id='18165668', status='COMPLETE'),
#   OptimizationRecord(id='18165669', status='COMPLETE'),
#   OptimizationRecord(id='18165670', status='COMPLETE'),
#   OptimizationRecord(id='18165671', status='COMPLETE'),
#   OptimizationRecord(id='18177724', status='COMPLETE'),
#   OptimizationRecord(id='18177725', status='COMPLETE'),
#   OptimizationRecord(id='18177726', status='COMPLETE'),
#   OptimizationRecord(id='18177727', status='COMPLETE'),
#   OptimizationRecord(id='18188759', status='COMPLETE'),
#   OptimizationRecord(id='18188760', status='COMPLETE'),
#   OptimizationRecord(id='18188761', status='COMPLETE'),
#   OptimizationRecord(id='18188762', status='COMPLETE'),
#   OptimizationRecord(id='18188763', status='COMPLETE'),
#   OptimizationRecord(id='18188764', status='COMPLETE'),
#   OptimizationRecord(id='18188765', status='COMPLETE'),
#   OptimizationRecord(id='18188766', status='INCOMPLETE')],
#  '18045715': [OptimizationRecord(id='18168667', status='COMPLETE'),
#   OptimizationRecord(id='18168668', status='COMPLETE'),
#   OptimizationRecord(id='18168669', status='COMPLETE'),
#   OptimizationRecord(id='18168670', status='COMPLETE')],
#  '18045716': [OptimizationRecord(id='18170053', status='COMPLETE')]}

# %%
resm = get_unfinished_torsiondrive_optimizations(ds, 'default', client, merged=True)

# %%
incomplete = (opt.dict() for opt in resm if opt.status == 'INCOMPLETE')

# %%
next(incomplete)
# Out:
# {'id': '18054332',
#  'hash_index': '91a94fe33f2ddcd980cf9e8b819cffab0caa5a96',
#  'procedure': 'optimization',
#  'program': 'geometric',
#  'version': 1,
#  'protocols': {},
#  'extras': {},
#  'stdout': '20999952',
#  'stderr': None,
#  'error': None,
#  'task_id': None,
#  'manager_name': None,
#  'status': <RecordStatusEnum.incomplete: 'INCOMPLETE'>,
#  'modified_on': datetime.datetime(2020, 3, 13, 23, 22, 13, 104561),
#  'created_on': datetime.datetime(2020, 3, 13, 23, 22, 13, 104563),
#  'provenance': {'creator': 'geomeTRIC',
#   'version': '0.9.7.2',
#   'routine': 'geometric.run_json.geometric_run_json',
#   'username': 'chodera',
#   'wall_time': 645.927755355835,
#   'hostname': 'ls16',
#   'cpu': 'Intel(R) Xeon(R) CPU E5-2697 v4 @ 2.30GHz',
#   'qcengine_version': '0.14.0'},
#  'schema_version': 1,
#  'initial_molecule': '11773276',
#  'qc_spec': {'driver': <DriverEnum.gradient: 'gradient'>,
#   'method': 'b3lyp-d3bj',
#   'basis': 'dzvp',
#   'keywords': '2',
#   'program': 'psi4'},
#  'keywords': {'coordsys': 'tric',
#   'enforce': 0.1,
#   'reset': True,
#   'qccnv': True,
#   'epsilon': 0,
#   'constraints': {'set': [{'type': 'dihedral',
#      'indices': [15, 11, 12, 30],
#      'value': 45}]},
#   'program': 'psi4'},
#  'energies': [-675.0485024144832,
#   -675.048290941928,
#   -675.0481114401578,
#   -675.048021185704,
#   -675.0475699468795,
#   -675.0477032719941,
#   -675.0477068620858,
#   -675.047708858558,
#   -675.0477107825824,
#   -675.0477129187867,
#   -675.0477134982008],
#  'final_molecule': '11784875',
#  'trajectory': ['18054230',
#   '18066909',
#   '18066911',
#   '18066913',
#   '18066915',
#   '18066917',
#   '18066919',
#   '18066921',
#   '18066923',
#   '18066924',
#   '18066925']}

# %% [markdown]
# All Lilac INCOMPLETEs?

# %%
count_unique_optimization_error_messages(resm, pretty_print=True)

# %%
restart_optimizations(resm, client)

# %%
restart_torsiondrives(ds.df.default.tolist(), client)
# Out:
# TorsionDriveRecord(id='18045681', status='ERROR')
# TorsionDriveRecord(id='18045715', status='ERROR')
# TorsionDriveRecord(id='18045716', status='ERROR')

# %% [markdown]
# ## Dataset tracking - OpenFF Gen 2 Torsion Set 5 Bayer

# %% [markdown]
# ### 2020.06.11 18:45 UTC

# %%
dataset = "OpenFF Gen 2 Torsion Set 5 Bayer"

# %%
ds = client.get_collection("TorsionDriveDataset", dataset)

# %%
ds.list_specifications()
# Out:
#                                          Description
# Name
# default  Standard OpenFF torsiondrive specification.

# %%
res = get_unfinished_torsiondrive_optimizations(ds, 'default', client, merged=False)
res
# Out:
# {'18045852': [OptimizationRecord(id='18171360', status='COMPLETE'),
#   OptimizationRecord(id='18171361', status='COMPLETE'),
#   OptimizationRecord(id='18171362', status='COMPLETE'),
#   OptimizationRecord(id='18171363', status='COMPLETE'),
#   OptimizationRecord(id='18171364', status='COMPLETE'),
#   OptimizationRecord(id='18171365', status='COMPLETE'),
#   OptimizationRecord(id='18171366', status='COMPLETE'),
#   OptimizationRecord(id='18171370', status='COMPLETE'),
#   OptimizationRecord(id='18171386', status='COMPLETE'),
#   OptimizationRecord(id='18171388', status='COMPLETE'),
#   OptimizationRecord(id='18171424', status='COMPLETE'),
#   OptimizationRecord(id='18171425', status='COMPLETE'),
#   OptimizationRecord(id='18171426', status='COMPLETE'),
#   OptimizationRecord(id='18171427', status='COMPLETE'),
#   OptimizationRecord(id='18171428', status='COMPLETE'),
#   OptimizationRecord(id='18171429', status='COMPLETE'),
#   OptimizationRecord(id='18171430', status='COMPLETE'),
#   OptimizationRecord(id='18171431', status='COMPLETE'),
#   OptimizationRecord(id='18171432', status='COMPLETE'),
#   OptimizationRecord(id='18171433', status='COMPLETE'),
#   OptimizationRecord(id='18171434', status='COMPLETE'),
#   OptimizationRecord(id='18171435', status='COMPLETE'),
#   OptimizationRecord(id='18171436', status='COMPLETE'),
#   OptimizationRecord(id='18171439', status='COMPLETE'),
#   OptimizationRecord(id='18171449', status='COMPLETE'),
#   OptimizationRecord(id='18171450', status='COMPLETE'),
#   OptimizationRecord(id='18171451', status='COMPLETE'),
#   OptimizationRecord(id='18171452', status='COMPLETE'),
#   OptimizationRecord(id='18171453', status='COMPLETE'),
#   OptimizationRecord(id='18171454', status='COMPLETE'),
#   OptimizationRecord(id='18171455', status='COMPLETE'),
#   OptimizationRecord(id='18171456', status='COMPLETE'),
#   OptimizationRecord(id='18171457', status='COMPLETE'),
#   OptimizationRecord(id='18171458', status='COMPLETE'),
#   OptimizationRecord(id='18171459', status='COMPLETE'),
#   OptimizationRecord(id='18171460', status='COMPLETE'),
#   OptimizationRecord(id='18171467', status='COMPLETE'),
#   OptimizationRecord(id='18171468', status='COMPLETE'),
#   OptimizationRecord(id='18171469', status='COMPLETE'),
#   OptimizationRecord(id='18171470', status='COMPLETE'),
#   OptimizationRecord(id='18171471', status='COMPLETE'),
#   OptimizationRecord(id='18171472', status='COMPLETE'),
#   OptimizationRecord(id='18171473', status='COMPLETE'),
#   OptimizationRecord(id='18171474', status='COMPLETE'),
#   OptimizationRecord(id='18171475', status='COMPLETE'),
#   OptimizationRecord(id='18171476', status='COMPLETE'),
#   OptimizationRecord(id='18171477', status='COMPLETE'),
#   OptimizationRecord(id='18171478', status='COMPLETE'),
#   OptimizationRecord(id='18171479', status='COMPLETE'),
#   OptimizationRecord(id='18171480', status='COMPLETE'),
#   OptimizationRecord(id='18171481', status='COMPLETE'),
#   OptimizationRecord(id='18171482', status='COMPLETE'),
#   OptimizationRecord(id='18171483', status='COMPLETE'),
#   OptimizationRecord(id='18171484', status='COMPLETE'),
#   OptimizationRecord(id='18171485', status='COMPLETE'),
#   OptimizationRecord(id='18171486', status='COMPLETE'),
#   OptimizationRecord(id='18171487', status='COMPLETE'),
#   OptimizationRecord(id='18171488', status='COMPLETE'),
#   OptimizationRecord(id='18171489', status='COMPLETE'),
#   OptimizationRecord(id='18171490', status='COMPLETE'),
#   OptimizationRecord(id='18171491', status='COMPLETE'),
#   OptimizationRecord(id='18171492', status='COMPLETE'),
#   OptimizationRecord(id='18171493', status='COMPLETE'),
#   OptimizationRecord(id='18171494', status='COMPLETE'),
#   OptimizationRecord(id='18171495', status='COMPLETE'),
#   OptimizationRecord(id='18171496', status='COMPLETE'),
#   OptimizationRecord(id='18171497', status='COMPLETE'),
#   OptimizationRecord(id='18171498', status='COMPLETE'),
#   OptimizationRecord(id='18171499', status='COMPLETE'),
#   OptimizationRecord(id='18171500', status='COMPLETE'),
#   OptimizationRecord(id='18171501', status='COMPLETE'),
#   OptimizationRecord(id='18171502', status='COMPLETE'),
#   OptimizationRecord(id='18171515', status='COMPLETE'),
#   OptimizationRecord(id='18171516', status='COMPLETE'),
#   OptimizationRecord(id='18171517', status='COMPLETE'),
#   OptimizationRecord(id='18171518', status='COMPLETE'),
#   OptimizationRecord(id='18171519', status='COMPLETE'),
#   OptimizationRecord(id='18171520', status='COMPLETE'),
#   OptimizationRecord(id='18171521', status='COMPLETE'),
#   OptimizationRecord(id='18171522', status='COMPLETE'),
#   OptimizationRecord(id='18171523', status='COMPLETE'),
#   OptimizationRecord(id='18171524', status='COMPLETE'),
#   OptimizationRecord(id='18171525', status='COMPLETE'),
#   OptimizationRecord(id='18171526', status='COMPLETE'),
#   OptimizationRecord(id='18171527', status='COMPLETE'),
#   OptimizationRecord(id='18171528', status='COMPLETE'),
#   OptimizationRecord(id='18171529', status='COMPLETE'),
#   OptimizationRecord(id='18171530', status='COMPLETE'),
#   OptimizationRecord(id='18171531', status='COMPLETE'),
#   OptimizationRecord(id='18171532', status='COMPLETE'),
#   OptimizationRecord(id='18171543', status='COMPLETE'),
#   OptimizationRecord(id='18171544', status='COMPLETE'),
#   OptimizationRecord(id='18171545', status='COMPLETE'),
#   OptimizationRecord(id='18171546', status='COMPLETE'),
#   OptimizationRecord(id='18171547', status='COMPLETE'),
#   OptimizationRecord(id='18171548', status='COMPLETE'),
#   OptimizationRecord(id='18171549', status='COMPLETE'),
#   OptimizationRecord(id='18171550', status='COMPLETE'),
#   OptimizationRecord(id='18171551', status='COMPLETE'),
#   OptimizationRecord(id='18171552', status='COMPLETE'),
#   OptimizationRecord(id='18171553', status='COMPLETE'),
#   OptimizationRecord(id='18171554', status='COMPLETE'),
#   OptimizationRecord(id='18171555', status='COMPLETE'),
#   OptimizationRecord(id='18171559', status='COMPLETE'),
#   OptimizationRecord(id='18171575', status='COMPLETE'),
#   OptimizationRecord(id='18171576', status='COMPLETE'),
#   OptimizationRecord(id='18171577', status='COMPLETE'),
#   OptimizationRecord(id='18171578', status='COMPLETE'),
#   OptimizationRecord(id='18171579', status='COMPLETE'),
#   OptimizationRecord(id='18171580', status='COMPLETE'),
#   OptimizationRecord(id='18171581', status='COMPLETE'),
#   OptimizationRecord(id='18171582', status='COMPLETE'),
#   OptimizationRecord(id='18171583', status='COMPLETE'),
#   OptimizationRecord(id='18171584', status='COMPLETE'),
#   OptimizationRecord(id='18171585', status='COMPLETE'),
#   OptimizationRecord(id='18171586', status='COMPLETE'),
#   OptimizationRecord(id='18171587', status='COMPLETE'),
#   OptimizationRecord(id='18171588', status='COMPLETE'),
#   OptimizationRecord(id='18171589', status='COMPLETE'),
#   OptimizationRecord(id='18171590', status='COMPLETE'),
#   OptimizationRecord(id='18171591', status='COMPLETE'),
#   OptimizationRecord(id='18171592', status='COMPLETE'),
#   OptimizationRecord(id='18171593', status='COMPLETE'),
#   OptimizationRecord(id='18171594', status='COMPLETE'),
#   OptimizationRecord(id='18171595', status='COMPLETE'),
#   OptimizationRecord(id='18171596', status='COMPLETE'),
#   OptimizationRecord(id='18171597', status='COMPLETE'),
#   OptimizationRecord(id='18171598', status='COMPLETE'),
#   OptimizationRecord(id='18171599', status='COMPLETE'),
#   OptimizationRecord(id='18171600', status='COMPLETE'),
#   OptimizationRecord(id='18171601', status='COMPLETE'),
#   OptimizationRecord(id='18171627', status='COMPLETE'),
#   OptimizationRecord(id='18171628', status='COMPLETE'),
#   OptimizationRecord(id='18171629', status='COMPLETE'),
#   OptimizationRecord(id='18171630', status='COMPLETE'),
#   OptimizationRecord(id='18171631', status='COMPLETE'),
#   OptimizationRecord(id='18171632', status='COMPLETE'),
#   OptimizationRecord(id='18171633', status='COMPLETE'),
#   OptimizationRecord(id='18171634', status='COMPLETE'),
#   OptimizationRecord(id='18171635', status='COMPLETE'),
#   OptimizationRecord(id='18171636', status='COMPLETE'),
#   OptimizationRecord(id='18171637', status='COMPLETE'),
#   OptimizationRecord(id='18171638', status='COMPLETE'),
#   OptimizationRecord(id='18171639', status='COMPLETE'),
#   OptimizationRecord(id='18171652', status='COMPLETE'),
#   OptimizationRecord(id='18171653', status='COMPLETE'),
#   OptimizationRecord(id='18171654', status='COMPLETE'),
#   OptimizationRecord(id='18171655', status='COMPLETE'),
#   OptimizationRecord(id='18171656', status='COMPLETE'),
#   OptimizationRecord(id='18171657', status='COMPLETE'),
#   OptimizationRecord(id='18171658', status='COMPLETE'),
#   OptimizationRecord(id='18171659', status='COMPLETE'),
#   OptimizationRecord(id='18171660', status='COMPLETE'),
#   OptimizationRecord(id='18171661', status='COMPLETE'),
#   OptimizationRecord(id='18171662', status='COMPLETE'),
#   OptimizationRecord(id='18171663', status='COMPLETE'),
#   OptimizationRecord(id='18171664', status='COMPLETE'),
#   OptimizationRecord(id='18171665', status='COMPLETE'),
#   OptimizationRecord(id='18171666', status='COMPLETE'),
#   OptimizationRecord(id='18171667', status='COMPLETE'),
#   OptimizationRecord(id='18171668', status='COMPLETE'),
#   OptimizationRecord(id='18171685', status='COMPLETE'),
#   OptimizationRecord(id='18171686', status='COMPLETE'),
#   OptimizationRecord(id='18171687', status='COMPLETE'),
#   OptimizationRecord(id='18171688', status='COMPLETE')],
#  '18045856': [OptimizationRecord(id='18174481', status='COMPLETE'),
#   OptimizationRecord(id='18174482', status='COMPLETE'),
#   OptimizationRecord(id='18174483', status='COMPLETE'),
#   OptimizationRecord(id='18174484', status='COMPLETE'),
#   OptimizationRecord(id='18174485', status='COMPLETE'),
#   OptimizationRecord(id='18174486', status='COMPLETE'),
#   OptimizationRecord(id='18174487', status='COMPLETE'),
#   OptimizationRecord(id='18174488', status='COMPLETE'),
#   OptimizationRecord(id='18174489', status='COMPLETE'),
#   OptimizationRecord(id='18174490', status='COMPLETE'),
#   OptimizationRecord(id='18174491', status='COMPLETE'),
#   OptimizationRecord(id='18174492', status='COMPLETE'),
#   OptimizationRecord(id='18174493', status='COMPLETE'),
#   OptimizationRecord(id='18174494', status='COMPLETE'),
#   OptimizationRecord(id='18174495', status='COMPLETE'),
#   OptimizationRecord(id='18174496', status='COMPLETE'),
#   OptimizationRecord(id='18174497', status='COMPLETE'),
#   OptimizationRecord(id='18174498', status='COMPLETE'),
#   OptimizationRecord(id='18174499', status='COMPLETE'),
#   OptimizationRecord(id='18174500', status='COMPLETE'),
#   OptimizationRecord(id='18174501', status='COMPLETE'),
#   OptimizationRecord(id='18174502', status='COMPLETE'),
#   OptimizationRecord(id='18174503', status='COMPLETE'),
#   OptimizationRecord(id='18174504', status='COMPLETE'),
#   OptimizationRecord(id='18174505', status='COMPLETE'),
#   OptimizationRecord(id='18174506', status='COMPLETE'),
#   OptimizationRecord(id='18174507', status='COMPLETE'),
#   OptimizationRecord(id='18174508', status='COMPLETE'),
#   OptimizationRecord(id='18174509', status='COMPLETE'),
#   OptimizationRecord(id='18174510', status='COMPLETE'),
#   OptimizationRecord(id='18174511', status='COMPLETE'),
#   OptimizationRecord(id='18174512', status='COMPLETE'),
#   OptimizationRecord(id='18174513', status='COMPLETE'),
#   OptimizationRecord(id='18174514', status='COMPLETE'),
#   OptimizationRecord(id='18174515', status='COMPLETE'),
#   OptimizationRecord(id='18174516', status='COMPLETE'),
#   OptimizationRecord(id='18174517', status='COMPLETE'),
#   OptimizationRecord(id='18174527', status='COMPLETE'),
#   OptimizationRecord(id='18174528', status='COMPLETE'),
#   OptimizationRecord(id='18174529', status='COMPLETE'),
#   OptimizationRecord(id='18174530', status='COMPLETE'),
#   OptimizationRecord(id='18174531', status='COMPLETE'),
#   OptimizationRecord(id='18174532', status='COMPLETE'),
#   OptimizationRecord(id='18174533', status='COMPLETE'),
#   OptimizationRecord(id='18174534', status='COMPLETE'),
#   OptimizationRecord(id='18174547', status='COMPLETE'),
#   OptimizationRecord(id='18174548', status='COMPLETE'),
#   OptimizationRecord(id='18174549', status='COMPLETE'),
#   OptimizationRecord(id='18174550', status='COMPLETE'),
#   OptimizationRecord(id='18174551', status='COMPLETE'),
#   OptimizationRecord(id='18174552', status='COMPLETE'),
#   OptimizationRecord(id='18174553', status='COMPLETE'),
#   OptimizationRecord(id='18174554', status='COMPLETE'),
#   OptimizationRecord(id='18174555', status='COMPLETE'),
#   OptimizationRecord(id='18174556', status='COMPLETE'),
#   OptimizationRecord(id='18174557', status='COMPLETE'),
#   OptimizationRecord(id='18174558', status='COMPLETE'),
#   OptimizationRecord(id='18174559', status='COMPLETE'),
#   OptimizationRecord(id='18174560', status='COMPLETE'),
#   OptimizationRecord(id='18174580', status='COMPLETE'),
#   OptimizationRecord(id='18174581', status='COMPLETE'),
#   OptimizationRecord(id='18174582', status='COMPLETE'),
#   OptimizationRecord(id='18174583', status='COMPLETE'),
#   OptimizationRecord(id='18174584', status='COMPLETE'),
#   OptimizationRecord(id='18174585', status='COMPLETE')],
#  '18045858': [OptimizationRecord(id='18176672', status='COMPLETE'),
#   OptimizationRecord(id='18176673', status='COMPLETE'),
#   OptimizationRecord(id='18176674', status='COMPLETE'),
#   OptimizationRecord(id='18176675', status='COMPLETE'),
#   OptimizationRecord(id='18176676', status='COMPLETE'),
#   OptimizationRecord(id='18176677', status='COMPLETE'),
#   OptimizationRecord(id='18176678', status='COMPLETE'),
#   OptimizationRecord(id='18176679', status='COMPLETE'),
#   OptimizationRecord(id='18176680', status='COMPLETE'),
#   OptimizationRecord(id='18176681', status='COMPLETE'),
#   OptimizationRecord(id='18176682', status='COMPLETE'),
#   OptimizationRecord(id='18176683', status='COMPLETE'),
#   OptimizationRecord(id='18176684', status='COMPLETE'),
#   OptimizationRecord(id='18176685', status='COMPLETE'),
#   OptimizationRecord(id='18176686', status='COMPLETE'),
#   OptimizationRecord(id='18176687', status='COMPLETE'),
#   OptimizationRecord(id='18176701', status='COMPLETE'),
#   OptimizationRecord(id='18176702', status='COMPLETE'),
#   OptimizationRecord(id='18176703', status='INCOMPLETE'),
#   OptimizationRecord(id='18176704', status='COMPLETE'),
#   OptimizationRecord(id='18176705', status='COMPLETE'),
#   OptimizationRecord(id='18176706', status='COMPLETE'),
#   OptimizationRecord(id='18176707', status='COMPLETE'),
#   OptimizationRecord(id='18176708', status='COMPLETE'),
#   OptimizationRecord(id='18176709', status='COMPLETE'),
#   OptimizationRecord(id='18176710', status='COMPLETE'),
#   OptimizationRecord(id='18176711', status='COMPLETE'),
#   OptimizationRecord(id='18176712', status='COMPLETE'),
#   OptimizationRecord(id='18176726', status='COMPLETE'),
#   OptimizationRecord(id='18176727', status='COMPLETE'),
#   OptimizationRecord(id='18176728', status='COMPLETE')],
#  '18045864': [OptimizationRecord(id='18184437', status='COMPLETE'),
#   OptimizationRecord(id='18184438', status='COMPLETE'),
#   OptimizationRecord(id='18184439', status='COMPLETE'),
#   OptimizationRecord(id='18184440', status='COMPLETE'),
#   OptimizationRecord(id='18184443', status='COMPLETE'),
#   OptimizationRecord(id='18184454', status='COMPLETE'),
#   OptimizationRecord(id='18184455', status='COMPLETE'),
#   OptimizationRecord(id='18184456', status='COMPLETE'),
#   OptimizationRecord(id='18184457', status='COMPLETE'),
#   OptimizationRecord(id='18184458', status='COMPLETE'),
#   OptimizationRecord(id='18184459', status='COMPLETE'),
#   OptimizationRecord(id='18184460', status='COMPLETE'),
#   OptimizationRecord(id='18184461', status='COMPLETE'),
#   OptimizationRecord(id='18184462', status='COMPLETE'),
#   OptimizationRecord(id='18184463', status='COMPLETE'),
#   OptimizationRecord(id='18184464', status='COMPLETE'),
#   OptimizationRecord(id='18184465', status='COMPLETE'),
#   OptimizationRecord(id='18184466', status='COMPLETE'),
#   OptimizationRecord(id='18184467', status='COMPLETE'),
#   OptimizationRecord(id='18184468', status='COMPLETE'),
#   OptimizationRecord(id='18184469', status='COMPLETE'),
#   OptimizationRecord(id='18184470', status='COMPLETE'),
#   OptimizationRecord(id='18184471', status='COMPLETE'),
#   OptimizationRecord(id='18184472', status='COMPLETE'),
#   OptimizationRecord(id='18184473', status='COMPLETE'),
#   OptimizationRecord(id='18184474', status='COMPLETE'),
#   OptimizationRecord(id='18184475', status='COMPLETE'),
#   OptimizationRecord(id='18184476', status='COMPLETE'),
#   OptimizationRecord(id='18184477', status='COMPLETE'),
#   OptimizationRecord(id='18184478', status='COMPLETE'),
#   OptimizationRecord(id='18184479', status='COMPLETE'),
#   OptimizationRecord(id='18184480', status='COMPLETE'),
#   OptimizationRecord(id='18184481', status='COMPLETE'),
#   OptimizationRecord(id='18184506', status='COMPLETE'),
#   OptimizationRecord(id='18184507', status='COMPLETE'),
#   OptimizationRecord(id='18184515', status='COMPLETE'),
#   OptimizationRecord(id='18184516', status='COMPLETE'),
#   OptimizationRecord(id='18184517', status='COMPLETE'),
#   OptimizationRecord(id='18184518', status='COMPLETE'),
#   OptimizationRecord(id='18184519', status='COMPLETE'),
#   OptimizationRecord(id='18184520', status='COMPLETE'),
#   OptimizationRecord(id='18184521', status='COMPLETE'),
#   OptimizationRecord(id='18184522', status='COMPLETE'),
#   OptimizationRecord(id='18184523', status='COMPLETE'),
#   OptimizationRecord(id='18184524', status='COMPLETE'),
#   OptimizationRecord(id='18184525', status='COMPLETE'),
#   OptimizationRecord(id='18184526', status='COMPLETE'),
#   OptimizationRecord(id='18184527', status='COMPLETE'),
#   OptimizationRecord(id='18184528', status='COMPLETE'),
#   OptimizationRecord(id='18184529', status='COMPLETE'),
#   OptimizationRecord(id='18184530', status='COMPLETE'),
#   OptimizationRecord(id='18184531', status='COMPLETE'),
#   OptimizationRecord(id='18184532', status='COMPLETE'),
#   OptimizationRecord(id='18184533', status='COMPLETE'),
#   OptimizationRecord(id='18184534', status='COMPLETE'),
#   OptimizationRecord(id='18184535', status='COMPLETE'),
#   OptimizationRecord(id='18184536', status='COMPLETE'),
#   OptimizationRecord(id='18184537', status='COMPLETE'),
#   OptimizationRecord(id='18184538', status='COMPLETE'),
#   OptimizationRecord(id='18184539', status='COMPLETE'),
#   OptimizationRecord(id='18184540', status='COMPLETE'),
#   OptimizationRecord(id='18184541', status='COMPLETE'),
#   OptimizationRecord(id='18184542', status='COMPLETE'),
#   OptimizationRecord(id='18184543', status='COMPLETE'),
#   OptimizationRecord(id='18184544', status='COMPLETE'),
#   OptimizationRecord(id='18184545', status='COMPLETE'),
#   OptimizationRecord(id='18184546', status='COMPLETE'),
#   OptimizationRecord(id='18184547', status='COMPLETE'),
#   OptimizationRecord(id='18184548', status='COMPLETE'),
#   OptimizationRecord(id='18184549', status='COMPLETE'),
#   OptimizationRecord(id='18184550', status='COMPLETE'),
#   OptimizationRecord(id='18184551', status='COMPLETE'),
#   OptimizationRecord(id='18184552', status='COMPLETE'),
#   OptimizationRecord(id='18184553', status='COMPLETE'),
#   OptimizationRecord(id='18184554', status='COMPLETE'),
#   OptimizationRecord(id='18184555', status='COMPLETE'),
#   OptimizationRecord(id='18184556', status='COMPLETE'),
#   OptimizationRecord(id='18184557', status='COMPLETE'),
#   OptimizationRecord(id='18184558', status='COMPLETE'),
#   OptimizationRecord(id='18184559', status='COMPLETE'),
#   OptimizationRecord(id='18184560', status='COMPLETE'),
#   OptimizationRecord(id='18184561', status='COMPLETE'),
#   OptimizationRecord(id='18184562', status='COMPLETE'),
#   OptimizationRecord(id='18184563', status='COMPLETE'),
#   OptimizationRecord(id='18184564', status='COMPLETE'),
#   OptimizationRecord(id='18184594', status='COMPLETE'),
#   OptimizationRecord(id='18184595', status='COMPLETE'),
#   OptimizationRecord(id='18184605', status='COMPLETE'),
#   OptimizationRecord(id='18184606', status='COMPLETE'),
#   OptimizationRecord(id='18184607', status='COMPLETE'),
#   OptimizationRecord(id='18184608', status='COMPLETE'),
#   OptimizationRecord(id='18184609', status='COMPLETE'),
#   OptimizationRecord(id='18184610', status='COMPLETE'),
#   OptimizationRecord(id='18184611', status='COMPLETE'),
#   OptimizationRecord(id='18184612', status='COMPLETE'),
#   OptimizationRecord(id='18184613', status='COMPLETE'),
#   OptimizationRecord(id='18184614', status='COMPLETE'),
#   OptimizationRecord(id='18184615', status='COMPLETE'),
#   OptimizationRecord(id='18184616', status='COMPLETE'),
#   OptimizationRecord(id='18184617', status='COMPLETE'),
#   OptimizationRecord(id='18184618', status='COMPLETE'),
#   OptimizationRecord(id='18184619', status='COMPLETE'),
#   OptimizationRecord(id='18184620', status='COMPLETE'),
#   OptimizationRecord(id='18184621', status='COMPLETE'),
#   OptimizationRecord(id='18184622', status='COMPLETE'),
#   OptimizationRecord(id='18184623', status='COMPLETE'),
#   OptimizationRecord(id='18184624', status='COMPLETE'),
#   OptimizationRecord(id='18184632', status='COMPLETE'),
#   OptimizationRecord(id='18184633', status='COMPLETE'),
#   OptimizationRecord(id='18184634', status='COMPLETE'),
#   OptimizationRecord(id='18184642', status='COMPLETE'),
#   OptimizationRecord(id='18184643', status='COMPLETE'),
#   OptimizationRecord(id='18184644', status='COMPLETE'),
#   OptimizationRecord(id='18184645', status='COMPLETE'),
#   OptimizationRecord(id='18184646', status='COMPLETE'),
#   OptimizationRecord(id='18184647', status='COMPLETE'),
#   OptimizationRecord(id='18184648', status='COMPLETE'),
#   OptimizationRecord(id='18184649', status='COMPLETE'),
#   OptimizationRecord(id='18184650', status='COMPLETE'),
#   OptimizationRecord(id='18184651', status='COMPLETE'),
#   OptimizationRecord(id='18184652', status='COMPLETE'),
#   OptimizationRecord(id='18184653', status='COMPLETE'),
#   OptimizationRecord(id='18184654', status='COMPLETE'),
#   OptimizationRecord(id='18184655', status='COMPLETE'),
#   OptimizationRecord(id='18184656', status='COMPLETE'),
#   OptimizationRecord(id='18184657', status='COMPLETE'),
#   OptimizationRecord(id='18184658', status='COMPLETE'),
#   OptimizationRecord(id='18184659', status='COMPLETE'),
#   OptimizationRecord(id='18184660', status='COMPLETE'),
#   OptimizationRecord(id='18184661', status='COMPLETE'),
#   OptimizationRecord(id='18184662', status='COMPLETE'),
#   OptimizationRecord(id='18184663', status='COMPLETE'),
#   OptimizationRecord(id='18184664', status='COMPLETE'),
#   OptimizationRecord(id='18184665', status='COMPLETE'),
#   OptimizationRecord(id='18184666', status='COMPLETE'),
#   OptimizationRecord(id='18184667', status='COMPLETE'),
#   OptimizationRecord(id='18184668', status='COMPLETE'),
#   OptimizationRecord(id='18184669', status='COMPLETE'),
#   OptimizationRecord(id='18184670', status='COMPLETE'),
#   OptimizationRecord(id='18184671', status='COMPLETE'),
#   OptimizationRecord(id='18184672', status='COMPLETE'),
#   OptimizationRecord(id='18184673', status='COMPLETE'),
#   OptimizationRecord(id='18184674', status='COMPLETE'),
#   OptimizationRecord(id='18184675', status='COMPLETE'),
#   OptimizationRecord(id='18184676', status='COMPLETE'),
#   OptimizationRecord(id='18184677', status='COMPLETE'),
#   OptimizationRecord(id='18184678', status='COMPLETE'),
#   OptimizationRecord(id='18184690', status='COMPLETE'),
#   OptimizationRecord(id='18184691', status='COMPLETE'),
#   OptimizationRecord(id='18184692', status='COMPLETE'),
#   OptimizationRecord(id='18184693', status='COMPLETE'),
#   OptimizationRecord(id='18184694', status='COMPLETE'),
#   OptimizationRecord(id='18184695', status='COMPLETE'),
#   OptimizationRecord(id='18184696', status='COMPLETE'),
#   OptimizationRecord(id='18184697', status='COMPLETE'),
#   OptimizationRecord(id='18184698', status='COMPLETE'),
#   OptimizationRecord(id='18184699', status='COMPLETE'),
#   OptimizationRecord(id='18184700', status='COMPLETE'),
#   OptimizationRecord(id='18184701', status='COMPLETE'),
#   OptimizationRecord(id='18184702', status='COMPLETE'),
#   OptimizationRecord(id='18184703', status='COMPLETE'),
#   OptimizationRecord(id='18184704', status='COMPLETE'),
#   OptimizationRecord(id='18184705', status='COMPLETE'),
#   OptimizationRecord(id='18184706', status='COMPLETE'),
#   OptimizationRecord(id='18184707', status='COMPLETE'),
#   OptimizationRecord(id='18184708', status='COMPLETE'),
#   OptimizationRecord(id='18184709', status='COMPLETE'),
#   OptimizationRecord(id='18184710', status='COMPLETE'),
#   OptimizationRecord(id='18184711', status='COMPLETE'),
#   OptimizationRecord(id='18184712', status='COMPLETE'),
#   OptimizationRecord(id='18184713', status='COMPLETE'),
#   OptimizationRecord(id='18184714', status='COMPLETE'),
#   OptimizationRecord(id='18184715', status='COMPLETE'),
#   OptimizationRecord(id='18184716', status='COMPLETE'),
#   OptimizationRecord(id='18184717', status='COMPLETE'),
#   OptimizationRecord(id='18184718', status='COMPLETE'),
#   OptimizationRecord(id='18184719', status='COMPLETE'),
#   OptimizationRecord(id='18184720', status='COMPLETE'),
#   OptimizationRecord(id='18184721', status='COMPLETE'),
#   OptimizationRecord(id='18184722', status='COMPLETE'),
#   OptimizationRecord(id='18184723', status='COMPLETE'),
#   OptimizationRecord(id='18184724', status='COMPLETE'),
#   OptimizationRecord(id='18184725', status='COMPLETE'),
#   OptimizationRecord(id='18184726', status='COMPLETE'),
#   OptimizationRecord(id='18184727', status='COMPLETE'),
#   OptimizationRecord(id='18184728', status='COMPLETE'),
#   OptimizationRecord(id='18184729', status='COMPLETE'),
#   OptimizationRecord(id='18184730', status='COMPLETE'),
#   OptimizationRecord(id='18184731', status='COMPLETE'),
#   OptimizationRecord(id='18184732', status='COMPLETE'),
#   OptimizationRecord(id='18184733', status='COMPLETE'),
#   OptimizationRecord(id='18184734', status='COMPLETE'),
#   OptimizationRecord(id='18184735', status='COMPLETE'),
#   OptimizationRecord(id='18184736', status='COMPLETE'),
#   OptimizationRecord(id='18184737', status='COMPLETE'),
#   OptimizationRecord(id='18184738', status='COMPLETE'),
#   OptimizationRecord(id='18184739', status='COMPLETE'),
#   OptimizationRecord(id='18184740', status='COMPLETE'),
#   OptimizationRecord(id='18184741', status='COMPLETE'),
#   OptimizationRecord(id='18184742', status='COMPLETE'),
#   OptimizationRecord(id='18184743', status='COMPLETE'),
#   OptimizationRecord(id='18184744', status='COMPLETE'),
#   OptimizationRecord(id='18184745', status='COMPLETE'),
#   OptimizationRecord(id='18184746', status='COMPLETE'),
#   OptimizationRecord(id='18184758', status='COMPLETE'),
#   OptimizationRecord(id='18184759', status='COMPLETE'),
#   OptimizationRecord(id='18184760', status='COMPLETE'),
#   OptimizationRecord(id='18184761', status='COMPLETE'),
#   OptimizationRecord(id='18184762', status='COMPLETE'),
#   OptimizationRecord(id='18184763', status='COMPLETE'),
#   OptimizationRecord(id='18184764', status='COMPLETE'),
#   OptimizationRecord(id='18184765', status='COMPLETE'),
#   OptimizationRecord(id='18184766', status='COMPLETE'),
#   OptimizationRecord(id='18184767', status='COMPLETE'),
#   OptimizationRecord(id='18184768', status='COMPLETE'),
#   OptimizationRecord(id='18184769', status='COMPLETE'),
#   OptimizationRecord(id='18184770', status='COMPLETE'),
#   OptimizationRecord(id='18184771', status='COMPLETE'),
#   OptimizationRecord(id='18184772', status='COMPLETE'),
#   OptimizationRecord(id='18184773', status='COMPLETE'),
#   OptimizationRecord(id='18184787', status='COMPLETE'),
#   OptimizationRecord(id='18184788', status='COMPLETE'),
#   OptimizationRecord(id='18184789', status='COMPLETE'),
#   OptimizationRecord(id='18184790', status='COMPLETE'),
#   OptimizationRecord(id='18184791', status='COMPLETE'),
#   OptimizationRecord(id='18184792', status='COMPLETE'),
#   OptimizationRecord(id='18184793', status='COMPLETE'),
#   OptimizationRecord(id='18184794', status='COMPLETE'),
#   OptimizationRecord(id='18184795', status='COMPLETE'),
#   OptimizationRecord(id='18184796', status='COMPLETE'),
#   OptimizationRecord(id='18184797', status='COMPLETE'),
#   OptimizationRecord(id='18184798', status='COMPLETE'),
#   OptimizationRecord(id='18184799', status='COMPLETE'),
#   OptimizationRecord(id='18184800', status='COMPLETE'),
#   OptimizationRecord(id='18184801', status='COMPLETE'),
#   OptimizationRecord(id='18184802', status='COMPLETE'),
#   OptimizationRecord(id='18184803', status='COMPLETE'),
#   OptimizationRecord(id='18184804', status='COMPLETE'),
#   OptimizationRecord(id='18184805', status='COMPLETE'),
#   OptimizationRecord(id='18184806', status='COMPLETE'),
#   OptimizationRecord(id='18184807', status='COMPLETE'),
#   OptimizationRecord(id='18184808', status='COMPLETE'),
#   OptimizationRecord(id='18184809', status='COMPLETE'),
#   OptimizationRecord(id='18184810', status='COMPLETE'),
#   OptimizationRecord(id='18184811', status='COMPLETE'),
#   OptimizationRecord(id='18184812', status='COMPLETE'),
#   OptimizationRecord(id='18184813', status='COMPLETE'),
#   OptimizationRecord(id='18184814', status='INCOMPLETE'),
#   OptimizationRecord(id='18184815', status='COMPLETE'),
#   OptimizationRecord(id='18184816', status='COMPLETE'),
#   OptimizationRecord(id='18184817', status='COMPLETE'),
#   OptimizationRecord(id='18184818', status='COMPLETE'),
#   OptimizationRecord(id='18184819', status='COMPLETE'),
#   OptimizationRecord(id='18184820', status='COMPLETE'),
#   OptimizationRecord(id='18184821', status='COMPLETE'),
#   OptimizationRecord(id='18184822', status='COMPLETE'),
#   OptimizationRecord(id='18184842', status='COMPLETE'),
#   OptimizationRecord(id='18184843', status='COMPLETE'),
#   OptimizationRecord(id='18184844', status='COMPLETE'),
#   OptimizationRecord(id='18184845', status='COMPLETE'),
#   OptimizationRecord(id='18184846', status='COMPLETE'),
#   OptimizationRecord(id='18184847', status='COMPLETE'),
#   OptimizationRecord(id='18184848', status='COMPLETE'),
#   OptimizationRecord(id='18184849', status='COMPLETE'),
#   OptimizationRecord(id='18184850', status='COMPLETE'),
#   OptimizationRecord(id='18184851', status='COMPLETE'),
#   OptimizationRecord(id='18184852', status='COMPLETE'),
#   OptimizationRecord(id='18184853', status='COMPLETE'),
#   OptimizationRecord(id='18184854', status='COMPLETE'),
#   OptimizationRecord(id='18184855', status='COMPLETE'),
#   OptimizationRecord(id='18184856', status='COMPLETE'),
#   OptimizationRecord(id='18184863', status='COMPLETE'),
#   OptimizationRecord(id='18184864', status='COMPLETE'),
#   OptimizationRecord(id='18184865', status='COMPLETE'),
#   OptimizationRecord(id='18184866', status='COMPLETE'),
#   OptimizationRecord(id='18184867', status='COMPLETE'),
#   OptimizationRecord(id='18184868', status='COMPLETE'),
#   OptimizationRecord(id='18184869', status='COMPLETE'),
#   OptimizationRecord(id='18184870', status='COMPLETE'),
#   OptimizationRecord(id='18184871', status='COMPLETE'),
#   OptimizationRecord(id='18184872', status='COMPLETE'),
#   OptimizationRecord(id='18184873', status='COMPLETE'),
#   OptimizationRecord(id='18184874', status='COMPLETE'),
#   OptimizationRecord(id='18184875', status='COMPLETE'),
#   OptimizationRecord(id='18184876', status='COMPLETE'),
#   OptimizationRecord(id='18184877', status='COMPLETE'),
#   OptimizationRecord(id='18184878', status='COMPLETE'),
#   OptimizationRecord(id='18184879', status='COMPLETE'),
#   OptimizationRecord(id='18184880', status='COMPLETE'),
#   OptimizationRecord(id='18184881', status='COMPLETE'),
#   OptimizationRecord(id='18184882', status='COMPLETE'),
#   OptimizationRecord(id='18184883', status='COMPLETE'),
#   OptimizationRecord(id='18184884', status='COMPLETE'),
#   OptimizationRecord(id='18184885', status='COMPLETE'),
#   OptimizationRecord(id='18184886', status='COMPLETE'),
#   OptimizationRecord(id='18184887', status='COMPLETE'),
#   OptimizationRecord(id='18184888', status='COMPLETE'),
#   OptimizationRecord(id='18184889', status='COMPLETE'),
#   OptimizationRecord(id='18184890', status='COMPLETE'),
#   OptimizationRecord(id='18184891', status='COMPLETE'),
#   OptimizationRecord(id='18184892', status='COMPLETE'),
#   OptimizationRecord(id='18184893', status='COMPLETE'),
#   OptimizationRecord(id='18184894', status='COMPLETE'),
#   OptimizationRecord(id='18184895', status='COMPLETE'),
#   OptimizationRecord(id='18184896', status='COMPLETE'),
#   OptimizationRecord(id='18184897', status='COMPLETE'),
#   OptimizationRecord(id='18184898', status='COMPLETE'),
#   OptimizationRecord(id='18184899', status='COMPLETE'),
#   OptimizationRecord(id='18184900', status='COMPLETE'),
#   OptimizationRecord(id='18184901', status='COMPLETE'),
#   OptimizationRecord(id='18184902', status='INCOMPLETE'),
#   OptimizationRecord(id='18184903', status='COMPLETE'),
#   OptimizationRecord(id='18184909', status='COMPLETE'),
#   OptimizationRecord(id='18184921', status='COMPLETE'),
#   OptimizationRecord(id='18184922', status='COMPLETE'),
#   OptimizationRecord(id='18184940', status='COMPLETE'),
#   OptimizationRecord(id='18184946', status='COMPLETE'),
#   OptimizationRecord(id='18184947', status='COMPLETE'),
#   OptimizationRecord(id='18184948', status='COMPLETE'),
#   OptimizationRecord(id='18184949', status='COMPLETE'),
#   OptimizationRecord(id='18184950', status='COMPLETE'),
#   OptimizationRecord(id='18184951', status='COMPLETE'),
#   OptimizationRecord(id='18184952', status='COMPLETE')],
#  '18045865': [OptimizationRecord(id='18185168', status='COMPLETE'),
#   OptimizationRecord(id='18185169', status='COMPLETE'),
#   OptimizationRecord(id='18185170', status='COMPLETE'),
#   OptimizationRecord(id='18185171', status='COMPLETE'),
#   OptimizationRecord(id='18185172', status='COMPLETE'),
#   OptimizationRecord(id='18185173', status='COMPLETE'),
#   OptimizationRecord(id='18185174', status='COMPLETE'),
#   OptimizationRecord(id='18185175', status='COMPLETE'),
#   OptimizationRecord(id='18185176', status='COMPLETE'),
#   OptimizationRecord(id='18185177', status='COMPLETE'),
#   OptimizationRecord(id='18185178', status='COMPLETE'),
#   OptimizationRecord(id='18185179', status='COMPLETE'),
#   OptimizationRecord(id='18185180', status='COMPLETE'),
#   OptimizationRecord(id='18185181', status='COMPLETE'),
#   OptimizationRecord(id='18185182', status='COMPLETE'),
#   OptimizationRecord(id='18185183', status='COMPLETE'),
#   OptimizationRecord(id='18185184', status='COMPLETE'),
#   OptimizationRecord(id='18185185', status='COMPLETE'),
#   OptimizationRecord(id='18185186', status='COMPLETE'),
#   OptimizationRecord(id='18185187', status='COMPLETE'),
#   OptimizationRecord(id='18185188', status='COMPLETE'),
#   OptimizationRecord(id='18185189', status='COMPLETE'),
#   OptimizationRecord(id='18185190', status='COMPLETE'),
#   OptimizationRecord(id='18185191', status='COMPLETE'),
#   OptimizationRecord(id='18185192', status='COMPLETE'),
#   OptimizationRecord(id='18185193', status='COMPLETE'),
#   OptimizationRecord(id='18185194', status='INCOMPLETE'),
#   OptimizationRecord(id='18185195', status='COMPLETE'),
#   OptimizationRecord(id='18185196', status='COMPLETE'),
#   OptimizationRecord(id='18185197', status='COMPLETE'),
#   OptimizationRecord(id='18185198', status='COMPLETE'),
#   OptimizationRecord(id='18185199', status='COMPLETE'),
#   OptimizationRecord(id='18185200', status='COMPLETE'),
#   OptimizationRecord(id='18185201', status='COMPLETE'),
#   OptimizationRecord(id='18185202', status='COMPLETE'),
#   OptimizationRecord(id='18185203', status='COMPLETE'),
#   OptimizationRecord(id='18185204', status='COMPLETE'),
#   OptimizationRecord(id='18185205', status='COMPLETE'),
#   OptimizationRecord(id='18185206', status='COMPLETE'),
#   OptimizationRecord(id='18185207', status='COMPLETE'),
#   OptimizationRecord(id='18185208', status='COMPLETE'),
#   OptimizationRecord(id='18185209', status='COMPLETE'),
#   OptimizationRecord(id='18185210', status='COMPLETE'),
#   OptimizationRecord(id='18185211', status='COMPLETE'),
#   OptimizationRecord(id='18185212', status='COMPLETE'),
#   OptimizationRecord(id='18185213', status='COMPLETE'),
#   OptimizationRecord(id='18185214', status='COMPLETE'),
#   OptimizationRecord(id='18185215', status='COMPLETE'),
#   OptimizationRecord(id='18185216', status='COMPLETE'),
#   OptimizationRecord(id='18185217', status='COMPLETE'),
#   OptimizationRecord(id='18185218', status='COMPLETE'),
#   OptimizationRecord(id='18185219', status='COMPLETE'),
#   OptimizationRecord(id='18185220', status='COMPLETE'),
#   OptimizationRecord(id='18185221', status='COMPLETE'),
#   OptimizationRecord(id='18185222', status='COMPLETE'),
#   OptimizationRecord(id='18185223', status='COMPLETE'),
#   OptimizationRecord(id='18185224', status='COMPLETE'),
#   OptimizationRecord(id='18185225', status='COMPLETE'),
#   OptimizationRecord(id='18185226', status='COMPLETE'),
#   OptimizationRecord(id='18185227', status='COMPLETE'),
#   OptimizationRecord(id='18185228', status='COMPLETE'),
#   OptimizationRecord(id='18185229', status='COMPLETE'),
#   OptimizationRecord(id='18185230', status='COMPLETE'),
#   OptimizationRecord(id='18185231', status='COMPLETE'),
#   OptimizationRecord(id='18185232', status='COMPLETE'),
#   OptimizationRecord(id='18185233', status='COMPLETE'),
#   OptimizationRecord(id='18185234', status='COMPLETE'),
#   OptimizationRecord(id='18185235', status='COMPLETE'),
#   OptimizationRecord(id='18185236', status='COMPLETE'),
#   OptimizationRecord(id='18185237', status='COMPLETE'),
#   OptimizationRecord(id='18185238', status='COMPLETE'),
#   OptimizationRecord(id='18185239', status='COMPLETE'),
#   OptimizationRecord(id='18185240', status='COMPLETE'),
#   OptimizationRecord(id='18185241', status='COMPLETE'),
#   OptimizationRecord(id='18185242', status='COMPLETE'),
#   OptimizationRecord(id='18185243', status='COMPLETE'),
#   OptimizationRecord(id='18185244', status='COMPLETE'),
#   OptimizationRecord(id='18185245', status='COMPLETE'),
#   OptimizationRecord(id='18185246', status='COMPLETE'),
#   OptimizationRecord(id='18185247', status='COMPLETE'),
#   OptimizationRecord(id='18185248', status='COMPLETE'),
#   OptimizationRecord(id='18185260', status='COMPLETE'),
#   OptimizationRecord(id='18185261', status='COMPLETE'),
#   OptimizationRecord(id='18185262', status='COMPLETE'),
#   OptimizationRecord(id='18185263', status='COMPLETE'),
#   OptimizationRecord(id='18185264', status='COMPLETE'),
#   OptimizationRecord(id='18185265', status='COMPLETE'),
#   OptimizationRecord(id='18185266', status='COMPLETE'),
#   OptimizationRecord(id='18185267', status='COMPLETE'),
#   OptimizationRecord(id='18185268', status='COMPLETE'),
#   OptimizationRecord(id='18185269', status='COMPLETE'),
#   OptimizationRecord(id='18185270', status='COMPLETE'),
#   OptimizationRecord(id='18185271', status='COMPLETE'),
#   OptimizationRecord(id='18185272', status='COMPLETE'),
#   OptimizationRecord(id='18185273', status='COMPLETE'),
#   OptimizationRecord(id='18185274', status='COMPLETE'),
#   OptimizationRecord(id='18185275', status='COMPLETE'),
#   OptimizationRecord(id='18185276', status='COMPLETE'),
#   OptimizationRecord(id='18185277', status='COMPLETE'),
#   OptimizationRecord(id='18185278', status='COMPLETE'),
#   OptimizationRecord(id='18185279', status='COMPLETE'),
#   OptimizationRecord(id='18185280', status='COMPLETE'),
#   OptimizationRecord(id='18185281', status='COMPLETE'),
#   OptimizationRecord(id='18185282', status='COMPLETE'),
#   OptimizationRecord(id='18185283', status='COMPLETE'),
#   OptimizationRecord(id='18185284', status='COMPLETE'),
#   OptimizationRecord(id='18185285', status='COMPLETE'),
#   OptimizationRecord(id='18185286', status='COMPLETE'),
#   OptimizationRecord(id='18185287', status='COMPLETE'),
#   OptimizationRecord(id='18185288', status='COMPLETE'),
#   OptimizationRecord(id='18185289', status='COMPLETE'),
#   OptimizationRecord(id='18185290', status='COMPLETE'),
#   OptimizationRecord(id='18185291', status='COMPLETE'),
#   OptimizationRecord(id='18185292', status='COMPLETE'),
#   OptimizationRecord(id='18185293', status='COMPLETE'),
#   OptimizationRecord(id='18185294', status='COMPLETE'),
#   OptimizationRecord(id='18185295', status='COMPLETE'),
#   OptimizationRecord(id='18185296', status='COMPLETE'),
#   OptimizationRecord(id='18185297', status='COMPLETE'),
#   OptimizationRecord(id='18185298', status='COMPLETE'),
#   OptimizationRecord(id='18185299', status='COMPLETE'),
#   OptimizationRecord(id='18185300', status='COMPLETE'),
#   OptimizationRecord(id='18185301', status='COMPLETE'),
#   OptimizationRecord(id='18185302', status='COMPLETE'),
#   OptimizationRecord(id='18185313', status='COMPLETE'),
#   OptimizationRecord(id='18185314', status='COMPLETE'),
#   OptimizationRecord(id='18185315', status='COMPLETE'),
#   OptimizationRecord(id='18185316', status='COMPLETE'),
#   OptimizationRecord(id='18185317', status='COMPLETE'),
#   OptimizationRecord(id='18185318', status='COMPLETE'),
#   OptimizationRecord(id='18185319', status='COMPLETE'),
#   OptimizationRecord(id='18185320', status='COMPLETE'),
#   OptimizationRecord(id='18185321', status='COMPLETE'),
#   OptimizationRecord(id='18185322', status='COMPLETE'),
#   OptimizationRecord(id='18185331', status='COMPLETE'),
#   OptimizationRecord(id='18185332', status='COMPLETE'),
#   OptimizationRecord(id='18185333', status='COMPLETE'),
#   OptimizationRecord(id='18185334', status='COMPLETE'),
#   OptimizationRecord(id='18185335', status='COMPLETE'),
#   OptimizationRecord(id='18185336', status='COMPLETE'),
#   OptimizationRecord(id='18185337', status='COMPLETE'),
#   OptimizationRecord(id='18185338', status='COMPLETE'),
#   OptimizationRecord(id='18185339', status='COMPLETE'),
#   OptimizationRecord(id='18185340', status='COMPLETE'),
#   OptimizationRecord(id='18185341', status='COMPLETE'),
#   OptimizationRecord(id='18185342', status='COMPLETE'),
#   OptimizationRecord(id='18185343', status='COMPLETE'),
#   OptimizationRecord(id='18185344', status='COMPLETE'),
#   OptimizationRecord(id='18185345', status='COMPLETE'),
#   OptimizationRecord(id='18185346', status='COMPLETE'),
#   OptimizationRecord(id='18185347', status='COMPLETE'),
#   OptimizationRecord(id='18185348', status='COMPLETE'),
#   OptimizationRecord(id='18185349', status='COMPLETE'),
#   OptimizationRecord(id='18185350', status='COMPLETE'),
#   OptimizationRecord(id='18185351', status='COMPLETE'),
#   OptimizationRecord(id='18185352', status='COMPLETE'),
#   OptimizationRecord(id='18185353', status='COMPLETE'),
#   OptimizationRecord(id='18185354', status='COMPLETE'),
#   OptimizationRecord(id='18185355', status='COMPLETE'),
#   OptimizationRecord(id='18185356', status='COMPLETE'),
#   OptimizationRecord(id='18185357', status='COMPLETE'),
#   OptimizationRecord(id='18185358', status='COMPLETE'),
#   OptimizationRecord(id='18185359', status='COMPLETE'),
#   OptimizationRecord(id='18185360', status='COMPLETE'),
#   OptimizationRecord(id='18185361', status='COMPLETE'),
#   OptimizationRecord(id='18185362', status='COMPLETE'),
#   OptimizationRecord(id='18185363', status='COMPLETE'),
#   OptimizationRecord(id='18185364', status='COMPLETE'),
#   OptimizationRecord(id='18185365', status='COMPLETE'),
#   OptimizationRecord(id='18185366', status='COMPLETE'),
#   OptimizationRecord(id='18185367', status='INCOMPLETE'),
#   OptimizationRecord(id='18185368', status='COMPLETE'),
#   OptimizationRecord(id='18185369', status='COMPLETE'),
#   OptimizationRecord(id='18185370', status='COMPLETE'),
#   OptimizationRecord(id='18185371', status='COMPLETE'),
#   OptimizationRecord(id='18185372', status='COMPLETE'),
#   OptimizationRecord(id='18185373', status='COMPLETE'),
#   OptimizationRecord(id='18185374', status='COMPLETE'),
#   OptimizationRecord(id='18185375', status='COMPLETE'),
#   OptimizationRecord(id='18185376', status='COMPLETE'),
#   OptimizationRecord(id='18185377', status='COMPLETE'),
#   OptimizationRecord(id='18185378', status='COMPLETE'),
#   OptimizationRecord(id='18185379', status='COMPLETE'),
#   OptimizationRecord(id='18185380', status='COMPLETE'),
#   OptimizationRecord(id='18185381', status='COMPLETE'),
#   OptimizationRecord(id='18185382', status='COMPLETE'),
#   OptimizationRecord(id='18185383', status='COMPLETE'),
#   OptimizationRecord(id='18185384', status='COMPLETE'),
#   OptimizationRecord(id='18185385', status='COMPLETE'),
#   OptimizationRecord(id='18185386', status='COMPLETE'),
#   OptimizationRecord(id='18185387', status='COMPLETE'),
#   OptimizationRecord(id='18185388', status='COMPLETE'),
#   OptimizationRecord(id='18185389', status='COMPLETE'),
#   OptimizationRecord(id='18185390', status='COMPLETE'),
#   OptimizationRecord(id='18185402', status='COMPLETE'),
#   OptimizationRecord(id='18185403', status='COMPLETE'),
#   OptimizationRecord(id='18185404', status='COMPLETE'),
#   OptimizationRecord(id='18185405', status='COMPLETE'),
#   OptimizationRecord(id='18185406', status='COMPLETE'),
#   OptimizationRecord(id='18185407', status='COMPLETE'),
#   OptimizationRecord(id='18185408', status='COMPLETE'),
#   OptimizationRecord(id='18185409', status='COMPLETE'),
#   OptimizationRecord(id='18185410', status='COMPLETE'),
#   OptimizationRecord(id='18185411', status='COMPLETE'),
#   OptimizationRecord(id='18185412', status='COMPLETE'),
#   OptimizationRecord(id='18185413', status='COMPLETE'),
#   OptimizationRecord(id='18185414', status='COMPLETE'),
#   OptimizationRecord(id='18185415', status='COMPLETE'),
#   OptimizationRecord(id='18185416', status='COMPLETE'),
#   OptimizationRecord(id='18185417', status='COMPLETE'),
#   OptimizationRecord(id='18185418', status='COMPLETE'),
#   OptimizationRecord(id='18185419', status='COMPLETE'),
#   OptimizationRecord(id='18185420', status='COMPLETE'),
#   OptimizationRecord(id='18185421', status='COMPLETE'),
#   OptimizationRecord(id='18185422', status='COMPLETE'),
#   OptimizationRecord(id='18185423', status='COMPLETE'),
#   OptimizationRecord(id='18185424', status='COMPLETE'),
#   OptimizationRecord(id='18185425', status='COMPLETE'),
#   OptimizationRecord(id='18185426', status='COMPLETE'),
#   OptimizationRecord(id='18185427', status='INCOMPLETE'),
#   OptimizationRecord(id='18185428', status='COMPLETE'),
#   OptimizationRecord(id='18185429', status='COMPLETE'),
#   OptimizationRecord(id='18185430', status='COMPLETE'),
#   OptimizationRecord(id='18185431', status='COMPLETE'),
#   OptimizationRecord(id='18185432', status='COMPLETE'),
#   OptimizationRecord(id='18185433', status='COMPLETE'),
#   OptimizationRecord(id='18185434', status='COMPLETE'),
#   OptimizationRecord(id='18185435', status='COMPLETE'),
#   OptimizationRecord(id='18185448', status='COMPLETE'),
#   OptimizationRecord(id='18185449', status='COMPLETE'),
#   OptimizationRecord(id='18185450', status='COMPLETE'),
#   OptimizationRecord(id='18185451', status='COMPLETE'),
#   OptimizationRecord(id='18185452', status='COMPLETE'),
#   OptimizationRecord(id='18185453', status='COMPLETE')],
#  '18045869': [OptimizationRecord(id='18188601', status='COMPLETE'),
#   OptimizationRecord(id='18188602', status='COMPLETE'),
#   OptimizationRecord(id='18188603', status='COMPLETE'),
#   OptimizationRecord(id='18188604', status='COMPLETE'),
#   OptimizationRecord(id='18188605', status='COMPLETE'),
#   OptimizationRecord(id='18188606', status='COMPLETE'),
#   OptimizationRecord(id='18188607', status='COMPLETE'),
#   OptimizationRecord(id='18188608', status='COMPLETE'),
#   OptimizationRecord(id='18188609', status='COMPLETE'),
#   OptimizationRecord(id='18188610', status='COMPLETE'),
#   OptimizationRecord(id='18188611', status='COMPLETE'),
#   OptimizationRecord(id='18188612', status='COMPLETE'),
#   OptimizationRecord(id='18188613', status='COMPLETE'),
#   OptimizationRecord(id='18188614', status='COMPLETE'),
#   OptimizationRecord(id='18188615', status='COMPLETE'),
#   OptimizationRecord(id='18188616', status='COMPLETE'),
#   OptimizationRecord(id='18188617', status='COMPLETE'),
#   OptimizationRecord(id='18188618', status='COMPLETE'),
#   OptimizationRecord(id='18188619', status='COMPLETE'),
#   OptimizationRecord(id='18188620', status='COMPLETE'),
#   OptimizationRecord(id='18188621', status='COMPLETE'),
#   OptimizationRecord(id='18188622', status='COMPLETE'),
#   OptimizationRecord(id='18188623', status='COMPLETE'),
#   OptimizationRecord(id='18188624', status='COMPLETE'),
#   OptimizationRecord(id='18188625', status='COMPLETE'),
#   OptimizationRecord(id='18188626', status='COMPLETE'),
#   OptimizationRecord(id='18188627', status='COMPLETE'),
#   OptimizationRecord(id='18188628', status='COMPLETE'),
#   OptimizationRecord(id='18188629', status='COMPLETE'),
#   OptimizationRecord(id='18188630', status='COMPLETE'),
#   OptimizationRecord(id='18188631', status='COMPLETE'),
#   OptimizationRecord(id='18188632', status='COMPLETE'),
#   OptimizationRecord(id='18188633', status='COMPLETE'),
#   OptimizationRecord(id='18188634', status='COMPLETE'),
#   OptimizationRecord(id='18188635', status='COMPLETE'),
#   OptimizationRecord(id='18188636', status='COMPLETE'),
#   OptimizationRecord(id='18188637', status='COMPLETE'),
# ...
#   OptimizationRecord(id='18313220', status='COMPLETE'),
#   OptimizationRecord(id='18313221', status='COMPLETE'),
#   OptimizationRecord(id='18313222', status='COMPLETE'),
#   OptimizationRecord(id='18313223', status='COMPLETE'),
#   OptimizationRecord(id='18313224', status='COMPLETE'),
#   OptimizationRecord(id='18313225', status='COMPLETE'),
#   OptimizationRecord(id='18313226', status='COMPLETE'),
#   OptimizationRecord(id='18313227', status='COMPLETE'),
#   OptimizationRecord(id='18313228', status='COMPLETE'),
#   OptimizationRecord(id='18313229', status='COMPLETE'),
#   OptimizationRecord(id='18313230', status='COMPLETE'),
#   OptimizationRecord(id='18313231', status='COMPLETE'),
#   OptimizationRecord(id='18313232', status='COMPLETE'),
#   OptimizationRecord(id='18313233', status='COMPLETE'),
#   OptimizationRecord(id='18313234', status='COMPLETE'),
#   OptimizationRecord(id='18313235', status='COMPLETE'),
#   OptimizationRecord(id='18313236', status='COMPLETE'),
#   OptimizationRecord(id='18313237', status='COMPLETE'),
#   OptimizationRecord(id='18313238', status='COMPLETE'),
#   OptimizationRecord(id='18313239', status='COMPLETE'),
#   OptimizationRecord(id='18313240', status='COMPLETE'),
#   OptimizationRecord(id='18313241', status='COMPLETE'),
#   OptimizationRecord(id='18313242', status='COMPLETE'),
#   OptimizationRecord(id='18313243', status='COMPLETE'),
#   OptimizationRecord(id='18313244', status='COMPLETE'),
#   OptimizationRecord(id='18386530', status='COMPLETE'),
#   OptimizationRecord(id='18386531', status='COMPLETE'),
#   OptimizationRecord(id='18386542', status='COMPLETE'),
#   OptimizationRecord(id='18386543', status='COMPLETE'),
#   OptimizationRecord(id='18386544', status='COMPLETE'),
#   OptimizationRecord(id='18386545', status='COMPLETE'),
#   OptimizationRecord(id='18386546', status='COMPLETE'),
#   OptimizationRecord(id='18386547', status='COMPLETE'),
#   OptimizationRecord(id='18392330', status='COMPLETE'),
#   OptimizationRecord(id='18392331', status='COMPLETE'),
#   OptimizationRecord(id='18392332', status='COMPLETE'),
#   OptimizationRecord(id='18392333', status='COMPLETE'),
#   OptimizationRecord(id='18392334', status='COMPLETE'),
#   OptimizationRecord(id='18392335', status='COMPLETE'),
#   OptimizationRecord(id='18392336', status='COMPLETE'),
#   OptimizationRecord(id='18392337', status='COMPLETE'),
#   OptimizationRecord(id='18392338', status='COMPLETE'),
#   OptimizationRecord(id='18392339', status='COMPLETE'),
#   OptimizationRecord(id='18392340', status='COMPLETE'),
#   OptimizationRecord(id='18392341', status='COMPLETE'),
#   OptimizationRecord(id='18409908', status='COMPLETE'),
#   OptimizationRecord(id='18409909', status='COMPLETE'),
#   OptimizationRecord(id='18409910', status='COMPLETE'),
#   OptimizationRecord(id='18409911', status='COMPLETE'),
#   OptimizationRecord(id='18409912', status='COMPLETE'),
#   OptimizationRecord(id='18409913', status='COMPLETE'),
#   OptimizationRecord(id='18409914', status='COMPLETE'),
#   OptimizationRecord(id='18409915', status='COMPLETE'),
#   OptimizationRecord(id='18409916', status='COMPLETE'),
#   OptimizationRecord(id='18409917', status='COMPLETE'),
#   OptimizationRecord(id='18409918', status='COMPLETE'),
#   OptimizationRecord(id='18409919', status='COMPLETE'),
#   OptimizationRecord(id='18409920', status='COMPLETE'),
#   OptimizationRecord(id='18409921', status='COMPLETE'),
#   OptimizationRecord(id='18426300', status='COMPLETE'),
#   OptimizationRecord(id='18426301', status='COMPLETE'),
#   OptimizationRecord(id='18426302', status='COMPLETE'),
#   OptimizationRecord(id='18426303', status='COMPLETE'),
#   OptimizationRecord(id='18426304', status='COMPLETE'),
#   OptimizationRecord(id='18426305', status='COMPLETE'),
#   OptimizationRecord(id='18426306', status='COMPLETE'),
#   OptimizationRecord(id='18426307', status='COMPLETE'),
#   OptimizationRecord(id='18426308', status='COMPLETE'),
#   OptimizationRecord(id='18426309', status='COMPLETE'),
#   OptimizationRecord(id='18426310', status='COMPLETE'),
#   OptimizationRecord(id='18426311', status='COMPLETE'),
#   OptimizationRecord(id='18432401', status='ERROR'),
#   OptimizationRecord(id='18432402', status='COMPLETE'),
#   OptimizationRecord(id='18432403', status='COMPLETE'),
#   OptimizationRecord(id='18432404', status='COMPLETE'),
#   OptimizationRecord(id='18432405', status='COMPLETE'),
#   OptimizationRecord(id='18432406', status='COMPLETE'),
#   OptimizationRecord(id='18432407', status='COMPLETE'),
#   OptimizationRecord(id='18432408', status='COMPLETE'),
#   OptimizationRecord(id='18432409', status='COMPLETE'),
#   OptimizationRecord(id='18432410', status='COMPLETE'),
#   OptimizationRecord(id='18432411', status='COMPLETE'),
#   OptimizationRecord(id='18432412', status='COMPLETE')],
#  '18045964': [OptimizationRecord(id='18316240', status='COMPLETE'),
#   OptimizationRecord(id='18316241', status='COMPLETE'),
#   OptimizationRecord(id='18316242', status='ERROR'),
#   OptimizationRecord(id='18316243', status='COMPLETE'),
#   OptimizationRecord(id='18316244', status='ERROR'),
#   OptimizationRecord(id='18316245', status='COMPLETE'),
#   OptimizationRecord(id='18316246', status='COMPLETE'),
#   OptimizationRecord(id='18316247', status='COMPLETE'),
#   OptimizationRecord(id='18316248', status='COMPLETE'),
#   OptimizationRecord(id='18316249', status='ERROR'),
#   OptimizationRecord(id='18316250', status='COMPLETE'),
#   OptimizationRecord(id='18316251', status='COMPLETE'),
#   OptimizationRecord(id='18316252', status='ERROR'),
#   OptimizationRecord(id='18316253', status='COMPLETE'),
#   OptimizationRecord(id='18316254', status='ERROR'),
#   OptimizationRecord(id='18316255', status='ERROR'),
#   OptimizationRecord(id='18316256', status='COMPLETE'),
#   OptimizationRecord(id='18316257', status='COMPLETE'),
#   OptimizationRecord(id='18316258', status='ERROR'),
#   OptimizationRecord(id='18316259', status='COMPLETE'),
#   OptimizationRecord(id='18316260', status='COMPLETE'),
#   OptimizationRecord(id='18316261', status='COMPLETE'),
#   OptimizationRecord(id='18316262', status='ERROR'),
#   OptimizationRecord(id='18316263', status='COMPLETE'),
#   OptimizationRecord(id='18316264', status='COMPLETE'),
#   OptimizationRecord(id='18316265', status='COMPLETE'),
#   OptimizationRecord(id='18316266', status='COMPLETE'),
#   OptimizationRecord(id='18316267', status='ERROR'),
#   OptimizationRecord(id='18316268', status='COMPLETE'),
#   OptimizationRecord(id='18316269', status='ERROR'),
#   OptimizationRecord(id='18316270', status='ERROR'),
#   OptimizationRecord(id='18316271', status='ERROR'),
#   OptimizationRecord(id='18316272', status='COMPLETE'),
#   OptimizationRecord(id='18316273', status='ERROR'),
#   OptimizationRecord(id='18316274', status='ERROR'),
#   OptimizationRecord(id='18316275', status='COMPLETE'),
#   OptimizationRecord(id='18316276', status='COMPLETE'),
#   OptimizationRecord(id='18316277', status='COMPLETE'),
#   OptimizationRecord(id='18316278', status='ERROR'),
#   OptimizationRecord(id='18316279', status='ERROR'),
#   OptimizationRecord(id='18316280', status='COMPLETE'),
#   OptimizationRecord(id='18316281', status='COMPLETE'),
#   OptimizationRecord(id='18316282', status='ERROR'),
#   OptimizationRecord(id='18316283', status='COMPLETE'),
#   OptimizationRecord(id='18316284', status='ERROR'),
#   OptimizationRecord(id='18316285', status='ERROR'),
#   OptimizationRecord(id='18316286', status='COMPLETE'),
#   OptimizationRecord(id='18316287', status='COMPLETE'),
#   OptimizationRecord(id='18316288', status='COMPLETE'),
#   OptimizationRecord(id='18316289', status='COMPLETE'),
#   OptimizationRecord(id='18316290', status='ERROR'),
#   OptimizationRecord(id='18316291', status='COMPLETE'),
#   OptimizationRecord(id='18316292', status='COMPLETE'),
#   OptimizationRecord(id='18316293', status='COMPLETE'),
#   OptimizationRecord(id='18316294', status='ERROR'),
#   OptimizationRecord(id='18316295', status='COMPLETE'),
#   OptimizationRecord(id='18316296', status='COMPLETE'),
#   OptimizationRecord(id='18316297', status='COMPLETE'),
#   OptimizationRecord(id='18316298', status='COMPLETE'),
#   OptimizationRecord(id='18316299', status='COMPLETE'),
#   OptimizationRecord(id='18316300', status='COMPLETE'),
#   OptimizationRecord(id='18316301', status='ERROR'),
#   OptimizationRecord(id='18316302', status='COMPLETE'),
#   OptimizationRecord(id='18316303', status='COMPLETE'),
#   OptimizationRecord(id='18316304', status='COMPLETE'),
#   OptimizationRecord(id='18316305', status='ERROR'),
#   OptimizationRecord(id='18316306', status='ERROR'),
#   OptimizationRecord(id='18316307', status='COMPLETE'),
#   OptimizationRecord(id='18316308', status='ERROR'),
#   OptimizationRecord(id='18316309', status='COMPLETE'),
#   OptimizationRecord(id='18316310', status='COMPLETE'),
#   OptimizationRecord(id='18316311', status='COMPLETE'),
#   OptimizationRecord(id='18316312', status='COMPLETE'),
#   OptimizationRecord(id='18316313', status='COMPLETE'),
#   OptimizationRecord(id='18316314', status='COMPLETE'),
#   OptimizationRecord(id='18316315', status='COMPLETE'),
#   OptimizationRecord(id='18316316', status='COMPLETE'),
#   OptimizationRecord(id='18316317', status='ERROR'),
#   OptimizationRecord(id='18316318', status='COMPLETE'),
#   OptimizationRecord(id='18316319', status='ERROR'),
#   OptimizationRecord(id='18316320', status='COMPLETE'),
#   OptimizationRecord(id='18316321', status='ERROR'),
#   OptimizationRecord(id='18316322', status='COMPLETE'),
#   OptimizationRecord(id='18316323', status='COMPLETE'),
#   OptimizationRecord(id='18316324', status='COMPLETE'),
#   OptimizationRecord(id='18316325', status='COMPLETE'),
#   OptimizationRecord(id='18316326', status='COMPLETE'),
#   OptimizationRecord(id='18316327', status='COMPLETE'),
#   OptimizationRecord(id='18316328', status='COMPLETE'),
#   OptimizationRecord(id='18316329', status='COMPLETE'),
#   OptimizationRecord(id='18316330', status='COMPLETE'),
#   OptimizationRecord(id='18316331', status='COMPLETE'),
#   OptimizationRecord(id='18316332', status='ERROR'),
#   OptimizationRecord(id='18316333', status='COMPLETE'),
#   OptimizationRecord(id='18316334', status='ERROR'),
#   OptimizationRecord(id='18316335', status='COMPLETE'),
#   OptimizationRecord(id='18316336', status='COMPLETE'),
#   OptimizationRecord(id='18316337', status='COMPLETE'),
#   OptimizationRecord(id='18316338', status='COMPLETE'),
#   OptimizationRecord(id='18316353', status='ERROR'),
#   OptimizationRecord(id='18316373', status='COMPLETE'),
#   OptimizationRecord(id='18316374', status='ERROR'),
#   OptimizationRecord(id='18316375', status='ERROR'),
#   OptimizationRecord(id='18316376', status='COMPLETE'),
#   OptimizationRecord(id='18316377', status='ERROR'),
#   OptimizationRecord(id='18316378', status='COMPLETE'),
#   OptimizationRecord(id='18316379', status='COMPLETE'),
#   OptimizationRecord(id='18316380', status='COMPLETE'),
#   OptimizationRecord(id='18316381', status='COMPLETE'),
#   OptimizationRecord(id='18316382', status='COMPLETE'),
#   OptimizationRecord(id='18316383', status='COMPLETE'),
#   OptimizationRecord(id='18316384', status='ERROR'),
#   OptimizationRecord(id='18316385', status='COMPLETE'),
#   OptimizationRecord(id='18316386', status='COMPLETE'),
#   OptimizationRecord(id='18316387', status='COMPLETE'),
#   OptimizationRecord(id='18316388', status='COMPLETE'),
#   OptimizationRecord(id='18316389', status='COMPLETE'),
#   OptimizationRecord(id='18316390', status='ERROR'),
#   OptimizationRecord(id='18316391', status='COMPLETE'),
#   OptimizationRecord(id='18316392', status='COMPLETE'),
#   OptimizationRecord(id='18316393', status='COMPLETE'),
#   OptimizationRecord(id='18316394', status='ERROR'),
#   OptimizationRecord(id='18316395', status='ERROR'),
#   OptimizationRecord(id='18316396', status='COMPLETE')],
#  '18045965': [OptimizationRecord(id='18319165', status='COMPLETE'),
#   OptimizationRecord(id='18319166', status='COMPLETE'),
#   OptimizationRecord(id='18319167', status='COMPLETE'),
#   OptimizationRecord(id='18319168', status='COMPLETE'),
#   OptimizationRecord(id='18319169', status='COMPLETE'),
#   OptimizationRecord(id='18319170', status='COMPLETE'),
#   OptimizationRecord(id='18319171', status='COMPLETE'),
#   OptimizationRecord(id='18319172', status='COMPLETE'),
#   OptimizationRecord(id='18319173', status='COMPLETE'),
#   OptimizationRecord(id='18319174', status='COMPLETE'),
#   OptimizationRecord(id='18319175', status='COMPLETE'),
#   OptimizationRecord(id='18319176', status='COMPLETE'),
#   OptimizationRecord(id='18319177', status='COMPLETE'),
#   OptimizationRecord(id='18319178', status='COMPLETE'),
#   OptimizationRecord(id='18319179', status='COMPLETE'),
#   OptimizationRecord(id='18319180', status='COMPLETE'),
#   OptimizationRecord(id='18319181', status='COMPLETE'),
#   OptimizationRecord(id='18319182', status='COMPLETE')],
#  '18045966': [OptimizationRecord(id='18319486', status='ERROR'),
#   OptimizationRecord(id='18319487', status='ERROR'),
#   OptimizationRecord(id='18319488', status='COMPLETE'),
#   OptimizationRecord(id='18319489', status='COMPLETE'),
#   OptimizationRecord(id='18319490', status='ERROR'),
#   OptimizationRecord(id='18319491', status='ERROR'),
#   OptimizationRecord(id='18319492', status='ERROR'),
#   OptimizationRecord(id='18319493', status='COMPLETE'),
#   OptimizationRecord(id='18319494', status='COMPLETE')],
#  '18045967': [OptimizationRecord(id='18319495', status='COMPLETE'),
#   OptimizationRecord(id='18319496', status='ERROR'),
#   OptimizationRecord(id='18319497', status='COMPLETE'),
#   OptimizationRecord(id='18319498', status='COMPLETE'),
#   OptimizationRecord(id='18319499', status='COMPLETE'),
#   OptimizationRecord(id='18319500', status='COMPLETE'),
#   OptimizationRecord(id='18319501', status='ERROR'),
#   OptimizationRecord(id='18319502', status='ERROR'),
#   OptimizationRecord(id='18319503', status='COMPLETE'),
#   OptimizationRecord(id='18319504', status='ERROR'),
#   OptimizationRecord(id='18319505', status='COMPLETE'),
#   OptimizationRecord(id='18319506', status='COMPLETE'),
#   OptimizationRecord(id='18319507', status='ERROR'),
#   OptimizationRecord(id='18319508', status='ERROR'),
#   OptimizationRecord(id='18319509', status='ERROR'),
#   OptimizationRecord(id='18319510', status='ERROR'),
#   OptimizationRecord(id='18319511', status='ERROR'),
#   OptimizationRecord(id='18319512', status='ERROR'),
#   OptimizationRecord(id='18319513', status='ERROR'),
#   OptimizationRecord(id='18319514', status='COMPLETE'),
#   OptimizationRecord(id='18319515', status='COMPLETE'),
#   OptimizationRecord(id='18319516', status='COMPLETE'),
#   OptimizationRecord(id='18319517', status='COMPLETE'),
#   OptimizationRecord(id='18319518', status='COMPLETE'),
#   OptimizationRecord(id='18319519', status='ERROR'),
#   OptimizationRecord(id='18319520', status='COMPLETE'),
#   OptimizationRecord(id='18319521', status='COMPLETE'),
#   OptimizationRecord(id='18319522', status='COMPLETE'),
#   OptimizationRecord(id='18319523', status='ERROR'),
#   OptimizationRecord(id='18319524', status='ERROR'),
#   OptimizationRecord(id='18319525', status='COMPLETE'),
#   OptimizationRecord(id='18319526', status='COMPLETE'),
#   OptimizationRecord(id='18319527', status='ERROR'),
#   OptimizationRecord(id='18319528', status='COMPLETE'),
#   OptimizationRecord(id='18319529', status='ERROR')],
#  '18045969': [OptimizationRecord(id='18319745', status='COMPLETE'),
#   OptimizationRecord(id='18319746', status='ERROR'),
#   OptimizationRecord(id='18319747', status='ERROR'),
#   OptimizationRecord(id='18319748', status='ERROR'),
#   OptimizationRecord(id='18319749', status='ERROR'),
#   OptimizationRecord(id='18319750', status='ERROR'),
#   OptimizationRecord(id='18319751', status='ERROR'),
#   OptimizationRecord(id='18319752', status='ERROR'),
#   OptimizationRecord(id='18319753', status='ERROR'),
#   OptimizationRecord(id='18319754', status='ERROR'),
#   OptimizationRecord(id='18319755', status='ERROR'),
#   OptimizationRecord(id='18319756', status='ERROR'),
#   OptimizationRecord(id='18319757', status='ERROR'),
#   OptimizationRecord(id='18319758', status='ERROR'),
#   OptimizationRecord(id='18319759', status='ERROR'),
#   OptimizationRecord(id='18319760', status='COMPLETE'),
#   OptimizationRecord(id='18319761', status='ERROR'),
#   OptimizationRecord(id='18319762', status='ERROR'),
#   OptimizationRecord(id='18319763', status='ERROR')]}

# %%
resm = merge(res)

# %% [raw]
# resm = get_unfinished_torsiondrive_optimizations(ds, 'default', client, merged=True)

# %%
incomplete = (opt.dict() for opt in resm if opt.status == 'INCOMPLETE')

# %%
next(incomplete)
# Out:
# {'id': '18176703',
#  'hash_index': '987dfba90bed40ca09961ab0337cbf3a07a92124',
#  'procedure': 'optimization',
#  'program': 'geometric',
#  'version': 1,
#  'protocols': {},
#  'extras': {},
#  'stdout': '21136170',
#  'stderr': None,
#  'error': None,
#  'task_id': None,
#  'manager_name': None,
#  'status': <RecordStatusEnum.incomplete: 'INCOMPLETE'>,
#  'modified_on': datetime.datetime(2020, 3, 17, 1, 10, 47, 676123),
#  'created_on': datetime.datetime(2020, 3, 17, 1, 10, 47, 676124),
#  'provenance': {'creator': 'geomeTRIC',
#   'version': '0.9.7.2',
#   'routine': 'geometric.run_json.geometric_run_json',
#   'username': 'chodera',
#   'qcengine_version': '0.14.0',
#   'wall_time': 2287.1003198623657,
#   'hostname': 'lt03',
#   'cpu': 'Intel(R) Xeon(R) CPU E5-2697 v4 @ 2.30GHz'},
#  'schema_version': 1,
#  'initial_molecule': '11758666',
#  'qc_spec': {'driver': <DriverEnum.gradient: 'gradient'>,
#   'method': 'b3lyp-d3bj',
#   'basis': 'dzvp',
#   'keywords': '2',
#   'program': 'psi4'},
#  'keywords': {'coordsys': 'tric',
#   'enforce': 0.1,
#   'reset': True,
#   'qccnv': True,
#   'epsilon': 0,
#   'constraints': {'set': [{'type': 'dihedral',
#      'indices': [19, 12, 11, 37],
#      'value': 60}]},
#   'program': 'psi4'},
#  'energies': [-1741.9437728769947,
#   -1741.9538551601008,
#   -1741.96406379732,
#   -1741.9667215564718,
#   -1741.9692865601605,
#   -1741.9708504628313,
#   -1741.9727697364654,
#   -1741.9737740773749,
#   -1741.9747048988281,
#   -1741.9759129889865,
#   -1741.9771772442546,
#   -1741.9783918544115,
#   -1741.979219939155,
#   -1741.9796154931464,
#   -1741.9799445000044,
#   -1741.980099420213,
#   -1741.9801816572913,
#   -1741.9802332024801,
#   -1741.9802786777439,
#   -1741.9802849120151,
#   -1741.980301459635,
#   -1741.9803103538247,
#   -1741.980313399242,
#   -1741.9803157083784,
#   -1741.9803170252217,
#   -1741.9803184240031,
#   -1741.9803190365767],
#  'final_molecule': '11896671',
#  'trajectory': ['18189202',
#   '18189229',
#   '18189230',
#   '18189231',
#   '18189232',
#   '18189233',
#   '18189234',
#   '18189235',
#   '18189236',
#   '18189237',
#   '18189238',
#   '18189239',
#   '18189240',
#   '18189241',
#   '18189242',
#   '18189243',
#   '18189244',
#   '18189245',
#   '18189246',
#   '18189247',
#   '18189248',
#   '18189249',
#   '18189250',
#   '18189251',
#   '18189252',
#   '18189253',
#   '18189254']}

# %% [markdown]
# All Lilac INCOMPLETEs?

# %%
count_unique_optimization_error_messages(resm, pretty_print=True)
# Out:
# There are 2471 instances of
# -------------------------------------
# geometric.errors.QCEngineAPIEngineError: QCEngineAPI computation did not execute correctly. Message: QCEngine Unknown Error:
# -------------------------------------
#
# There are 5 instances of
# -------------------------------------
# concurrent.futures.process.BrokenProcessPool: A process in the process pool was terminated abruptly while the future was running or pending.
# -------------------------------------
#
# There are 2 instances of
# -------------------------------------
# parsl.executors.high_throughput.interchange.ManagerLost: Task failure due to loss of Manager b'7e247217149c' on host dt041
# -------------------------------------
#
# There are 3 instances of
# -------------------------------------
# parsl.executors.high_throughput.interchange.ManagerLost: Task failure due to loss of Manager b'e1287308837e' on host dt045
# -------------------------------------
#
# There are 3 instances of
# -------------------------------------
# parsl.executors.high_throughput.interchange.ManagerLost: Task failure due to loss of Manager b'5ad67cb849a8' on host dt041
# -------------------------------------
#
# There are 3 instances of
# -------------------------------------
# parsl.executors.high_throughput.interchange.ManagerLost: Task failure due to loss of Manager b'620f39a74916' on host dt035
# -------------------------------------
#
# There are 4 instances of
# -------------------------------------
# parsl.executors.high_throughput.interchange.ManagerLost: Task failure due to loss of Manager b'00993eb3730e' on host dt039
# -------------------------------------
#
# There are 4 instances of
# -------------------------------------
# parsl.executors.high_throughput.interchange.ManagerLost: Task failure due to loss of Manager b'30a985322696' on host dt039
# -------------------------------------
#
# There are 3 instances of
# -------------------------------------
# parsl.executors.high_throughput.interchange.ManagerLost: Task failure due to loss of Manager b'6ee01e7102b6' on host dt032
# -------------------------------------
#
# There are 3 instances of
# -------------------------------------
# parsl.executors.high_throughput.interchange.ManagerLost: Task failure due to loss of Manager b'9e1929204d32' on host dt035
# -------------------------------------
#
# There are 2 instances of
# -------------------------------------
# parsl.executors.high_throughput.interchange.ManagerLost: Task failure due to loss of Manager b'1608db010dff' on host dt029
# -------------------------------------
#
# There are 3 instances of
# -------------------------------------
# parsl.executors.high_throughput.interchange.ManagerLost: Task failure due to loss of Manager b'a56c0a68466e' on host dt048
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# parsl.executors.high_throughput.interchange.ManagerLost: Task failure due to loss of Manager b'91725446de82' on host dt047
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# parsl.executors.high_throughput.interchange.ManagerLost: Task failure due to loss of Manager b'd730662c6f91' on host dt039
# -------------------------------------
#
# There are 2 instances of
# -------------------------------------
# parsl.executors.high_throughput.interchange.ManagerLost: Task failure due to loss of Manager b'f4d70a665190' on host dt031
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# parsl.executors.high_throughput.interchange.ManagerLost: Task failure due to loss of Manager b'8782ca6c51ec' on host dt041
# -------------------------------------
#
# There are 4 instances of
# -------------------------------------
# parsl.executors.high_throughput.interchange.ManagerLost: Task failure due to loss of Manager b'42d8f34bf09a' on host dt032
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# parsl.executors.high_throughput.interchange.ManagerLost: Task failure due to loss of Manager b'b1d1911a86dd' on host dt029
# -------------------------------------
#
# There are 4 instances of
# -------------------------------------
# parsl.executors.high_throughput.interchange.ManagerLost: Task failure due to loss of Manager b'503f8b15540c' on host dt011
# -------------------------------------
#
# There are 1 instances of
# -------------------------------------
# parsl.executors.high_throughput.interchange.ManagerLost: Task failure due to loss of Manager b'7b8d56d4a244' on host dt035
# -------------------------------------
#
# There are 2 instances of
# -------------------------------------
# parsl.executors.high_throughput.interchange.ManagerLost: Task failure due to loss of Manager b'9576065d34aa' on host dt039
# -------------------------------------
#
# There are 3 instances of
# -------------------------------------
# RuntimeError: Not bracketed
# -------------------------------------
#
# There are 14 instances of
# -------------------------------------
# ValueError: Cannot continue a constrained optimization; please implement constrained optimization in Cartesian coordinates
# -------------------------------------
#
# There are 16 instances of
# -------------------------------------
#
# -------------------------------------
#
# There are 2 instances of
# -------------------------------------
# geometric.errors.GeomOptNotConvergedError: Optimizer.optimizeGeometry() failed to converge.
# -------------------------------------

# %%
restart_optimizations(resm, client)
# Out:
# OptimizationRecord(id='18216615', status='ERROR')
# OptimizationRecord(id='18216652', status='ERROR')
# OptimizationRecord(id='18216653', status='ERROR')
# OptimizationRecord(id='18234259', status='ERROR')
# OptimizationRecord(id='18234260', status='ERROR')
# OptimizationRecord(id='18234261', status='ERROR')
# OptimizationRecord(id='18234262', status='ERROR')
# OptimizationRecord(id='18234264', status='ERROR')
# OptimizationRecord(id='18234267', status='ERROR')
# OptimizationRecord(id='18234270', status='ERROR')
# OptimizationRecord(id='18234274', status='ERROR')
# OptimizationRecord(id='18234276', status='ERROR')
# OptimizationRecord(id='18234281', status='ERROR')
# OptimizationRecord(id='18234282', status='ERROR')
# OptimizationRecord(id='18234283', status='ERROR')
# OptimizationRecord(id='18234284', status='ERROR')
# OptimizationRecord(id='18234285', status='ERROR')
# OptimizationRecord(id='18234286', status='ERROR')
# OptimizationRecord(id='18234287', status='ERROR')
# OptimizationRecord(id='18234288', status='ERROR')
# OptimizationRecord(id='18234290', status='ERROR')
# OptimizationRecord(id='18234291', status='ERROR')
# OptimizationRecord(id='18234292', status='ERROR')
# OptimizationRecord(id='18234293', status='ERROR')
# OptimizationRecord(id='18234294', status='ERROR')
# OptimizationRecord(id='18234295', status='ERROR')
# OptimizationRecord(id='18234300', status='ERROR')
# OptimizationRecord(id='18234301', status='ERROR')
# OptimizationRecord(id='18234302', status='ERROR')
# OptimizationRecord(id='18234303', status='ERROR')
# OptimizationRecord(id='18234305', status='ERROR')
# OptimizationRecord(id='18234306', status='ERROR')
# OptimizationRecord(id='18234307', status='ERROR')
# OptimizationRecord(id='18234308', status='ERROR')
# OptimizationRecord(id='18234309', status='ERROR')
# OptimizationRecord(id='18234310', status='ERROR')
# OptimizationRecord(id='18234311', status='ERROR')
# OptimizationRecord(id='18234312', status='ERROR')
# OptimizationRecord(id='18234314', status='ERROR')
# OptimizationRecord(id='18234315', status='ERROR')
# OptimizationRecord(id='18234316', status='ERROR')
# OptimizationRecord(id='18234329', status='ERROR')
# OptimizationRecord(id='18234330', status='ERROR')
# OptimizationRecord(id='18234333', status='ERROR')
# OptimizationRecord(id='18234334', status='ERROR')
# OptimizationRecord(id='18234338', status='ERROR')
# OptimizationRecord(id='18234339', status='ERROR')
# OptimizationRecord(id='18234340', status='ERROR')
# OptimizationRecord(id='18234341', status='ERROR')
# OptimizationRecord(id='18234342', status='ERROR')
# OptimizationRecord(id='18234344', status='ERROR')
# OptimizationRecord(id='18234345', status='ERROR')
# OptimizationRecord(id='18234346', status='ERROR')
# OptimizationRecord(id='18234349', status='ERROR')
# OptimizationRecord(id='18234350', status='ERROR')
# OptimizationRecord(id='18234352', status='ERROR')
# OptimizationRecord(id='18234356', status='ERROR')
# OptimizationRecord(id='18234357', status='ERROR')
# OptimizationRecord(id='18234358', status='ERROR')
# OptimizationRecord(id='18234359', status='ERROR')
# OptimizationRecord(id='18234360', status='ERROR')
# OptimizationRecord(id='18234366', status='ERROR')
# OptimizationRecord(id='18234368', status='ERROR')
# OptimizationRecord(id='18234369', status='ERROR')
# OptimizationRecord(id='18234372', status='ERROR')
# OptimizationRecord(id='18234373', status='ERROR')
# OptimizationRecord(id='18234375', status='ERROR')
# OptimizationRecord(id='18234377', status='ERROR')
# OptimizationRecord(id='18234381', status='ERROR')
# OptimizationRecord(id='18234382', status='ERROR')
# OptimizationRecord(id='18234383', status='ERROR')
# OptimizationRecord(id='18234384', status='ERROR')
# OptimizationRecord(id='18234385', status='ERROR')
# OptimizationRecord(id='18234387', status='ERROR')
# OptimizationRecord(id='18234388', status='ERROR')
# OptimizationRecord(id='18234390', status='ERROR')
# OptimizationRecord(id='18234391', status='ERROR')
# OptimizationRecord(id='18234394', status='ERROR')
# OptimizationRecord(id='18234395', status='ERROR')
# OptimizationRecord(id='18234396', status='ERROR')
# OptimizationRecord(id='18234397', status='ERROR')
# OptimizationRecord(id='18234398', status='ERROR')
# OptimizationRecord(id='18234399', status='ERROR')
# OptimizationRecord(id='18234400', status='ERROR')
# OptimizationRecord(id='18234401', status='ERROR')
# OptimizationRecord(id='18234402', status='ERROR')
# OptimizationRecord(id='18234404', status='ERROR')
# OptimizationRecord(id='18234405', status='ERROR')
# OptimizationRecord(id='18243375', status='ERROR')
# OptimizationRecord(id='18243406', status='ERROR')
# OptimizationRecord(id='18243409', status='ERROR')
# OptimizationRecord(id='18243427', status='ERROR')
# OptimizationRecord(id='18243433', status='ERROR')
# OptimizationRecord(id='18243437', status='ERROR')
# OptimizationRecord(id='18243438', status='ERROR')
# OptimizationRecord(id='18243439', status='ERROR')
# OptimizationRecord(id='18243441', status='ERROR')
# OptimizationRecord(id='18243468', status='ERROR')
# OptimizationRecord(id='18243481', status='ERROR')
# OptimizationRecord(id='18243495', status='ERROR')
# OptimizationRecord(id='18243498', status='ERROR')
# OptimizationRecord(id='18243499', status='ERROR')
# OptimizationRecord(id='18243514', status='ERROR')
# OptimizationRecord(id='18243520', status='ERROR')
# OptimizationRecord(id='18243564', status='ERROR')
# OptimizationRecord(id='18243568', status='ERROR')
# OptimizationRecord(id='18243569', status='ERROR')
# OptimizationRecord(id='18243584', status='ERROR')
# OptimizationRecord(id='18243608', status='ERROR')
# OptimizationRecord(id='18243610', status='ERROR')
# OptimizationRecord(id='18243618', status='ERROR')
# OptimizationRecord(id='18243629', status='ERROR')
# OptimizationRecord(id='18243632', status='ERROR')
# OptimizationRecord(id='18243635', status='ERROR')
# OptimizationRecord(id='18243666', status='ERROR')
# OptimizationRecord(id='18243674', status='ERROR')
# OptimizationRecord(id='18243731', status='ERROR')
# OptimizationRecord(id='18243737', status='ERROR')
# OptimizationRecord(id='18243756', status='ERROR')
# OptimizationRecord(id='18243768', status='ERROR')
# OptimizationRecord(id='18243811', status='ERROR')
# OptimizationRecord(id='18243813', status='ERROR')
# OptimizationRecord(id='18246164', status='ERROR')
# OptimizationRecord(id='18246166', status='ERROR')
# OptimizationRecord(id='18246170', status='ERROR')
# OptimizationRecord(id='18246175', status='ERROR')
# OptimizationRecord(id='18246180', status='ERROR')
# OptimizationRecord(id='18246181', status='ERROR')
# OptimizationRecord(id='18246182', status='ERROR')
# OptimizationRecord(id='18246183', status='ERROR')
# OptimizationRecord(id='18246186', status='ERROR')
# OptimizationRecord(id='18246187', status='ERROR')
# OptimizationRecord(id='18246189', status='ERROR')
# OptimizationRecord(id='18246190', status='ERROR')
# OptimizationRecord(id='18246192', status='ERROR')
# OptimizationRecord(id='18246194', status='ERROR')
# OptimizationRecord(id='18246196', status='ERROR')
# OptimizationRecord(id='18246198', status='ERROR')
# OptimizationRecord(id='18246199', status='ERROR')
# OptimizationRecord(id='18246200', status='ERROR')
# OptimizationRecord(id='18246202', status='ERROR')
# OptimizationRecord(id='18246205', status='ERROR')
# OptimizationRecord(id='18246206', status='ERROR')
# OptimizationRecord(id='18246207', status='ERROR')
# OptimizationRecord(id='18246208', status='ERROR')
# OptimizationRecord(id='18246210', status='ERROR')
# OptimizationRecord(id='18246211', status='ERROR')
# OptimizationRecord(id='18246214', status='ERROR')
# OptimizationRecord(id='18246215', status='ERROR')
# OptimizationRecord(id='18246217', status='ERROR')
# OptimizationRecord(id='18246219', status='ERROR')
# OptimizationRecord(id='18246220', status='ERROR')
# OptimizationRecord(id='18246221', status='ERROR')
# OptimizationRecord(id='18246222', status='ERROR')
# OptimizationRecord(id='18246223', status='ERROR')
# OptimizationRecord(id='18246225', status='ERROR')
# OptimizationRecord(id='18246227', status='ERROR')
# OptimizationRecord(id='18246228', status='ERROR')
# OptimizationRecord(id='18246229', status='ERROR')
# OptimizationRecord(id='18246230', status='ERROR')
# OptimizationRecord(id='18246231', status='ERROR')
# OptimizationRecord(id='18246232', status='ERROR')
# OptimizationRecord(id='18246233', status='ERROR')
# OptimizationRecord(id='18246234', status='ERROR')
# OptimizationRecord(id='18246235', status='ERROR')
# OptimizationRecord(id='18246236', status='ERROR')
# OptimizationRecord(id='18246237', status='ERROR')
# OptimizationRecord(id='18246240', status='ERROR')
# OptimizationRecord(id='18246243', status='ERROR')
# OptimizationRecord(id='18246246', status='ERROR')
# OptimizationRecord(id='18246247', status='ERROR')
# OptimizationRecord(id='18246253', status='ERROR')
# OptimizationRecord(id='18246254', status='ERROR')
# OptimizationRecord(id='18246255', status='ERROR')
# OptimizationRecord(id='18246260', status='ERROR')
# OptimizationRecord(id='18246261', status='ERROR')
# OptimizationRecord(id='18246262', status='ERROR')
# OptimizationRecord(id='18246263', status='ERROR')
# OptimizationRecord(id='18246272', status='ERROR')
# OptimizationRecord(id='18246273', status='ERROR')
# OptimizationRecord(id='18246274', status='ERROR')
# OptimizationRecord(id='18246275', status='ERROR')
# OptimizationRecord(id='18246276', status='ERROR')
# OptimizationRecord(id='18246277', status='ERROR')
# OptimizationRecord(id='18246278', status='ERROR')
# OptimizationRecord(id='18246279', status='ERROR')
# OptimizationRecord(id='18246281', status='ERROR')
# OptimizationRecord(id='18246282', status='ERROR')
# OptimizationRecord(id='18246283', status='ERROR')
# OptimizationRecord(id='18246285', status='ERROR')
# OptimizationRecord(id='18246286', status='ERROR')
# OptimizationRecord(id='18246287', status='ERROR')
# OptimizationRecord(id='18246288', status='ERROR')
# OptimizationRecord(id='18246289', status='ERROR')
# OptimizationRecord(id='18246292', status='ERROR')
# OptimizationRecord(id='18246293', status='ERROR')
# OptimizationRecord(id='18246294', status='ERROR')
# OptimizationRecord(id='18246296', status='ERROR')
# OptimizationRecord(id='18246298', status='ERROR')
# OptimizationRecord(id='18246299', status='ERROR')
# OptimizationRecord(id='18246303', status='ERROR')
# OptimizationRecord(id='18246304', status='ERROR')
# OptimizationRecord(id='18246305', status='ERROR')
# OptimizationRecord(id='18246306', status='ERROR')
# OptimizationRecord(id='18246307', status='ERROR')
# OptimizationRecord(id='18246308', status='ERROR')
# OptimizationRecord(id='18246314', status='ERROR')
# OptimizationRecord(id='18246316', status='ERROR')
# OptimizationRecord(id='18246318', status='ERROR')
# OptimizationRecord(id='18246321', status='ERROR')
# OptimizationRecord(id='18246325', status='ERROR')
# OptimizationRecord(id='18246328', status='ERROR')
# OptimizationRecord(id='18246400', status='ERROR')
# OptimizationRecord(id='18246415', status='ERROR')
# OptimizationRecord(id='18246534', status='ERROR')
# OptimizationRecord(id='18246538', status='ERROR')
# OptimizationRecord(id='18246548', status='ERROR')
# OptimizationRecord(id='18246654', status='ERROR')
# OptimizationRecord(id='18246669', status='ERROR')
# OptimizationRecord(id='18246682', status='ERROR')
# OptimizationRecord(id='18246683', status='ERROR')
# OptimizationRecord(id='18246685', status='ERROR')
# OptimizationRecord(id='18246687', status='ERROR')
# OptimizationRecord(id='18246691', status='ERROR')
# OptimizationRecord(id='18246696', status='ERROR')
# OptimizationRecord(id='18246722', status='ERROR')
# OptimizationRecord(id='18246726', status='ERROR')
# OptimizationRecord(id='18246735', status='ERROR')
# OptimizationRecord(id='18246758', status='ERROR')
# OptimizationRecord(id='18246766', status='ERROR')
# OptimizationRecord(id='18246768', status='ERROR')
# OptimizationRecord(id='18246770', status='ERROR')
# OptimizationRecord(id='18246775', status='ERROR')
# OptimizationRecord(id='18246776', status='ERROR')
# OptimizationRecord(id='18246788', status='ERROR')
# OptimizationRecord(id='18246789', status='ERROR')
# OptimizationRecord(id='18246800', status='ERROR')
# OptimizationRecord(id='18246802', status='ERROR')
# OptimizationRecord(id='18246807', status='ERROR')
# OptimizationRecord(id='18246808', status='ERROR')
# OptimizationRecord(id='18246810', status='ERROR')
# OptimizationRecord(id='18246842', status='ERROR')
# OptimizationRecord(id='18246845', status='ERROR')
# OptimizationRecord(id='18246846', status='ERROR')
# OptimizationRecord(id='18246852', status='ERROR')
# OptimizationRecord(id='18246853', status='ERROR')
# OptimizationRecord(id='18246855', status='ERROR')
# OptimizationRecord(id='18246858', status='ERROR')
# OptimizationRecord(id='18246861', status='ERROR')
# OptimizationRecord(id='18246863', status='ERROR')
# OptimizationRecord(id='18246865', status='ERROR')
# OptimizationRecord(id='18246870', status='ERROR')
# OptimizationRecord(id='18246874', status='ERROR')
# OptimizationRecord(id='18246876', status='ERROR')
# OptimizationRecord(id='18246878', status='ERROR')
# OptimizationRecord(id='18246886', status='ERROR')
# OptimizationRecord(id='18246887', status='ERROR')
# OptimizationRecord(id='18246888', status='ERROR')
# OptimizationRecord(id='18246889', status='ERROR')
# OptimizationRecord(id='18246897', status='ERROR')
# OptimizationRecord(id='18246898', status='ERROR')
# OptimizationRecord(id='18246899', status='ERROR')
# OptimizationRecord(id='18246901', status='ERROR')
# OptimizationRecord(id='18246902', status='ERROR')
# OptimizationRecord(id='18253285', status='ERROR')
# OptimizationRecord(id='18253294', status='ERROR')
# OptimizationRecord(id='18253297', status='ERROR')
# OptimizationRecord(id='18253300', status='ERROR')
# OptimizationRecord(id='18253303', status='ERROR')
# OptimizationRecord(id='18253307', status='ERROR')
# OptimizationRecord(id='18253316', status='ERROR')
# OptimizationRecord(id='18253317', status='ERROR')
# OptimizationRecord(id='18253341', status='ERROR')
# OptimizationRecord(id='18254526', status='ERROR')
# OptimizationRecord(id='18254589', status='ERROR')
# OptimizationRecord(id='18254596', status='ERROR')
# OptimizationRecord(id='18254604', status='ERROR')
# OptimizationRecord(id='18254611', status='ERROR')
# OptimizationRecord(id='18254612', status='ERROR')
# OptimizationRecord(id='18254613', status='ERROR')
# OptimizationRecord(id='18254615', status='ERROR')
# OptimizationRecord(id='18254616', status='ERROR')
# OptimizationRecord(id='18254617', status='ERROR')
# OptimizationRecord(id='18254618', status='ERROR')
# OptimizationRecord(id='18254620', status='ERROR')
# OptimizationRecord(id='18254622', status='ERROR')
# OptimizationRecord(id='18254623', status='ERROR')
# OptimizationRecord(id='18254624', status='ERROR')
# OptimizationRecord(id='18254625', status='ERROR')
# OptimizationRecord(id='18254628', status='ERROR')
# OptimizationRecord(id='18254630', status='ERROR')
# OptimizationRecord(id='18254632', status='ERROR')
# OptimizationRecord(id='18254633', status='ERROR')
# OptimizationRecord(id='18254635', status='ERROR')
# OptimizationRecord(id='18254637', status='ERROR')
# OptimizationRecord(id='18254638', status='ERROR')
# OptimizationRecord(id='18254639', status='ERROR')
# OptimizationRecord(id='18254641', status='ERROR')
# OptimizationRecord(id='18254642', status='ERROR')
# OptimizationRecord(id='18254643', status='ERROR')
# OptimizationRecord(id='18254645', status='ERROR')
# OptimizationRecord(id='18254646', status='ERROR')
# OptimizationRecord(id='18254647', status='ERROR')
# OptimizationRecord(id='18254648', status='ERROR')
# OptimizationRecord(id='18254649', status='ERROR')
# OptimizationRecord(id='18254650', status='ERROR')
# OptimizationRecord(id='18254651', status='ERROR')
# OptimizationRecord(id='18254666', status='ERROR')
# OptimizationRecord(id='18254667', status='ERROR')
# OptimizationRecord(id='18254668', status='ERROR')
# OptimizationRecord(id='18254669', status='ERROR')
# OptimizationRecord(id='18254670', status='ERROR')
# OptimizationRecord(id='18254671', status='ERROR')
# OptimizationRecord(id='18254675', status='ERROR')
# OptimizationRecord(id='18254676', status='ERROR')
# OptimizationRecord(id='18254677', status='ERROR')
# OptimizationRecord(id='18254678', status='ERROR')
# OptimizationRecord(id='18254702', status='ERROR')
# OptimizationRecord(id='18254704', status='ERROR')
# OptimizationRecord(id='18254706', status='ERROR')
# OptimizationRecord(id='18254708', status='ERROR')
# OptimizationRecord(id='18254709', status='ERROR')
# OptimizationRecord(id='18254710', status='ERROR')
# OptimizationRecord(id='18254711', status='ERROR')
# OptimizationRecord(id='18254713', status='ERROR')
# OptimizationRecord(id='18254714', status='ERROR')
# OptimizationRecord(id='18254715', status='ERROR')
# OptimizationRecord(id='18254716', status='ERROR')
# OptimizationRecord(id='18254717', status='ERROR')
# OptimizationRecord(id='18254718', status='ERROR')
# OptimizationRecord(id='18254719', status='ERROR')
# OptimizationRecord(id='18254720', status='ERROR')
# OptimizationRecord(id='18254721', status='ERROR')
# OptimizationRecord(id='18254729', status='ERROR')
# OptimizationRecord(id='18254731', status='ERROR')
# OptimizationRecord(id='18254732', status='ERROR')
# OptimizationRecord(id='18254739', status='ERROR')
# OptimizationRecord(id='18254743', status='ERROR')
# OptimizationRecord(id='18254744', status='ERROR')
# OptimizationRecord(id='18254759', status='ERROR')
# OptimizationRecord(id='18254761', status='ERROR')
# OptimizationRecord(id='18254763', status='ERROR')
# OptimizationRecord(id='18257423', status='ERROR')
# OptimizationRecord(id='18257461', status='ERROR')
# OptimizationRecord(id='18257499', status='ERROR')
# OptimizationRecord(id='18257500', status='ERROR')
# OptimizationRecord(id='18257501', status='ERROR')
# OptimizationRecord(id='18257502', status='ERROR')
# OptimizationRecord(id='18257503', status='ERROR')
# OptimizationRecord(id='18257504', status='ERROR')
# OptimizationRecord(id='18257506', status='ERROR')
# OptimizationRecord(id='18257507', status='ERROR')
# OptimizationRecord(id='18257509', status='ERROR')
# OptimizationRecord(id='18257511', status='ERROR')
# OptimizationRecord(id='18257512', status='ERROR')
# OptimizationRecord(id='18257516', status='ERROR')
# OptimizationRecord(id='18257544', status='ERROR')
# OptimizationRecord(id='18257547', status='ERROR')
# OptimizationRecord(id='18257548', status='ERROR')
# OptimizationRecord(id='18257549', status='ERROR')
# OptimizationRecord(id='18257563', status='ERROR')
# OptimizationRecord(id='18257564', status='ERROR')
# OptimizationRecord(id='18257565', status='ERROR')
# OptimizationRecord(id='18257566', status='ERROR')
# OptimizationRecord(id='18257573', status='ERROR')
# OptimizationRecord(id='18257587', status='ERROR')
# OptimizationRecord(id='18257588', status='ERROR')
# OptimizationRecord(id='18257589', status='ERROR')
# OptimizationRecord(id='18257590', status='ERROR')
# OptimizationRecord(id='18257591', status='ERROR')
# OptimizationRecord(id='18257592', status='ERROR')
# OptimizationRecord(id='18257594', status='ERROR')
# OptimizationRecord(id='18257595', status='ERROR')
# OptimizationRecord(id='18257596', status='ERROR')
# OptimizationRecord(id='18257597', status='ERROR')
# OptimizationRecord(id='18257598', status='ERROR')
# OptimizationRecord(id='18257600', status='ERROR')
# OptimizationRecord(id='18257601', status='ERROR')
# OptimizationRecord(id='18257603', status='ERROR')
# OptimizationRecord(id='18257604', status='ERROR')
# OptimizationRecord(id='18257606', status='ERROR')
# OptimizationRecord(id='18257607', status='ERROR')
# OptimizationRecord(id='18257608', status='ERROR')
# OptimizationRecord(id='18257609', status='ERROR')
# OptimizationRecord(id='18257610', status='ERROR')
# OptimizationRecord(id='18257611', status='ERROR')
# OptimizationRecord(id='18257612', status='ERROR')
# OptimizationRecord(id='18257613', status='ERROR')
# OptimizationRecord(id='18257617', status='ERROR')
# OptimizationRecord(id='18257618', status='ERROR')
# OptimizationRecord(id='18257619', status='ERROR')
# OptimizationRecord(id='18257621', status='ERROR')
# OptimizationRecord(id='18257622', status='ERROR')
# OptimizationRecord(id='18257623', status='ERROR')
# OptimizationRecord(id='18257624', status='ERROR')
# OptimizationRecord(id='18257625', status='ERROR')
# OptimizationRecord(id='18257626', status='ERROR')
# OptimizationRecord(id='18257628', status='ERROR')
# OptimizationRecord(id='18257629', status='ERROR')
# OptimizationRecord(id='18257630', status='ERROR')
# OptimizationRecord(id='18257632', status='ERROR')
# OptimizationRecord(id='18257634', status='ERROR')
# OptimizationRecord(id='18257635', status='ERROR')
# OptimizationRecord(id='18257636', status='ERROR')
# OptimizationRecord(id='18257637', status='ERROR')
# OptimizationRecord(id='18257638', status='ERROR')
# OptimizationRecord(id='18257639', status='ERROR')
# OptimizationRecord(id='18257641', status='ERROR')
# OptimizationRecord(id='18257642', status='ERROR')
# OptimizationRecord(id='18257643', status='ERROR')
# OptimizationRecord(id='18257644', status='ERROR')
# OptimizationRecord(id='18257670', status='ERROR')
# OptimizationRecord(id='18257672', status='ERROR')
# OptimizationRecord(id='18257674', status='ERROR')
# OptimizationRecord(id='18257675', status='ERROR')
# OptimizationRecord(id='18257676', status='ERROR')
# OptimizationRecord(id='18257677', status='ERROR')
# OptimizationRecord(id='18257678', status='ERROR')
# OptimizationRecord(id='18257679', status='ERROR')
# OptimizationRecord(id='18257680', status='ERROR')
# OptimizationRecord(id='18257681', status='ERROR')
# OptimizationRecord(id='18257682', status='ERROR')
# OptimizationRecord(id='18257683', status='ERROR')
# OptimizationRecord(id='18257684', status='ERROR')
# OptimizationRecord(id='18257685', status='ERROR')
# OptimizationRecord(id='18257686', status='ERROR')
# OptimizationRecord(id='18257687', status='ERROR')
# OptimizationRecord(id='18257688', status='ERROR')
# OptimizationRecord(id='18257689', status='ERROR')
# OptimizationRecord(id='18257691', status='ERROR')
# OptimizationRecord(id='18257726', status='ERROR')
# OptimizationRecord(id='18257727', status='ERROR')
# OptimizationRecord(id='18257728', status='ERROR')
# OptimizationRecord(id='18257729', status='ERROR')
# OptimizationRecord(id='18257730', status='ERROR')
# OptimizationRecord(id='18257731', status='ERROR')
# OptimizationRecord(id='18257732', status='ERROR')
# OptimizationRecord(id='18257733', status='ERROR')
# OptimizationRecord(id='18257734', status='ERROR')
# OptimizationRecord(id='18257735', status='ERROR')
# OptimizationRecord(id='18257736', status='ERROR')
# OptimizationRecord(id='18257737', status='ERROR')
# OptimizationRecord(id='18257738', status='ERROR')
# OptimizationRecord(id='18257739', status='ERROR')
# OptimizationRecord(id='18257740', status='ERROR')
# OptimizationRecord(id='18257742', status='ERROR')
# OptimizationRecord(id='18257743', status='ERROR')
# OptimizationRecord(id='18257744', status='ERROR')
# OptimizationRecord(id='18257745', status='ERROR')
# OptimizationRecord(id='18257746', status='ERROR')
# OptimizationRecord(id='18257747', status='ERROR')
# OptimizationRecord(id='18257749', status='ERROR')
# OptimizationRecord(id='18257750', status='ERROR')
# OptimizationRecord(id='18257751', status='ERROR')
# OptimizationRecord(id='18257752', status='ERROR')
# OptimizationRecord(id='18257753', status='ERROR')
# OptimizationRecord(id='18257754', status='ERROR')
# OptimizationRecord(id='18257755', status='ERROR')
# OptimizationRecord(id='18257756', status='ERROR')
# OptimizationRecord(id='18257757', status='ERROR')
# OptimizationRecord(id='18257758', status='ERROR')
# OptimizationRecord(id='18257759', status='ERROR')
# OptimizationRecord(id='18257760', status='ERROR')
# OptimizationRecord(id='18257761', status='ERROR')
# OptimizationRecord(id='18257762', status='ERROR')
# OptimizationRecord(id='18257763', status='ERROR')
# OptimizationRecord(id='18257764', status='ERROR')
# OptimizationRecord(id='18257778', status='ERROR')
# OptimizationRecord(id='18257779', status='ERROR')
# OptimizationRecord(id='18257780', status='ERROR')
# OptimizationRecord(id='18257781', status='ERROR')
# OptimizationRecord(id='18257782', status='ERROR')
# OptimizationRecord(id='18257783', status='ERROR')
# OptimizationRecord(id='18257784', status='ERROR')
# OptimizationRecord(id='18257785', status='ERROR')
# OptimizationRecord(id='18257786', status='ERROR')
# OptimizationRecord(id='18257787', status='ERROR')
# OptimizationRecord(id='18257788', status='ERROR')
# OptimizationRecord(id='18257789', status='ERROR')
# OptimizationRecord(id='18257790', status='ERROR')
# OptimizationRecord(id='18257791', status='ERROR')
# OptimizationRecord(id='18257792', status='ERROR')
# OptimizationRecord(id='18257793', status='ERROR')
# OptimizationRecord(id='18257794', status='ERROR')
# OptimizationRecord(id='18257795', status='ERROR')
# OptimizationRecord(id='18258288', status='ERROR')
# OptimizationRecord(id='18258289', status='ERROR')
# OptimizationRecord(id='18258290', status='ERROR')
# OptimizationRecord(id='18258291', status='ERROR')
# OptimizationRecord(id='18258301', status='ERROR')
# OptimizationRecord(id='18258302', status='ERROR')
# OptimizationRecord(id='18258303', status='ERROR')
# OptimizationRecord(id='18258304', status='ERROR')
# OptimizationRecord(id='18258305', status='ERROR')
# OptimizationRecord(id='18258306', status='ERROR')
# OptimizationRecord(id='18258307', status='ERROR')
# OptimizationRecord(id='18258308', status='ERROR')
# OptimizationRecord(id='18258309', status='ERROR')
# OptimizationRecord(id='18258310', status='ERROR')
# OptimizationRecord(id='18258311', status='ERROR')
# OptimizationRecord(id='18258312', status='ERROR')
# OptimizationRecord(id='18258313', status='ERROR')
# OptimizationRecord(id='18258314', status='ERROR')
# OptimizationRecord(id='18258315', status='ERROR')
# OptimizationRecord(id='18258316', status='ERROR')
# OptimizationRecord(id='18258317', status='ERROR')
# OptimizationRecord(id='18258318', status='ERROR')
# OptimizationRecord(id='18258319', status='ERROR')
# OptimizationRecord(id='18258320', status='ERROR')
# OptimizationRecord(id='18258321', status='ERROR')
# OptimizationRecord(id='18258322', status='ERROR')
# OptimizationRecord(id='18258323', status='ERROR')
# OptimizationRecord(id='18258324', status='ERROR')
# OptimizationRecord(id='18258325', status='ERROR')
# OptimizationRecord(id='18258326', status='ERROR')
# OptimizationRecord(id='18258327', status='ERROR')
# OptimizationRecord(id='18258328', status='ERROR')
# OptimizationRecord(id='18258329', status='ERROR')
# OptimizationRecord(id='18258330', status='ERROR')
# OptimizationRecord(id='18258331', status='ERROR')
# OptimizationRecord(id='18258332', status='ERROR')
# OptimizationRecord(id='18258333', status='ERROR')
# OptimizationRecord(id='18258334', status='ERROR')
# OptimizationRecord(id='18258335', status='ERROR')
# OptimizationRecord(id='18258336', status='ERROR')
# OptimizationRecord(id='18258337', status='ERROR')
# OptimizationRecord(id='18258338', status='ERROR')
# OptimizationRecord(id='18258339', status='ERROR')
# OptimizationRecord(id='18258340', status='ERROR')
# OptimizationRecord(id='18258341', status='ERROR')
# OptimizationRecord(id='18258342', status='ERROR')
# OptimizationRecord(id='18258343', status='ERROR')
# OptimizationRecord(id='18258345', status='ERROR')
# OptimizationRecord(id='18258346', status='ERROR')
# OptimizationRecord(id='18258347', status='ERROR')
# OptimizationRecord(id='18258348', status='ERROR')
# OptimizationRecord(id='18258349', status='ERROR')
# OptimizationRecord(id='18258350', status='ERROR')
# OptimizationRecord(id='18258351', status='ERROR')
# OptimizationRecord(id='18258352', status='ERROR')
# OptimizationRecord(id='18258353', status='ERROR')
# OptimizationRecord(id='18258354', status='ERROR')
# OptimizationRecord(id='18258356', status='ERROR')
# OptimizationRecord(id='18258357', status='ERROR')
# OptimizationRecord(id='18258358', status='ERROR')
# OptimizationRecord(id='18258359', status='ERROR')
# OptimizationRecord(id='18258360', status='ERROR')
# OptimizationRecord(id='18258361', status='ERROR')
# OptimizationRecord(id='18258362', status='ERROR')
# OptimizationRecord(id='18258363', status='ERROR')
# OptimizationRecord(id='18258364', status='ERROR')
# OptimizationRecord(id='18258365', status='ERROR')
# OptimizationRecord(id='18258366', status='ERROR')
# OptimizationRecord(id='18258367', status='ERROR')
# OptimizationRecord(id='18258368', status='ERROR')
# OptimizationRecord(id='18258369', status='ERROR')
# OptimizationRecord(id='18258370', status='ERROR')
# OptimizationRecord(id='18258371', status='ERROR')
# OptimizationRecord(id='18258372', status='ERROR')
# OptimizationRecord(id='18258373', status='ERROR')
# OptimizationRecord(id='18258374', status='ERROR')
# OptimizationRecord(id='18258375', status='ERROR')
# OptimizationRecord(id='18258376', status='ERROR')
# OptimizationRecord(id='18258377', status='ERROR')
# OptimizationRecord(id='18258378', status='ERROR')
# OptimizationRecord(id='18258379', status='ERROR')
# OptimizationRecord(id='18258380', status='ERROR')
# OptimizationRecord(id='18258381', status='ERROR')
# OptimizationRecord(id='18258382', status='ERROR')
# OptimizationRecord(id='18258383', status='ERROR')
# OptimizationRecord(id='18258384', status='ERROR')
# OptimizationRecord(id='18258385', status='ERROR')
# OptimizationRecord(id='18258386', status='ERROR')
# OptimizationRecord(id='18258387', status='ERROR')
# OptimizationRecord(id='18258388', status='ERROR')
# OptimizationRecord(id='18258389', status='ERROR')
# OptimizationRecord(id='18258390', status='ERROR')
# OptimizationRecord(id='18258391', status='ERROR')
# OptimizationRecord(id='18258392', status='ERROR')
# OptimizationRecord(id='18258393', status='ERROR')
# OptimizationRecord(id='18258394', status='ERROR')
# OptimizationRecord(id='18258395', status='ERROR')
# OptimizationRecord(id='18258396', status='ERROR')
# OptimizationRecord(id='18258397', status='ERROR')
# OptimizationRecord(id='18258398', status='ERROR')
# OptimizationRecord(id='18258399', status='ERROR')
# OptimizationRecord(id='18258400', status='ERROR')
# OptimizationRecord(id='18258401', status='ERROR')
# OptimizationRecord(id='18258402', status='ERROR')
# OptimizationRecord(id='18258403', status='ERROR')
# OptimizationRecord(id='18258404', status='ERROR')
# OptimizationRecord(id='18258405', status='ERROR')
# OptimizationRecord(id='18258406', status='ERROR')
# OptimizationRecord(id='18258407', status='ERROR')
# OptimizationRecord(id='18258408', status='ERROR')
# OptimizationRecord(id='18258409', status='ERROR')
# OptimizationRecord(id='18258410', status='ERROR')
# OptimizationRecord(id='18258411', status='ERROR')
# OptimizationRecord(id='18258412', status='ERROR')
# OptimizationRecord(id='18258414', status='ERROR')
# OptimizationRecord(id='18258415', status='ERROR')
# OptimizationRecord(id='18258416', status='ERROR')
# OptimizationRecord(id='18258417', status='ERROR')
# OptimizationRecord(id='18258418', status='ERROR')
# OptimizationRecord(id='18258419', status='ERROR')
# OptimizationRecord(id='18258420', status='ERROR')
# OptimizationRecord(id='18258699', status='ERROR')
# OptimizationRecord(id='18258700', status='ERROR')
# OptimizationRecord(id='18258701', status='ERROR')
# OptimizationRecord(id='18258702', status='ERROR')
# OptimizationRecord(id='18258703', status='ERROR')
# OptimizationRecord(id='18258704', status='ERROR')
# OptimizationRecord(id='18258705', status='ERROR')
# OptimizationRecord(id='18258706', status='ERROR')
# OptimizationRecord(id='18258707', status='ERROR')
# OptimizationRecord(id='18258708', status='ERROR')
# OptimizationRecord(id='18258709', status='ERROR')
# OptimizationRecord(id='18258710', status='ERROR')
# OptimizationRecord(id='18258711', status='ERROR')
# OptimizationRecord(id='18258712', status='ERROR')
# OptimizationRecord(id='18258713', status='ERROR')
# OptimizationRecord(id='18258715', status='ERROR')
# OptimizationRecord(id='18258716', status='ERROR')
# OptimizationRecord(id='18258718', status='ERROR')
# OptimizationRecord(id='18258719', status='ERROR')
# OptimizationRecord(id='18258721', status='ERROR')
# OptimizationRecord(id='18258722', status='ERROR')
# OptimizationRecord(id='18258723', status='ERROR')
# OptimizationRecord(id='18258724', status='ERROR')
# OptimizationRecord(id='18258725', status='ERROR')
# OptimizationRecord(id='18258726', status='ERROR')
# OptimizationRecord(id='18258727', status='ERROR')
# OptimizationRecord(id='18258728', status='ERROR')
# OptimizationRecord(id='18258729', status='ERROR')
# OptimizationRecord(id='18258731', status='ERROR')
# OptimizationRecord(id='18258732', status='ERROR')
# OptimizationRecord(id='18258733', status='ERROR')
# OptimizationRecord(id='18258734', status='ERROR')
# OptimizationRecord(id='18258736', status='ERROR')
# OptimizationRecord(id='18258737', status='ERROR')
# OptimizationRecord(id='18258738', status='ERROR')
# OptimizationRecord(id='18258739', status='ERROR')
# OptimizationRecord(id='18258740', status='ERROR')
# OptimizationRecord(id='18258741', status='ERROR')
# OptimizationRecord(id='18258742', status='ERROR')
# OptimizationRecord(id='18258743', status='ERROR')
# OptimizationRecord(id='18258745', status='ERROR')
# OptimizationRecord(id='18258747', status='ERROR')
# OptimizationRecord(id='18258748', status='ERROR')
# OptimizationRecord(id='18258749', status='ERROR')
# OptimizationRecord(id='18258750', status='ERROR')
# OptimizationRecord(id='18258751', status='ERROR')
# OptimizationRecord(id='18258752', status='ERROR')
# OptimizationRecord(id='18258753', status='ERROR')
# OptimizationRecord(id='18258754', status='ERROR')
# OptimizationRecord(id='18258755', status='ERROR')
# OptimizationRecord(id='18258777', status='ERROR')
# OptimizationRecord(id='18258778', status='ERROR')
# OptimizationRecord(id='18258779', status='ERROR')
# OptimizationRecord(id='18258780', status='ERROR')
# OptimizationRecord(id='18258781', status='ERROR')
# OptimizationRecord(id='18258783', status='ERROR')
# OptimizationRecord(id='18258784', status='ERROR')
# OptimizationRecord(id='18258785', status='ERROR')
# OptimizationRecord(id='18258787', status='ERROR')
# OptimizationRecord(id='18258788', status='ERROR')
# OptimizationRecord(id='18258789', status='ERROR')
# OptimizationRecord(id='18258790', status='ERROR')
# OptimizationRecord(id='18258791', status='ERROR')
# OptimizationRecord(id='18258793', status='ERROR')
# OptimizationRecord(id='18258794', status='ERROR')
# OptimizationRecord(id='18258824', status='ERROR')
# OptimizationRecord(id='18258825', status='ERROR')
# OptimizationRecord(id='18258827', status='ERROR')
# OptimizationRecord(id='18258828', status='ERROR')
# OptimizationRecord(id='18258829', status='ERROR')
# OptimizationRecord(id='18258831', status='ERROR')
# OptimizationRecord(id='18258834', status='ERROR')
# OptimizationRecord(id='18258835', status='ERROR')
# OptimizationRecord(id='18258836', status='ERROR')
# OptimizationRecord(id='18258837', status='ERROR')
# OptimizationRecord(id='18258838', status='ERROR')
# OptimizationRecord(id='18258839', status='ERROR')
# OptimizationRecord(id='18258840', status='ERROR')
# OptimizationRecord(id='18258841', status='ERROR')
# OptimizationRecord(id='18258842', status='ERROR')
# OptimizationRecord(id='18258843', status='ERROR')
# OptimizationRecord(id='18258844', status='ERROR')
# OptimizationRecord(id='18258846', status='ERROR')
# OptimizationRecord(id='18258847', status='ERROR')
# OptimizationRecord(id='18258848', status='ERROR')
# OptimizationRecord(id='18258849', status='ERROR')
# OptimizationRecord(id='18258850', status='ERROR')
# OptimizationRecord(id='18258851', status='ERROR')
# OptimizationRecord(id='18258852', status='ERROR')
# OptimizationRecord(id='18258862', status='ERROR')
# OptimizationRecord(id='18258904', status='ERROR')
# OptimizationRecord(id='18258921', status='ERROR')
# OptimizationRecord(id='18258922', status='ERROR')
# OptimizationRecord(id='18258923', status='ERROR')
# OptimizationRecord(id='18258924', status='ERROR')
# OptimizationRecord(id='18258925', status='ERROR')
# OptimizationRecord(id='18258927', status='ERROR')
# OptimizationRecord(id='18258928', status='ERROR')
# OptimizationRecord(id='18258929', status='ERROR')
# OptimizationRecord(id='18258930', status='ERROR')
# OptimizationRecord(id='18258931', status='ERROR')
# OptimizationRecord(id='18258932', status='ERROR')
# OptimizationRecord(id='18258933', status='ERROR')
# OptimizationRecord(id='18258934', status='ERROR')
# OptimizationRecord(id='18258935', status='ERROR')
# OptimizationRecord(id='18258936', status='ERROR')
# OptimizationRecord(id='18258937', status='ERROR')
# OptimizationRecord(id='18258938', status='ERROR')
# OptimizationRecord(id='18258939', status='ERROR')
# OptimizationRecord(id='18258943', status='ERROR')
# OptimizationRecord(id='18258944', status='ERROR')
# OptimizationRecord(id='18258945', status='ERROR')
# OptimizationRecord(id='18258946', status='ERROR')
# OptimizationRecord(id='18258947', status='ERROR')
# OptimizationRecord(id='18258948', status='ERROR')
# OptimizationRecord(id='18258949', status='ERROR')
# OptimizationRecord(id='18258950', status='ERROR')
# OptimizationRecord(id='18258951', status='ERROR')
# OptimizationRecord(id='18258952', status='ERROR')
# OptimizationRecord(id='18258953', status='ERROR')
# OptimizationRecord(id='18258954', status='ERROR')
# OptimizationRecord(id='18258955', status='ERROR')
# OptimizationRecord(id='18258956', status='ERROR')
# OptimizationRecord(id='18258957', status='ERROR')
# OptimizationRecord(id='18258958', status='ERROR')
# OptimizationRecord(id='18258959', status='ERROR')
# OptimizationRecord(id='18258960', status='ERROR')
# OptimizationRecord(id='18258961', status='ERROR')
# OptimizationRecord(id='18258962', status='ERROR')
# OptimizationRecord(id='18258963', status='ERROR')
# OptimizationRecord(id='18258964', status='ERROR')
# OptimizationRecord(id='18258965', status='ERROR')
# OptimizationRecord(id='18258966', status='ERROR')
# OptimizationRecord(id='18258967', status='ERROR')
# OptimizationRecord(id='18258969', status='ERROR')
# OptimizationRecord(id='18258971', status='ERROR')
# OptimizationRecord(id='18258972', status='ERROR')
# OptimizationRecord(id='18258973', status='ERROR')
# OptimizationRecord(id='18258974', status='ERROR')
# OptimizationRecord(id='18258975', status='ERROR')
# OptimizationRecord(id='18258977', status='ERROR')
# OptimizationRecord(id='18258978', status='ERROR')
# OptimizationRecord(id='18258979', status='ERROR')
# OptimizationRecord(id='18258980', status='ERROR')
# OptimizationRecord(id='18258981', status='ERROR')
# OptimizationRecord(id='18258982', status='ERROR')
# OptimizationRecord(id='18258986', status='ERROR')
# OptimizationRecord(id='18258987', status='ERROR')
# OptimizationRecord(id='18258992', status='ERROR')
# OptimizationRecord(id='18258993', status='ERROR')
# OptimizationRecord(id='18258994', status='ERROR')
# OptimizationRecord(id='18258997', status='ERROR')
# OptimizationRecord(id='18258998', status='ERROR')
# OptimizationRecord(id='18258999', status='ERROR')
# OptimizationRecord(id='18259000', status='ERROR')
# OptimizationRecord(id='18259001', status='ERROR')
# OptimizationRecord(id='18259002', status='ERROR')
# OptimizationRecord(id='18259003', status='ERROR')
# OptimizationRecord(id='18259004', status='ERROR')
# OptimizationRecord(id='18259005', status='ERROR')
# OptimizationRecord(id='18259006', status='ERROR')
# OptimizationRecord(id='18259007', status='ERROR')
# OptimizationRecord(id='18259009', status='ERROR')
# OptimizationRecord(id='18260684', status='ERROR')
# OptimizationRecord(id='18260685', status='ERROR')
# OptimizationRecord(id='18260686', status='ERROR')
# OptimizationRecord(id='18260687', status='ERROR')
# OptimizationRecord(id='18260688', status='ERROR')
# OptimizationRecord(id='18260692', status='ERROR')
# OptimizationRecord(id='18260693', status='ERROR')
# OptimizationRecord(id='18260694', status='ERROR')
# OptimizationRecord(id='18260695', status='ERROR')
# OptimizationRecord(id='18260696', status='ERROR')
# OptimizationRecord(id='18260697', status='ERROR')
# OptimizationRecord(id='18260698', status='ERROR')
# OptimizationRecord(id='18260699', status='ERROR')
# OptimizationRecord(id='18260700', status='ERROR')
# OptimizationRecord(id='18260701', status='ERROR')
# OptimizationRecord(id='18260702', status='ERROR')
# OptimizationRecord(id='18260703', status='ERROR')
# OptimizationRecord(id='18260704', status='ERROR')
# OptimizationRecord(id='18260706', status='ERROR')
# OptimizationRecord(id='18260707', status='ERROR')
# OptimizationRecord(id='18260709', status='ERROR')
# OptimizationRecord(id='18260710', status='ERROR')
# OptimizationRecord(id='18260711', status='ERROR')
# OptimizationRecord(id='18260713', status='ERROR')
# OptimizationRecord(id='18260714', status='ERROR')
# OptimizationRecord(id='18260715', status='ERROR')
# OptimizationRecord(id='18260716', status='ERROR')
# OptimizationRecord(id='18260717', status='ERROR')
# OptimizationRecord(id='18260718', status='ERROR')
# OptimizationRecord(id='18261935', status='ERROR')
# OptimizationRecord(id='18261936', status='ERROR')
# OptimizationRecord(id='18261937', status='ERROR')
# OptimizationRecord(id='18261943', status='ERROR')
# OptimizationRecord(id='18261944', status='ERROR')
# OptimizationRecord(id='18261946', status='ERROR')
# OptimizationRecord(id='18261949', status='ERROR')
# OptimizationRecord(id='18262471', status='ERROR')
# OptimizationRecord(id='18283739', status='ERROR')
# OptimizationRecord(id='18283741', status='ERROR')
# OptimizationRecord(id='18283742', status='ERROR')
# OptimizationRecord(id='18283744', status='ERROR')
# OptimizationRecord(id='18283745', status='ERROR')
# OptimizationRecord(id='18283746', status='ERROR')
# OptimizationRecord(id='18283747', status='ERROR')
# OptimizationRecord(id='18283748', status='ERROR')
# OptimizationRecord(id='18283749', status='ERROR')
# OptimizationRecord(id='18283752', status='ERROR')
# OptimizationRecord(id='18283754', status='ERROR')
# OptimizationRecord(id='18283755', status='ERROR')
# OptimizationRecord(id='18283758', status='ERROR')
# OptimizationRecord(id='18283759', status='ERROR')
# OptimizationRecord(id='18283760', status='ERROR')
# OptimizationRecord(id='18283761', status='ERROR')
# OptimizationRecord(id='18283762', status='ERROR')
# OptimizationRecord(id='18283763', status='ERROR')
# OptimizationRecord(id='18283768', status='ERROR')
# OptimizationRecord(id='18283769', status='ERROR')
# OptimizationRecord(id='18283773', status='ERROR')
# OptimizationRecord(id='18283774', status='ERROR')
# OptimizationRecord(id='18283775', status='ERROR')
# OptimizationRecord(id='18283776', status='ERROR')
# OptimizationRecord(id='18283777', status='ERROR')
# OptimizationRecord(id='18283778', status='ERROR')
# OptimizationRecord(id='18283779', status='ERROR')
# OptimizationRecord(id='18283780', status='ERROR')
# OptimizationRecord(id='18283781', status='ERROR')
# OptimizationRecord(id='18283782', status='ERROR')
# OptimizationRecord(id='18283783', status='ERROR')
# OptimizationRecord(id='18283784', status='ERROR')
# OptimizationRecord(id='18283788', status='ERROR')
# OptimizationRecord(id='18283789', status='ERROR')
# OptimizationRecord(id='18283790', status='ERROR')
# OptimizationRecord(id='18283794', status='ERROR')
# OptimizationRecord(id='18283795', status='ERROR')
# OptimizationRecord(id='18283796', status='ERROR')
# OptimizationRecord(id='18283797', status='ERROR')
# OptimizationRecord(id='18283798', status='ERROR')
# OptimizationRecord(id='18283799', status='ERROR')
# OptimizationRecord(id='18283802', status='ERROR')
# OptimizationRecord(id='18283803', status='ERROR')
# OptimizationRecord(id='18283804', status='ERROR')
# OptimizationRecord(id='18283805', status='ERROR')
# OptimizationRecord(id='18283806', status='ERROR')
# OptimizationRecord(id='18283807', status='ERROR')
# OptimizationRecord(id='18283808', status='ERROR')
# OptimizationRecord(id='18283809', status='ERROR')
# OptimizationRecord(id='18283810', status='ERROR')
# OptimizationRecord(id='18283813', status='ERROR')
# OptimizationRecord(id='18283817', status='ERROR')
# OptimizationRecord(id='18283818', status='ERROR')
# OptimizationRecord(id='18283820', status='ERROR')
# OptimizationRecord(id='18283821', status='ERROR')
# OptimizationRecord(id='18283822', status='ERROR')
# OptimizationRecord(id='18283823', status='ERROR')
# OptimizationRecord(id='18283824', status='ERROR')
# OptimizationRecord(id='18283829', status='ERROR')
# OptimizationRecord(id='18283830', status='ERROR')
# OptimizationRecord(id='18283831', status='ERROR')
# OptimizationRecord(id='18283835', status='ERROR')
# OptimizationRecord(id='18283836', status='ERROR')
# OptimizationRecord(id='18283837', status='ERROR')
# OptimizationRecord(id='18283839', status='ERROR')
# OptimizationRecord(id='18283840', status='ERROR')
# OptimizationRecord(id='18283841', status='ERROR')
# OptimizationRecord(id='18283842', status='ERROR')
# OptimizationRecord(id='18283843', status='ERROR')
# OptimizationRecord(id='18283845', status='ERROR')
# OptimizationRecord(id='18283846', status='ERROR')
# OptimizationRecord(id='18283847', status='ERROR')
# OptimizationRecord(id='18283848', status='ERROR')
# OptimizationRecord(id='18283849', status='ERROR')
# OptimizationRecord(id='18283850', status='ERROR')
# OptimizationRecord(id='18283851', status='ERROR')
# OptimizationRecord(id='18283852', status='ERROR')
# OptimizationRecord(id='18283853', status='ERROR')
# OptimizationRecord(id='18283854', status='ERROR')
# OptimizationRecord(id='18283855', status='ERROR')
# OptimizationRecord(id='18283857', status='ERROR')
# OptimizationRecord(id='18283858', status='ERROR')
# OptimizationRecord(id='18283860', status='ERROR')
# OptimizationRecord(id='18283861', status='ERROR')
# OptimizationRecord(id='18283862', status='ERROR')
# OptimizationRecord(id='18283863', status='ERROR')
# OptimizationRecord(id='18283864', status='ERROR')
# OptimizationRecord(id='18283865', status='ERROR')
# OptimizationRecord(id='18283869', status='ERROR')
# OptimizationRecord(id='18283870', status='ERROR')
# OptimizationRecord(id='18283874', status='ERROR')
# OptimizationRecord(id='18283876', status='ERROR')
# OptimizationRecord(id='18283877', status='ERROR')
# OptimizationRecord(id='18283879', status='ERROR')
# OptimizationRecord(id='18283881', status='ERROR')
# OptimizationRecord(id='18283882', status='ERROR')
# OptimizationRecord(id='18283883', status='ERROR')
# OptimizationRecord(id='18283884', status='ERROR')
# OptimizationRecord(id='18283885', status='ERROR')
# OptimizationRecord(id='18283886', status='ERROR')
# OptimizationRecord(id='18283887', status='ERROR')
# OptimizationRecord(id='18283888', status='ERROR')
# OptimizationRecord(id='18283890', status='ERROR')
# OptimizationRecord(id='18283891', status='ERROR')
# OptimizationRecord(id='18283892', status='ERROR')
# OptimizationRecord(id='18283893', status='ERROR')
# OptimizationRecord(id='18283894', status='ERROR')
# OptimizationRecord(id='18283895', status='ERROR')
# OptimizationRecord(id='18283896', status='ERROR')
# OptimizationRecord(id='18283897', status='ERROR')
# OptimizationRecord(id='18283898', status='ERROR')
# OptimizationRecord(id='18283899', status='ERROR')
# OptimizationRecord(id='18283900', status='ERROR')
# OptimizationRecord(id='18283901', status='ERROR')
# OptimizationRecord(id='18283902', status='ERROR')
# OptimizationRecord(id='18283904', status='ERROR')
# OptimizationRecord(id='18283905', status='ERROR')
# OptimizationRecord(id='18283906', status='ERROR')
# OptimizationRecord(id='18283907', status='ERROR')
# OptimizationRecord(id='18283908', status='ERROR')
# OptimizationRecord(id='18283910', status='ERROR')
# OptimizationRecord(id='18283912', status='ERROR')
# OptimizationRecord(id='18283913', status='ERROR')
# OptimizationRecord(id='18283914', status='ERROR')
# OptimizationRecord(id='18283915', status='ERROR')
# OptimizationRecord(id='18283916', status='ERROR')
# OptimizationRecord(id='18283917', status='ERROR')
# OptimizationRecord(id='18283918', status='ERROR')
# OptimizationRecord(id='18283919', status='ERROR')
# OptimizationRecord(id='18283921', status='ERROR')
# OptimizationRecord(id='18283922', status='ERROR')
# OptimizationRecord(id='18283923', status='ERROR')
# OptimizationRecord(id='18283924', status='ERROR')
# OptimizationRecord(id='18283925', status='ERROR')
# OptimizationRecord(id='18283926', status='ERROR')
# OptimizationRecord(id='18283927', status='ERROR')
# OptimizationRecord(id='18283928', status='ERROR')
# OptimizationRecord(id='18283929', status='ERROR')
# OptimizationRecord(id='18283930', status='ERROR')
# OptimizationRecord(id='18283931', status='ERROR')
# OptimizationRecord(id='18283932', status='ERROR')
# OptimizationRecord(id='18283933', status='ERROR')
# OptimizationRecord(id='18283934', status='ERROR')
# OptimizationRecord(id='18283935', status='ERROR')
# OptimizationRecord(id='18283939', status='ERROR')
# OptimizationRecord(id='18283942', status='ERROR')
# OptimizationRecord(id='18283943', status='ERROR')
# OptimizationRecord(id='18283944', status='ERROR')
# OptimizationRecord(id='18283945', status='ERROR')
# OptimizationRecord(id='18283946', status='ERROR')
# OptimizationRecord(id='18283947', status='ERROR')
# OptimizationRecord(id='18283951', status='ERROR')
# OptimizationRecord(id='18283955', status='ERROR')
# OptimizationRecord(id='18283958', status='ERROR')
# ...
# OptimizationRecord(id='18305377', status='ERROR')
# OptimizationRecord(id='18305378', status='ERROR')
# OptimizationRecord(id='18305379', status='ERROR')
# OptimizationRecord(id='18305380', status='ERROR')
# OptimizationRecord(id='18305394', status='ERROR')
# OptimizationRecord(id='18305396', status='ERROR')
# OptimizationRecord(id='18305397', status='ERROR')
# OptimizationRecord(id='18305398', status='ERROR')
# OptimizationRecord(id='18305400', status='ERROR')
# OptimizationRecord(id='18305401', status='ERROR')
# OptimizationRecord(id='18305402', status='ERROR')
# OptimizationRecord(id='18305403', status='ERROR')
# OptimizationRecord(id='18305405', status='ERROR')
# OptimizationRecord(id='18305406', status='ERROR')
# OptimizationRecord(id='18305407', status='ERROR')
# OptimizationRecord(id='18305408', status='ERROR')
# OptimizationRecord(id='18305419', status='ERROR')
# OptimizationRecord(id='18305420', status='ERROR')
# OptimizationRecord(id='18305422', status='ERROR')
# OptimizationRecord(id='18305423', status='ERROR')
# OptimizationRecord(id='18305424', status='ERROR')
# OptimizationRecord(id='18305425', status='ERROR')
# OptimizationRecord(id='18305426', status='ERROR')
# OptimizationRecord(id='18305427', status='ERROR')
# OptimizationRecord(id='18305428', status='ERROR')
# OptimizationRecord(id='18305429', status='ERROR')
# OptimizationRecord(id='18305431', status='ERROR')
# OptimizationRecord(id='18305432', status='ERROR')
# OptimizationRecord(id='18305433', status='ERROR')
# OptimizationRecord(id='18305434', status='ERROR')
# OptimizationRecord(id='18305435', status='ERROR')
# OptimizationRecord(id='18305436', status='ERROR')
# OptimizationRecord(id='18305437', status='ERROR')
# OptimizationRecord(id='18305438', status='ERROR')
# OptimizationRecord(id='18305439', status='ERROR')
# OptimizationRecord(id='18305440', status='ERROR')
# OptimizationRecord(id='18305441', status='ERROR')
# OptimizationRecord(id='18305442', status='ERROR')
# OptimizationRecord(id='18305445', status='ERROR')
# OptimizationRecord(id='18305446', status='ERROR')
# OptimizationRecord(id='18305447', status='ERROR')
# OptimizationRecord(id='18305448', status='ERROR')
# OptimizationRecord(id='18305449', status='ERROR')
# OptimizationRecord(id='18305450', status='ERROR')
# OptimizationRecord(id='18305451', status='ERROR')
# OptimizationRecord(id='18305452', status='ERROR')
# OptimizationRecord(id='18305453', status='ERROR')
# OptimizationRecord(id='18305454', status='ERROR')
# OptimizationRecord(id='18305455', status='ERROR')
# OptimizationRecord(id='18305456', status='ERROR')
# OptimizationRecord(id='18305457', status='ERROR')
# OptimizationRecord(id='18305458', status='ERROR')
# OptimizationRecord(id='18305459', status='ERROR')
# OptimizationRecord(id='18305460', status='ERROR')
# OptimizationRecord(id='18305461', status='ERROR')
# OptimizationRecord(id='18305462', status='ERROR')
# OptimizationRecord(id='18305463', status='ERROR')
# OptimizationRecord(id='18305464', status='ERROR')
# OptimizationRecord(id='18305465', status='ERROR')
# OptimizationRecord(id='18305467', status='ERROR')
# OptimizationRecord(id='18308485', status='ERROR')
# OptimizationRecord(id='18308486', status='ERROR')
# OptimizationRecord(id='18308497', status='ERROR')
# OptimizationRecord(id='18308501', status='ERROR')
# OptimizationRecord(id='18308502', status='ERROR')
# OptimizationRecord(id='18308503', status='ERROR')
# OptimizationRecord(id='18308504', status='ERROR')
# OptimizationRecord(id='18308506', status='ERROR')
# OptimizationRecord(id='18308509', status='ERROR')
# OptimizationRecord(id='18308511', status='ERROR')
# OptimizationRecord(id='18308512', status='ERROR')
# OptimizationRecord(id='18308513', status='ERROR')
# OptimizationRecord(id='18308514', status='ERROR')
# OptimizationRecord(id='18308515', status='ERROR')
# OptimizationRecord(id='18308516', status='ERROR')
# OptimizationRecord(id='18308517', status='ERROR')
# OptimizationRecord(id='18308518', status='ERROR')
# OptimizationRecord(id='18308520', status='ERROR')
# OptimizationRecord(id='18308521', status='ERROR')
# OptimizationRecord(id='18308522', status='ERROR')
# OptimizationRecord(id='18308523', status='ERROR')
# OptimizationRecord(id='18308524', status='ERROR')
# OptimizationRecord(id='18308526', status='ERROR')
# OptimizationRecord(id='18308527', status='ERROR')
# OptimizationRecord(id='18308528', status='ERROR')
# OptimizationRecord(id='18308529', status='ERROR')
# OptimizationRecord(id='18308530', status='ERROR')
# OptimizationRecord(id='18308531', status='ERROR')
# OptimizationRecord(id='18308532', status='ERROR')
# OptimizationRecord(id='18308534', status='ERROR')
# OptimizationRecord(id='18308535', status='ERROR')
# OptimizationRecord(id='18308536', status='ERROR')
# OptimizationRecord(id='18308537', status='ERROR')
# OptimizationRecord(id='18308538', status='ERROR')
# OptimizationRecord(id='18308539', status='ERROR')
# OptimizationRecord(id='18308540', status='ERROR')
# OptimizationRecord(id='18308541', status='ERROR')
# OptimizationRecord(id='18308542', status='ERROR')
# OptimizationRecord(id='18308543', status='ERROR')
# OptimizationRecord(id='18308544', status='ERROR')
# OptimizationRecord(id='18308546', status='ERROR')
# OptimizationRecord(id='18308547', status='ERROR')
# OptimizationRecord(id='18308548', status='ERROR')
# OptimizationRecord(id='18308550', status='ERROR')
# OptimizationRecord(id='18308551', status='ERROR')
# OptimizationRecord(id='18308552', status='ERROR')
# OptimizationRecord(id='18308553', status='ERROR')
# OptimizationRecord(id='18308554', status='ERROR')
# OptimizationRecord(id='18308556', status='ERROR')
# OptimizationRecord(id='18308557', status='ERROR')
# OptimizationRecord(id='18308558', status='ERROR')
# OptimizationRecord(id='18308559', status='ERROR')
# OptimizationRecord(id='18308560', status='ERROR')
# OptimizationRecord(id='18308561', status='ERROR')
# OptimizationRecord(id='18308562', status='ERROR')
# OptimizationRecord(id='18308563', status='ERROR')
# OptimizationRecord(id='18308564', status='ERROR')
# OptimizationRecord(id='18308566', status='ERROR')
# OptimizationRecord(id='18308568', status='ERROR')
# OptimizationRecord(id='18309833', status='ERROR')
# OptimizationRecord(id='18309834', status='ERROR')
# OptimizationRecord(id='18309860', status='ERROR')
# OptimizationRecord(id='18309861', status='ERROR')
# OptimizationRecord(id='18309862', status='ERROR')
# OptimizationRecord(id='18309867', status='ERROR')
# OptimizationRecord(id='18309875', status='ERROR')
# OptimizationRecord(id='18309876', status='ERROR')
# OptimizationRecord(id='18309878', status='ERROR')
# OptimizationRecord(id='18309879', status='ERROR')
# OptimizationRecord(id='18309880', status='ERROR')
# OptimizationRecord(id='18309881', status='ERROR')
# OptimizationRecord(id='18309882', status='ERROR')
# OptimizationRecord(id='18309883', status='ERROR')
# OptimizationRecord(id='18309886', status='ERROR')
# OptimizationRecord(id='18309887', status='ERROR')
# OptimizationRecord(id='18309888', status='ERROR')
# OptimizationRecord(id='18309889', status='ERROR')
# OptimizationRecord(id='18309891', status='ERROR')
# OptimizationRecord(id='18309907', status='ERROR')
# OptimizationRecord(id='18309908', status='ERROR')
# OptimizationRecord(id='18309913', status='ERROR')
# OptimizationRecord(id='18309914', status='ERROR')
# OptimizationRecord(id='18309915', status='ERROR')
# OptimizationRecord(id='18309916', status='ERROR')
# OptimizationRecord(id='18309918', status='ERROR')
# OptimizationRecord(id='18309919', status='ERROR')
# OptimizationRecord(id='18309921', status='ERROR')
# OptimizationRecord(id='18309930', status='ERROR')
# OptimizationRecord(id='18309934', status='ERROR')
# OptimizationRecord(id='18309935', status='ERROR')
# OptimizationRecord(id='18309936', status='ERROR')
# OptimizationRecord(id='18309937', status='ERROR')
# OptimizationRecord(id='18309938', status='ERROR')
# OptimizationRecord(id='18309940', status='ERROR')
# OptimizationRecord(id='18309944', status='ERROR')
# OptimizationRecord(id='18309945', status='ERROR')
# OptimizationRecord(id='18309946', status='ERROR')
# OptimizationRecord(id='18309947', status='ERROR')
# OptimizationRecord(id='18309950', status='ERROR')
# OptimizationRecord(id='18309952', status='ERROR')
# OptimizationRecord(id='18309954', status='ERROR')
# OptimizationRecord(id='18309955', status='ERROR')
# OptimizationRecord(id='18309956', status='ERROR')
# OptimizationRecord(id='18309957', status='ERROR')
# OptimizationRecord(id='18309969', status='ERROR')
# OptimizationRecord(id='18309973', status='ERROR')
# OptimizationRecord(id='18309974', status='ERROR')
# OptimizationRecord(id='18309975', status='ERROR')
# OptimizationRecord(id='18309976', status='ERROR')
# OptimizationRecord(id='18309977', status='ERROR')
# OptimizationRecord(id='18309978', status='ERROR')
# OptimizationRecord(id='18309979', status='ERROR')
# OptimizationRecord(id='18309981', status='ERROR')
# OptimizationRecord(id='18309982', status='ERROR')
# OptimizationRecord(id='18309986', status='ERROR')
# OptimizationRecord(id='18309987', status='ERROR')
# OptimizationRecord(id='18309988', status='ERROR')
# OptimizationRecord(id='18309989', status='ERROR')
# OptimizationRecord(id='18309990', status='ERROR')
# OptimizationRecord(id='18309991', status='ERROR')
# OptimizationRecord(id='18309992', status='ERROR')
# OptimizationRecord(id='18309993', status='ERROR')
# OptimizationRecord(id='18310000', status='ERROR')
# OptimizationRecord(id='18310001', status='ERROR')
# OptimizationRecord(id='18310002', status='ERROR')
# OptimizationRecord(id='18310006', status='ERROR')
# OptimizationRecord(id='18310007', status='ERROR')
# OptimizationRecord(id='18310008', status='ERROR')
# OptimizationRecord(id='18310009', status='ERROR')
# OptimizationRecord(id='18310012', status='ERROR')
# OptimizationRecord(id='18310013', status='ERROR')
# OptimizationRecord(id='18310014', status='ERROR')
# OptimizationRecord(id='18310016', status='ERROR')
# OptimizationRecord(id='18310017', status='ERROR')
# OptimizationRecord(id='18310021', status='ERROR')
# OptimizationRecord(id='18310023', status='ERROR')
# OptimizationRecord(id='18310025', status='ERROR')
# OptimizationRecord(id='18310026', status='ERROR')
# OptimizationRecord(id='18310027', status='ERROR')
# OptimizationRecord(id='18310028', status='ERROR')
# OptimizationRecord(id='18310029', status='ERROR')
# OptimizationRecord(id='18310030', status='ERROR')
# OptimizationRecord(id='18310031', status='ERROR')
# OptimizationRecord(id='18310032', status='ERROR')
# OptimizationRecord(id='18310034', status='ERROR')
# OptimizationRecord(id='18310037', status='ERROR')
# OptimizationRecord(id='18310038', status='ERROR')
# OptimizationRecord(id='18310042', status='ERROR')
# OptimizationRecord(id='18310043', status='ERROR')
# OptimizationRecord(id='18310044', status='ERROR')
# OptimizationRecord(id='18310045', status='ERROR')
# OptimizationRecord(id='18310047', status='ERROR')
# OptimizationRecord(id='18310048', status='ERROR')
# OptimizationRecord(id='18310050', status='ERROR')
# OptimizationRecord(id='18310051', status='ERROR')
# OptimizationRecord(id='18310052', status='ERROR')
# OptimizationRecord(id='18310053', status='ERROR')
# OptimizationRecord(id='18310055', status='ERROR')
# OptimizationRecord(id='18310056', status='ERROR')
# OptimizationRecord(id='18310058', status='ERROR')
# OptimizationRecord(id='18310059', status='ERROR')
# OptimizationRecord(id='18310060', status='ERROR')
# OptimizationRecord(id='18310061', status='ERROR')
# OptimizationRecord(id='18310062', status='ERROR')
# OptimizationRecord(id='18310063', status='ERROR')
# OptimizationRecord(id='18310065', status='ERROR')
# OptimizationRecord(id='18310066', status='ERROR')
# OptimizationRecord(id='18310067', status='ERROR')
# OptimizationRecord(id='18310068', status='ERROR')
# OptimizationRecord(id='18310069', status='ERROR')
# OptimizationRecord(id='18310070', status='ERROR')
# OptimizationRecord(id='18310072', status='ERROR')
# OptimizationRecord(id='18310073', status='ERROR')
# OptimizationRecord(id='18310074', status='ERROR')
# OptimizationRecord(id='18310076', status='ERROR')
# OptimizationRecord(id='18310079', status='ERROR')
# OptimizationRecord(id='18310080', status='ERROR')
# OptimizationRecord(id='18310081', status='ERROR')
# OptimizationRecord(id='18310082', status='ERROR')
# OptimizationRecord(id='18310083', status='ERROR')
# OptimizationRecord(id='18310084', status='ERROR')
# OptimizationRecord(id='18310085', status='ERROR')
# OptimizationRecord(id='18310086', status='ERROR')
# OptimizationRecord(id='18432401', status='ERROR')
# OptimizationRecord(id='18316242', status='ERROR')
# OptimizationRecord(id='18316244', status='ERROR')
# OptimizationRecord(id='18316249', status='ERROR')
# OptimizationRecord(id='18316252', status='ERROR')
# OptimizationRecord(id='18316254', status='ERROR')
# OptimizationRecord(id='18316255', status='ERROR')
# OptimizationRecord(id='18316258', status='ERROR')
# OptimizationRecord(id='18316262', status='ERROR')
# OptimizationRecord(id='18316267', status='ERROR')
# OptimizationRecord(id='18316269', status='ERROR')
# OptimizationRecord(id='18316270', status='ERROR')
# OptimizationRecord(id='18316271', status='ERROR')
# OptimizationRecord(id='18316273', status='ERROR')
# OptimizationRecord(id='18316274', status='ERROR')
# OptimizationRecord(id='18316278', status='ERROR')
# OptimizationRecord(id='18316279', status='ERROR')
# OptimizationRecord(id='18316282', status='ERROR')
# OptimizationRecord(id='18316284', status='ERROR')
# OptimizationRecord(id='18316285', status='ERROR')
# OptimizationRecord(id='18316290', status='ERROR')
# OptimizationRecord(id='18316294', status='ERROR')
# OptimizationRecord(id='18316301', status='ERROR')
# OptimizationRecord(id='18316305', status='ERROR')
# OptimizationRecord(id='18316306', status='ERROR')
# OptimizationRecord(id='18316308', status='ERROR')
# OptimizationRecord(id='18316317', status='ERROR')
# OptimizationRecord(id='18316319', status='ERROR')
# OptimizationRecord(id='18316321', status='ERROR')
# OptimizationRecord(id='18316332', status='ERROR')
# OptimizationRecord(id='18316334', status='ERROR')
# OptimizationRecord(id='18316353', status='ERROR')
# OptimizationRecord(id='18316374', status='ERROR')
# OptimizationRecord(id='18316375', status='ERROR')
# OptimizationRecord(id='18316377', status='ERROR')
# OptimizationRecord(id='18316384', status='ERROR')
# OptimizationRecord(id='18316390', status='ERROR')
# OptimizationRecord(id='18316394', status='ERROR')
# OptimizationRecord(id='18316395', status='ERROR')
# OptimizationRecord(id='18319486', status='ERROR')
# OptimizationRecord(id='18319487', status='ERROR')
# OptimizationRecord(id='18319490', status='ERROR')
# OptimizationRecord(id='18319491', status='ERROR')
# OptimizationRecord(id='18319492', status='ERROR')
# OptimizationRecord(id='18319496', status='ERROR')
# OptimizationRecord(id='18319501', status='ERROR')
# OptimizationRecord(id='18319502', status='ERROR')
# OptimizationRecord(id='18319504', status='ERROR')
# OptimizationRecord(id='18319507', status='ERROR')
# OptimizationRecord(id='18319508', status='ERROR')
# OptimizationRecord(id='18319509', status='ERROR')
# OptimizationRecord(id='18319510', status='ERROR')
# OptimizationRecord(id='18319511', status='ERROR')
# OptimizationRecord(id='18319512', status='ERROR')
# OptimizationRecord(id='18319513', status='ERROR')
# OptimizationRecord(id='18319519', status='ERROR')
# OptimizationRecord(id='18319523', status='ERROR')
# OptimizationRecord(id='18319524', status='ERROR')
# OptimizationRecord(id='18319527', status='ERROR')
# OptimizationRecord(id='18319529', status='ERROR')
# OptimizationRecord(id='18319746', status='ERROR')
# OptimizationRecord(id='18319747', status='ERROR')
# OptimizationRecord(id='18319748', status='ERROR')
# OptimizationRecord(id='18319749', status='ERROR')
# OptimizationRecord(id='18319750', status='ERROR')
# OptimizationRecord(id='18319751', status='ERROR')
# OptimizationRecord(id='18319752', status='ERROR')
# OptimizationRecord(id='18319753', status='ERROR')
# OptimizationRecord(id='18319754', status='ERROR')
# OptimizationRecord(id='18319755', status='ERROR')
# OptimizationRecord(id='18319756', status='ERROR')
# OptimizationRecord(id='18319757', status='ERROR')
# OptimizationRecord(id='18319758', status='ERROR')
# OptimizationRecord(id='18319759', status='ERROR')
# OptimizationRecord(id='18319761', status='ERROR')
# OptimizationRecord(id='18319762', status='ERROR')
# OptimizationRecord(id='18319763', status='ERROR')

# %%
restart_torsiondrives(ds.df.default.tolist(), client)
# Out:
# TorsionDriveRecord(id='18045852', status='ERROR')
# TorsionDriveRecord(id='18045856', status='ERROR')
# TorsionDriveRecord(id='18045864', status='ERROR')
# TorsionDriveRecord(id='18045865', status='ERROR')
# TorsionDriveRecord(id='18045870', status='ERROR')
# TorsionDriveRecord(id='18045875', status='ERROR')
# TorsionDriveRecord(id='18045879', status='ERROR')
# TorsionDriveRecord(id='18045886', status='ERROR')
# TorsionDriveRecord(id='18045891', status='ERROR')
# TorsionDriveRecord(id='18045896', status='ERROR')
# TorsionDriveRecord(id='18045901', status='ERROR')
# TorsionDriveRecord(id='18045902', status='ERROR')
# TorsionDriveRecord(id='18045905', status='ERROR')
# TorsionDriveRecord(id='18045909', status='ERROR')
# TorsionDriveRecord(id='18045910', status='ERROR')
# TorsionDriveRecord(id='18045912', status='ERROR')
# TorsionDriveRecord(id='18045913', status='ERROR')
# TorsionDriveRecord(id='18045916', status='ERROR')
# TorsionDriveRecord(id='18045917', status='ERROR')
# TorsionDriveRecord(id='18045920', status='ERROR')
# TorsionDriveRecord(id='18045921', status='ERROR')
# TorsionDriveRecord(id='18045925', status='ERROR')
# TorsionDriveRecord(id='18045929', status='ERROR')
# TorsionDriveRecord(id='18045930', status='ERROR')
# TorsionDriveRecord(id='18045937', status='ERROR')
# TorsionDriveRecord(id='18045941', status='ERROR')
# TorsionDriveRecord(id='18045942', status='ERROR')
# TorsionDriveRecord(id='18045948', status='ERROR')
# TorsionDriveRecord(id='18045953', status='ERROR')
# TorsionDriveRecord(id='18045956', status='ERROR')
# TorsionDriveRecord(id='18045959', status='ERROR')
# TorsionDriveRecord(id='18045960', status='ERROR')
# TorsionDriveRecord(id='18045964', status='ERROR')
# TorsionDriveRecord(id='18045965', status='ERROR')
# TorsionDriveRecord(id='18045966', status='ERROR')
# TorsionDriveRecord(id='18045967', status='ERROR')
# TorsionDriveRecord(id='18045969', status='ERROR')

# %% [markdown]
# ## Dataset tracking - OpenFF Gen 2 Torsion Set 6 supplemental

# %% [markdown]
# ### 2020.06.11 22:45 UTC

# %%
dataset = "OpenFF Gen 2 Torsion Set 6 supplemental"

# %%
ds = client.get_collection("TorsionDriveDataset", dataset)

# %%
ds.list_specifications()
# Out:
#                                          Description
# Name
# default  Standard OpenFF torsiondrive specification.

# %%
res = get_unfinished_torsiondrive_optimizations(ds, 'default', client, merged=False)
res
# Out:
# {'18046187': [OptimizationRecord(id='18324676', status='COMPLETE'),
#   OptimizationRecord(id='18324677', status='COMPLETE'),
#   OptimizationRecord(id='18324678', status='COMPLETE'),
#   OptimizationRecord(id='18358328', status='COMPLETE'),
#   OptimizationRecord(id='18358329', status='COMPLETE'),
#   OptimizationRecord(id='18366513', status='COMPLETE'),
#   OptimizationRecord(id='18366514', status='COMPLETE'),
#   OptimizationRecord(id='18366515', status='COMPLETE'),
#   OptimizationRecord(id='18366516', status='COMPLETE'),
#   OptimizationRecord(id='18383325', status='ERROR'),
#   OptimizationRecord(id='18383326', status='COMPLETE'),
#   OptimizationRecord(id='18383327', status='COMPLETE'),
#   OptimizationRecord(id='18383328', status='COMPLETE')]}

# %%
resm = merge(res)

# %%
incomplete = (opt.dict() for opt in resm if opt.status == 'INCOMPLETE')

# %%
next(incomplete)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-11-3729b8af7b87> in <module>
# ----> 1 next(incomplete)
#
# StopIteration:

# %% [markdown]
# Yay!

# %%
count_unique_optimization_error_messages(resm, pretty_print=True)
# Out:
# There are 1 instances of
# -------------------------------------
# numpy.linalg.LinAlgError: Eigenvalues did not converge
# -------------------------------------

# %%
restart_optimizations(resm, client)
# Out:
# OptimizationRecord(id='18383325', status='ERROR')

# %%
restart_torsiondrives(ds.df.default.tolist(), client)
# Out:
# TorsionDriveRecord(id='18046187', status='ERROR')
