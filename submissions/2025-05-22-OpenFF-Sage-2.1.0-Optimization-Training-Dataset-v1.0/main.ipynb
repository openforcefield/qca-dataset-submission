# %%
import json
import requests
import datetime
from collections import Counter, defaultdict

import numpy as np
from deepdiff import DeepDiff
import periodictable

from qcportal import PortalClient
from qcportal.external import scaffold
from qcportal.serialization import encode_to_json
from qcportal.optimization import OptimizationDatasetEntry
from qcportal.torsiondrive import TorsiondriveDatasetEntry
DatasetEntry = {"optimization": OptimizationDatasetEntry, "torsiondrive": TorsiondriveDatasetEntry}

ADDRESS = "https://api.qcarchive.molssi.org:443/"
client = PortalClient(ADDRESS, cache_dir=".")

# %% [markdown]
# # Get Records and Molecular Statistics

# %%
# _________ Pull Record IDs of Relevant Datasets ____________
print("Getting record ids")

file = requests.get(
    "https://raw.githubusercontent.com/openforcefield/sage-2.1.0/8d196aa104f83b8c901d922073ee68b875ae8c32/inputs-and-outputs/data-sets/opt-set-for-fitting-2.1.0.json"
)
data = json.loads(file.content)
provenance = data["provenance"]
# list with: {type, record_id, cmiles, inchi_key}
entry_dicts = data["entries"][ADDRESS]
dataset_type = entry_dicts[0]["type"]
# Out:
# Getting record ids

# %%
# _________ Get Records ____________
print("Getting records")
records = client.get_records([int(x["record_id"]) for x in entry_dicts], missing_ok=False)
# Out:
# Getting records

# %%
cmiles_by_record_id = {
    int(x["record_id"]): {"cmiles": x["cmiles"], "mol": None} 
    for x in entry_dicts
}
for record in records:
    cmiles_by_record_id[record.id]["mol"] = record.initial_molecule
    
cmiles_count = defaultdict(Counter)
molecules = []
for recid, x in cmiles_by_record_id.items():
    cmiles = x["cmiles"]

    if cmiles not in cmiles_count:
        molecules.append(x["mol"])
    hash = x["mol"].get_hash()
    cmiles_count[cmiles][hash] += 1
    
print(f"There are {len(records)} records (conformers) and {len(cmiles_count)} unique SMILES strings (unique molecules)")
# Out:
# There are 5580 records (conformers) and 1701 unique SMILES strings (unique molecules)

# %%
# _________ Pull Statistics from Dataset ____________
     
print("Generating Molecular Statistics")

lx = len(cmiles_count)
n_confs, n_heavy_atoms, masses, unique_charges = np.zeros(lx), [], np.zeros(lx), np.zeros(lx)
elements = []
for i, (cmiles, hashes) in enumerate(cmiles_count.items()):
    n_confs[i] = len(hashes)
    n_heavy_atoms.append(len([x for x in molecules[i].symbols if x != "H"]))
    elements.extend(list(set([x for x in molecules[i].symbols])))
    masses[i] = sum([getattr(periodictable, x).mass for x in molecules[i].symbols])
    unique_charges[i] = molecules[i].molecular_charge
    
unique_charges = sorted(set(unique_charges))

elements = sorted(list(set(elements)))
# Out:
# Generating Molecular Statistics

# %%
# _________ Write Output Part 1 (Run Before Approval) ____________

print("\n# Heavy Atom Counts")
counts1 = Counter(n_heavy_atoms)
for n_heavy in sorted(counts1):
    print(f"{str(n_heavy):>3}: {counts1[n_heavy]}")

print("* Number of unique molecules: {}".format(len(cmiles_count)))
print("* Number of conformers:", int(sum(n_confs)))
print(
    "* Number of conformers (min, mean, max): {:.2f}, {:.2f}, {:.2f}".format(
        min(n_confs), np.mean(n_confs), max(n_confs)
    )
)
print(
    "* Molecular weight (min, mean, max): {:.2f}, {:.2f}, {:.2f}".format(
        min(masses), np.mean(masses), max(masses)
    )
)
print("* Charges: {}".format(", ".join([str(x) for x in unique_charges])))
# Out:
# # Heavy Atom Counts
#   1: 1
#   2: 3
#   3: 4
#   4: 9
#   5: 15
#   6: 19
#   7: 33
#   8: 63
#   9: 73
#  10: 125
#  11: 152
#  12: 153
#  13: 151
#  14: 130
#  15: 137
#  16: 74
#  17: 73
#  18: 56
#  19: 51
#  20: 41
#  21: 47
#  22: 33
#  23: 29
#  24: 24
#  25: 32
#  26: 7
#  27: 14
#  28: 17
#  29: 14
#  30: 9
#  31: 21
#  32: 21
#  33: 13
#  34: 12
#  35: 5
#  36: 18
#  37: 8
#  38: 9
#  39: 5
# * Number of unique molecules: 1701
# * Number of conformers: 5385
# * Number of conformers (min, mean, max): 1.00, 3.17, 17.00
# * Molecular weight (min, mean, max): 16.04, 235.40, 544.64
# * Charges: -3.0, -2.0, -1.0, 0.0, 1.0, 2.0

# %% [markdown]
# # Validate Inter-database Record Entry Names and Specifications

# %%
# Get Dataset Ids of Interest:
dataset_names = [
    "OpenFF Gen 2 Opt Set 1 Roche",
    "OpenFF Gen 2 Opt Set 2 Coverage",
    "OpenFF Gen 2 Opt Set 3 Pfizer Discrepancy",
    "OpenFF Gen 2 Opt Set 4 eMolecules Discrepancy",
    "OpenFF Gen 2 Opt Set 5 Bayer",
    "OpenFF Gen2 Optimization Dataset Protomers v1.0",
    "OpenFF Iodine Chemistry Optimization Dataset v1.0",
    "OpenFF Optimization Set 1",
    "SMIRNOFF Coverage Set 1",
    "OpenFF Aniline Para Opt v1.0",
]
dataset_ids = [client.get_dataset(dataset_type, ds_name).id for ds_name in dataset_names]
print(f"We expect our records to come from the following datasets: {dataset_ids}")

record_ids = set([int(x["record_id"]) for x in entry_dicts])
tmp_ds_ids1 = []
wrong_ds1 = defaultdict(list)
for rec_id in record_ids:
    response = client.query_dataset_records(record_id=[rec_id])
    ds_name = None
    for resp in response:
        if resp["dataset_name"] in dataset_names:
            tmp_ds_ids1.append(resp["dataset_name"])
            ds_name = resp["dataset_name"]
    if ds_name is None:
        wrong_ds1[rec_id] = [resp["dataset_name"] for resp in response]
tmp_ds_ids1 = set(tmp_ds_ids1)
print(f"There are {len(wrong_ds1)} records that aren't in the datasets that we expect.")
# Out:
# We expect our records to come from the following datasets: [251, 253, 255, 254, 270, 345, 372, 41, 43, 315]
# There are 0 records that aren't in the datasets that we expect.

# %%
# __________ Check that all records share a single specification __________
specification_list = []
for rec in records:
    tmp = encode_to_json(rec.specification)
    if all(len(DeepDiff(tmp, x)) > 0 for x in specification_list) or not specification_list:
        specification_list.append(tmp)
        
print(f"These records have {len(specification_list)} unique specifications")
# Out:
# These records have 5 unique specifications

# %%
specification_ds_ids = [[] for _ in range(len(specification_list))]
for ds_name in dataset_names:
    tmp_ds = client.get_dataset(dataset_type, ds_name)
    spec = encode_to_json(tmp_ds.specifications["default"].specification)
    for i, ref_spec in enumerate(specification_list):
        if len(DeepDiff(spec, ref_spec)) == 0:
            specification_ds_ids[i].append(tmp_ds.id)
            break
print(f"The follow datasets (represented by their ids) share a spec: {specification_ds_ids}")
# Out:
# The follow datasets (represented by their ids) share a spec: [[251, 253, 255, 254, 270], [345], [372, 315], [41], [43]]

# %%
# Determine if multiple datasets have entries with the same name
entry_dict = defaultdict(lambda: defaultdict(list))
for rec in records:
    response = client.query_dataset_records(record_id=[rec.id])
    for resp in response:
        if resp["dataset_name"] != "OpenFF Sage 2.0.0 Torsion Drive Training Dataset v1.0":
            entry_dict[resp["entry_name"]]["orig records"].append((rec.id, resp["dataset_name"]))
        
print("Entry names representing different records when in different datasets.")
repeat_entry_names = defaultdict(list)
for entry_name, tmp_record_dict in entry_dict.items():
    tmp = tmp_record_dict["orig records"]
    if len(tmp) > 1: # entry name is in multiple datasets
        tmp_dict = defaultdict(list)
        for x in tmp:
            tmp_dict[x[0]].append(x[1])
        if len(tmp_dict) > 1: # entry name is assigned to multiple different records
            print(len(tmp), entry_name)
            for rec_id, tmp_ds_names in tmp_dict.items():
                repeat_entry_names[entry_name].append(rec_id)
                print("    ", rec_id, tmp_ds_names)
print("We will rename all of these entry names later to include their respective dataset id of origin.")
# Out:
# Entry names representing different records when in different datasets.
# 3 cn1c(cccc1=o)c2ccccc2oc-1
#      18433007 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760571 ['OpenFF Optimization Set 1']
# 3 c1cc(c(=o)[nh]c1)cn2cc[nh2+]cc2-1
#      18433009 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760625 ['OpenFF Optimization Set 1']
# 3 cc(c)s(=o)(=o)c1cccs1-1
#      18433011 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760116 ['OpenFF Optimization Set 1']
# 3 cc1ccccc1oc2ccccc2-1
#      18433014 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760526 ['OpenFF Optimization Set 1']
# 3 cc1ccccc1s(=o)(=o)n(c)c-1
#      18433016 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760532 ['OpenFF Optimization Set 1']
# 3 cc1ccccc1c2ccccc2c3ccccc3-1
#      18433018 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760541 ['OpenFF Optimization Set 1']
# 3 c1ccc(cc1)coc2ccccc2-1
#      18433020 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760736 ['OpenFF Optimization Set 1']
# 3 cc1ccccc1c(=o)c2ccccc2f-5
#      18433026 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760493 ['OpenFF Optimization Set 1']
# 3 cc1ccccc1c(=o)c2ccccc2f-3
#      18433024 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760491 ['OpenFF Optimization Set 1']
# 3 cc1ccccc1c(=o)c2ccccc2f-6
#      18433027 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760494 ['OpenFF Optimization Set 1']
# 3 cc1ccccc1c(=o)c2ccccc2f-2
#      18433023 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760490 ['OpenFF Optimization Set 1']
# 3 cc1ccccc1c(=o)c2ccccc2f-4
#      18433025 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760492 ['OpenFF Optimization Set 1']
# 3 cc1ccccc1c(=o)c2ccccc2f-1
#      18433022 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760489 ['OpenFF Optimization Set 1']
# 3 c1ccc(cc1)c[n@@]2ccccs2(=o)=o-4
#      18433033 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760744 ['OpenFF Optimization Set 1']
# 3 c1ccc(cc1)c[n@@]2ccccs2(=o)=o-3
#      18433032 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760743 ['OpenFF Optimization Set 1']
# 3 c1ccc(cc1)c[n@@]2ccccs2(=o)=o-1
#      18433030 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760741 ['OpenFF Optimization Set 1']
# 3 cc1ccccc1c(=o)n2ccccc2-1
#      18433036 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760485 ['OpenFF Optimization Set 1']
# 3 c1ccc(cc1)c2ccccc2[c@h]3cccc(=o)n3-1
#      18433040 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760837 ['OpenFF Optimization Set 1']
# 3 c1cc1(co)o-2
#      18433049 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760031 ['OpenFF Optimization Set 1']
# 3 c1cc1(co)o-1
#      18433048 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760030 ['OpenFF Optimization Set 1']
# 3 cn1ccc(c1c(=o)n(c)c)o-1
#      18433051 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760578 ['OpenFF Optimization Set 1']
# 3 c1ccc(cc1)cn2ccnc2-1
#      18433054 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760753 ['OpenFF Optimization Set 1']
# 3 c[c@@h](c1ccccc1)oc2ccccc2-2
#      18433060 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760422 ['OpenFF Optimization Set 1']
# 3 c[c@@h](c1ccccc1)oc2ccccc2-3
#      18433061 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760423 ['OpenFF Optimization Set 1']
# 3 c[c@@h](c1ccccc1)oc2ccccc2-1
#      18433059 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760421 ['OpenFF Optimization Set 1']
# 3 cc1ccccc1c(=o)c2ccccc2-1
#      18433064 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760487 ['OpenFF Optimization Set 1']
# 3 cc[n@@]1ccccs1(=o)=o-1
#      18433066 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760162 ['OpenFF Optimization Set 1']
# 3 cs(=o)(=o)cc1ccccc1-2
#      18433085 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760401 ['OpenFF Optimization Set 1']
# 3 cs(=o)(=o)cc1ccccc1-1
#      18433084 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760400 ['OpenFF Optimization Set 1']
# 3 cc1ccccc1coc2ccccc2-1
#      18433089 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760512 ['OpenFF Optimization Set 1']
# 3 cc1ccccc1coc2ccccc2-2
#      18433090 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760513 ['OpenFF Optimization Set 1']
# 3 cn(c)s(=o)(=o)c1ccccn1-1
#      18433115 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760221 ['OpenFF Optimization Set 1']
# 3 c1ccc(c(c1)o)oc2ccccn2-4
#      18433124 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1683360 ['OpenFF Optimization Set 1']
# 3 c1ccc(c(c1)o)oc2ccccn2-2
#      18433122 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760671 ['OpenFF Optimization Set 1']
# 3 c1ccc(c(c1)o)oc2ccccn2-3
#      18433123 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760672 ['OpenFF Optimization Set 1']
# 3 c1ccc(c(c1)o)oc2ccccn2-1
#      18433121 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760670 ['OpenFF Optimization Set 1']
# 3 c1ccc(c(c1)o)oc2ccccn2-5
#      18433125 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760673 ['OpenFF Optimization Set 1']
# 3 cc1ccnn1c2ccccc2oc-1
#      18433127 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760559 ['OpenFF Optimization Set 1']
# 3 c1ccnc(c1)c2ccccn2-1
#      18433130 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760914 ['OpenFF Optimization Set 1']
# 3 c1ccc(cc1)c(=o)n2ccccc2-1
#      18433132 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760690 ['OpenFF Optimization Set 1']
# 3 cc1=ncc(=o)n(c2c1cccc2)c-1
#      18433135 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760136 ['OpenFF Optimization Set 1']
# 3 c1ccnc(c1)c2ncco2-1
#      18433144 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760918 ['OpenFF Optimization Set 1']
# 3 c1ccc(cc1)cnc2ccccc2-2
#      18433150 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760734 ['OpenFF Optimization Set 1']
# 3 c1ccc(cc1)cnc2ccccc2-1
#      18433149 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760733 ['OpenFF Optimization Set 1']
# 3 c1ccc2c(c1)cccnc2=o-1
#      18433152 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760857 ['OpenFF Optimization Set 1']
# 3 cn(c)c(=o)[c@h](c1ccccc1)oc-2
#      18433156 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760191 ['OpenFF Optimization Set 1']
# 3 cn(c)c(=o)[c@h](c1ccccc1)oc-1
#      18433155 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760190 ['OpenFF Optimization Set 1']
# 3 coc1ccccc1nc(=o)nc2ccccn2-3
#      18433160 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760382 ['OpenFF Optimization Set 1']
# 3 coc1ccccc1nc(=o)nc2ccccn2-5
#      18433162 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760384 ['OpenFF Optimization Set 1']
# 3 coc1ccccc1nc(=o)nc2ccccn2-4
#      18433161 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760383 ['OpenFF Optimization Set 1']
# 3 coc1ccccc1nc(=o)nc2ccccn2-1
#      18433158 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760380 ['OpenFF Optimization Set 1']
# 3 coc1ccccc1nc(=o)nc2ccccn2-2
#      18433159 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760381 ['OpenFF Optimization Set 1']
# 3 c[c@h](c1ccccc1)s(=o)(=o)c-1
#      18433167 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760446 ['OpenFF Optimization Set 1']
# 3 c[c@h](c1ccccc1)s(=o)(=o)c-2
#      18433168 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760447 ['OpenFF Optimization Set 1']
# 3 c1ccc(cc1)c2=ncc(=o)nc3c2cccc3-1
#      18433170 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760719 ['OpenFF Optimization Set 1']
# 3 cc(=o)c1ccccc1f-1
#      18433189 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760104 ['OpenFF Optimization Set 1']
# 3 c1ccc(c(c1)c2ccccn2)c3ncco3-1
#      18433191 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760682 ['OpenFF Optimization Set 1']
# 3 c1ccc(c(c1)c2ccccn2)c3ncco3-2
#      18433192 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760683 ['OpenFF Optimization Set 1']
# 3 cn(c)c(=o)c1cccc(=o)[nh]1-1
#      18433194 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760207 ['OpenFF Optimization Set 1']
# 3 c1ccc(cc1)c(=o)c2ccccc2o-1
#      18433197 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760709 ['OpenFF Optimization Set 1']
# 3 c1ccc(cc1)oc2ccccn2-2
#      18433200 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760819 ['OpenFF Optimization Set 1']
# 3 c1ccc(cc1)c2ccccc2c3cccc(=o)[nh]3-1
#      18433203 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760840 ['OpenFF Optimization Set 1']
# 3 coc1cccnc1n2cccn2-1
#      18433206 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760396 ['OpenFF Optimization Set 1']
# 3 c[c@@h]1ccccn1c(=o)c2ccccc2-1
#      18433208 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760430 ['OpenFF Optimization Set 1']
# 3 cc1ccccc1c2=ncc(=o)nc3c2cccc3-3
#      18433212 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760499 ['OpenFF Optimization Set 1']
# 3 cc1ccccc1c2=ncc(=o)nc3c2cccc3-1
#      18433210 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760497 ['OpenFF Optimization Set 1']
# 3 cc1ccccc1c2=ncc(=o)nc3c2cccc3-2
#      18433211 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760498 ['OpenFF Optimization Set 1']
# 3 cc(=o)c1ccccc1o-1
#      18433214 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760106 ['OpenFF Optimization Set 1']
# 3 cc1cccc2c1c(=o)nccc2-1
#      18433216 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760480 ['OpenFF Optimization Set 1']
# 3 cn(c)c(=o)c1ccc[nh]c1=o-1
#      18433221 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760205 ['OpenFF Optimization Set 1']
# 3 c1ccc(c(c1)c2ccccn2)n-1
#      18433224 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760676 ['OpenFF Optimization Set 1']
# 3 cnc(=o)c1c(cc[nh]1)o-1
#      18433226 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760303 ['OpenFF Optimization Set 1']
# 3 cn(c)c(=o)c1c(cc[nh]1)oc-1
#      18433229 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760201 ['OpenFF Optimization Set 1']
# 3 cn(c)c(=o)c1c(cc[nh]1)oc-2
#      18433230 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760202 ['OpenFF Optimization Set 1']
# 3 cn(c)c(=o)c1c(cc[nh]1)oc-3
#      18433231 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760203 ['OpenFF Optimization Set 1']
# 3 c1ccnc(c1)oc2ccccc2-2
#      18433236 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760908 ['OpenFF Optimization Set 1']
# 3 c1ccnc(c1)oc2ccccc2-1
#      18433234 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760907 ['OpenFF Optimization Set 1']
# 3 c1ccnc(c1)oc2ccccc2-3
#      18433238 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760909 ['OpenFF Optimization Set 1']
# 3 c1c(co1)(co)o-1
#      18433244 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760028 ['OpenFF Optimization Set 1']
# 3 c1ccc2c(c1)c(=ncc(=o)n2)c3ccccc3cl-2
#      18433251 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760853 ['OpenFF Optimization Set 1']
# 3 c1ccc2c(c1)c(=ncc(=o)n2)c3ccccc3cl-1
#      18433250 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760852 ['OpenFF Optimization Set 1']
# 3 c1ccc2c(c1)c(=ncc(=o)n2)c3ccccc3cl-3
#      18433252 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760854 ['OpenFF Optimization Set 1']
# 3 cc(=o)nc1ccccn1-1
#      18433254 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760075 ['OpenFF Optimization Set 1']
# 3 cc(=o)c1ccc[nh]c1=o-1
#      18433256 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760097 ['OpenFF Optimization Set 1']
# 3 cc(=o)oc1cccc(=o)[nh]1-1
#      18433258 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760086 ['OpenFF Optimization Set 1']
# 3 cn(c)c(=o)nc1ccccc1-1
#      18433260 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760186 ['OpenFF Optimization Set 1']
# 3 cnc(=o)c1cccc(=o)[nh]1-1
#      18433262 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760318 ['OpenFF Optimization Set 1']
# 3 c1ccc(cc1)c2=ncc(=o)nc3c2c(ccc3)f-1
#      18433265 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760717 ['OpenFF Optimization Set 1']
# 3 cc1ccnn1c2ccccc2f-1
#      18433268 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760557 ['OpenFF Optimization Set 1']
# 3 c1ccc(cc1)nc2ccccn2-1
#      18433271 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760792 ['OpenFF Optimization Set 1']
# 3 c1ccc(cc1)c(=o)nc2ncco2-3
#      18433287 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760699 ['OpenFF Optimization Set 1']
# 3 c1ccc(cc1)c(=o)nc2ncco2-1
#      18433274 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760697 ['OpenFF Optimization Set 1']
# 3 c1ccc(cc1)c(=o)nc2ncco2-2
#      18433286 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760698 ['OpenFF Optimization Set 1']
# 3 cn(c)s(=o)(=o)c1cccs1-1
#      18433290 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760224 ['OpenFF Optimization Set 1']
# 3 c1ccnc(c1)nc2ncco2-1
#      18433297 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760897 ['OpenFF Optimization Set 1']
# 3 c1ccnc(c1)nc2ncco2-2
#      18433298 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760898 ['OpenFF Optimization Set 1']
# 3 c1ccnc(c1)nc2ncco2-3
#      18433299 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760899 ['OpenFF Optimization Set 1']
# 3 c1ccc(cc1)nc2ncco2-1
#      18433303 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760794 ['OpenFF Optimization Set 1']
# 3 cc(=o)n(c)c1cccs1-1
#      18433309 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760048 ['OpenFF Optimization Set 1']
# 3 cc(=o)n(c)c1cccs1-3
#      18433311 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760050 ['OpenFF Optimization Set 1']
# 3 cc(=o)n(c)c1cccs1-2
#      18433310 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760049 ['OpenFF Optimization Set 1']
# 3 cn(c)c(=o)c1cccs1-1
#      18433322 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760214 ['OpenFF Optimization Set 1']
# 3 cc(=o)ncc1nccn1c-3
#      18433326 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760066 ['OpenFF Optimization Set 1']
# 3 c1ccc(cc1)c2(cc2)nc3ccccc3-3
#      18433332 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760714 ['OpenFF Optimization Set 1']
# 3 c1ccc(cc1)c2(cc2)nc3ccccc3-1
#      18433330 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760712 ['OpenFF Optimization Set 1']
# 3 c1ccc(cc1)c2(cc2)nc3ccccc3-2
#      18433331 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760713 ['OpenFF Optimization Set 1']
# 3 c1ccc(cc1)s(=o)(=o)n2cccc2-1
#      18433335 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760824 ['OpenFF Optimization Set 1']
# 3 cnc(=o)c1c(ccn1c)cl-1
#      18433337 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1683541 ['OpenFF Optimization Set 1']
# 3 cc(=o)oc1cccc(=o)n1c-1
#      18433339 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760088 ['OpenFF Optimization Set 1']
# 3 c1cc(c(nc1)n2cccn2)f-1
#      18433342 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760633 ['OpenFF Optimization Set 1']
# 3 cc1ccccc1s(=o)(=o)c2ccccc2c-1
#      18433344 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760534 ['OpenFF Optimization Set 1']
# 3 cn(c)s(=o)(=o)c1ccccc1o-1
#      18433346 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760218 ['OpenFF Optimization Set 1']
# 3 cn(c)s(=o)(=o)c1ccccc1o-2
#      18433347 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760219 ['OpenFF Optimization Set 1']
# 3 c1ccc(c(c1)c[n@@]2ccccs2(=o)=o)o-9
#      18433361 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760667 ['OpenFF Optimization Set 1']
# 3 c1ccc(c(c1)c[n@@]2ccccs2(=o)=o)o-4
#      18433356 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760662 ['OpenFF Optimization Set 1']
# 3 c1ccc(c(c1)c[n@@]2ccccs2(=o)=o)o-5
#      18433357 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760663 ['OpenFF Optimization Set 1']
# 3 c1cc(c2c(c1)non2)c3c=cnc=c3-1
#      18433366 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760635 ['OpenFF Optimization Set 1']
# 3 c1cc(c2c(c1)non2)c3c=cnc=c3-2
#      18433367 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760636 ['OpenFF Optimization Set 1']
# 3 c1ccc(c(c1)c#n)nc(=o)nc2ccccn2-4
#      18433372 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760644 ['OpenFF Optimization Set 1']
# 3 c1ccc(c(c1)c#n)nc(=o)nc2ccccn2-1
#      18433369 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760641 ['OpenFF Optimization Set 1']
# 3 c1ccc(c(c1)c#n)nc(=o)nc2ccccn2-2
#      18433370 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760642 ['OpenFF Optimization Set 1']
# 3 c1ccc(c(c1)c#n)nc(=o)nc2ccccn2-3
#      18433371 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760643 ['OpenFF Optimization Set 1']
# 3 c1ccc(c(c1)c2c=cnc=c2)[n+](=o)[o-]-1
#      18433374 ['OpenFF Gen 2 Opt Set 1 Roche', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      1760657 ['OpenFF Optimization Set 1']
# 3 c1cc1nc(=o)c[n@@]2c[c@h](co2)o-0
#      18433463 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003302 ['SMIRNOFF Coverage Set 1']
# 3 c1cc1nc(=o)c[n@@]2c[c@h](co2)o-12
#      18433488 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003314 ['SMIRNOFF Coverage Set 1']
# 3 c1cc1nc(=o)c[n@@]2c[c@h](co2)o-13
#      18433489 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003315 ['SMIRNOFF Coverage Set 1']
# 3 c1cc1nc(=o)c[n@@]2c[c@h](co2)o-8
#      18433484 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003310 ['SMIRNOFF Coverage Set 1']
# 3 c[c@h]1c[n@@](s(=o)(=o)c1)[nh2+]c-0
#      18433490 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003396 ['SMIRNOFF Coverage Set 1']
# 3 cc[c@@h]1c[c@]1(c2ccc(nn2)oc)[nh3+]-0
#      18433491 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003352 ['SMIRNOFF Coverage Set 1']
# 3 cc[c@@h]1c[c@]1(c2ccc(nn2)oc)[nh3+]-2
#      18433493 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003354 ['SMIRNOFF Coverage Set 1']
# 3 c[c@]1(cc(=o)n1)c2[nh+]ccs2-0
#      18433494 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2002943 ['SMIRNOFF Coverage Set 1']
# 3 c[c@]1(cc(=o)n1)c2[nh+]ccs2-1
#      18433495 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2002944 ['SMIRNOFF Coverage Set 1']
# 3 c[c@@h](c1[nh]c(=o)[nh]n1)nc#n-0
#      18433496 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003435 ['SMIRNOFF Coverage Set 1']
# 3 c[c@@h](c1[nh]c(=o)[nh]n1)nc#n-3
#      18433499 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003438 ['SMIRNOFF Coverage Set 1']
# 3 c1nc[c@h]2[c@h]1[c@h]2o-0
#      18433500 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003481 ['SMIRNOFF Coverage Set 1']
# 3 cc1(c[c@]1(c(=o)n)c(=o)o)c-0
#      18433503 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003499 ['SMIRNOFF Coverage Set 1']
# 3 cc1(c[c@]1(c(=o)n)c(=o)o)c-2
#      18433505 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003501 ['SMIRNOFF Coverage Set 1']
# 3 c1cc1nc(=o)c[n@h+]2c[c@h](co2)o-3
#      18433537 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003274 ['SMIRNOFF Coverage Set 1']
# 3 c1cc1nc(=o)c[n@h+]2c[c@h](co2)o-10
#      18433544 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003281 ['SMIRNOFF Coverage Set 1']
# 3 c1cc1nc(=o)c[n@h+]2c[c@h](co2)o-13
#      18433547 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003284 ['SMIRNOFF Coverage Set 1']
# 3 c1cc1nc(=o)c[n@h+]2c[c@h](co2)o-12
#      18433546 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003283 ['SMIRNOFF Coverage Set 1']
# 3 c1cc1nc(=o)c[n@h+]2c[c@h](co2)o-8
#      18433542 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003279 ['SMIRNOFF Coverage Set 1']
# 3 c1cc1nc(=o)c[n@h+]2c[c@h](co2)o-6
#      18433540 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003277 ['SMIRNOFF Coverage Set 1']
# 3 coc(=o)cc1csc(n1)[n-]s(=o)(=o)c-0
#      18433551 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003104 ['SMIRNOFF Coverage Set 1']
# 3 coc(=o)cc1csc(n1)[n-]s(=o)(=o)c-40
#      18433591 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003144 ['SMIRNOFF Coverage Set 1']
# 3 coc(=o)cc1csc(n1)[n-]s(=o)(=o)c-28
#      18433579 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003132 ['SMIRNOFF Coverage Set 1']
# 3 coc(=o)cc1csc(n1)[n-]s(=o)(=o)c-37
#      18433588 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003141 ['SMIRNOFF Coverage Set 1']
# 3 coc(=o)cc1csc(n1)[n-]s(=o)(=o)c-6
#      18433557 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003110 ['SMIRNOFF Coverage Set 1']
# 3 coc(=o)cc1csc(n1)[n-]s(=o)(=o)c-21
#      18433572 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003125 ['SMIRNOFF Coverage Set 1']
# 3 coc(=o)cc1csc(n1)[n-]s(=o)(=o)c-8
#      18433559 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003112 ['SMIRNOFF Coverage Set 1']
# 3 coc(=o)cc1csc(n1)[n-]s(=o)(=o)c-34
#      18433585 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003138 ['SMIRNOFF Coverage Set 1']
# 3 coc(=o)cc1csc(n1)[n-]s(=o)(=o)c-13
#      18433564 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003117 ['SMIRNOFF Coverage Set 1']
# 2 coc(=o)cc1csc(n1)[n-]s(=o)(=o)c-4
#      18433555 ['OpenFF Gen 2 Opt Set 2 Coverage']
#      2003108 ['SMIRNOFF Coverage Set 1']
# 2 coc(=o)cc1csc(n1)[n-]s(=o)(=o)c-14
#      18433565 ['OpenFF Gen 2 Opt Set 2 Coverage']
#      2003118 ['SMIRNOFF Coverage Set 1']
# 3 c[c@@h]1c[n@@](s(=o)(=o)c1)nc-0
#      18433608 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003399 ['SMIRNOFF Coverage Set 1']
# 3 cc1(c[c@]1(c(=o)n)c(=o)[o-])c-0
#      18433609 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003497 ['SMIRNOFF Coverage Set 1']
# 3 cc1(c[c@]1(c(=o)n)c(=o)[o-])c-1
#      18433610 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003498 ['SMIRNOFF Coverage Set 1']
# 3 c[c@]1(cc(=o)n1)c2nccs2-0
#      18433611 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2002947 ['SMIRNOFF Coverage Set 1']
# 3 c[c@]1(cc(=o)n1)c2nccs2-1
#      18433612 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2002948 ['SMIRNOFF Coverage Set 1']
# 3 c[c@@h](c1[nh][nh]c(=o)n1)nc#n-0
#      18433613 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003414 ['SMIRNOFF Coverage Set 1']
# 3 c[c@@h](c1[nh][nh]c(=o)n1)nc#n-2
#      18433615 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003416 ['SMIRNOFF Coverage Set 1']
# 3 c[c@@h](c1[nh][nh]c(=o)n1)nc#n-3
#      18433616 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003417 ['SMIRNOFF Coverage Set 1']
# 3 c[c@@h](c1[nh][nh]c(=o)n1)nc#n-1
#      18433614 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003415 ['SMIRNOFF Coverage Set 1']
# 3 c[s@](=[n-])(=o)nc1cc1-1
#      18433675 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2002930 ['SMIRNOFF Coverage Set 1']
# 3 c1c[nh+]c(cc1cl)[s@](=o)o-0
#      18433676 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003000 ['SMIRNOFF Coverage Set 1']
# 3 coc(=o)cc1cs/c(=n/s(=o)(=o)c)/[nh]1-0
#      18433679 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003147 ['SMIRNOFF Coverage Set 1']
# 3 coc(=o)cc1cs/c(=n/s(=o)(=o)c)/[nh]1-10
#      18433689 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003157 ['SMIRNOFF Coverage Set 1']
# 2 coc(=o)cc1cs/c(=n/s(=o)(=o)c)/[nh]1-3
#      18433682 ['OpenFF Gen 2 Opt Set 2 Coverage']
#      2003150 ['SMIRNOFF Coverage Set 1']
# 3 coc(=o)cc1cs/c(=n/s(=o)(=o)c)/[nh]1-17
#      18433696 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003164 ['SMIRNOFF Coverage Set 1']
# 2 coc(=o)cc1cs/c(=n/s(=o)(=o)c)/[nh]1-16
#      18433695 ['OpenFF Gen 2 Opt Set 2 Coverage']
#      2003163 ['SMIRNOFF Coverage Set 1']
# 3 coc(=o)cc1cs/c(=n/s(=o)(=o)c)/[nh]1-12
#      18433691 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003159 ['SMIRNOFF Coverage Set 1']
# 2 coc(=o)cc1cs/c(=n/s(=o)(=o)c)/[nh]1-15
#      18433694 ['OpenFF Gen 2 Opt Set 2 Coverage']
#      2003162 ['SMIRNOFF Coverage Set 1']
# 2 coc(=o)cc1cs/c(=n/s(=o)(=o)c)/[nh]1-8
#      18433687 ['OpenFF Gen 2 Opt Set 2 Coverage']
#      2003155 ['SMIRNOFF Coverage Set 1']
# 2 coc(=o)cc1cs/c(=n/s(=o)(=o)c)/[nh]1-14
#      18433693 ['OpenFF Gen 2 Opt Set 2 Coverage']
#      2003161 ['SMIRNOFF Coverage Set 1']
# 3 c[c@@h](c1[nh]c(=o)[n-]n1)nc#n-0
#      18433699 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003422 ['SMIRNOFF Coverage Set 1']
# 3 c[c@@h](c1[nh]c(=o)[n-]n1)nc#n-1
#      18433700 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003423 ['SMIRNOFF Coverage Set 1']
# 3 c[c@@h](c1[nh]c(=o)[n-]n1)nc#n-2
#      18433701 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003424 ['SMIRNOFF Coverage Set 1']
# 3 c1[c@@h]2[c@@h]([c@h]2o)c[nh2+]1-0
#      18433703 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003485 ['SMIRNOFF Coverage Set 1']
# 3 cc[c@@h]1c[c@@]1(c2ccc(nn2)oc)n-0
#      18433704 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003358 ['SMIRNOFF Coverage Set 1']
# 3 c1c[nh+]c(cc1cl)[s@@](=o)[o-]-0
#      18433706 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003006 ['SMIRNOFF Coverage Set 1']
# 2 coc(=o)cc1csc(n1)ns(=o)(=o)c-0
#      18433707 ['OpenFF Gen 2 Opt Set 2 Coverage']
#      2003051 ['SMIRNOFF Coverage Set 1']
# 3 coc(=o)cc1csc(n1)ns(=o)(=o)c-20
#      18433756 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003071 ['SMIRNOFF Coverage Set 1']
# 3 coc(=o)cc1csc(n1)ns(=o)(=o)c-8
#      18433715 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003059 ['SMIRNOFF Coverage Set 1']
# 2 coc(=o)cc1csc(n1)ns(=o)(=o)c-47
#      18433783 ['OpenFF Gen 2 Opt Set 2 Coverage']
#      2003098 ['SMIRNOFF Coverage Set 1']
# 3 coc(=o)cc1csc(n1)ns(=o)(=o)c-44
#      18433780 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003095 ['SMIRNOFF Coverage Set 1']
# 2 coc(=o)cc1csc(n1)ns(=o)(=o)c-32
#      18433768 ['OpenFF Gen 2 Opt Set 2 Coverage']
#      2003083 ['SMIRNOFF Coverage Set 1']
# 2 coc(=o)cc1csc(n1)ns(=o)(=o)c-6
#      18433713 ['OpenFF Gen 2 Opt Set 2 Coverage']
#      2003057 ['SMIRNOFF Coverage Set 1']
# 2 coc(=o)cc1csc(n1)ns(=o)(=o)c-29
#      18433765 ['OpenFF Gen 2 Opt Set 2 Coverage']
#      2003080 ['SMIRNOFF Coverage Set 1']
# 3 coc(=o)cc1csc(n1)ns(=o)(=o)c-34
#      18433770 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003085 ['SMIRNOFF Coverage Set 1']
# 3 coc(=o)cc1csc(n1)ns(=o)(=o)c-51
#      18433787 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003102 ['SMIRNOFF Coverage Set 1']
# 2 coc(=o)cc1csc(n1)ns(=o)(=o)c-4
#      18433711 ['OpenFF Gen 2 Opt Set 2 Coverage']
#      2003055 ['SMIRNOFF Coverage Set 1']
# 3 c1ccc(cc1)p(=n)(c2ccccc2)c3ccccc3-0
#      18433789 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003760 ['SMIRNOFF Coverage Set 1']
# 3 c1ccc(cc1)p(=n)(c2ccccc2)c3ccccc3-1
#      18433790 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003761 ['SMIRNOFF Coverage Set 1']
# 3 c(n)[p@h](=o)o-0
#      18433791 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2002962 ['SMIRNOFF Coverage Set 1']
# 3 c(n)[p@h](=o)o-2
#      18433793 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2002964 ['SMIRNOFF Coverage Set 1']
# 3 cn1cccc1c(=s)n=p(n(c)c)(n(c)c)n(c)c-0
#      18433820 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003520 ['SMIRNOFF Coverage Set 1']
# 3 cn1cccc1c(=s)n=p(n(c)c)(n(c)c)n(c)c-7
#      18433827 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003527 ['SMIRNOFF Coverage Set 1']
# 3 cn1cccc1c(=s)n=p(n(c)c)(n(c)c)n(c)c-6
#      18433826 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003526 ['SMIRNOFF Coverage Set 1']
# 3 cn1cccc1c(=s)n=p(n(c)c)(n(c)c)n(c)c-1
#      18433821 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003521 ['SMIRNOFF Coverage Set 1']
# 3 cn1cccc1c(=s)n=p(n(c)c)(n(c)c)n(c)c-2
#      18433822 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003522 ['SMIRNOFF Coverage Set 1']
# 3 c1conc1c2(cc2)c(=o)[o-]-0
#      18433829 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2002951 ['SMIRNOFF Coverage Set 1']
# 3 c(cbr)c1n[n-]nn1-0
#      18433831 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2002967 ['SMIRNOFF Coverage Set 1']
# 3 coc1ccc(cc1oc)c2ccc3ccccc3[o+]2-0
#      18433833 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003457 ['SMIRNOFF Coverage Set 1']
# 3 coc1ccc(cc1oc)c2ccc3ccccc3[o+]2-2
#      18433853 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003459 ['SMIRNOFF Coverage Set 1']
# 3 c1cc(n(c1o)br)o-0
#      18433855 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003465 ['SMIRNOFF Coverage Set 1']
# 3 c1cc(ccc1[n+](=o)[o-])s(=o)(=o)[n-]cl-0
#      18433856 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003390 ['SMIRNOFF Coverage Set 1']
# 3 c=c=cn1cccc1=o-0
#      18433857 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003468 ['SMIRNOFF Coverage Set 1']
# 3 c=c=cn1cccc1=o-1
#      18433858 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003469 ['SMIRNOFF Coverage Set 1']
# 3 cssccn=c=s-0
#      18433859 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003820 ['SMIRNOFF Coverage Set 1']
# 3 cssccn=c=s-8
#      18433867 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003828 ['SMIRNOFF Coverage Set 1']
# 3 cssccn=c=s-2
#      18433861 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003822 ['SMIRNOFF Coverage Set 1']
# 3 cssccn=c=s-10
#      18433869 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003830 ['SMIRNOFF Coverage Set 1']
# 3 cssccn=c=s-11
#      18433870 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003831 ['SMIRNOFF Coverage Set 1']
# 3 cssccn=c=s-1
#      18433860 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003821 ['SMIRNOFF Coverage Set 1']
# 3 cssccn=c=s-9
#      18433868 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003829 ['SMIRNOFF Coverage Set 1']
# 3 csc(=s)[n-]n-0
#      18433871 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003032 ['SMIRNOFF Coverage Set 1']
# 3 csc(=s)[n-]n-2
#      18433873 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003034 ['SMIRNOFF Coverage Set 1']
# 3 cc(=o)n[p@](=o)(oc)sc-0
#      18433875 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003765 ['SMIRNOFF Coverage Set 1']
# 3 cc(=o)n[p@](=o)(oc)sc-10
#      18433895 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003775 ['SMIRNOFF Coverage Set 1']
# 3 cc(=o)n[p@](=o)(oc)sc-4
#      18433879 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003769 ['SMIRNOFF Coverage Set 1']
# 3 cc(=o)n[p@](=o)(oc)sc-7
#      18433892 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003772 ['SMIRNOFF Coverage Set 1']
# 3 cc(=o)n[p@](=o)(oc)sc-5
#      18433880 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003770 ['SMIRNOFF Coverage Set 1']
# 3 cc(=o)n[p@](=o)(oc)sc-3
#      18433878 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003768 ['SMIRNOFF Coverage Set 1']
# 3 cc(=o)n[p@](=o)(oc)sc-8
#      18433893 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003773 ['SMIRNOFF Coverage Set 1']
# 3 cc(=o)n[p@](=o)(oc)sc-2
#      18433877 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003767 ['SMIRNOFF Coverage Set 1']
# 3 cc(=o)n[p@](=o)(oc)sc-9
#      18433894 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003774 ['SMIRNOFF Coverage Set 1']
# 3 cc(=o)n[p@](=o)(oc)sc-1
#      18433876 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003766 ['SMIRNOFF Coverage Set 1']
# 2 cc(=o)n[p@](=o)(oc)sc-6
#      18433881 ['OpenFF Gen 2 Opt Set 2 Coverage']
#      2003771 ['SMIRNOFF Coverage Set 1']
# 3 cop(=o)(nc(=o)c(cl)(cl)cl)oc-0
#      18433896 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003503 ['SMIRNOFF Coverage Set 1']
# 3 cop(=o)(nc(=o)c(cl)(cl)cl)oc-1
#      18433897 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003504 ['SMIRNOFF Coverage Set 1']
# 3 cop(=o)(nc(=o)c(cl)(cl)cl)oc-2
#      18433898 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003505 ['SMIRNOFF Coverage Set 1']
# 3 cop(=o)(nc(=o)c(cl)(cl)cl)oc-4
#      18433900 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003507 ['SMIRNOFF Coverage Set 1']
# 3 cop(=o)(nc(=o)c(cl)(cl)cl)oc-3
#      18433899 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003506 ['SMIRNOFF Coverage Set 1']
# 3 c1ccc(cc1)p(=o)(cl)cl-0
#      18433901 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003406 ['SMIRNOFF Coverage Set 1']
# 3 c1c(snn1)cnn-0
#      18433902 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2002981 ['SMIRNOFF Coverage Set 1']
# 3 c1c(snn1)cnn-3
#      18433905 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2002984 ['SMIRNOFF Coverage Set 1']
# 3 c1c(snn1)cnn-2
#      18433904 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2002983 ['SMIRNOFF Coverage Set 1']
# 3 cnc(=o)s-0
#      18433907 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003402 ['SMIRNOFF Coverage Set 1']
# 3 c1cc(ccc1c2ccc(cc2)osoc3ccc(cc3)cl)osoc4ccc(cc4)cl-0
#      18433919 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003542 ['SMIRNOFF Coverage Set 1']
# 3 c1cc(ccc1c2ccc(cc2)osoc3ccc(cc3)cl)osoc4ccc(cc4)cl-18
#      18433937 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003560 ['SMIRNOFF Coverage Set 1']
# 3 c1cc(ccc1c2ccc(cc2)osoc3ccc(cc3)cl)osoc4ccc(cc4)cl-82
#      18434065 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003624 ['SMIRNOFF Coverage Set 1']
# 3 c1cc(ccc1c2ccc(cc2)osoc3ccc(cc3)cl)osoc4ccc(cc4)cl-92
#      18434075 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003634 ['SMIRNOFF Coverage Set 1']
# 3 c1cc(ccc1c2ccc(cc2)osoc3ccc(cc3)cl)osoc4ccc(cc4)cl-52
#      18434001 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003594 ['SMIRNOFF Coverage Set 1']
# 3 c1cc(ccc1c2ccc(cc2)osoc3ccc(cc3)cl)osoc4ccc(cc4)cl-31
#      18433950 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003573 ['SMIRNOFF Coverage Set 1']
# 3 c1cc(ccc1c2ccc(cc2)osoc3ccc(cc3)cl)osoc4ccc(cc4)cl-44
#      18433993 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003586 ['SMIRNOFF Coverage Set 1']
# 2 c1cc(ccc1c2ccc(cc2)osoc3ccc(cc3)cl)osoc4ccc(cc4)cl-55
#      18434004 ['OpenFF Gen 2 Opt Set 2 Coverage']
#      2003597 ['SMIRNOFF Coverage Set 1']
# 3 cc(=o)oc#coc(=o)c-0
#      18434077 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003480 ['SMIRNOFF Coverage Set 1']
# 3 c#cc1ccccc1-0
#      18434078 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2002924 ['SMIRNOFF Coverage Set 1']
# 3 coc(=o)c[n+]#c-0
#      18434079 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2002990 ['SMIRNOFF Coverage Set 1']
# 3 coc(=o)c[n+]#c-1
#      18434080 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2002991 ['SMIRNOFF Coverage Set 1']
# 3 c1cs(=o)(=o)ccc12cn=c(o2)n-0
#      18434081 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003013 ['SMIRNOFF Coverage Set 1']
# 3 [c@@](c(f)(f)br)(f)(cl)br-0
#      18434082 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003380 ['SMIRNOFF Coverage Set 1']
# 3 [c@@](c(f)(f)br)(f)(cl)br-2
#      18434084 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003382 ['SMIRNOFF Coverage Set 1']
# 3 [c@@](c(f)(f)br)(f)(cl)br-1
#      18434083 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003381 ['SMIRNOFF Coverage Set 1']
# 3 cc1c(cc(s1)br)c2cc2-0
#      18434086 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003011 ['SMIRNOFF Coverage Set 1']
# 3 cc(=o)oo-0
#      18434087 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003024 ['SMIRNOFF Coverage Set 1']
# 3 c(c#n)n=[n+]=[n-]-0
#      18434089 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003040 ['SMIRNOFF Coverage Set 1']
# 3 c1=n[c@h](c(=n1)c(=o)n)[n+]#n-0
#      18434091 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003756 ['SMIRNOFF Coverage Set 1']
# 3 c[s@@](=o)cl-0
#      18434093 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003376 ['SMIRNOFF Coverage Set 1']
# 3 ccc1ccc(cc1)n=s=o-0
#      18434094 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003408 ['SMIRNOFF Coverage Set 1']
# 3 cc(c)s(=o)(=o)br-0
#      18434095 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003461 ['SMIRNOFF Coverage Set 1']
# 3 c1ccc(cc1)s(=o)(=o)n(f)s(=o)(=o)c2ccccc2-0
#      18434096 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003528 ['SMIRNOFF Coverage Set 1']
# 3 c1ccc(cc1)s(=o)(=o)n(f)s(=o)(=o)c2ccccc2-1
#      18434097 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003529 ['SMIRNOFF Coverage Set 1']
# 3 c1ccc(cc1)s(=o)(=o)n(f)s(=o)(=o)c2ccccc2-2
#      18434098 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003530 ['SMIRNOFF Coverage Set 1']
# 3 p(br)(br)br-0
#      18434120 ['OpenFF Gen 2 Opt Set 2 Coverage', 'OpenFF Sage 2.0.0 Optimization Training Dataset v1.1']
#      2003764 ['SMIRNOFF Coverage Set 1']
# We will rename all of these entry names later to include their respective dataset id of origin.

# %%
# ___________ Check that given a dataset id, entry_name, and spec_name, the same record is returned ________________
records = client.get_records([int(x["record_id"]) for x in entry_dicts], missing_ok=False)
track_records_dict = defaultdict(lambda: defaultdict(list))
for rec in records:
    response = client.query_dataset_records(record_id=rec.id)
    for resp in response:
        tmp_ds = client.get_dataset(dataset_type, resp["dataset_name"])
        rec2 = tmp_ds.get_record(resp["entry_name"], resp["specification_name"])
        track_records_dict[rec.id == rec2.id][rec.id].append([resp["dataset_name"], resp["entry_name"], resp["specification_name"], rec2.id])

print("Given a record id, ensure that the same record is returned given a dataset name, entry name, and spec name")
for key, value in track_records_dict.items():
    print(key, len(value))
# Out:
# Given a record id, ensure that the same record is returned given a dataset name, entry name, and spec name
# True 5580

# %% [markdown]
# # Make New Dataset

# %%
# _________ Initialize New Dataset ____________
print("Initializing new dataset")

with open("ds_info.json") as f:
    dataset_information = json.load(f)

#dataset = client.get_dataset(dataset_type, dataset_information["dataset_name"])
dataset = client.add_dataset(
    dataset_type,
    dataset_information["dataset_name"],
    tagline=dataset_information["dataset_tagline"],
    description=dataset_information["description"],
    provenance=provenance,
    default_tag="openff",
    owner_user="openffbot",
    extras={
        "submitter": dataset_information["metadata.submitter"],
        "creation_data": str(datetime.date.today()),
        'collection_type': 'OptimizationDataset',
        'long_description_url': dataset_information["metadata.long_description_url"],
        "short description": dataset_information["dataset_tagline"],
        "dataset_name": dataset_information["dataset_name"],
        "elements": provenance['applied-filters']['ElementFilter-3']['allowed_elements'],
    },
)

# %%
# _________ Organize Records by Dataset ____________
print("Organizing records")
records = client.get_records([int(x["record_id"]) for x in entry_dicts], missing_ok=False)
records_to_copy = defaultdict(lambda: defaultdict(list))
record_ids_to_copy = defaultdict(lambda: defaultdict(list))
dataset_names_from_id = defaultdict(str)
for rec in records:
    try:
        response = client.query_dataset_records(record_id=rec.id)
        if len(response) > 1:
            ds_id, spec_name, entry_name, ds_name = None, None, None, None
            for resp in response:
                if resp["dataset_id"] in dataset_ids:
                    ds_id = resp["dataset_id"]
                    ds_name = resp["dataset_name"]
                    spec_name = resp["specification_name"]
                    entry_name = resp["entry_name"]
        else:
            ds_id = response[0]["dataset_id"]
            ds_name = response[0]["dataset_name"]
            spec_name = response[0]["specification_name"]
            entry_name = response[0]["entry_name"]

        if ds_id is None:
            raise ValueError(f"This record, {rec.id}, is not found in a target dataset.")
        dataset_names_from_id[ds_id] = ds_name
        
        records_to_copy[ds_id][spec_name].append(entry_name)
        record_ids_to_copy[ds_id][entry_name] = rec.id

    except Exception as e:
        print(f"Failed record {rec.id}, {response}, {str(e)}")

# %%
# _________ Copy Records by Dataset ____________
print("Copying records")
for i, (ds_id, tmp_dict) in enumerate(records_to_copy.items()):
    print(f"Copying entries from ds-{ds_id} ({i+1} of {len(records_to_copy)})")
    new_spec_name = "default-" + "-".join([[str(y) for y in x] for x in specification_ds_ids if ds_id in x][0])
    for spec_name, entry_names in tmp_dict.items():
        dataset.copy_records_from( ds_id, entry_names=entry_names, specification_names=[spec_name])
        
        # Handle Repeat Spec Names
        dataset.rename_specification({spec_name: new_spec_name})
        
        # Handle Repeat Entry Names
        tmp_repeat_entry_names = list(set(repeat_entry_names.keys()) & set(entry_names))
        for entry_name in tmp_repeat_entry_names.keys():
            if record_ids_to_copy[ds_id][entry_name] in repeat_entry_names[entry_name]:
                repeat_entry_names[entry_name].remove(record_ids_to_copy[ds_id][entry_name])
            else:
                tmp_repeat_entry_names.remove(entry_name)
        name_map = {entry_name: f"{entry_name}-{ds_id}" for entry_name in tmp_repeat_entry_names}
        dataset.rename_entries(name_map)

# %% [markdown]
# # Validate that New Dataset Contains the Expected Records

# %%
new_record_ids = set([rec.id for _, _, rec in dataset.iterate_records()])
old_record_ids = set([rec.id for rec in records])
print(f"New record IDs match old record IDs: {set(new_record_ids) == set(old_record_ids)}")
print(f"There are {len(new_record_ids - old_record_ids)} record ids in the new dataset that aren't in the target list")
print(f"There are {len(old_record_ids - new_record_ids)} record ids in the target list that aren't in the new dataset")

# %% [markdown]
# # Write Out Dataset Metadata

# %%
# _________ Write Output Part 2 (Run After Approval) ____________

elements = set(
    sym
    for entry in dataset.iterate_entries()
    for sym in entry.initial_molecule.symbols
)

print("\n\n# Output for README Part 2\n")
print("* Description: {}".format(dataset.description))
print("* Purpose: {}".format(dataset.tagline))
print("* Name: {}".format(dataset.name))
print("* Submitter: {}\n".format(dataset.extras["submitter"]))

print("\n## Metadata")
print(f"* Elements: {{{', '.join(elements)}}}")

for spec, obj in dataset.specifications.items():
    od = obj.dict()['specification']
    print("* Program:", od["program"])
    od = od["qc_specification"]
    print("* QC Specifications:", spec)
    for field, value in od.items():
        print(f"  * {field}: {od[field]}")
    print("  * SCF Properties:")
    for field in od["keywords"]["scf_properties"]:
        print(f"    * {field}")

# %%
scaffold.to_json(dataset, compress=True)
