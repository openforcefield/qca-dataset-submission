# %% [markdown]
# # OpenFF NSP Optimization Set 1 Sulfur v4.0
#
# This notebook generates optimizations for Sulfur set of molecules in the NSP molecules set obtained from Pubchem.

# %%
import pathlib
from pprint import pprint
from openff.toolkit import Molecule
import numpy as np

from openff.qcsubmit import workflow_components
from openff.qcsubmit.factories import OptimizationDatasetFactory
from openff.qcsubmit.utils.visualize import molecules_to_pdf

# %%
input_file = 'set1-S-smiles.smi'
molecules = Molecule.from_file(input_file, allow_undefined_stereo=True)
molecules_to_pdf(molecules, f"dataset.pdf")

# %%
len(molecules)
# Out:
# 636

# %%
dataset_factory = OptimizationDatasetFactory()
dataset_factory.add_workflow_components(
    workflow_components.StandardConformerGenerator(max_conformers=10)
)

description = """\
Optimization dataset to probe coverage of nitrogen, sulfur, and phosphorus (i.e., NSP) functional groups in general, and sulfur in particular. Molecules were curated from PubChem datasets, retaining those with HAC < 40 and applying additional filters; the preprocessing steps are detailed at https://github.com/pavankum/NSP_sets. This dataset includes a broader set of molecules, many of which may not be drug-like, but are informative for differentiating force field parameter ranges. In addition to the default OpenFF QC specification (B3LYP-D3BJ/DZVP), an SPICE-level QC specification (ωB97M-D3BJ/def2-TZVPPD) is included, since many molecules have charged states. Set 1 prioritizes neutral molecules.

- Number of unique molecules: 635
- Number of filtered molecules: 0
- Number of conformers: 3970
- Number of conformers per molecule (min, mean, max): 1, 6.25, 10
- Mean molecular weight: 259.86
- Min molecular weight: 87.14
- Max molecular weight: 593.89
- Charges: [0.0]
## Metadata
- Elements: {I, F, O, S, Br, C, P, N, H, Cl}
- Spec: default
	 - basis: DZVP
	 - implicit_solvent: None
	 - keywords: {}
	 - maxiter: 200
	 - method: B3LYP-D3BJ
	 - program: psi4
	- SCF properties:
		- dipole
		- quadrupole
		- wiberg_lowdin_indices
		- mayer_indices
		- lowdin_charges
		- mulliken_charges
- Spec: WB97M-D3BJ/def2-TZVPPD
	 - basis: def2-TZVPPD
	 - implicit_solvent: None
	 - keywords: {}
	 - maxiter: 200
	 - method: WB97M-D3BJ
	 - program: psi4
	- SCF properties:
		- dipole
		- quadrupole
		- wiberg_lowdin_indices
		- mayer_indices
		- lowdin_charges
		- mulliken_charges
"""

dataset = dataset_factory.create_dataset(
    dataset_name="OpenFF NSP Optimization Set 1 Sulfur v4.0",
    tagline="Molecules curated from Pubchem for Sulfur",
    description=description,
    molecules=molecules,
)

dataset.metadata.submitter = "pavankum"
dataset.metadata.long_description_url = (
    "https://github.com/openforcefield/qca-dataset-submission/tree/master/"
    "submissions/" + str(pathlib.Path.cwd().name)
)
# Out:
# Deduplication                 : 100%|████████| 636/636 [00:01<00:00, 400.40it/s]
# StandardConformerGenerator    :   0%|                   | 0/635 [00:00<?, ?it/s]Warning: Pubchem_CID_253: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_41: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_876: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_495: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_465: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_162: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_149: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   0%|           | 1/635 [00:02<29:43,  2.81s/it]Warning: Pubchem_CID_1703: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1709: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1082: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1857: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   1%|           | 6/635 [00:03<03:47,  2.77it/s]Warning: Pubchem_CID_2062: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2239: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1238: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :
Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: Pubchem_CID_23736: Force field setup failed due to missing parameters
# [14:22:32] UFFTYPER: Unrecognized charge state for atom: 18
# Warning: Pubchem_CID_182860: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 18 S on residue UNL-1
# Warning: Pubchem_CID_182860: Force field setup failed due to missing parameters
# [14:22:32] UFFTYPER: Unrecognized charge state for atom: 4
# Warning: Pubchem_CID_390752: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 S on residue UNL-1
# Warning: Pubchem_CID_390752: Force field setup failed due to missing parameters
# [14:22:33] UFFTYPER: Unrecognized charge state for atom: 10
# Warning: OEMMFFParams::PrepMol() : unable to type atom 10 S on residue UNL-1
# Warning: Pubchem_CID_12588425: Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 10 S on residue UNL-1
# Warning: Pubchem_CID_12588425: Force field setup failed due to missing parameters
# [14:22:33] UFFTYPER: Unrecognized charge state for atom: 8
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 S on residue UNL-1
# Warning: Pubchem_CID_12838927: Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 S on residue UNL-1
# Warning: Pubchem_CID_12838927: Force field setup failed due to missing parameters
# [14:22:33] UFFTYPER: Unrecognized charge state for atom: 4
# Warning: Pubchem_CID_147197786: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 S on residue UNL-1
# Warning: Pubchem_CID_147197786: Force field setup failed due to missing parameters
# [14:22:33] UFFTYPER: Unrecognized charge state for atom: 7
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 20 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 21 H on residue UNL-1
# Warning: Pubchem_CID_147259174: Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 20 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 21 H on residue UNL-1
# Warning: Pubchem_CID_147259174: Force field setup failed due to missing parameters
# Warning: Pubchem_CID_33492: Failed due to unspecified stereochemistry
# [14:22:34] UFFTYPER: Unrecognized charge state for atom: 6
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 S on residue UNL-1
# Warning: Pubchem_CID_147426358: Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 S on residue UNL-1
# Warning: Pubchem_CID_147426358: Force field setup failed due to missing parameters
# Warning: Pubchem_CID_53633: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_65036: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_95200: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_74761: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_228231: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_232159: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_275705: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_249129: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_293864: Failed due to unspecified stereochemistry
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 4 of molecule 'Pubchem_CID_147197786'
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing 'Pubchem_CID_147197786'
# Warning: Pubchem_CID_216681: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_288006: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_435400: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_85119270: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_53632: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_66999: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_71019: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_144833: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_229427: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_240077: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_244892: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_361194: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_847: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1704: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3352: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3726: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3873: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3883: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4078: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4236: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4445: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1524: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2159: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2375: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2717: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2935: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3154: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_85446186: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_77480821: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_141347267: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_139556004: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_130350957: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_89997159: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_89997240: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3695: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4963: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_5628: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_18626: Failed due to unspecified stereochemistry
# Warning: 1024 max ring conf limit reached for C1CCCCCC(CCCC1)[NH]
# Warning: 1024 max ring conf limit reached for CC1C(=O)NC(C(=O)NC2CSSCC(C(=O)NC(C(=O)N1)C)NC2=O)C
# StandardConformerGenerator    :  22%|█▉       | 139/635 [03:11<03:33,  2.32it/s]Warning: 1024 max ring conf limit reached for C1CCCCCC(CCCC1)[SH3]
# StandardConformerGenerator    :  25%|██▎      | 161/635 [03:28<01:41,  4.66it/s]Warning: 1024 max ring conf limit reached for CC1CCC2CC(CC(O2)(C)O)OC(=O)C=C(CCC=CC=C1)C
# Warning: 1024 max ring conf limit reached for CC/1CCC2CC(CC(O2)(C)O)OC(=O)/C=C(/CC/C=C\C=C1)\C
# StandardConformerGenerator    :  86%|███████▊ | 547/635 [05:08<00:01, 78.01it/s]Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 4 of molecule 'Pubchem_CID_147197786'
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing 'Pubchem_CID_147197786'
# StandardConformerGenerator    : 100%|█████████| 635/635 [05:09<00:00,  2.05it/s]
# Preparation                   :  36%|███▏     | 228/635 [00:33<00:48,  8.37it/s]Warning: bond stereochemistry may be assigned incorrectly for molecule Pubchem_CID_327576
# Warning: bond stereochemistry may be assigned incorrectly for molecule Pubchem_CID_327576
# Warning: bond stereochemistry may be assigned incorrectly for molecule Pubchem_CID_327576
# Preparation                   :  87%|███████▊ | 555/635 [01:13<00:09,  8.60it/s]Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 4 of molecule 'Pubchem_CID_147197786'
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing 'Pubchem_CID_147197786'
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 4 of molecule 'Pubchem_CID_147197786'
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChI when writing 'Pubchem_CID_147197786'
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 4 of molecule 'Pubchem_CID_147197786'
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChIKey when writing 'Pubchem_CID_147197786'
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 4 of molecule 'Pubchem_CID_147197786'
# Warning: OE3DToAtomStereo had a problem during OEMolToInChI when writing 'Pubchem_CID_147197786'
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 4 of molecule 'Pubchem_CID_147197786'
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing 'Pubchem_CID_147197786'
# Preparation                   : 100%|█████████| 635/635 [01:23<00:00,  7.65it/s]

# %%
dataset.n_molecules
# Out:
# 635

# %% [markdown]
# Add a new qcspecification to the factory which will be applied to the dataset.
#
#     Parameters:
#         method: The name of the method to use eg B3LYP-D3BJ
#         basis: The name of the basis to use can also be `None`
#         program: The name of the program to execute the computation
#         spec_name: The name the spec should be stored under
#         spec_description: The description of the spec
#         store_wavefunction: what parts of the wavefunction that should be saved
#         overwrite: If there is a spec under this name already overwrite it
#         implicit_solvent: The implicit solvent settings if it is to be used.
#         maxiter: The maximum number of SCF iterations that should be done.
#         scf_properties: The list of SCF properties that should be extracted from the calculation.
#         keywords: Program specific computational keywords that should be passed to
#             the program

# %%
dataset.add_qc_spec(method='WB97M-D3BJ',
                    basis='def2-TZVPPD',
                    program='psi4',
                    spec_name="WB97M-D3BJ/def2-TZVPPD",
                    spec_description="SPICE sets level of theory",
                    store_wavefunction='none',
                    implicit_solvent=None,
                    maxiter=200,
                    scf_properties=['dipole', 'quadrupole', 'wiberg_lowdin_indices', 'mayer_indices', 'lowdin_charges', 'mulliken_charges'],
                    keywords={}
                    )
dataset.add_qc_spec(method='B3LYP-D3BJ',
                    basis='DZVP',
                    program='psi4',
                    spec_name="default",
                    spec_description="Standard OpenFF optimization quantum chemistry specification.",
                    store_wavefunction='none',
                    implicit_solvent=None,
                    maxiter=200,
                    scf_properties=['dipole', 'quadrupole', 'wiberg_lowdin_indices', 'mayer_indices', 'lowdin_charges', 'mulliken_charges'],
                    keywords={},
                    overwrite=True
                    )

# %%
pprint(dataset.dict()['qc_specifications'])
# Out:
# {'WB97M-D3BJ/def2-TZVPPD': {'basis': 'def2-TZVPPD',
#                             'implicit_solvent': None,
#                             'keywords': {},
#                             'maxiter': 200,
#                             'method': 'WB97M-D3BJ',
#                             'program': 'psi4',
#                             'scf_properties': ['dipole',
#                                                'quadrupole',
#                                                'wiberg_lowdin_indices',
#                                                'mayer_indices',
#                                                'lowdin_charges',
#                                                'mulliken_charges'],
#                             'spec_description': 'SPICE sets level of theory',
#                             'spec_name': 'WB97M-D3BJ/def2-TZVPPD',
#                             'store_wavefunction': 'none'},
#  'default': {'basis': 'DZVP',
#              'implicit_solvent': None,
#              'keywords': {},
#              'maxiter': 200,
#              'method': 'B3LYP-D3BJ',
#              'program': 'psi4',
#              'scf_properties': ['dipole',
#                                 'quadrupole',
#                                 'wiberg_lowdin_indices',
#                                 'mayer_indices',
#                                 'lowdin_charges',
#                                 'mulliken_charges'],
#              'spec_description': 'Standard OpenFF optimization quantum '
#                                  'chemistry specification.',
#              'spec_name': 'default',
#              'store_wavefunction': 'none'}}

# %%
# summarize dataset for readme
confs = np.array([len(mol.conformers) for mol in dataset.molecules])

print("- Number of unique molecules:", dataset.n_molecules)
print("- Number of filtered molecules:", dataset.n_filtered)
print("- Number of conformers:", sum(confs))
print(
    "- Number of conformers per molecule (min, mean, max): "
    f"{confs.min()}, {confs.mean():.2f}, {confs.max()}"
)

masses = [
    [
        sum([atom.mass.m for atom in molecule.atoms])
        for molecule in dataset.molecules
    ]
]
print(f"- Mean molecular weight: {np.mean(np.array(masses)):.2f}")
print(f"- Min molecular weight: {np.min(np.array(masses)):.2f}")
print(f"- Max molecular weight: {np.max(np.array(masses)):.2f}")
print("- Charges:", sorted(set(m.total_charge.m for m in dataset.molecules)))


print("## Metadata")
print(f"- Elements: {{{', '.join(dataset.metadata.dict()['elements'])}}}")


fields = [
    "basis",
    "implicit_solvent",
    "keywords",
    "maxiter",
    "method",
    "program",
]
for spec, obj in dataset.qc_specifications.items():
    od = obj.dict()
    print("- Spec:", spec)
    for field in fields:
        print(f"\t - {field}: {od[field]}")
    print("\t- SCF properties:")
    for field in od["scf_properties"]:
        print(f"\t\t- {field}")


# export the dataset
dataset.export_dataset("dataset.json.bz2")
dataset.molecules_to_file("dataset.smi", "smi")
dataset.visualize("dataset.pdf", columns=4)
# Out:
# - Number of unique molecules: 635
# - Number of filtered molecules: 0
# - Number of conformers: 3970
# - Number of conformers per molecule (min, mean, max): 1, 6.25, 10
# - Mean molecular weight: 259.86
# - Min molecular weight: 87.14
# - Max molecular weight: 593.89
# - Charges: [0.0]
# ## Metadata
# - Elements: {F, H, N, Br, I, O, Cl, C, S, P}
# - Spec: default
# 	 - basis: DZVP
# 	 - implicit_solvent: None
# 	 - keywords: {}
# 	 - maxiter: 200
# 	 - method: B3LYP-D3BJ
# 	 - program: psi4
# 	- SCF properties:
# 		- dipole
# 		- quadrupole
# 		- wiberg_lowdin_indices
# 		- mayer_indices
# 		- lowdin_charges
# 		- mulliken_charges
# - Spec: WB97M-D3BJ/def2-TZVPPD
# 	 - basis: def2-TZVPPD
# 	 - implicit_solvent: None
# 	 - keywords: {}
# 	 - maxiter: 200
# 	 - method: WB97M-D3BJ
# 	 - program: psi4
# 	- SCF properties:
# 		- dipole
# 		- quadrupole
# 		- wiberg_lowdin_indices
# 		- mayer_indices
# 		- lowdin_charges
# 		- mulliken_charges
