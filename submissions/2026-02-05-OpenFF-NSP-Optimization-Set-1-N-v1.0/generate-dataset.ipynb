# %% [markdown]
# # OpenFF NSP Optimization Set 1 N v1.0
#
# This notebook generates optimizations for Nitrogen set of molecules in the NSP molecules set obtained from Pubchem.

# %%
import qcportal
import pathlib
from pprint import pprint
from openff.toolkit import Molecule, ForceField
import numpy as np
import tqdm

from openff.qcsubmit.utils import get_symmetry_classes, get_symmetry_group
from openff.qcsubmit import workflow_components
from openff.qcsubmit.factories import OptimizationDatasetFactory
from openff.qcsubmit.utils.visualize import molecules_to_pdf
from qcportal.singlepoint import SinglepointDriver, QCSpecification

# %%
input_file = 'set1-N-smiles.smi'
molecules = Molecule.from_file(input_file, allow_undefined_stereo=True)
molecules_to_pdf(molecules, f"dataset.pdf")

# %%
len(molecules)
# Out:
# 620

# %%
dataset_factory = OptimizationDatasetFactory()
dataset_factory.add_workflow_components(
    workflow_components.StandardConformerGenerator(max_conformers=10)
)

description = """\
This optimization dataset looks at the coverage for NSP elements.
This dataset uses the OpenFF default level of theory (B3LYP-D3BJ/DZVP), and WB97M-D3BJ/def2-TZVP.
"""

dataset = dataset_factory.create_dataset(
    dataset_name="OpenFF NSP Optimization Set 1 N v1.0",
    tagline="Molecules curated from Pubchem for Nitrogen",
    description=description,
    molecules=molecules,
)

dataset.metadata.submitter = "pavankum"
dataset.metadata.long_description_url = (
    "https://github.com/openforcefield/qca-dataset-submission/tree/master/"
    "submissions/" + str(pathlib.Path.cwd().name)
)
# Out:
# Deduplication                 : 100%|████████| 620/620 [00:02<00:00, 288.79it/s]
# StandardConformerGenerator    :   0%|                   | 0/609 [00:00<?, ?it/s]Warning: Pubchem_CID_23: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_24: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_26: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_28: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_29: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   0%|           | 2/609 [00:03<12:55,  1.28s/it]Warning: Pubchem_CID_63: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_128: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   1%|           | 4/609 [00:03<05:46,  1.74it/s]Warning: Pubchem_CID_131: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_144: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_151: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_166: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_92: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_142: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_153: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_162: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_298: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_320: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_408: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_85: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_409: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_554: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_577: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_589: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_404: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1232: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1260: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1289: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1562: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1850: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_132: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_152: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_185: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_200: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_236: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_336: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_350: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1276: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1284: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1883: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2171: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2172: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2613: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2623: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3329: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4258: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4414: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_433: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_499: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2779: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2921: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3291: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3156: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3535: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3788: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4626: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_497: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_643: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_648: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1002: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_921: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1283: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1350: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4072: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_20773: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1269: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1375: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1307: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1956: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2086: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_782: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2069: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2270: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2461: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2952: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3292: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3349: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3608: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3650: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_17: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_154: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_164: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_426: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_30: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2042: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2320: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2454: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2867: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3943: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4513: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_5627: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_7626: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4532: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4226: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4884: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_5968: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_7200: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_7292: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_9023: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_8069: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_9497: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_21936: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_24305: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1559170: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1592105: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2027163: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3939684: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4859174: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_5110735: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1642: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2327: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2563: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2751: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2804: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3475: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3702: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4641: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_5271: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_5342: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_5272: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4509: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_12213: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_12872: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_15841: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_17007: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_19021: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_40244: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_43880: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_44054: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_600548: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_45465: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_383294: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_383298: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_667473: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_667836: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_667992: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_668000: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_668095: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3446252: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1270: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1273: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1840: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2420: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2546: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3491: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3514: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_5300: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_6261: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1419: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1600: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2034: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_19423: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_21130: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_22505: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_5726: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1234: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1550: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2036: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2045: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_11382: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_43589: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4826: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_110091: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_232: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_587: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2105: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2090: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2232: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2713: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_20892: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_430: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_412: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_583: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_939: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_799: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1239: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1288: Failed due to unspecified stereochemistry
# Warning: 1024 max ring conf limit reached for C1CCC(=O)NCCCCCC(=O)NCC1
# Warning: Pubchem_CID_1622: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_20739483: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 C on residue UNL-1
# Warning: Pubchem_CID_20739483: Force field setup failed due to missing parameters
# Warning: Pubchem_CID_88325088: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 16 H on residue UNL-1
# Warning: Pubchem_CID_88325088: Force field setup failed due to missing parameters
# Warning: Pubchem_CID_1805: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1627: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4209: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_10539: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1962: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2173: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2609: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2622: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2873: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3695: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_5370: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1496: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_18717856: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_20812242: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_165: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_830: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2101: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2302: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2520: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2604: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2755: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2771: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_149: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_606: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_773: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_917: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_191: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1458: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1484: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_137243369: Failed to build structure from CT
# Warning: Pubchem_CID_137243369: Failed to build structure from CT
# Warning: Pubchem_CID_1636: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_50114: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_55645: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3051974: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3058026: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3859: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_16118: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_68785: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_131351: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_290021: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_332505: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_338118: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_372256: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_423323: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_72601: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_438628: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_559401: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_577271: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2999116: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3457345: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3589750: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3706067: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4109937: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4157901: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2507: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_52818: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_54163: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_54738: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_62179: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_63976: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_127667: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 N on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 S on residue UNL-1
# Warning: Pubchem_CID_19040046: Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 N on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 S on residue UNL-1
# Warning: Pubchem_CID_19040046: Force field setup failed due to missing parameters
# Warning: Pubchem_CID_123630469: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_20138779: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_20537304: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_385501: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_100627: Failed due to unspecified stereochemistry
# Warning: Hit maximum duplicate removal time limit for Pubchem_CID_24
# Warning: Pubchem_CID_270895: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_283963: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  12%|█▏        | 71/609 [02:27<02:59,  3.00it/s]Warning: 1024 max ring conf limit reached for C1CCCCCC2(CCCCC1)NNC(=S)NN2
# Warning: 1024 max ring conf limit reached for CC1CC(=O)OC(C=CC(C(=CCc2ccccc2C(=O)O1)C)O)C
# Warning: 1024 max ring conf limit reached for CC1CC=CC2C(C(=C)C(C3C2(C(C=CC(C1)(C)O)O)C(=O)NC3C)C)O
# StandardConformerGenerator    : 100%|█████████| 609/609 [05:07<00:00,  1.98it/s]
# Preparation                   : 100%|█████████| 609/609 [01:12<00:00,  8.44it/s]

# %%
dataset.n_molecules
# Out:
# 609

# %% [markdown]
# Add a new qcspecification to the factory which will be applied to the dataset.
#
#     Parameters:
#         method: The name of the method to use eg B3LYP-D3BJ
#         basis: The name of the basis to use can also be `None`
#         program: The name of the program to execute the computation
#         spec_name: The name the spec should be stored under
#         spec_description: The description of the spec
#         store_wavefunction: what parts of the wavefunction that should be saved
#         overwrite: If there is a spec under this name already overwrite it
#         implicit_solvent: The implicit solvent settings if it is to be used.
#         maxiter: The maximum number of SCF iterations that should be done.
#         scf_properties: The list of SCF properties that should be extracted from the calculation.
#         keywords: Program specific computational keywords that should be passed to
#             the program

# %%
dataset.add_qc_spec(method='WB97M-D3BJ',
                    basis='def2-TZVP',
                    program='psi4',
                    spec_name="WB97M-D3BJ/def2-TZVP",
                    spec_description="WB97M-D3BJ/def2-TZVP",
                    store_wavefunction='none',
                    implicit_solvent=None,
                    maxiter=200,
                    scf_properties=['dipole', 'quadrupole', 'wiberg_lowdin_indices', 'mayer_indices', 'lowdin_charges', 'mulliken_charges'],
                    keywords={}
                    )

# %%
pprint(dataset.dict()['qc_specifications'])
# Out:
# {'WB97M-D3BJ/def2-TZVP': {'basis': 'def2-TZVP',
#                           'implicit_solvent': None,
#                           'keywords': {},
#                           'maxiter': 200,
#                           'method': 'WB97M-D3BJ',
#                           'program': 'psi4',
#                           'scf_properties': ['dipole',
#                                              'quadrupole',
#                                              'wiberg_lowdin_indices',
#                                              'mayer_indices',
#                                              'lowdin_charges',
#                                              'mulliken_charges'],
#                           'spec_description': 'WB97M-D3BJ/def2-TZVP',
#                           'spec_name': 'WB97M-D3BJ/def2-TZVP',
#                           'store_wavefunction': 'none'},
#  'default': {'basis': 'DZVP',
#              'implicit_solvent': None,
#              'keywords': {},
#              'maxiter': 200,
#              'method': 'B3LYP-D3BJ',
#              'program': 'psi4',
#              'scf_properties': ['dipole',
#                                 'quadrupole',
#                                 'wiberg_lowdin_indices',
#                                 'mayer_indices'],
#              'spec_description': 'Standard OpenFF optimization quantum '
#                                  'chemistry specification.',
#              'spec_name': 'default',
#              'store_wavefunction': 'none'}}

# %%
# summarize dataset for readme
confs = np.array([len(mol.conformers) for mol in dataset.molecules])

print("* Number of unique molecules:", dataset.n_molecules)
print("* Number of filtered molecules:", dataset.n_filtered)
print("* Number of conformers:", sum(confs))
print(
    "* Number of conformers per molecule (min, mean, max): "
    f"{confs.min()}, {confs.mean():.2f}, {confs.max()}"
)

masses = [
    [
        sum([atom.mass.m for atom in molecule.atoms])
        for molecule in dataset.molecules
    ]
]
print(f"* Mean molecular weight: {np.mean(np.array(masses)):.2f}")
print(f"* Min molecular weight: {np.min(np.array(masses)):.2f}")
print(f"* Max molecular weight: {np.max(np.array(masses)):.2f}")
print("* Charges:", sorted(set(m.total_charge.m for m in dataset.molecules)))


print("## Metadata")
print(f"* Elements: {{{', '.join(dataset.metadata.dict()['elements'])}}}")


fields = [
    "basis",
    "implicit_solvent",
    "keywords",
    "maxiter",
    "method",
    "program",
]
for spec, obj in dataset.qc_specifications.items():
    od = obj.dict()
    print("* Spec:", spec)
    for field in fields:
        print(f"\t * {field}: {od[field]}")
    print("\t* SCF properties:")
    for field in od["scf_properties"]:
        print(f"\t\t* {field}")


# export the dataset
dataset.export_dataset("dataset.json.bz2")
dataset.molecules_to_file("dataset.smi", "smi")
dataset.visualize("dataset.pdf", columns=4)
# Out:
# * Number of unique molecules: 609
# * Number of filtered molecules: 0
# * Number of conformers: 3432
# * Number of conformers per molecule (min, mean, max): 1, 5.64, 10
# * Mean molecular weight: 242.01
# * Min molecular weight: 67.05
# * Max molecular weight: 555.24
# * Charges: [-1.0, 0.0, 1.0, 2.0]
# ## Metadata
# * Elements: {O, N, Cl, S, P, C, F, Br, H, I}
# * Spec: default
# 	 * basis: DZVP
# 	 * implicit_solvent: None
# 	 * keywords: {}
# 	 * maxiter: 200
# 	 * method: B3LYP-D3BJ
# 	 * program: psi4
# 	* SCF properties:
# 		* dipole
# 		* quadrupole
# 		* wiberg_lowdin_indices
# 		* mayer_indices
# * Spec: WB97M-D3BJ/def2-TZVP
# 	 * basis: def2-TZVP
# 	 * implicit_solvent: None
# 	 * keywords: {}
# 	 * maxiter: 200
# 	 * method: WB97M-D3BJ
# 	 * program: psi4
# 	* SCF properties:
# 		* dipole
# 		* quadrupole
# 		* wiberg_lowdin_indices
# 		* mayer_indices
# 		* lowdin_charges
# 		* mulliken_charges
