# %% [markdown]
# # OpenFF NSP Optimization Set 1 Phosphorus v4.0
#
# This notebook generates optimizations for phosphorus set of molecules in the NSP molecules set obtained from Pubchem.

# %%
import qcportal
import pathlib
from pprint import pprint
from openff.toolkit import Molecule, ForceField
import numpy as np
import tqdm

from openff.qcsubmit.utils import get_symmetry_classes, get_symmetry_group
from openff.qcsubmit import workflow_components
from openff.qcsubmit.factories import OptimizationDatasetFactory
from openff.qcsubmit.utils.visualize import molecules_to_pdf
from qcportal.singlepoint import SinglepointDriver, QCSpecification

# %%
input_file = 'set1-P-smiles.smi'
molecules = Molecule.from_file(input_file, allow_undefined_stereo=True)
molecules_to_pdf(molecules, f"dataset.pdf")

# %%
len(molecules)
# Out:
# 430

# %%
dataset_factory = OptimizationDatasetFactory()
dataset_factory.add_workflow_components(
    workflow_components.StandardConformerGenerator(max_conformers=10)
)

description = """\
Optimization dataset to probe coverage of nitrogen, sulfur, and phosphorus (i.e., NSP) functional groups in general, and phosphorus in particular. Molecules were curated from PubChem datasets, retaining those with HAC < 40 and applying additional filters; the preprocessing steps are detailed at https://github.com/pavankum/NSP_sets. This dataset includes a broader set of molecules, many of which may not be drug-like, but are informative for differentiating force field parameter ranges. In addition to the default OpenFF QC specification (B3LYP-D3BJ/DZVP), an SPICE-level QC specification (ωB97M-D3BJ/def2-TZVPPD) is included, since many molecules have charged states. Set1 prioritizes neutral molecules.

- Number of unique molecules: 430
- Number of filtered molecules: 0
- Number of conformers: 2910
- Number of conformers per molecule (min, mean, max): 1, 6.77, 10
- Mean molecular weight: 278.25
- Min molecular weight: 90.10
- Max molecular weight: 586.68
- Charges: [0.0]
## Metadata
- Elements: {H, Br, N, S, C, F, I, Cl, P, O}
- Spec: default
	 - basis: DZVP
	 - implicit_solvent: None
	 - keywords: {}
	 - maxiter: 200
	 - method: B3LYP-D3BJ
	 - program: psi4
	- SCF properties:
		- dipole
		- quadrupole
		- wiberg_lowdin_indices
		- mayer_indices
		- lowdin_charges
		- mulliken_charges
- Spec: WB97M-D3BJ/def2-TZVPPD
	 - basis: def2-TZVPPD
	 - implicit_solvent: None
	 - keywords: {}
	 - maxiter: 200
	 - method: WB97M-D3BJ
	 - program: psi4
	- SCF properties:
		- dipole
		- quadrupole
		- wiberg_lowdin_indices
		- mayer_indices
		- lowdin_charges
		- mulliken_charges
        """

dataset = dataset_factory.create_dataset(
    dataset_name="OpenFF NSP Optimization Set 1 Phosphorus v4.0",
    tagline="Molecules curated from Pubchem for Phosphorus",
    description=description,
    molecules=molecules,
)

dataset.metadata.submitter = "pavankum"
dataset.metadata.long_description_url = (
    "https://github.com/openforcefield/qca-dataset-submission/tree/master/"
    "submissions/" + str(pathlib.Path.cwd().name)
)
# Out:
# Deduplication                 : 100%|████████| 430/430 [00:02<00:00, 169.18it/s]
# StandardConformerGenerator    :   0%|                   | 0/430 [00:00<?, ?it/s]Warning: Pubchem_CID_174255: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   0%|           | 1/430 [00:04<34:08,  4.78s/it]Warning: Pubchem_CID_102472: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_145198: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   3%|▎         | 13/430 [00:06<01:54,  3.65it/s]Warning: Pubchem_CID_74049568: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_85375645: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :
Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_12660578: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_12760380: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_12785252: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_148919677: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_9299: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_32872: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_37419: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_35754: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_51617: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_77113: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_108842: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_112011: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_112009: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_232684: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_297309: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_320382: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_217: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_391: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4577: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_76816: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_97004: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_108198: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_150935424: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_85116942: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_439911: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_85430283: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_147496434: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_150486968: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_151699028: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_148242207: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_154076252: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_12521979: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_12739232: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_76492509: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_53051: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_264144: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_325164: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_325165: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_342346: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_149813502: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_77324: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_84055: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_126337: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_150950: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_177918: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_179596: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_196732: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_90126: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_99928: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_140936: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_26486: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_75769: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_82207: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_90479: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_157230: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_198503: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_175825: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4618: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_11705: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_15415: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_18763: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_468: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_516: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4660: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_91837: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_114070: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_116839: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_117837: Failed due to unspecified stereochemistry
# Warning: 1024 max ring conf limit reached for CC1CCCC2C(N2)CC(OC(=O)CC(C(C(=O)C(C1O)C)(C)C)O)[CH2]
# StandardConformerGenerator    :  78%|██████▏ | 334/430 [04:07<00:00, 102.27it/s]Warning: 1024 max ring conf limit reached for CP1(=NP(=NP(=NP(=NP(=N1)(C)C)(C)C)(C)C)(C)C)C
# StandardConformerGenerator    : 100%|█████████| 430/430 [06:19<00:00,  1.13it/s]
# Preparation                   : 100%|█████████| 430/430 [00:57<00:00,  7.52it/s]

# %%
dataset.n_molecules
# Out:
# 430

# %% [markdown]
# Add a new qcspecification to the factory which will be applied to the dataset.
#
#     Parameters:
#         method: The name of the method to use eg B3LYP-D3BJ
#         basis: The name of the basis to use can also be `None`
#         program: The name of the program to execute the computation
#         spec_name: The name the spec should be stored under
#         spec_description: The description of the spec
#         store_wavefunction: what parts of the wavefunction that should be saved
#         overwrite: If there is a spec under this name already overwrite it
#         implicit_solvent: The implicit solvent settings if it is to be used.
#         maxiter: The maximum number of SCF iterations that should be done.
#         scf_properties: The list of SCF properties that should be extracted from the calculation.
#         keywords: Program specific computational keywords that should be passed to
#             the program

# %%
dataset.add_qc_spec(method='WB97M-D3BJ',
                    basis='def2-TZVPPD',
                    program='psi4',
                    spec_name="WB97M-D3BJ/def2-TZVPPD",
                    spec_description="SPICE sets level of theory",
                    store_wavefunction='none',
                    implicit_solvent=None,
                    maxiter=200,
                    scf_properties=['dipole', 'quadrupole', 'wiberg_lowdin_indices', 'mayer_indices', 'lowdin_charges', 'mulliken_charges'],
                    keywords={}
                    )
dataset.add_qc_spec(method='B3LYP-D3BJ',
                    basis='DZVP',
                    program='psi4',
                    spec_name="default",
                    spec_description="Standard OpenFF optimization quantum chemistry specification.",
                    store_wavefunction='none',
                    implicit_solvent=None,
                    maxiter=200,
                    scf_properties=['dipole', 'quadrupole', 'wiberg_lowdin_indices', 'mayer_indices', 'lowdin_charges', 'mulliken_charges'],
                    keywords={},
                    overwrite=True
                    )

# %%
pprint(dataset.dict()['qc_specifications'])
# Out:
# {'WB97M-D3BJ/def2-TZVPPD': {'basis': 'def2-TZVPPD',
#                             'implicit_solvent': None,
#                             'keywords': {},
#                             'maxiter': 200,
#                             'method': 'WB97M-D3BJ',
#                             'program': 'psi4',
#                             'scf_properties': ['dipole',
#                                                'quadrupole',
#                                                'wiberg_lowdin_indices',
#                                                'mayer_indices',
#                                                'lowdin_charges',
#                                                'mulliken_charges'],
#                             'spec_description': 'SPICE sets level of theory',
#                             'spec_name': 'WB97M-D3BJ/def2-TZVPPD',
#                             'store_wavefunction': 'none'},
#  'default': {'basis': 'DZVP',
#              'implicit_solvent': None,
#              'keywords': {},
#              'maxiter': 200,
#              'method': 'B3LYP-D3BJ',
#              'program': 'psi4',
#              'scf_properties': ['dipole',
#                                 'quadrupole',
#                                 'wiberg_lowdin_indices',
#                                 'mayer_indices',
#                                 'lowdin_charges',
#                                 'mulliken_charges'],
#              'spec_description': 'Standard OpenFF optimization quantum '
#                                  'chemistry specification.',
#              'spec_name': 'default',
#              'store_wavefunction': 'none'}}

# %%
# summarize dataset for readme
confs = np.array([len(mol.conformers) for mol in dataset.molecules])

print("- Number of unique molecules:", dataset.n_molecules)
print("- Number of filtered molecules:", dataset.n_filtered)
print("- Number of conformers:", sum(confs))
print(
    "- Number of conformers per molecule (min, mean, max): "
    f"{confs.min()}, {confs.mean():.2f}, {confs.max()}"
)

masses = [
    [
        sum([atom.mass.m for atom in molecule.atoms])
        for molecule in dataset.molecules
    ]
]
print(f"- Mean molecular weight: {np.mean(np.array(masses)):.2f}")
print(f"- Min molecular weight: {np.min(np.array(masses)):.2f}")
print(f"- Max molecular weight: {np.max(np.array(masses)):.2f}")
print("- Charges:", sorted(set(m.total_charge.m for m in dataset.molecules)))


print("## Metadata")
print(f"- Elements: {{{', '.join(dataset.metadata.dict()['elements'])}}}")


fields = [
    "basis",
    "implicit_solvent",
    "keywords",
    "maxiter",
    "method",
    "program",
]
for spec, obj in dataset.qc_specifications.items():
    od = obj.dict()
    print("- Spec:", spec)
    for field in fields:
        print(f"\t - {field}: {od[field]}")
    print("\t- SCF properties:")
    for field in od["scf_properties"]:
        print(f"\t\t- {field}")


# export the dataset
dataset.export_dataset("dataset.json.bz2")
dataset.molecules_to_file("dataset.smi", "smi")
dataset.visualize("dataset.pdf", columns=4)
# Out:
# - Number of unique molecules: 430
# - Number of filtered molecules: 0
# - Number of conformers: 2910
# - Number of conformers per molecule (min, mean, max): 1, 6.77, 10
# - Mean molecular weight: 278.25
# - Min molecular weight: 90.10
# - Max molecular weight: 586.68
# - Charges: [0.0]
# ## Metadata
# - Elements: {I, P, Cl, N, S, Br, F, O, H, C}
# - Spec: default
# 	 - basis: DZVP
# 	 - implicit_solvent: None
# 	 - keywords: {}
# 	 - maxiter: 200
# 	 - method: B3LYP-D3BJ
# 	 - program: psi4
# 	- SCF properties:
# 		- dipole
# 		- quadrupole
# 		- wiberg_lowdin_indices
# 		- mayer_indices
# 		- lowdin_charges
# 		- mulliken_charges
# - Spec: WB97M-D3BJ/def2-TZVPPD
# 	 - basis: def2-TZVPPD
# 	 - implicit_solvent: None
# 	 - keywords: {}
# 	 - maxiter: 200
# 	 - method: WB97M-D3BJ
# 	 - program: psi4
# 	- SCF properties:
# 		- dipole
# 		- quadrupole
# 		- wiberg_lowdin_indices
# 		- mayer_indices
# 		- lowdin_charges
# 		- mulliken_charges
