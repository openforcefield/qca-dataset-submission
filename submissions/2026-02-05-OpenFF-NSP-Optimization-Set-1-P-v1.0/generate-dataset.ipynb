# %% [markdown]
# # OpenFF NSP Optimization Set 1 P v1.0
#
# This notebook generates optimizations for Phosphorous set of molecules in the NSP molecules set obtained from Pubchem.

# %%
import qcportal
import pathlib
from pprint import pprint
from openff.toolkit import Molecule, ForceField
import numpy as np
import tqdm

from openff.qcsubmit.utils import get_symmetry_classes, get_symmetry_group
from openff.qcsubmit import workflow_components
from openff.qcsubmit.factories import OptimizationDatasetFactory
from openff.qcsubmit.utils.visualize import molecules_to_pdf
from qcportal.singlepoint import SinglepointDriver, QCSpecification

# %%
input_file = 'set1-P-smiles.smi'
molecules = Molecule.from_file(input_file, allow_undefined_stereo=True)
molecules_to_pdf(molecules, f"dataset.pdf")

# %%
len(molecules)
# Out:
# 430

# %%
dataset_factory = OptimizationDatasetFactory()
dataset_factory.add_workflow_components(
    workflow_components.StandardConformerGenerator(max_conformers=10)
)

description = """\
This optimization dataset looks at the coverage for NSP elements.
This dataset uses the OpenFF default level of theory (B3LYP-D3BJ/DZVP), and WB97M-D3BJ/def2-TZVP.
"""

dataset = dataset_factory.create_dataset(
    dataset_name="OpenFF NSP Optimization Set 1 P v1.0",
    tagline="Molecules curated from Pubchem for Nitrogen",
    description=description,
    molecules=molecules,
)

dataset.metadata.submitter = "pavankum"
dataset.metadata.long_description_url = (
    "https://github.com/openforcefield/qca-dataset-submission/tree/master/"
    "submissions/" + str(pathlib.Path.cwd().name)
)
# Out:
# Deduplication                 : 100%|████████| 430/430 [00:01<00:00, 244.69it/s]
# StandardConformerGenerator    :   2%|▏          | 7/423 [00:02<02:12,  3.15it/s]Warning: Pubchem_CID_174255: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_102472: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_145198: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_87673: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   2%|▏         | 10/423 [00:07<05:46,  1.19it/s]Warning: Pubchem_CID_55391: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  11%|█         | 47/423 [00:09<00:34, 11.03it/s]Warning: Pubchem_CID_543461: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_584302: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_545155: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  12%|█▏        | 51/423 [00:10<00:52,  7.08it/s]Warning: Pubchem_CID_2785401: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_70843: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_117317: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_124530: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_170325: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_248378: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_377940: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_425761: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_17959997: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_18335481: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_18336614: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_18343629: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  15%|█▍        | 63/423 [00:13<00:58,  6.19it/s]Warning: Pubchem_CID_18709849: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  16%|█▋        | 69/423 [00:14<00:39,  9.00it/s]Warning: Pubchem_CID_18710451: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  18%|█▊        | 76/423 [00:14<00:25, 13.50it/s]Warning: Pubchem_CID_12759248: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_16686119: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_9320: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  20%|█▉        | 83/423 [00:17<01:05,  5.22it/s]Warning: Pubchem_CID_9: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_31: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_46: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_59: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_68: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_82: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_112: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_150: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_202: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_274: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_212: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1026: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1364: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1381: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4176: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4420: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_5464: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_6537: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_19504: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_25256: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_26176: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_33553: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_44843: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4802: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_9300: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_11547: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_11700: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_26957: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2907: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_31070: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3690: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_31515: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_12236: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_36027: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_64619: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_65400: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_75178: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_89131: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_89132: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  20%|█▉        | 83/423 [00:28<01:05,  5.22it/s]Warning: Pubchem_CID_90125: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_99802: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3619: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3721: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_5853: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_12026: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_15778: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_20453: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_38337: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_40806: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_51437: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_52852: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_38335: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_113636: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_126655: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_131200: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_158762: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_158764: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_158770: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_198926: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_243431: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_243765: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_402969: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_5249309: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_11032254: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_20339315: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_46183162: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_57372610: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_57094008: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3419: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_28222: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_32292: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_38334: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_97539: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_97258: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_104465: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_354522: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_401448: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_75939: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_55053: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_161393: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_185730: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_198219: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_216656: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_114254: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_280839: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_395332: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_551676: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_590476: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1556921: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2305736: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2838434: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3089976: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_6421252: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_9299: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_32872: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_35754: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_37419: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_77113: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_108842: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_112011: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_112009: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_232684: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_320382: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_297309: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_391: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1058: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1132: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3992: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4995: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_12237: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_76816: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_66593848: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_70373721: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_26118: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_193862: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_5280571: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_9862854: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_623099: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_626134: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_635791: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 N on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 N on residue UNL-1
# Warning: Pubchem_CID_3485481: Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 N on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 N on residue UNL-1
# Warning: Pubchem_CID_3485481: Force field setup failed due to missing parameters
# Warning: Pubchem_CID_53051: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_264144: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_173208: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_256463: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_290260: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4131: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_325164: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_36576: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_80336: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_94516: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_102268: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_126337: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_150950: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_90126: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_99928: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_140936: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_26486: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_82207: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_75769: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_90479: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_157230: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_175827: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_180273: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_11705: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_15415: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_18763: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_468: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_516: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3993: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_5431: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_88650: Failed due to unspecified stereochemistry
# Warning: 1024 max ring conf limit reached for CC1CCCC2(C(O2)CC(OC(=O)CC(C(C(=O)C(C1O)C)(C)C)O)[CH2])C
# StandardConformerGenerator    :  79%|███████▏ | 336/423 [03:48<00:01, 80.60it/s]Warning: 1024 max ring conf limit reached for CP1(=NP(=NP(=NP(=NP(=NP(=N1)(C)C)(C)C)(C)C)(C)C)(C)C)C
# StandardConformerGenerator    : 100%|█████████| 423/423 [14:35<00:00,  2.07s/it]
# Preparation                   : 100%|█████████| 422/422 [01:08<00:00,  6.19it/s]

# %%
dataset.n_molecules
# Out:
# 422

# %% [markdown]
# Add a new qcspecification to the factory which will be applied to the dataset.
#
#     Parameters:
#         method: The name of the method to use eg B3LYP-D3BJ
#         basis: The name of the basis to use can also be `None`
#         program: The name of the program to execute the computation
#         spec_name: The name the spec should be stored under
#         spec_description: The description of the spec
#         store_wavefunction: what parts of the wavefunction that should be saved
#         overwrite: If there is a spec under this name already overwrite it
#         implicit_solvent: The implicit solvent settings if it is to be used.
#         maxiter: The maximum number of SCF iterations that should be done.
#         scf_properties: The list of SCF properties that should be extracted from the calculation.
#         keywords: Program specific computational keywords that should be passed to
#             the program

# %%
dataset.add_qc_spec(method='WB97M-D3BJ',
                    basis='def2-TZVP',
                    program='psi4',
                    spec_name="WB97M-D3BJ/def2-TZVP",
                    spec_description="WB97M-D3BJ/def2-TZVP",
                    store_wavefunction='none',
                    implicit_solvent=None,
                    maxiter=200,
                    scf_properties=['dipole', 'quadrupole', 'wiberg_lowdin_indices', 'mayer_indices', 'lowdin_charges', 'mulliken_charges'],
                    keywords={}
                    )

# %%
pprint(dataset.dict()['qc_specifications'])
# Out:
# {'WB97M-D3BJ/def2-TZVP': {'basis': 'def2-TZVP',
#                           'implicit_solvent': None,
#                           'keywords': {},
#                           'maxiter': 200,
#                           'method': 'WB97M-D3BJ',
#                           'program': 'psi4',
#                           'scf_properties': ['dipole',
#                                              'quadrupole',
#                                              'wiberg_lowdin_indices',
#                                              'mayer_indices',
#                                              'lowdin_charges',
#                                              'mulliken_charges'],
#                           'spec_description': 'WB97M-D3BJ/def2-TZVP',
#                           'spec_name': 'WB97M-D3BJ/def2-TZVP',
#                           'store_wavefunction': 'none'},
#  'default': {'basis': 'DZVP',
#              'implicit_solvent': None,
#              'keywords': {},
#              'maxiter': 200,
#              'method': 'B3LYP-D3BJ',
#              'program': 'psi4',
#              'scf_properties': ['dipole',
#                                 'quadrupole',
#                                 'wiberg_lowdin_indices',
#                                 'mayer_indices'],
#              'spec_description': 'Standard OpenFF optimization quantum '
#                                  'chemistry specification.',
#              'spec_name': 'default',
#              'store_wavefunction': 'none'}}

# %%
# summarize dataset for readme
confs = np.array([len(mol.conformers) for mol in dataset.molecules])

print("* Number of unique molecules:", dataset.n_molecules)
print("* Number of filtered molecules:", dataset.n_filtered)
print("* Number of conformers:", sum(confs))
print(
    "* Number of conformers per molecule (min, mean, max): "
    f"{confs.min()}, {confs.mean():.2f}, {confs.max()}"
)

masses = [
    [
        sum([atom.mass.m for atom in molecule.atoms])
        for molecule in dataset.molecules
    ]
]
print(f"* Mean molecular weight: {np.mean(np.array(masses)):.2f}")
print(f"* Min molecular weight: {np.min(np.array(masses)):.2f}")
print(f"* Max molecular weight: {np.max(np.array(masses)):.2f}")
print("* Charges:", sorted(set(m.total_charge.m for m in dataset.molecules)))


print("## Metadata")
print(f"* Elements: {{{', '.join(dataset.metadata.dict()['elements'])}}}")


fields = [
    "basis",
    "implicit_solvent",
    "keywords",
    "maxiter",
    "method",
    "program",
]
for spec, obj in dataset.qc_specifications.items():
    od = obj.dict()
    print("* Spec:", spec)
    for field in fields:
        print(f"\t * {field}: {od[field]}")
    print("\t* SCF properties:")
    for field in od["scf_properties"]:
        print(f"\t\t* {field}")


# export the dataset
dataset.export_dataset("dataset.json.bz2")
dataset.molecules_to_file("dataset.smi", "smi")
dataset.visualize("dataset.pdf", columns=4)
# Out:
# * Number of unique molecules: 422
# * Number of filtered molecules: 0
# * Number of conformers: 2819
# * Number of conformers per molecule (min, mean, max): 1, 6.68, 10
# * Mean molecular weight: 277.86
# * Min molecular weight: 90.10
# * Max molecular weight: 588.74
# * Charges: [-5.0, -4.0, -3.0, -2.0, -1.0, 0.0, 1.0, 2.0, 3.0]
# ## Metadata
# * Elements: {Cl, F, P, Br, S, H, I, N, C, O}
# * Spec: default
# 	 * basis: DZVP
# 	 * implicit_solvent: None
# 	 * keywords: {}
# 	 * maxiter: 200
# 	 * method: B3LYP-D3BJ
# 	 * program: psi4
# 	* SCF properties:
# 		* dipole
# 		* quadrupole
# 		* wiberg_lowdin_indices
# 		* mayer_indices
# * Spec: WB97M-D3BJ/def2-TZVP
# 	 * basis: def2-TZVP
# 	 * implicit_solvent: None
# 	 * keywords: {}
# 	 * maxiter: 200
# 	 * method: WB97M-D3BJ
# 	 * program: psi4
# 	* SCF properties:
# 		* dipole
# 		* quadrupole
# 		* wiberg_lowdin_indices
# 		* mayer_indices
# 		* lowdin_charges
# 		* mulliken_charges
