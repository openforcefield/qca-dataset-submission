# %% [markdown]
# # OpenFF Additional Generated ChEMBL TorsionDrives 4.0
#
# This notebook generates additional torsiondrives from molecules for torsions in Sage 2.2.1 with low or no existing coverage in QCArchive.
# Input files are obtained from the process in the [fragment-chembl-data](https://github.com/lilyminium/fragment-chembl-data/commit/d94c9fc4be6945c4e680b2bb5b31a2693c4b772b) repo. Low coverage torsions are identified from the [profile-qc-data](https://github.com/lilyminium/profile-qc-data) repo.

# %%
import zstandard
import qcportal
import pathlib

from openff.toolkit import Molecule, ForceField
import numpy as np
import tqdm

from openff.qcsubmit.utils import get_symmetry_classes, get_symmetry_group
from openff.qcsubmit.workflow_components import TorsionIndexer
from openff.qcsubmit import workflow_components
from openff.qcsubmit.factories import TorsiondriveDatasetFactory
from openff.qcsubmit.utils.visualize import molecules_to_pdf

# %%
def load_molecules(file: str, parameter_id: str) -> list[Molecule]:
    """Load SMILES from file and assign dihedrals to rotate around by pattern"""
    case_molecules = []
    forcefield = ForceField("inputs/openff_unconstrained-2.2.1.offxml")

    molecules = Molecule.from_file(file, allow_undefined_stereo=True)

    for mol in molecules:
        
        unique_central_bonds = set()
        torsion_indexer = TorsionIndexer()
        symmetry_classes = get_symmetry_classes(mol)

        labels = forcefield.label_molecules(mol.to_topology())[0]["ProperTorsions"]
        for (i, j, k, l), parameter in labels.items():
            if parameter.id != parameter_id:
                continue
            central_bond = tuple(sorted([j, k]))
            # ignore torsions around rings
            if mol.get_bond_between(j, k).is_in_ring():
                continue
                
            symmetry_group = get_symmetry_group(central_bond, symmetry_classes)
            if central_bond in unique_central_bonds:
                continue
                
            unique_central_bonds.add(central_bond)
            torsion_indexer.add_torsion((i, j, k, l), symmetry_group, (-165, 180))

        assert len(torsion_indexer.torsions)
        mol.properties["dihedrals"] = torsion_indexer
        case_molecules.append(mol)
    return case_molecules


def visualize(mols, filename):
    """Draw output molecules as PDF"""
    new_mols = []
    for mol in mols:
        for val in mol.properties["dihedrals"].torsions.values():
            new_mol = Molecule(mol)
            new_mol.properties["dihedrals"] = val.get_dihedrals
            new_mols.append(new_mol)
    molecules_to_pdf(new_mols, filename)

# %%
input_directory = pathlib.Path("inputs")
input_files = input_directory.glob("*.smi")
all_molecules = []
for file in tqdm.tqdm(input_files):
    parameter_id = file.stem.split("-")[-1]
    molecules = load_molecules(file, parameter_id)
    all_molecules.extend(molecules)
    visualize(molecules, f"inputs/{parameter_id}_molecules.pdf")
# Out:
# 29it [00:08,  3.28it/s]

# %%
len(all_molecules)
# Out:
# 290

# %%
dataset_factory = TorsiondriveDatasetFactory()
dataset_factory.add_workflow_components(
    workflow_components.StandardConformerGenerator(max_conformers=5)
)

description = """\
Molecules were curated to add more coverage for rare torsions, as listed in `inputs/`.
Rare torsions that run through a ring were not included.
Molecules were generated according to the process in https://github.com/lilyminium/fragment-chembl-data/commit/d94c9fc4be6945c4e680b2bb5b31a2693c4b772b
repo. In short:

- ChEMBL molecules were split into "elementary" fragments without rotatable bonds
- Elementary fragments were combined with a single bond
- For each torsion, a pool of up to 5000 molecules were initially selected after sorting for low molecular weight
- Up to 250 molecules were selected from this pool by maximising chemical diversity, using the Tanimoto distance of the Morgan fingerprints
- Up to 10 molecules were selected from the second pool by maximising the diversity of coupled torsions through the central bond

"""

dataset = dataset_factory.create_dataset(
    dataset_name="OpenFF Additional Generated ChEMBL TorsionDrives 4.0",
    tagline="Additional TorsionDrives curated from ChEMBL fragments for rare torsions",
    description=description,
    molecules=all_molecules,
)

dataset.metadata.submitter = "lilyminium"
dataset.metadata.long_description_url = (
    "https://github.com/openforcefield/qca-dataset-submission/tree/master/"
    "submissions/" + str(pathlib.Path.cwd().name)
)
# Out:
# Deduplication                 : 100%|███████| 290/290 [00:00<00:00, 1654.10it/s]
# StandardConformerGenerator    :   0%|                   | 0/285 [00:00<?, ?it/s]Warning: t12: Failed due to unspecified stereochemistry
# Warning: t12: Failed due to unspecified stereochemistry
# Warning: t12: Failed due to unspecified stereochemistry
# Warning: t12: Failed due to unspecified stereochemistry
# Warning: t12: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   7%|▋         | 19/285 [00:05<00:50,  5.28it/s]Warning: t7: Failed due to unspecified stereochemistry
# Warning: t7: Failed due to unspecified stereochemistry
# Warning: t7: Failed due to unspecified stereochemistry
# Warning: t7: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   8%|▊         | 24/285 [00:05<00:36,  7.16it/s]Warning: t7: Failed due to unspecified stereochemistry
# Warning: t59: Failed due to unspecified stereochemistry
# Warning: t59: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  10%|█         | 29/285 [00:06<00:26,  9.55it/s]Warning: t59: Failed due to unspecified stereochemistry
# Warning: t59: Failed due to unspecified stereochemistry
# Warning: t59: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  13%|█▎        | 37/285 [00:06<00:16, 15.01it/s]Warning: t138a: Failed due to unspecified stereochemistry
# Warning: t138a: Failed due to unspecified stereochemistry
# Warning: t138a: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  15%|█▌        | 43/285 [00:06<00:13, 17.93it/s]Warning: t138a: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  17%|█▋        | 48/285 [00:06<00:10, 21.61it/s]Warning: t88: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 10 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 11 H on residue UNL-1
# Warning: t88: Force field setup failed due to missing parameters
# Warning: t88: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: t88: Force field setup failed due to missing parameters
# Warning: t88: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 12 H on residue UNL-1
# Warning: t88: Force field setup failed due to missing parameters
# Warning: t88: Failed due to unspecified stereochemistry
# Warning: t88: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 S on residue UNL-1
# Warning: t88: Force field setup failed due to missing parameters
# Warning: t88: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 12 H on residue UNL-1
# Warning: t88: Force field setup failed due to missing parameters
# Warning: t88: Failed due to unspecified stereochemistry
# Warning: t88: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: t88: Force field setup failed due to missing parameters
# Warning: t88: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 11 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 12 H on residue UNL-1
# Warning: t88: Force field setup failed due to missing parameters
# Warning: t88: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 10 H on residue UNL-1
# Warning: t88: Force field setup failed due to missing parameters
# Warning: t62: Failed due to unspecified stereochemistry
# Warning: t62: Failed due to unspecified stereochemistry
# Warning: t62: Failed due to unspecified stereochemistry
# Warning: t62: Failed due to unspecified stereochemistry
# Warning: t62: Failed due to unspecified stereochemistry
# Warning: t62: Failed due to unspecified stereochemistry
# Warning: t89: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 10 H on residue UNL-1
# Warning: t89: Force field setup failed due to missing parameters
# Warning: t89: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 17 H on residue UNL-1
# Warning: t89: Force field setup failed due to missing parameters
# [17:41:29] UFFTYPER: Unrecognized atom type: S_5+4 (4)
# [17:41:29] UFFTYPER: Unrecognized atom type: S_5+4 (0)
# [17:41:29] UFFTYPER: Unrecognized charge state for atom: 1
# [17:41:29] UFFTYPER: Unrecognized atom type: S_5+4 (1)
# [17:41:29] UFFTYPER: Unrecognized charge state for atom: 3
# [17:41:29] UFFTYPER: Unrecognized charge state for atom: 1
# [17:41:29] UFFTYPER: Unrecognized atom type: S_5+4 (0)
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule 't88'
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing 't88'
# StandardConformerGenerator    :  19%|█▊        | 53/285 [00:13<01:42,  2.26it/s]Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule 't88'
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing 't88'
# Warning: t89: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 11 H on residue UNL-1
# Warning: t89: Force field setup failed due to missing parameters
# Warning: t89: Failed due to unspecified stereochemistry
# Warning: t89: Failed due to unspecified stereochemistry
# Warning: t89: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 S on residue UNL-1
# Warning: t89: Force field setup failed due to missing parameters
# Warning: t89: Failed due to unspecified stereochemistry
# Warning: t89: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 12 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 13 H on residue UNL-1
# Warning: t89: Force field setup failed due to missing parameters
# Warning: t89: Failed due to unspecified stereochemistry
# [17:41:30] UFFTYPER: Unrecognized atom type: S_5+4 (1)
# Warning: OEMMFFParams::PrepMol() : unable to type atom 10 H on residue UNL-1
# Warning: t89: Force field setup failed due to missing parameters
# [17:41:30] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: t89: Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: t89: Force field setup failed due to missing parameters
# Warning: t42a: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  26%|██▌       | 73/285 [00:14<00:37,  5.59it/s]Warning: t42a: Failed due to unspecified stereochemistry
# Warning: t42a: Failed due to unspecified stereochemistry
# Warning: t42a: Failed due to unspecified stereochemistry
# Warning: t42a: Failed due to unspecified stereochemistry
# Warning: t141: Failed due to unspecified stereochemistry
# Warning: t141: Failed due to unspecified stereochemistry
# Warning: t141: Failed due to unspecified stereochemistry
# Warning: t141: Failed due to unspecified stereochemistry
# Warning: t141: Failed due to unspecified stereochemistry
# Warning: t60: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  28%|██▊       | 81/285 [00:14<00:30,  6.70it/s]Warning: t60: Failed due to unspecified stereochemistry
# Warning: t60: Failed due to unspecified stereochemistry
# Warning: t60: Failed due to unspecified stereochemistry
# Warning: t60: Failed due to unspecified stereochemistry
# Warning: t60: Failed due to unspecified stereochemistry
# Warning: t61: Failed due to unspecified stereochemistry
# Warning: t61: Failed due to unspecified stereochemistry
# Warning: t61: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  36%|███▎     | 103/285 [00:14<00:14, 12.65it/s]Warning: t61: Failed due to unspecified stereochemistry
# Warning: t154: Failed due to unspecified stereochemistry
# Warning: t154: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: t154: Force field setup failed due to missing parameters
# Warning: t154: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  41%|███▋     | 117/285 [00:14<00:09, 17.67it/s]Warning: t154: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: t154: Force field setup failed due to missing parameters
# [17:41:31] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: t154: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 10 H on residue UNL-1
# Warning: t154: Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: t154: Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: t154: Force field setup failed due to missing parameters
# Warning: t154: Failed due to unspecified stereochemistry
# Warning: t165: Failed due to unspecified stereochemistry
# Warning: t154: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: t154: Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: t154: Force field setup failed due to missing parameters
# [17:41:31] UFFTYPER: Unrecognized charge state for atom: 4
# StandardConformerGenerator    :  44%|███▉     | 125/285 [00:15<00:08, 19.30it/s]Warning: t165: Failed due to unspecified stereochemistry
# Warning: t165: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: t158: Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: t158: Force field setup failed due to missing parameters
# [17:41:31] UFFTYPER: Unrecognized charge state for atom: 4
# StandardConformerGenerator    :  47%|████▏    | 134/285 [00:15<00:06, 23.70it/s]Warning: OEMMFFParams::PrepMol() : unable to type atom 2 S on residue UNL-1
# Warning: t158: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: t158: Force field setup failed due to missing parameters
# [17:41:31] UFFTYPER: Unrecognized charge state for atom: 1
# [17:41:31] UFFTYPER: Unrecognized charge state for atom: 2
# Warning: t158: Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 S on residue UNL-1
# Warning: t158: Force field setup failed due to missing parameters
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule 't158'
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule 't158'
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing 't158'
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: t158: Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: t158: Force field setup failed due to missing parameters
# [17:41:31] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: t158: Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: t158: Force field setup failed due to missing parameters
# [17:41:31] UFFTYPER: Unrecognized charge state for atom: 0
# [17:41:31] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: t164: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  49%|████▍    | 141/285 [00:15<00:05, 24.02it/s]Warning: OEMMFFParams::PrepMol() : unable to type atom 3 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: t158: Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: t158: Force field setup failed due to missing parameters
# [17:41:31] UFFTYPER: Unrecognized charge state for atom: 3
# Warning: t158: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: t158: Force field setup failed due to missing parameters
# [17:41:31] UFFTYPER: Unrecognized charge state for atom: 0
# [17:41:31] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: t164: Failed due to unspecified stereochemistry
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule 't158'
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule 't158'
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing 't158'
# Warning: t164: Failed due to unspecified stereochemistry
# Warning: t164: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: t164: Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: t164: Force field setup failed due to missing parameters
# [17:41:31] UFFTYPER: Warning: hybridization set to SP3 for atom 4
# StandardConformerGenerator    :  53%|████▊    | 152/285 [00:15<00:04, 30.23it/s]Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: t167: Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: t167: Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 S on residue UNL-1
# Warning: t167: Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 S on residue UNL-1
# Warning: t167: Force field setup failed due to missing parameters
# StandardConformerGenerator    :  57%|█████    | 162/285 [00:15<00:03, 36.85it/s]Warning: t8: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  60%|█████▎   | 170/285 [00:16<00:02, 42.50it/s]Warning: t8: Failed due to unspecified stereochemistry
# Warning: t8: Failed due to unspecified stereochemistry
# Warning: t8: Failed due to unspecified stereochemistry
# Warning: t8: Failed due to unspecified stereochemistry
# Warning: t8: Failed due to unspecified stereochemistry
# Warning: t8: Failed due to unspecified stereochemistry
# Warning: t8: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  62%|█████▌   | 177/285 [00:16<00:02, 39.72it/s]Warning: t81: Failed due to unspecified stereochemistry
# Warning: t81: Failed due to unspecified stereochemistry
# Warning: t81: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 C on residue UNL-1
# Warning: t81: Force field setup failed due to missing parameters
# Warning: t81: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  64%|█████▊   | 183/285 [00:16<00:02, 41.99it/s]Warning: t55: Failed due to unspecified stereochemistry
# Warning: t55: Failed due to unspecified stereochemistry
# Warning: t55: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  68%|██████   | 193/285 [00:16<00:01, 50.43it/s]Warning: t55: Failed due to unspecified stereochemistry
# Warning: t55: Failed due to unspecified stereochemistry
# Warning: t54: Failed due to unspecified stereochemistry
# Warning: t54: Failed due to unspecified stereochemistry
# Warning: t54: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  70%|██████▎  | 200/285 [00:16<00:01, 50.89it/s]Warning: t112: Failed due to unspecified stereochemistry
# Warning: t112: Failed due to unspecified stereochemistry
# Warning: t112: Failed due to unspecified stereochemistry
# Warning: t112: Failed due to unspecified stereochemistry
# Warning: t112: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  73%|██████▌  | 207/285 [00:16<00:01, 53.27it/s]Warning: t112: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 S on residue UNL-1
# Warning: t112: Force field setup failed due to missing parameters
# Warning: t112: Failed due to unspecified stereochemistry
# Warning: t112: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  76%|██████▊  | 216/285 [00:16<00:01, 61.14it/s]Warning: t33: Failed due to unspecified stereochemistry
# Warning: t33: Failed due to unspecified stereochemistry
# Warning: t33: Failed due to unspecified stereochemistry
# Warning: t33: Failed due to unspecified stereochemistry
# Warning: t33: Failed due to unspecified stereochemistry
# Warning: t33: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  79%|███████  | 224/285 [00:16<00:00, 63.57it/s]Warning: t33: Failed due to unspecified stereochemistry
# Warning: t113: Failed due to unspecified stereochemistry
# Warning: t113: Failed due to unspecified stereochemistry
# Warning: t113: Failed due to unspecified stereochemistry
# Warning: t113: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  81%|███████▎ | 231/285 [00:17<00:00, 62.37it/s]Warning: t30: Failed due to unspecified stereochemistry
# Warning: t113: Failed due to unspecified stereochemistry
# Warning: t30: Failed due to unspecified stereochemistry
# Warning: t30: Failed due to unspecified stereochemistry
# Warning: t30: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  84%|███████▌ | 238/285 [00:17<00:00, 61.56it/s]Warning: t30: Failed due to unspecified stereochemistry
# Warning: t114: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: t114: Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: t114: Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: t114: Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: t114: Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: t114: Force field setup failed due to missing parameters
# Warning: t114: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 10 H on residue UNL-1
# Warning: t114: Force field setup failed due to missing parameters
# Warning: t114: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: t114: Force field setup failed due to missing parameters
# StandardConformerGenerator    :  86%|███████▊ | 246/285 [00:17<00:00, 61.01it/s]Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: t114: Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: t114: Force field setup failed due to missing parameters
# Warning: t114: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: t114: Force field setup failed due to missing parameters
# [17:41:33] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: t114: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: t114: Force field setup failed due to missing parameters
# Warning: t114: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: t114: Force field setup failed due to missing parameters
# Warning: t31a: Failed due to unspecified stereochemistry
# Warning: t114: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: t114: Force field setup failed due to missing parameters
# Warning: t31a: Failed due to unspecified stereochemistry
# Warning: t31a: Failed due to unspecified stereochemistry
# Warning: t31a: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  90%|████████ | 256/285 [00:17<00:00, 63.38it/s]Warning: t103: Failed due to unspecified stereochemistry
# Warning: t31a: Failed due to unspecified stereochemistry
# Warning: t103: Failed due to unspecified stereochemistry
# Warning: t103: Failed due to unspecified stereochemistry
# Warning: t103: Failed due to unspecified stereochemistry
# Warning: t103: Failed due to unspecified stereochemistry
# Warning: t103: Failed due to unspecified stereochemistry
# Warning: t31a: Failed to build structure from CT
# Warning: t31a: Failed to build structure from CT
# Warning: t103: Failed due to unspecified stereochemistry
# Warning: t102: Failed due to unspecified stereochemistry
# Warning: t102: Failed due to unspecified stereochemistry
# Warning: t102: Failed due to unspecified stereochemistry
# Warning: t102: Failed due to unspecified stereochemistry
# Warning: t102: Failed due to unspecified stereochemistry
# Warning: t102: Failed due to unspecified stereochemistry
# Warning: t102: Failed due to unspecified stereochemistry
# Warning: t102: Failed due to unspecified stereochemistry
# StandardConformerGenerator    : 100%|█████████| 285/285 [00:42<00:00,  6.67it/s]
# Preparation                   :  17%|█▌       | 48/284 [00:00<00:02, 114.02it/s]Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule 't88'
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing 't88'
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule 't88'
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChI when writing 't88'
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule 't88'
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChIKey when writing 't88'
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule 't88'
# Warning: OE3DToAtomStereo had a problem during OEMolToInChI when writing 't88'
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule 't88'
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing 't88'
# Preparation                   :  46%|███▋    | 131/284 [00:01<00:01, 110.87it/s]Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule 't158'
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule 't158'
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing 't158'
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule 't158'
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule 't158'
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChI when writing 't158'
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule 't158'
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule 't158'
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChIKey when writing 't158'
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule 't158'
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule 't158'
# Warning: OE3DToAtomStereo had a problem during OEMolToInChI when writing 't158'
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule 't158'
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule 't158'
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing 't158'
# Preparation                   :  64%|█████▏  | 183/284 [00:01<00:00, 105.24it/s]Warning: bond stereochemistry may be assigned incorrectly for molecule t55
# Warning: bond stereochemistry may be assigned incorrectly for molecule t55
# Warning: bond stereochemistry may be assigned incorrectly for molecule t55
# Warning: bond stereochemistry may be assigned incorrectly for molecule t55
# Preparation                   :  74%|█████▉  | 209/284 [00:01<00:00, 113.19it/s]Warning: bond stereochemistry may be assigned incorrectly for molecule t112
# Warning: bond stereochemistry may be assigned incorrectly for molecule t112
# Warning: bond stereochemistry may be assigned incorrectly for molecule t112
# Warning: bond stereochemistry may be assigned incorrectly for molecule t112
# Preparation                   : 100%|█████████| 284/284 [00:02<00:00, 99.44it/s]

# %%
print(description)
# Out:
# Molecules were curated to add more coverage for rare torsions, as listed in `inputs/`.
# Rare torsions that run through a ring were not included.
# Molecules were generated according to the process in https://github.com/lilyminium/fragment-chembl-data/commit/d94c9fc4be6945c4e680b2bb5b31a2693c4b772b
# repo. In short:
#
# - ChEMBL molecules were split into "elementary" fragments without rotatable bonds
# - Elementary fragments were combined with a single bond
# - For each torsion, a pool of up to 5000 molecules were initially selected after sorting for low molecular weight
# - Up to 250 molecules were selected from this pool by maximising chemical diversity, using the Tanimoto distance of the Morgan fingerprints
# - Up to 10 molecules were selected from the second pool by maximising the diversity of coupled torsions through the central bond

# %%
# summarize dataset for readme
confs = np.array([len(mol.conformers) for mol in dataset.molecules])

print("* Number of unique molecules:", dataset.n_molecules)
# With multiple torsions per unique molecule, n_molecules * confs.mean() no
# longer equals the number of conformers. instead, the number of dihedrals *
# confs.mean() should equal the number of conformers. The dataset contains one
# record per driven torsion (rather than combining multiple dihedrals into the
# same record), so n_records is the same as manually adding up len(dihedrals)
# for each record.
print("* Number of driven torsions:", dataset.n_records)
print("* Number of filtered molecules:", dataset.n_filtered)
print("* Number of conformers:", sum(confs))
print(
    "* Number of conformers per molecule (min, mean, max): "
    f"{confs.min()}, {confs.mean():.2f}, {confs.max()}"
)

masses = [
    [
        sum([atom.mass.m for atom in molecule.atoms])
        for molecule in dataset.molecules
    ]
]
print(f"* Mean molecular weight: {np.mean(np.array(masses)):.2f}")
print(f"* Max molecular weight: {np.max(np.array(masses)):.2f}")
print("* Charges:", sorted(set(m.total_charge.m for m in dataset.molecules)))


print("## Metadata")
print(f"* Elements: {{{', '.join(dataset.metadata.dict()['elements'])}}}")


fields = [
    "basis",
    "implicit_solvent",
    "keywords",
    "maxiter",
    "method",
    "program",
]
for spec, obj in dataset.qc_specifications.items():
    od = obj.dict()
    print("* Spec:", spec)
    for field in fields:
        print(f"\t * {field}: {od[field]}")
    print("\t* SCF properties:")
    for field in od["scf_properties"]:
        print(f"\t\t* {field}")


# export the dataset
dataset.export_dataset("dataset.json.bz2")
dataset.molecules_to_file("output.smi", "smi")
dataset.visualize("dataset.pdf", columns=8)
# Out:
# * Number of unique molecules: 270
# * Number of driven torsions: 275
# * Number of filtered molecules: 17
# * Number of conformers: 352
# * Number of conformers per molecule (min, mean, max): 1, 1.28, 4
# * Mean molecular weight: 124.98
# * Max molecular weight: 312.99
# * Charges: [-1.0, 0.0, 1.0, 2.0]
# ## Metadata
# * Elements: {O, Cl, Br, C, I, P, F, H, N, S}
# * Spec: default
# 	 * basis: DZVP
# 	 * implicit_solvent: None
# 	 * keywords: {}
# 	 * maxiter: 200
# 	 * method: B3LYP-D3BJ
# 	 * program: psi4
# 	* SCF properties:
# 		* dipole
# 		* quadrupole
# 		* wiberg_lowdin_indices
# 		* mayer_indices
