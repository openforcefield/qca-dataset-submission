# %% [markdown]
# # Generation process
#
# This notebook documents the generation of a dataset of representative torsiondrive molecules shared by XtalPi. The conformers used are the post-optimization conformers shared by XtalPi.

# %% [markdown]
# ## Imports

# %%
import openff.qcsubmit
import openff.toolkit
import openeye
import qcelemental
import qcportal
import pyarrow
import pyarrow.dataset as ds
import numpy as np

print("OpenFF QCSubmit:", openff.qcsubmit.__version__)
print("OpenFF Toolkit:", openff.toolkit.__version__)
print("OpenEye:", openeye.__version__)
print("QCElemental:", qcelemental.__version__)
print("QCPortal:", qcportal.__version__)
print("PyArrow:", pyarrow.__version__)
# Out:
# OpenFF QCSubmit: 0.50.2
# OpenFF Toolkit: 0.15.0
# OpenEye: 2022.1.1
# QCElemental: 0.27.1
# QCPortal: 0.53
# PyArrow: 14.0.2

# %%
import tqdm

from openff.units import unit

from openff.toolkit import Molecule
from openff.toolkit.utils import OpenEyeToolkitWrapper, ToolkitRegistry

from openff.qcsubmit.datasets import TorsiondriveDataset
from openff.qcsubmit.factories import TorsiondriveDatasetFactory

# %% [markdown]
# ## Setting up dataset

# %%
dataset_factory = TorsiondriveDatasetFactory()

# %% [markdown]
# ## Loading input

# %%
input_dataset = ds.dataset("/data/chodera/lilywang/datasets/xff/output/xff-td-dataset")
input_dataset.schema
# Out:
# ATOM: list<item: double>
#   child 0, item: double
# frozen_atoms: list<item: int64>
#   child 0, item: int64
# frozen_0: int64
# frozen_1: int64
# frozen_2: int64
# frozen_3: int64
# angle: int64
# CORE_TIME: double
# INPUT_MOLECULE: list<item: double>
#   child 0, item: double
# FINGERPRINT: string
# CA_TYPE: string
# ENERGY: double
# filename: string
# directory: string
# parent: string
# smiles: string
# mapped_smiles: string
# n_atoms: int64
# atomic_numbers: list<item: int64>
#   child 0, item: int64

# %%
from openff.toolkit import Molecule
from openff.units import unit
import numpy as np

from openff.qcsubmit.workflow_components import TorsionIndexer

columns = [
    "mapped_smiles", "ATOM", "ENERGY",
    "frozen_atoms", "frozen_0", "frozen_1", "frozen_2", "frozen_3",
]
df = input_dataset.to_table(columns=columns).to_pandas()
all_molecules = []
# sort by torsion scan and take lowest energy conformer
groupby = ["mapped_smiles", "frozen_0", "frozen_1", "frozen_2", "frozen_3"]
for (mapped_smiles, *_), subdf in df.groupby(by=groupby):
    mol = Molecule.from_mapped_smiles(
        mapped_smiles,
        allow_undefined_stereo=True,
    )
    subdf = subdf.sort_values("ENERGY")
    conformer = np.array(subdf.ATOM.values[0]).reshape((-1, 3))
    mol._conformers = [conformer * unit.angstrom]
    
    torsion_indexer = TorsionIndexer()
    # frozen atoms indexes from 1
    frozen_atoms = tuple(
        [atom - 1 for atom in subdf.frozen_atoms.values[0]]
    )
    assert max(frozen_atoms) < len(mol.atoms)
    torsion_indexer.add_torsion(frozen_atoms, (0, 3), (-165, 180))
    mol.properties["dihedrals"] = torsion_indexer
    
    all_molecules.append(mol)

len(all_molecules)
# Out:
# 424

# %%
dataset = dataset_factory.create_dataset(
    dataset_name="XtalPi Shared Fragments TorsiondriveDataset v1.0",
    tagline="B3LYP-D3BJ/DZVP torsion drive of fragments shared by XtalPi.",
    description=(
        "A dataset containing representative fragments shared by XtalPi "
        "used in fitting the XFF force field "
        "(DOI: 10.1021/acs.jctc.3c00920). "
        "Conformers are the post-optimization geometries shared by XtalPi. "
        "Each conformer will be converged according to the 'GAU_LOOSE' criteria."
    ),
    molecules=all_molecules
)
dataset.metadata.submitter = "lilyminium"
dataset.metadata.long_description_url = (
    "https://github.com/openforcefield/qca-dataset-submission/tree/master/"
    "submissions/"
    "2024-01-30-xtalpi-shared-fragments-torsiondrive-v1.0"
)
# Out:
# Deduplication                 : 100%|████████| 424/424 [00:02<00:00, 177.47it/s]
# Preparation                   : 100%|█████████| 170/170 [00:09<00:00, 18.48it/s]

# %%
dataset.dict()
# Out:
# {'qc_specifications': {'default': {'method': 'B3LYP-D3BJ',
#    'basis': 'DZVP',
#    'program': 'psi4',
#    'spec_name': 'default',
#    'spec_description': 'Standard OpenFF optimization quantum chemistry specification.',
#    'store_wavefunction': 'none',
#    'implicit_solvent': None,
#    'maxiter': 200,
#    'scf_properties': ['dipole',
#     'quadrupole',
#     'wiberg_lowdin_indices',
#     'mayer_indices'],
#    'keywords': {}}},
#  'driver': 'deferred',
#  'priority': 'normal',
#  'dataset_tags': ['openff'],
#  'compute_tag': 'openff',
#  'dataset_name': 'XtalPi Shared Fragments TorsiondriveDataset v1.0',
#  'dataset_tagline': 'B3LYP-D3BJ/DZVP torsion drive of fragments shared by XtalPi.',
#  'type': 'TorsionDriveDataset',
#  'description': "A dataset containing representative fragments shared by XtalPi used in fitting the XFF force field (DOI: 10.1021/acs.jctc.3c00920). Conformers are the post-optimization geometries shared by XtalPi. Each conformer will be converged according to the 'GAU_LOOSE' criteria.",
#  'metadata': {'submitter': 'lilyminium',
#   'creation_date': datetime.date(2024, 1, 31),
#   'collection_type': 'TorsionDriveDataset',
#   'dataset_name': 'XtalPi Shared Fragments TorsiondriveDataset v1.0',
#   'short_description': 'B3LYP-D3BJ/DZVP torsion drive of fragments shared by XtalPi.',
#   'long_description_url': HttpUrl('https://github.com/openforcefield/qca-dataset-submission/tree/master/submissions/2024-01-30-xtalpi-shared-fragments-torsiondrive-v1.0', ),
#   'long_description': "A dataset containing representative fragments shared by XtalPi used in fitting the XFF force field (DOI: 10.1021/acs.jctc.3c00920). Conformers are the post-optimization geometries shared by XtalPi. Each conformer will be converged according to the 'GAU_LOOSE' criteria.",
#   'elements': {'Br', 'C', 'Cl', 'F', 'H', 'N', 'O', 'P', 'S'}},
#  'provenance': {'openff-qcsubmit': '0.50.2',
#   'openff-toolkit': '0.15.0',
#   'OpenEyeToolkitWrapper': '2022.1.1',
#   'RDKitToolkitWrapper': '2023.09.4',
#   'AmberToolsToolkitWrapper': '22.0'},
#  'dataset': {'[H][C:1](=[C:2]([H])[N:3]([H])[C:4]([H])([H])[C@@]1(C(C(C(O1)([H])[H])([H])[H])([H])[H])[H])[H]': {'index': '[H][C:1](=[C:2]([H])[N:3]([H])[C:4]([H])([H])[C@@]1(C(C(C(O1)([H])[H])([H])[H])([H])[H])[H])[H]',
#    'initial_molecules': [{'schema_name': 'qcschema_molecule',
#      'schema_version': 2,
#      'validated': True,
#      'symbols': array(['C', 'C', 'C', 'C', 'C', 'C', 'C', 'N', 'O', 'H', 'H', 'H', 'H',
#             'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H'], dtype='<U1'),
#      'geometry': array([[-6.89069734,  0.02173185,  0.23092453],
#             [-4.95051553,  1.1895826 , -0.91557231],
#             [ 4.33881118,  1.99177134,  0.2373496 ],
#             [ 2.4950054 ,  0.95393375,  2.24990792],
#             [ 4.73622059, -0.30349002, -1.48230117],
#             [-1.53615837, -1.4800335 ,  0.8052123 ],
#             [ 1.34246144, -1.44545151,  1.00193279],
#             [-2.40373163,  0.5996101 , -0.74077264],
#             [ 2.34855163, -1.54825261, -1.51858391],
#             [-8.78968312,  0.76401627,  0.03155843],
#             [-6.65164699, -1.61836145,  1.43789261],
#             [-5.31069733,  2.79868439, -2.14786271],
#             [ 6.10343744,  2.71326877,  1.03934937],
#             [ 3.44893915,  3.52263847, -0.83450306],
#             [ 3.48522189,  0.45183352,  3.99582589],
#             [ 1.0266882 ,  2.32852053,  2.71912692],
#             [ 5.23321856,  0.16346131, -3.43363237],
#             [ 6.20245909, -1.56960652, -0.71337161],
#             [-2.15390984, -3.33158716,  0.06821911],
#             [-2.34439423, -1.28293507,  2.70419808],
#             [ 1.94774072, -3.14658297,  2.03674682],
#             [-1.36910658,  0.82656621, -2.33437868]]),
#      'name': 'C7H13NO',
#      'identifiers': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:10][C:1](=[C:2]([H:12])[N:8]([H:22])[C:6]([H:19])([H:20])[C@@:7]1([C:4]([C:3]([C:5]([O:9]1)([H:17])[H:18])([H:13])[H:14])([H:15])[H:16])[H:21])[H:11]'},
#      'molecular_charge': 0.0,
#      'molecular_multiplicity': 1,
#      'connectivity': [(0, 1, 2.0),
#       (0, 9, 1.0),
#       (0, 10, 1.0),
#       (1, 7, 1.0),
#       (1, 11, 1.0),
#       (2, 3, 1.0),
#       (2, 4, 1.0),
#       (2, 12, 1.0),
#       (2, 13, 1.0),
#       (3, 6, 1.0),
#       (3, 14, 1.0),
#       (3, 15, 1.0),
#       (4, 8, 1.0),
#       (4, 16, 1.0),
#       (4, 17, 1.0),
#       (5, 6, 1.0),
#       (5, 7, 1.0),
#       (5, 18, 1.0),
#       (5, 19, 1.0),
#       (6, 8, 1.0),
#       (6, 20, 1.0),
#       (7, 21, 1.0)],
#      'fix_com': False,
#      'fix_orientation': False,
#      'fix_symmetry': 'c1',
#      'provenance': {'creator': 'QCElemental',
#       'version': '0.27.1',
#       'routine': 'qcelemental.molparse.from_schema'},
#      'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:10][C:1](=[C:2]([H:12])[N:8]([H:22])[C:6]([H:19])([H:20])[C@@:7]1([C:4]([C:3]([C:5]([O:9]1)([H:17])[H:18])([H:13])[H:14])([H:15])[H:16])[H:21])[H:11]'}},
#     {'schema_name': 'qcschema_molecule',
#      'schema_version': 2,
#      'validated': True,
#      'symbols': array(['C', 'C', 'C', 'C', 'C', 'C', 'C', 'N', 'O', 'H', 'H', 'H', 'H',
#             'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H'], dtype='<U1'),
#      'geometry': array([[ 5.2791389 , -2.33796916, -0.51627318],
#             [ 4.29440262, -0.15155604,  0.31634015],
#             [-2.53544554, -2.71856   ,  0.58260256],
#             [-1.72021769, -0.6154838 ,  2.42451862],
#             [-4.02133719, -1.22794404, -1.3993422 ],
#             [ 0.8728645 ,  3.0490731 ,  0.32352111],
#             [-1.71492646,  1.81545989,  0.77459874],
#             [ 2.67415144,  1.44375076, -0.98681498],
#             [-2.67944267,  1.09396245, -1.66144721],
#             [ 6.66827658, -3.34198065,  0.60395647],
#             [ 4.79158956, -3.13033133, -2.34836266],
#             [ 4.84733648,  0.59110633,  2.15655545],
#             [-3.65510827, -4.20464063,  1.48608062],
#             [-0.87191963, -3.59577087, -0.28270303],
#             [-3.08025358, -0.41819639,  3.97220431],
#             [ 0.12925727, -1.00023204,  3.26072243],
#             [-4.09824905, -2.12178449, -3.26242318],
#             [-5.97323531, -0.87418731, -0.76004785],
#             [ 0.57447674,  4.7664562 , -0.80029901],
#             [ 1.69300564,  3.63715587,  2.1327449 ],
#             [-2.97896426,  3.24730537,  1.6049444 ],
#             [ 1.94358332,  0.70845832, -2.59969623]]),
#      'name': 'C7H13NO',
#      'identifiers': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:10][C:1](=[C:2]([H:12])[N:8]([H:22])[C:6]([H:19])([H:20])[C@@:7]1([C:4]([C:3]([C:5]([O:9]1)([H:17])[H:18])([H:13])[H:14])([H:15])[H:16])[H:21])[H:11]'},
#      'molecular_charge': 0.0,
#      'molecular_multiplicity': 1,
#      'connectivity': [(0, 1, 2.0),
#       (0, 9, 1.0),
#       (0, 10, 1.0),
#       (1, 7, 1.0),
#       (1, 11, 1.0),
#       (2, 3, 1.0),
#       (2, 4, 1.0),
#       (2, 12, 1.0),
#       (2, 13, 1.0),
#       (3, 6, 1.0),
#       (3, 14, 1.0),
#       (3, 15, 1.0),
#       (4, 8, 1.0),
#       (4, 16, 1.0),
#       (4, 17, 1.0),
#       (5, 6, 1.0),
#       (5, 7, 1.0),
#       (5, 18, 1.0),
#       (5, 19, 1.0),
#       (6, 8, 1.0),
#       (6, 20, 1.0),
#       (7, 21, 1.0)],
#      'fix_com': False,
#      'fix_orientation': False,
#      'fix_symmetry': 'c1',
#      'provenance': {'creator': 'QCElemental',
#       'version': '0.27.1',
#       'routine': 'qcelemental.molparse.from_schema'},
#      'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:10][C:1](=[C:2]([H:12])[N:8]([H:22])[C:6]([H:19])([H:20])[C@@:7]1([C:4]([C:3]([C:5]([O:9]1)([H:17])[H:18])([H:13])[H:14])([H:15])[H:16])[H:21])[H:11]'}},
#     {'schema_name': 'qcschema_molecule',
#      'schema_version': 2,
#      'validated': True,
#      'symbols': array(['C', 'C', 'C', 'C', 'C', 'C', 'C', 'N', 'O', 'H', 'H', 'H', 'H',
#             'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H'], dtype='<U1'),
#      'geometry': array([[ 6.80849425, -1.68884824,  0.01190527],
#             [ 5.09734725,  0.12018658,  0.47961249],
#             [-3.90644184, -1.6262983 ,  1.69224974],
#             [-2.69342665,  0.98341348,  2.1707284 ],
#             [-4.41402228, -1.55429974, -1.15594547],
#             [ 1.13043417,  2.26313601, -0.65006579],
#             [-1.71360365,  1.81300324, -0.47110872],
#             [ 2.50936732, -0.01398397,  0.04081808],
#             [-2.32493005, -0.20238967, -2.1866021 ],
#             [ 8.75963648, -1.44790816,  0.58562613],
#             [ 6.30488224, -3.46197826, -0.89667505],
#             [ 5.67409166,  1.87800982,  1.38535822],
#             [-5.61645501, -1.95000839,  2.81002275],
#             [-2.55698842, -3.13448872,  2.12405216],
#             [-4.0861548 ,  2.34042581,  2.87880878],
#             [-1.15178807,  0.86700635,  3.53983498],
#             [-4.4697692 , -3.4113336 , -2.06244709],
#             [-6.1996245 , -0.5637053 , -1.57433083],
#             [ 1.58510227,  2.91924892, -2.57588568],
#             [ 1.65823467,  3.78436554,  0.65611291],
#             [-2.69021411,  3.54418135, -1.08961608],
#             [ 1.97003948, -1.50630069, -1.03689272]]),
#      'name': 'C7H13NO',
#      'identifiers': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:10][C:1](=[C:2]([H:12])[N:8]([H:22])[C:6]([H:19])([H:20])[C@@:7]1([C:4]([C:3]([C:5]([O:9]1)([H:17])[H:18])([H:13])[H:14])([H:15])[H:16])[H:21])[H:11]'},
#      'molecular_charge': 0.0,
#      'molecular_multiplicity': 1,
#      'connectivity': [(0, 1, 2.0),
#       (0, 9, 1.0),
#       (0, 10, 1.0),
#       (1, 7, 1.0),
#       (1, 11, 1.0),
#       (2, 3, 1.0),
#       (2, 4, 1.0),
#       (2, 12, 1.0),
#       (2, 13, 1.0),
#       (3, 6, 1.0),
#       (3, 14, 1.0),
#       (3, 15, 1.0),
#       (4, 8, 1.0),
#       (4, 16, 1.0),
#       (4, 17, 1.0),
#       (5, 6, 1.0),
#       (5, 7, 1.0),
#       (5, 18, 1.0),
#       (5, 19, 1.0),
#       (6, 8, 1.0),
#       (6, 20, 1.0),
#       (7, 21, 1.0)],
#      'fix_com': False,
#      'fix_orientation': False,
#      'fix_symmetry': 'c1',
#      'provenance': {'creator': 'QCElemental',
#       'version': '0.27.1',
#       'routine': 'qcelemental.molparse.from_schema'},
#      'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:10][C:1](=[C:2]([H:12])[N:8]([H:22])[C:6]([H:19])([H:20])[C@@:7]1([C:4]([C:3]([C:5]([O:9]1)([H:17])[H:18])([H:13])[H:14])([H:15])[H:16])[H:21])[H:11]'}}],
#    'attributes': {'canonical_smiles': 'C=CNCC1CCCO1',
#     'canonical_isomeric_smiles': 'C=CNC[C@@H]1CCCO1',
#     'canonical_explicit_hydrogen_smiles': '[H]C(=C([H])N([H])C([H])([H])C1(C(C(C(O1)([H])[H])([H])[H])([H])[H])[H])[H]',
#     'canonical_isomeric_explicit_hydrogen_smiles': '[H]C(=C([H])N([H])C([H])([H])[C@@]1(C(C(C(O1)([H])[H])([H])[H])([H])[H])[H])[H]',
#     'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:10][C:1](=[C:2]([H:12])[N:8]([H:22])[C:6]([H:19])([H:20])[C@@:7]1([C:4]([C:3]([C:5]([O:9]1)([H:17])[H:18])([H:13])[H:14])([H:15])[H:16])[H:21])[H:11]',
#     'molecular_formula': 'C7H13NO',
#     'standard_inchi': 'InChI=1S/C7H13NO/c1-2-8-6-7-4-3-5-9-7/h2,7-8H,1,3-6H2/t7-/m0/s1',
#     'inchi_key': 'WIPOXTDSTNBLNV-ZETCQYMHSA-N',
#     'fixed_hydrogen_inchi': 'InChI=1/C7H13NO/c1-2-8-6-7-4-3-5-9-7/h2,7-8H,1,3-6H2/t7-/m0/s1',
#     'fixed_hydrogen_inchi_key': 'WIPOXTDSTNBLNV-ZETCQYMHNA-N',
#     'unique_fixed_hydrogen_inchi_keys': {'WIPOXTDSTNBLNV-ZETCQYMHNA-N'}},
#    'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:10][C:1](=[C:2]([H:12])[N:8]([H:22])[C:6]([H:19])([H:20])[C@@:7]1([C:4]([C:3]([C:5]([O:9]1)([H:17])[H:18])([H:13])[H:14])([H:15])[H:16])[H:21])[H:11]'},
#    'keywords': {'grid_spacing': [15],
#     'dihedral_ranges': [(-165, 180)],
#     'energy_decrease_thresh': None,
#     'energy_upper_limit': None,
#     'additional_keywords': {}},
#    'constraints': {},
#    'dihedrals': [(0, 1, 7, 5)]},
#   '[H][C:2](=[S:1])[N:3]=[C:4]1N(C(=N[H])N(S1)[H])[H]': {'index': '[H][C:2](=[S:1])[N:3]=[C:4]1N(C(=N[H])N(S1)[H])[H]',
#    'initial_molecules': [{'schema_name': 'qcschema_molecule',
#      'schema_version': 2,
#      'validated': True,
#      'symbols': array(['C', 'C', 'C', 'N', 'N', 'N', 'N', 'S', 'S', 'H', 'H', 'H', 'H'],
#            dtype='<U1'),
#      'geometry': array([[-4.19462508e+00,  2.05545511e+00,  2.83459000e-03],
#             [ 4.40041625e+00,  1.68941520e-01,  6.99199000e-03],
#             [ 4.06291100e-02,  1.23021171e+00, -6.97308900e-02],
#             [ 6.69586658e+00,  8.73998330e-01,  2.60593230e-01],
#             [-1.81168044e+00,  2.90091857e+00, -7.88015800e-02],
#             [ 2.46798232e+00,  1.99347209e+00, -1.00911380e-01],
#             [ 3.24919510e+00, -2.15202011e+00, -2.67018300e-01],
#             [-5.11435478e+00, -9.71697170e-01,  1.18485830e-01],
#             [-1.97098430e-01, -2.09854086e+00, -5.78256200e-02],
#             [-5.62476981e+00,  3.53794525e+00, -1.00155500e-02],
#             [ 7.89905520e+00, -6.31546470e-01,  2.67585220e-01],
#             [ 2.90602083e+00,  3.85617513e+00, -5.76366500e-02],
#             [ 4.11261097e+00, -3.68288724e+00,  4.91517770e-01]]),
#      'name': 'C3H4N4S2',
#      'identifiers': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:10][C:1](=[S:8])[N:5]=[C:3]1[N:6]([C:2](=[N:4][H:11])[N:7]([S:9]1)[H:13])[H:12]'},
#      'molecular_charge': 0.0,
#      'molecular_multiplicity': 1,
#      'connectivity': [(0, 4, 1.0),
#       (0, 7, 2.0),
#       (0, 9, 1.0),
#       (1, 3, 2.0),
#       (1, 5, 1.0),
#       (1, 6, 1.0),
#       (2, 4, 2.0),
#       (2, 5, 1.0),
#       (2, 8, 1.0),
#       (3, 10, 1.0),
#       (5, 11, 1.0),
#       (6, 8, 1.0),
#       (6, 12, 1.0)],
#      'fix_com': False,
#      'fix_orientation': False,
#      'fix_symmetry': 'c1',
#      'provenance': {'creator': 'QCElemental',
#       'version': '0.27.1',
#       'routine': 'qcelemental.molparse.from_schema'},
#      'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:10][C:1](=[S:8])[N:5]=[C:3]1[N:6]([C:2](=[N:4][H:11])[N:7]([S:9]1)[H:13])[H:12]'}}],
#    'attributes': {'canonical_smiles': 'C(=S)N=C1NC(=N)NS1',
#     'canonical_isomeric_smiles': 'C(=S)N=C1NC(=N)NS1',
#     'canonical_explicit_hydrogen_smiles': '[H]C(=S)N=C1N(C(=N[H])N(S1)[H])[H]',
#     'canonical_isomeric_explicit_hydrogen_smiles': '[H]C(=S)N=C1N(C(=N[H])N(S1)[H])[H]',
#     'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:10][C:1](=[S:8])[N:5]=[C:3]1[N:6]([C:2](=[N:4][H:11])[N:7]([S:9]1)[H:13])[H:12]',
#     'molecular_formula': 'C3H4N4S2',
#     'standard_inchi': 'InChI=1S/C3H4N4S2/c4-2-6-3(5-1-8)9-7-2/h1H,(H3,4,5,6,7,8)',
#     'inchi_key': 'SZSQKSWULGXXCB-UHFFFAOYSA-N',
#     'fixed_hydrogen_inchi': 'InChI=1/C3H4N4S2/c4-2-6-3(5-1-8)9-7-2/h1H,(H3,4,5,6,7,8)/f/h4,6-7H/b4-2-,5-3-',
#     'fixed_hydrogen_inchi_key': 'SZSQKSWULGXXCB-OKJXGGGSNA-N',
#     'unique_fixed_hydrogen_inchi_keys': {'SZSQKSWULGXXCB-OKJXGGGSNA-N'}},
#    'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:10][C:1](=[S:8])[N:5]=[C:3]1[N:6]([C:2](=[N:4][H:11])[N:7]([S:9]1)[H:13])[H:12]'},
#    'keywords': {'grid_spacing': [15],
#     'dihedral_ranges': [(-165, 180)],
#     'energy_decrease_thresh': None,
#     'energy_upper_limit': None,
#     'additional_keywords': {}},
#    'constraints': {},
#    'dihedrals': [(7, 0, 4, 2)]},
#   '[H]C1=C([N:1]([C:2](=C1[H])[S:3](=O)(=O)[O:4][H])[H])[H]': {'index': '[H]C1=C([N:1]([C:2](=C1[H])[S:3](=O)(=O)[O:4][H])[H])[H]',
#    'initial_molecules': [{'schema_name': 'qcschema_molecule',
#      'schema_version': 2,
#      'validated': True,
#      'symbols': array(['C', 'C', 'C', 'C', 'N', 'O', 'O', 'O', 'S', 'H', 'H', 'H', 'H',
#             'H'], dtype='<U1'),
#      'geometry': array([[-5.07448156, -1.32450904,  0.07332137],
#             [-2.57720849, -2.26767135, -0.1124387 ],
#             [-4.93086238,  1.2882263 ,  0.15004425],
#             [-0.9956967 , -0.18519316, -0.14853247],
#             [-2.4460615 ,  1.96418133,  0.03420404],
#             [ 3.18494441, -0.07634494,  2.71440261],
#             [ 3.31098914, -2.21872744, -1.47360843],
#             [ 2.88258823,  2.6040426 , -1.09528526],
#             [ 2.29091498,  0.04403062, -0.26739625],
#             [-6.7929985 , -2.4281091 ,  0.12717857],
#             [-1.9823227 , -4.21749076, -0.23375912],
#             [-6.39993547,  2.70230836,  0.25756967],
#             [-1.73098913,  3.73296499, -0.06387274],
#             [ 3.81724677, -1.78257865,  3.01165652]]),
#      'name': 'C4H5NO3S',
#      'identifiers': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:10][C:1]1=[C:3]([N:5]([C:4](=[C:2]1[H:11])[S:9](=[O:7])(=[O:8])[O:6][H:14])[H:13])[H:12]'},
#      'molecular_charge': 0.0,
#      'molecular_multiplicity': 1,
#      'connectivity': [(0, 1, 1.0),
#       (0, 2, 2.0),
#       (0, 9, 1.0),
#       (1, 3, 2.0),
#       (1, 10, 1.0),
#       (2, 4, 1.0),
#       (2, 11, 1.0),
#       (3, 4, 1.0),
#       (3, 8, 1.0),
#       (4, 12, 1.0),
#       (5, 8, 1.0),
#       (5, 13, 1.0),
#       (6, 8, 2.0),
#       (7, 8, 2.0)],
#      'fix_com': False,
#      'fix_orientation': False,
#      'fix_symmetry': 'c1',
#      'provenance': {'creator': 'QCElemental',
#       'version': '0.27.1',
#       'routine': 'qcelemental.molparse.from_schema'},
#      'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:10][C:1]1=[C:3]([N:5]([C:4](=[C:2]1[H:11])[S:9](=[O:7])(=[O:8])[O:6][H:14])[H:13])[H:12]'}},
#     {'schema_name': 'qcschema_molecule',
#      'schema_version': 2,
#      'validated': True,
#      'symbols': array(['C', 'C', 'C', 'C', 'N', 'O', 'O', 'O', 'S', 'H', 'H', 'H', 'H',
#             'H'], dtype='<U1'),
#      'geometry': array([[-5.07750512, -1.29975363,  0.0814472 ],
#             [-2.58590123, -2.25935655, -0.10809233],
#             [-4.91744532,  1.31203685,  0.13946179],
#             [-0.99172827, -0.18689391, -0.16724076],
#             [-2.42867602,  1.97249613,  0.01001555],
#             [ 3.17681859,  0.11772994,  2.71534747],
#             [ 3.29190291, -2.33343382, -1.32356418],
#             [ 2.93644543,  2.5088004 , -1.24136109],
#             [ 2.2990408 ,  0.01266117, -0.27041981],
#             [-6.80244713, -2.39239327,  0.14909939],
#             [-2.0023538 , -4.21295542, -0.22223179],
#             [-6.37782567,  2.73575651,  0.23961727],
#             [-1.70661166,  3.73731136, -0.10884822],
#             [ 3.30040668, -1.61987323,  3.32081572]]),
#      'name': 'C4H5NO3S',
#      'identifiers': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:10][C:1]1=[C:3]([N:5]([C:4](=[C:2]1[H:11])[S:9](=[O:7])(=[O:8])[O:6][H:14])[H:13])[H:12]'},
#      'molecular_charge': 0.0,
#      'molecular_multiplicity': 1,
#      'connectivity': [(0, 1, 1.0),
#       (0, 2, 2.0),
#       (0, 9, 1.0),
#       (1, 3, 2.0),
#       (1, 10, 1.0),
#       (2, 4, 1.0),
#       (2, 11, 1.0),
#       (3, 4, 1.0),
#       (3, 8, 1.0),
#       (4, 12, 1.0),
#       (5, 8, 1.0),
#       (5, 13, 1.0),
#       (6, 8, 2.0),
#       (7, 8, 2.0)],
#      'fix_com': False,
#      'fix_orientation': False,
#      'fix_symmetry': 'c1',
#      'provenance': {'creator': 'QCElemental',
#       'version': '0.27.1',
#       'routine': 'qcelemental.molparse.from_schema'},
#      'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:10][C:1]1=[C:3]([N:5]([C:4](=[C:2]1[H:11])[S:9](=[O:7])(=[O:8])[O:6][H:14])[H:13])[H:12]'}}],
#    'attributes': {'canonical_smiles': 'C1=CNC(=C1)S(=O)(=O)O',
#     'canonical_isomeric_smiles': 'C1=CNC(=C1)S(=O)(=O)O',
#     'canonical_explicit_hydrogen_smiles': '[H]C1=C(N(C(=C1[H])S(=O)(=O)O[H])[H])[H]',
#     'canonical_isomeric_explicit_hydrogen_smiles': '[H]C1=C(N(C(=C1[H])S(=O)(=O)O[H])[H])[H]',
#     'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:10][C:1]1=[C:3]([N:5]([C:4](=[C:2]1[H:11])[S:9](=[O:7])(=[O:8])[O:6][H:14])[H:13])[H:12]',
#     'molecular_formula': 'C4H5NO3S',
#     'standard_inchi': 'InChI=1S/C4H5NO3S/c6-9(7,8)4-2-1-3-5-4/h1-3,5H,(H,6,7,8)',
#     'inchi_key': 'KKQCQCXUVZBOCL-UHFFFAOYSA-N',
#     'fixed_hydrogen_inchi': 'InChI=1/C4H5NO3S/c6-9(7,8)4-2-1-3-5-4/h1-3,5H,(H,6,7,8)/f/h6H',
#     'fixed_hydrogen_inchi_key': 'KKQCQCXUVZBOCL-BRMMOCHJNA-N',
#     'unique_fixed_hydrogen_inchi_keys': {'KKQCQCXUVZBOCL-BRMMOCHJNA-N'}},
#    'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:10][C:1]1=[C:3]([N:5]([C:4](=[C:2]1[H:11])[S:9](=[O:7])(=[O:8])[O:6][H:14])[H:13])[H:12]'},
#    'keywords': {'grid_spacing': [15],
#     'dihedral_ranges': [(-165, 180)],
#     'energy_decrease_thresh': None,
#     'energy_upper_limit': None,
#     'additional_keywords': {}},
#    'constraints': {},
#    'dihedrals': [(4, 3, 8, 5)]},
#   '[H]C1=[C:1](ON=C1[H])[C:2]([H])([H])[S:3](=[O:4])(=O)[H]': {'index': '[H]C1=[C:1](ON=C1[H])[C:2]([H])([H])[S:3](=[O:4])(=O)[H]',
#    'initial_molecules': [{'schema_name': 'qcschema_molecule',
#      'schema_version': 2,
#      'validated': True,
#      'symbols': array(['C', 'C', 'C', 'C', 'N', 'O', 'O', 'O', 'S', 'H', 'H', 'H', 'H',
#             'H'], dtype='<U1'),
#      'geometry': array([[-3.15244112,  1.81413708,  1.09093889],
#             [-5.40839617,  1.19279513, -0.22752303],
#             [ 0.85132162, -1.03462505,  1.69735201],
#             [-1.73231194, -0.32559981,  0.88382491],
#             [-5.36342069, -1.10624567, -1.16048081],
#             [ 3.15905516,  2.80095206, -0.69107284],
#             [ 5.64253324, -1.28652555,  0.1145174 ],
#             [-3.01297933, -2.08417894, -0.46600646],
#             [ 3.29946181,  0.04195192, -0.51967468],
#             [-2.65695493,  3.56307861,  2.01577086],
#             [-7.07135516,  2.3466619 , -0.52685564],
#             [ 1.37950007, -0.13927282,  3.484466  ],
#             [ 1.06864012, -3.08176536,  1.86799427],
#             [ 2.37349601, -0.93994977, -2.73216603]]),
#      'name': 'C4H5NO3S',
#      'identifiers': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:10][C:1]1=[C:4]([O:8][N:5]=[C:2]1[H:11])[C:3]([H:12])([H:13])[S:9](=[O:6])(=[O:7])[H:14]'},
#      'molecular_charge': 0.0,
#      'molecular_multiplicity': 1,
#      'connectivity': [(0, 1, 1.0),
#       (0, 3, 2.0),
#       (0, 9, 1.0),
#       (1, 4, 2.0),
#       (1, 10, 1.0),
#       (2, 3, 1.0),
#       (2, 8, 1.0),
#       (2, 11, 1.0),
#       (2, 12, 1.0),
#       (3, 7, 1.0),
#       (4, 7, 1.0),
#       (5, 8, 2.0),
#       (6, 8, 2.0),
#       (8, 13, 1.0)],
#      'fix_com': False,
#      'fix_orientation': False,
#      'fix_symmetry': 'c1',
#      'provenance': {'creator': 'QCElemental',
#       'version': '0.27.1',
#       'routine': 'qcelemental.molparse.from_schema'},
#      'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:10][C:1]1=[C:4]([O:8][N:5]=[C:2]1[H:11])[C:3]([H:12])([H:13])[S:9](=[O:6])(=[O:7])[H:14]'}},
#     {'schema_name': 'qcschema_molecule',
#      'schema_version': 2,
#      'validated': True,
#      'symbols': array(['C', 'C', 'C', 'C', 'N', 'O', 'O', 'O', 'S', 'H', 'H', 'H', 'H',
#             'H'], dtype='<U1'),
#      'geometry': array([[-3.15263009,  1.81394811,  1.09112786],
#             [-5.40839617,  1.19279513, -0.22733405],
#             [ 0.85132162, -1.03443608,  1.69735201],
#             [-1.73231194, -0.32559981,  0.88382491],
#             [-5.36342069, -1.10624567, -1.16066979],
#             [ 3.15905516,  2.80095206, -0.69145079],
#             [ 5.64253324, -1.28652555,  0.11489535],
#             [-3.01279036, -2.08417894, -0.46619543],
#             [ 3.29946181,  0.04195192, -0.51967468],
#             [-2.6571439 ,  3.56288964,  2.01633777],
#             [-7.07135516,  2.3466619 , -0.52666667],
#             [ 1.37968904, -0.13927282,  3.484466  ],
#             [ 1.06864012, -3.08157639,  1.8678053 ],
#             [ 2.37368499, -0.94013875, -2.73216603]]),
#      'name': 'C4H5NO3S',
#      'identifiers': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:10][C:1]1=[C:4]([O:8][N:5]=[C:2]1[H:11])[C:3]([H:12])([H:13])[S:9](=[O:6])(=[O:7])[H:14]'},
#      'molecular_charge': 0.0,
#      'molecular_multiplicity': 1,
#      'connectivity': [(0, 1, 1.0),
#       (0, 3, 2.0),
#       (0, 9, 1.0),
#       (1, 4, 2.0),
#       (1, 10, 1.0),
#       (2, 3, 1.0),
#       (2, 8, 1.0),
#       (2, 11, 1.0),
#       (2, 12, 1.0),
#       (3, 7, 1.0),
#       (4, 7, 1.0),
#       (5, 8, 2.0),
#       (6, 8, 2.0),
#       (8, 13, 1.0)],
#      'fix_com': False,
#      'fix_orientation': False,
#      'fix_symmetry': 'c1',
#      'provenance': {'creator': 'QCElemental',
#       'version': '0.27.1',
#       'routine': 'qcelemental.molparse.from_schema'},
#      'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:10][C:1]1=[C:4]([O:8][N:5]=[C:2]1[H:11])[C:3]([H:12])([H:13])[S:9](=[O:6])(=[O:7])[H:14]'}}],
#    'attributes': {'canonical_smiles': 'C1=C(ON=C1)CS(=O)=O',
#     'canonical_isomeric_smiles': 'C1=C(ON=C1)CS(=O)=O',
#     'canonical_explicit_hydrogen_smiles': '[H]C1=C(ON=C1[H])C([H])([H])S(=O)(=O)[H]',
#     'canonical_isomeric_explicit_hydrogen_smiles': '[H]C1=C(ON=C1[H])C([H])([H])S(=O)(=O)[H]',
#     'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:10][C:1]1=[C:4]([O:8][N:5]=[C:2]1[H:11])[C:3]([H:12])([H:13])[S:9](=[O:6])(=[O:7])[H:14]',
#     'molecular_formula': 'C4H5NO3S',
#     'standard_inchi': 'InChI=1S/C4H5NO3S/c6-9(7)3-4-1-2-5-8-4/h1-2,9H,3H2',
#     'inchi_key': 'QVIHVYSDESGQOW-UHFFFAOYSA-N',
#     'fixed_hydrogen_inchi': 'InChI=1/C4H5NO3S/c6-9(7)3-4-1-2-5-8-4/h1-2,9H,3H2',
#     'fixed_hydrogen_inchi_key': 'QVIHVYSDESGQOW-UHFFFAOYNA-N',
#     'unique_fixed_hydrogen_inchi_keys': {'QVIHVYSDESGQOW-UHFFFAOYNA-N'}},
#    'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:10][C:1]1=[C:4]([O:8][N:5]=[C:2]1[H:11])[C:3]([H:12])([H:13])[S:9](=[O:6])(=[O:7])[H:14]'},
#    'keywords': {'grid_spacing': [15],
#     'dihedral_ranges': [(-165, 180)],
#     'energy_decrease_thresh': None,
#     'energy_upper_limit': None,
#     'additional_keywords': {}},
#    'constraints': {},
#    'dihedrals': [(3, 2, 8, 5)]},
#   '[H][C:1]([H])([H])[C:2](C([H])([H])[H])(C([H])([H])OP(=O)([O-])[O-])[O:3][H:4]': {'index': '[H][C:1]([H])([H])[C:2](C([H])([H])[H])(C([H])([H])OP(=O)([O-])[O-])[O:3][H:4]',
#    'initial_molecules': [{'schema_name': 'qcschema_molecule',
#      'schema_version': 2,
#      'validated': True,
#      'symbols': array(['C', 'C', 'C', 'C', 'O', 'O', 'O', 'O', 'O', 'P', 'H', 'H', 'H',
#             'H', 'H', 'H', 'H', 'H', 'H'], dtype='<U1'),
#      'geometry': array([[-5.82886023,  1.65162063, -0.22072001],
#             [-4.07500542, -2.77147233, -0.65630188],
#             [-1.36173665,  1.02649923, -1.74119365],
#             [-3.44950607, -0.01001555,  0.0614161 ],
#             [-2.71062315,  0.11017103,  2.61821555],
#             [ 4.01831363,  2.82098316, -0.37246502],
#             [ 5.21299849, -1.99025955, -0.65233346],
#             [ 1.99970819, -0.40043297,  2.73896905],
#             [ 0.76250449, -0.538194  , -1.96626003],
#             [ 3.31212298,  0.04610932,  0.11036001],
#             [-7.26127263,  1.04615238,  1.15348883],
#             [-6.64578884,  1.53559145, -2.12915442],
#             [-5.35453897,  3.62997491,  0.18103576],
#             [-2.35422081, -3.90115061, -0.48036838],
#             [-4.76607826, -2.93115419, -2.61330226],
#             [-5.52404741, -3.51583545,  0.63211339],
#             [-2.21683772,  1.23210143, -3.64414786],
#             [-0.82278675,  2.92794166, -1.08243512],
#             [-0.710726  , -0.11262768,  2.73840213]]),
#      'name': 'C4H9O5P',
#      'identifiers': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:11][C:1]([H:12])([H:13])[C:4]([C:2]([H:14])([H:15])[H:16])([C:3]([H:17])([H:18])[O:9][P:10](=[O:6])([O-:7])[O-:8])[O:5][H:19]'},
#      'molecular_charge': -2.0,
#      'molecular_multiplicity': 1,
#      'connectivity': [(0, 3, 1.0),
#       (0, 10, 1.0),
#       (0, 11, 1.0),
#       (0, 12, 1.0),
#       (1, 3, 1.0),
#       (1, 13, 1.0),
#       (1, 14, 1.0),
#       (1, 15, 1.0),
#       (2, 3, 1.0),
#       (2, 8, 1.0),
#       (2, 16, 1.0),
#       (2, 17, 1.0),
#       (3, 4, 1.0),
#       (4, 18, 1.0),
#       (5, 9, 2.0),
#       (6, 9, 1.0),
#       (7, 9, 1.0),
#       (8, 9, 1.0)],
#      'fix_com': False,
#      'fix_orientation': False,
#      'fix_symmetry': 'c1',
#      'provenance': {'creator': 'QCElemental',
#       'version': '0.27.1',
#       'routine': 'qcelemental.molparse.from_schema'},
#      'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:11][C:1]([H:12])([H:13])[C:4]([C:2]([H:14])([H:15])[H:16])([C:3]([H:17])([H:18])[O:9][P:10](=[O:6])([O-:7])[O-:8])[O:5][H:19]'}},
#     {'schema_name': 'qcschema_molecule',
#      'schema_version': 2,
#      'validated': True,
#      'symbols': array(['C', 'C', 'C', 'C', 'O', 'O', 'O', 'O', 'O', 'P', 'H', 'H', 'H',
#             'H', 'H', 'H', 'H', 'H', 'H'], dtype='<U1'),
#      'geometry': array([[ 5.8332066 , -1.6400933 , -0.21845234],
#             [ 4.05743096,  2.77374001, -0.65838058],
#             [ 1.36305945, -1.03840451, -1.74194954],
#             [ 3.44553764,  0.00944863,  0.06066021],
#             [ 2.70665473, -0.11395049,  2.61764863],
#             [-5.22565965,  1.9609688 , -0.68672647],
#             [-1.99876332,  0.45769167,  2.73122117],
#             [-3.99261336, -2.83440021, -0.32182036],
#             [-0.76420524,  0.52043057, -1.97703147],
#             [-3.30815455, -0.04592034,  0.11168281],
#             [ 7.26165058, -1.02631026,  1.15632342],
#             [ 6.65051315, -1.52104056, -2.12631984],
#             [ 5.36890089, -3.62071525,  0.18443727],
#             [ 2.33192204,  3.89548143, -0.48036838],
#             [ 4.74491333,  2.93587851, -2.61632582],
#             [ 5.50496117,  3.52490614,  0.62795599],
#             [ 2.22212895, -1.24816411, -3.64282505],
#             [ 0.82694415, -2.93833515, -1.076388  ],
#             [ 0.71091497,  0.13473747,  2.73783521]]),
#      'name': 'C4H9O5P',
#      'identifiers': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:11][C:1]([H:12])([H:13])[C:4]([C:2]([H:14])([H:15])[H:16])([C:3]([H:17])([H:18])[O:9][P:10](=[O:6])([O-:7])[O-:8])[O:5][H:19]'},
#      'molecular_charge': -2.0,
#      'molecular_multiplicity': 1,
#      'connectivity': [(0, 3, 1.0),
#       (0, 10, 1.0),
#       (0, 11, 1.0),
#       (0, 12, 1.0),
#       (1, 3, 1.0),
#       (1, 13, 1.0),
#       (1, 14, 1.0),
#       (1, 15, 1.0),
#       (2, 3, 1.0),
#       (2, 8, 1.0),
#       (2, 16, 1.0),
#       (2, 17, 1.0),
#       (3, 4, 1.0),
#       (4, 18, 1.0),
#       (5, 9, 2.0),
#       (6, 9, 1.0),
#       (7, 9, 1.0),
#       (8, 9, 1.0)],
#      'fix_com': False,
#      'fix_orientation': False,
#      'fix_symmetry': 'c1',
#      'provenance': {'creator': 'QCElemental',
#       'version': '0.27.1',
#       'routine': 'qcelemental.molparse.from_schema'},
#      'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:11][C:1]([H:12])([H:13])[C:4]([C:2]([H:14])([H:15])[H:16])([C:3]([H:17])([H:18])[O:9][P:10](=[O:6])([O-:7])[O-:8])[O:5][H:19]'}},
#     {'schema_name': 'qcschema_molecule',
#      'schema_version': 2,
#      'validated': True,
#      'symbols': array(['C', 'C', 'C', 'C', 'O', 'O', 'O', 'O', 'O', 'P', 'H', 'H', 'H',
#             'H', 'H', 'H', 'H', 'H', 'H'], dtype='<U1'),
#      'geometry': array([[-5.85021414,  1.60343262, -0.21297213],
#             [-4.00395171, -2.7799761 , -0.66934099],
#             [-1.37288603,  1.0805454 , -1.7394929 ],
#             [-3.43722285, -0.00944863,  0.06217199],
#             [-2.70552089,  0.11886377,  2.6199163 ],
#             [ 1.97759839, -0.55803612,  2.7068437 ],
#             [ 3.98713315,  2.8455496 , -0.21108241],
#             [ 5.22131328, -1.93526852, -0.74247339],
#             [ 0.77459874, -0.44408564, -2.01539291],
#             [ 3.29983976,  0.0434637 ,  0.11432843],
#             [-7.26826462,  0.9639493 ,  1.16066979],
#             [-6.66581993,  1.47625405, -2.12121757],
#             [-5.41708891,  3.59029066,  0.19464179],
#             [-2.26332498, -3.87715109, -0.48603756],
#             [-4.67801702, -2.94570508, -2.6316326 ],
#             [-5.44713555, -3.55665354,  0.60698003],
#             [-2.24442772,  1.30466692, -3.63243156],
#             [-0.85680182,  2.97820837, -1.04955389],
#             [-0.71261572, -0.16875254,  2.73821315]]),
#      'name': 'C4H9O5P',
#      'identifiers': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:11][C:1]([H:12])([H:13])[C:4]([C:2]([H:14])([H:15])[H:16])([C:3]([H:17])([H:18])[O:9][P:10](=[O:6])([O-:7])[O-:8])[O:5][H:19]'},
#      'molecular_charge': -2.0,
#      'molecular_multiplicity': 1,
#      'connectivity': [(0, 3, 1.0),
#       (0, 10, 1.0),
#       (0, 11, 1.0),
#       (0, 12, 1.0),
#       (1, 3, 1.0),
#       (1, 13, 1.0),
#       (1, 14, 1.0),
#       (1, 15, 1.0),
#       (2, 3, 1.0),
#       (2, 8, 1.0),
#       (2, 16, 1.0),
#       (2, 17, 1.0),
#       (3, 4, 1.0),
#       (4, 18, 1.0),
#       (5, 9, 2.0),
#       (6, 9, 1.0),
#       (7, 9, 1.0),
#       (8, 9, 1.0)],
#      'fix_com': False,
#      'fix_orientation': False,
#      'fix_symmetry': 'c1',
#      'provenance': {'creator': 'QCElemental',
#       'version': '0.27.1',
#       'routine': 'qcelemental.molparse.from_schema'},
#      'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:11][C:1]([H:12])([H:13])[C:4]([C:2]([H:14])([H:15])[H:16])([C:3]([H:17])([H:18])[O:9][P:10](=[O:6])([O-:7])[O-:8])[O:5][H:19]'}},
#     {'schema_name': 'qcschema_molecule',
#      'schema_version': 2,
#      'validated': True,
#      'symbols': array(['C', 'C', 'C', 'C', 'O', 'O', 'O', 'O', 'O', 'P', 'H', 'H', 'H',
#             'H', 'H', 'H', 'H', 'H', 'H'], dtype='<U1'),
#      'geometry': array([[ 5.65708413, -1.9271427 , -0.11206076],
#             [ 4.45446242,  2.6592226 , -0.69258462],
#             [ 1.34510706, -0.79916518, -1.7967516 ],
#             [ 3.47766299,  0.00793685,  0.06727425],
#             [ 2.6516637 ,  0.09826576,  2.59081452],
#             [-5.20959698,  2.10402107, -0.35262289],
#             [-2.06339196, -0.06859706,  2.78054302],
#             [-4.08048562, -2.70438706, -0.83563689],
#             [-0.74776463,  0.82014114, -1.80109797],
#             [-3.34651599, -0.05499103,  0.09921062],
#             [ 7.16149509, -1.40387754,  1.2192513 ],
#             [ 6.46966636, -2.02427462, -2.02465257],
#             [ 4.96298772, -3.80798711,  0.41252721],
#             [ 2.85953357,  3.97409404, -0.65422318],
#             [ 5.28461911,  2.67623014, -2.60215287],
#             [ 5.88952044,  3.29114702,  0.66877408],
#             [ 2.17261813, -0.83318025, -3.72200458],
#             [ 0.76231552, -2.74577206, -1.33641432],
#             [ 0.62701113,  0.05839254,  2.69777302]]),
#      'name': 'C4H9O5P',
#      'identifiers': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:11][C:1]([H:12])([H:13])[C:4]([C:2]([H:14])([H:15])[H:16])([C:3]([H:17])([H:18])[O:9][P:10](=[O:6])([O-:7])[O-:8])[O:5][H:19]'},
#      'molecular_charge': -2.0,
#      'molecular_multiplicity': 1,
#      'connectivity': [(0, 3, 1.0),
#       (0, 10, 1.0),
#       (0, 11, 1.0),
#       (0, 12, 1.0),
#       (1, 3, 1.0),
#       (1, 13, 1.0),
#       (1, 14, 1.0),
#       (1, 15, 1.0),
#       (2, 3, 1.0),
#       (2, 8, 1.0),
#       (2, 16, 1.0),
#       (2, 17, 1.0),
#       (3, 4, 1.0),
#       (4, 18, 1.0),
#       (5, 9, 2.0),
#       (6, 9, 1.0),
#       (7, 9, 1.0),
#       (8, 9, 1.0)],
#      'fix_com': False,
#      'fix_orientation': False,
#      'fix_symmetry': 'c1',
#      'provenance': {'creator': 'QCElemental',
#       'version': '0.27.1',
#       'routine': 'qcelemental.molparse.from_schema'},
#      'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:11][C:1]([H:12])([H:13])[C:4]([C:2]([H:14])([H:15])[H:16])([C:3]([H:17])([H:18])[O:9][P:10](=[O:6])([O-:7])[O-:8])[O:5][H:19]'}}],
#    'attributes': {'canonical_smiles': 'CC(C)(COP(=O)([O-])[O-])O',
#     'canonical_isomeric_smiles': 'CC(C)(COP(=O)([O-])[O-])O',
#     'canonical_explicit_hydrogen_smiles': '[H]C([H])([H])C(C([H])([H])[H])(C([H])([H])OP(=O)([O-])[O-])O[H]',
#     'canonical_isomeric_explicit_hydrogen_smiles': '[H]C([H])([H])C(C([H])([H])[H])(C([H])([H])OP(=O)([O-])[O-])O[H]',
#     'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:11][C:1]([H:12])([H:13])[C:4]([C:2]([H:14])([H:15])[H:16])([C:3]([H:17])([H:18])[O:9][P:10](=[O:6])([O-:7])[O-:8])[O:5][H:19]',
#     'molecular_formula': 'C4H9O5P',
#     'standard_inchi': 'InChI=1S/C4H11O5P/c1-4(2,5)3-9-10(6,7)8/h5H,3H2,1-2H3,(H2,6,7,8)/p-2',
#     'inchi_key': 'DCFHGIIQUGQRMF-UHFFFAOYSA-L',
#     'fixed_hydrogen_inchi': 'InChI=1/C4H11O5P/c1-4(2,5)3-9-10(6,7)8/h5H,3H2,1-2H3,(H2,6,7,8)/p-2/fC4H9O5P/q-2',
#     'fixed_hydrogen_inchi_key': 'DCFHGIIQUGQRMF-IGTWXDDRNA-L',
#     'unique_fixed_hydrogen_inchi_keys': {'DCFHGIIQUGQRMF-IGTWXDDRNA-L'}},
#    'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:11][C:1]([H:12])([H:13])[C:4]([C:2]([H:14])([H:15])[H:16])([C:3]([H:17])([H:18])[O:9][P:10](=[O:6])([O-:7])[O-:8])[O:5][H:19]'},
#    'keywords': {'grid_spacing': [15],
#     'dihedral_ranges': [(-165, 180)],
#     'energy_decrease_thresh': None,
#     'energy_upper_limit': None,
#     'additional_keywords': {}},
#    'constraints': {},
#    'dihedrals': [(0, 3, 4, 18)]},
#   '[H]C(=C1C(=O)[N:1]([C@@:2](C(=O)N1[H])([H])[O:3][C:4]([H])([H])[H])[H])[H]': {'index': '[H]C(=C1C(=O)[N:1]([C@@:2](C(=O)N1[H])([H])[O:3][C:4]([H])([H])[H])[H])[H]',
#    'initial_molecules': [{'schema_name': 'qcschema_molecule',
#      'schema_version': 2,
#      'validated': True,
#      'symbols': array(['C', 'C', 'C', 'C', 'C', 'C', 'N', 'N', 'O', 'O', 'O', 'H', 'H',
#             'H', 'H', 'H', 'H', 'H', 'H'], dtype='<U1'),
#      'geometry': array([[ 5.28820959e+00,  1.79523982e+00,  1.35493363e+00],
#             [-5.73626365e+00, -1.37024041e+00,  1.33471356e+00],
#             [ 3.06702550e+00,  1.05711279e+00,  3.96086600e-01],
#             [ 2.70438706e+00, -1.64897502e+00, -3.88149750e-01],
#             [-1.36362637e+00,  2.06074634e+00, -7.26599690e-01],
#             [-1.88689154e+00, -7.75921550e-01, -9.61492650e-01],
#             [ 1.03008971e+00,  2.71270185e+00,  6.61404000e-03],
#             [ 3.73031940e-01, -2.21286929e+00, -1.40444446e+00],
#             [ 4.39172351e+00, -3.21442414e+00, -2.43774670e-01],
#             [-3.04208112e+00,  3.61277841e+00, -1.04671930e+00],
#             [-3.05455331e+00, -1.62762111e+00,  1.30485589e+00],
#             [ 6.78638446e+00,  4.16684610e-01,  1.54844159e+00],
#             [ 5.64121043e+00,  3.73088629e+00,  1.93583544e+00],
#             [-6.37347930e+00, -2.21060162e+00,  3.10878845e+00],
#             [-6.60024644e+00, -2.39258225e+00, -2.57002750e-01],
#             [-6.31697649e+00,  6.15861740e-01,  1.25364431e+00],
#             [-3.18607825e+00, -1.03386916e+00, -2.55812225e+00],
#             [ 1.29559623e+00,  4.58504250e+00,  3.23710090e-01],
#             [ 1.33981580e-01, -4.08558788e+00, -1.74081571e+00]]),
#      'name': 'C6H8N2O3',
#      'identifiers': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:12][C:1](=[C:3]1[C:4](=[O:9])[N:8]([C@@:6]([C:5](=[O:10])[N:7]1[H:18])([H:17])[O:11][C:2]([H:14])([H:15])[H:16])[H:19])[H:13]'},
#      'molecular_charge': 0.0,
#      'molecular_multiplicity': 1,
#      'connectivity': [(0, 2, 2.0),
#       (0, 11, 1.0),
#       (0, 12, 1.0),
#       (1, 10, 1.0),
#       (1, 13, 1.0),
#       (1, 14, 1.0),
#       (1, 15, 1.0),
#       (2, 3, 1.0),
#       (2, 6, 1.0),
#       (3, 7, 1.0),
#       (3, 8, 2.0),
#       (4, 5, 1.0),
#       (4, 6, 1.0),
#       (4, 9, 2.0),
#       (5, 7, 1.0),
#       (5, 10, 1.0),
#       (5, 16, 1.0),
#       (6, 17, 1.0),
#       (7, 18, 1.0)],
#      'fix_com': False,
#      'fix_orientation': False,
#      'fix_symmetry': 'c1',
#      'provenance': {'creator': 'QCElemental',
#       'version': '0.27.1',
#       'routine': 'qcelemental.molparse.from_schema'},
#      'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:12][C:1](=[C:3]1[C:4](=[O:9])[N:8]([C@@:6]([C:5](=[O:10])[N:7]1[H:18])([H:17])[O:11][C:2]([H:14])([H:15])[H:16])[H:19])[H:13]'}}],
#    'attributes': {'canonical_smiles': 'COC1C(=O)NC(=C)C(=O)N1',
#     'canonical_isomeric_smiles': 'CO[C@H]1C(=O)NC(=C)C(=O)N1',
#     'canonical_explicit_hydrogen_smiles': '[H]C(=C1C(=O)N(C(C(=O)N1[H])([H])OC([H])([H])[H])[H])[H]',
#     'canonical_isomeric_explicit_hydrogen_smiles': '[H]C(=C1C(=O)N([C@@](C(=O)N1[H])([H])OC([H])([H])[H])[H])[H]',
#     'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:12][C:1](=[C:3]1[C:4](=[O:9])[N:8]([C@@:6]([C:5](=[O:10])[N:7]1[H:18])([H:17])[O:11][C:2]([H:14])([H:15])[H:16])[H:19])[H:13]',
#     'molecular_formula': 'C6H8N2O3',
#     'standard_inchi': 'InChI=1S/C6H8N2O3/c1-3-4(9)8-6(11-2)5(10)7-3/h6H,1H2,2H3,(H,7,10)(H,8,9)/t6-/m0/s1',
#     'inchi_key': 'BFHIBVQMZBLHGM-LURJTMIESA-N',
#     'fixed_hydrogen_inchi': 'InChI=1/C6H8N2O3/c1-3-4(9)8-6(11-2)5(10)7-3/h6H,1H2,2H3,(H,7,10)(H,8,9)/t6-/m0/s1/f/h7-8H',
#     'fixed_hydrogen_inchi_key': 'BFHIBVQMZBLHGM-OCSBBNMYNA-N',
#     'unique_fixed_hydrogen_inchi_keys': {'BFHIBVQMZBLHGM-OCSBBNMYNA-N'}},
#    'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:12][C:1](=[C:3]1[C:4](=[O:9])[N:8]([C@@:6]([C:5](=[O:10])[N:7]1[H:18])([H:17])[O:11][C:2]([H:14])([H:15])[H:16])[H:19])[H:13]'},
#    'keywords': {'grid_spacing': [15],
#     'dihedral_ranges': [(-165, 180)],
#     'energy_decrease_thresh': None,
#     'energy_upper_limit': None,
#     'additional_keywords': {}},
#    'constraints': {},
#    'dihedrals': [(7, 5, 10, 1)]},
#   '[H]C1=C(OC(=C1[H])N(O[H])O[H])[C:2](=[O:1])[N:3]([H:4])[H]': {'index': '[H]C1=C(OC(=C1[H])N(O[H])O[H])[C:2](=[O:1])[N:3]([H:4])[H]',
#    'initial_molecules': [{'schema_name': 'qcschema_molecule',
#      'schema_version': 2,
#      'validated': True,
#      'symbols': array(['C', 'C', 'C', 'C', 'C', 'N', 'N', 'O', 'O', 'O', 'O', 'H', 'H',
#             'H', 'H', 'H', 'H'], dtype='<U1'),
#      'geometry': array([[ 1.29635212,  3.1146466 ,  0.18311446],
#             [-1.39575172,  3.00938885,  0.02381055],
#             [ 2.15731134,  0.69390743, -0.03401507],
#             [-1.96796079,  0.50512379, -0.27495515],
#             [ 4.7409449 , -0.34695372,  0.03061356],
#             [ 4.90213854, -2.91339077, -0.19029542],
#             [-4.27701714, -0.74833155, -0.75116613],
#             [ 6.57964842,  1.04275088,  0.26890803],
#             [-4.39191249, -2.87673008,  0.91084799],
#             [-6.28182758,  0.89176176, -0.1642172 ],
#             [ 0.13832795, -0.9376821 , -0.33108002],
#             [ 2.47440739,  4.76267675,  0.43255831],
#             [-2.72139459,  4.55801941,  0.06103815],
#             [ 6.63369459, -3.71047725, -0.15533549],
#             [ 3.35690949, -4.01661288, -0.35829207],
#             [-5.37343624, -4.08124151, -0.07162062],
#             [-6.08605196,  1.30145438,  1.63650282]]),
#      'name': 'C5H6N2O4',
#      'identifiers': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:12][C:1]1=[C:3]([O:11][C:4](=[C:2]1[H:13])[N:7]([O:9][H:16])[O:10][H:17])[C:5](=[O:8])[N:6]([H:14])[H:15]'},
#      'molecular_charge': 0.0,
#      'molecular_multiplicity': 1,
#      'connectivity': [(0, 1, 1.0),
#       (0, 2, 2.0),
#       (0, 11, 1.0),
#       (1, 3, 2.0),
#       (1, 12, 1.0),
#       (2, 4, 1.0),
#       (2, 10, 1.0),
#       (3, 6, 1.0),
#       (3, 10, 1.0),
#       (4, 5, 1.0),
#       (4, 7, 2.0),
#       (5, 13, 1.0),
#       (5, 14, 1.0),
#       (6, 8, 1.0),
#       (6, 9, 1.0),
#       (8, 15, 1.0),
#       (9, 16, 1.0)],
#      'fix_com': False,
#      'fix_orientation': False,
#      'fix_symmetry': 'c1',
#      'provenance': {'creator': 'QCElemental',
#       'version': '0.27.1',
#       'routine': 'qcelemental.molparse.from_schema'},
#      'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:12][C:1]1=[C:3]([O:11][C:4](=[C:2]1[H:13])[N:7]([O:9][H:16])[O:10][H:17])[C:5](=[O:8])[N:6]([H:14])[H:15]'}},
#     {'schema_name': 'qcschema_molecule',
#      'schema_version': 2,
#      'validated': True,
#      'symbols': array(['C', 'C', 'C', 'C', 'C', 'N', 'N', 'O', 'O', 'O', 'O', 'H', 'H',
#             'H', 'H', 'H', 'H'], dtype='<U1'),
#      'geometry': array([[ 1.29616315,  3.11804811,  0.16648487],
#             [-1.39594069,  3.0139242 ,  0.00944863],
#             [ 2.15561059,  0.6961751 , -0.04365267],
#             [-1.96985051,  0.50833633, -0.27949049],
#             [ 4.73773237, -0.34752063,  0.03307021],
#             [ 4.90062676, -2.9124459 , -0.22657816],
#             [-4.28155248, -0.7403947 , -0.74398518],
#             [ 6.57568   ,  1.03972731,  0.28723837],
#             [-4.37944029, -2.89562734,  0.88439183],
#             [-6.28315039,  0.88703744, -0.12264323],
#             [ 0.13511542, -0.9356034 , -0.33164693],
#             [ 2.47535225,  4.76626723,  0.40950365],
#             [-2.71912692,  4.5650114 ,  0.03760555],
#             [ 3.34878367, -4.0205813 , -0.22544433],
#             [ 6.61895472, -3.71501259, -0.02305466],
#             [-5.36417658, -4.08558788, -0.11206076],
#             [-6.02123435,  1.36154767,  1.65407728]]),
#      'name': 'C5H6N2O4',
#      'identifiers': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:12][C:1]1=[C:3]([O:11][C:4](=[C:2]1[H:13])[N:7]([O:9][H:16])[O:10][H:17])[C:5](=[O:8])[N:6]([H:14])[H:15]'},
#      'molecular_charge': 0.0,
#      'molecular_multiplicity': 1,
#      'connectivity': [(0, 1, 1.0),
#       (0, 2, 2.0),
#       (0, 11, 1.0),
#       (1, 3, 2.0),
#       (1, 12, 1.0),
#       (2, 4, 1.0),
#       (2, 10, 1.0),
#       (3, 6, 1.0),
#       (3, 10, 1.0),
#       (4, 5, 1.0),
#       (4, 7, 2.0),
#       (5, 13, 1.0),
#       (5, 14, 1.0),
#       (6, 8, 1.0),
#       (6, 9, 1.0),
#       (8, 15, 1.0),
#       (9, 16, 1.0)],
#      'fix_com': False,
#      'fix_orientation': False,
#      'fix_symmetry': 'c1',
#      'provenance': {'creator': 'QCElemental',
#       'version': '0.27.1',
#       'routine': 'qcelemental.molparse.from_schema'},
#      'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:12][C:1]1=[C:3]([O:11][C:4](=[C:2]1[H:13])[N:7]([O:9][H:16])[O:10][H:17])[C:5](=[O:8])[N:6]([H:14])[H:15]'}},
#     {'schema_name': 'qcschema_molecule',
#      'schema_version': 2,
#      'validated': True,
#      'symbols': array(['C', 'C', 'C', 'C', 'C', 'N', 'N', 'O', 'O', 'O', 'O', 'H', 'H',
#             'H', 'H', 'H', 'H'], dtype='<U1'),
#      'geometry': array([[ 1.29597418,  3.11578043,  0.17687837],
#             [-1.39612966,  3.01033372,  0.01984212],
#             [ 2.15712237,  0.69504127, -0.04157397],
#             [-1.96814976,  0.50569071, -0.27722282],
#             [ 4.74000004, -0.34676474,  0.03099151],
#             [ 4.90478416, -2.91093412, -0.23716063],
#             [-4.277962  , -0.74776463, -0.74870949],
#             [ 6.57719178,  1.04086115,  0.28856118],
#             [-4.38775509, -2.87899775,  0.91028107],
#             [-6.28201656,  0.89024998, -0.15514651],
#             [ 0.13776103, -0.93692621, -0.33485947],
#             [ 2.47421841,  4.76399956,  0.42537735],
#             [-2.72196151,  4.5587753 ,  0.05706973],
#             [ 3.35388593, -4.02020336, -0.2394283 ],
#             [ 6.62386801, -3.71255594, -0.03684966],
#             [-5.36852295, -4.08350918, -0.07294343],
#             [-6.08151661,  1.30013157,  1.64500659]]),
#      'name': 'C5H6N2O4',
#      'identifiers': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:12][C:1]1=[C:3]([O:11][C:4](=[C:2]1[H:13])[N:7]([O:9][H:16])[O:10][H:17])[C:5](=[O:8])[N:6]([H:14])[H:15]'},
#      'molecular_charge': 0.0,
#      'molecular_multiplicity': 1,
#      'connectivity': [(0, 1, 1.0),
#       (0, 2, 2.0),
#       (0, 11, 1.0),
#       (1, 3, 2.0),
#       (1, 12, 1.0),
#       (2, 4, 1.0),
#       (2, 10, 1.0),
#       (3, 6, 1.0),
#       (3, 10, 1.0),
#       (4, 5, 1.0),
#       (4, 7, 2.0),
#       (5, 13, 1.0),
#       (5, 14, 1.0),
#       (6, 8, 1.0),
#       (6, 9, 1.0),
#       (8, 15, 1.0),
#       (9, 16, 1.0)],
#      'fix_com': False,
#      'fix_orientation': False,
#      'fix_symmetry': 'c1',
#      'provenance': {'creator': 'QCElemental',
#       'version': '0.27.1',
#       'routine': 'qcelemental.molparse.from_schema'},
#      'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:12][C:1]1=[C:3]([O:11][C:4](=[C:2]1[H:13])[N:7]([O:9][H:16])[O:10][H:17])[C:5](=[O:8])[N:6]([H:14])[H:15]'}},
#     {'schema_name': 'qcschema_molecule',
#      'schema_version': 2,
#      'validated': True,
#      'symbols': array(['C', 'C', 'C', 'C', 'C', 'N', 'N', 'O', 'O', 'O', 'O', 'H', 'H',
#             'H', 'H', 'H', 'H'], dtype='<U1'),
#      'geometry': array([[-1.27537616e+00,  3.07231673e+00,  3.38449950e-01],
#             [ 1.41597179e+00,  2.93342186e+00,  1.94641790e-01],
#             [-2.16770484e+00,  6.75955030e-01, -2.45664000e-03],
#             [ 1.95681140e+00,  4.42951800e-01, -2.28089940e-01],
#             [-4.76872388e+00, -3.28245430e-01, -2.00311000e-02],
#             [-4.96072005e+00, -2.88296618e+00, -3.39961730e-01],
#             [ 4.21805768e+00, -8.99320660e-01, -7.03545040e-01],
#             [-6.58909705e+00,  1.07638800e+00,  2.63616790e-01],
#             [ 6.19244354e+00,  9.05178810e-01, -4.58258590e-01],
#             [ 4.57653873e+00, -2.79887336e+00,  1.15632342e+00],
#             [-1.76311450e-01, -9.64705190e-01, -3.73031940e-01],
# ...
#     {'schema_name': 'qcschema_molecule',
#      'schema_version': 2,
#      'validated': True,
#      'symbols': array(['C', 'C', 'N', 'O', 'O', 'O', 'O', 'P', 'H', 'H', 'H', 'H', 'H',
#             'H', 'H', 'H'], dtype='<U1'),
#      'geometry': array([[-2.67169479, -2.28146635, -0.62776702],
#             [-4.17213734, -0.23772755,  0.81598374],
#             [-0.24585337, -1.38970459, -1.69451742],
#             [-4.23903364,  2.08266716, -0.50701352],
#             [ 2.39598375, -1.68809235,  2.39239327],
#             [ 4.20312885,  0.32900132, -1.7394929 ],
#             [ 1.0246095 ,  2.76731494,  1.1122928 ],
#             [ 1.76027989,  0.24396364,  0.11130487],
#             [-2.30641074, -3.89812705,  0.61529483],
#             [-3.77680663, -2.97367303, -2.23176655],
#             [-6.12365751, -0.89327354,  1.05692382],
#             [-3.36295661,  0.00925966,  2.7130798 ],
#             [-0.4809353 , -0.54820955, -3.4037747 ],
#             [-2.69115897,  2.97329508, -0.03987322],
#             [ 2.94400433, -3.32459517,  1.76141372],
#             [ 5.09867006,  1.91202489, -1.4737974 ]]),
#      'name': 'C2H8NO4P',
#      'identifiers': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:9][C:1]([H:10])([C:2]([H:11])([H:12])[O:4][H:14])[N:3]([H:13])[P:8](=[O:7])([O:5][H:15])[O:6][H:16]'},
#      'molecular_charge': 0.0,
#      'molecular_multiplicity': 1,
#      'connectivity': [(0, 1, 1.0),
#       (0, 2, 1.0),
#       (0, 8, 1.0),
#       (0, 9, 1.0),
#       (1, 3, 1.0),
#       (1, 10, 1.0),
#       (1, 11, 1.0),
#       (2, 7, 1.0),
#       (2, 12, 1.0),
#       (3, 13, 1.0),
#       (4, 7, 1.0),
#       (4, 14, 1.0),
#       (5, 7, 1.0),
#       (5, 15, 1.0),
#       (6, 7, 2.0)],
#      'fix_com': False,
#      'fix_orientation': False,
#      'fix_symmetry': 'c1',
#      'provenance': {'creator': 'QCElemental',
#       'version': '0.27.1',
#       'routine': 'qcelemental.molparse.from_schema'},
#      'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:9][C:1]([H:10])([C:2]([H:11])([H:12])[O:4][H:14])[N:3]([H:13])[P:8](=[O:7])([O:5][H:15])[O:6][H:16]'}},
#     {'schema_name': 'qcschema_molecule',
#      'schema_version': 2,
#      'validated': True,
#      'symbols': array(['C', 'C', 'N', 'O', 'O', 'O', 'O', 'P', 'H', 'H', 'H', 'H', 'H',
#             'H', 'H', 'H'], dtype='<U1'),
#      'geometry': array([[ 2.65204164, -2.40259779,  0.30160029],
#             [ 4.34315755, -0.17650042, -0.48017941],
#             [ 0.05971535, -2.35346492, -0.71979668],
#             [ 3.39375915,  2.19586176,  0.40931468],
#             [-4.59940441, -0.86398278, -0.10809233],
#             [-1.16520513,  0.85963641,  2.75011843],
#             [-1.4758761 ,  2.35516567, -1.98477935],
#             [-1.76443728,  0.22620022, -0.17007535],
#             [ 3.53529963, -4.17761754, -0.29933262],
#             [ 2.51446958, -2.4619352 ,  2.36442533],
#             [ 6.22003354, -0.42537735,  0.35980385],
#             [ 4.57181441, -0.13095802, -2.54319342],
#             [ 0.01511781, -2.81833754, -2.58684609],
#             [ 2.22515251,  2.86236816, -0.86209306],
#             [-4.70749675, -2.39352711,  0.90215525],
#             [ 0.47791174,  1.72891043,  2.79452699]]),
#      'name': 'C2H8NO4P',
#      'identifiers': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:9][C:1]([H:10])([C:2]([H:11])([H:12])[O:4][H:14])[N:3]([H:13])[P:8](=[O:7])([O:5][H:15])[O:6][H:16]'},
#      'molecular_charge': 0.0,
#      'molecular_multiplicity': 1,
#      'connectivity': [(0, 1, 1.0),
#       (0, 2, 1.0),
#       (0, 8, 1.0),
#       (0, 9, 1.0),
#       (1, 3, 1.0),
#       (1, 10, 1.0),
#       (1, 11, 1.0),
#       (2, 7, 1.0),
#       (2, 12, 1.0),
#       (3, 13, 1.0),
#       (4, 7, 1.0),
#       (4, 14, 1.0),
#       (5, 7, 1.0),
#       (5, 15, 1.0),
#       (6, 7, 2.0)],
#      'fix_com': False,
#      'fix_orientation': False,
#      'fix_symmetry': 'c1',
#      'provenance': {'creator': 'QCElemental',
#       'version': '0.27.1',
#       'routine': 'qcelemental.molparse.from_schema'},
#      'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:9][C:1]([H:10])([C:2]([H:11])([H:12])[O:4][H:14])[N:3]([H:13])[P:8](=[O:7])([O:5][H:15])[O:6][H:16]'}},
#     {'schema_name': 'qcschema_molecule',
#      'schema_version': 2,
#      'validated': True,
#      'symbols': array(['C', 'C', 'N', 'O', 'O', 'O', 'O', 'P', 'H', 'H', 'H', 'H', 'H',
#             'H', 'H', 'H'], dtype='<U1'),
#      'geometry': array([[ 2.61632582,  2.25614402,  0.45580194],
#             [ 4.43632105,  0.33731611, -0.76685086],
#             [ 0.01341706,  2.24896306, -0.56975243],
#             [ 4.45030502, -2.03504606,  0.44673126],
#             [-2.62312883,  0.02456644,  2.89373761],
#             [-4.23789981,  0.49246263, -1.74610694],
#             [-0.85566799, -2.87502933, -0.52969023],
#             [-1.81186941, -0.2787346 , -0.03458199],
#             [ 2.52429616,  1.88235619,  2.48725753],
#             [ 3.33498866,  4.18423159,  0.20938165],
#             [ 4.0171798 ,  0.19275206, -2.80492049],
#             [ 6.36667629,  1.07166369, -0.59167325],
#             [-0.07048678,  2.81342425, -2.40410958],
#             [ 2.82589645, -2.84819522,  0.09883268],
#             [-3.08875735,  1.75914605,  3.27999763],
#             [-5.01174266, -1.03349122, -2.41582588]]),
#      'name': 'C2H8NO4P',
#      'identifiers': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:9][C:1]([H:10])([C:2]([H:11])([H:12])[O:4][H:14])[N:3]([H:13])[P:8](=[O:7])([O:5][H:15])[O:6][H:16]'},
#      'molecular_charge': 0.0,
#      'molecular_multiplicity': 1,
#      'connectivity': [(0, 1, 1.0),
#       (0, 2, 1.0),
#       (0, 8, 1.0),
#       (0, 9, 1.0),
#       (1, 3, 1.0),
#       (1, 10, 1.0),
#       (1, 11, 1.0),
#       (2, 7, 1.0),
#       (2, 12, 1.0),
#       (3, 13, 1.0),
#       (4, 7, 1.0),
#       (4, 14, 1.0),
#       (5, 7, 1.0),
#       (5, 15, 1.0),
#       (6, 7, 2.0)],
#      'fix_com': False,
#      'fix_orientation': False,
#      'fix_symmetry': 'c1',
#      'provenance': {'creator': 'QCElemental',
#       'version': '0.27.1',
#       'routine': 'qcelemental.molparse.from_schema'},
#      'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:9][C:1]([H:10])([C:2]([H:11])([H:12])[O:4][H:14])[N:3]([H:13])[P:8](=[O:7])([O:5][H:15])[O:6][H:16]'}},
#     {'schema_name': 'qcschema_molecule',
#      'schema_version': 2,
#      'validated': True,
#      'symbols': array(['C', 'C', 'N', 'O', 'O', 'O', 'O', 'P', 'H', 'H', 'H', 'H', 'H',
#             'H', 'H', 'H'], dtype='<U1'),
#      'geometry': array([[-2.69437151,  2.28978115,  0.62568832],
#             [-4.19821556,  0.24188494, -0.80710203],
#             [-0.23810549,  1.43524699,  1.65728981],
#             [-4.21824666, -2.09230477,  0.49246263],
#             [ 2.66016747,  1.79146037, -2.23951443],
#             [ 4.09617035, -0.579579  ,  1.81602681],
#             [ 0.92766655, -2.64769527, -1.31657219],
#             [ 1.75914605, -0.23205837, -0.14059562],
#             [-2.36933862,  3.91589048, -0.61718455],
#             [-3.78360965,  2.96498029,  2.2480182 ],
#             [-6.15937333,  0.8845808 , -1.0032556 ],
#             [-3.42550655,  0.01927521, -2.72139459],
#             [-0.44540845,  0.60754695,  3.37694058],
#             [-2.68435596, -2.96743693, -0.04440856],
#             [ 3.15206318,  3.38355463, -1.46604953],
#             [ 4.62340394, -2.33948094,  1.80506639]]),
#      'name': 'C2H8NO4P',
#      'identifiers': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:9][C:1]([H:10])([C:2]([H:11])([H:12])[O:4][H:14])[N:3]([H:13])[P:8](=[O:7])([O:5][H:15])[O:6][H:16]'},
#      'molecular_charge': 0.0,
#      'molecular_multiplicity': 1,
#      'connectivity': [(0, 1, 1.0),
#       (0, 2, 1.0),
#       (0, 8, 1.0),
#       (0, 9, 1.0),
#       (1, 3, 1.0),
#       (1, 10, 1.0),
#       (1, 11, 1.0),
#       (2, 7, 1.0),
#       (2, 12, 1.0),
#       (3, 13, 1.0),
#       (4, 7, 1.0),
#       (4, 14, 1.0),
#       (5, 7, 1.0),
#       (5, 15, 1.0),
#       (6, 7, 2.0)],
#      'fix_com': False,
#      'fix_orientation': False,
#      'fix_symmetry': 'c1',
#      'provenance': {'creator': 'QCElemental',
#       'version': '0.27.1',
#       'routine': 'qcelemental.molparse.from_schema'},
#      'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:9][C:1]([H:10])([C:2]([H:11])([H:12])[O:4][H:14])[N:3]([H:13])[P:8](=[O:7])([O:5][H:15])[O:6][H:16]'}}],
#    'attributes': {'canonical_smiles': 'C(CO)NP(=O)(O)O',
#     'canonical_isomeric_smiles': 'C(CO)NP(=O)(O)O',
#     'canonical_explicit_hydrogen_smiles': '[H]C([H])(C([H])([H])O[H])N([H])P(=O)(O[H])O[H]',
#     'canonical_isomeric_explicit_hydrogen_smiles': '[H]C([H])(C([H])([H])O[H])N([H])P(=O)(O[H])O[H]',
#     'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:9][C:1]([H:10])([C:2]([H:11])([H:12])[O:4][H:14])[N:3]([H:13])[P:8](=[O:7])([O:5][H:15])[O:6][H:16]',
#     'molecular_formula': 'C2H8NO4P',
#     'standard_inchi': 'InChI=1S/C2H8NO4P/c4-2-1-3-8(5,6)7/h4H,1-2H2,(H3,3,5,6,7)',
#     'inchi_key': 'GSLKYZINFJYFNZ-UHFFFAOYSA-N',
#     'fixed_hydrogen_inchi': 'InChI=1/C2H8NO4P/c4-2-1-3-8(5,6)7/h4H,1-2H2,(H3,3,5,6,7)/f/h3,5-6H',
#     'fixed_hydrogen_inchi_key': 'GSLKYZINFJYFNZ-VDBCHIHONA-N',
#     'unique_fixed_hydrogen_inchi_keys': {'GSLKYZINFJYFNZ-VDBCHIHONA-N'}},
#    'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:9][C:1]([H:10])([C:2]([H:11])([H:12])[O:4][H:14])[N:3]([H:13])[P:8](=[O:7])([O:5][H:15])[O:6][H:16]'},
#    'keywords': {'grid_spacing': [15],
#     'dihedral_ranges': [(-165, 180)],
#     'energy_decrease_thresh': None,
#     'energy_upper_limit': None,
#     'additional_keywords': {}},
#    'constraints': {},
#    'dihedrals': [(0, 1, 3, 13)]},
#   '[H]C([H])([H])[S:3](=[O:4])(=O)[C:2]([H])([H])[C:1]([H])([H])C#N': {'index': '[H]C([H])([H])[S:3](=[O:4])(=O)[C:2]([H])([H])[C:1]([H])([H])C#N',
#    'initial_molecules': [{'schema_name': 'qcschema_molecule',
#      'schema_version': 2,
#      'validated': True,
#      'symbols': array(['C', 'C', 'C', 'C', 'N', 'O', 'O', 'S', 'H', 'H', 'H', 'H', 'H',
#             'H', 'H'], dtype='<U1'),
#      'geometry': array([[-4.28533193e+00,  2.44133718e+00, -1.27178570e-01],
#             [ 2.90299727e+00, -1.01383807e+00, -5.83925400e-02],
#             [ 5.47642631e+00,  1.88970000e-04, -1.03934900e-02],
#             [ 9.37682100e-01,  1.12457602e+00,  8.63604800e-02],
#             [ 7.50088991e+00,  8.42250930e-01,  2.77789700e-02],
#             [-2.44568355e+00, -1.67505324e+00, -2.37425190e+00],
#             [-2.62501856e+00, -1.55165412e+00,  2.45078581e+00],
#             [-2.21721566e+00, -2.73632340e-01,  1.62516400e-02],
#             [-6.20737237e+00,  1.68658057e+00, -1.42863300e-01],
#             [-3.92363835e+00,  3.49580436e+00, -1.86345893e+00],
#             [-4.00055021e+00,  3.61504608e+00,  1.54598494e+00],
#             [ 2.61934938e+00, -2.10477696e+00, -1.79486187e+00],
#             [ 2.64731733e+00, -2.31056813e+00,  1.53634734e+00],
#             [ 1.10095444e+00,  2.39900732e+00, -1.53218994e+00],
#             [ 1.11096999e+00,  2.20020813e+00,  1.84116016e+00]]),
#      'name': 'C4H7NO2S',
#      'identifiers': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:9][C:1]([H:10])([H:11])[S:8](=[O:6])(=[O:7])[C:4]([H:14])([H:15])[C:2]([H:12])([H:13])[C:3]#[N:5]'},
#      'molecular_charge': 0.0,
#      'molecular_multiplicity': 1,
#      'connectivity': [(0, 7, 1.0),
#       (0, 8, 1.0),
#       (0, 9, 1.0),
#       (0, 10, 1.0),
#       (1, 2, 1.0),
#       (1, 3, 1.0),
#       (1, 11, 1.0),
#       (1, 12, 1.0),
#       (2, 4, 3.0),
#       (3, 7, 1.0),
#       (3, 13, 1.0),
#       (3, 14, 1.0),
#       (5, 7, 2.0),
#       (6, 7, 2.0)],
#      'fix_com': False,
#      'fix_orientation': False,
#      'fix_symmetry': 'c1',
#      'provenance': {'creator': 'QCElemental',
#       'version': '0.27.1',
#       'routine': 'qcelemental.molparse.from_schema'},
#      'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:9][C:1]([H:10])([H:11])[S:8](=[O:6])(=[O:7])[C:4]([H:14])([H:15])[C:2]([H:12])([H:13])[C:3]#[N:5]'}},
#     {'schema_name': 'qcschema_molecule',
#      'schema_version': 2,
#      'validated': True,
#      'symbols': array(['C', 'C', 'C', 'C', 'N', 'O', 'O', 'S', 'H', 'H', 'H', 'H', 'H',
#             'H', 'H'], dtype='<U1'),
#      'geometry': array([[ 4.29270186e+00,  2.43812465e+00, -1.88970000e-04],
#             [-2.90224138e+00, -1.01364909e+00,  0.00000000e+00],
#             [-5.47585939e+00,  7.55890000e-04,  0.00000000e+00],
#             [-9.36359290e-01,  1.12967828e+00,  1.88970000e-04],
#             [-7.50126785e+00,  8.42061960e-01,  0.00000000e+00],
#             [ 2.53109917e+00, -1.61363714e+00,  2.41563691e+00],
#             [ 2.53091020e+00, -1.61382611e+00, -2.41563691e+00],
#             [ 2.21608183e+00, -2.74010290e-01,  0.00000000e+00],
#             [ 6.21285258e+00,  1.67845474e+00, -1.88970000e-04],
#             [ 3.97296020e+00,  3.55381895e+00,  1.70604475e+00],
#             [ 3.97296020e+00,  3.55362998e+00, -1.70642269e+00],
#             [-2.63182157e+00, -2.20890087e+00,  1.66900611e+00],
#             [-2.63182157e+00, -2.20871189e+00, -1.66919509e+00],
#             [-1.10397800e+00,  2.30641074e+00,  1.69017105e+00],
#             [-1.10397800e+00,  2.30659971e+00, -1.68960413e+00]]),
#      'name': 'C4H7NO2S',
#      'identifiers': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:9][C:1]([H:10])([H:11])[S:8](=[O:6])(=[O:7])[C:4]([H:14])([H:15])[C:2]([H:12])([H:13])[C:3]#[N:5]'},
#      'molecular_charge': 0.0,
#      'molecular_multiplicity': 1,
#      'connectivity': [(0, 7, 1.0),
#       (0, 8, 1.0),
#       (0, 9, 1.0),
#       (0, 10, 1.0),
#       (1, 2, 1.0),
#       (1, 3, 1.0),
#       (1, 11, 1.0),
#       (1, 12, 1.0),
#       (2, 4, 3.0),
#       (3, 7, 1.0),
#       (3, 13, 1.0),
#       (3, 14, 1.0),
#       (5, 7, 2.0),
#       (6, 7, 2.0)],
#      'fix_com': False,
#      'fix_orientation': False,
#      'fix_symmetry': 'c1',
#      'provenance': {'creator': 'QCElemental',
#       'version': '0.27.1',
#       'routine': 'qcelemental.molparse.from_schema'},
#      'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:9][C:1]([H:10])([H:11])[S:8](=[O:6])(=[O:7])[C:4]([H:14])([H:15])[C:2]([H:12])([H:13])[C:3]#[N:5]'}}],
#    'attributes': {'canonical_smiles': 'CS(=O)(=O)CCC#N',
#     'canonical_isomeric_smiles': 'CS(=O)(=O)CCC#N',
#     'canonical_explicit_hydrogen_smiles': '[H]C([H])([H])S(=O)(=O)C([H])([H])C([H])([H])C#N',
#     'canonical_isomeric_explicit_hydrogen_smiles': '[H]C([H])([H])S(=O)(=O)C([H])([H])C([H])([H])C#N',
#     'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:9][C:1]([H:10])([H:11])[S:8](=[O:6])(=[O:7])[C:4]([H:14])([H:15])[C:2]([H:12])([H:13])[C:3]#[N:5]',
#     'molecular_formula': 'C4H7NO2S',
#     'standard_inchi': 'InChI=1S/C4H7NO2S/c1-8(6,7)4-2-3-5/h2,4H2,1H3',
#     'inchi_key': 'LQFRYKBDZNPJSW-UHFFFAOYSA-N',
#     'fixed_hydrogen_inchi': 'InChI=1/C4H7NO2S/c1-8(6,7)4-2-3-5/h2,4H2,1H3',
#     'fixed_hydrogen_inchi_key': 'LQFRYKBDZNPJSW-UHFFFAOYNA-N',
#     'unique_fixed_hydrogen_inchi_keys': {'LQFRYKBDZNPJSW-UHFFFAOYNA-N'}},
#    'extras': {'canonical_isomeric_explicit_hydrogen_mapped_smiles': '[H:9][C:1]([H:10])([H:11])[S:8](=[O:6])(=[O:7])[C:4]([H:14])([H:15])[C:2]([H:12])([H:13])[C:3]#[N:5]'},
#    'keywords': {'grid_spacing': [15],
#     'dihedral_ranges': [(-165, 180)],
#     'energy_decrease_thresh': None,
#     'energy_upper_limit': None,
#     'additional_keywords': {}},
#    'constraints': {},
#    'dihedrals': [(1, 3, 7, 5)]}},
#  'filtered_molecules': {'LinearTorsionRemoval': {'component': 'LinearTorsionRemoval',
#    'component_settings': {},
#    'component_provenance': {'openff-qcsubmit': '0.50.2',
#     'openff-toolkit': '0.15.0',
#     'OpenEyeToolkitWrapper': '2022.1.1',
#     'RDKitToolkitWrapper': '2023.09.4',
#     'AmberToolsToolkitWrapper': '22.0'},
#    'molecules': ['[H]c1c(c(c(nc1[H])[H])C#CC2=NC(=C(S2)[H])[H])[H]']}},
#  'optimization_procedure': {'program': 'geometric',
#   'coordsys': 'dlc',
#   'enforce': 0.1,
#   'epsilon': 0.0,
#   'reset': True,
#   'qccnv': True,
#   'molcnv': False,
#   'check': 0,
#   'trust': 0.1,
#   'tmax': 0.3,
#   'maxiter': 300,
#   'convergence_set': 'GAU',
#   'constraints': {}},
#  'protocols': {},
#  'grid_spacing': [15],
#  'energy_upper_limit': 0.05,
#  'dihedral_ranges': None,
#  'energy_decrease_thresh': None}

# %% [markdown]
# ## Exporting dataset

# %%
dataset.export_dataset("dataset.json.bz2")
dataset.molecules_to_file('dataset.smi', 'smi')
dataset.visualize("dataset.pdf", columns=8)

print(dataset.qc_specifications)
# Out:
# {'default': QCSpec(method='B3LYP-D3BJ', basis='DZVP', program='psi4', spec_name='default', spec_description='Standard OpenFF optimization quantum chemistry specification.', store_wavefunction=<WavefunctionProtocolEnum.none: 'none'>, implicit_solvent=None, maxiter=200, scf_properties=[<SCFProperties.Dipole: 'dipole'>, <SCFProperties.Quadrupole: 'quadrupole'>, <SCFProperties.WibergLowdinIndices: 'wiberg_lowdin_indices'>, <SCFProperties.MayerIndices: 'mayer_indices'>], keywords={})}

# %% [markdown]
# ## Dataset information

# %%
import numpy as np
from collections import Counter

# %%
print("n_molecules:", dataset.n_molecules)
print("n_conformers:", dataset.n_records)
# Out:
# n_molecules: 169
# n_conformers: 169

# %%
n_confs = np.array(
    [mol.n_conformers for mol in dataset.molecules]
)
n_heavy_atoms = np.array(
    [mol.to_rdkit().GetNumHeavyAtoms() for mol in dataset.molecules]
)

# %%
print(
    "Number of conformers (min, mean, max):",
    n_confs.min(), n_confs.mean(), n_confs.max()
)
print("# heavy atoms")
counts = Counter(n_heavy_atoms)
for n_heavy in sorted(counts):
    print(f"{str(n_heavy):>3}: {counts[n_heavy]}")
# Out:
# Number of conformers (min, mean, max): 1 2.485207100591716 6
# # heavy atoms
#   4: 1
#   5: 1
#   6: 4
#   7: 4
#   8: 4
#   9: 8
#  10: 3
#  11: 15
#  12: 12
#  13: 26
#  14: 21
#  15: 16
#  16: 19
#  17: 8
#  18: 5
#  19: 12
#  20: 5
#  21: 4
#  24: 1

# %%
unique_charges = set([
    mol.total_charge.m_as(unit.elementary_charge)
    for mol in dataset.molecules
])
unique_charges
# Out:
# {-2.0, -1.0, 0.0}

# %%
masses = np.array([
    sum([atom.mass.m for atom in mol.atoms])
    for mol in dataset.molecules
])
print("MW (min, mean, max):", masses.min(), masses.mean(), masses.max())
# Out:
# MW (min, mean, max): 78.49803100000001 201.1501543544379 314.3822960000001

# %%
elements = set(
    atom.symbol
    for mol in dataset.molecules
    for atom in mol.atoms
)
print(elements)
# Out:
# {'C', 'H', 'O', 'P', 'F', 'N', 'Cl', 'S', 'Br'}
