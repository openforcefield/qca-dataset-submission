# %%
import pickle

# %%
tid_clusters_list = pickle.load(open('1st_tid_clusters_list.p','rb'))
tid_clusters_list2 = pickle.load(open('2nd_tid_clusters_list_interst.p','rb'))

# %%
count = 0
for tid, clusters in tid_clusters_list.items():
    for cluster in clusters: 
        count +=len(cluster['torsions'])
print(f'# input entries in the 1st batch: {count}')

count = 0
for tid, clusters in tid_clusters_list2.items():
    for cluster in clusters: 
        count +=len(cluster['torsions'])
print(f'# input entries in the second batch: {count}')
# Out:
# # input entries in the 1st batch: 1085
# # input entries in the second batch: 164

# %%
# copied from https://github.com/openforcefield/qca-dataset-submission/blob/master/submissions/2021-03-23-OpenFF-Amide-Torsion-Set-v1.0/generate-dataset.ipynb
import logging
import warnings
from pprint import pprint

import numpy as np
from openff.qcsubmit.common_structures import TorsionIndexer
from openff.qcsubmit.factories import TorsiondriveDatasetFactory
from openff.qcsubmit.datasets import TorsiondriveDataset, load_dataset
from openff.toolkit.topology import Molecule
from openff.toolkit.utils import UndefinedStereochemistryError
from simtk import unit
from tqdm import tqdm

# %%
# Warnings that tell us we have undefined stereo and charged molecules
logging.getLogger("openforcefield").setLevel(logging.ERROR)
warnings.simplefilter("ignore")

# %%
def gen_molecules(cluster_list):
    molecules = []
    for tid, clusters in tqdm(cluster_list.items()):
        for cluster in clusters: 
            torsions = cluster['torsions']
            for torsion in torsions: 
                smiles_pattern = torsion['mol_index']
                dihedrals = torsion['indices']

                # RDKit is unable to understand the stereochemistry of these molecules so
                # we skip them.
                if smiles_pattern == "[H]/C(=C(/C([H])([H])[H])\\[H])/C(=C(\\C([H])([H])[H])/[H])/[H]":
                    continue

                # 1. generate off molecule object. 
                try:
                    molecule: Molecule = Molecule.from_smiles(smiles_pattern)
                except UndefinedStereochemistryError:
                    molecule: Molecule = Molecule.from_smiles(smiles_pattern, allow_undefined_stereo=True)
                    molecule = ([molecule] + molecule.enumerate_stereoisomers(max_isomers=1))[-1]

                molecule = molecule.canonical_order_atoms()
                # 2. generate conformers. 
                try:
                    molecule.generate_conformers(n_conformers=10)
                except Exception:
                    print(f"Skipping {smiles_pattern} - OMEGA error.")
                    continue
                # 3. check if the molecule is rdkit compatible. 
                try:
                    molecule.to_rdkit()
                except Exception:
                    print(f"Skipping {smiles_pattern} - RDKit incompatible.")
                    continue

                # 4. add dihedrals info.
                torsion_indexer = TorsionIndexer()
                torsion_indexer.add_torsion(dihedrals, (-165, 180), True)

                molecule.properties["dihedrals"] = torsion_indexer
                molecules.append(molecule)
    return molecules

# %%
# 1st batch 
molecules1 = gen_molecules(tid_clusters_list)
# Out:
# ned_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 9, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 10, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 14, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 6, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 6, aromatic: False, chiral: False
#
#  78%|███████▊  | 131/167 [02:34<00:38,  1.07s/it]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 9, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 10, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 14, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 6, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 6, aromatic: False, chiral: False
#
#  79%|███████▉  | 132/167 [02:36<00:46,  1.32s/it]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 15, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 16, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 20, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 17, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 17, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 9, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 10, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 14, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 6, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 6, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True
# Atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 17, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: True
# Atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 9, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: True
# Atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 9, aromatic: False, chiral: False
#
#  80%|███████▉  | 133/167 [02:39<00:59,  1.76s/it]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 13, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 7, aromatic: False, chiral: False
#
#  81%|████████  | 135/167 [02:45<01:06,  2.08s/it]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
#
#  83%|████████▎ | 139/167 [02:48<00:38,  1.37s/it]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 0, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 0, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 0, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 5, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 0, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 5, aromatic: False, chiral: False
#
#  85%|████████▌ | 142/167 [02:51<00:28,  1.12s/it]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
#  86%|████████▌ | 144/167 [02:54<00:31,  1.36s/it]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 0, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 0, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
#  89%|████████▊ | 148/167 [02:59<00:23,  1.24s/it]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 9, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 9, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 8, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 8, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 8, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 8, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 2, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 0, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 2, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 0, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
#  96%|█████████▋| 161/167 [03:16<00:07,  1.27s/it]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 15, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 13, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 15, name: , idx: 12, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 14, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 15, name: , idx: 12, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 14, aromatic: False, chiral: False
#
# 100%|██████████| 167/167 [03:18<00:00,  1.19s/it]

# %%
print(f'len(molecules1) = {len(molecules1)}')
# Out:
# len(molecules1) = 1084

# %%
# second batch (molecules generated using additional substituents for higher torsion parameter coverage)
molecules2 = gen_molecules(tid_clusters_list2)
# Out:
#  85%|████████▌ | 17/20 [00:25<00:04,  1.64s/it]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 7, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 8, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 7, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 8, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 8, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 8, aromatic: False, chiral: False
#
# 100%|██████████| 20/20 [00:29<00:00,  1.49s/it]

# %%
print(f'len(molecules2) = {len(molecules2)}')
# Out:
# len(molecules2) = 164

# %%
# 3rd batch (addition of charged molecules)
import copy 
molecules3 = []
from openeye import oequacpac, oechem

for tid, clusters in tqdm(tid_clusters_list.items()):
    for cluster in clusters: 
        torsions = cluster['torsions']
        for torsion in torsions: 
            smiles_pattern = torsion['mol_index']
            dihedrals = torsion['indices']

            # RDKit is unable to understand the stereochemistry of these molecules so
            # we skip them.
            if smiles_pattern == "[H]/C(=C(/C([H])([H])[H])\\[H])/C(=C(\\C([H])([H])[H])/[H])/[H]":
                continue
            try:
                molecule: Molecule = Molecule.from_smiles(smiles_pattern)
            except UndefinedStereochemistryError:
                molecule: Molecule = Molecule.from_smiles(smiles_pattern, allow_undefined_stereo=True)
                molecule = ([molecule] + molecule.enumerate_stereoisomers(max_isomers=1))[-1]

            molecule = molecule.canonical_order_atoms()

            try:
                molecule.generate_conformers(n_conformers=1)
            except Exception:
                print(f"Skipping {smiles_pattern} - OMEGA error.")
                continue
            try:
                molecule.to_rdkit()
            except Exception:
                print(f"Skipping {smiles_pattern} - RDKit incompatible.")
                continue

            # map atoms
            atom_map = {atomidx:idx+1 for idx, atomidx in enumerate(dihedrals)}
            oemol = molecule.to_openeye()
            if oechem.OENetCharge(oemol) == 0: 
                for oeatom in oemol.GetAtoms():
                    oe_index = oeatom.GetIdx()
                    if oe_index in atom_map:
                        oeatom.SetMapIdx(atom_map[oe_index])

                options = oequacpac.OEFormalChargeOptions()
                # add one as the input is included
                options.SetMaxCount(5)
                for protomer in oequacpac.OEEnumerateFormalCharges(oemol, options):
                    charge = oechem.OENetCharge(protomer)
                    if charge !=0.0:
                        try:
                            off_protomer = Molecule.from_openeye(protomer)
                            dihedrals = [k for k, v in sorted(off_protomer.properties['atom_map'].items(), key=lambda item: item[1])]
                        except UndefinedStereochemistryError:
                            # off_protomer = Molecule.from_openeye(protomer, allow_undefined_stereo=True)
                            # off_protomer = ([off_protomer] + off_protomer.enumerate_stereoisomers(max_isomers=1))[-1]
                            print(f"Skipping {off_protomer.to_smiles()} - UndefinedStereochemistryError.")
                            continue

                        try:
                            off_protomer.generate_conformers(n_conformers=10)
                        except Exception:
                            print(f"Skipping {off_protomer.to_smiles()} - OMEGA error.")
                            continue

                        # dihedrals =   list(off_protomer.properties['atom_map'].keys())
                        # dihedrals = [k for k, v in sorted(off_protomer.properties['atom_map'].items(), key=lambda item: item[1])]
                        if len(dihedrals) == 4: 
                            torsion_indexer = TorsionIndexer()
                            torsion_indexer.add_torsion(dihedrals, (-165, 180), True)

                            off_protomer.properties["dihedrals"] = torsion_indexer
                            off_protomer_copy = copy.deepcopy(off_protomer)
                            del off_protomer_copy.properties['atom_map']
                            molecules3 .append(off_protomer_copy)
# Out:
# l: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: False
#
# Skipping [H]C([H])([H])C([H])(C([H])([H])[H])[N+]([H])([H])N([H])S(=O)(=O)C([H])([H])[H] - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])C([H])(C([H])([H])[H])[N+]([H])([H])N([H])S(=O)(=O)C([H])([H])[H] - UndefinedStereochemistryError.
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 9, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 10, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 14, aromatic: False, chiral: False
#
# Skipping [H]C([H])([H])C([H])(C([H])([H])[H])[N+]([H])([H])N([H])S(=O)(=O)C([H])([H])[H] - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])C([H])(C([H])([H])[H])[N+]([H])([H])N([H])S(=O)(=O)C([H])([H])[H] - UndefinedStereochemistryError.
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 6, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 6, aromatic: False, chiral: False
#
# Skipping [H]C([H])([H])C([H])(C([H])([H])[H])[N+]([H])([H])N([H])S(=O)(=O)C([H])([H])[H] - UndefinedStereochemistryError.
#  79%|███████▉  | 132/167 [03:38<01:18,  2.24s/it]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 15, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 16, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 20, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Skipping [H]C([H])([H])C([H])([H])[N+]([H])([H])N([H])[H] - UndefinedStereochemistryError.
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 17, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 7, aromatic: False, chiral: False
#
# Skipping [H]C([H])([H])C([H])([H])[N+]([H])([H])N([H])C([H])([H])[H] - UndefinedStereochemistryError.
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 17, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: False
#
# Skipping [H]C([H])([H])C([H])([H])N([H])[N+]([H])(C([H])([H])[H])C([H])([H])[H] - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])C([H])([H])N([H])[N+]([H])(C([H])([H])[H])C([H])([H])[H] - UndefinedStereochemistryError.
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 9, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 10, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 14, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 6, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 6, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True
# Atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 17, aromatic: False, chiral: False
#
# Skipping [H]C([H])([H])C([H])([H])N([H])[N+]([H])([H])C([H])(C([H])([H])[H])C([H])([H])[H] - UndefinedStereochemistryError.
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: True
# Atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 9, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: True
# Atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 9, aromatic: False, chiral: False
#
#  80%|███████▉  | 133/167 [03:42<01:28,  2.61s/it]Skipping [H]C([H])([H])C([H])([H])N([H])[N+]([H])([H])C([H])(C([H])([H])[H])C([H])([H])[H] - UndefinedStereochemistryError.
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 13, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 10, aromatic: False, chiral: False
#
# Skipping [H]C([H])([H])C(=O)N([H])[N+]([H])(C([H])([H])[H])C([H])([H])[H] - UndefinedStereochemistryError.
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 15, aromatic: False, chiral: False
#
# Skipping [H]C([H])([H])C(=O)N([H])[N+]([H])(C([H])([H])[H])C([H])([H])[H] - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])C(=O)N([H])[N+]([H])(C([H])([H])[H])C([H])([H])[H] - UndefinedStereochemistryError.
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: False
#
# Skipping [H]C([H])([H])C(=O)N([H])[N+]([H])(C([H])([H])[H])C([H])([H])[H] - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])C(=O)N([H])[N+]([H])(C([H])([H])[H])C([H])([H])[H] - UndefinedStereochemistryError.
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: False
#
# Skipping [H]C([H])([H])C(=O)N([H])[N+]([H])(C([H])([H])[H])C([H])([H])[H] - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])C(=O)N([H])[N+]([H])(C([H])([H])[H])C([H])([H])[H] - UndefinedStereochemistryError.
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 7, aromatic: False, chiral: False
#
# Skipping [H]C([H])([H])C(=O)N(C([H])([H])[H])[N-]S(=O)(=O)C([H])([H])[H] - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])C(=O)N(C([H])([H])[H])[N-]S(=O)(=O)C([H])([H])[H] - UndefinedStereochemistryError.
#  80%|████████  | 134/167 [03:46<01:45,  3.18s/it]Skipping [H]C([H])([H])C(=O)N([H])[N+]([H])([H])C([H])([H])C([H])([H])[H] - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])C(=O)N([H])[N+]([H])([H])C([H])([H])C([H])([H])[H] - UndefinedStereochemistryError.
#  81%|████████  | 135/167 [03:49<01:35,  3.00s/it]Skipping [H]C([H])([H])[N-]/N=[N+](/[C-](Br)Br)\[O-] - OMEGA error.
# Skipping [H]C([H])([H])N([H])/N=[N+](/[C-](Br)Br)\[O-] - OMEGA error.
# Skipping [H]C([H])([H])N([H])/N=[N+](/[C-](Br)Br)\[O-] - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])N([H])/N=[N+](/[C-](Br)Br)\[O-] - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])N([H])/N=[N+](/[C-](Br)Br)\[O-] - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])N([H])/N=[N+](/[C-](Br)Br)\[O-] - UndefinedStereochemistryError.
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: False
#
#  83%|████████▎ | 138/167 [03:52<00:54,  1.89s/it]Skipping [H]C([H])([H])[N-]N=O - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])[N-]N=O - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])[N-]N=O - UndefinedStereochemistryError.
# Skipping [C-](/[N+](=N/N=S=O)/[O-])(Br)Br - OMEGA error.
# Skipping [C-](Br)(Br)/[N+](=N/N=[N+](\[O-])/[C-](Br)Br)/[O-] - OMEGA error.
# Skipping [H]C(/[N+](=N/N=[N+](/[C-](Br)Br)\[O-])/[O-])(Br)Br - OMEGA error.
# Skipping [H]C(/[N+](=N/N=[N+](/[C-](Br)Br)\[O-])/[O-])(Br)Br - OMEGA error.
# Skipping [C-](/[N+](=N/N=[N+]=[N-])/[O-])(Br)Br - OMEGA error.
# Skipping [H]C(=N/N=[N+](/[C-](Br)Br)\[O-])[H] - OMEGA error.
#  83%|████████▎ | 139/167 [03:54<00:55,  1.99s/it]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 0, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 0, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 0, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 5, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 0, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 5, aromatic: False, chiral: False
#
# Skipping [H]C([H])([H])S[P+](=O)([H])([H])C([H])([H])N([H])[H] - OMEGA error.
#  85%|████████▌ | 142/167 [03:57<00:37,  1.51s/it]Skipping [H]C([H])([H])S/N=[N+](/[C-](Br)Br)\[O-] - OMEGA error.
# Skipping [H]C([H])([H])S/N=[N+](/[C-](Br)Br)\[O-] - UndefinedStereochemistryError.
# Skipping [H]C(=S(=C([H])[H])(C([H])([H])[H])N([H])[O-])[H] - UndefinedStereochemistryError.
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 15, aromatic: False, chiral: False
#
# Skipping [H]C(=S(=C([H])[H])(C([H])([H])[H])/N=[N+](/[C-](Br)Br)\[O-])[H] - OMEGA error.
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
#  86%|████████▌ | 144/167 [04:02<00:43,  1.90s/it]Skipping [H]C(=S(=C([H])[H])(C([H])([H])[H])[N+]([H])([H])[H])[H] - UndefinedStereochemistryError.
# Skipping [H]C(=S(=C([H])[H])(C([H])([H])[H])[N+]([H])([H])[H])[H] - UndefinedStereochemistryError.
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
# Skipping [H]C([H])([H])C([H])(C([H])([H])[H])S(=O)(=O)[N-]C([H])([H])[H] - UndefinedStereochemistryError.
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 0, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 0, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
# Skipping [H]C(=S(=C([H])[H])(C([H])([H])[H])[N+]([H])([H])C([H])([H])C([H])([H])[H])[H] - UndefinedStereochemistryError.
# Skipping [H]C(=S(=C([H])[H])(C([H])([H])[H])[N+]([H])([H])C([H])([H])C([H])([H])[H])[H] - UndefinedStereochemistryError.
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
#  87%|████████▋ | 146/167 [04:05<00:35,  1.69s/it]Skipping [H]N([H])S(=O)(=O)[O-] - UndefinedStereochemistryError.
#  89%|████████▊ | 148/167 [04:10<00:37,  1.97s/it]Skipping [H]C([H])([H])C([H])([H])[N-]S(=O)(=O)N([H])O[H] - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])C([H])([H])[N-]S(=O)(=O)N([H])O[H] - UndefinedStereochemistryError.
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 9, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 9, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 8, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 8, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 15, aromatic: False, chiral: False
#
# Skipping [H]C([H])([H])C([H])(C([H])([H])[H])S(=O)(=O)[N-]C([H])([H])[H] - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])C([H])(C([H])([H])[H])S(=O)(=O)[N-]C([H])([H])[H] - UndefinedStereochemistryError.
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 8, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 8, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Skipping [H]C([H])([H])C([H])(C([H])([H])[H])S(=O)(=O)[N-]C([H])([H])[H] - UndefinedStereochemistryError.
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 2, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 0, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 2, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 0, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
# Skipping [H]C([H])([H])C([H])(C([H])([H])[H])S(=O)(=O)[N-]C([H])([H])[H] - UndefinedStereochemistryError.
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 12, aromatic: False, chiral: False
#
# Skipping [H]C([H])([H])C([H])([H])N([H])S(=O)(=O)[N-][H] - UndefinedStereochemistryError.
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 7, aromatic: False, chiral: False
#
# Skipping [H]C([H])([H])C([H])([H])N([H])S(=O)(=O)[N-][H] - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])C([H])([H])N([H])S(=O)(=O)[N-][H] - UndefinedStereochemistryError.
#  89%|████████▉ | 149/167 [04:13<00:40,  2.27s/it]Skipping [H]C([H])([H])C([H])([H])N([H])S(=O)(=O)[O-] - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])C([H])([H])N([H])S(=O)(=O)[O-] - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])C(=O)[N-]S(=O)(=O)C([H])([H])C([H])([H])[H] - UndefinedStereochemistryError.
#  90%|█████████ | 151/167 [04:15<00:28,  1.79s/it]Skipping [H]C([H])([H])C(=O)[N-]S(=O)(=O)C([H])([H])C([H])([H])[H] - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])C(=O)[N-]S(=O)(=O)C([H])([H])C([H])([H])[H] - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])C(=O)N(C([H])([H])[H])S(=O)(=O)[C-](F)F - OMEGA error.
# Skipping [H]C([H])([H])C(=O)N(C([H])([H])[H])S(=O)(=O)[C-](F)F - UndefinedStereochemistryError.
#  91%|█████████ | 152/167 [04:18<00:29,  1.99s/it]Skipping [H]C([H])([H])C(=O)[N-]S(=O)(=O)C(F)(F)F - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])C(=O)[N-]S(=O)(=O)C(F)(F)F - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])C(=O)[N-]S(=O)(=O)C(F)(F)F - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])C(=O)[N-]S(=O)(=O)C(F)(F)F - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])C(=O)[N-]S(=O)(=O)C(F)(F)F - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])C(=O)[N-]S(=O)(=O)C(F)(F)F - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])C(=O)[N-]S(=O)(=O)C(F)(F)F - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])C(=O)[N-]S(=O)(=O)C(F)(F)F - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])C(=O)[N-]S(=O)(=O)C(F)(F)F - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])C(=O)[N-]S(=O)(=O)C(F)(F)F - UndefinedStereochemistryError.
#  92%|█████████▏| 153/167 [04:19<00:25,  1.83s/it]Skipping [H]C([H])([H])C(=O)[N-]S(=O)(=O)C(F)(F)F - UndefinedStereochemistryError.
# Skipping [H]C([H])([H])C(=O)[N-]S(=O)(=O)C(F)(F)F - UndefinedStereochemistryError.
# Skipping [H]C(=[N+]([H])S(=C([H])[H])(=C([H])[H])C([H])([H])[H])[H] - UndefinedStereochemistryError.
# Skipping [H]C(=[N+]([H])S(=C([H])[H])(=C([H])[H])C([H])([H])[H])[H] - UndefinedStereochemistryError.
# Skipping [H]C(=[N+]([H])S(=C([H])[H])(=C([H])[H])C([H])([H])[H])[H] - UndefinedStereochemistryError.
# Skipping [H]C(=NS(=O)(=O)[C-](F)F)[H] - OMEGA error.
#  93%|█████████▎| 155/167 [04:21<00:16,  1.41s/it]Skipping [H]C(=NS(=O)(=O)[N-]C([H])([H])[H])[H] - UndefinedStereochemistryError.
# Skipping [H]C(=NS(=O)(=O)[C-](F)F)[H] - OMEGA error.
#  93%|█████████▎| 156/167 [04:23<00:17,  1.56s/it]Skipping [H]C(=NS(=O)(=O)[N-]O[H])[H] - UndefinedStereochemistryError.
#  95%|█████████▍| 158/167 [04:24<00:10,  1.15s/it]Skipping [H]C([H])(N([H])[H])[P+](=O)([H])([H])OC([H])([H])F - OMEGA error.
# Skipping [H]C([H])(N([H])[H])[P+](=O)([H])([H])OC(F)(F)F - OMEGA error.
# Skipping [H]C([H])([H])C([H])([H])O[P+](=O)([H])([H])C([H])([H])N([H])[H] - OMEGA error.
# Skipping [H]C([H])([H])C(C([H])([H])[H])(C([H])([H])[H])O[P+](=O)([H])([H])C([H])([H])N([H])[H] - OMEGA error.
#  95%|█████████▌| 159/167 [04:26<00:11,  1.38s/it]Skipping [H]C([H])([H])O[P+](=O)([H])([H])C([H])([H])N([H])[H] - OMEGA error.
#  96%|█████████▌| 160/167 [04:27<00:09,  1.31s/it]Skipping [H]C([H])([H])C([H])([H])[N@@](C([H])([H])[H])[P+](=O)([H])([H])C([H])([H])N([H])[H] - OMEGA error.
# Skipping [H]C([H])([H])C(C([H])([H])[H])(C([H])([H])[H])N([H])[P+](=O)([H])([H])C([H])([H])N([H])[H] - OMEGA error.
# Skipping [H]C([H])([H])C([H])(C([H])([H])[H])[N@@](C([H])([H])[H])[P+](=O)([H])([H])C([H])([H])N([H])[H] - OMEGA error.
#  96%|█████████▋| 161/167 [04:30<00:09,  1.62s/it]Skipping [H]C([H])([H])S(=O)(=O)N([H])[P+](=O)([H])([H])C([H])([H])N([H])[H] - OMEGA error.
# Skipping [H]C([H])([H])C([H])([H])[N@@](C([H])([H])[H])[P+](=O)([H])([H])C([H])([H])N([H])[H] - OMEGA error.
# Skipping [H]C([H])([H])C(C([H])([H])[H])(C([H])([H])[H])N([H])[P+](=O)([H])([H])C([H])([H])N([H])[H] - OMEGA error.
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 15, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 13, aromatic: False, chiral: False
#
# Skipping [H]C([H])([H])C([H])(C([H])([H])[H])[N@@](C([H])([H])[H])[P+](=O)([H])([H])C([H])([H])N([H])[H] - OMEGA error.
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 15, name: , idx: 12, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 14, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 15, name: , idx: 12, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 14, aromatic: False, chiral: False
#
#  97%|█████████▋| 162/167 [04:32<00:09,  1.86s/it]Skipping [H]C([H])([H])S(=O)(=O)N([H])[P+](=O)([H])([H])C([H])([H])N([H])[H] - OMEGA error.
# 100%|██████████| 167/167 [04:33<00:00,  1.64s/it]

# %%
print(f'len(molecules1) = {len(molecules1)}')
print(f'len(molecules2) = {len(molecules2)}')
print(f'len(molecules3) = {len(molecules3)}')
# Out:
# len(molecules1) = 1084
# len(molecules2) = 164
# len(molecules3) = 383

# %%
molecules = list(molecules1 +molecules2 + molecules3)
print(f'len(molecules) = {len(molecules)}')
# Out:
# len(molecules) = 1631

# %%
dataset_factory = TorsiondriveDatasetFactory()

dataset = dataset_factory.create_dataset(
    dataset_name="OpenFF Gen3 Torsion Set v1.1",
    tagline="OpenFF Gen3 Torsion Set v1.1",
    description="This dataset is a simple-molecule-only torsiondrive dataset, aiming to avoid issue of torsion parameter contamination by large internal non-bonded interactions during a valece parameter optimization. Molecules with one effective rotating bond were generate by combining two simple substituents, which were identified by fragmenting small drug like molecules. Torsions from the generated molecule set were selected using clustering method, in a way that the dataset can allow a chemical diversity of molecules training each torsion parameter.",
    molecules=molecules,
)

dataset.metadata.submitter = "hyesujang"
dataset.metadata.long_description_url = (
    "https://github.com/openforcefield/qca-dataset-submission/tree/master/"
    "submissions/"
    "2021-05-07-OpenFF-Gen3-Torsion-Set-v1.1"
)
# Out:
# Deduplication                 : 100%|██████| 1631/1631 [00:04<00:00, 388.12it/s]
# Preparation                   :  20%|█▋      | 275/1352 [00:05<00:16, 64.40it/s]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
#
# Preparation                   :  21%|█▋      | 282/1352 [00:05<00:18, 56.47it/s]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
#
# Preparation                   :  22%|█▋      | 294/1352 [00:05<00:19, 53.82it/s]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 13, aromatic: False, chiral: False
#
# Preparation                   :  22%|█▊      | 300/1352 [00:05<00:21, 49.90it/s]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 19, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 10, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 20, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 24, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 7, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 15, aromatic: False, chiral: False
#
# Preparation                   :  23%|█▊      | 306/1352 [00:06<00:21, 48.27it/s]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 13, aromatic: False, chiral: False
#
# Preparation                   :  24%|█▉      | 326/1352 [00:06<00:17, 57.48it/s]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 13, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 9, aromatic: False, chiral: False
#
# Preparation                   :  30%|██▍     | 409/1352 [00:08<00:15, 59.88it/s]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 17, aromatic: False, chiral: False
#
# Preparation                   :  52%|████▏   | 700/1352 [00:12<00:13, 49.88it/s]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 15, aromatic: False, chiral: False
#
# Preparation                   :  52%|████▏   | 708/1352 [00:12<00:11, 54.00it/s]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 9, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 10, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 14, aromatic: False, chiral: False
#
# Preparation                   :  53%|████▎   | 722/1352 [00:13<00:10, 61.17it/s]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 15, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 16, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 20, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 17, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 17, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True
# Atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 17, aromatic: False, chiral: False
#
# Preparation                   :  54%|████▎   | 729/1352 [00:13<00:10, 57.99it/s]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 13, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 12, aromatic: False, chiral: False
#
# Preparation                   :  55%|████▍   | 750/1352 [00:13<00:09, 60.78it/s]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
#
# Preparation                   :  56%|████▍   | 760/1352 [00:13<00:08, 70.48it/s]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Preparation                   :  58%|████▌   | 778/1352 [00:13<00:07, 77.23it/s]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 15, aromatic: False, chiral: False
#
# Preparation                   :  59%|████▋   | 794/1352 [00:14<00:07, 78.41it/s]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Preparation                   :  60%|████▊   | 812/1352 [00:14<00:07, 74.83it/s]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 12, aromatic: False, chiral: False
#
# Preparation                   :  65%|█████▏  | 880/1352 [00:15<00:08, 55.88it/s]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 15, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 13, aromatic: False, chiral: False
#
# Preparation                   :  75%|█████▏ | 1012/1352 [00:18<00:04, 69.78it/s]Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 12, aromatic: False, chiral: False
#
# Preparation                   : 100%|███████| 1352/1352 [00:24<00:00, 54.18it/s]

# %%
confs = np.array([len(mol.conformers) for mol in dataset.molecules])
masses = []
for molecule in dataset.molecules:
    mass = sum(atom.mass.value_in_unit(unit.dalton) for atom in molecule.atoms)
    masses.append(mass)
charges = sorted(set(m.total_charge/m.total_charge.unit for m in dataset.molecules))
# Out:
# nd order: 1, chiral: False to atom atomic num: 8, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 15, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 13, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 13, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 19, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 10, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 20, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 24, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 7, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 13, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 13, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 9, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 17, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 9, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 10, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 14, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 15, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 16, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 20, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 17, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 17, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True
# Atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 17, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 13, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 15, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 13, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 13, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 19, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 10, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 20, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 24, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 7, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 13, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 13, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 9, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 17, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 9, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 10, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 14, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 15, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 16, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 20, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 17, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 17, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True
# Atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 17, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 13, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 15, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 13, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 12, aromatic: False, chiral: False

# %%
print("Number of unique molecules       ", dataset.n_molecules)
print("Number of filtered molecules     ", dataset.n_filtered)
print("Number of torsion drives         ", dataset.n_records)
print("Number of conformers min mean max",
      confs.min(), "{:6.2f}".format(confs.mean()), confs.max())

print(f'Mean molecular weight: {np.mean(np.array(masses)):.2f}')
print(f'Max molecular weight: {np.max(np.array(masses)):.2f}')
print("Charges:", charges)
# Out:
# Number of unique molecules        1352
# Number of filtered molecules      0
# Number of torsion drives          1353
# Number of conformers min mean max 1   2.53 12
# Mean molecular weight: 133.56
# Max molecular weight: 433.68
# Charges: [-2.0, -1.0, 0.0, 1.0, 2.0]

# %%
pprint(dataset.metadata.dict())
# Out:
# {'collection_type': 'TorsiondriveDataset',
#  'creation_date': datetime.date(2021, 5, 7),
#  'dataset_name': 'OpenFF Gen3 Torsion Set v1.1',
#  'elements': {'C', 'S', 'H', 'N', 'F', 'Cl', 'Br', 'P', 'O'},
#  'long_description': 'This dataset is a simple-molecule-only torsiondrive '
#                      'dataset, aiming to avoid issue of torsion parameter '
#                      'contamination by large internal non-bonded interactions '
#                      'during a valece parameter optimization. Molecules with '
#                      'one effective rotating bond were generate by combining '
#                      'two simple substituents, which were identified by '
#                      'fragmenting small drug like molecules. Torsions from the '
#                      'generated molecule set were selected using clustering '
#                      'method, in a way that the dataset can allow a chemical '
#                      'diversity of molecules training each torsion parameter.',
#  'long_description_url': HttpUrl('https://github.com/openforcefield/qca-dataset-submission/tree/master/submissions/2021-05-07-OpenFF-Gen3-Torsion-Set-v1.1', scheme='https', host='github.com', tld='com', host_type='domain', path='/openforcefield/qca-dataset-submission/tree/master/submissions/2021-05-07-OpenFF-Gen3-Torsion-Set-v1.1'),
#  'short_description': 'OpenFF Gen3 Torsion Set v1.1',
#  'submitter': 'hyesujang'}

# %%
dataset.priority = 'high'

# %%
for spec, obj in dataset.qc_specifications.items():
    print("Spec:", spec)
    pprint(obj.dict())
# Out:
# Spec: default
# {'basis': 'DZVP',
#  'implicit_solvent': None,
#  'method': 'B3LYP-D3BJ',
#  'program': 'psi4',
#  'spec_description': 'Standard OpenFF optimization quantum chemistry '
#                      'specification.',
#  'spec_name': 'default',
#  'store_wavefunction': 'none'}

# %%
pprint(dataset.scf_properties)
# Out:
# [<SCFProperties.Dipole: 'dipole'>,
#  <SCFProperties.Quadrupole: 'quadrupole'>,
#  <SCFProperties.WibergLowdinIndices: 'wiberg_lowdin_indices'>,
#  <SCFProperties.MayerIndices: 'mayer_indices'>]

# %%
dataset.export_dataset("dataset-expansion-1.json.bz2")
dataset.molecules_to_file("dataset-expansion-1.smi", "smi")

dataset.visualize("dataset-expansion-1.pdf", columns=8)
# Out:
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 13, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 19, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 10, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 20, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 24, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 7, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 13, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 13, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 9, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 17, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 9, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 10, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 14, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 15, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 16, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 20, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 17, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 17, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True
# Atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 17, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 13, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 2, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 10, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 15, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 1, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 10, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 15, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 13, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 8, name: , idx: 12, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 7, name: , idx: 7, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 16, name: , idx: 4, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 12, aromatic: False, chiral: False
