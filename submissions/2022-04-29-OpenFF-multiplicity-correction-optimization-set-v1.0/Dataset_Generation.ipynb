# %%
from openff.qcsubmit.common_structures import QCSpec, SCFProperties
from openff.qcsubmit.factories import OptimizationDatasetFactory
from openff.qcsubmit import workflow_components
import numpy as np
from qcelemental.models.results import WavefunctionProtocolEnum
from qcportal.models.common_models import DriverEnum
from openeye import oechem
import logging

# %%
logging.getLogger("openff").setLevel(logging.ERROR)

# %%
factory = OptimizationDatasetFactory()
factory.add_workflow_components(workflow_components.StandardConformerGenerator(max_conformers=50))
factory.dict()
# Out:
# {'qc_specifications': {'default': {'method': 'B3LYP-D3BJ',
#    'basis': 'DZVP',
#    'program': 'psi4',
#    'spec_name': 'default',
#    'spec_description': 'Standard OpenFF optimization quantum chemistry specification.',
#    'store_wavefunction': 'none',
#    'implicit_solvent': None,
#    'maxiter': 200,
#    'scf_properties': ['dipole',
#     'quadrupole',
#     'wiberg_lowdin_indices',
#     'mayer_indices'],
#    'keywords': None}},
#  'driver': 'gradient',
#  'priority': 'normal',
#  'dataset_tags': ['openff'],
#  'compute_tag': 'openff',
#  'type': 'OptimizationDatasetFactory',
#  'workflow': [{'type': 'StandardConformerGenerator',
#    'rms_cutoff': None,
#    'max_conformers': 50,
#    'clear_existing': True}],
#  'optimization_program': {'program': 'geometric',
#   'coordsys': 'dlc',
#   'enforce': 0.0,
#   'epsilon': 1e-05,
#   'reset': True,
#   'qccnv': False,
#   'molcnv': False,
#   'check': 0,
#   'trust': 0.1,
#   'tmax': 0.3,
#   'maxiter': 300,
#   'convergence_set': 'GAU',
#   'constraints': {}}}

# %%
dataset = factory.create_dataset(dataset_name="OpenFF multiplicity correction optimization set v1.0", 
                                 molecules="dataset.smi", tagline="QM Dataset for fitting multiplicity corrected torsions", 
                                 description="Data source: https://github.com/openforcefield/qca-dataset-submission/blob/master/submissions/2022-04-29-OpenFF-multiplicity-correction-optimization-data-v1.0/")
# Out:
# Deduplication                 : 100%|█████████| 99/99 [00:00<00:00, 1650.07it/s]
# StandardConformerGenerator    :   1%|            | 1/99 [00:00<00:45,  2.15it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   2%|▏           | 2/99 [00:00<00:34,  2.84it/s]Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  14%|█▌         | 14/99 [00:00<00:03, 21.76it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 S
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 S
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 S
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 S
# Warning: : Force field setup failed due to missing parameters
# RDKit ERROR: [21:39:45] UFFTYPER: Unrecognized charge state for atom: 4
# RDKit ERROR: [21:39:45] UFFTYPER: Unrecognized charge state for atom: 1
# RDKit ERROR: [21:39:45] UFFTYPER: Unrecognized charge state for atom: 6
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S
# Warning: : Force field setup failed due to missing parameters
# [21:39:45] UFFTYPER: Unrecognized charge state for atom: 4
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# [21:39:45] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 S
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 S
# Warning: : Force field setup failed due to missing parameters
# [21:39:45] UFFTYPER: Unrecognized charge state for atom: 6
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 10 S
# Warning: : Force field setup failed due to missing parameters
# StandardConformerGenerator    :  20%|██▏        | 20/99 [00:01<00:04, 18.51it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 S
# Warning: : Force field setup failed due to missing parameters
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 6 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# StandardConformerGenerator    :  27%|███        | 27/99 [00:01<00:02, 25.69it/s]Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 6 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 10 S
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 S
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 S
# Warning: : Force field setup failed due to missing parameters
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# RDKit ERROR: [21:39:46] UFFTYPER: Unrecognized charge state for atom: 6
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 S
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 S
# Warning: : Force field setup failed due to missing parameters
# [21:39:46] UFFTYPER: Unrecognized charge state for atom: 6
# RDKit ERROR: [21:39:46] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S
# Warning: OEMMFFParams::PrepMol() : unable to type atom 14 H
# Warning: : Force field setup failed due to missing parameters
# [21:39:46] UFFTYPER: Unrecognized charge state for atom: 1
# RDKit ERROR: [21:39:46] UFFTYPER: Unrecognized charge state for atom: 11
# RDKit ERROR: [21:39:46] UFFTYPER: Unrecognized charge state for atom: 2
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 11 S
# Warning: : Force field setup failed due to missing parameters
# [21:39:46] UFFTYPER: Unrecognized charge state for atom: 11
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 9 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 8 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 S
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 S
# Warning: : Force field setup failed due to missing parameters
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 10 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# [21:39:46] UFFTYPER: Unrecognized charge state for atom: 2
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 S
# Warning: : Force field setup failed due to missing parameters
# [21:39:46] UFFTYPER: Unrecognized charge state for atom: 2
# RDKit ERROR: [21:39:46] UFFTYPER: Unrecognized charge state for atom: 2
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  31%|███▍       | 31/99 [00:02<00:04, 14.02it/s]Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 9 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 8 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 10 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  35%|███▉       | 35/99 [00:02<00:05, 12.63it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  38%|████▏      | 38/99 [00:03<00:06,  9.39it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 C
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  57%|██████▏    | 56/99 [00:03<00:01, 23.41it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  63%|██████▉    | 62/99 [00:03<00:01, 27.12it/s]RDKit ERROR: [21:39:48] UFFTYPER: Unrecognized charge state for atom: 2
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 S
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 S
# Warning: : Force field setup failed due to missing parameters
# [21:39:48] UFFTYPER: Unrecognized charge state for atom: 2
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S
# Warning: : Force field setup failed due to missing parameters
# RDKit ERROR: [21:39:48] UFFTYPER: Unrecognized charge state for atom: 1
# RDKit ERROR: [21:39:48] UFFTYPER: Unrecognized charge state for atom: 5
# RDKit ERROR: [21:39:48] UFFTYPER: Unrecognized charge state for atom: 1
# [21:39:48] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 S
# Warning: : Force field setup failed due to missing parameters
# [21:39:48] UFFTYPER: Unrecognized charge state for atom: 5
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S
# Warning: : Force field setup failed due to missing parameters
# [21:39:48] UFFTYPER: Unrecognized charge state for atom: 1
# StandardConformerGenerator    :  72%|███████▉   | 71/99 [00:03<00:00, 30.97it/s]RDKit ERROR: [21:39:48] UFFTYPER: Unrecognized charge state for atom: 2
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 S
# Warning: : Force field setup failed due to missing parameters
# [21:39:48] UFFTYPER: Unrecognized charge state for atom: 2
# RDKit ERROR: [21:39:48] UFFTYPER: Unrecognized charge state for atom: 4
# RDKit ERROR: [21:39:48] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 S
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S
# Warning: : Force field setup failed due to missing parameters
# [21:39:48] UFFTYPER: Unrecognized charge state for atom: 4
# [21:39:48] UFFTYPER: Unrecognized charge state for atom: 1
# StandardConformerGenerator    :  77%|████████▍  | 76/99 [00:03<00:00, 30.46it/s]RDKit ERROR: [21:39:48] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S
# Warning: : Force field setup failed due to missing parameters
# [21:39:48] UFFTYPER: Unrecognized charge state for atom: 1
# RDKit ERROR: [21:39:48] UFFTYPER: Unrecognized charge state for atom: 1
# RDKit ERROR: [21:39:48] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S
# Warning: : Force field setup failed due to missing parameters
# [21:39:48] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S
# Warning: : Force field setup failed due to missing parameters
# [21:39:48] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    : 100%|███████████| 99/99 [00:05<00:00, 18.66it/s]
# Preparation                   :  23%|██▌        | 23/99 [00:00<00:02, 27.14it/s]Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 6 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 6 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 6 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 6 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 6 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Preparation                   :  28%|███        | 28/99 [00:00<00:02, 32.49it/s]Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 9 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 9 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 9 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 9 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 9 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 8 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 8 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 8 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 8 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 8 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 10 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 10 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 10 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 10 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 10 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Preparation                   : 100%|███████████| 99/99 [00:02<00:00, 42.83it/s]

# %%
#issue: 26 molecules are filtered
#need to fix this 

confs = np.array([len(mol.conformers) for mol in dataset.molecules])

print("Number of unique molecules       ", dataset.n_molecules)
print("Number of filtered molecules     ", dataset.n_filtered)
print("Number of conformers             ", dataset.n_records)
print("Number of conformers min mean max",
      confs.min(), "{:6.2f}".format(confs.mean()), confs.max())

masses = []
for molecule in dataset.molecules:
    oemol = molecule.to_openeye()
    mass = oechem.OECalculateMolecularWeight(oemol)
    masses.append(mass)

print(f'Mean molecular weight: {np.mean(np.array(masses)):.2f}')
print(f'Max molecular weight: {np.max(np.array(masses)):.2f}')
print("Charges:", sorted(set(m.total_charge/m.total_charge.unit for m in dataset.molecules)))
# Out:
# Number of unique molecules        99
# Number of filtered molecules      0
# Number of conformers              400
# Number of conformers min mean max 1   4.04 50
# Mean molecular weight: 172.23
# Max molecular weight: 317.32
# Charges: [-1.0, 0.0, 1.0]

# %%
dataset.visualize("dataset.pdf")

# %%
dataset.metadata.submitter = 'Jessica Maat'

# %%
dataset.metadata.long_description_url = 'https://github.com/openforcefield/qca-dataset-submission/tree/master/submissions/2022-04-29-OpenFF-multiplicity-correction-optimization-set-v1.0'

# %%
dataset.metadata
# Out:
# Metadata(submitter='Jessica Maat', creation_date=datetime.date(2022, 5, 24), collection_type='OptimizationDataset', dataset_name='OpenFF multiplicity correction optimization set v1.0', short_description='QM Dataset for fitting multiplicity corrected torsions', long_description_url=HttpUrl('https://github.com/openforcefield/qca-dataset-submission/tree/master/submissions/2022-04-29-OpenFF-multiplicity-correction-optimization-set-v1.0', scheme='https', host='github.com', tld='com', host_type='domain', port='443', path='/openforcefield/qca-dataset-submission/tree/master/submissions/2022-04-29-OpenFF-multiplicity-correction-optimization-set-v1.0'), long_description='Data source: https://github.com/openforcefield/qca-dataset-submission/blob/master/submissions/2022-04-29-OpenFF-multiplicity-correction-optimization-data-v1.0/', elements={'N', 'O', 'C', 'S', 'H', 'P'})

# %%
dataset.export_dataset("dataset.json.bz2")
