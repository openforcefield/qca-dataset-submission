# %% [markdown]
# # OpenFF Additional Generated ChEMBL Optimizations 4.0
#
# This notebook generates additional optimizations from molecules for bond, angle, and improper parameters in Sage 2.2.1 with either low coverage, or where a substantial number of existing records have the molecules minimize to a different value to the QM.
# Input files are obtained from the process in the [fragment-chembl-data](https://github.com/lilyminium/fragment-chembl-data/commit/1a85d6b296350867a134529aa76930965a710a68) repo.

# %%
import zstandard
import qcportal
import pathlib

from openff.toolkit import Molecule, ForceField
import numpy as np
import tqdm

from openff.qcsubmit.utils import get_symmetry_classes, get_symmetry_group
from openff.qcsubmit import workflow_components
from openff.qcsubmit.factories import OptimizationDatasetFactory
from openff.qcsubmit.utils.visualize import molecules_to_pdf

# %%
input_directory = pathlib.Path("inputs")
input_files = input_directory.glob("*.smi")
all_molecules = []
for file in tqdm.tqdm(input_files):
    parameter_id = file.stem.split("-")[-1]
    molecules = Molecule.from_file(file, allow_undefined_stereo=True)
    for mol in molecules:
        mol.name = None
    all_molecules.extend(molecules)
    molecules_to_pdf(molecules, f"inputs/{parameter_id}_molecules.pdf")
# Out:
# 68it [00:02, 31.89it/s]

# %%
len(all_molecules)
# Out:
# 1880

# %%
dataset_factory = OptimizationDatasetFactory()
dataset_factory.add_workflow_components(
    workflow_components.StandardConformerGenerator(max_conformers=10)
)

description = """\
This optimization dataset adds more coverage for rare parameters, as listed in `inputs/`.
The parameters, as in Sage 2.2.1 are:
- a16, a36, a7
- b15, b23, b24, b29, b40, b42, b44, b47, b49, b54, b55, b59, b62, b63, b64, b65, b67, b69, b74, b76, b77, b78, b80, b81, b82
- i4, i5
- t101, t102, t103, t112, t113, t114, t12, t126, t128, t129, t136, t137, t138a, t141, t141a, t141c
- t154, t158, t164, t165, t167, t30, t31a, t33, t42a, t49, t54, t55, t59, t60, t61, t62, t7, t73, t8, t81, t88, t89.

Molecules were generated according to the process in https://github.com/lilyminium/fragment-chembl-data/commit/1a85d6b296350867a134529aa76930965a710a68
repo. In short, for torsions:

- ChEMBL molecules were split into "elementary" fragments without rotatable bonds
- Elementary fragments were combined with a single bond
- For each torsion, a pool of up to 5000 molecules were initially selected after sorting for low molecular weight
- Up to 250 molecules were selected from this pool by maximising chemical diversity, using the Tanimoto distance of the Morgan fingerprints
- Up to 10 molecules were selected from the second pool by maximising the diversity of coupled torsions through the central bond

For bonds, angles, and impropers:
- For each torsion, a pool of up to 10000 molecules were initially selected after sorting for low molecular weight
- Up to 500 molecules were selected from this pool by maximising chemical diversity, using the Tanimoto distance of the Morgan fingerprints
- Up to 50 molecules were selected from the second pool by maximising the diversity of other parameters applied to the atoms of each parameter


This dataset uses the OpenFF default level of theory (B3LYP-D3BJ/DZVP).
It covers the H, N, P, F, Br, C, I, Cl, S, O elements and -3.0, -2.0, -1.0, 0.0, 1.0, 2.0 charges.
Molecular MW ranges from 32 – 313 Da with mean MW of 126 Da.

"""

dataset = dataset_factory.create_dataset(
    dataset_name="OpenFF Additional Generated ChEMBL TorsionDrives 4.0",
    tagline="Additional TorsionDrives curated from ChEMBL fragments for rare torsions",
    description=description,
    molecules=all_molecules,
)

dataset.metadata.submitter = "lilyminium"
dataset.metadata.long_description_url = (
    "https://github.com/openforcefield/qca-dataset-submission/tree/master/"
    "submissions/" + str(pathlib.Path.cwd().name)
)
# Out:
# Deduplication                 : 100%|█████| 1880/1880 [00:00<00:00, 2037.29it/s]
# StandardConformerGenerator    :   0%|                  | 0/1847 [00:00<?, ?it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   0%|          | 7/1847 [00:02<08:27,  3.62it/s]Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 13 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 13 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   1%|         | 10/1847 [00:02<06:04,  5.04it/s][15:31:02] UFFTYPER: Warning: hybridization set to SP3 for atom 7
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 Cl on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 Cl on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# StandardConformerGenerator    :   1%|▏        | 26/1847 [00:02<01:41, 17.95it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# StandardConformerGenerator    :   2%|▏        | 36/1847 [00:03<01:08, 26.58it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   2%|▏        | 45/1847 [00:03<00:52, 34.41it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   3%|▎        | 53/1847 [00:03<00:46, 38.48it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   3%|▎        | 60/1847 [00:03<00:45, 39.15it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   4%|▎        | 67/1847 [00:03<00:43, 40.53it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 Cl on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   4%|▎        | 76/1847 [00:03<00:40, 43.64it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   5%|▍        | 85/1847 [00:03<00:33, 52.27it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:03] UFFTYPER: Unrecognized charge state for atom: 2
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   5%|▍        | 94/1847 [00:04<00:30, 56.82it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   5%|▍       | 101/1847 [00:04<00:36, 47.41it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   6%|▍       | 113/1847 [00:04<00:29, 59.49it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 S on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# [15:31:03] UFFTYPER: Unrecognized charge state for atom: 5
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# StandardConformerGenerator    :   6%|▌       | 120/1847 [00:04<00:29, 59.18it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:03] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:03] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 S on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 10 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:03] UFFTYPER: Unrecognized charge state for atom: 5
# [15:31:04] UFFTYPER: Unrecognized charge state for atom: 1
# [15:31:04] UFFTYPER: Warning: hybridization set to SP3 for atom 2
# StandardConformerGenerator    :   7%|▌       | 127/1847 [00:04<00:33, 51.77it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:04] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Force field setup failed due to missing parameters
# [15:31:04] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:04] UFFTYPER: Unrecognized atom type: S_5+4 (1)
# Warning: template fit failed.  rms/cutoff = 0.20/0.15
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# StandardConformerGenerator    :   7%|▌       | 135/1847 [00:04<00:30, 56.45it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:04] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# [15:31:04] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# [15:31:04] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# StandardConformerGenerator    :   8%|▋       | 145/1847 [00:04<00:25, 65.79it/s][15:31:04] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OEMMFFParams::PrepMol() : unable to type atom 12 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 12 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:04] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:04] UFFTYPER: Unrecognized charge state for atom: 2
# StandardConformerGenerator    :   8%|▋       | 153/1847 [00:04<00:24, 67.90it/s]Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 11 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:04] UFFTYPER: Unrecognized charge state for atom: 5
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:04] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:04] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# StandardConformerGenerator    :   9%|▋       | 161/1847 [00:05<00:23, 70.53it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 S on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:04] UFFTYPER: Unrecognized charge state for atom: 5
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 Cl on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:04] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 14 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 15 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:04] UFFTYPER: Unrecognized charge state for atom: 1
# [15:31:04] UFFTYPER: Unrecognized atom type: S_5+4 (5)
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:04] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:04] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 Cl on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 Cl on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# StandardConformerGenerator    :   9%|▋       | 169/1847 [00:05<00:23, 70.45it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  10%|▊       | 177/1847 [00:05<00:26, 63.67it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 13 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 14 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:04] UFFTYPER: Warning: hybridization set to SP3 for atom 4
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:04] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# StandardConformerGenerator    :  10%|▊       | 185/1847 [00:05<00:25, 64.02it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  10%|▊       | 193/1847 [00:05<00:24, 67.22it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:05] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [15:31:05] UFFTYPER: Unrecognized charge state for atom: 1Warning: : Failed due to unspecified stereochemistry
#
# StandardConformerGenerator    :  11%|▊       | 201/1847 [00:05<00:25, 65.18it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:05] UFFTYPER: Unrecognized atom type: S_5+4 (1)
# StandardConformerGenerator    :  11%|▉       | 208/1847 [00:05<00:25, 64.63it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 Cl on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 Cl on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  12%|▉       | 215/1847 [00:05<00:26, 60.46it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:05] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# StandardConformerGenerator    :  12%|▉       | 224/1847 [00:06<00:30, 52.49it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# StandardConformerGenerator    :  13%|█       | 241/1847 [00:06<00:21, 75.45it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# StandardConformerGenerator    :  14%|█       | 250/1847 [00:06<00:22, 71.73it/s]Warning: OEMMFFParams::PrepMol() : unable to type atom 1 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# StandardConformerGenerator    :  14%|█       | 258/1847 [00:06<00:21, 72.23it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  14%|█▏      | 266/1847 [00:06<00:22, 71.54it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# StandardConformerGenerator    :  15%|█▏      | 275/1847 [00:06<00:24, 65.48it/s]Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:06] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# StandardConformerGenerator    :  15%|█▏      | 286/1847 [00:06<00:22, 70.56it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  16%|█▎      | 296/1847 [00:07<00:21, 71.79it/s]Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  16%|█▎      | 304/1847 [00:07<00:21, 73.15it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  17%|█▎      | 313/1847 [00:07<00:20, 73.90it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  17%|█▍      | 322/1847 [00:07<00:19, 77.08it/s]Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  18%|█▍      | 330/1847 [00:07<00:19, 77.07it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  18%|█▍      | 338/1847 [00:07<00:21, 71.74it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  19%|█▍      | 346/1847 [00:07<00:20, 72.80it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# StandardConformerGenerator    :  19%|█▌      | 355/1847 [00:07<00:20, 73.78it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  20%|█▌      | 363/1847 [00:07<00:19, 75.24it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# StandardConformerGenerator    :  20%|█▌      | 371/1847 [00:08<00:20, 70.43it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  21%|█▋      | 381/1847 [00:08<00:19, 76.14it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  21%|█▋      | 389/1847 [00:08<00:19, 76.55it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  21%|█▋      | 397/1847 [00:08<00:20, 71.42it/s]Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  22%|█▊      | 407/1847 [00:08<00:19, 75.01it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 Br on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 Br on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  23%|█▊      | 417/1847 [00:08<00:18, 75.29it/s]Warning: OEMMFFParams::PrepMol() : unable to type atom 1 Br on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 Br on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 Br on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 S on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Force field setup failed due to missing parameters
# ...
# Warning: OEMMFFParams::PrepMol() : unable to type atom 10 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:30] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [15:31:30] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:30] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [15:31:30] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 15 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 16 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:30] UFFTYPER: Warning: hybridization set to SP3 for atom 6
# [15:31:30] UFFTYPER: Unrecognized charge state for atom: 6
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 10 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:30] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [15:31:30] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:31:30] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [15:31:30] UFFTYPER: Unrecognized charge state for atom: 1
# [15:31:30] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [15:31:30] UFFTYPER: Unrecognized charge state for atom: 1
# StandardConformerGenerator    : 100%|███████| 1847/1847 [01:19<00:00, 23.35it/s]
# Preparation                   :   8%|▌      | 140/1844 [00:01<00:13, 129.27it/s]Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Preparation                   :  23%|█▌     | 428/1844 [00:03<00:10, 132.47it/s]Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Preparation                   :  29%|██     | 543/1844 [00:04<00:09, 143.34it/s]Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Preparation                   :  30%|██     | 559/1844 [00:04<00:08, 145.33it/s]Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Preparation                   :  33%|██▎    | 603/1844 [00:04<00:09, 135.19it/s]Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Preparation                   :  34%|██▍    | 631/1844 [00:04<00:09, 134.20it/s]Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Preparation                   :  39%|██▋    | 715/1844 [00:05<00:09, 117.38it/s]Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Preparation                   :  53%|███▋   | 972/1844 [00:07<00:07, 117.48it/s]Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Preparation                   :  59%|███▌  | 1080/1844 [00:08<00:07, 106.91it/s]Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Preparation                   :  59%|███▌  | 1093/1844 [00:08<00:06, 111.12it/s]Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Preparation                   :  63%|███▊  | 1168/1844 [00:09<00:06, 102.44it/s]Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Preparation                   :  65%|███▉  | 1194/1844 [00:09<00:05, 110.49it/s]Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Preparation                   :  70%|████▏ | 1295/1844 [00:10<00:04, 123.65it/s]Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Preparation                   :  77%|████▌ | 1420/1844 [00:11<00:03, 114.15it/s]Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Preparation                   :  78%|████▋ | 1444/1844 [00:12<00:03, 113.38it/s]Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Preparation                   :  79%|████▋ | 1456/1844 [00:12<00:03, 110.48it/s]Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Preparation                   :  82%|████▉ | 1516/1844 [00:12<00:02, 111.29it/s]Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Preparation                   :  83%|████▉ | 1529/1844 [00:12<00:02, 115.77it/s]Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 9 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 9 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 9 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 9 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 9 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Preparation                   :  87%|██████ | 1600/1844 [00:13<00:02, 98.11it/s]Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Preparation                   :  91%|█████▍| 1673/1844 [00:14<00:01, 105.47it/s]Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Preparation                   : 100%|██████| 1844/1844 [00:15<00:00, 117.13it/s]

# %%
dataset.n_molecules
# Out:
# 1844

# %%
print(description)
# Out:
# This optimization dataset adds more coverage for rare parameters, as listed in `inputs/`.
# The parameters, as in Sage 2.2.1 are:
# - a16, a36, a7
# - b15, b23, b24, b29, b40, b42, b44, b47, b49, b54, b55, b59, b62, b63, b64, b65, b67, b69, b74, b76, b77, b78, b80, b81, b82
# - i4, i5
# - t101, t102, t103, t112, t113, t114, t12, t126, t128, t129, t136, t137, t138a, t141, t141a, t141c
# - t154, t158, t164, t165, t167, t30, t31a, t33, t42a, t49, t54, t55, t59, t60, t61, t62, t7, t73, t8, t81, t88, t89.
#
# Molecules were generated according to the process in https://github.com/lilyminium/fragment-chembl-data/commit/1a85d6b296350867a134529aa76930965a710a68
# repo. In short, for torsions:
#
# - ChEMBL molecules were split into "elementary" fragments without rotatable bonds
# - Elementary fragments were combined with a single bond
# - For each torsion, a pool of up to 5000 molecules were initially selected after sorting for low molecular weight
# - Up to 250 molecules were selected from this pool by maximising chemical diversity, using the Tanimoto distance of the Morgan fingerprints
# - Up to 10 molecules were selected from the second pool by maximising the diversity of coupled torsions through the central bond
#
# For bonds, angles, and impropers:
# - For each torsion, a pool of up to 10000 molecules were initially selected after sorting for low molecular weight
# - Up to 500 molecules were selected from this pool by maximising chemical diversity, using the Tanimoto distance of the Morgan fingerprints
# - Up to 50 molecules were selected from the second pool by maximising the diversity of other parameters applied to the atoms of each parameter
#
#
# This dataset uses the OpenFF default level of theory (B3LYP-D3BJ/DZVP).
# It covers the H, N, P, F, Br, C, I, Cl, S, O elements and -3.0, -2.0, -1.0, 0.0, 1.0, 2.0 charges.
# Molecular MW ranges from 32 – 313 Da with mean MW of 126 Da.

# %%
# summarize dataset for readme
confs = np.array([len(mol.conformers) for mol in dataset.molecules])

print("* Number of unique molecules:", dataset.n_molecules)
# With multiple torsions per unique molecule, n_molecules * confs.mean() no
# longer equals the number of conformers. instead, the number of dihedrals *
# confs.mean() should equal the number of conformers. The dataset contains one
# record per driven torsion (rather than combining multiple dihedrals into the
# same record), so n_records is the same as manually adding up len(dihedrals)
# for each record.
print("* Number of filtered molecules:", dataset.n_filtered)
print("* Number of conformers:", sum(confs))
print(
    "* Number of conformers per molecule (min, mean, max): "
    f"{confs.min()}, {confs.mean():.2f}, {confs.max()}"
)

masses = [
    [
        sum([atom.mass.m for atom in molecule.atoms])
        for molecule in dataset.molecules
    ]
]
print(f"* Mean molecular weight: {np.mean(np.array(masses)):.2f}")
print(f"* Min molecular weight: {np.min(np.array(masses)):.2f}")
print(f"* Max molecular weight: {np.max(np.array(masses)):.2f}")
print("* Charges:", sorted(set(m.total_charge.m for m in dataset.molecules)))


print("## Metadata")
print(f"* Elements: {{{', '.join(dataset.metadata.dict()['elements'])}}}")


fields = [
    "basis",
    "implicit_solvent",
    "keywords",
    "maxiter",
    "method",
    "program",
]
for spec, obj in dataset.qc_specifications.items():
    od = obj.dict()
    print("* Spec:", spec)
    for field in fields:
        print(f"\t * {field}: {od[field]}")
    print("\t* SCF properties:")
    for field in od["scf_properties"]:
        print(f"\t\t* {field}")


# export the dataset
dataset.export_dataset("dataset.json.bz2")
dataset.molecules_to_file("output.smi", "smi")
dataset.visualize("dataset.pdf", columns=8)
# Out:
# * Number of unique molecules: 1844
# * Number of filtered molecules: 3
# * Number of conformers: 2429
# * Number of conformers per molecule (min, mean, max): 1, 1.32, 6
# * Mean molecular weight: 125.99
# * Min molecular weight: 32.05
# * Max molecular weight: 312.99
# * Charges: [-3.0, -2.0, -1.0, 0.0, 1.0, 2.0]
# ## Metadata
# * Elements: {F, Br, Cl, P, S, O, N, H, C, I}
# * Spec: default
# 	 * basis: DZVP
# 	 * implicit_solvent: None
# 	 * keywords: {}
# 	 * maxiter: 200
# 	 * method: B3LYP-D3BJ
# 	 * program: psi4
# 	* SCF properties:
# 		* dipole
# 		* quadrupole
# 		* wiberg_lowdin_indices
# 		* mayer_indices
