# %% [markdown]
# # OpenFF Additional Generated ChEMBL Optimizations v4.0
#
# This notebook generates additional optimizations from molecules for bond, angle, and improper parameters in Sage 2.2.1 with either low coverage, or where a substantial number of existing records have the molecules minimize to a different value to the QM.
# Input files are obtained from the process in the [fragment-chembl-data](https://github.com/lilyminium/fragment-chembl-data/commit/1a85d6b296350867a134529aa76930965a710a68) repo.

# %%
import zstandard
import qcportal
import pathlib

from openff.toolkit import Molecule, ForceField
import numpy as np
import tqdm

from openff.qcsubmit.utils import get_symmetry_classes, get_symmetry_group
from openff.qcsubmit import workflow_components
from openff.qcsubmit.factories import OptimizationDatasetFactory
from openff.qcsubmit.utils.visualize import molecules_to_pdf

# %%
input_directory = pathlib.Path("inputs")
input_files = input_directory.glob("*.smi")
all_molecules = []
for file in tqdm.tqdm(input_files):
    parameter_id = file.stem.split("-")[-1]
    molecules = Molecule.from_file(file, allow_undefined_stereo=True)
    for mol in molecules:
        mol.name = None
    all_molecules.extend(molecules)
    molecules_to_pdf(molecules, f"inputs/{parameter_id}_molecules.pdf")
# Out:
# 68it [00:02, 31.85it/s]

# %%
len(all_molecules)
# Out:
# 1880

# %%
dataset_factory = OptimizationDatasetFactory()
dataset_factory.add_workflow_components(
    workflow_components.StandardConformerGenerator(max_conformers=10)
)

description = """\
This optimization dataset adds more coverage for rare parameters, as listed in `inputs/`.
The parameters, as in Sage 2.2.1 are:
- a16, a36, a7
- b15, b23, b24, b29, b40, b42, b44, b47, b49, b54, b55, b59, b62, b63, b64, b65, b67, b69, b74, b76, b77, b78, b80, b81, b82
- i4, i5
- t101, t102, t103, t112, t113, t114, t12, t126, t128, t129, t136, t137, t138a, t141, t141a, t141c
- t154, t158, t164, t165, t167, t30, t31a, t33, t42a, t49, t54, t55, t59, t60, t61, t62, t7, t73, t8, t81, t88, t89.

Molecules were generated according to the process in https://github.com/lilyminium/fragment-chembl-data/commit/1a85d6b296350867a134529aa76930965a710a68
repo. In short, for torsions:

- ChEMBL molecules were split into "elementary" fragments without rotatable bonds
- Elementary fragments were combined with a single bond
- For each torsion, a pool of up to 5000 molecules were initially selected after sorting for low molecular weight
- Up to 250 molecules were selected from this pool by maximising chemical diversity, using the Tanimoto distance of the Morgan fingerprints
- Up to 10 molecules were selected from the second pool by maximising the diversity of coupled torsions through the central bond

For bonds, angles, and impropers:
- For each torsion, a pool of up to 10000 molecules were initially selected after sorting for low molecular weight
- Up to 500 molecules were selected from this pool by maximising chemical diversity, using the Tanimoto distance of the Morgan fingerprints
- Up to 50 molecules were selected from the second pool by maximising the diversity of other parameters applied to the atoms of each parameter


This dataset uses the OpenFF default level of theory (B3LYP-D3BJ/DZVP).
It covers the H, N, P, F, Br, C, I, Cl, S, O elements and -3.0, -2.0, -1.0, 0.0, 1.0, 2.0 charges.
Molecular MW ranges from 32 – 313 Da with mean MW of 126 Da.

"""

dataset = dataset_factory.create_dataset(
    dataset_name="OpenFF Additional Generated ChEMBL Optimizations v4.0",
    tagline="Additional Optimizations curated from ChEMBL fragments for rare parameters",
    description=description,
    molecules=all_molecules,
)

dataset.metadata.submitter = "lilyminium"
dataset.metadata.long_description_url = (
    "https://github.com/openforcefield/qca-dataset-submission/tree/master/"
    "submissions/" + str(pathlib.Path.cwd().name)
)
# Out:
# Deduplication                 : 100%|█████| 1880/1880 [00:00<00:00, 2058.86it/s]
# StandardConformerGenerator    :   0%|                  | 0/1847 [00:00<?, ?it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   0%|        | 1/1847 [00:02<1:26:46,  2.82s/it]Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   0%|          | 2/1847 [00:03<41:34,  1.35s/it]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 13 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 13 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   1%|         | 23/1847 [00:03<02:23, 12.75it/s]Warning: : Failed due to unspecified stereochemistry
# [15:39:24] UFFTYPER: Warning: hybridization set to SP3 for atom 7
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 Cl on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 Cl on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# StandardConformerGenerator    :   2%|▏        | 33/1847 [00:03<01:33, 19.33it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   2%|▏        | 42/1847 [00:03<01:12, 25.02it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   3%|▏        | 51/1847 [00:03<00:56, 31.77it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   3%|▎        | 59/1847 [00:03<00:49, 36.28it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   4%|▎        | 71/1847 [00:03<00:35, 49.47it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 Cl on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# StandardConformerGenerator    :   4%|▍        | 80/1847 [00:04<00:33, 52.97it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:25] UFFTYPER: Unrecognized charge state for atom: 2
# StandardConformerGenerator    :   5%|▍        | 88/1847 [00:04<00:32, 54.06it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   5%|▍        | 96/1847 [00:04<00:34, 50.76it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   6%|▍       | 108/1847 [00:04<00:26, 64.67it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 S on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# [15:39:25] UFFTYPER: Unrecognized charge state for atom: 5
# StandardConformerGenerator    :   6%|▌       | 117/1847 [00:04<00:25, 67.85it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:26] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:26] UFFTYPER: Unrecognized charge state for atom: 1
# [15:39:26] UFFTYPER: Warning: hybridization set to SP3 for atom 2
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 S on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# StandardConformerGenerator    :   7%|▌       | 125/1847 [00:04<00:29, 58.46it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 10 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:26] UFFTYPER: Unrecognized charge state for atom: 5
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:26] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:26] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: template fit failed.  rms/cutoff = 0.20/0.15
# [15:39:26] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:26] UFFTYPER: Unrecognized atom type: S_5+4 (1)
# StandardConformerGenerator    :   7%|▌       | 137/1847 [00:04<00:23, 71.77it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:26] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:26] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:26] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:26] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OEMMFFParams::PrepMol() : unable to type atom 12 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 12 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# StandardConformerGenerator    :   8%|▋       | 146/1847 [00:05<00:24, 69.94it/s]Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# [15:39:26] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:26] UFFTYPER: Unrecognized charge state for atom: 2
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 11 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:26] UFFTYPER: Unrecognized charge state for atom: 5
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   8%|▋       | 156/1847 [00:05<00:22, 76.83it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:26] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:26] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 S on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 Cl on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:26] UFFTYPER: Unrecognized charge state for atom: 1
# [15:39:26] UFFTYPER: Unrecognized charge state for atom: 5
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:26] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:26] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 14 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 15 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:26] UFFTYPER: Unrecognized atom type: S_5+4 (5)
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:26] UFFTYPER: Unrecognized charge state for atom: 1
# StandardConformerGenerator    :   9%|▋       | 165/1847 [00:05<00:22, 73.46it/s]Warning: OEMMFFParams::PrepMol() : unable to type atom 3 Cl on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 Cl on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   9%|▋       | 173/1847 [00:05<00:25, 64.86it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 13 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 14 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:26] UFFTYPER: Warning: hybridization set to SP3 for atom 4
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  10%|▊       | 181/1847 [00:05<00:24, 68.13it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:26] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  10%|▊       | 191/1847 [00:05<00:23, 70.89it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  11%|▊       | 200/1847 [00:05<00:23, 71.05it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# [15:39:27] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [15:39:27] UFFTYPER: Unrecognized charge state for atom: 1
# StandardConformerGenerator    :  11%|▉       | 208/1847 [00:05<00:22, 72.40it/s]Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:27] UFFTYPER: Unrecognized atom type: S_5+4 (1)
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 Cl on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 Cl on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# StandardConformerGenerator    :  12%|▉       | 216/1847 [00:05<00:23, 69.67it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:27] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# StandardConformerGenerator    :  12%|▉       | 224/1847 [00:06<00:22, 72.04it/s]Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# StandardConformerGenerator    :  13%|█       | 232/1847 [00:06<00:25, 63.82it/s]Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# StandardConformerGenerator    :  13%|█       | 241/1847 [00:06<00:24, 64.86it/s]Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# StandardConformerGenerator    :  14%|█       | 251/1847 [00:06<00:23, 68.06it/s]Warning: OEMMFFParams::PrepMol() : unable to type atom 1 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 I on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# StandardConformerGenerator    :  14%|█▏      | 261/1847 [00:06<00:21, 73.00it/s]Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 I on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# StandardConformerGenerator    :  15%|█▏      | 270/1847 [00:06<00:21, 73.24it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# StandardConformerGenerator    :  15%|█▏      | 280/1847 [00:06<00:20, 76.65it/s]Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 5 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:28] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# StandardConformerGenerator    :  16%|█▎      | 289/1847 [00:07<00:20, 75.47it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  16%|█▎      | 297/1847 [00:07<00:21, 71.03it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 4 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  17%|█▎      | 306/1847 [00:07<00:22, 67.55it/s]Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 0 C on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  17%|█▎      | 317/1847 [00:07<00:19, 77.75it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  18%|█▍      | 326/1847 [00:07<00:20, 75.38it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  18%|█▍      | 335/1847 [00:07<00:19, 78.20it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  19%|█▍      | 343/1847 [00:07<00:19, 75.54it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  19%|█▌      | 351/1847 [00:07<00:20, 74.56it/s]Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  19%|█▌      | 359/1847 [00:07<00:20, 71.99it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  20%|█▌      | 368/1847 [00:08<00:20, 72.83it/s]Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  20%|█▋      | 376/1847 [00:08<00:20, 71.11it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  21%|█▋      | 384/1847 [00:08<00:20, 69.72it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# StandardConformerGenerator    :  21%|█▋      | 391/1847 [00:08<00:21, 66.58it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 S on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  22%|█▋      | 399/1847 [00:08<00:21, 66.39it/s]Warning: : Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  22%|█▊      | 408/1847 [00:08<00:21, 66.58it/s]Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 Br on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 Br on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# StandardConformerGenerator    :  23%|█▊      | 417/1847 [00:08<00:20, 70.64it/s]Warning: OEMMFFParams::PrepMol() : unable to type atom 1 Br on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 Br on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 Br on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 Br on residue UNL-1
# ...
# [15:39:53] UFFTYPER: Unrecognized charge state for atom: 1
# [15:39:53] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [15:39:53] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 6 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 15 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 16 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:53] UFFTYPER: Warning: hybridization set to SP3 for atom 6
# [15:39:53] UFFTYPER: Unrecognized charge state for atom: 6
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:53] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [15:39:53] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 9 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 10 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:53] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [15:39:53] UFFTYPER: Unrecognized charge state for atom: 1
# Warning: : Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 1 P on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 7 H on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 8 H on residue UNL-1
# Warning: : Force field setup failed due to missing parameters
# [15:39:53] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [15:39:53] UFFTYPER: Unrecognized charge state for atom: 1
# [15:39:53] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [15:39:53] UFFTYPER: Unrecognized charge state for atom: 1
# StandardConformerGenerator    : 100%|███████| 1847/1847 [01:20<00:00, 22.92it/s]
# Preparation                   :   8%|▌      | 147/1844 [00:01<00:12, 131.77it/s]Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Preparation                   :  23%|█▌     | 415/1844 [00:03<00:09, 143.92it/s]Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Preparation                   :  23%|█▋     | 430/1844 [00:03<00:10, 129.00it/s]Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Preparation                   :  29%|██     | 541/1844 [00:04<00:09, 135.94it/s]Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Preparation                   :  31%|██▏    | 569/1844 [00:04<00:10, 123.07it/s]Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Preparation                   :  33%|██▎    | 607/1844 [00:04<00:10, 119.08it/s]Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Preparation                   :  34%|██▍    | 633/1844 [00:05<00:10, 120.47it/s]Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Preparation                   :  39%|██▋    | 714/1844 [00:05<00:09, 115.76it/s]Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Preparation                   :  52%|███▋   | 968/1844 [00:07<00:06, 126.88it/s]Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 1 of molecule ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Preparation                   :  59%|███▌  | 1081/1844 [00:09<00:07, 108.51it/s]Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Preparation                   :  59%|███▌  | 1094/1844 [00:09<00:06, 113.88it/s]Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Preparation                   :  64%|███▊  | 1171/1844 [00:09<00:05, 120.95it/s]Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Preparation                   :  65%|███▉  | 1199/1844 [00:09<00:05, 126.46it/s]Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Preparation                   :  70%|████▏ | 1292/1844 [00:10<00:04, 129.31it/s]Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Preparation                   :  77%|████▋ | 1422/1844 [00:11<00:03, 122.56it/s]Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Preparation                   :  79%|████▋ | 1448/1844 [00:11<00:03, 117.12it/s]Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Preparation                   :  79%|████▊ | 1460/1844 [00:12<00:03, 116.84it/s]Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 2 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Preparation                   :  82%|████▉ | 1509/1844 [00:12<00:03, 110.76it/s]Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 3 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Preparation                   :  83%|████▉ | 1534/1844 [00:12<00:02, 113.22it/s]Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 9 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 9 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 9 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToSTDInChIKey when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 9 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChI when writing ''
# Warning: OE3DToAtomStereo is unable to perceive atom stereo from a flat geometry on atom 9 of molecule ''
# Warning: OE3DToAtomStereo had a problem during OEMolToInChIKey when writing ''
# Preparation                   :  86%|██████ | 1592/1844 [00:13<00:02, 99.66it/s]Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Preparation                   :  91%|█████▍| 1677/1844 [00:14<00:01, 106.11it/s]Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Warning: bond stereochemistry may be assigned incorrectly for molecule
# Preparation                   : 100%|██████| 1844/1844 [00:15<00:00, 118.88it/s]

# %%
dataset.n_molecules
# Out:
# 1844

# %%
print(description)
# Out:
# This optimization dataset adds more coverage for rare parameters, as listed in `inputs/`.
# The parameters, as in Sage 2.2.1 are:
# - a16, a36, a7
# - b15, b23, b24, b29, b40, b42, b44, b47, b49, b54, b55, b59, b62, b63, b64, b65, b67, b69, b74, b76, b77, b78, b80, b81, b82
# - i4, i5
# - t101, t102, t103, t112, t113, t114, t12, t126, t128, t129, t136, t137, t138a, t141, t141a, t141c
# - t154, t158, t164, t165, t167, t30, t31a, t33, t42a, t49, t54, t55, t59, t60, t61, t62, t7, t73, t8, t81, t88, t89.
#
# Molecules were generated according to the process in https://github.com/lilyminium/fragment-chembl-data/commit/1a85d6b296350867a134529aa76930965a710a68
# repo. In short, for torsions:
#
# - ChEMBL molecules were split into "elementary" fragments without rotatable bonds
# - Elementary fragments were combined with a single bond
# - For each torsion, a pool of up to 5000 molecules were initially selected after sorting for low molecular weight
# - Up to 250 molecules were selected from this pool by maximising chemical diversity, using the Tanimoto distance of the Morgan fingerprints
# - Up to 10 molecules were selected from the second pool by maximising the diversity of coupled torsions through the central bond
#
# For bonds, angles, and impropers:
# - For each torsion, a pool of up to 10000 molecules were initially selected after sorting for low molecular weight
# - Up to 500 molecules were selected from this pool by maximising chemical diversity, using the Tanimoto distance of the Morgan fingerprints
# - Up to 50 molecules were selected from the second pool by maximising the diversity of other parameters applied to the atoms of each parameter
#
#
# This dataset uses the OpenFF default level of theory (B3LYP-D3BJ/DZVP).
# It covers the H, N, P, F, Br, C, I, Cl, S, O elements and -3.0, -2.0, -1.0, 0.0, 1.0, 2.0 charges.
# Molecular MW ranges from 32 – 313 Da with mean MW of 126 Da.

# %%
# summarize dataset for readme
confs = np.array([len(mol.conformers) for mol in dataset.molecules])

print("* Number of unique molecules:", dataset.n_molecules)
# With multiple torsions per unique molecule, n_molecules * confs.mean() no
# longer equals the number of conformers. instead, the number of dihedrals *
# confs.mean() should equal the number of conformers. The dataset contains one
# record per driven torsion (rather than combining multiple dihedrals into the
# same record), so n_records is the same as manually adding up len(dihedrals)
# for each record.
print("* Number of filtered molecules:", dataset.n_filtered)
print("* Number of conformers:", sum(confs))
print(
    "* Number of conformers per molecule (min, mean, max): "
    f"{confs.min()}, {confs.mean():.2f}, {confs.max()}"
)

masses = [
    [
        sum([atom.mass.m for atom in molecule.atoms])
        for molecule in dataset.molecules
    ]
]
print(f"* Mean molecular weight: {np.mean(np.array(masses)):.2f}")
print(f"* Min molecular weight: {np.min(np.array(masses)):.2f}")
print(f"* Max molecular weight: {np.max(np.array(masses)):.2f}")
print("* Charges:", sorted(set(m.total_charge.m for m in dataset.molecules)))


print("## Metadata")
print(f"* Elements: {{{', '.join(dataset.metadata.dict()['elements'])}}}")


fields = [
    "basis",
    "implicit_solvent",
    "keywords",
    "maxiter",
    "method",
    "program",
]
for spec, obj in dataset.qc_specifications.items():
    od = obj.dict()
    print("* Spec:", spec)
    for field in fields:
        print(f"\t * {field}: {od[field]}")
    print("\t* SCF properties:")
    for field in od["scf_properties"]:
        print(f"\t\t* {field}")


# export the dataset
dataset.export_dataset("dataset.json.bz2")
dataset.molecules_to_file("output.smi", "smi")
dataset.visualize("dataset.pdf", columns=8)
# Out:
# * Number of unique molecules: 1844
# * Number of filtered molecules: 3
# * Number of conformers: 2430
# * Number of conformers per molecule (min, mean, max): 1, 1.32, 6
# * Mean molecular weight: 125.99
# * Min molecular weight: 32.05
# * Max molecular weight: 312.99
# * Charges: [-3.0, -2.0, -1.0, 0.0, 1.0, 2.0]
# ## Metadata
# * Elements: {Cl, C, H, S, F, N, P, Br, I, O}
# * Spec: default
# 	 * basis: DZVP
# 	 * implicit_solvent: None
# 	 * keywords: {}
# 	 * maxiter: 200
# 	 * method: B3LYP-D3BJ
# 	 * program: psi4
# 	* SCF properties:
# 		* dipole
# 		* quadrupole
# 		* wiberg_lowdin_indices
# 		* mayer_indices
