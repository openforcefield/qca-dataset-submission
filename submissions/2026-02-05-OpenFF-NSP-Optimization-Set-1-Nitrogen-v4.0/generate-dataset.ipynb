# %% [markdown]
# # OpenFF NSP Optimization Set 1 Nitrogen v4.0
#
# This notebook generates optimizations for Nitrogen set of molecules in the NSP molecules set obtained from Pubchem.

# %%
import pathlib
from pprint import pprint
from openff.toolkit import Molecule
import numpy as np

from openff.qcsubmit import workflow_components
from openff.qcsubmit.factories import OptimizationDatasetFactory
from openff.qcsubmit.utils.visualize import molecules_to_pdf

# %%
input_file = 'set1-N-smiles.smi'
molecules = Molecule.from_file(input_file, allow_undefined_stereo=True)
molecules_to_pdf(molecules, f"dataset.pdf")

# %%
len(molecules)
# Out:
# 604

# %%
dataset_factory = OptimizationDatasetFactory()
dataset_factory.add_workflow_components(
    workflow_components.StandardConformerGenerator(max_conformers=10)
)

description = """\
Optimization dataset to probe coverage of nitrogen, sulfur, and phosphorus (i.e., NSP) functional groups in general, and nitrogen in particular. Molecules were curated from PubChem datasets, retaining those with HAC < 40 and applying additional filters; the preprocessing steps are detailed at https://github.com/pavankum/NSP_sets. This dataset includes a broader set of molecules, many of which may not be drug-like, but are informative for differentiating force field parameter ranges. In addition to the default OpenFF QC specification (B3LYP-D3BJ/DZVP), an SPICE-level QC specification (ωB97M-D3BJ/def2-TZVPPD) is included, since many molecules have charged states. Set1 prioritizes neutral molecules first, followed by charged molecules.

- Number of unique molecules: 604
- Number of filtered molecules: 0
- Number of conformers: 3390
- Number of conformers per molecule (min, mean, max): 1, 5.61, 10
- Mean molecular weight: 248.42
- Min molecular weight: 67.05
- Max molecular weight: 593.89
- Charges: [-1.0, 0.0, 1.0]
## Metadata
- Elements: {P, O, C, F, N, H, Br, Cl, I, S}
- Spec: default
	 - basis: DZVP
	 - implicit_solvent: None
	 - keywords: {}
	 - maxiter: 200
	 - method: B3LYP-D3BJ
	 - program: psi4
	- SCF properties:
		- dipole
		- quadrupole
		- wiberg_lowdin_indices
		- mayer_indices
		- lowdin_charges
		- mulliken_charges
- Spec: WB97M-D3BJ/def2-TZVPPD
	 - basis: def2-TZVPPD
	 - implicit_solvent: None
	 - keywords: {}
	 - maxiter: 200
	 - method: WB97M-D3BJ
	 - program: psi4
	- SCF properties:
		- dipole
		- quadrupole
		- wiberg_lowdin_indices
		- mayer_indices
		- lowdin_charges
		- mulliken_charges
"""

dataset = dataset_factory.create_dataset(
    dataset_name="OpenFF NSP Optimization Set 1 Nitrogen v4.0",
    tagline="Molecules curated from Pubchem for Nitrogen",
    description=description,
    molecules=molecules,
)

dataset.metadata.submitter = "pavankum"
dataset.metadata.long_description_url = (
    "https://github.com/openforcefield/qca-dataset-submission/tree/master/"
    "submissions/" + str(pathlib.Path.cwd().name)
)
# Out:
# Deduplication                 : 100%|████████| 604/604 [00:01<00:00, 358.51it/s]
# StandardConformerGenerator    :   0%|                   | 0/604 [00:00<?, ?it/s]Warning: Pubchem_CID_4: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_28: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_26: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_24: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_29: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_23: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   0%|           | 1/604 [00:03<38:04,  3.79s/it]Warning: Pubchem_CID_63: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   0%|           | 3/604 [00:04<12:04,  1.21s/it]Warning: Pubchem_CID_152: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_128: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_237: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_245: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_298: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_320: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_336: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_92: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_191: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_314: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_408: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_415: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_416: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_432: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_409: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_554: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_589: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1258: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2252: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1562: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1850: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1620: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2020: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2304: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2358: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2491: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_154: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_185: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_236: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_414: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_433: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_579: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_902: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2174: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2609: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2654: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4258: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4676: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_15392: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_15898: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_22532: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_499: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2779: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1227: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2921: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3156: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3291: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3535: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3788: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4626: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_782: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_833: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2271: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2555: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2663: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2952: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_45465: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2339: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2569: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2576: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2594: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2659: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2724: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2479: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4509: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_8271: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_17: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_232: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_690: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_632: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_694: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_830: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_30: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2042: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2867: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_5432: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_5039: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3944: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_5637: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_7626: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_12807: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4227: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_7200: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_7292: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_8069: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_9023: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_9497: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_9924: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_12917: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_12143: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_152778855: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_148245197: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_147998341: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2027163: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2751: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2563: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3702: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3768: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_5586: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_9835: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_17229: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_19021: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_26804: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_43880: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_52067: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_52648: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_85190956: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_152298473: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_13376329: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_13424993: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_14145607: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_383296: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_77914208: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_74523063: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_78393946: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_76844631: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2225: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2295: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1840: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2420: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_5124: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1419: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1600: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2942: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4278: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_5131: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_19856: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_53660: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_5726: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_71886: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2036: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2045: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2056: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_11382: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_43589: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_275: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_427: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_828: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2105: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3428: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3910: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_22323: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_29786: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_57461: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_438: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1065: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1523: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1373: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1959: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2397: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2424: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1805: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2245: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2610: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2655: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4415: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_4857: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_5370: Failed due to unspecified stereochemistry
# Warning: 1024 max ring conf limit reached for C1CCC(=O)NCCCCCC(=O)NCC1
# Warning: Pubchem_CID_1497: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_85806943: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_140533775: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_140400784: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_140417843: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2102: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2302: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2982: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_5305: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_5612: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_193: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_211: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_776: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1463: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_224: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_1958: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_2440: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_56046: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_49401724: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_3859: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_16118: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_68785: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_131351: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_290021: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_332505: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_338118: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_372256: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_423323: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_72601: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_438628: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_32807908: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_77995688: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_78088163: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_76312975: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_12509541: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_12509544: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_12509550: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_52818: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_54163: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_54738: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_62179: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_63976: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_127667: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_147348: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_237852: Failed due to unspecified stereochemistry
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 N on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 S on residue UNL-1
# Warning: Pubchem_CID_19040046: Force field setup failed due to missing parameters
# Warning: OEMMFFParams::PrepMol() : unable to type atom 2 N on residue UNL-1
# Warning: OEMMFFParams::PrepMol() : unable to type atom 3 S on residue UNL-1
# Warning: Pubchem_CID_19040046: Force field setup failed due to missing parameters
# Warning: Pubchem_CID_140408765: Failed due to unspecified stereochemistry
# Warning: Hit maximum duplicate removal time limit for Pubchem_CID_24
# Warning: Pubchem_CID_385501: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_74402505: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_85122998: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_76061105: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_76333621: Failed due to unspecified stereochemistry
# Warning: Pubchem_CID_100627: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :   9%|▊         | 52/604 [02:35<02:42,  3.40it/s]Warning: Pubchem_CID_270895: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  10%|█         | 63/604 [02:35<01:19,  6.78it/s]Warning: Pubchem_CID_283963: Failed due to unspecified stereochemistry
# StandardConformerGenerator    :  12%|█▏        | 71/604 [02:48<00:49, 10.69it/s]Warning: 1024 max ring conf limit reached for CC1CC(=O)OC(C=CC(C(=CCc2ccccc2C(=O)O1)C)O)C
# Warning: 1024 max ring conf limit reached for CC1CC=CC2C(C(=C)C(C3C2(C(C=CC(C1)(C)O)O)C(=O)NC3C)C)O
# StandardConformerGenerator    : 100%|█████████| 604/604 [04:47<00:00,  2.10it/s]
# Preparation                   : 100%|█████████| 604/604 [00:49<00:00, 12.11it/s]

# %%
dataset.n_molecules
# Out:
# 604

# %% [markdown]
# Add a new qcspecification to the factory which will be applied to the dataset.
#
#     Parameters:
#         method: The name of the method to use eg B3LYP-D3BJ
#         basis: The name of the basis to use can also be `None`
#         program: The name of the program to execute the computation
#         spec_name: The name the spec should be stored under
#         spec_description: The description of the spec
#         store_wavefunction: what parts of the wavefunction that should be saved
#         overwrite: If there is a spec under this name already overwrite it
#         implicit_solvent: The implicit solvent settings if it is to be used.
#         maxiter: The maximum number of SCF iterations that should be done.
#         scf_properties: The list of SCF properties that should be extracted from the calculation.
#         keywords: Program specific computational keywords that should be passed to
#             the program

# %%
dataset.add_qc_spec(method='WB97M-D3BJ',
                    basis='def2-TZVPPD',
                    program='psi4',
                    spec_name="WB97M-D3BJ/def2-TZVPPD",
                    spec_description="SPICE sets level of theory",
                    store_wavefunction='none',
                    implicit_solvent=None,
                    maxiter=200,
                    scf_properties=['dipole', 'quadrupole', 'wiberg_lowdin_indices', 'mayer_indices', 'lowdin_charges', 'mulliken_charges'],
                    keywords={}
                    )
dataset.add_qc_spec(method='B3LYP-D3BJ',
                    basis='DZVP',
                    program='psi4',
                    spec_name="default",
                    spec_description="Standard OpenFF optimization quantum chemistry specification.",
                    store_wavefunction='none',
                    implicit_solvent=None,
                    maxiter=200,
                    scf_properties=['dipole', 'quadrupole', 'wiberg_lowdin_indices', 'mayer_indices', 'lowdin_charges', 'mulliken_charges'],
                    keywords={},
                    overwrite=True
                    )

# %%
pprint(dataset.dict()['qc_specifications'])
# Out:
# {'WB97M-D3BJ/def2-TZVPPD': {'basis': 'def2-TZVPPD',
#                             'implicit_solvent': None,
#                             'keywords': {},
#                             'maxiter': 200,
#                             'method': 'WB97M-D3BJ',
#                             'program': 'psi4',
#                             'scf_properties': ['dipole',
#                                                'quadrupole',
#                                                'wiberg_lowdin_indices',
#                                                'mayer_indices',
#                                                'lowdin_charges',
#                                                'mulliken_charges'],
#                             'spec_description': 'SPICE sets level of theory',
#                             'spec_name': 'WB97M-D3BJ/def2-TZVPPD',
#                             'store_wavefunction': 'none'},
#  'default': {'basis': 'DZVP',
#              'implicit_solvent': None,
#              'keywords': {},
#              'maxiter': 200,
#              'method': 'B3LYP-D3BJ',
#              'program': 'psi4',
#              'scf_properties': ['dipole',
#                                 'quadrupole',
#                                 'wiberg_lowdin_indices',
#                                 'mayer_indices',
#                                 'lowdin_charges',
#                                 'mulliken_charges'],
#              'spec_description': 'Standard OpenFF optimization quantum '
#                                  'chemistry specification.',
#              'spec_name': 'default',
#              'store_wavefunction': 'none'}}

# %%
# summarize dataset for readme
confs = np.array([len(mol.conformers) for mol in dataset.molecules])

print("- Number of unique molecules:", dataset.n_molecules)
print("- Number of filtered molecules:", dataset.n_filtered)
print("- Number of conformers:", sum(confs))
print(
    "- Number of conformers per molecule (min, mean, max): "
    f"{confs.min()}, {confs.mean():.2f}, {confs.max()}"
)

masses = [
    [
        sum([atom.mass.m for atom in molecule.atoms])
        for molecule in dataset.molecules
    ]
]
print(f"- Mean molecular weight: {np.mean(np.array(masses)):.2f}")
print(f"- Min molecular weight: {np.min(np.array(masses)):.2f}")
print(f"- Max molecular weight: {np.max(np.array(masses)):.2f}")
print("- Charges:", sorted(set(m.total_charge.m for m in dataset.molecules)))


print("## Metadata")
print(f"- Elements: {{{', '.join(dataset.metadata.dict()['elements'])}}}")


fields = [
    "basis",
    "implicit_solvent",
    "keywords",
    "maxiter",
    "method",
    "program",
]
for spec, obj in dataset.qc_specifications.items():
    od = obj.dict()
    print("- Spec:", spec)
    for field in fields:
        print(f"\t - {field}: {od[field]}")
    print("\t- SCF properties:")
    for field in od["scf_properties"]:
        print(f"\t\t- {field}")


# export the dataset
dataset.export_dataset("dataset.json.bz2")
dataset.molecules_to_file("dataset.smi", "smi")
dataset.visualize("dataset.pdf", columns=4)
# Out:
# - Number of unique molecules: 604
# - Number of filtered molecules: 0
# - Number of conformers: 3390
# - Number of conformers per molecule (min, mean, max): 1, 5.61, 10
# - Mean molecular weight: 248.42
# - Min molecular weight: 67.05
# - Max molecular weight: 593.89
# - Charges: [-1.0, 0.0, 1.0]
# ## Metadata
# - Elements: {I, P, Br, Cl, O, N, C, S, H, F}
# - Spec: default
# 	 - basis: DZVP
# 	 - implicit_solvent: None
# 	 - keywords: {}
# 	 - maxiter: 200
# 	 - method: B3LYP-D3BJ
# 	 - program: psi4
# 	- SCF properties:
# 		- dipole
# 		- quadrupole
# 		- wiberg_lowdin_indices
# 		- mayer_indices
# 		- lowdin_charges
# 		- mulliken_charges
# - Spec: WB97M-D3BJ/def2-TZVPPD
# 	 - basis: def2-TZVPPD
# 	 - implicit_solvent: None
# 	 - keywords: {}
# 	 - maxiter: 200
# 	 - method: WB97M-D3BJ
# 	 - program: psi4
# 	- SCF properties:
# 		- dipole
# 		- quadrupole
# 		- wiberg_lowdin_indices
# 		- mayer_indices
# 		- lowdin_charges
# 		- mulliken_charges
